# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
import pandas as pd
pd.options.display.max_rows = 3000
pd.options.display.max_columns = 100
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# 텍스트 전처리
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from konlpy.tag import Okt 
import MeCab
mecab = MeCab.Tagger()
import re 
from string import punctuation
import requests
import pickle
import ast

# 토픽모델링
import gensim
from gensim import corpora, models
from gensim.models import CoherenceModel
import pyLDAvis 
import pyLDAvis.gensim

# %% [markdown]
# #### 미리 만들어둔 리뷰데이터 불러오기

# %%
df = pd.read_csv("D:/review.csv")

# %%
df
# Out:
#             DATE  STAR                                             REVIEW  \
# 0     2019-12-27     5  부산에도 기다리던 지역화폐가 나왔네요 앱도 깔끔하고 카드도 바로 신청하고 잘 사용하...
# 1     2019-12-27     5                                                화이팅
# 2     2019-12-28     5                                 기다렸었는데 앞으로 잘 쓸게요^^
# 3     2019-12-28     5    동백전으로 여기저기 많이 사용해 볼게요. 부산 경제에도 많은 도움이 되면 좋겠습니다.
# 4     2019-12-28     5              부산 동백전 쓰기 편하게 잘 만들어졌네요 부산에서 혜택이 많았겠네요
# 5     2019-12-28     5                  잘 사용해 볼게요. 동백전으로 혜택 많이 받으면 좋겠습니다.
# 6     2019-12-28     5                                   가자 글로벌 테스트베드 부산!
# 7     2019-12-29     5  오~ 부산도 드디어 모바일 지역화폐가 나왔네요!~ 앱설치하고 카드신청도 해봤는데요 ...
# 8     2019-12-30     5               드디어 기다리던 동백전앱이 출시됐네요 앞으로 이용 많이 하겠습니다
# 9     2019-12-30     4     군더더기 없는 ui가 마음에 드는군요. 많은 사업장에서 사용가능하면 더 좋겠습니다.
# 10    2019-12-30     5                                                좋아요
# 11    2019-12-30     1  선택약정선택하면 네트워크장애라고 뜨면서 진행되지 않음...부산시에서 개인정보를 팔아...
# 12    2019-12-30     5                        많은 이용 바랍니다 부산시민과 함께 성장해 갑시다
# 13    2019-12-30     5  부산을 대표하는 꽃 이름으로 지은 동백전. 이름이 멋지네요. 부산에서 이용하는 혜택...
# 14    2019-12-30     3                                       편의점에서도 사용되나요
# 15    2019-12-30     5                                    설치가 아주 간단하고 쉽네요
# 16    2019-12-30     5                          군더더기 없이 사용하기 편하고 좋습니다. ^^
# 17    2019-12-30     5                   어플이 깔끔하니 사용하기 좋아요 자주 사용하게 될듯 하네요
# 18    2019-12-31     1         아니 QR코드 결제가 안되냐 기본인데 하. 카드 신청도 잘 안되고 미치겄네.
# 19    2020-01-01     5  회원가입이 안 돼요 다음주에 만 18세 되는 사람인데요 계속 만 14세 이상만 가입...
# 20    2020-01-01     5  적립한도 볼 수 있게 잘 쓰고 있는데 충전한도 말고 적립한도도 볼 수 있게 하면 훨...
# 21    2020-01-01     1  지웠다 깔아도 들어갈 수가 없음 -_- 마트에서는 결제가 안됐다고 하고 돈이 빠졌는...
# 22    2020-01-01     1  앱 오류 안고쳐주실건가요?? 충전하려고 앱들어가면 데이터 상태로는 들어가지지도 않고...
# 23    2020-01-01     1  오류 좀 개선해주새오 너무 오류가 심해요. 캐시백이 안되어서 문의했더니 다시 가게에...
# 24    2020-01-01     3           앱실행이 안됩니다 사용자 정보 취득에 실패하였다면서 앱이 꺼져버립니다….
# 25    2020-01-01     1                          안들어가져요 먹통입니다..다시 설치해도 그래요
# 26    2020-01-01     1               정말 오류가 많이 뜨네요 오류가 계속 떠서 사용하기 너무 힘들어요
# 27    2020-01-01     1  발급받은 지 한참 지났는데 앱 오류 때문에 충전을 못합니다 빨리 개선 부탁드립니다…...
# 28    2020-01-01     1          안켜져요 ㅠㅠ 계속 오류나서 새로 설치했는데 자꾸 네트워크 오류라고 하네요
# 29    2020-01-01     1                       욕나올정도로 후짐 며칠전부터 가맹점조회 아예 안됨.
# 30    2020-01-01     1  동백전 카드 결제지연 오류 아니 무슨 카드가 사용자가 많다고 오류가 되서 계산이 안...
# 31    2020-01-01     3  가맹점 찾기 4/2일까지는 문제 없었는데 4/3일 서버 폭주로 접속 제한된 다음부터...
# 32    2020-01-01     3  갑자기 가맹점 찾기가 안되요 갑자기 가맹점 찾기가 안되요 삭제후 재설치 했는데도 안...
# 33    2020-01-01     3     가맹점찾기 가맹점찾기 아무것도 안뜨고 도대체 어딜 봐야하나요? 오류가 너무 잦아요!
# 34    2020-01-01     4  가맹점 찾기가 안 되어 문의드립니다. 동백전 정말 잘 사용하고 있어요! 캐시백 10...
# 35    2020-01-01     1                         가맹점 가맹점 찾기 아예안되요 쓰지말라는건가요?
# 36    2020-01-01     1  어플이 진짜 구려요 오류나서 접속이 안되고 로그인도 안되고..써야할 때 못쓰면 무슨...
# 37    2020-01-01     3  가맹점 찾기 가맹점검색하려면 0만뜨고 전에는 검색이 됐는데ㅠㅠ 아무것도 안나오는데 ...
# 38    2020-01-01     3  오류가 장난 아니네요;;;; 좋아요~ 포인트도 많이 쌓이고 돈쓸맛 나는데 오류가 심...
# 39    2020-01-01     1  갑자기 왜 안들어가지죠 낮에 분명 사용하고 방금 가맹점 카페와서 사용하려고 하는데 ...
# 40    2020-01-01     1  못쓰겠네요 버그빨리 수정요 뭔 자꾸 튕기니 ㅋㅋㅋ 쓰지말라는 뜻인가요? 빨리 버그 ...
# 41    2020-01-01     3  가맹점찾기 다 좋은데 얼마전부터 가맹점찾기가 안되네요 계속 0건만 뜹니다 빨리 해결...
# 42    2020-01-01     4  네트워크 네트워크로 인해 실행이 안된다고 뜨네욤,,, 아까 까지 되었는데,,, 수정...
# 43    2020-01-01     3  기간별 검색기능 강화 요청 예를들어 4월1일부터 오늘까지 사용실적 또는 적립실적 검...
# 44    2020-01-01     2    문자인증이 안와요 어플이 안켜져서 삭제했다가 다시 깔았는데 문자인증메세지가 안와요ㅠㅠ
# 45    2020-01-01     4  교통카드 이용내역 다 좋은데 카드 이용 내역에 후불교통카드로 쓰인 금액도 적혀있으면...
# 46    2020-01-01     3  한달동안 결제한 내역 총 합계를 볼 수 있었으면 한달동안 결제한 내역 총 합계를 볼...
# 47    2020-01-01     1  문제가 많네요 50만원 충전했다가 충전취소하고 다시 충전하려고 했더니 충전이 안되는...
# 48    2020-01-01     1  앱 쓰레기 동백전 신청하려고 앱 깔았는데 에러만 벌써 15번째… KT에서 개발한거라...
# 49    2020-01-01     1                                최악 어플이되야ㅡ쓰죠!!!!!!!!
# 50    2020-01-01     1  금액 충전이 안 되고 자꾸 꺼져요 금액 충전해서 쓰고 싶은데 앱이 자꾸 다운되고 꺼...
# 51    2020-01-01     1   사용내역 보려고 하면 어플이 꺼져요 충전만 되고 뭐 하려고 하면 꺼져서 쓸수가없어요^^
# 52    2020-01-01     1         안켜져요 업데이트하고나서 동백전 어플이 안들어가집니다. 오류 보완 부탁드려요
# 53    2020-01-01     1  어플을 운영을 하실거면, 불편함은 제때 개선좀 하세요 국민들 불편함 의견제기 1. ...
# 54    2020-01-01     5                             열면 안들어지네요 안들어가쟈여 고쳐주세요
# 55    2020-01-01     5  잘 쓰고 있어요 렉이나 오류도 없고 캐시백도 많이 받아서 쓰는 재미가 쏠쏠하고 좋아...
# 56    2020-01-01     1            오류 어플 오류가 너무 많아요 쓰고싶을때 한번도 제대로 써본적이 없어요
# 57    2020-01-01     1  이번달만 오류가 몇번인지..ㅡㅡ 하 이렇게 오류가 많이 나는데 어찌 쓰란말인가요? ...
# 58    2020-01-01     3     확실히 진짜 좋은데… 카카오 뱅크 계좌는 왜 등록이 안되는건가요? 정말 불편해요….
# 59    2020-01-01     1                ㅋㅋ고객센터 고객센터 답변 얼마나 기다렸는데 일 쥰나 안 해요~
# 60    2020-01-01     1  결제안된다해서 다른카드로 결제했는데 동백전에선 또 돈이 나가네요 일반 슈퍼인데도 동...
# 61    2020-01-01     4  가맹점 찾기 기능 개선 해주세요 가맹점 찾기 기능에서 현재 위치에서 지도를 보면 사...
# 62    2020-01-01     3  좋긴한데요…. 결제 어플인데 이거 업뎃때문에 못쓴다고 안 막았으면 합니다. 결제해야...
# 63    2020-01-01     5              백원 단위도 충전되게 해주세요ㅠㅠㅠㅠ 제발요 ㅠㅠㅠㅠ다좋은데ㅠㅠㅠㅠ
# 64    2020-01-01     4                       택시는 안되나요? 몇번 결제할려는데 다 안되네요 ㅠ
# 65    2020-01-01     3  가맹점 표시 지도상에 한꺼번에 표시될 수 있게 해 주시고 띄어쓰기 잘못하면 검색이 ...
# 66    2020-01-01     1  사용자정보취득에 실패하였습니다 사용자정보취득에 실패하였습니다 앱을 다시 실행해주세요...
# 67    2020-01-01     2  앱더럽게안됨 안들어가지고 삭제했다가 다시 들어가니 로그인 화면도 없고 회원가입하라고...
# 68    2020-01-01     1  갑자기 안되니까 어이없네… 아니 왜 갑자기 네트워크 불안정 하다고 뜨고 안 들어가지...
# 69    2020-01-01     3  어플실행오류 어플이 갑자기 실행이 안됩니다. 와이파이도하고 데이터로도 해봤지만 두개...
# 70    2020-01-01     3  갑자기 서비스가 안돼요 개인정보 확인이 안된다고? 오류메시지가뜨고 튕겨서 삭제했다 ...
# 71    2020-01-01     4  어플 설치가안되어요ㅠㅠ 잘쓰고있었는데 금일 저녁 씨유에서 카드 주니 포스기에서 결제...
# 72    2020-01-01     1  본인인증단계에서 인증문자가 안와요 개선해주세요 본인인증단계에서 인증문자가 안와요 개...
# 73    2020-01-01     5  이 앱 덕분에 동백전 씁니다 오랜만에 앱 제대로 만들었다 싶네요. 놀라울 정도로 간...
# 74    2020-01-01     4  빠르고 좋은 앱이네요 메인화면 하단 카드바가 메인 화면 진입시 움직이는 모션은 예쁘...
# 75    2020-01-01     5  내가 보유한동백전 칸에 불필요한건 삭제 너무 잘쓰고있습니다 ㅎ 근데 충전할라고 켜면...
# 76    2020-01-01     4                                           좋아요 좋습니당
# 77    2020-01-01     1         앱 사용 내역 볼려고하면 계에에에에ㅔㅔㅔㅔㅔ속 나가지네요 빨리 고쳐 주세요
# 78    2020-01-01     3            큐알 코드 결제 부탁… 실물 카드로만 되는 보네여….. 아이폰은 웁니다
# 79    2020-01-01     1          클릭 안됨 가입 다 하고 맨 마지막에 비밀번호 설정하는 거 클릭이 안되네요
# 80    2020-01-01     1                       쓰라는거야? 카드 신청도 안되고 계좌 등록도 안되고
# 81    2020-01-01     5  너무좋아요 얼마 쓰지도 않았는데 캐시백 쏠쏠해요 5000원 단위 충전도 가능해서 현...
# 82    2020-01-01     5                                   정말 잘쓰고 있습니다!! 굿굿
# 83    2020-01-01     5  금액을 직접 설정해서 충전하면 좋겠어요 정해진 금액만 말고 사용자가 충전하고 싶은 ...
# 84    2020-01-01     1  ㅠ가맹점 찾기라뇨ㅠ 생각보다 안되는곳도 많고 충전금액 환불은 왜 안되는거죠? 계속 ...
# 85    2020-01-01     2  가맹점 찾기 왜있나요? 되는곳도있고 아닌곳이있고. 그게 헷갈려서 찾기 서비스가 있는...
# 86    2020-01-01     3        가맹점이 두개씩 중복되서 나와요 가맹점 검색하면 중복해서 나와서 보기 힘들어요
# 87    2020-01-01     1  인증안됩니다. 전화번호 누르고 인증하기 버튼이 먹통이네요. 혜택도 좋은데 이러다 잊...
# 88    2020-01-01     5  QR코드 간편결제도 되었으면 좋겠어요 카카오페이처럼 QR코드로 간편결제도 되었으면 ...
# 89    2020-01-01     5  동백전 최고 동백전 충전하면 캐쉬백도 10%나 해주고 가정생활에 많은 도움이 되네요...
# 90    2020-01-01     5             할인 많이 되네요 할인 생각보다 많이 되네요 더 가맹점 늘려주시길..
# 91    2020-01-01     1                      안증안되요.. 쓰고싶어도 인증이안되니 쓸수가없네요..
# 92    2020-01-01     1  출시기념 1월 한달간 이벤트를 하는데 1월 지났는데도 아직 다운로드를 받지 못하는 ...
# 93    2020-01-01     5                            기다렸는데 드디어 빨리 가입 흥해라 동백전
# 94    2020-01-01     1         뭐 이런 개쓰레기 같은 앱이 다 있어. 죽도록 카드신청해도 안됨. 안써!!!
# 95    2020-01-01     4  앱에서 결제되게 해주세요 동백전 좋다 좋다 말 많이 듣고 드디어 실물카드 받았습니다...
# 96    2020-01-01     1  실행이 안됩니다 어플을 실행시키면 알림설정 창과 필수동의 까지는 되는데 그 다음 화...
# 97    2020-01-01     5                          쓸만하네요 캐시백 비율이 높아서 쓰는데 좋네요
# 98    2020-01-01     5            국굿 아이폰 바코드나 큐알코드 결제만 앱에서 가능 하면 최고일것 같아요
# 99    2020-01-01     5                                     어플 오류 아예 접속 불가
# 100   2020-01-01     4                       너무 좋은데 앱실행이 안되요 저만 안되나요!!!??
# 101   2020-01-01     1  앱 오류 빨리좀 해결해주세요 잘사용하다가 앱켜면 사용자정보를 읽을수없다고 다시시도해...
# 102   2020-01-01     1  잘사용하고있었는데 잘 사용하고있던 중이었는데 갑자기 앱 오류로 안들어가져서 앱삭제하...
# 103   2020-01-01     1       아예오류나고안들어가져요 오류나고 아예안들어가지는데 어떻게요? 서버없다고만 뜨고요
# 104   2020-01-01     4  사용자찾을 수 없다고 오류가 계속 뜨고 넘어가질 않는데 왜그럴까요ㅠ 어플 삭제 후에...
# 105   2020-01-01     5  어제까지 앱실행 잘 됐는데 No server is available to handl...
# 106   2020-01-01     1  오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하...
# 107   2020-01-01     1                        503오류 뜨면서 실행안되네요 우째해야되나요ㅡ.ㅡ
# 108   2020-01-01     1   돈 넣었는데 어플 실행이 안돼요 ? 잘 쓰다가 돈 남아있는데 어플 실행이 안돼요 뭔데요
# 109   2020-01-01     1  오류 갑자기 오늘 접속오류 계속 뜨길래 삭제 후 다시 깔았더니 아예 안되네요; 빠른...
# 110   2020-01-01     1                             아이폰 X 충전안됨 충전하러 가면 튕겨요
# 111   2020-01-01     2  내역만 들어가면 팅김 내역에 들어가면 팅겨요. 아이폰 xs입니다. 다른 내역 확인 ...
# 112   2020-01-01     1  카드신청안됨 다 하고 마지막에 계속 오류가 나요ㅠ 청구서 수령관련 등록을 해야된다는...
# 113   2020-01-01     1  왜때문에 인증이안되나효 내이름에 내 탄생일에 내 명의의 핸드폰번혼데 자꾸 확인하래 ...
# 114   2020-01-01     1  고객 서비스가 최악이네요 어플 오류로 인하여 충전 하려고 하니 바탕화면으로 팅기는데...
# 115   2020-01-01     1                 안들어가져요 업데이트 했는데 안들어가져요.. 해결 좀 해주세여
# 116   2020-01-01     1  앱 꺼짐 문제 앱 들어가서 캐쉬백을 누르면 앱이 꺼져버리는데 어떻게 해야되나요? 다...
# 117   2020-01-01     1    불안정한 앱 이용내역 확인 시 강제종료 앱 메뉴도 간단하고 동백전 서비스도 훌륭한데
# 118   2020-01-01     1  ㅠ 주민등록증 찍는데 청소년들은 청소년증으로 하라해서 청소년증 찍고 발급날짜 했는데...
# 119   2020-01-01     4  개선사항 요청하고 싶습니다! 본인 인증 수단을 공인인증서도 추가 하였으면 좋겠습니다...
# 120   2020-01-01     2  동백전 어플설치 저는 아이폰이라 설치를 했지만, 아버지도 동백전 어플 설치해드리려고...
# 121   2020-01-01     3  어플 팅김현상 2월달부터 잘 사용하다가 오늘 업데이트를 했는데 어플 접속이 안됩니다...
# 122   2020-01-01     4  동백점 미가맹점 결제 가능 요청 잘 사용중입니다. 감사합니다^^* 다만 동백점 미가...
# 123   2020-01-01     5  아이폰에서도 쓸 수 있어 좋아요 동백전 아이폰에서도 쓸 수 있어서 좋아요. 자주 사...
# 124   2020-01-01     5                        동백전 아이폰 앱 드디어 출시됐네요… 잘 쓸게요…
# 125   2020-01-01     1  노트2에서는 버전이 낮아서 검색이 안되는데.. 어느버전 까지 가능 한가요? 앱 다운...
# 126   2020-01-01     5  부산경제를 위한 동백전이네요.. 10% 혜택을 주니 잘 사용하겠습니다. 앱 사용이 ...
# 127   2020-01-01     1                                         아이폰은 안되나요?
# 128   2020-01-02     5                            이름도 이쁘고 앱도 깔금하게 잘되어 있네요
# 129   2020-01-02     5                                          정말 편리하네요~
# 130   2020-01-02     5             부산시에도 지역화폐가 생겼네요~ 동백전 이름 좋고 화면도 깔끔하네요~
# 131   2020-01-02     5              심플하고 사용하기 편하네요. 잡다한 기능보다 기본에 충실한게 좋죠.
# 132   2020-01-02     5                    부산에서도 이제 사용이 가능하군요..많니 기대가 됩니다.
# 133   2020-01-03     1  아니 QR기반 회사 KT가 왜 카드를 발행해요? 카드는 또 하나카드네? 하도인가? ...
# 134   2020-01-04     1                                   부산은행은 결제계좌로등록이안됨
# 135   2020-01-04     3  카드도 발급받고, 가입도 다 했는데 새로 앱 실행할때마다 인증된 폰번호와 현재 폰번...
# 136   2020-01-05     5  가입하고 카드 신청해놓고 아직 사용은 안해 봤지만 어플은 정말 잘 만들었네요 박수 ...
# 137   2020-01-05     5              부산이 살아야 대한민국이 산다! 부산지역경제를 위하여 똑똑한 소비!
# 138   2020-01-06     5                                                 신청
# 139   2020-01-06     1                 개인 정보 입력만 13회 했습니다. 이 어이없는 오류 뭡니까?
# 140   2020-01-06     1  동백전 앱 들어갈려면 꼭...세,네번만에...들어감....프로그램 개발을 어떻게 한...
# 141   2020-01-08     2                              아직 사용 경험이 없어 잘 모르겠습니다
# 142   2020-01-09     5  시안성과 디자인도 뛰어나 사용이 간편하며, 다양한 혜택이 있어 무조건 강추 합니다....
# 143   2020-01-09     5  이벤트기간에 사용하면 10% 캐시백 즉시 지급되구요 평상시엔 6%적립이 되어서 사용합니다
# 144   2020-01-09     5                사용시 가입자에게 혜택이 매우 큰것 같습니다. 적극 사용할께요.
# 145   2020-01-09     5                                            너무 조아요.
# 146   2020-01-09     5                                         사용편리해서 좋아요
# 147   2020-01-09     5                                           캐시백 개꿀~!
# 148   2020-01-09     1                  네트워크오류로 계속안들어가 지는데 원래이런건가요? 답답하네요
# 149   2020-01-09     5                                         너무 편하고 좋아요
# 150   2020-01-09     3  오늘 카드발급 후 앱을 깔아 하나은행 계좌를 등록했는데 결제상황 등 보유내역 등 전...
# 151   2020-01-09     5                                           응원할께요..,
# 152   2020-01-09     5                         동백전 설치후 사용해보니 새로운 세상이 열리네요
# 153   2020-01-09     5                       앱도 편리해서 사용도 좋고, 캐시백도 좋네요.굿~~
# 154   2020-01-09     5                              사용이 편리하고 앱 디자인도 멋집니다.
# 155   2020-01-09     5                                        혜택이 혜자스럽네요.
# 156   2020-01-09     5         바로바로 캐시백이 들어오니까 혜택이 더욱 크게 느껴지네요! 굿입니다 ^^bb
# 157   2020-01-09     5  앱설치 후 사용해보니 App 디자인도 세련되었고 심플한것이 너무너무 마음에 들어요....
# 158   2020-01-09     5  동백전을 설치 후 사용해보니 새로운 세상이 열리네요..^^ 앞으로 카드사용은 자제하...
# 159   2020-01-09     5                                            캐쉬백 좋아요
# 160   2020-01-09     5                                      사용하기에 매우 편리 함
# 161   2020-01-09     5         체크카드라서 좋아요 10퍼센트 페이백 좋네요 프로모션기간이 길었으면 좋겠어요
# 162   2020-01-10     5                          좋아요. qr코드결제도 어서 됐으면 좋겠네요.
# 163   2020-01-10     5                                               Good
# 164   2020-01-10     5                                           좋은것 같아요ᆢ
# 165   2020-01-10     1        새마을금고 없어 카드발급 안돼요 괜히 충전하여 환불 해주세요 사용도 못 하는데
# 166   2020-01-10     5                                            괜찮아요...
# 167   2020-01-10     5                                캐시백도 바로 사용가능하고 매우만족
# 168   2020-01-10     5                                               신나네요
# 169   2020-01-10     1                                     카드만들다 사용 포기합니다
# 170   2020-01-10     5      할인폭이 너무 크고 넘 편리해요. 우리 부산시 상공인에게 도움된다니 더욱 좋네요.
# 171   2020-01-10     5                       동백전으로 이용할 생각 입니다 사용하기 편리 합니다
# 172   2020-01-10     5                                                 만족
# 173   2020-01-10     2                                충전하려니깐 카카오뱅크가 없네요ㅜㅜ
# 174   2020-01-10     2  본인명의폰 아닌사람은 가입을 못하네요 공인인증같은거나 다른 인증할수있는방법 더 생기...
# 175   2020-01-11     5  아주 유용한 앱 서비스네요. 충전하구 카드 받아서 쓰는 게 좋구 쓰고나니 캐쉬백이 ...
# 176   2020-01-11     1                                            안들어가지네요
# 177   2020-01-11     3  어플에서 바로 결제가 됐으면 좋겠어요. 카드 발급 받는 게 시간도 오래 걸리고 은행...
# 178   2020-01-12     5                             매우 유용합니다. 전 가족이 쓰고 있어요
# 179   2020-01-12     5                                           너무 좋습니다😊
# 180   2020-01-13     5                동백전을 사용해 보니 사용하면 할수록 차곡 차곡 적립되는 캐시백
# 181   2020-01-13     5                           동백전 휴대폰 단말기 살때도 캐시백 되나요?
# 182   2020-01-14     1  너무 어려워요. 충전방식이라 많이 번거롭네요. 폰결제 되는 쉬은 방법으로 업그레이드...
# 183   2020-01-14     3  1:1문의 답변확인이 안되네요 호완성문제인지 다른어플은 정상적으로 작동하는데 이것만...
# 184   2020-01-14     5                                  정말 사용하기 편하고 좋습니다.
# 185   2020-01-14     1                           계좌등록이 계속 실패로 떠서 사용이 불가능함
# 186   2020-01-16     5                                         깔끔하고 혜택 좋고
# 187   2020-01-17     5       회원가입 할때 동의사항들전부선택햇는데도 다음으로 안넘어가지는데 혹시 오류인가요?
# 188   2020-01-17     1  치명적인 단점 지적합니다. 환불정책 정말 불편하네요. 전체 적립금에 60%이상 써야...
# 189   2020-01-18     1  회원가입할때 직장주소 검색하고 다시들어오니까 어플 끄지도 않았는데 처음부터 다시 입...
# 190   2020-01-18     1  아니... 계좌등록하려니 계속 계좌번호 오류라고하는데 왜그런거예요? 숫자 잘못친줄알...
# 191   2020-01-18     5                                              좋아요~~
# 192   2020-01-19     5                        교통카드..버스나 지하철만 써도 캐시백 되나요??
# 193   2020-01-21     1                    앱이 다운로드가 안되고 계속 로딩 중이네요 서버좀 늘려요
# 194   2020-01-22     3  본인명의 핸펀만가능한거가요?? 아이핀이나 본인인증다른방법도 하게 해주세요!! 배우자...
# 195   2020-01-23     1                      들어가지지도 않구만ㅡㅡ 전화도 안받고... 장난합니까
# 196   2020-01-23     3      가맹점찾기가 너무 불편하네요 지도에서 찾기 기능이 있으면 훨씬 찾기 편할것 같아요
# 197   2020-01-23     1  앱 접속시 계속 팅김 카드신청과정에서도 불안정함 주민번호 입력하면 자꾸 다른숫자로 ...
# 198   2020-01-23     5          카드도 너무 예쁘고 앱도 깔끔해서 좋아요 편하게 잘 사용할 것 같네요 :)
# 199   2020-01-23     4  기능도 만족스럽고 검색해서 가맹점 찾을 수 있는거 너무 좋은거 같아요!! 그런데 카...
# 200   2020-01-24     3  18살인데 카드 발급받을때 주민등록증 번호를 작성하라는데 주민등록증이나 운전면허가 ...
# 201   2020-01-25     1                                 최악임 깔고나서 본인인증문자아안옴
# 202   2020-01-26     1               앱 실행이 안됩니다. 네트워크 상태를 확인하라는 매세지만 뜨네요.
# 203   2020-01-29     4  가맹점 찾기 카테고리를 구별로 나누어 주셨으면 좋겠습니다. ㄱ부터 시작하니까 해운대...
# 204   2020-01-29     5                                      정말 유용한 앱이네요~~
# 205   2020-01-30     1             동백전가입시 LGU+알뜰폰은 인증이 안돼 가입이 안됩니다 조정바랍니다
# 206   2020-01-30     5  동백전 정말 좋아요. 어디다가 리뷰를 써야될지 몰라서 여기 씁니다. 우선 적립이 바...
# 207   2020-01-31     1  아직 써보지도 못했을 뿐더러 예기치못한 오류라며 앱 접속조차 안되네요... 부산지역...
# 208   2020-01-31     5  동백전 앱을 다운받아 회원가입 2단계까진 잘되나 다음단계에서 처음단계로 되돌아가버려...
# 209   2020-01-31     3   어제부터 통신중예기치않은 오류라고 앱사용이 불가합니다 무슨문제인거고 언제 정상화되나요?
# 210   2020-01-31     5    본인인증 방법이 폰인증 밖에 없나요? 본인명의의 폰이 아닌 사람은 발급이 불가하나요?
# 211   2020-01-31     4  추천인은 뭘 써야하나요? 한글은 안써지고 숫자는 써지는데 휴대폰번호를 쓰는것도 아닌...
# 212   2020-01-31     5                                                좋아요
# 213   2020-01-31     1  카드신청에 들어가서 카드선택후 신청하기누르면 '일정기간 미사용으로 작업이중단됩니다'...
# 214   2020-01-31     5  다운받았는데 카드신청이 안되네요 계좌등록하고 충전 후에 카드신청 가능한건가요? 사용...
# 215   2020-01-31     2  회원가입시 인증번호가 안옵니다. 이틀째 가입중인데 인증번호가 계속 수신이 안되는데 ...
# 216   2020-02-01     1                           지금 카드사용 불가네요 통신오류 뜹니다 ㅜㅜ
# 217   2020-02-01     5          가맹점 검색에서 지역을 지정 후 검색 가능하도록 기능 추가 부탁 드립니다.
# 218   2020-02-02     3  -네트워크 상태 원할하지 않습니다- 계속 뜨네요. 해결 하셔야 할듯합니다. 속도 제...
# 219   2020-02-02     4                                                좋아요
# 220   2020-02-03     3  껐다가 켜면 다시 처음부터 인증해야 하는 치명적인 버그가 존재합니다. 충전 하자마자...
# 221   2020-02-03     5                              친구가 캐시 바로 들어오더라고 추천해줌
# 222   2020-02-04     5      지역경제에 기여하면서 캐쉬백도 가능한 동백전이 있으니 더이상의 카드는 필요없네요.
# 223   2020-02-04     5                                                좋아여
# 224   2020-02-04     5                                                 최고
# 225   2020-02-04     5                                                  굿
# 226   2020-02-04     5                                                좋아요
# 227   2020-02-04     5                                          세금공제 30프로
# 228   2020-02-04     5                                                 최고
# 229   2020-02-04     4  부산의 주유소에서 사용이 안된다하여 난감한 경험있습니다. 사용가능하도록 지원, 배려...
# 230   2020-02-04     5                      쓰자마자 깨시가 10%로 바로 들어오니깐 완전짱입니다
# 231   2020-02-04     3  슈퍼에서 우유를 2 번 샀읍니다 .10%씩 적립 되여 기분 좋았읍니다. 택시는 개인...
# 232   2020-02-04     5                                        동백전 편하고 좋아요
# 233   2020-02-04     3                              실물카드받았는데 어플엔 등록안되어있어요
# 234   2020-02-04     4                                    지역 자영업에 도움이 됩니다
# 235   2020-02-04     5                                소상공인과 시민들에게 좋은 제도네요
# 236   2020-02-04     2                            걸제불가능한 곳에 대한 정보 제공이 필요함
# 237   2020-02-04     5                                           너무 좋아요ㅎㅎ
# 238   2020-02-04     5                                      케시포인트 너무 좋습니다
# 239   2020-02-04     4                                           절약에 도움이됨
# 240   2020-02-04     5                                             적립 대박~
# 241   2020-02-04     5                                               넘좋아요
# 242   2020-02-04     5                                                멋져요
# 243   2020-02-04     2                         업데이트 실행 안되네요. 삭제 후 재설치도 안됨
# 244   2020-02-04     5                                             캐시백 개꿀
# 245   2020-02-04     5                                              최고입니다
# 246   2020-02-04     5                                                 굿굿
# 247   2020-02-04     1  깔고 위치확인동의 같은 것들 모두 동의 누른다음에 계속 흰화면이 뜨고 한 4~5분 ...
# 248   2020-02-05     2                  동백전 어플들어가니깐 악성코드를탐지햇다고뜨는데 왜그런거에요?
# 249   2020-02-05     5                                                편해요
# 250   2020-02-05     5                                             완전 좋아요
# 251   2020-02-05     1  카드 수령지가 자택 외에 설정이 안되네요... 리뷰 보니 형식적인 답변 뿐이고 활성...
# 252   2020-02-05     5                                            신통방통합니다
# 253   2020-02-05     5                                        정말 좋습니다 굿^^
# 254   2020-02-05     5                                                 구웃
# 255   2020-02-05     4                 사용이 편하네요...동백전 지점 정보가 좀더 명확했음 하네요~
# 256   2020-02-05     5  가맹점이 어디더라 생각 안하고 일단 들어가서 결재하면 어지간하면 가맹점이네요 ㅋㅋ ...
# 257   2020-02-05     3                         동백전 밴드앱 악성코드로 인식합니다 확인바랍니다
# 258   2020-02-05     5                                              무리 없음
# 259   2020-02-05     1  네이버 밴드 어플을 악성코드로 인식하네요. 밴드어플을 삭제하고 어플설치후 밴드를 다...
# 260   2020-02-05     1                                                 ㅇ아
# 261   2020-02-05     1  앱 시작하면 악성코드가 발견되었다면서 창이 뜨는데 이거 해킹당한거 아닌가요? 불안해...
# 262   2020-02-05     5                                                 굿.
# 263   2020-02-05     1                                    카드는 언제받을 수 있나요?
# 264   2020-02-05     1  사용처 제한으로 불편함이 많음. 특히 재래시장에는 카드계산기 없는 상점이 많아 더 ...
# 265   2020-02-06     1  앱 업로드이후 자꾸 재시작해야 하는 버그가 계속발생 합니다. 업로드전에는 전혀 문제...
# 266   2020-02-06     2  동백전의 의도는 너무 좋으나 앱이 너무 안 좋습니다. 동백전이 활성화하지 못하게 된...
# 267   2020-02-06     5  동백전회원가입하려는데 현재폰이 부모님명의로 되어있는데 휴대폰인증말고 다른방법으로 가...
# 268   2020-02-06     5                                     편하게 잘 사용하고 있어요
# 269   2020-02-07     1  와이파이 연결시에는 어플 접속이 잘됩니다. 하지만 데이터 사용시 접속이 잘 안됩니다...
# 270   2020-02-07     4  음식점 가맹점되는곳에서 카드사용시 배달의 민족이나 배달대행어플을 통해서 계산해도 캐...
# 271   2020-02-07     3                                                잘안됨
# 272   2020-02-07     3                          휴대폰 명의가 틀리는데 어떻게 가입안 안될까요
# 273   2020-02-07     1  인증문자 자체가 안오는데 뭘 어떻게 카드발급 받으라는거죠? 뭔가 제대로 이용할수 있...
# 274   2020-02-08     1                            인증번호 발송됐다는데..인번이 안와서...
# 275   2020-02-08     5             페이코랑 하나머니가 추가되어 피킹률 12퍼센트를 넘길수있는 갓혜자카드
# 276   2020-02-08     5                                                  굿
# 277   2020-02-09     3  가맹점 찾기를 통해 나오는 가맹점이 10년전쯤에 그 자리에 있던걸로 현재는 없어졌는...
# 278   2020-02-09     5          캐쉬백 이벤트기간 10퍼 장난 아니네요 좀 있음 6퍼겠지만 대만족중 입니다
# 279   2020-02-09     3  동백전어플을깔고난후에 회원가입 약관선택 후 다음 화면으로 넘어가지지않고 네트워크가원...
# 280   2020-02-09     5                                              페이백 굿
# 281   2020-02-09     3  아직 사용하기전이나 왜 항상 국가사업이 들어간 금융앱이나 국가,지자체에서 실시하는 ...
# 282   2020-02-10     3                                   아쉽지만 쓰는데 불편함은 없다
# 283   2020-02-10     1                             인증번호가 안오네요 앱에 문제가 있나요?
# 284   2020-02-10     2    계속 통신 오류가 뜨네요. 이러면 동백전 사용하기 불편해서 사용이 안될 것 같은데요.
# 285   2020-02-11     1                                      앱이문제네요 성질돋구네요
# 286   2020-02-11     3  가입은 수월히 카드신청시 은행계좌 연결하여 다시 키려면 다시 처음부터, 충전계좌 연...
# 287   2020-02-11     1                                         다운로드가안되여..
# 288   2020-02-11     1  어플실행시 정상적인OS가 아니라서 이용할수가 없다고 메세지가 나옵니다. 엘지V40이...
# 289   2020-02-11     2               어제부터 와이파이해도, 안해도 서버통신?문제로 연결안된다고 뜨네요
# 290   2020-02-11     1                 본인인증이 휴대폰말고 아이핀이나 공인인증도 추가되었음 합니다.
# 291   2020-02-12     1                                          다운이안받아지네요
# 292   2020-02-12     4  이벤기간이라 캐시백 비율이 높아 내가 내는 돈은 줄었음. 그러나 이 카드를 아예 안...
# 293   2020-02-12     5                      내게 만족을 주는 그런 카드면서 행복감을 주는 동백전
# 294   2020-02-12     1  어플이 실행안되요 통신중 오류가 발생했다고 어플 삭제후 다시 하여도 그대로 입니다 ...
# 295   2020-02-13     1  업데이트 이후에 뭘사러 갔더니 분명 해당점포가 캐쉬백대상점포인걸로 아는데 캐쉬백이 ...
# 296   2020-02-14     1                                       카드신청오류 계속뜨네요
# 297   2020-02-14     1             하이마트에서 사용가능한다고 나오나 사용이되지 않습니다 확인부탁드릴게요
# 298   2020-02-14     1  네트워크 연결이 원활하지 않습니다. 접속오류 다른 어플과 인터넷은 잘 사용되는 중인...
# 299   2020-02-15     1   계속 렉걸리고 네트워크접속이 안된다고하고 예기치못한오류가 생겼다며 너무 잘 안됩니다ㅠㅠ
# 300   2020-02-15     3  켤때마다 통신이어쩌고하면서 종료되고 다시들어가야 됩니다. 이번에는 5번이나 튕기고 ...
# 301   2020-02-15     3  동백전 앱 사용시 카드충전금액이 모자라거나 안되어 있으면 연결계좌에서 빠져나가잖아요...
# 302   2020-02-16     1                              카드신청이 안됩니다 눌러도 반응이없어요
# 303   2020-02-17     2           카드신청시 주민번호 입력후 다음화면으로 넘어가지않습니다. 업데이트해주세요
# 304   2020-02-17     5  정말 좋은 카드라서 잘 사용하고 있는데 앱에 문제가 있는지 실행하려고 앱을 누르면 ...
# 305   2020-02-18     3    인증된 번홓하 현재 번호가 달라서 계속 초기화 하라고 뜨는데 어떻게 해결해야 되나요?
# 306   2020-02-18     4  너무좋은 카드인데 앱 오류가 너무 심해서 잔액 확인이 안되는점 빨리 개선 되었음 좋...
# 307   2020-02-18     1  휴대폰 본인인증 문자가 10~20분뒤에 전송되어서 가입이 불가능합니다. 인증시스템에...
# 308   2020-02-19     3  아빠 폰에도 동백전 깔아드려서 쓰는데 이상하게 동백전만 켯다 끄면 문자에 들어갈 수...
# 309   2020-02-19     1                               실행도 안되는구만. 별 하나도 아까워
# 310   2020-02-19     3  정상적인 os가 아니면 서비스 이용이 안된다면서 앱실행이 안됩니다 고객센터 전화연결...
# 311   2020-02-19     1                          연3일째 계속 앱도운로드중 아직도 다운중이네요
# 312   2020-02-19     1             회원가입 과정중 인증번호 전송 버튼을 아무리 눌러도 전송이 되지 않음
# 313   2020-02-20     3  왜 두번 터치해야 정상적으로 어플이 실행되는지 모르겠네요. 한번 실행하면 보안프로그...
# 314   2020-02-22     5                                  캐시백 현재 10프로 대박. ㅎ
# 315   2020-02-22     5  너무좋네요 근데홍보가 이제되기시작했는지 지금만든사람이 많아요 10프로캐시백 3월까지...
# 316   2020-02-23     1  탭으론 접속조차 안되네요. 저 처럼 폰은 2g폰이고 탭으로 인터넷하는 사람은 어떻게...
# 317   2020-02-24     5  잘사용하고 있습니다^^ 근데 어플을 실행시키면 왜 첫번째는 실행되다가 닫기고 두번째...
# 318   2020-02-26     3                                           동백전앱이 안됨
# 319   2020-02-27     1  일정 시간 미사용으로 작업이 중단 되었습니다 라고 계속 떠는데 어떻게 하면 되나요....
# 320   2020-02-27     3    혹시 카드 수령지를 자택에서 직장으로 변경되지 않나요? 이것땜에 가입 못하고 있읍니다
# 321   2020-02-28     5                                              굿 좋아용
# 322   2020-02-28     1                                        어플 다운 불가...
# 323   2020-02-28     4  다 좋은데 연결계좌 은행에 카카오뱅크가 없어서 불편합니다. 연결계좌은행은 좀 다양해...
# 324   2020-02-28     4                       월별 사용합계를 자동으로 볼수 있으면 더 좋을듯해요
# 325   2020-02-28     5                                                좋아요
# 326   2020-02-28     3                                       체크카드도 캐시백주시지
# 327   2020-02-28     5                                            겁나 좋음 짱
# 328   2020-02-28     5                                                좋아요
# 329   2020-02-28     5                                     캐쉬백 짱. 지역 발전 짱
# 330   2020-02-28     5                                       잘 이용됩니다. 굿~~
# 331   2020-02-28     5                                                개편함
# 332   2020-02-28     5                                              감사합니다
# 333   2020-02-28     5                                                  굿
# 334   2020-02-28     5                                              매우 좋음
# 335   2020-02-28     5                                              최곱니다.
# 336   2020-02-28     5  부산 동백전이 엄청 편리하고 캐시백이 10% 되니 얼마나 좋습니까! 3월이후에도 년...
# 337   2020-02-28     5                                           10프로 꿀~~
# 338   2020-02-28     5                                              추천합니다
# 339   2020-02-28     5                                               좋아요~
# 340   2020-02-28     5                                                  굿
# 341   2020-02-28     5                                          폰결제 쫌 되겠죠
# 342   2020-02-28     5                                   어느카드보다 혜택 최고입니다.
# 343   2020-02-28     5                           사용한금액에 포이트도 받고 너무 좋아요,,굿
# 344   2020-02-28     5                                                좋아요
# 345   2020-02-28     1           동백전 사용가능 업체라고 검색하고 갔는데 사용되지 않았습니다. 완전 비추
# 346   2020-02-28     5                                                  굿
# 347   2020-02-28     5                                                좋아요
# 348   2020-02-28     5                                               좋아요.
# 349   2020-02-28     5                                                좋아요
# 350   2020-02-28     3  공인인증서로도 로그인가능하게해주세요 휴대폰명의가 다른게 너무불편.. 제발요 아님 폰...
# 351   2020-02-28     4               미적용 매장에서도 체크 카드 겸용이용 할수 있으면 더욱 좋겠군요.
# 352   2020-02-28     5                                              감사합니다
# 353   2020-02-28     5                                  사업자용카드로 등록 가능한가요?
# 354   2020-02-28     5                                             최고 입니다
# 355   2020-02-28     5                                                좋아요
# 356   2020-02-28     5                                                 따봉
# 357   2020-02-28     5                                      캐시적립이 정말대박이네요
# 358   2020-02-28     5                                            최고의지역화폐
# 359   2020-02-28     5                                 로그인후 사용하게 해주세요~~^^
# 360   2020-02-28     4                                                좋아요
# 361   2020-02-28     4                                         사용 편하고 좋아요
# 362   2020-02-28     5                                                좋아요
# 363   2020-02-28     5                                            아주만족합니다
# 364   2020-02-28     5                      이렇게 좋을 수 가 없습니다 10%할인 너무 좋습니다
# 365   2020-02-28     5        너무좋아요 하지만 택시에서 카드결제시 5번중 1번만 승인되서 다른카드로해요ㅠㅠ
# 366   2020-02-28     3                                    충전금액 입력가능하게 합시다
# 367   2020-02-28     4            편리하고 좋아요, 다만 잔액부족시 바로 카드결제 되는점은 개선 바랍니다
# 368   2020-02-28     4           전월사용실적이 연간으로 있으면 더편할것같아요^^ 동백전 너무 좋습니다~~
# 369   2020-02-28     3                                    좋아요 계속 10% 해주셍ᆢ
# 370   2020-02-28     5                 편리합니다. 그러나 Pay 앱이나 잔액을 표시하면 좋을듯합니다
# 371   2020-02-28     5                                              넘 좋아요
# 372   2020-02-28     5                                캐시백 모으는 재미가 쏠쏠하네요♡♡
# 373   2020-02-28     5                                        좋아요🤗 동백전 짱.
# 374   2020-02-28     5  개꿀입니다 대신 여기가 사용가능한곳(결제는 웬만한곳에서 가능하나 캐쉬백이 되는곳) ...
# 375   2020-02-28     5                                 사용하기 아주 편리하게 잘만들었음
# 376   2020-02-28     5                                  좋은데 에러가 너무 많이 뜹니다
# 377   2020-02-28     5                                                좋아요
# 378   2020-02-28     1  도대체 고객센터는 왜있는겁니까? 2/19에 1:1문의 했는데 9일이 지났는데도 보지...
# 379   2020-02-28     5            너무 좋아요~~^^그리고3월달까지 이벤 연장도 해주셔서 감사합니다~^^
# 380   2020-02-28     5                               캐쉬백 이만큼 되는 카드는 동백전 뿐
# 381   2020-02-28     5                                       바로 캐쉬백되니 좋아요
# 382   2020-02-28     1  충전금액 환불이 자유로울거라 생각하고 카드발급, 어플설치를 하고 충전을 했었는데 급...
# 383   2020-02-28     5                                             굿요~~~~
# 384   2020-02-28     4                                                좋아요
# 385   2020-02-28     5                                  부산에선 동백전 좋아요~~~^^
# 386   2020-02-29     4                                  온라인은 사용이 안되서 아쉬워요
# 387   2020-02-29     5  10% 캐시백이 2월까지라서 약간 아쉬웠는데 3월까지 연장이라 좋아용ㅎ 꿀이 떨어지...
# 388   2020-02-29     2  동백전 사용시 와이파이가터지는 곳에서도 모바일 데이터를 켜지 않으면 사용이 안되는데...
# 389   2020-02-29     5                                            캐쉬백넘좋아요
# 390   2020-02-29     5                                               Good
# 391   2020-02-29     5                                            사용하기 쉬움
# 392   2020-02-29     4  덕분에 잘 사용하고 있습니다 업데이트 되면서 충전하기가 더 어렵게 되었네요 이전처럼...
# 393   2020-02-29     5                                            좋아요^^~♡
# 394   2020-02-29     5       편하게 잘쓰고있는데 3월도 10% 캐시백해준다니 넘 좋아요~10% 1년 가즈아~
# 395   2020-02-29     5                                                  굳
# 396   2020-02-29     4                                              맘에들어요
# 397   2020-02-29     3                                                 좋음
# 398   2020-02-29     5                                                좋아요
# 399   2020-02-29     4                           충전금액이 얼마나 남았는지 알려주면 좋겠어요
# 400   2020-02-29     5                                        진짜진짜진짜루 좋아영
# 401   2020-02-29     5                                                 없음
# 402   2020-02-29     5                                             앱너무좋아요
# 403   2020-02-29     4                                               완전좋음
# 404   2020-02-29     5                                 너무좋아요 보너스 받는 느낌입니다
# 405   2020-02-29     5                                              정말좋네요
# 406   2020-02-29     5                      잘 사용하고 있어요. 10프로 적립~ 오~ 유익해요.
# 407   2020-02-29     5                                             완전굿입니다
# 408   2020-02-29     5                                             대박좋아야ㅡ
# 409   2020-02-29     5                                                  굿
# 410   2020-02-29     5                     너무 잘쓰고 있어요 ㅎㅎ 사용방법이 간단해서 좋네요^^
# 411   2020-02-29     5                                                편리함
# 412   2020-02-29     5                                                  굿
# 413   2020-02-29     5                             아주 유용합니다. 포인트가 금방 쌓여요.
# 414   2020-02-29     5                                         잘사용하고있습니다.
# 415   2020-02-29     5                                                좋아요
# 416   2020-02-29     4  어플도 보기 편하고 실시간 캐쉬백 확인되니 너무 잘 쓰고있어요.. (가맹점 찾기 힘...
# 417   2020-02-29     3  카드신청 일주일이 지나도 오지않음 배송업체는 전화도 받지않음 언제 오려나? 차라리 ...
# 418   2020-02-29     5                 최고입니다. 학령기 자녀를 둔 주부에게는 선물같은 카드이네요.
# 419   2020-02-29     5            혜택업소가 좀더 많았으면 해요. 10프로혜택 너무좋아요. 다같이 윈윈!
# 420   2020-02-29     5                                                  굿
# 421   2020-02-29     5      코로나 여파로 사용실적이 적은데 3.4월까지 10% 혜택을 연장 해주면 좋겠습니다
# 422   2020-02-29     5                                             쓸만합니ㅣ다
# 423   2020-02-29     5                                               Good
# 424   2020-02-29     5                                         사용하기 편리해요.
# 425   2020-02-29     5                                         동백전 너무 좋아요
# 426   2020-02-29     5                                              아주좋아요
# 427   2020-02-29     5                                         좋아요 부산 화이팅
# 428   2020-02-29     5                                                갠차늠
# 429   2020-02-29     5                          지역경제도 살리고 우리집에도 도움되는 최고 앱
# 430   2020-02-29     5                                                좋아요
# 431   2020-02-29     5                               너무 편하고 좋습니다 혜택도 많고~~
# 432   2020-02-29     1                                          업데이트가 안되요
# 433   2020-02-29     5                                       10프로충전너무좋아요.
# 434   2020-02-29     5                                    오거돈 시장님 감사합니다 ㅎ
# 435   2020-02-29     5                                             감사합니다~
# 436   2020-02-29     5                                             좋고 편해요
# 437   2020-02-29     5                                                 좋음
# 438   2020-02-29     4                                    택시가 연동이안되 아쉽네요~
# 439   2020-02-29     5                                                 굳굳
# 440   2020-02-29     3                                      아직은 완벽한 어플아닌듯
# 441   2020-02-29     5                                                 감사
# 442   2020-02-29     5                                              너무좋아요
# 443   2020-02-29     5                                                좋네요
# 444   2020-02-29     5                                               긋입니다
# 445   2020-02-29     4                                       쏙쏙 되돌아 오는 재미
# 446   2020-02-29     5                                                좋아요
# 447   2020-02-29     1  아니 충전하려 들어가면 계속 튕기고 지우고 깔아도 튕기는데 이러면 그냥 쓰지말라는 ...
# 448   2020-03-01     5                                            무조건 조아여
# 449   2020-03-01     5                                                좋아요
# 450   2020-03-01     5                                       너무좋습니다ㅅㅅㅅㅅㅅㅅ
# 451   2020-03-01     5                                                 개꿀
# 452   2020-03-01     5                                                  굿
# 453   2020-03-01     4                    아직 동백전을 모르는사람이많은듯 더욱더 홍보가 필요합니다
# 454   2020-03-01     4  잘쓰고있습니다~ 한가지 요청드리고 싶은건 월별 또는 일정기간별 사용금액을 조회했을때...
# 455   2020-03-01     5                                                개꿀~
# 456   2020-03-01     5                                     포인트적립 정말 최곱니다ㅋ
# 457   2020-03-01     5                                            알림이 빨라요
# 458   2020-03-02     1                                   계속 통신중 오류 뜨는건 뭐여
# 459   2020-03-02     1                                             업데이트안됨
# 460   2020-03-02     1  회원가입조차 되질않아요. 문자인증전까지 입력은 되는데 인증문자가 전혀 오질않네요 S...
# 461   2020-03-02     5                          10프로 할인이 연장되어 기분이 좋아서 리뷰씀
# 462   2020-03-02     4                                     아주 유용하게 쓸것 같네요
# 463   2020-03-02     1                                      업데이트가 너무 안되네요
# 464   2020-03-02     5                                       말이 필요없음. 최고.
# 465   2020-03-02     1  충전 환불 제도도 불편하고 상담원 연결 너무 안됩니다. 그리고 쓸 금액만 충전해서 ...
# 466   2020-03-03     4                                        가맹점도 많고 좋아요
# 467   2020-03-03     5                                                좋아요
# 468   2020-03-03     3                                            조금번잡스러움
# 469   2020-03-03     5                                                좋아요
# 470   2020-03-04     5                                         다들 좋은거 인정?
# 471   2020-03-04     5       대형마트 사용만 가능하면 우리나라 최고의 카드혜택이라 믿어 의심치 않습니다~^^
# 472   2020-03-04     5          어떤 vvip 신용카드가 10% 할인을 해주겠나요. 이보다 좋을 순 없어요
# 473   2020-03-04     4                      충전 할려니까 옳바르지 않는 계좌라고 하면서 안되네요
# 474   2020-03-04     1                                왜 자꾸 다운로드대기중인가요..ㅜㅜ
# 475   2020-03-04     1                                      계속 오류가 떠요..ㅜㅜ
# 476   2020-03-04     2          앱에 접속안되는 날이 왜이리많아요? 접속할때마다 30~40%는 접속불가;;
# 477   2020-03-04     1                                   업데이트 왜이리 안돼요????
# 478   2020-03-04     2  동백전 사용하기 좋아요! 그렇지만, 안드로이드 버전이 낮아 동백전 어플 자체가 아예...
# 479   2020-03-04     5                                             너무 조아요
# 480   2020-03-04     5                                   포인트많이 쌓여서 좋아요...
# 481   2020-03-04     2  본인인증 단계에서 휴대폰 인증번호 발송이 안되고, 카드번호로 인증하려고 해도 번호오...
# 482   2020-03-04     5                    기간 설정해서 사용내역을 볼 때 합계도 나왔으면 좋겠어요
# 483   2020-03-05     1                               업데이트3일동안 안되고 앱실행이안되여
# 484   2020-03-05     1                                   하루종일 앱이 실행이 안되요~
# 485   2020-03-05     1  가입하려고 폰인증번호 전송누르면 예기치못한문제발생 했다고 진행이 안됩니다 수십번을 ...
# 486   2020-03-05     2  팝업창 아랫부분 닫기인지 다시보지않기 인지 선택하는 창이 화면에 잘려서 누를수가 없...
# 487   2020-03-06     5  간단 명료하게 잘 꾸며져 있슴다! 적절히 사용하여 부산 경제에 도움이 되도록 주위 ...
# 488   2020-03-06     4  가맹점 확인할때 카테고리가 나눠져있긴 하지만, 그 속에서 가게 이름을 일일이 다 보...
# 489   2020-03-06     1                                      지금 설치가 안되요 ㅠㅠ
# 490   2020-03-07     5  잘쓰고 있습니다. 충전을 해야하는데 업데이트를 요구하는데 설치는 계속 대기중이네요....
# 491   2020-03-07     4                         동백전 잔액이랑 캐시백 바로 업데이트되니 좋아요
# 492   2020-03-09     2  카드가 도착했다해서 우편함에 놔둬달라했는데 집에 갔는데 없더라구요ㅠㅜ 그래서 재발급...
# 493   2020-03-09     1                                              안열리네요
# 494   2020-03-09     4  어플이 와이파이! 연결될때만! 실행 됩니다 데이터를 켜면 " 네트워크 상태가 원활하...
# 495   2020-03-09     5  동백전카드 가입에서 비밀번호 실패하고 나서는 접속하기가 힘들어요~~~ 충전시킬려고 ...
# 496   2020-03-10     1  가입이 안됩니다!!인증이 안되요~ㅎㅎ발급 받아보려고 어플깔고 휴대폰 인증하는거 아무...
# 497   2020-03-10     1  이음카드에 비하면 너무 기능도 없고 카드 1개 밖에 신청도 안되고 부족한점이 너무 많아요
# 498   2020-03-10     3  2g폰 사용하고 있는데 동백전 발급받을 수 있는 방법은 없나요? 예를들면 아이패드나...
# 499   2020-03-10     2  동백전은 좋은데 어플이 왜이래요? 결제가 두번 된거 같아 확인하려고 하니 네트워크 ...
# 500   2020-03-10     1  계좌도 다 안맞다그러고 신분증 발급일자도 틀리다고그러고... 그냥 발급이 이제 안되...
# 501   2020-03-11     4  잘 사용하고 있습니다. 아쉬운건 잔액정보인데, 1.사용 전 금액 상품권 100원 캐...
# 502   2020-03-11     4  동백전은 너무좋은데 간혹오류로 결제가안될때가있고 어플들어가는거도 팅길때가있어요 유용...
# 503   2020-03-11     2  폰마다 차이가있는지 제폰에서는 와이파이 아니면 앱에 접속이 거의 안됩니다(A5). ...
# 504   2020-03-11     1  전산오류로 결제가 두번 됐는데 충전한 돈으로 결제한 첫번째 결제를 취소시키고 두번째...
# 505   2020-03-11     3                                              아직 모름
# 506   2020-03-11     1                               인증번호가 안오는데 어떻게 해야될까요
# 507   2020-03-12     1                           데이터 인식을 못하나봐요 깔아도 쓸수가없네요
# 508   2020-03-12     5                                                좋아요
# 509   2020-03-12     1                 열때마다 다시 종료해야되네요.. 어플 제대로 좀 만드세요...
# 510   2020-03-12     3  카드발급해서 사용중인데, 계속 카드등록발급하라고 어플에 뜨네요.카드등록 할수있게 해주세요
# 511   2020-03-12     2                       앱이 자주 버벅 거립니다 터치도 안되고 먹통이 되요
# 512   2020-03-12     5  최고에요. 계속되는 10% 적립혜택도 좋고, UI도 신경써서 만든 것 같아요. 편리...
# 513   2020-03-13     5                                                좋아요
# 514   2020-03-14     1                          돈만빠져나가고 충전이안됨 아직은 많이 부족한듯
# 515   2020-03-14     3                                            열리지가않아요
# 516   2020-03-15     2  네트워크가 원활하지 않아 안된다고 뜨네요. 그런데 옆에 남편은 확인이 잘되는데 뭐가...
# 517   2020-03-16     2                결제도 안되고 잔액확인도안됩니다 계속 오류뜨는데 왜이런건가요??
# 518   2020-03-16     1  급하게 충전 해야 할 때 안 됩니다.... 어플도 통신사도 케이티라 뭐가 쓰레긴지는...
# 519   2020-03-16     2  네트워크 오류라면서 어플 접속이 안될뿐더러 오늘 실 결제한 금액 캐시백도 안됐네요....
# 520   2020-03-16     1                                인터넷 접속이 안될때가 더 많습니다
# 521   2020-03-16     1                                 뭐가자꾸 접속이안된대 짜증나게ㅡㅡ
# 522   2020-03-16     4  어플에 접속이 안되는데 어떻게 쓰라는거에요?? 아이폰에서 안드로이드로 넘어왓는데 아...
# 523   2020-03-16     1                         명불허전 공무원 작품.. 접속장애 엄청 심합니다
# 524   2020-03-16     3  혜택은 좋은데, 어플 동작이 너무 느림. 이 가게가 해당되는지 확인하려고 어플켜다가...
# 525   2020-03-16     2  신청을해서 등록하려는데 자꾸 통신상연결이안된다하고 네트워크문제라고뜨네요 다른인터넷어...
# 526   2020-03-16     1  제 폰이 이상한건 가요ㅜ 데이터로는 동백전이 안들어가지고 돈 충전도 안됩니다 길에서...
# 527   2020-03-16     1                              오늘 결제도 안되고 어플실행도 안되요.
# 528   2020-03-16     1                                    어휴 어플관리 진짜 최악이다
# 529   2020-03-16     1  진짜 넘하시네요! 아니 뭐 접속도 안되고 맨날천날 통신이 불안하다고 하면 시에서 일...
# 530   2020-03-17     2  어플이 연결이되야지 충전을할껀데 어제도오후내내 안되서 결국딴카드사용햇네요 네트워크오...
# 531   2020-03-17     3                   연결이잘안되요..네트워크 상태....라면서뜨지를않아요...
# 532   2020-03-18     5           가맹점 검색할때 현재 위치가 아닌 처음 접속했던 위치로 계속 검색되는듯요
# 533   2020-03-18     5  잘 사용하고 있습니다. 월별 이용금액(합계) 좀 보이게 개선해주세요. 사용금액 합계...
# 534   2020-03-18     1  설치하고 카드 신청하는데 폰으로 인증번호 확인차 문자앱 실행해서 보고 다시 동백전앱...
# 535   2020-03-18     5  접속이 잘되다가 갑자기 안되네여 다른분들말처럼 데이터 와이파이 구분없이 네트워크 장...
# 536   2020-03-19     5                                                좋아요
# 537   2020-03-19     1  마이너스 없어서 별 1개만 줌 카드신청하고 일주일 만에 받았는데 어플에서 충전이 안...
# 538   2020-03-19     1  어플 접속이 자꾸 튕겨요 캐쉬백도 제대로 들어오지않고 부족하게 들어오고 고객센터 전...
# 539   2020-03-20     2  다른어플은 실행이되는데 이어플은 lte인데도 왜 실행이 안되고 와이파이껴야 그나마 ...
# 540   2020-03-20     1  문의글남겨도답변도안하고점심이라고일안하고가맹점이라고버젓이되잇는데사장은동백전가입안되잇다...
# 541   2020-03-20     5                                             넘좋아요~♡
# 542   2020-03-20     5  앱을 실행할 때마다 아래와 같이 계속 에러가 뜨면서 초기화 되요 ㅠㅠ -------...
# 543   2020-03-20     3  카드신청시 일정시간미사용으로 거래불가가 계속 뜨는데 제거후 다시 설치해도 그렇네요 ...
# 544   2020-03-20     4  잘 사용 하고 있습니다. 근데. 가맹점에 포함 돼 있는 곳인데 앱에는 검색이 안되네...
# 545   2020-03-21     5  제안을 하고자 합니다. 어린이들도 동백전 사용자로 참여하도록 하면 어떨까요? 인천의...
# 546   2020-03-22     3  와이파이에서만 접속이 됩니다. 거의 일주일 이런 상탠데 오류 언제 잡아주실지..??...
# 547   2020-03-22     1                                             서버 좀ㅡㅡ
# 548   2020-03-23     3  동백전 어플이 와이파이 일 때는 잘 되지만 와이파이가 아닌 상태에서는 오류가 떠서 ...
# 549   2020-03-23     5                          진짜 다 좋은데 카카오뱅크 계좌등록되게해주세요
# 550   2020-03-23     2    앱 실행하니 통신 중 예기치않는 오류가 발생했다면서 실행이 안 됩니다. 왜 이런거죠?
# 551   2020-03-24     5                                    괞찬아서 주변에 강추합니다.
# 552   2020-03-24     1          자기명의휴대폰아니면 가입이 안되는거 같은데 아이핀으로 가입할수있게 해주세요
# 553   2020-03-24     3                    어플에서 바로 qr코드같은걸로 결제기능이 있으면 좋겠네요
# 554   2020-03-24     5                                     그냥 무조건 사용해야합니다
# 555   2020-03-25     3  원래 와이파이있어야만 접속가능한건가요? 데이터로는 접속이안되고 꼭 와이파이가있어야만...
# 556   2020-03-25     3  뭐 켜져야 잔액을 확인하고 사용하는 곳 확인해서 쓰지 와이파이연결하니까 데이터만 된...
# 557   2020-03-25     3          데이터확인하라고 연결이안되요. 다른 앱은 실행되는데 1시간째 안되니 화나요
# 558   2020-03-25     1                   아니 충전할려고 앱켰더니 실행이 안되면 어쩌라고요 짜증나네
# 559   2020-03-25     1           어플이 왜이러죠? 데이터상태에서 사용이 안되면 밖에선 사용하지말란건가요?
# 560   2020-03-25     2  일단 어플이 너무 느려요ㅠㅠ 또 실행할때 네트워크가 불안정하다고 안열리네요.. 가맹...
# 561   2020-03-25     5                                     캐시백이 많아 너무 좋네요
# 562   2020-03-25     1                 제발 서버 확장 좀 하세요 앱에 한번 들어가려면 하루종일 걸림
# 563   2020-03-25     1                           앱 접속이 안되요 확인해주세요 계속 오류나요
# 564   2020-03-25     2                                        어플이 실행이 잘안됨
# 565   2020-03-25     1       앱이 잘 열리지도 닫히지도 않아요 일단 카드신청만 겨우하고 강제 종료했네요 ㅡㅡ
# 566   2020-03-26     1  Ios 안드로이드 버전 낮으니까 아예 플레이스토어에 없네요 ...다른 카드나 은행앱...
# 567   2020-03-26     5                   동백전 가맹점 위치 알수 있는 어플 있으면 더 좋겠네요..
# 568   2020-03-27     3  일정시간 미사용으로 작업이 중단되었습니다 카드 신청을 할려니 위처럼 나오며 안되네요...
# 569   2020-03-27     1  갤s8 브라우저ㅡ 크롬으로 설정해야된다고 진작좀 알려주지 어제 전화문의는 그런거 안...
# 570   2020-03-28     1  아니 앱 설치해서 들어가니깐 이앱을 삭제하시겠습니까 뜨고 예하면 진짜 삭제되고 아니...
# 571   2020-03-28     1  네트워크도 잘안되는걸 어떻게 써라고? 써다가 열불나서 카드부쉈음. 일부러 이렇게 만...
# 572   2020-03-28     5  이용내역 조회시 이용기간에 따른 합계액이 표기되면 좋겠습니다. (30일치 결제내역조...
# 573   2020-03-28     2  본인확인 방법을 추가해 주세요!! 법인사용자의 경우 본인명의의 폰이 아니라며 어플 ...
# 574   2020-03-29     2  설치 후 켤때마다 초기화,재인증하라고 하죠? 등록된 정보와 핸드폰 번호가 다르다는 ...
# 575   2020-03-29     5                                       저한테는 너무 좋습니다
# 576   2020-03-30     1  별 1개도 아깝습니다 결제가 제대로안돼서 어플실행시키는데 들어가져야지 확인을하지ㅡㅡ...
# 577   2020-03-30     1                                  어플이 실행되야 쓰던가 하죠..
# 578   2020-03-30     1        동백전 가입할라는데 인증번호가 안와요 3번 시간초과됫는데도 안와요 왜안오는거죠
# 579   2020-03-30     2                                     아 진짜 불편하네요.. .
# 580   2020-03-30     2  가입은 하고 되는가 볼려고 100.000 원 충전 했는데요 카드를 만들수가 없네요~...
# 581   2020-03-30     1  카드뱌아서 충전하고 사용하는대 어플에는 사용됬다고 금액뜨는대 가게에서는 사용중지되있...
# 582   2020-03-30     2  어플화면에서는 결제완료창이랑 캐쉬백 내역이 뜨는데 가맹점에서 실결제가 되지는 않는 ...
# 583   2020-03-30     1                                             접속이 안됨
# 584   2020-03-30     3                                         앱 실행이 안됩니다
# 585   2020-03-30     1  앱연결하기 하늘의별따기임ㅡ얼마썼는지 확인을할수가없음ㅡ앱이 실행이돼야 뭘하지 ㅡㅡㅡㅡ...
# 586   2020-03-30     1                       오류 투성이. 접속 됐다 안됐다 네트워크도 불안정함
# 587   2020-03-30     2                              급하게 만든거 엄청티나네 안정성 엉망임
# 588   2020-03-30     1  카드가 오류가 떠서 결제가 취소됐는데 캐쉬백은 들어왔고 어플은 켜지지도 않고. 어플...
# 589   2020-03-30     1  이거 확인안되는데 왜이렇죠? 결제안된다고하는데 어플에는 결제한거처럼 나오고 진짜 왜...
# 590   2020-03-30     1   안들어가지는게 너무심하네요. 이래서 사용가능하겠어요? 데이터 와이파이 다 안들어가져요.
# 591   2020-03-30     1  다운로드만 되고 아이콘누르면 동백전로고만 내내떠있고 아무것도 안되는데요.. 와이파이...
# 592   2020-03-30     1             동백전은 좋은데 앱이 말썽이네요 충전할때마다 짜증이 나요 앱이 쓰레기
# 593   2020-03-30     5                                            굿~~~~~!
# 594   2020-03-30     2                      오늘 하루종일 먹통에 2중 결재 됐습니다 확인해주세요
# 595   2020-03-30     5                               카뱅이 없어서 아쉽긴 하지만 좋아요♡
# 596   2020-03-30     2  어플이 켜져야 잔액 확인을 할텐데 어플이 켜질 생각을 안하네요 리뷰 보니까 다른분들...
# 597   2020-03-30     3    잘사용하고있습니다. 3월 30일 오후 8부터 앱 자체가 켜지지 않습니다.이유가 뭔가요
# 598   2020-03-30     5                          부산사람이라면 강추. 이벤트10프로 평소6프로
# 599   2020-03-30     1                   카드를 받고 앱을 실행할려니 안되네요. 이렇게 허접하다니?
# 600   2020-03-30     1                           켜져야 뭘하지 공공기관에서 만드는 어플 답다
# 601   2020-03-30     5  결제 알림문자를 받음과 동시 입금 알림문자가 울립니다.코로나 같은 지금 시기에 경제...
# 602   2020-03-30     4  출시 되자마자 사용해서 몇달짼데 처음보다는 세분화된 충전 단위도 편리하구요 너무 잘...
# 603   2020-03-30     1  와 앱 실행 너무 안되요 너무너무너무 너어어어무!!!!!! LTE로 해도 안되고 와...
# 604   2020-03-30     1        머 접속이되야하지ㅡ....우짜라는건지 안되요 아예 로딩도안되고 따운됨 ...하
# 605   2020-03-30     1  왜 제일은행계좌연결이없나요 그리고 카드는왔는데 잔액충전을못하고있어요 어플이 오류라고...
# 606   2020-03-30     3  잘 쓰다가 3월 30일 갑자기 카드가 잘 안되더니 어플도 안되네요 ㅠㅠ 혜택이 마음...
# 607   2020-03-30     1                           앱이 화면이 멈춰있어요 접속이 안되는거같아요
# 608   2020-03-30     1  돈 충전하고 카페에서 사용했는데 직원분이 은행에 문제가 있는거같다고 안된다해서 디른...
# 609   2020-03-30     5  지금 앱이 첫화면에서 넘어가지를 않네요 폰을 다시 켜보아도 마찬가지고 앱제거하고 다...
# 610   2020-03-30     1  서버터져서 안써지는게 태반입니다. 심지어 결제처리도 안되었는데 앱 들어오니 결제된것...
# 611   2020-03-30     1         정보 수집 동의후 동백전카드 이미지모양에서 어플실행이 멈추는데 이건 모에요?
# 612   2020-03-30     1                                              안들어가짐
# 613   2020-03-30     1  동백전이 어플없이 사용가능하다면 모르겠지만, 필수적으로 어플이 필요한 서비스인데 이...
# 614   2020-03-30     1                 앱이 안열림 ㅡ.ㅡ뭐하자는거임? 사용자 증가로 오류? 골때리네
# 615   2020-03-30     1  앱 알림은 결제가 되었다고 뜨는데 업체에서는 결제가 안되었다고 해서 다른 카드로 결...
# 616   2020-03-30     3  오늘 결제가 된걸로 처리되는디 편의점은 안됐다고하고 충전금액만 차금되네요 ㅠ kt서...
# 617   2020-03-30     3                                     실행이안됩니다 개선해주세요
# 618   2020-03-30     1  짜증나요 매장에서는 결제안됐다 그러고 저는 결제됐다고 알람 떴는데 결제하려고 어플드...
# 619   2020-03-30     3  오류가 잘나는데 조금전 결재하는데 동백전카드는 금액지불되는데 결재안뜬다고.현금내었는...
# 620   2020-03-30     3     너무 어이 없네요 사용할수 없어요 카드로 결재도 안되고 앱도 다운되어 먹통이 됐어요
# 621   2020-03-30     1  아니 결제를 했는데 제 핸드폰에서는 결제가 됐다고 알림이 왔는데 정작 결제한곳에서는...
# ...
# 1641     0
# 1642     0
# 1643     0
# 1644     0
# 1645     0
# 1646     1
# 1647     0
# 1648     0
# 1649     0
# 1650     1
# 1651     0
# 1652     0
# 1653     0
# 1654     0
# 1655     0
# 1656     0
# 1657     0
# 1658     0
# 1659     0
# 1660     0
# 1661     0
# 1662     0
# 1663     0
# 1664     0
# 1665    25
# 1666     0
# 1667     0
# 1668     1
# 1669     0
# 1670     1
# 1671     0
# 1672     0
# 1673     0
# 1674     0
# 1675     0
# 1676    24
# 1677     6
# 1678     0
# 1679     0
# 1680     0
# 1681     0
# 1682    22
# 1683     0
# 1684     0
# 1685     0
# 1686     0
# 1687     1
# 1688     0
# 1689     0
# 1690     0
# 1691    59
# 1692     0
# 1693     0
# 1694     0
# 1695     0
# 1696     0
# 1697     0
# 1698     0
# 1699     0
# 1700     0
# 1701     0
# 1702     0
# 1703     0
# 1704     0
# 1705     0
# 1706     0
# 1707     0
# 1708     0
# 1709     1
# 1710     0
# 1711     0
# 1712     0
# 1713     2
# 1714     0
# 1715     0
# 1716     0
# 1717    75
# 1718     0
# 1719    56
# 1720    32
# 1721     0
# 1722     0
# 1723     0
# 1724     0
# 1725     0
# 1726     0
# 1727     0
# 1728     0
# 1729     0
# 1730     0
# 1731     0
# 1732     0
# 1733     0
# 1734     0
# 1735     0
# 1736     0
# 1737     0
# 1738     0
# 1739     0
# 1740     0
# 1741     0
# 1742     0
# 1743     0
# 1744     0
# 1745     1
# 1746     0
# 1747     0
# 1748     0
# 1749    18
# 1750     0
# 1751     0
# 1752     0
# 1753     0
# 1754     0
# 1755     0
# 1756     0
# 1757     0
# 1758     0
# 1759     0
# 1760     0
# 1761     0
# 1762     0
# 1763     0
# 1764     0
# 1765     0
# 1766    60
# 1767     3
# 1768     0
# 1769     0
# 1770     0
# 1771     0
# 1772     0
# 1773     0
# 1774     0
# 1775     0
# 1776     0
# 1777     1
# 1778     0
# 1779     0
# 1780     2
# 1781    30
# 1782    26
# 1783     0
# 1784     0
# 1785     0
# 1786     0
# 1787     0
# 1788     0
# 1789     0
# 1790     0
# 1791     0
# 1792     0
# 1793     0
# 1794     1
# 1795     0
# 1796    65
# 1797     0
# 1798     0
# 1799     8
# 1800     0
# 1801     0
# 1802     0
# 1803     0
# 1804     0
# 1805     0
# 1806     0
# 1807     0
# 1808     0
# 1809     0
# 1810     0
# 1811     0
# 1812     0
# 1813     0
# 1814     0
# 1815     0
# 1816     1
# 1817     2
# 1818     7
# 1819     0
# 1820   132
# 1821     1
# 1822     0
# 1823    77
# 1824     0
# 1825     0
# 1826     0
# 1827     1
# 1828     0
# 1829     1
# 1830     0
# 1831     7
# 1832     2
# 1833     2
# 1834    10
# 1835     1
# 1836     1
# 1837     1
# 1838    33
# 1839     2
# 1840     3
# 1841     4
# 1842     1
# 1843     7
# 1844    70
# 1845     2
# 1846     0
# 1847    13
# 1848     0
# 1849     0
# 1850     1
# 1851     0
# 1852     0
# 1853     1
# 1854     0
# 1855     0
# 1856     2
# 1857    24
# 1858    11
# 1859    10
# 1860    23
# 1861     4
# 1862     8
# 1863     2
# 1864    16
# 1865     5
# 1866     2
# 1867    29
# 1868     1
# 1869    24
# 1870     3
# 1871     7
# 1872     0
# 1873     6
# 1874    15
# 1875     3
# 1876     0
# 1877     0
# 1878     0
# 1879     0
# 1880     0
# 1881     0
# 1882     0
# 1883     0
# 1884     0
# 1885     1
# 1886    17
# 1887     0
# 1888     0
# 1889    12
# 1890     3
# 1891     2
# 1892     1
# 1893     2
# 1894     3
# 1895    40
# 1896     0
# 1897     5
# 1898     4
# 1899     3
# 1900     4
# 1901     7
# 1902     6
# 1903     1
# 1904     6
# 1905    22
# 1906     0
# 1907     0
# 1908     0
# 1909     4
# 1910    11
# 1911    16
# 1912     3
# 1913     5
# 1914     5
# 1915     4
# 1916    11
# 1917     3
# 1918     0
# 1919     8
# 1920     5
# 1921     6
# 1922     3
# 1923     1
# 1924     0
# 1925    25
# 1926     4
# 1927     0
# 1928    16
# 1929     4
# 1930     5
# 1931     8
# 1932     5
# 1933    12
# 1934     8
# 1935     8
# 1936    10
# 1937     1
# 1938     9
# 1939     9
# 1940    20
# 1941     0
# 1942     4
# 1943     7
# 1944    12
# 1945    68
# 1946     8
# 1947    49
# 1948     5
# 1949    13
# 1950     5
# 1951     4
# 1952     7
# 1953     0
# 1954    26
# 1955     1
# 1956     1
# 1957     1
# 1958     9
# 1959    21
# 1960     0
# 1961    26
# 1962     7
# 1963     4
# 1964    10
# 1965     4
# 1966     7
# 1967     2
# 1968     8
# 1969    11
# 1970     4
# 1971     3
# 1972     3
# 1973    15
# 1974     3
# 1975     9
# 1976     0
# 1977     3
# 1978    14
# 1979     1
# 1980    10
# 1981     0
# 1982     0
# 1983     5
# 1984     0
# 1985     3
# 1986    25
# 1987    20
# 1988     0
# 1989     4
# 1990     0
# 1991     3
# 1992     4
# 1993     3
# 1994    10
# 1995    11
# 1996     0
# 1997     5
# 1998     6
# 1999     5
# 2000     7
# 2001     4
# 2002     3
# 2003     7
# 2004     3
# 2005     0
# 2006     6
# 2007     3
# 2008     0
# 2009     0
# 2010     0
# 2011     0
# 2012     1
# 2013     0
# 2014     1
# 2015     0
# 2016     2
# 2017     0
# 2018     0
# 2019     0
# 2020     1
# 2021     0
# 2022     0
# 2023     0
# 2024     1
# 2025     1
# 2026     0
# 2027     0
# 2028     4
# 2029     0
# 2030     0
# 2031    20
# 2032     0
# 2033     0
# 2034     2
# 2035     1
# 2036     1
# 2037     3
# 2038     3
# 2039     2
# 2040     2
# 2041     0
# 2042     0
# 2043     1
# 2044     1
# 2045     0
# 2046     0
# 2047     0
# 2048     3
# 2049     1
# 2050    12
# 2051     3
# 2052    10
# 2053     2
# 2054     1
# 2055     1
# 2056     0
# 2057     1
# 2058     1
# 2059     2
# 2060    12
# 2061     9
# 2062     0
# 2063     1
# 2064     6
# 2065     4
# 2066     1
# 2067    22
# 2068     0
# 2069     0
# 2070     1
# 2071     7
# 2072     0
# 2073     0
# 2074     5
# 2075     0
# 2076     0
# 2077     1
# 2078     1
# 2079     9
# 2080     0
# 2081     7
# 2082     0
# 2083     3
# 2084     4
# 2085     1
# 2086     2
# 2087     0
# 2088   107
# 2089     9
# 2090     0
# 2091     0
# 2092    49
# 2093     5
# 2094     0
# 2095     0
# 2096     0
# 2097     4
# 2098     0
# 2099     0
# 2100     0
# 2101     0
# 2102     1
# 2103     4
# 2104     0
# 2105     0
# 2106     1
# 2107     0
# 2108     0
# 2109     0
# 2110     2
# 2111     0
# 2112     2
# 2113     0
# 2114     0
# 2115     0
# 2116     0
# 2117     3
# 2118     0
# 2119     2
# 2120     2
# 2121     1
# 2122     0
# 2123     5
# 2124     0
# 2125     0
# 2126     0
# 2127     0
# 2128     1
# 2129    26
# 2130    16
# 2131     6
# 2132    20
# 2133    74
# 2134     0
# 2135     0
# 2136     0
# 2137     0
# 2138     0
# 2139     0
# 2140     0
# 2141     0
# 2142     0
# 2143     0
# 2144     0
# 2145     1
# 2146     0
# 2147     2
# 2148     0
# 2149     0
# 2150     2
# 2151     0
# 2152     1
# 2153     0
# 2154     1
# 2155     0
# 2156     1
# 2157     1
# 2158     0
# 2159     0
# 2160     0
# 2161     1
# 2162     0
# 2163     2
# 2164     0
# 2165     1
# 2166     0
# 2167     1
# 2168     1
# 2169     2
# 2170     2
# 2171     5
# 2172     2
# 2173     2
# 2174     3
# 2175     0
# 2176     1
# 2177     0
# 2178     0
# 2179     0
# 2180     0
# 2181     0
# 2182     0
# 2183     0
# 2184     5
# 2185     1
# 2186     2
# 2187     0
# 2188     0
# 2189     1
# 2190     0
# 2191     2
# 2192     0
# 2193     3
# 2194     1
# 2195     2
# 2196     1
# 2197     1
# 2198     0
# 2199    21
# 2200     0
# 2201     0
# 2202    12
# 2203     4
# 2204     0
# 2205     0
# 2206     1
# 2207     0
# 2208     2
# 2209     0
# 2210     3
# 2211     0
# 2212     0
# 2213     0
# 2214     1
# 2215     1
# 2216     2
# 2217     1
# 2218     1
# 2219     0
# 2220     1
# 2221     1
# 2222     0
# 2223    11
# 2224     0
# 2225     4
# 2226     0
# 2227     0
# 2228     0
# 2229     0
# 2230     9
# 2231     8
# 2232     9
# 2233     0
# 2234     0
# 2235     0
# 2236     1
# 2237     0
# 2238     1
# 2239     0
# 2240     0
# 2241     0
# 2242     0
# 2243     0
# 2244     0
# 2245     0
# 2246     0
# 2247     0
# 2248     0
# 2249     0
# 2250     0
# 2251     0
# 2252     2
# 2253     5
# 2254     0
# 2255    15
# 2256     0
# 2257     0
# 2258     0
# 2259     0
# 2260     0
# 2261     0
# 2262     0
# 2263     0
# 2264     0
# 2265     0
# 2266     1
# 2267     0
# 2268     0
# 2269     2
# 2270     4
# 2271     0
# 2272     0
# 2273     1
# 2274     0
# 2275     1
# 2276     1
# 2277     0
# 2278     0
# 2279     1
# 2280     0
# 2281     0
# 2282     0
# 2283     0
# 2284     0
# 2285     0
# 2286     0
# 2287     0
# 2288     0
# 2289     6
# 2290     0
# 2291     0
# 2292     0
# 2293     1
# 2294     0
# 2295     0
# 2296     0
# 2297     0
# 2298     1
# 2299     1
# 2300     0
# 2301     0
# 2302     0
# 2303     2
# 2304     9
# 2305     0
# 2306     1
# 2307     0
# 2308     0
# 2309     0
# 2310     1
# 2311     1
# 2312     0
# 2313     1
# 2314     0
# 2315     0
# 2316     0
# 2317     0
# 2318     1
# 2319     0
# 2320     0
# 2321     0
# 2322     0
# 2323     0
# 2324     0
# 2325     8
# 2326     3
# 2327     1
# 2328     0
# 2329     1
# 2330     1
# 2331     0
# 2332     0
# 2333     0
# 2334     1
# 2335     0
# 2336     0
# 2337     1
# 2338     0
# 2339     2
# 2340     0
# 2341     0
# 2342     0
# 2343     2
# 2344    19
# 2345     0
# 2346     1
# 2347     0
# 2348     0
# 2349     1
# 2350     0
# 2351     0
# 2352     0
# 2353     1
# 2354     1
# 2355     1
# 2356     1
# 2357     0
# 2358    40
# 2359     0
# 2360     0
# 2361     0
# 2362     2
# 2363     1
# 2364     0
# 2365     0
# 2366     0
# 2367     0
# 2368     0
# 2369     0
# 2370     0
# 2371     0
# 2372     4
# 2373     1
# 2374     3
# 2375     0
# 2376     0
# 2377     0
# 2378    18
# 2379     0
# 2380     0
# 2381     2
# 2382     0
# 2383     0
# 2384     0
# 2385     0
# 2386     0
# 2387     3
# 2388     0
# 2389     0
# 2390     0
# 2391     0
# 2392     0
# 2393     2
# 2394     0
# 2395     0
# 2396     0
# 2397     0
# 2398     0
# 2399     0
# 2400     1
# 2401     0
# 2402     0
# 2403     0
# 2404     0
# 2405     1
# 2406     0
# 2407     3
# 2408    17
# 2409     0
# 2410     0
# 2411     0
# 2412     0
# 2413     1
# 2414     0
# 2415     0
# 2416     0
# 2417     0
# 2418     0
# 2419     0
# 2420     0
# 2421     0
# 2422     0
# 2423     2
# 2424     0
# 2425    38
# 2426     1
# 2427     4
# 2428     1
# 2429     1
# 2430     0
# 2431     0
# 2432     0
# 2433     0
# 2434     0
# 2435     2
# 2436     0
# 2437     1
# 2438     0
# 2439     0
# 2440     0
# 2441     4
# 2442     0
# 2443     4
# 2444     0
# 2445     0
# 2446     0
# 2447     0
# 2448     0
# 2449     0
# 2450     0
# 2451     0
# 2452     0
# 2453     0
# 2454     1
# 2455     0
# 2456     0
# 2457     7
# 2458     0
# 2459     0
# 2460     0
# 2461     0
# 2462     0
# 2463     0
# 2464     0
# 2465     0
# 2466     0
# 2467     2
# 2468     0
# 2469     0
# 2470     0
# 2471     0
# 2472     0
# 2473     3
# 2474     0
# 2475     0
# 2476     0
# 2477     1
# 2478     1
# 2479     1
# 2480     1
# 2481     0
# 2482     5
# 2483     0
# 2484     1
# 2485     0
# 2486     2
# 2487     1
# 2488     2
# 2489     2
# 2490     0
# 2491     3
# 2492     1
# 2493     0
# 2494     1
# 2495     0
# 2496     0
# 2497     0
# 2498     0
# 2499     0
# 2500     0
# 2501     0
# 2502     1
# 2503     0
# 2504     0
# 2505     1
# 2506     1
# 2507     2
# 2508     0
# 2509     0
# 2510     0
# 2511     0
# 2512     2
# 2513     2
# 2514     0
# 2515     2
# 2516     0
# 2517     2
# 2518     9
# 2519     0
# 2520     2
# 2521     3
# 2522     1
# 2523     0
# 2524     2
# 2525     0
# 2526     2
# 2527     2
# 2528     2
# 2529     3
# 2530     0
# 2531     1
# 2532     1
# 2533     0
# 2534     0
# 2535     0
# 2536     0
# 2537     1
# 2538     0
# 2539     1
# 2540     3
# 2541     2
# 2542     1
# 2543     0
# 2544     3
# 2545     1
# 2546     2
# 2547     2
# 2548     4
# 2549     3
# 2550     5
# 2551     4
# 2552    15
# 2553     0
# 2554     0
# 2555     0
# 2556    14
# 2557     0
# 2558     0
# 2559     0
# 2560     1
# 2561     0
# 2562     2
# 2563     0
# 2564     1
# 2565     0
# 2566     0
# 2567     0
# 2568     2
# 2569     1
# 2570     0
# 2571     0
# 2572     2
# 2573     0
# 2574     0
# 2575     0
# 2576    12
# 2577     5
# 2578    38
# 2579     0
# 2580     0
# 2581     0
# 2582     1
# 2583     0
# 2584     1
# 2585     0
# 2586     0
# 2587     0
# 2588     1
# 2589     0
# 2590     0
# 2591     0
# 2592     1
# 2593     6
# 2594     0
# 2595     0
# 2596     0
# 2597     4
# 2598     0
# 2599     8
# 2600     0
# 2601     0
# 2602     0
# 2603     4
# 2604     0
# 2605     0
# 2606     4
# 2607     4
# 2608     6
# 2609     0
# 2610     0
# 2611     0
# 2612     2
# 2613     1
# 2614     0
# 2615     0
# 2616     0
# 2617     0
# 2618     0
# 2619     0
# 2620     2
# 2621     0
# 2622     0
# 2623     8
# 2624     0
# 2625     0
# 2626     0
# 2627     2
# 2628     0
# 2629     0
# 2630     0
# 2631     1
# 2632     7
# 2633     2
# 2634     0
# 2635     0
# 2636     1
# 2637     8
# 2638     0
# 2639     0
# 2640     0
# 2641     0
# 2642     1
# 2643     1
# 2644    26
# 2645     0
# 2646     0
# 2647     0
# 2648     0
# 2649     0
# 2650     1
# 2651     0
# 2652     0
# 2653     1
# 2654     7
# 2655    10
# 2656     3
# 2657     0
# 2658     0
# 2659     0
# 2660     0
# 2661     1
# 2662     0
# 2663     1
# 2664     0
# 2665     1
# 2666     1
# 2667     0
# 2668   100
# 2669     0
# 2670     0
# 2671     0
# 2672     0
# 2673     0
# 2674    17
# 2675     9
# 2676   139
# 2677    55
# 2678     0
# 2679     0
# 2680     0
# 2681     0
# 2682     0
# 2683     0
# 2684     0
# 2685     0
# 2686     0
# 2687     0
# 2688     0
# 2689     0
# 2690     0
# 2691     0
# 2692     0
# 2693     0
# 2694     0
# 2695     0
# 2696     0
# 2697     0
# 2698     0
# 2699     0
# 2700     0
# 2701     0
# 2702     3
# 2703     0
# 2704     4
# 2705     0
# 2706     0
# 2707     5
# 2708     0
# 2709     5
# 2710     4
# 2711     0
# 2712     0
# 2713     0
# 2714     0
# 2715     0
# 2716     0
# 2717     1
# 2718     2
# 2719     2
# 2720     0
# 2721     0
# 2722     0
# 2723     0
# 2724     0
# 2725     1
# 2726     0
# 2727     0
# 2728     0
# 2729     0
# 2730     0
# 2731     0
# 2732     0
# 2733     2
# 2734     0
# 2735     0
# 2736     0
# 2737     0
# 2738     0
# 2739     0
# 2740     0
# 2741     0
# 2742     1
# 2743     0
# 2744     1
# 2745     0
# 2746     0
# 2747     0
# 2748     0
# 2749     0
# 2750     0
# 2751     3
# 2752     0
# 2753     0
# 2754     0
# 2755     0
# 2756    16
# 2757     0
# 2758     4
# 2759    12
# 2760     0
# 2761     0
# 2762     0
# 2763     0
# 2764     0
# 2765     0
# 2766     0
# 2767     0
# 2768     0
# 2769     0
# 2770     0
# 2771     0
# 2772    34
# 2773     9
# 2774     0
# 2775     0
# 2776     0
# 2777    11
# 2778     0
# 2779     0
# 2780     0
# 2781     0
# 2782     0
# 2783     0
# 2784     0
# 2785     3
# 2786     0
# 2787     0
# 2788     4
# 2789     0
# 2790    91
# 2791     0
# 2792     0
# 2793     0
# 2794     0
# 2795     0
# 2796     1
# 2797     0
# 2798     0
# 2799     4
# 2800     0
# 2801     6
# 2802     5
# 2803     0
# 2804     0
# 2805     0
# 2806    12
# 2807     1
# 2808     0
# 2809     0
# 2810     0
# 2811     0
# 2812     0
# 2813     0
# 2814     0
# 2815     0
# 2816     0
# 2817     0
# 2818     0
# 2819     0
# 2820     0
# 2821     0
# 2822     2
# 2823     0
# 2824     0
# 2825     0
# 2826     0
# 2827     0
# 2828     0
# 2829     0
# 2830     0
# 2831     0
# 2832    10
# 2833     0
# 2834     0
# 2835     0
# 2836     0
# 2837     0
# 2838     0
# 2839     0
# 2840     0
# 2841     0
# 2842     0
# 2843     0
# 2844     0
# 2845     0
# 2846     0
# 2847     0
# 2848     0
# 2849     0
# 2850     0
# 2851     0
# 2852     0
# 2853     0
# 2854     0
# 2855     0
# 2856     5
# 2857     0
# 2858     0
# 2859     0
# 2860     0
# 2861     4
# 2862     4
# 2863     0
# 2864     0
# 2865     0
# 2866     0
# 2867     0
# 2868     0
# 2869     1
# 2870     0

# %%
df.shape
# Out:
# (2871, 4)

# %% [markdown]
# #### corpus (말뭉치) 생성

# %%
corpus = df['REVIEW']
corpus
# Out:
# 0       부산에도 기다리던 지역화폐가 나왔네요 앱도 깔끔하고 카드도 바로 신청하고 잘 사용하...
# 1                                                     화이팅
# 2                                      기다렸었는데 앞으로 잘 쓸게요^^
# 3         동백전으로 여기저기 많이 사용해 볼게요. 부산 경제에도 많은 도움이 되면 좋겠습니다.
# 4                   부산 동백전 쓰기 편하게 잘 만들어졌네요 부산에서 혜택이 많았겠네요
# 5                       잘 사용해 볼게요. 동백전으로 혜택 많이 받으면 좋겠습니다.
# 6                                        가자 글로벌 테스트베드 부산!
# 7       오~ 부산도 드디어 모바일 지역화폐가 나왔네요!~ 앱설치하고 카드신청도 해봤는데요 ...
# 8                    드디어 기다리던 동백전앱이 출시됐네요 앞으로 이용 많이 하겠습니다
# 9          군더더기 없는 ui가 마음에 드는군요. 많은 사업장에서 사용가능하면 더 좋겠습니다.
# 10                                                    좋아요
# 11      선택약정선택하면 네트워크장애라고 뜨면서 진행되지 않음...부산시에서 개인정보를 팔아...
# 12                            많은 이용 바랍니다 부산시민과 함께 성장해 갑시다
# 13      부산을 대표하는 꽃 이름으로 지은 동백전. 이름이 멋지네요. 부산에서 이용하는 혜택...
# 14                                           편의점에서도 사용되나요
# 15                                        설치가 아주 간단하고 쉽네요
# 16                              군더더기 없이 사용하기 편하고 좋습니다. ^^
# 17                       어플이 깔끔하니 사용하기 좋아요 자주 사용하게 될듯 하네요
# 18             아니 QR코드 결제가 안되냐 기본인데 하. 카드 신청도 잘 안되고 미치겄네.
# 19      회원가입이 안 돼요 다음주에 만 18세 되는 사람인데요 계속 만 14세 이상만 가입...
# 20      적립한도 볼 수 있게 잘 쓰고 있는데 충전한도 말고 적립한도도 볼 수 있게 하면 훨...
# 21      지웠다 깔아도 들어갈 수가 없음 -_- 마트에서는 결제가 안됐다고 하고 돈이 빠졌는...
# 22      앱 오류 안고쳐주실건가요?? 충전하려고 앱들어가면 데이터 상태로는 들어가지지도 않고...
# 23      오류 좀 개선해주새오 너무 오류가 심해요. 캐시백이 안되어서 문의했더니 다시 가게에...
# 24               앱실행이 안됩니다 사용자 정보 취득에 실패하였다면서 앱이 꺼져버립니다….
# 25                              안들어가져요 먹통입니다..다시 설치해도 그래요
# 26                   정말 오류가 많이 뜨네요 오류가 계속 떠서 사용하기 너무 힘들어요
# 27      발급받은 지 한참 지났는데 앱 오류 때문에 충전을 못합니다 빨리 개선 부탁드립니다…...
# 28              안켜져요 ㅠㅠ 계속 오류나서 새로 설치했는데 자꾸 네트워크 오류라고 하네요
# 29                           욕나올정도로 후짐 며칠전부터 가맹점조회 아예 안됨.
# 30      동백전 카드 결제지연 오류 아니 무슨 카드가 사용자가 많다고 오류가 되서 계산이 안...
# 31      가맹점 찾기 4/2일까지는 문제 없었는데 4/3일 서버 폭주로 접속 제한된 다음부터...
# 32      갑자기 가맹점 찾기가 안되요 갑자기 가맹점 찾기가 안되요 삭제후 재설치 했는데도 안...
# 33         가맹점찾기 가맹점찾기 아무것도 안뜨고 도대체 어딜 봐야하나요? 오류가 너무 잦아요!
# 34      가맹점 찾기가 안 되어 문의드립니다. 동백전 정말 잘 사용하고 있어요! 캐시백 10...
# 35                             가맹점 가맹점 찾기 아예안되요 쓰지말라는건가요?
# 36      어플이 진짜 구려요 오류나서 접속이 안되고 로그인도 안되고..써야할 때 못쓰면 무슨...
# 37      가맹점 찾기 가맹점검색하려면 0만뜨고 전에는 검색이 됐는데ㅠㅠ 아무것도 안나오는데 ...
# 38      오류가 장난 아니네요;;;; 좋아요~ 포인트도 많이 쌓이고 돈쓸맛 나는데 오류가 심...
# 39      갑자기 왜 안들어가지죠 낮에 분명 사용하고 방금 가맹점 카페와서 사용하려고 하는데 ...
# 40      못쓰겠네요 버그빨리 수정요 뭔 자꾸 튕기니 ㅋㅋㅋ 쓰지말라는 뜻인가요? 빨리 버그 ...
# 41      가맹점찾기 다 좋은데 얼마전부터 가맹점찾기가 안되네요 계속 0건만 뜹니다 빨리 해결...
# 42      네트워크 네트워크로 인해 실행이 안된다고 뜨네욤,,, 아까 까지 되었는데,,, 수정...
# 43      기간별 검색기능 강화 요청 예를들어 4월1일부터 오늘까지 사용실적 또는 적립실적 검...
# 44        문자인증이 안와요 어플이 안켜져서 삭제했다가 다시 깔았는데 문자인증메세지가 안와요ㅠㅠ
# 45      교통카드 이용내역 다 좋은데 카드 이용 내역에 후불교통카드로 쓰인 금액도 적혀있으면...
# 46      한달동안 결제한 내역 총 합계를 볼 수 있었으면 한달동안 결제한 내역 총 합계를 볼...
# 47      문제가 많네요 50만원 충전했다가 충전취소하고 다시 충전하려고 했더니 충전이 안되는...
# 48      앱 쓰레기 동백전 신청하려고 앱 깔았는데 에러만 벌써 15번째… KT에서 개발한거라...
# 49                                    최악 어플이되야ㅡ쓰죠!!!!!!!!
# 50      금액 충전이 안 되고 자꾸 꺼져요 금액 충전해서 쓰고 싶은데 앱이 자꾸 다운되고 꺼...
# 51       사용내역 보려고 하면 어플이 꺼져요 충전만 되고 뭐 하려고 하면 꺼져서 쓸수가없어요^^
# 52             안켜져요 업데이트하고나서 동백전 어플이 안들어가집니다. 오류 보완 부탁드려요
# 53      어플을 운영을 하실거면, 불편함은 제때 개선좀 하세요 국민들 불편함 의견제기 1. ...
# 54                                 열면 안들어지네요 안들어가쟈여 고쳐주세요
# 55      잘 쓰고 있어요 렉이나 오류도 없고 캐시백도 많이 받아서 쓰는 재미가 쏠쏠하고 좋아...
# 56                오류 어플 오류가 너무 많아요 쓰고싶을때 한번도 제대로 써본적이 없어요
# 57      이번달만 오류가 몇번인지..ㅡㅡ 하 이렇게 오류가 많이 나는데 어찌 쓰란말인가요? ...
# 58         확실히 진짜 좋은데… 카카오 뱅크 계좌는 왜 등록이 안되는건가요? 정말 불편해요….
# 59                    ㅋㅋ고객센터 고객센터 답변 얼마나 기다렸는데 일 쥰나 안 해요~
# 60      결제안된다해서 다른카드로 결제했는데 동백전에선 또 돈이 나가네요 일반 슈퍼인데도 동...
# 61      가맹점 찾기 기능 개선 해주세요 가맹점 찾기 기능에서 현재 위치에서 지도를 보면 사...
# 62      좋긴한데요…. 결제 어플인데 이거 업뎃때문에 못쓴다고 안 막았으면 합니다. 결제해야...
# 63                  백원 단위도 충전되게 해주세요ㅠㅠㅠㅠ 제발요 ㅠㅠㅠㅠ다좋은데ㅠㅠㅠㅠ
# 64                           택시는 안되나요? 몇번 결제할려는데 다 안되네요 ㅠ
# 65      가맹점 표시 지도상에 한꺼번에 표시될 수 있게 해 주시고 띄어쓰기 잘못하면 검색이 ...
# 66      사용자정보취득에 실패하였습니다 사용자정보취득에 실패하였습니다 앱을 다시 실행해주세요...
# 67      앱더럽게안됨 안들어가지고 삭제했다가 다시 들어가니 로그인 화면도 없고 회원가입하라고...
# 68      갑자기 안되니까 어이없네… 아니 왜 갑자기 네트워크 불안정 하다고 뜨고 안 들어가지...
# 69      어플실행오류 어플이 갑자기 실행이 안됩니다. 와이파이도하고 데이터로도 해봤지만 두개...
# 70      갑자기 서비스가 안돼요 개인정보 확인이 안된다고? 오류메시지가뜨고 튕겨서 삭제했다 ...
# 71      어플 설치가안되어요ㅠㅠ 잘쓰고있었는데 금일 저녁 씨유에서 카드 주니 포스기에서 결제...
# 72      본인인증단계에서 인증문자가 안와요 개선해주세요 본인인증단계에서 인증문자가 안와요 개...
# 73      이 앱 덕분에 동백전 씁니다 오랜만에 앱 제대로 만들었다 싶네요. 놀라울 정도로 간...
# 74      빠르고 좋은 앱이네요 메인화면 하단 카드바가 메인 화면 진입시 움직이는 모션은 예쁘...
# 75      내가 보유한동백전 칸에 불필요한건 삭제 너무 잘쓰고있습니다 ㅎ 근데 충전할라고 켜면...
# 76                                               좋아요 좋습니당
# 77             앱 사용 내역 볼려고하면 계에에에에ㅔㅔㅔㅔㅔ속 나가지네요 빨리 고쳐 주세요
# 78                큐알 코드 결제 부탁… 실물 카드로만 되는 보네여….. 아이폰은 웁니다
# 79              클릭 안됨 가입 다 하고 맨 마지막에 비밀번호 설정하는 거 클릭이 안되네요
# 80                           쓰라는거야? 카드 신청도 안되고 계좌 등록도 안되고
# 81      너무좋아요 얼마 쓰지도 않았는데 캐시백 쏠쏠해요 5000원 단위 충전도 가능해서 현...
# 82                                       정말 잘쓰고 있습니다!! 굿굿
# 83      금액을 직접 설정해서 충전하면 좋겠어요 정해진 금액만 말고 사용자가 충전하고 싶은 ...
# 84      ㅠ가맹점 찾기라뇨ㅠ 생각보다 안되는곳도 많고 충전금액 환불은 왜 안되는거죠? 계속 ...
# 85      가맹점 찾기 왜있나요? 되는곳도있고 아닌곳이있고. 그게 헷갈려서 찾기 서비스가 있는...
# 86            가맹점이 두개씩 중복되서 나와요 가맹점 검색하면 중복해서 나와서 보기 힘들어요
# 87      인증안됩니다. 전화번호 누르고 인증하기 버튼이 먹통이네요. 혜택도 좋은데 이러다 잊...
# 88      QR코드 간편결제도 되었으면 좋겠어요 카카오페이처럼 QR코드로 간편결제도 되었으면 ...
# 89      동백전 최고 동백전 충전하면 캐쉬백도 10%나 해주고 가정생활에 많은 도움이 되네요...
# 90                 할인 많이 되네요 할인 생각보다 많이 되네요 더 가맹점 늘려주시길..
# 91                          안증안되요.. 쓰고싶어도 인증이안되니 쓸수가없네요..
# 92      출시기념 1월 한달간 이벤트를 하는데 1월 지났는데도 아직 다운로드를 받지 못하는 ...
# 93                                기다렸는데 드디어 빨리 가입 흥해라 동백전
# 94             뭐 이런 개쓰레기 같은 앱이 다 있어. 죽도록 카드신청해도 안됨. 안써!!!
# 95      앱에서 결제되게 해주세요 동백전 좋다 좋다 말 많이 듣고 드디어 실물카드 받았습니다...
# 96      실행이 안됩니다 어플을 실행시키면 알림설정 창과 필수동의 까지는 되는데 그 다음 화...
# 97                              쓸만하네요 캐시백 비율이 높아서 쓰는데 좋네요
# 98                국굿 아이폰 바코드나 큐알코드 결제만 앱에서 가능 하면 최고일것 같아요
# 99                                         어플 오류 아예 접속 불가
# 100                          너무 좋은데 앱실행이 안되요 저만 안되나요!!!??
# 101     앱 오류 빨리좀 해결해주세요 잘사용하다가 앱켜면 사용자정보를 읽을수없다고 다시시도해...
# 102     잘사용하고있었는데 잘 사용하고있던 중이었는데 갑자기 앱 오류로 안들어가져서 앱삭제하...
# 103          아예오류나고안들어가져요 오류나고 아예안들어가지는데 어떻게요? 서버없다고만 뜨고요
# 104     사용자찾을 수 없다고 오류가 계속 뜨고 넘어가질 않는데 왜그럴까요ㅠ 어플 삭제 후에...
# 105     어제까지 앱실행 잘 됐는데 No server is available to handl...
# 106     오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하...
# 107                           503오류 뜨면서 실행안되네요 우째해야되나요ㅡ.ㅡ
# 108      돈 넣었는데 어플 실행이 안돼요 ? 잘 쓰다가 돈 남아있는데 어플 실행이 안돼요 뭔데요
# 109     오류 갑자기 오늘 접속오류 계속 뜨길래 삭제 후 다시 깔았더니 아예 안되네요; 빠른...
# 110                                아이폰 X 충전안됨 충전하러 가면 튕겨요
# 111     내역만 들어가면 팅김 내역에 들어가면 팅겨요. 아이폰 xs입니다. 다른 내역 확인 ...
# 112     카드신청안됨 다 하고 마지막에 계속 오류가 나요ㅠ 청구서 수령관련 등록을 해야된다는...
# 113     왜때문에 인증이안되나효 내이름에 내 탄생일에 내 명의의 핸드폰번혼데 자꾸 확인하래 ...
# 114     고객 서비스가 최악이네요 어플 오류로 인하여 충전 하려고 하니 바탕화면으로 팅기는데...
# 115                    안들어가져요 업데이트 했는데 안들어가져요.. 해결 좀 해주세여
# 116     앱 꺼짐 문제 앱 들어가서 캐쉬백을 누르면 앱이 꺼져버리는데 어떻게 해야되나요? 다...
# 117       불안정한 앱 이용내역 확인 시 강제종료 앱 메뉴도 간단하고 동백전 서비스도 훌륭한데
# 118     ㅠ 주민등록증 찍는데 청소년들은 청소년증으로 하라해서 청소년증 찍고 발급날짜 했는데...
# 119     개선사항 요청하고 싶습니다! 본인 인증 수단을 공인인증서도 추가 하였으면 좋겠습니다...
# 120     동백전 어플설치 저는 아이폰이라 설치를 했지만, 아버지도 동백전 어플 설치해드리려고...
# 121     어플 팅김현상 2월달부터 잘 사용하다가 오늘 업데이트를 했는데 어플 접속이 안됩니다...
# 122     동백점 미가맹점 결제 가능 요청 잘 사용중입니다. 감사합니다^^* 다만 동백점 미가...
# 123     아이폰에서도 쓸 수 있어 좋아요 동백전 아이폰에서도 쓸 수 있어서 좋아요. 자주 사...
# 124                           동백전 아이폰 앱 드디어 출시됐네요… 잘 쓸게요…
# 125     노트2에서는 버전이 낮아서 검색이 안되는데.. 어느버전 까지 가능 한가요? 앱 다운...
# 126     부산경제를 위한 동백전이네요.. 10% 혜택을 주니 잘 사용하겠습니다. 앱 사용이 ...
# 127                                            아이폰은 안되나요?
# 128                               이름도 이쁘고 앱도 깔금하게 잘되어 있네요
# 129                                             정말 편리하네요~
# 130                부산시에도 지역화폐가 생겼네요~ 동백전 이름 좋고 화면도 깔끔하네요~
# 131                 심플하고 사용하기 편하네요. 잡다한 기능보다 기본에 충실한게 좋죠.
# 132                       부산에서도 이제 사용이 가능하군요..많니 기대가 됩니다.
# 133     아니 QR기반 회사 KT가 왜 카드를 발행해요? 카드는 또 하나카드네? 하도인가? ...
# 134                                      부산은행은 결제계좌로등록이안됨
# 135     카드도 발급받고, 가입도 다 했는데 새로 앱 실행할때마다 인증된 폰번호와 현재 폰번...
# 136     가입하고 카드 신청해놓고 아직 사용은 안해 봤지만 어플은 정말 잘 만들었네요 박수 ...
# 137                 부산이 살아야 대한민국이 산다! 부산지역경제를 위하여 똑똑한 소비!
# 138                                                    신청
# 139                    개인 정보 입력만 13회 했습니다. 이 어이없는 오류 뭡니까?
# 140     동백전 앱 들어갈려면 꼭...세,네번만에...들어감....프로그램 개발을 어떻게 한...
# 141                                 아직 사용 경험이 없어 잘 모르겠습니다
# 142     시안성과 디자인도 뛰어나 사용이 간편하며, 다양한 혜택이 있어 무조건 강추 합니다....
# 143     이벤트기간에 사용하면 10% 캐시백 즉시 지급되구요 평상시엔 6%적립이 되어서 사용합니다
# 144                   사용시 가입자에게 혜택이 매우 큰것 같습니다. 적극 사용할께요.
# 145                                               너무 조아요.
# 146                                            사용편리해서 좋아요
# 147                                              캐시백 개꿀~!
# 148                     네트워크오류로 계속안들어가 지는데 원래이런건가요? 답답하네요
# 149                                            너무 편하고 좋아요
# 150     오늘 카드발급 후 앱을 깔아 하나은행 계좌를 등록했는데 결제상황 등 보유내역 등 전...
# 151                                              응원할께요..,
# 152                            동백전 설치후 사용해보니 새로운 세상이 열리네요
# 153                          앱도 편리해서 사용도 좋고, 캐시백도 좋네요.굿~~
# 154                                 사용이 편리하고 앱 디자인도 멋집니다.
# 155                                           혜택이 혜자스럽네요.
# 156            바로바로 캐시백이 들어오니까 혜택이 더욱 크게 느껴지네요! 굿입니다 ^^bb
# 157     앱설치 후 사용해보니 App 디자인도 세련되었고 심플한것이 너무너무 마음에 들어요....
# 158     동백전을 설치 후 사용해보니 새로운 세상이 열리네요..^^ 앞으로 카드사용은 자제하...
# 159                                               캐쉬백 좋아요
# 160                                         사용하기에 매우 편리 함
# 161            체크카드라서 좋아요 10퍼센트 페이백 좋네요 프로모션기간이 길었으면 좋겠어요
# 162                             좋아요. qr코드결제도 어서 됐으면 좋겠네요.
# 163                                                  Good
# 164                                              좋은것 같아요ᆢ
# 165           새마을금고 없어 카드발급 안돼요 괜히 충전하여 환불 해주세요 사용도 못 하는데
# 166                                               괜찮아요...
# 167                                   캐시백도 바로 사용가능하고 매우만족
# 168                                                  신나네요
# 169                                        카드만들다 사용 포기합니다
# 170         할인폭이 너무 크고 넘 편리해요. 우리 부산시 상공인에게 도움된다니 더욱 좋네요.
# 171                          동백전으로 이용할 생각 입니다 사용하기 편리 합니다
# 172                                                    만족
# 173                                   충전하려니깐 카카오뱅크가 없네요ㅜㅜ
# 174     본인명의폰 아닌사람은 가입을 못하네요 공인인증같은거나 다른 인증할수있는방법 더 생기...
# 175     아주 유용한 앱 서비스네요. 충전하구 카드 받아서 쓰는 게 좋구 쓰고나니 캐쉬백이 ...
# 176                                               안들어가지네요
# 177     어플에서 바로 결제가 됐으면 좋겠어요. 카드 발급 받는 게 시간도 오래 걸리고 은행...
# 178                                매우 유용합니다. 전 가족이 쓰고 있어요
# 179                                              너무 좋습니다😊
# 180                   동백전을 사용해 보니 사용하면 할수록 차곡 차곡 적립되는 캐시백
# 181                              동백전 휴대폰 단말기 살때도 캐시백 되나요?
# 182     너무 어려워요. 충전방식이라 많이 번거롭네요. 폰결제 되는 쉬은 방법으로 업그레이드...
# 183     1:1문의 답변확인이 안되네요 호완성문제인지 다른어플은 정상적으로 작동하는데 이것만...
# 184                                     정말 사용하기 편하고 좋습니다.
# 185                              계좌등록이 계속 실패로 떠서 사용이 불가능함
# 186                                            깔끔하고 혜택 좋고
# 187          회원가입 할때 동의사항들전부선택햇는데도 다음으로 안넘어가지는데 혹시 오류인가요?
# 188     치명적인 단점 지적합니다. 환불정책 정말 불편하네요. 전체 적립금에 60%이상 써야...
# 189     회원가입할때 직장주소 검색하고 다시들어오니까 어플 끄지도 않았는데 처음부터 다시 입...
# 190     아니... 계좌등록하려니 계속 계좌번호 오류라고하는데 왜그런거예요? 숫자 잘못친줄알...
# 191                                                 좋아요~~
# 192                           교통카드..버스나 지하철만 써도 캐시백 되나요??
# 193                       앱이 다운로드가 안되고 계속 로딩 중이네요 서버좀 늘려요
# 194     본인명의 핸펀만가능한거가요?? 아이핀이나 본인인증다른방법도 하게 해주세요!! 배우자...
# 195                         들어가지지도 않구만ㅡㅡ 전화도 안받고... 장난합니까
# 196         가맹점찾기가 너무 불편하네요 지도에서 찾기 기능이 있으면 훨씬 찾기 편할것 같아요
# 197     앱 접속시 계속 팅김 카드신청과정에서도 불안정함 주민번호 입력하면 자꾸 다른숫자로 ...
# 198             카드도 너무 예쁘고 앱도 깔끔해서 좋아요 편하게 잘 사용할 것 같네요 :)
# 199     기능도 만족스럽고 검색해서 가맹점 찾을 수 있는거 너무 좋은거 같아요!! 그런데 카...
# 200     18살인데 카드 발급받을때 주민등록증 번호를 작성하라는데 주민등록증이나 운전면허가 ...
# 201                                    최악임 깔고나서 본인인증문자아안옴
# 202                  앱 실행이 안됩니다. 네트워크 상태를 확인하라는 매세지만 뜨네요.
# 203     가맹점 찾기 카테고리를 구별로 나누어 주셨으면 좋겠습니다. ㄱ부터 시작하니까 해운대...
# 204                                         정말 유용한 앱이네요~~
# 205                동백전가입시 LGU+알뜰폰은 인증이 안돼 가입이 안됩니다 조정바랍니다
# 206     동백전 정말 좋아요. 어디다가 리뷰를 써야될지 몰라서 여기 씁니다. 우선 적립이 바...
# 207     아직 써보지도 못했을 뿐더러 예기치못한 오류라며 앱 접속조차 안되네요... 부산지역...
# 208     동백전 앱을 다운받아 회원가입 2단계까진 잘되나 다음단계에서 처음단계로 되돌아가버려...
# 209      어제부터 통신중예기치않은 오류라고 앱사용이 불가합니다 무슨문제인거고 언제 정상화되나요?
# 210       본인인증 방법이 폰인증 밖에 없나요? 본인명의의 폰이 아닌 사람은 발급이 불가하나요?
# 211     추천인은 뭘 써야하나요? 한글은 안써지고 숫자는 써지는데 휴대폰번호를 쓰는것도 아닌...
# 212                                                   좋아요
# 213     카드신청에 들어가서 카드선택후 신청하기누르면 '일정기간 미사용으로 작업이중단됩니다'...
# 214     다운받았는데 카드신청이 안되네요 계좌등록하고 충전 후에 카드신청 가능한건가요? 사용...
# 215     회원가입시 인증번호가 안옵니다. 이틀째 가입중인데 인증번호가 계속 수신이 안되는데 ...
# 216                              지금 카드사용 불가네요 통신오류 뜹니다 ㅜㅜ
# 217             가맹점 검색에서 지역을 지정 후 검색 가능하도록 기능 추가 부탁 드립니다.
# 218     -네트워크 상태 원할하지 않습니다- 계속 뜨네요. 해결 하셔야 할듯합니다. 속도 제...
# 219                                                   좋아요
# 220     껐다가 켜면 다시 처음부터 인증해야 하는 치명적인 버그가 존재합니다. 충전 하자마자...
# 221                                 친구가 캐시 바로 들어오더라고 추천해줌
# 222         지역경제에 기여하면서 캐쉬백도 가능한 동백전이 있으니 더이상의 카드는 필요없네요.
# 223                                                   좋아여
# 224                                                    최고
# 225                                                     굿
# 226                                                   좋아요
# 227                                             세금공제 30프로
# 228                                                    최고
# 229     부산의 주유소에서 사용이 안된다하여 난감한 경험있습니다. 사용가능하도록 지원, 배려...
# 230                         쓰자마자 깨시가 10%로 바로 들어오니깐 완전짱입니다
# 231     슈퍼에서 우유를 2 번 샀읍니다 .10%씩 적립 되여 기분 좋았읍니다. 택시는 개인...
# 232                                           동백전 편하고 좋아요
# 233                                 실물카드받았는데 어플엔 등록안되어있어요
# 234                                       지역 자영업에 도움이 됩니다
# 235                                   소상공인과 시민들에게 좋은 제도네요
# 236                               걸제불가능한 곳에 대한 정보 제공이 필요함
# 237                                              너무 좋아요ㅎㅎ
# 238                                         케시포인트 너무 좋습니다
# 239                                              절약에 도움이됨
# 240                                                적립 대박~
# 241                                                  넘좋아요
# 242                                                   멋져요
# 243                            업데이트 실행 안되네요. 삭제 후 재설치도 안됨
# 244                                                캐시백 개꿀
# 245                                                 최고입니다
# 246                                                    굿굿
# 247     깔고 위치확인동의 같은 것들 모두 동의 누른다음에 계속 흰화면이 뜨고 한 4~5분 ...
# 248                     동백전 어플들어가니깐 악성코드를탐지햇다고뜨는데 왜그런거에요?
# 249                                                   편해요
# 250                                                완전 좋아요
# 251     카드 수령지가 자택 외에 설정이 안되네요... 리뷰 보니 형식적인 답변 뿐이고 활성...
# 252                                               신통방통합니다
# 253                                           정말 좋습니다 굿^^
# 254                                                    구웃
# 255                    사용이 편하네요...동백전 지점 정보가 좀더 명확했음 하네요~
# 256     가맹점이 어디더라 생각 안하고 일단 들어가서 결재하면 어지간하면 가맹점이네요 ㅋㅋ ...
# 257                            동백전 밴드앱 악성코드로 인식합니다 확인바랍니다
# 258                                                 무리 없음
# 259     네이버 밴드 어플을 악성코드로 인식하네요. 밴드어플을 삭제하고 어플설치후 밴드를 다...
# 260                                                    ㅇ아
# 261     앱 시작하면 악성코드가 발견되었다면서 창이 뜨는데 이거 해킹당한거 아닌가요? 불안해...
# 262                                                    굿.
# 263                                       카드는 언제받을 수 있나요?
# 264     사용처 제한으로 불편함이 많음. 특히 재래시장에는 카드계산기 없는 상점이 많아 더 ...
# 265     앱 업로드이후 자꾸 재시작해야 하는 버그가 계속발생 합니다. 업로드전에는 전혀 문제...
# 266     동백전의 의도는 너무 좋으나 앱이 너무 안 좋습니다. 동백전이 활성화하지 못하게 된...
# 267     동백전회원가입하려는데 현재폰이 부모님명의로 되어있는데 휴대폰인증말고 다른방법으로 가...
# 268                                        편하게 잘 사용하고 있어요
# 269     와이파이 연결시에는 어플 접속이 잘됩니다. 하지만 데이터 사용시 접속이 잘 안됩니다...
# 270     음식점 가맹점되는곳에서 카드사용시 배달의 민족이나 배달대행어플을 통해서 계산해도 캐...
# 271                                                   잘안됨
# 272                             휴대폰 명의가 틀리는데 어떻게 가입안 안될까요
# 273     인증문자 자체가 안오는데 뭘 어떻게 카드발급 받으라는거죠? 뭔가 제대로 이용할수 있...
# 274                               인증번호 발송됐다는데..인번이 안와서...
# 275                페이코랑 하나머니가 추가되어 피킹률 12퍼센트를 넘길수있는 갓혜자카드
# 276                                                     굿
# 277     가맹점 찾기를 통해 나오는 가맹점이 10년전쯤에 그 자리에 있던걸로 현재는 없어졌는...
# 278             캐쉬백 이벤트기간 10퍼 장난 아니네요 좀 있음 6퍼겠지만 대만족중 입니다
# 279     동백전어플을깔고난후에 회원가입 약관선택 후 다음 화면으로 넘어가지지않고 네트워크가원...
# 280                                                 페이백 굿
# 281     아직 사용하기전이나 왜 항상 국가사업이 들어간 금융앱이나 국가,지자체에서 실시하는 ...
# 282                                      아쉽지만 쓰는데 불편함은 없다
# 283                                인증번호가 안오네요 앱에 문제가 있나요?
# 284       계속 통신 오류가 뜨네요. 이러면 동백전 사용하기 불편해서 사용이 안될 것 같은데요.
# 285                                         앱이문제네요 성질돋구네요
# 286     가입은 수월히 카드신청시 은행계좌 연결하여 다시 키려면 다시 처음부터, 충전계좌 연...
# 287                                            다운로드가안되여..
# 288     어플실행시 정상적인OS가 아니라서 이용할수가 없다고 메세지가 나옵니다. 엘지V40이...
# 289                  어제부터 와이파이해도, 안해도 서버통신?문제로 연결안된다고 뜨네요
# 290                    본인인증이 휴대폰말고 아이핀이나 공인인증도 추가되었음 합니다.
# 291                                             다운이안받아지네요
# 292     이벤기간이라 캐시백 비율이 높아 내가 내는 돈은 줄었음. 그러나 이 카드를 아예 안...
# 293                         내게 만족을 주는 그런 카드면서 행복감을 주는 동백전
# 294     어플이 실행안되요 통신중 오류가 발생했다고 어플 삭제후 다시 하여도 그대로 입니다 ...
# 295     업데이트 이후에 뭘사러 갔더니 분명 해당점포가 캐쉬백대상점포인걸로 아는데 캐쉬백이 ...
# 296                                          카드신청오류 계속뜨네요
# 297                하이마트에서 사용가능한다고 나오나 사용이되지 않습니다 확인부탁드릴게요
# 298     네트워크 연결이 원활하지 않습니다. 접속오류 다른 어플과 인터넷은 잘 사용되는 중인...
# 299      계속 렉걸리고 네트워크접속이 안된다고하고 예기치못한오류가 생겼다며 너무 잘 안됩니다ㅠㅠ
# 300     켤때마다 통신이어쩌고하면서 종료되고 다시들어가야 됩니다. 이번에는 5번이나 튕기고 ...
# 301     동백전 앱 사용시 카드충전금액이 모자라거나 안되어 있으면 연결계좌에서 빠져나가잖아요...
# 302                                 카드신청이 안됩니다 눌러도 반응이없어요
# 303              카드신청시 주민번호 입력후 다음화면으로 넘어가지않습니다. 업데이트해주세요
# 304     정말 좋은 카드라서 잘 사용하고 있는데 앱에 문제가 있는지 실행하려고 앱을 누르면 ...
# 305       인증된 번홓하 현재 번호가 달라서 계속 초기화 하라고 뜨는데 어떻게 해결해야 되나요?
# 306     너무좋은 카드인데 앱 오류가 너무 심해서 잔액 확인이 안되는점 빨리 개선 되었음 좋...
# 307     휴대폰 본인인증 문자가 10~20분뒤에 전송되어서 가입이 불가능합니다. 인증시스템에...
# 308     아빠 폰에도 동백전 깔아드려서 쓰는데 이상하게 동백전만 켯다 끄면 문자에 들어갈 수...
# 309                                  실행도 안되는구만. 별 하나도 아까워
# 310     정상적인 os가 아니면 서비스 이용이 안된다면서 앱실행이 안됩니다 고객센터 전화연결...
# 311                             연3일째 계속 앱도운로드중 아직도 다운중이네요
# 312                회원가입 과정중 인증번호 전송 버튼을 아무리 눌러도 전송이 되지 않음
# 313     왜 두번 터치해야 정상적으로 어플이 실행되는지 모르겠네요. 한번 실행하면 보안프로그...
# 314                                     캐시백 현재 10프로 대박. ㅎ
# 315     너무좋네요 근데홍보가 이제되기시작했는지 지금만든사람이 많아요 10프로캐시백 3월까지...
# 316     탭으론 접속조차 안되네요. 저 처럼 폰은 2g폰이고 탭으로 인터넷하는 사람은 어떻게...
# 317     잘사용하고 있습니다^^ 근데 어플을 실행시키면 왜 첫번째는 실행되다가 닫기고 두번째...
# 318                                              동백전앱이 안됨
# 319     일정 시간 미사용으로 작업이 중단 되었습니다 라고 계속 떠는데 어떻게 하면 되나요....
# 320       혹시 카드 수령지를 자택에서 직장으로 변경되지 않나요? 이것땜에 가입 못하고 있읍니다
# 321                                                 굿 좋아용
# 322                                           어플 다운 불가...
# 323     다 좋은데 연결계좌 은행에 카카오뱅크가 없어서 불편합니다. 연결계좌은행은 좀 다양해...
# 324                          월별 사용합계를 자동으로 볼수 있으면 더 좋을듯해요
# 325                                                   좋아요
# 326                                          체크카드도 캐시백주시지
# 327                                               겁나 좋음 짱
# 328                                                   좋아요
# 329                                        캐쉬백 짱. 지역 발전 짱
# 330                                          잘 이용됩니다. 굿~~
# 331                                                   개편함
# 332                                                 감사합니다
# 333                                                     굿
# 334                                                 매우 좋음
# 335                                                 최곱니다.
# 336     부산 동백전이 엄청 편리하고 캐시백이 10% 되니 얼마나 좋습니까! 3월이후에도 년...
# 337                                              10프로 꿀~~
# 338                                                 추천합니다
# 339                                                  좋아요~
# 340                                                     굿
# 341                                             폰결제 쫌 되겠죠
# 342                                      어느카드보다 혜택 최고입니다.
# 343                              사용한금액에 포이트도 받고 너무 좋아요,,굿
# 344                                                   좋아요
# 345              동백전 사용가능 업체라고 검색하고 갔는데 사용되지 않았습니다. 완전 비추
# 346                                                     굿
# 347                                                   좋아요
# 348                                                  좋아요.
# 349                                                   좋아요
# 350     공인인증서로도 로그인가능하게해주세요 휴대폰명의가 다른게 너무불편.. 제발요 아님 폰...
# 351                  미적용 매장에서도 체크 카드 겸용이용 할수 있으면 더욱 좋겠군요.
# 352                                                 감사합니다
# 353                                     사업자용카드로 등록 가능한가요?
# 354                                                최고 입니다
# 355                                                   좋아요
# 356                                                    따봉
# 357                                         캐시적립이 정말대박이네요
# 358                                               최고의지역화폐
# 359                                    로그인후 사용하게 해주세요~~^^
# 360                                                   좋아요
# 361                                            사용 편하고 좋아요
# 362                                                   좋아요
# 363                                               아주만족합니다
# 364                         이렇게 좋을 수 가 없습니다 10%할인 너무 좋습니다
# 365           너무좋아요 하지만 택시에서 카드결제시 5번중 1번만 승인되서 다른카드로해요ㅠㅠ
# 366                                       충전금액 입력가능하게 합시다
# 367               편리하고 좋아요, 다만 잔액부족시 바로 카드결제 되는점은 개선 바랍니다
# 368              전월사용실적이 연간으로 있으면 더편할것같아요^^ 동백전 너무 좋습니다~~
# 369                                       좋아요 계속 10% 해주셍ᆢ
# 370                    편리합니다. 그러나 Pay 앱이나 잔액을 표시하면 좋을듯합니다
# 371                                                 넘 좋아요
# 372                                   캐시백 모으는 재미가 쏠쏠하네요♡♡
# 373                                           좋아요🤗 동백전 짱.
# 374     개꿀입니다 대신 여기가 사용가능한곳(결제는 웬만한곳에서 가능하나 캐쉬백이 되는곳) ...
# 375                                    사용하기 아주 편리하게 잘만들었음
# 376                                     좋은데 에러가 너무 많이 뜹니다
# 377                                                   좋아요
# 378     도대체 고객센터는 왜있는겁니까? 2/19에 1:1문의 했는데 9일이 지났는데도 보지...
# 379               너무 좋아요~~^^그리고3월달까지 이벤 연장도 해주셔서 감사합니다~^^
# 380                                  캐쉬백 이만큼 되는 카드는 동백전 뿐
# 381                                          바로 캐쉬백되니 좋아요
# 382     충전금액 환불이 자유로울거라 생각하고 카드발급, 어플설치를 하고 충전을 했었는데 급...
# 383                                                굿요~~~~
# 384                                                   좋아요
# 385                                     부산에선 동백전 좋아요~~~^^
# 386                                     온라인은 사용이 안되서 아쉬워요
# 387     10% 캐시백이 2월까지라서 약간 아쉬웠는데 3월까지 연장이라 좋아용ㅎ 꿀이 떨어지...
# 388     동백전 사용시 와이파이가터지는 곳에서도 모바일 데이터를 켜지 않으면 사용이 안되는데...
# 389                                               캐쉬백넘좋아요
# 390                                                  Good
# 391                                               사용하기 쉬움
# 392     덕분에 잘 사용하고 있습니다 업데이트 되면서 충전하기가 더 어렵게 되었네요 이전처럼...
# 393                                               좋아요^^~♡
# 394          편하게 잘쓰고있는데 3월도 10% 캐시백해준다니 넘 좋아요~10% 1년 가즈아~
# 395                                                     굳
# 396                                                 맘에들어요
# 397                                                    좋음
# 398                                                   좋아요
# 399                              충전금액이 얼마나 남았는지 알려주면 좋겠어요
# 400                                           진짜진짜진짜루 좋아영
# 401                                                    없음
# 402                                                앱너무좋아요
# 403                                                  완전좋음
# 404                                    너무좋아요 보너스 받는 느낌입니다
# 405                                                 정말좋네요
# 406                         잘 사용하고 있어요. 10프로 적립~ 오~ 유익해요.
# 407                                                완전굿입니다
# 408                                                대박좋아야ㅡ
# 409                                                     굿
# 410                        너무 잘쓰고 있어요 ㅎㅎ 사용방법이 간단해서 좋네요^^
# 411                                                   편리함
# 412                                                     굿
# 413                                아주 유용합니다. 포인트가 금방 쌓여요.
# 414                                            잘사용하고있습니다.
# 415                                                   좋아요
# 416     어플도 보기 편하고 실시간 캐쉬백 확인되니 너무 잘 쓰고있어요.. (가맹점 찾기 힘...
# 417     카드신청 일주일이 지나도 오지않음 배송업체는 전화도 받지않음 언제 오려나? 차라리 ...
# 418                    최고입니다. 학령기 자녀를 둔 주부에게는 선물같은 카드이네요.
# 419               혜택업소가 좀더 많았으면 해요. 10프로혜택 너무좋아요. 다같이 윈윈!
# 420                                                     굿
# 421         코로나 여파로 사용실적이 적은데 3.4월까지 10% 혜택을 연장 해주면 좋겠습니다
# 422                                                쓸만합니ㅣ다
# 423                                                  Good
# 424                                            사용하기 편리해요.
# 425                                            동백전 너무 좋아요
# 426                                                 아주좋아요
# 427                                            좋아요 부산 화이팅
# 428                                                   갠차늠
# 429                             지역경제도 살리고 우리집에도 도움되는 최고 앱
# 430                                                   좋아요
# 431                                  너무 편하고 좋습니다 혜택도 많고~~
# 432                                             업데이트가 안되요
# 433                                          10프로충전너무좋아요.
# 434                                       오거돈 시장님 감사합니다 ㅎ
# 435                                                감사합니다~
# 436                                                좋고 편해요
# 437                                                    좋음
# 438                                       택시가 연동이안되 아쉽네요~
# 439                                                    굳굳
# 440                                         아직은 완벽한 어플아닌듯
# 441                                                    감사
# 442                                                 너무좋아요
# 443                                                   좋네요
# 444                                                  긋입니다
# 445                                          쏙쏙 되돌아 오는 재미
# 446                                                   좋아요
# 447     아니 충전하려 들어가면 계속 튕기고 지우고 깔아도 튕기는데 이러면 그냥 쓰지말라는 ...
# 448                                               무조건 조아여
# 449                                                   좋아요
# 450                                          너무좋습니다ㅅㅅㅅㅅㅅㅅ
# 451                                                    개꿀
# 452                                                     굿
# 453                       아직 동백전을 모르는사람이많은듯 더욱더 홍보가 필요합니다
# 454     잘쓰고있습니다~ 한가지 요청드리고 싶은건 월별 또는 일정기간별 사용금액을 조회했을때...
# 455                                                   개꿀~
# 456                                        포인트적립 정말 최곱니다ㅋ
# 457                                               알림이 빨라요
# 458                                      계속 통신중 오류 뜨는건 뭐여
# 459                                                업데이트안됨
# 460     회원가입조차 되질않아요. 문자인증전까지 입력은 되는데 인증문자가 전혀 오질않네요 S...
# 461                             10프로 할인이 연장되어 기분이 좋아서 리뷰씀
# 462                                        아주 유용하게 쓸것 같네요
# 463                                         업데이트가 너무 안되네요
# 464                                          말이 필요없음. 최고.
# 465     충전 환불 제도도 불편하고 상담원 연결 너무 안됩니다. 그리고 쓸 금액만 충전해서 ...
# 466                                           가맹점도 많고 좋아요
# 467                                                   좋아요
# 468                                               조금번잡스러움
# 469                                                   좋아요
# 470                                            다들 좋은거 인정?
# 471          대형마트 사용만 가능하면 우리나라 최고의 카드혜택이라 믿어 의심치 않습니다~^^
# 472             어떤 vvip 신용카드가 10% 할인을 해주겠나요. 이보다 좋을 순 없어요
# 473                         충전 할려니까 옳바르지 않는 계좌라고 하면서 안되네요
# 474                                   왜 자꾸 다운로드대기중인가요..ㅜㅜ
# 475                                         계속 오류가 떠요..ㅜㅜ
# 476             앱에 접속안되는 날이 왜이리많아요? 접속할때마다 30~40%는 접속불가;;
# 477                                      업데이트 왜이리 안돼요????
# 478     동백전 사용하기 좋아요! 그렇지만, 안드로이드 버전이 낮아 동백전 어플 자체가 아예...
# 479                                                너무 조아요
# 480                                      포인트많이 쌓여서 좋아요...
# 481     본인인증 단계에서 휴대폰 인증번호 발송이 안되고, 카드번호로 인증하려고 해도 번호오...
# 482                       기간 설정해서 사용내역을 볼 때 합계도 나왔으면 좋겠어요
# 483                                  업데이트3일동안 안되고 앱실행이안되여
# 484                                      하루종일 앱이 실행이 안되요~
# 485     가입하려고 폰인증번호 전송누르면 예기치못한문제발생 했다고 진행이 안됩니다 수십번을 ...
# 486     팝업창 아랫부분 닫기인지 다시보지않기 인지 선택하는 창이 화면에 잘려서 누를수가 없...
# 487     간단 명료하게 잘 꾸며져 있슴다! 적절히 사용하여 부산 경제에 도움이 되도록 주위 ...
# 488     가맹점 확인할때 카테고리가 나눠져있긴 하지만, 그 속에서 가게 이름을 일일이 다 보...
# 489                                         지금 설치가 안되요 ㅠㅠ
# 490     잘쓰고 있습니다. 충전을 해야하는데 업데이트를 요구하는데 설치는 계속 대기중이네요....
# 491                            동백전 잔액이랑 캐시백 바로 업데이트되니 좋아요
# 492     카드가 도착했다해서 우편함에 놔둬달라했는데 집에 갔는데 없더라구요ㅠㅜ 그래서 재발급...
# 493                                                 안열리네요
# 494     어플이 와이파이! 연결될때만! 실행 됩니다 데이터를 켜면 " 네트워크 상태가 원활하...
# 495     동백전카드 가입에서 비밀번호 실패하고 나서는 접속하기가 힘들어요~~~ 충전시킬려고 ...
# 496     가입이 안됩니다!!인증이 안되요~ㅎㅎ발급 받아보려고 어플깔고 휴대폰 인증하는거 아무...
# 497     이음카드에 비하면 너무 기능도 없고 카드 1개 밖에 신청도 안되고 부족한점이 너무 많아요
# 498     2g폰 사용하고 있는데 동백전 발급받을 수 있는 방법은 없나요? 예를들면 아이패드나...
# 499     동백전은 좋은데 어플이 왜이래요? 결제가 두번 된거 같아 확인하려고 하니 네트워크 ...
# 500     계좌도 다 안맞다그러고 신분증 발급일자도 틀리다고그러고... 그냥 발급이 이제 안되...
# 501     잘 사용하고 있습니다. 아쉬운건 잔액정보인데, 1.사용 전 금액 상품권 100원 캐...
# 502     동백전은 너무좋은데 간혹오류로 결제가안될때가있고 어플들어가는거도 팅길때가있어요 유용...
# 503     폰마다 차이가있는지 제폰에서는 와이파이 아니면 앱에 접속이 거의 안됩니다(A5). ...
# 504     전산오류로 결제가 두번 됐는데 충전한 돈으로 결제한 첫번째 결제를 취소시키고 두번째...
# 505                                                 아직 모름
# 506                                  인증번호가 안오는데 어떻게 해야될까요
# 507                              데이터 인식을 못하나봐요 깔아도 쓸수가없네요
# 508                                                   좋아요
# 509                    열때마다 다시 종료해야되네요.. 어플 제대로 좀 만드세요...
# 510     카드발급해서 사용중인데, 계속 카드등록발급하라고 어플에 뜨네요.카드등록 할수있게 해주세요
# 511                          앱이 자주 버벅 거립니다 터치도 안되고 먹통이 되요
# 512     최고에요. 계속되는 10% 적립혜택도 좋고, UI도 신경써서 만든 것 같아요. 편리...
# 513                                                   좋아요
# 514                             돈만빠져나가고 충전이안됨 아직은 많이 부족한듯
# 515                                               열리지가않아요
# 516     네트워크가 원활하지 않아 안된다고 뜨네요. 그런데 옆에 남편은 확인이 잘되는데 뭐가...
# 517                   결제도 안되고 잔액확인도안됩니다 계속 오류뜨는데 왜이런건가요??
# 518     급하게 충전 해야 할 때 안 됩니다.... 어플도 통신사도 케이티라 뭐가 쓰레긴지는...
# 519     네트워크 오류라면서 어플 접속이 안될뿐더러 오늘 실 결제한 금액 캐시백도 안됐네요....
# 520                                   인터넷 접속이 안될때가 더 많습니다
# 521                                    뭐가자꾸 접속이안된대 짜증나게ㅡㅡ
# 522     어플에 접속이 안되는데 어떻게 쓰라는거에요?? 아이폰에서 안드로이드로 넘어왓는데 아...
# 523                            명불허전 공무원 작품.. 접속장애 엄청 심합니다
# 524     혜택은 좋은데, 어플 동작이 너무 느림. 이 가게가 해당되는지 확인하려고 어플켜다가...
# 525     신청을해서 등록하려는데 자꾸 통신상연결이안된다하고 네트워크문제라고뜨네요 다른인터넷어...
# 526     제 폰이 이상한건 가요ㅜ 데이터로는 동백전이 안들어가지고 돈 충전도 안됩니다 길에서...
# 527                                 오늘 결제도 안되고 어플실행도 안되요.
# 528                                       어휴 어플관리 진짜 최악이다
# 529     진짜 넘하시네요! 아니 뭐 접속도 안되고 맨날천날 통신이 불안하다고 하면 시에서 일...
# 530     어플이 연결이되야지 충전을할껀데 어제도오후내내 안되서 결국딴카드사용햇네요 네트워크오...
# 531                      연결이잘안되요..네트워크 상태....라면서뜨지를않아요...
# 532              가맹점 검색할때 현재 위치가 아닌 처음 접속했던 위치로 계속 검색되는듯요
# 533     잘 사용하고 있습니다. 월별 이용금액(합계) 좀 보이게 개선해주세요. 사용금액 합계...
# 534     설치하고 카드 신청하는데 폰으로 인증번호 확인차 문자앱 실행해서 보고 다시 동백전앱...
# 535     접속이 잘되다가 갑자기 안되네여 다른분들말처럼 데이터 와이파이 구분없이 네트워크 장...
# 536                                                   좋아요
# 537     마이너스 없어서 별 1개만 줌 카드신청하고 일주일 만에 받았는데 어플에서 충전이 안...
# 538     어플 접속이 자꾸 튕겨요 캐쉬백도 제대로 들어오지않고 부족하게 들어오고 고객센터 전...
# 539     다른어플은 실행이되는데 이어플은 lte인데도 왜 실행이 안되고 와이파이껴야 그나마 ...
# 540     문의글남겨도답변도안하고점심이라고일안하고가맹점이라고버젓이되잇는데사장은동백전가입안되잇다...
# 541                                                넘좋아요~♡
# 542     앱을 실행할 때마다 아래와 같이 계속 에러가 뜨면서 초기화 되요 ㅠㅠ -------...
# 543     카드신청시 일정시간미사용으로 거래불가가 계속 뜨는데 제거후 다시 설치해도 그렇네요 ...
# 544     잘 사용 하고 있습니다. 근데. 가맹점에 포함 돼 있는 곳인데 앱에는 검색이 안되네...
# 545     제안을 하고자 합니다. 어린이들도 동백전 사용자로 참여하도록 하면 어떨까요? 인천의...
# 546     와이파이에서만 접속이 됩니다. 거의 일주일 이런 상탠데 오류 언제 잡아주실지..??...
# 547                                                서버 좀ㅡㅡ
# 548     동백전 어플이 와이파이 일 때는 잘 되지만 와이파이가 아닌 상태에서는 오류가 떠서 ...
# 549                             진짜 다 좋은데 카카오뱅크 계좌등록되게해주세요
# 550       앱 실행하니 통신 중 예기치않는 오류가 발생했다면서 실행이 안 됩니다. 왜 이런거죠?
# 551                                       괞찬아서 주변에 강추합니다.
# 552             자기명의휴대폰아니면 가입이 안되는거 같은데 아이핀으로 가입할수있게 해주세요
# 553                       어플에서 바로 qr코드같은걸로 결제기능이 있으면 좋겠네요
# 554                                        그냥 무조건 사용해야합니다
# 555     원래 와이파이있어야만 접속가능한건가요? 데이터로는 접속이안되고 꼭 와이파이가있어야만...
# 556     뭐 켜져야 잔액을 확인하고 사용하는 곳 확인해서 쓰지 와이파이연결하니까 데이터만 된...
# 557             데이터확인하라고 연결이안되요. 다른 앱은 실행되는데 1시간째 안되니 화나요
# 558                      아니 충전할려고 앱켰더니 실행이 안되면 어쩌라고요 짜증나네
# 559              어플이 왜이러죠? 데이터상태에서 사용이 안되면 밖에선 사용하지말란건가요?
# 560     일단 어플이 너무 느려요ㅠㅠ 또 실행할때 네트워크가 불안정하다고 안열리네요.. 가맹...
# 561                                        캐시백이 많아 너무 좋네요
# 562                    제발 서버 확장 좀 하세요 앱에 한번 들어가려면 하루종일 걸림
# 563                              앱 접속이 안되요 확인해주세요 계속 오류나요
# 564                                           어플이 실행이 잘안됨
# 565          앱이 잘 열리지도 닫히지도 않아요 일단 카드신청만 겨우하고 강제 종료했네요 ㅡㅡ
# 566     Ios 안드로이드 버전 낮으니까 아예 플레이스토어에 없네요 ...다른 카드나 은행앱...
# 567                      동백전 가맹점 위치 알수 있는 어플 있으면 더 좋겠네요..
# 568     일정시간 미사용으로 작업이 중단되었습니다 카드 신청을 할려니 위처럼 나오며 안되네요...
# 569     갤s8 브라우저ㅡ 크롬으로 설정해야된다고 진작좀 알려주지 어제 전화문의는 그런거 안...
# 570     아니 앱 설치해서 들어가니깐 이앱을 삭제하시겠습니까 뜨고 예하면 진짜 삭제되고 아니...
# 571     네트워크도 잘안되는걸 어떻게 써라고? 써다가 열불나서 카드부쉈음. 일부러 이렇게 만...
# 572     이용내역 조회시 이용기간에 따른 합계액이 표기되면 좋겠습니다. (30일치 결제내역조...
# 573     본인확인 방법을 추가해 주세요!! 법인사용자의 경우 본인명의의 폰이 아니라며 어플 ...
# 574     설치 후 켤때마다 초기화,재인증하라고 하죠? 등록된 정보와 핸드폰 번호가 다르다는 ...
# 575                                          저한테는 너무 좋습니다
# 576     별 1개도 아깝습니다 결제가 제대로안돼서 어플실행시키는데 들어가져야지 확인을하지ㅡㅡ...
# 577                                     어플이 실행되야 쓰던가 하죠..
# 578           동백전 가입할라는데 인증번호가 안와요 3번 시간초과됫는데도 안와요 왜안오는거죠
# 579                                        아 진짜 불편하네요.. .
# 580     가입은 하고 되는가 볼려고 100.000 원 충전 했는데요 카드를 만들수가 없네요~...
# 581     카드뱌아서 충전하고 사용하는대 어플에는 사용됬다고 금액뜨는대 가게에서는 사용중지되있...
# 582     어플화면에서는 결제완료창이랑 캐쉬백 내역이 뜨는데 가맹점에서 실결제가 되지는 않는 ...
# 583                                                접속이 안됨
# 584                                            앱 실행이 안됩니다
# 585     앱연결하기 하늘의별따기임ㅡ얼마썼는지 확인을할수가없음ㅡ앱이 실행이돼야 뭘하지 ㅡㅡㅡㅡ...
# 586                          오류 투성이. 접속 됐다 안됐다 네트워크도 불안정함
# 587                                 급하게 만든거 엄청티나네 안정성 엉망임
# 588     카드가 오류가 떠서 결제가 취소됐는데 캐쉬백은 들어왔고 어플은 켜지지도 않고. 어플...
# 589     이거 확인안되는데 왜이렇죠? 결제안된다고하는데 어플에는 결제한거처럼 나오고 진짜 왜...
# 590      안들어가지는게 너무심하네요. 이래서 사용가능하겠어요? 데이터 와이파이 다 안들어가져요.
# 591     다운로드만 되고 아이콘누르면 동백전로고만 내내떠있고 아무것도 안되는데요.. 와이파이...
# 592                동백전은 좋은데 앱이 말썽이네요 충전할때마다 짜증이 나요 앱이 쓰레기
# 593                                               굿~~~~~!
# 594                         오늘 하루종일 먹통에 2중 결재 됐습니다 확인해주세요
# 595                                  카뱅이 없어서 아쉽긴 하지만 좋아요♡
# 596     어플이 켜져야 잔액 확인을 할텐데 어플이 켜질 생각을 안하네요 리뷰 보니까 다른분들...
# 597       잘사용하고있습니다. 3월 30일 오후 8부터 앱 자체가 켜지지 않습니다.이유가 뭔가요
# 598                             부산사람이라면 강추. 이벤트10프로 평소6프로
# 599                      카드를 받고 앱을 실행할려니 안되네요. 이렇게 허접하다니?
# 600                              켜져야 뭘하지 공공기관에서 만드는 어플 답다
# 601     결제 알림문자를 받음과 동시 입금 알림문자가 울립니다.코로나 같은 지금 시기에 경제...
# 602     출시 되자마자 사용해서 몇달짼데 처음보다는 세분화된 충전 단위도 편리하구요 너무 잘...
# 603     와 앱 실행 너무 안되요 너무너무너무 너어어어무!!!!!! LTE로 해도 안되고 와...
# 604           머 접속이되야하지ㅡ....우짜라는건지 안되요 아예 로딩도안되고 따운됨 ...하
# 605     왜 제일은행계좌연결이없나요 그리고 카드는왔는데 잔액충전을못하고있어요 어플이 오류라고...
# 606     잘 쓰다가 3월 30일 갑자기 카드가 잘 안되더니 어플도 안되네요 ㅠㅠ 혜택이 마음...
# 607                              앱이 화면이 멈춰있어요 접속이 안되는거같아요
# 608     돈 충전하고 카페에서 사용했는데 직원분이 은행에 문제가 있는거같다고 안된다해서 디른...
# 609     지금 앱이 첫화면에서 넘어가지를 않네요 폰을 다시 켜보아도 마찬가지고 앱제거하고 다...
# 610     서버터져서 안써지는게 태반입니다. 심지어 결제처리도 안되었는데 앱 들어오니 결제된것...
# 611            정보 수집 동의후 동백전카드 이미지모양에서 어플실행이 멈추는데 이건 모에요?
# 612                                                 안들어가짐
# 613     동백전이 어플없이 사용가능하다면 모르겠지만, 필수적으로 어플이 필요한 서비스인데 이...
# 614                    앱이 안열림 ㅡ.ㅡ뭐하자는거임? 사용자 증가로 오류? 골때리네
# 615     앱 알림은 결제가 되었다고 뜨는데 업체에서는 결제가 안되었다고 해서 다른 카드로 결...
# 616     오늘 결제가 된걸로 처리되는디 편의점은 안됐다고하고 충전금액만 차금되네요 ㅠ kt서...
# 617                                        실행이안됩니다 개선해주세요
# 618     짜증나요 매장에서는 결제안됐다 그러고 저는 결제됐다고 알람 떴는데 결제하려고 어플드...
# 619     오류가 잘나는데 조금전 결재하는데 동백전카드는 금액지불되는데 결재안뜬다고.현금내었는...
# 620        너무 어이 없네요 사용할수 없어요 카드로 결재도 안되고 앱도 다운되어 먹통이 됐어요
# 621     아니 결제를 했는데 제 핸드폰에서는 결제가 됐다고 알림이 왔는데 정작 결제한곳에서는...
# 622     또 앱 실행이 안 돼요 몇번짼지 모르겠네요 언제 개선되나요?? 오늘 동백전앱 오류때...
# 623                     어플개떡같이 만들어서 켜지지도않고 계속 로딩이고 가끔씩만켜짐
# 624     주유하다가 결제 오류로 다시 결제 했는데 중복으로 결제 되서 취소 했는데도 돈이 안...
# 625     카드를 만드려다가 민증 발급일자 오류를 5번 초과해서 만들 수가 없습니다. 운전면허...
# 626                                          제발 본인확인 추가좀요
# 627      써야돠는데 왜안되냐고요...자주이라네요정말... 오늘쓸려고있었는데 안되면혜택도안되고뭐죠
# 628     교통카드 없는 카드 개설했다가 있는걸로 바꿀려고 하나카드 통해서 카드해지를 했습니다...
# 629                           인증번호가 안와서 신청못하고 있어요. 어케하나요.
# 630     결제가 먹통입니다 어플 접속도 안 되구요 다름 카드를 들고있었기에 망정이지 동백전만...
# 631              네트워크장애로 안되는경우가 잦네요. 다른뱅킹은 아무런 문제가 없는데...
# 632     동백전이라는 카드혜택은 좋지만 어플만 보면 너무 불편하네요 데이터로 접속하려면 네트...
# 633                                                     굿
# 634     집에서 와이파이 연결된경우에만 충전이나 어플확인이 가능합니다.. 어플연결이 안되다보...
# 635                느린속도데이터쓰는사람은 와이파이안잡으면아예안됨 밖에서 사용할수가없어요
# 636                                 회원할려는대 인증번호가 안오네요....
# 637     아인증번호 입력하려 나갔다오면 자꾸 앱강종돼서 처음으로돌아가요; 인증을 할수가없잖아...
# 638                               좋습니다 포인트도 바로사용가능해서 유용해요
# 639     어플 실행도 오래걸리고 가맹점 검색이 불편합니다. 지도 외에 지역별로 볼수 있는 방...
# 640                                   왜 댓글에 답장안해주냐? 무시하냐?
# 641        동백전 사용중에 알뜰폰통신사 이동했더니 켤때마다 계속 초기화 불러오는 오류가 있네요
# 642                        결제 실패는 곧 시스템 실패 ,kt 하나은행 똑바하세요
# 643                                                   좋아요
# 644     앱 실행 진짜 안됨 뭐 이런게 다있나 싶다. 캐시백 주니마니 생색이나 내지 말고 실...
# 645     너무 자주 에러나요. 미리 공지라도 하고 안돼야 당황을 덜하죠. 오늘도 일부러 동백...
# 646                   가맹점 왜 안뜨나요? 가맹점을 봐야 쓰든가하지 빨리좀 고쳐주세요
# 647     아니 어플에서는 사용가능하다해서 갔는데 사장님은 사용못한다면서 자기는 들은거 없다고...
# 648     잘쓰고있었는데 어플실행이 안되네요 다시 설치해도 마찬가지이고.. 쓰지말라고 만든건 ...
# 649                                            접속이 안되네요ㅜㅜ
# 650                  지금 가맹점찾기 저만 안되는 건가요?? 앱에 오류가 너무 많아요ㅠ
# 651                                       중소기업 수준도 안되는 어플
# 652                                 사용처도 확인안되는데 무슨, 불편하네요
# 653     가맹점찾기에 가맹점 자체가 아예 안나옵니다. 처음부터 안된게 아니고 어제부터 안나오...
# 654     아니 무슨 카드 발급 안해도 쓸수있나 싶어서 결제했는데 안돼는거 확인하고 환불하려 ...
# 655                                가맹점찾기에서 가맹점이 하나도 안보여요.
# 656     갑자기 가맹점 검색이 안되네요. 어떤날은 갑자기 결제 오류나고 이렇게 불안정해서 어...
# 657     동백전 앱에 들어가면 가맹점 찾기가 원래는 나오는데 어제 부터 위치를 잡아도 안나오...
# 658                어제 결제가 안되서 곤란한 경험을 했습니다. 결국 다른 카드로 했죠.
# 659             아니 부산에서 쓰라고 만든 카드 맞습니까 안되는곳이 왜 이렇게나 많은지 참
# 660     다른건 다 괜찮은데 가맹점 찾기에 가게가 하나도 안나와요ㅠㅠㅠ 몇번이나 재설치했는데...
# 661                       잘안될때가 많고 환불도 제약있고 그냥 안쓸랍니다 카뱅만세
# 662                              앱 개발자 바꿔라 제발!!! 부탁합니다!!!
# 663     나머지는 다되는데 왜 가맹점 조회가 안되는지요?? 가맹점 이게 찾아보고 가야되는데 ...
# 664                                          부산사람 만큼은 최고♡
# 665                                 결제내역을 문자로도 보내주면 좋겠네요.
# 666     어플켤때마다 초기화가 뜹니다..새로 휴대폰인증완료 후 재시작하면 또 뜨고.. 어플 ...
# 667                               매우 훌륭한 시스템을 갖추었다고 생각합니다
# 668                                                너무 좋아요
# 669     가압이 완료 된것 같은데 가드신청 을 햇는데 언제 돼나요 ... 충전도 좀금 해놧습...
# 670                  고객센터는 일하는사람있나요? 전화도안받고 1:1문의글 읽지도 않음
# 671                            예금이자 생각해보면 현명한 소비가 돈을 버는거임
# 672     잘 쓰고 있습니다 부산시청 열일해주셔서 감사합니다 10퍼센트 캐시백 넘 좋아요 4월...
# 673                                  로그인이 안 될 때가 너무 많습니다.
# 674     혜택은 좋으나 사용하기 불편한 부분이 있습니다 이용내역에 월간 결제 또는 적립내용이...
# 675                                         꼭 몇번 클릭해야 연결됨
# 676                                 빠르고 실용적인 면이 너무 좋습니다!!
# 677     로그인 잘 안되고 가맹점 찾기도 힘들고 별 하나 주기도 아깝네요. 그리고 충전식 카...
# 678                  오!!좋네요ㅎㅎ 근데갑자기 100만원에서70 만원으로?아쉬워라~~
# 679     kt앱이었네요 kt폰이 아니면 사용불가인 모양이네요 계좌등록 진행중에 인증완료를 누...
# 680                                  필요할때 앱이 작동을 안하네요,,,,
# 681             자꾸안괴요 충전해서 결제 해야 하는데 카드 달랑 한개 들고 나왓는데ㅠㅠㅠㅠ
# 682                           머고 네트워크이상하다고 안열린다 젠장 불편해죽겠네
# 683                                앱 접속이 왜 안되는거예요? 아 놔 진짜
# 684                        아니 왜 접속이 이렇게 안됩니까 사용을 할 수가 없네요
# 685                                    주말만 되면 접속이 안됨...ㅠㅠ
# 686                                  아니 동백전 앱도 안열리고 왜이럼이거
# 687     앱이 안열립니다. 왜이럽니까 진짜 확인 할게 있는데 시골이라 와이파이로. 접속 할수...
# 688     아니 데이터 무제한인데 네트워크 연결하라하고만 하고 왜 계속 접속이안되나요? 돈얼마...
# 689                                          웹에 접속이 안되네요?
# 690                                        앱에 접속이 너무 안됩니다
# 691     데이터 연결이 불안정하다더니 다른 어플들 접속은 잘만 됩니다. 어플 재설치도 하고 ...
# 692                                 머고 앱실행도안되고 장난하냐???!!!
# 693                              접속이 잘안되네요. 업데이트좀 부탁드립니다.
# 694                                             접속불가 충전불가
# 695                                          왜 로그인이 안되나요?
# 696                                쓰레기입니다 이딴게 세금으로 만들어지네요
# 697                     걍 먹통임 앱실행이 안됨 돈좀들여서 실력있는 개발자좀 씁시다
# 698     접속이 안되네요 빨리 계산해야되는데 앱이 접속이 안되서 주위사람들 눈치밥 먹으면서 ...
# 699                           ㄹㅇ 데이터 켜도 로그인 안되는 희대의 쓰레기 앱
# 700     충전금액 확인하고 쓰려고 했더니 어플은 켜지지도 않고 장난치는 것도 아니고 계좌결제...
# 701             앱이 와이파이든 데이터든 아무것도 연결이 안되네요. 안정성 좀 신경써주세요
# 702                    네트워크 오류라고 실행자체가 잘 안되네요 왜 2점인지 알겠네요
# 703                  아니 왜 잘 되던게 갑자기 네트워크 뭐라하면사 안들어가지냐 ㅠㅠㅠ
# 704         이거 왜 안들어가지나요? 계속튕기기만하네요...이러다 무용지물이 되는건아닌지...
# 705                                머하는거야 일부러 안되겠했냐 왜이래 자꾸
# 706                                    로그인 안되네요 사용하기 짜증나네
# 707                                         개느리고 접속 안됩니다.
# 708     2월에 발급 받아 쭉 사용 중이에요. 10프로 캐시백이 어마어마 하네요. 동백전 덕...
# 709                   왜 갑자기 접속이 안되나요??? 충전을 못해서 캐쉬백 못받았어요
# 710                                      접속이안돼요 충전은어찌해야하나
# 711     아니 와이파이 네 칸 풀로뜨고 유튜브 등등 빠르게 잘되는데 왜 이 앱만들어거면 네트...
# 712     네트워크 개선좀 빨리해주세요, 일주일째 데이터로도 접속이안되고 와이파이 연결된상태에...
# 713     엉망진창입니다. 사용하려고 만든어플이 어떻게 결제하려할때마다 앱이 오류가 빈번하게 ...
# 714     잘쓰고 있는데, 오늘 앱이 안열리네요~ 네트워크 상태가 원활하지 않습니다. 로 계속...
# 715                                                 접속도안됨
# 716                                            안정성이 최악이네요
# 717     한 번씩 앱이 먹통입니다.. 쓰고 싶어도 못쓰게 하는 앱이네요.. 충전금액 확인하고...
# 718     취지도좋고 캐시백도 큰점 좋습니다 아쉬운점이 있네요 1. 충전된 금액이 아닌 계좌연...
# 719                                          접속에러 언제 고치나요
# 720                                  접속 겁나 안됨..ㅡㅡ 뭐하는건지 ㅋ
# 721     좀 어플좀 들어가봅시다. 뭐좀 할라하믄 네트워크 상태가 안좋다하고. 충전도 못하고 ...
# 722                                       요즘세상에 들어가지지도 않네
# 723                                       와파든 데이터든 안들어가져요
# 724                                앱관리 안하냐 ? 네트워크 접속불량 머냐
# 725     리뷰는 스마트폰 쓰면서 처음 남겨봅니다. 10만원 충전해 놓고 사용하려고 보니 네트...
# 726                                     아니 츙전한 뒤로 안켜져요 ㅡㅡ
# 727                                          지금 사용이 안되네요.
# 728     동백전 카드는 잘사용하고 있는데요 앱은 왜 이따위로 만들었나요? 와이파이에서만 접속...
# 729     하... 식당에서 밥 먹고 나가기전에 돈 충전해서 결제하려고 어플을 켰는데 접속이 ...
# 730     발급 한 달도 지나지 않았는데 1. 시스템 장애로 결제 불가에 2. 앱 오류로 충전...
# 731                         아니 접속이 자꾸 안되는데 어째된거죠 짜증나네요 이젠
# 732     평점이 왜 2점대일까 했는데 오류 진짜 많이나고 쓰레기 같아요 충전 해야되는데 어차...
# 733                                           왜 또 안되냐. 에휴
# 734                               앱이 열리지가 않는데 어떻게 충전합니까??
# 735                                        통신오류가 너무 잦아요ㅡㅡ
# 736          로그인이 왜안되나요? 이리 안들어가지는 어플도 첨봅니다..빠른 수정 부탁드립니다
# 737     동일한 후기가 많습니다만 왜 자꾸 네트워크 연결안된다고 하나요?? 불편해서 못 쓰겠...
# 738            앱 접속 좀 하자. 지금 몇일째 접속이 안되는건지. 관리할 마음은 있는건지.
# 739                                  어플이 계속안열리네요 정말 노답이네요
# 740     앱자체가 안켜지네요 부모님꺼 계좌연결도 20분째 인증도못하고있어요 인터넷폰뱅킹안하시...
# 741      캐시백되는건 좋은데 앱이 몇번째 안들어가지는건지... 돈이 얼마있는지 확인할수가 없네요
# 742                                              안 열러요 ㅜㅜ
# 743     쓴지 얼마안됐어도 캐쉬백들어오는것도 좋고 맘에 들었는데 짜증나서 못써먹겠네요 무슨앱...
# 744     앱에 잘안들어가져요 벌써 5시간째 들어가지지않고 튕기는데 이게뭔가요? 할인해주셔서 ...
# 745              앱 실행이 안됨;; 와이파이 빵빵한데도 안되고 데이터로도 안됨요.. 불편
# 746     잔액 확인하려고 어플 들어가는데 접속 조차 안되면...카드를 어떻게 사용하라는건가요 대체
# 747     현재 시각 1시간째 먹통이네요ㅡㅡ 식구들이랑 외식하고 동백전으로 계산할려니 앱도 안...
# 748             똥입니다 잘쓰다 안되서 몇번을 다시해도 예기치 못한 오류라고 나오네요 짜증
# 749                         맨날 접속이 안됨 . 관리도 안할거 왜 만들었는지..
# 750     앱이 먹통입니다. 네트워크 연결이 안된다고 뜹니다. 빨리 고쳐주세요. 온 가족 폰의...
# 751                          이게 뭔가요? 계속 열리지도 않고 짜증 너무 나네요
# 752            어플실행시 오류. 오늘카드받아쓸려했더니 바로어플접속 먹통 이래가 뭐하겠나요?
# 753                          어플 진짜 못 만들었네요.. 툭하면 접속도 안 되고
# 754     왜 연결이안돼요-??? 위치켜도 가맹점나오지도않고-아니 도대체 점거안하고 뭐하시는건...
# 755                           접속도안되고 깔고지웠는데도 접속안되요 개선해주세요
# 756                                                 이게머요?
# 757     네트워크 관리 좀 해주세요 뭔 맨날 연결 안 돼서 충전도 못하고 오늘도 캐시백 혜택...
# 758     잘 쓰고있는데... 네트워크 오류가 너무 자주 발생해서 잔액을 제대로 확인할 수 없...
# 759      이거 인증번호가 밀려서 날라오죠? 3분안에 오지도 않아서 가입조차 진행할 수 없습니다.
# 760                            서버연결 진짜 쓰레기같네요 부산시청 실망입니다.
# 761             금액확인 후 사용할려고하니 오류뜨네요;;자주 에러가 나니 사용하기 불편해요
# 762            심심하면 안열리네요 쓰라는건지 쓰지말라는건지 뭐 열려야 확인도하고 충전도하죠
# 763                                캐시백은좋은데 앱사용오류가너무심해요 ㅜㅜ
# 764     이전엔 접속 되었는덕 오늘새벽에 뭐 서버넓힌다고 충전안되더니 지금은 어플이 켜지지않...
# 765                           몇번을시도해도잘되지가않네요 언제쯤 제대로 될까요?
# 766                와~~충전할려고 하는데 들어가지지가 않네요!! 앱이 왜 이때위인가요?
# 767                       이거 진짜 뭔 앱이 연결도 안되고 오류나고 *레기인지..
# 768     앱이 열려야 충전해서 사용을 하죠 안열리는 경우가 너무 많아요 네트워크가 원활하지않...
# 769         앱 실행 단계에서부터 막힙니다. 만들기만 하지 말고 관리도 좀 잘해주길 바랍니다.
# 770                      앱이 열리지가 않아요 잔액이 얼마남았는지 확인할수가 없네여
# 771     5G, Lte, Wifi 전부 데이터 연결 상태가 안좋다고 실행이 안됩니다. 실행이...
# 772     접속이 되야 충전을 하든 뭘하지... 제발 접속 좀 하게 해주세요! LTE wifi...
# 773                  이런 결제서비스가 접속이 안된다니..어처구니 없는 부산시와KT구나
# 774                                     어플 잘 되다가 접속이 안되네요
# 775                                        오류가 왤케 자주 난대요?
# 776                                                     굿
# 777                                계속어플접속이안돼요ㅠ왜그런거죠ㅠ;;;;;
# 778     다른앱은 잘되는데 동백전은 도대체 와이파이로도 데이터네트워크로도 네트워크 상태가 고...
# 779                어제부터 네트워크연결이 안된다고 접속이 안돼요.ㅡㅡ 어떻게 해결함요?
# 780     잘쓰고 있었는데, 최근에 번호이동을 한 뒤로(알뜰폰~알뜰폰) 계속 초기화하라고 하고...
# 781     오늘 하루종일 로그인이 안되네요 오류도 자주나고 등록된 가맹점에서도 사용 안되는곳이...
# 782     앱 실행이 ㅡㅡ 안되요 첫결제하고 포인트확인하려는데 종일 안됩니다 머 이런 어플이 ...
# 783     왜 계속 네트워크가 연결이 안된다고 하는지ᆢ와이파이도 무선도 다 해봤어요 고객센터는...
# 784            갑자기 네트워크 오류라고 실행이 안됩니다. 앱을 재설치해도 똑 같이 안됩니다
# 785     요 며칠동안 네트워크 상태가 원활하지 않다면서 접속이 안되는 이유를 모르겠네요. 충...
# 786                                            오류가 너무 잘떠요
# 787                                가맹점도 많고, 적립이 바로바로~참 좋죵
# 788                  노트 4에서도 되나요 부산은행서 호환이 안된다는데 이해가 안되서요
# 789                                                굿 좋아요.
# 790                                                   좋아요
# 791                                                   좋아요
# 792              앱이종종다운이되어서열리지 않을때가 있어요 벌써 2번 삭제후 다시 깔았어요
# 793                                                좋아요:))
# 794                                     ㅆ~~~~~~오~~~~~굳!!!
# 795                                                 할인 좋아
# 796                                 간편하게 유용하게 잘 활용할 수 있어요
# 797                                                   편리함
# 798                                               너무너무좋아요
# 799                                                   조아요
# 800                                                  좋아 요
# 801          고객센터 1:1문의는 아예 관리를 안하는것 같아요 읽지도않고 처리도 않해주시네요
# 802                                                많이 쓰세요
# 803                                                     굿
# 804                                                아주 좋네요
# 805                                    대형마트는 사용이 안돼는게 불편함
# 806       웬만한 식당, 가게 다 되어서 좋아요. 유용합니다. 월별 한도액이 늘어나면 좋겠어요.
# 807     소상공인 찾아서 사용하게되고 적립도 팍팍되고 최고입니다. 부산경제 화이팅! 상품권보...
# 808                                                아주 좋아요
# 809                                                아주 좋아요
# 810                                                  넘좋아요
# 811                                       죽이네요 엄청 적립받고있어요
# 812                  페이백 10프로 최고! 전 만족하며 잘 쓰고 있어요! 넘 좋음ㅋㅋ
# 813                 정말 좋아요 부산 시민이면 동백전카드는 무조건 있어줘야 플랙스죠 ㅎ
# 814                                                  조아조아
# 815     인증번호가안오네요;; 아니무슨 내폰skt고 다맞게했는데 인증번호 전송햇다카믄서 안오...
# 816                                         잘 사용하고 있어요 감사
# 817                               포인트를 바로바로 받을수 있어 넘좋아요^^
# 818     앱을 열때 마다 폰번호와 맞지않다고 나오고 초기화하라고 해서 몇번을 다시 했는지 모...
# 819                                                   좋아요
# 820                                  전산 다운이라고 사용안될때 똑땅해 ㅡ
# 821                                              잘 사용중입니다
# 822                                               아주 좋아요.
# 823                               쓰는 본인에게 이득이 되니 매우 만족합니다
# 824                                                   좋아요
# 825                   TV선전과같이 쓰고나면 웃음이나네요 쭉 10프로로가면 더 조을듯
# 826                                                   좋아요
# ...
# 2596                       앱 진짜 못만들었다 캐시 못쓰게 하려고 잔머리만 굴린듯
# 2597                                        가맹점찾기 만들어주세요.
# 2598                     동백전 지갑 어디갓어???? 있던게 없어짐.... 어이없네
# 2599    예전어플이 훨 쓰기편해서 지금어플이랑 너무비교됨. 별 쓸데없는 메뉴랑 소개글만 많고...
# 2600    적립금이랑 현금이랑 분리해서 보여주세요 현금하고 적립금이랑 구분이 안되서 잔고에 현...
# 2601    불편하네요 기존 앱보다 너무 불편하네요\n금액충전은 메인창에  한눈에 확인하고 충전...
# 2602    가맹점 안내 예전어플에 동백전 되는 가맹점 검색할수 있어서\n편했는데 없어져서 불편...
# 2603    회사 바뀌고 나서 문제가 많네요... 카드결제도 안되고 제한도 많고 고객센터 연락해...
# 2604                                       앱사용이 너무 불편합니다.
# 2605    최소한 기존의 편리한 기능은 따라가야 할거 아니냐? 너희들 대학생들 시켜서 앱 개발...
# 2606    나는 이전 하나카드를 삼성페이에 등록해서 사용하니 불편함을 못느겼는데 신규 사용자는...
# 2607    공지를 제대로못읽었는지 기존꺼못쓰고새로만들어쓰란소린줄알고 멀쩡한기존동백카드 삼성페이...
# 2608    전에 동백전보다 사용하기 너무 불편합니다. 그냥 전과 똑같이 하면 안되나요? 이벤트...
# 2609    이전 어플방식이 훨씬 편한데 캐시 이용법이 더 불편한 곳으로 굳이 업체를 바꾸셨네....
# 2610    기존것보다 쓰기도 불편해 유저들이 불편하다고 해도 수정보완할 생각은 없고 어떻게 이...
# 2611                    진짜 불편하게 바꼈다 불편한게 한두가지가 아니에요!!!!!!
# 2612    왤케 불편하게 바꼈는지.. 그전 동백전도 불편했지만 이건뭐 ㅠ 새건데도 복잡하게 바...
# 2613    불편해요 기존 앱에서는 한도가 얼마 남았고 얼마 더 충전할수 잇는지 명확하게 나와서...
# 2614    도대체 누가 앱을 이렇게 기획했나요… 처음에 알아보기 힘들면 그냥 알아보기 힘든건데...
# 2615    토스.. 앱이 정신없고 편의성도 줄은거 같지만 이것들은 적응이 되지만 토스등록은 왜...
# 2616                                                 별루다.
# 2617    동백전 사용하기 힘듦 동백전 사용가능 가맹점 리스트를 보고싶은데 아무리 찾아도 안보...
# 2618    푸시알림 사용내역 알림받으려규 푸시알림 켰더니 마케팅 알람이랑 같이 오네요… 알림껐...
# 2619    너무 불편해요 알림 설정 아무리 해도 절대 안와요\n\n앱 자체도 보기 불편하고 뱅...
# 2620    나만 불만 있는게 아니었구나~어디서 얼마나 할인받고 있는지 진짜 궁금한데 애먼 광고...
# 2621    결제 시 푸시 알림이 안와요 이전 앱에서는 결제 시 푸시 알림이 왔는데, 코나카드로...
# 2622    혜택 좋아서 잘쓰고있습니다 다만 카드 이용시 앱에서 결제 금액이랑 잔액, 사용처가 ...
# 2623    별 하나도 아까워요 예전 어플이 훨씬 사용하기 편하고 보기도 편해요 쓸데없는 팝업이...
# 2624    사용내역 푸시알림 왠만하면 리뷰 안남기는데 진짜 일대일 문의해도 된다고 하는데 푸시...
# 2625    직관성 최악 환불하기도 한참 찾아야하고\n돈옮기기를 계좌이체마냥 혼동하게 만들어둬서...
# 2626                                         앱이 먹통이네요..에휴
# 2627    어플개발자 짤라야겠는데요? 그사람월급도 시에서 지원받을텐데 세금아깝습니다 이상황 지...
# 2628    가맹점확인 가맹점 찾기 메뉴가 없어진거같은데 가맹점 확인할수있는거좀 만들어주세요ㅠ ...
# 2629                       잘사용할께요 타시도처럼 기부서비스도 있었으면합니다~~~
# 2630    공지사항 좀 그만 띄우세요 아니 무슨 어플들어가면 공지사항 팝업을 3개 4개를 띄웁...
# 2631    가맹점이 어디 있는지 찾을수 없으면 동백전의 유용한 기능을 못 쓰는데 어떻게 하라는...
# 2632    별 하나도 아까움. 삼성페이 등록 가능했던 이전 앱과 카드로 돌려주세요. 너무너무 ...
# 2633    별 하나도 아까워요. 캐시랑 충전한 금액 구분도 어렵고 진짜 지난앱보다 겉만 번드르...
# 2634    왜...? 오랜만에 동백전 쓰려고 다시 깔았는데 카드도 다시 발급받아야되고.. 그건...
# 2635                                   금액이 너무 적어서 불편합니다ㅠㅠ
# 2636    진짜 너무하네 예전보다 사용하기는 겁나어렵고 난 내돈넣고 사용하는데 광고도봐야되고 ...
# 2637    (21.04)전에 kt보다 훨 편하구만, 별점테러는 초기 정착시 설명 부족 때문일 ...
# 2638                                            거지같은 앱 ㅜㅜ
# 2639                                  참으로 불편하다. 일부러 그러는가?
# 2640                 이전 동백전카드에 잔액이 없어졌네요? 케시백된 금액은 사라졌나요?
# 2641                                                    굿
# 2642    지역사업하나 말아먹는 어플이네 어떻게 사업 땄는지 모르겠네요 볼수록 짜증나고 멀쩡한...
# 2643                                        전에 쓰던거 돌려줘요 걍
# 2644    저기.... 문제가 좀 많아야죠 1. 잔액이 카드사용 후에도 변경되지 않음 2. 이...
# 2645    코나 이벤트 참여할려고 선불카드도 발급받고 결제를해도 코나볼을 주지않습니다. 도대체...
# 2646    제발 총 받은 혜택 없에주세요. 총 받은 혜택 하나도 안궁금해요... 총 받은 혜택...
# 2647    다좋은데 가맹점 찾기가 없어졌네요 가맹점보고 충전했는데 없으니 너무 불편함니다 가맹...
# 2648                       연결계좌에 은행은 언제 늘려줄껍니까 돈쓰지 말까요???
# 2649    와 진짜 코나카드? 바뀌고나서 개구려짐 진심이럴꺼면 왜바꾼건지? 전 어플에서는 가맹...
# 2650    동백전 바뀌고 새로 등록한 카드는 직영점 사용가능. 그 전에 만든건 직영점 사용안됨...
# 2651                                               불편하네요.
# 2652    월별 이용금액 합계로 표시 안되나요?? 월별로 30만원까지 적립이되서 이번달에 얼마...
# 2653    이전 동백전사업자는 캐시백을 내 잔고처럼 쓸수있어서 자유로웠는데, 코나로 바뀌고 나...
# 2654    방금까지 사용했는데 갑자기 결제시 오류가 발생한다며 앱 실행이 전혀 안되네요 동백전...
# 2655    깔끔하고 쓰기 편하네요. 다 괜찮은데 캐시백 적립 내역과 캐시백 사용내역만 따로 볼...
# 2656    UI쫌 개선 합시다. 캐시백 때문에 쓰는 사람이 대부분일텐데.. 캐시백이 얼만지 어...
# 2657                                      이런 회사를 왜선정 햏는지?
# 2658    불편합니다 캐시백 금액+보유금액 한번에 조회하게 해주세요\n이전 어플은 가능했어요 ...
# 2659                                             생각보다 편하더
# 2660    알림 돈썻으면 알림좀 울리게해주세요\n토스랑도 연동이 됬으면 좋겠어요\n옛날 하나키...
# 2661                         충전도 안되면서 어떻게 쓰라는거야? 충전오류 미친ㅋ
# 2662    좋은데…. 깔끔하고 좋은데…\n사용하면 바로 알림이 울렸으면…하는 작은 아쉬움이 있...
# 2663        쓰레기어플임 하나도 제대로되는게없음 문제해결안되,상담사 연결안되 어떻해 쓰라는거냐
# 2664                          운영할거면 제대로 하길 이도저도 아닌꼴 만들지말고
# 2665    잘 쓰고있는데 딱 하나만 말씀드리자면 결제 시 부족한 금액 자동충전 기능에서 그 금...
# 2666                        사용 가능 금액과 캐쉬 금액 합산을 표시 해 달라!!
# 2667    어플에 댓글 남겨보는게 얼마만인지도 모르겠네요. 개발자님은 이 어플이 직관적이라고 ...
# 2668    캐시백 세부사용내역 보여주세요. 기본에 기본도 안되어 있는듯요. 누가 도대체 개발하...
# 2669    If you live in Busan(Korea republic of), This ...
# 2670                                                    굿
# 2671                                          구동백전을 돌려달라!
# 2672    아니 어플 좀 옛날처럼 하면 안되나요? 내지갑 이런거 왜하죠? 너무 불편. 그냥 메...
# 2673    업데이트 이후 사용불가 첫 화면으로 가기까지도 너무 오래 걸리고 운 좋게 충전버튼까...
# 2674    아니 저번꺼는 동백전 포인트를 on/off로 간단하게 됬는데 이건 그것도 안되고 심...
# 2675    진짜 앱 거지같음. 기존 동백전은 충전 금액이 자공으로 차감됐는데 이건 뭐 할때마다...
# 2676    전반적으로 저번 업체에 비해 불편함. 특히 캐시백 사용하기가 제일 불편함. 이 어플...
# 2677    지난 잔액과 이번 잔액 비교가 되었으면 좋겠습니다. 최소한 어린애 가계부도 입출내역...
# 2678                                         옛날 카드보다 복잡해요
# 2679                                               잘쓰고있어요
# 2680                            앞전 동백전카드보다 별루 페이결제도 안되고등등
# 2681                                    좀 불편한듯 쓸데없는 창도 많고
# 2682          그전 앱이 더 펹리하고 보기도 좋습니다.지금앱은 너무 불편해요.다시 돌려주세요
# 2683                                                  좋아요
# 2684    나까지 안보태고싶은데 불편..불편 이 앱을 개발한사람이 누군지가 궁금 사용을 해봤는...
# 2685                                                   불편
# 2686                                              너무 좋았어요
# 2687                                                 좋아요.
# 2688                                              도움되는 시책
# 2689    업데이타 하라는데 도무지 되질안네여 종전처럼 편리하게하면 동백전쓰는분들이 편할같네여...
# 2690                           포인트와 충전금액을 이전처럼 따로 금액분리 요함
# 2691                                                  좋아요
# 2692                                                  좋아요
# 2693                                             편리함이 좋아요
# 2694                               수도권꺼보다 불편함 부산이라서 그런가요?
# 2695                                                  좋아요
# 2696    영수증에보니 국민은행 체크카드라고 써있던데...거기에 관해 고지받은바는 없었던것같은데..
# 2697                                           저번보다 완전 불편
# 2698    업데이트 하라고 해놓고 업데이트 되도 안하고 짜증만 나네. 쿠키, 데이터 삭제해도 ...
# 2699                    삼성페이도 안되고.. 이 따위로 만들거면 왜 했냐 진짜 ㅡㅡ
# 2700    너무 불편해졌어요. 많은 분들의 의견과 동일한 내용들이지만, 몇 달이 지났는데도 개...
# 2701                                        계속사용가능토록 해주세요
# 2702    사람들 생각 다 같구나.. 전체적으로 더 복잡한거 같아요 캐쉬백도 바로바로 확인이 ...
# 2703           업데이트도 무슨 잘안돼는 쓰레기같은앱 국민청원하던가 해야지 이건비리있다 진짜
# 2704    이전 어플이 훨씬 사용하기 용이하고 한눈에 정보 파악하기 좋았음. 업체 바뀌면서 개...
# 2705          그냥 좀 간단히 만들면 되는것을 짜증 납니다 그리고 맨날 광고을 띄워야 합니까
# 2706                                       짜증나요 수시로 접속안되요
# 2707    1. 동백전 가맹점 배너 만들어주세요 -예전에 이 문제 관련해서 4/29일에 가맹점...
# 2708    어플 거지같아요 이용내역에 따른 캐시백이 얼아되었다는 금액을 같이 넣어주세요 작년 ...
# 2709    이전보다 훨 불편해짐..ui 누가 만든건지 참..글고 충전은 무슨 한도가 왤케높게함...
# 2710    아..진짜 이거 뭐 이따위로 만들었나요. 업데으트도 안되고..왜 이런 업체가 이런 ...
# 2711                                     이전에 사용하던게 훨씬 좋네요
# 2712     쓰기불편해요 개선의 의지가 없든지 능력부족 아래 1점짜리 리뷰 내용들 전부 공감됩니다.
# 2713                                   업데이트 하루종일 안되고 뭐에요?
# 2714       오늘 업데이트했더니, 10% 적립내역이 이제 보이네요..^^; 이거 제일 기다렸음.
# 2715                                                  좋아요
# 2716    앱을 굳이 바꿔야 했는지 예전 버전의 동백전 앱이 더 직관적이고 사용하기에 용이했습...
# 2717                                         갑자기 앱먹통은 뭐죠?
# 2718    오늘은 앱이 전혀 열리지 않네요. 무슨 일인지 몇번을 시도해도 열리지 않아요. 답답...
# 2719    이전 동백전은 오류 한 번도 없었는데, 잔액환불도 너무 느립니다. 6월 1일자 결제...
# 2720                                         업데이트도안되고 왕짜증
# 2721                           앱 안됨.. 카드 등록안됨. 50만원 돌리도~~
# 2722    동백전 등록하고 한참 사용중인데도 실물카드를 등록하라는 말이 계속 나오는데 무슨뜻인...
# 2723                                         왜안되는거에요..불편해
# 2724    아이폰 사용내역 알림 아이폰 사용내역 알림 언제쯤이면 사용 가능한가요?\n결제 내역...
# 2725    앱이 계속 실행이 안되면 어떻게 사용하란 얘긴가요?당장 써야하는데...사용이 잘 안...
# 2726                        먼저번거랑 비교가되네요 광고도많고 앱들어갈때 불편해요
# 2727                             사용가능금액중 내잔고 확인이 쉬웠으면 하네요
# 2728                                         간편하게사용할수있어좋음
# 2729       업데이트하고 나서 안들어가지고 환불도 시간엄청걸리는 바꾸고나서 좋아진게하나도 없네요
# 2730                                               구우응ㆍ우웃
# 2731                                                   완조
# 2732                                            앱실행이안되네요?
# 2733    어플을 열려고 하면 열리지 않는 경우가 자주 발생합니다. 캐시백 사용도 이전보다 불...
# 2734                        UI가 과거보다 어려워졌음. UI차원에서 개선 요망.
# 2735                                  앱이 이유도없이 자꾸 꺼져서 빡쳐염
# 2736                               동백전 혜택은 계속 되었으면 좋겠습니다.
# 2737                                   중단됫다고안되고업데이트하라고안되고
# 2738                                                 적립적립
# 2739    전 동백전은 삼성페이에서 사용이 되었는데 아건 카드를 들고 당겨야 되는건가요? 아님...
# 2740                                                  좋아용
# 2741                                                 좋습니다
# 2742    쓰기 싫음 자동으로 캐쉬도 안돼 사용 전후 잔액확인도 없고 승인 내역만 있어 바뀌고...
# 2743                            좋아요 10프로 적립된 포인트 현금처럼 씁니다
# 2744    정말로 교통카드 기능이 없어졌나요..? 삼성페이 등록도 안돼던데 언제 되게 만들 예...
# 2745    결제시 푸쉬알람이 안떠요 문의를 남겨서 재설정 하라는대로 다 했는데도 결제알람이 안...
# 2746    사용가능금액이 캐시백포함인지아닌지 알수가있어야죠\n사용자가 항상 그거 합계를 하던지...
# 2747    아이폰 결제내역 알림은 언제 되나요? 1:1 문의를 해서 시킨대로 다 했는데도 안되...
# 2748                         사용장애로 결제잘못됐음 빨리환불해라. 벌써2주째다.
# 2749    전 카드 대행사와 너무 비교돼서 별 한개도 아까워요... 카드 포인트 쓸때마다 어플...
# 2750                                                 충전하지
# 2751    아니 멀쩡한 이전 동백전(kt)을 왜 이딴 데랑 바꿔서 시민들에게 불편을 주는 건지...
# 2752                                                  좋아용
# 2753                                                 구제불능
# 2754                                       예전 보다 사용하기 불편함
# 2755    업데이트가 안되서 데이터, 캐시 삭제했는데도 안됩니다. 삭제하고 다시 깔아볼려고 해...
# 2756    사람들 불편사항 다 비슷한데 몇달이 지나도 개선의 의지가 안 보이네요. 잔액 나오게...
# 2757    분명히 지난 앱이 어떻게 구동되는지 봤을텐데 기본적인걸 애초에 안넣고 업데이트로 하...
# 2758    진짜 별한개도 아까움 캐시백 받은 내역 안 보여주는거 너무 투명성이 없음 업체 왜 ...
# 2759    다른 리뷰들처럼 캐시백이나 전반적인 부분에서 이전것보다 불편함. 개선의지도 없어보이...
# 2760    사용내역 보이게 하세요. 댓글은 리뷰 복붙같은거 달거면 달지말고요. 어떻게 다 댓글...
# 2761                                 사용자에게 만은 해택이있어 추천합니다
# 2762                                      포인트 사용하기 너무 불편함
# 2763                                           이전앱이 훨씬 나음
# 2764    진짜 전에쓰던어플이훨씬좋음 뭐하나편한것도없고 \n\n잔액환불도 전에쓰던건 빠릿빠릿바...
# 2765    너무 불편하네요 이전에 앱은 \n사용가능 금액 캐시백 금액 \n간단하게 바로 확인이...
# 2766       아이폰 알람 배너부터 알림설정 다 되어 있는데 어플에서 왜 푸쉬알림이 안오는걸까요?
# 2767                              최곱니다.. 현금도 바로 바로 돌려받고..
# 2768                              전에사용한앱에비해너무불편해요캐시쓰기도힘들고
# 2769                             왜 바꿨는지. 전보다 사용하기 넘 불편하네요
# 2770                                    전 동백전앱이 훨~~씬 편합니다
# 2771                                                  불편함
# 2772    최악의 앱. 사용하기 완전 불편하고, 연결된 카드가 있다는데 카드번호를 보니 내가 ...
# 2773    와..진짜 앱에 평가남겨보긴또 내가.. 부산시예산가지고 대행하는 업체이고 그거로 돈...
# 2774                                               최고입니다.
# 2775                       경기화폐는 삼성페이된다던데 동백전은 아직 계획이 없나요
# 2776    캐시백 함 받을랫다가 쓰러지겠네요 돈 묶여있는거 어케 뺍니까 ;;\n다섯 군데 돌아...
# 2777    개선요구사항 1.캐시백 내역 2.이번달 총 캐시백 금액 3.이번달 사용한 카드내역 ...
# 2778                     도대체 어디에 뭐가있는지 알수도없이 .. 별한개도 아깝네요
# 2779                                                   개똥
# 2780                      쓰레기보다 최악이라는 말보다 더 한 말이있다면 그 정도급
# 2781                  사용하기도전에 댓글보고ㅠ안씀.. 이게 부산시가ㅜ노리는건가....
# 2782                      계속해서 기기에서 충돌앱이라 나오는데...어찌 해결좀??
# 2783                                     불편합니다 저번앱이 훨나앗음ㅠ
# 2784    사용금액이랑 캐시백 금액 합쳐서 나와야지 아니 따로따로 나오면 어쩌자는 건데?? 어...
# 2785    케이뱅크밖에 안 쓰는데 은행이 없어서 사용 못하는 중ㅋㅋㅋ... 모든 은행 언제 들...
# 2786                                   충전은행 어케바꿔요 드럽게불편하네
# 2787                                                 충전하기
# 2788    충전 얼마했는진 알려줘야지 충전가능금액을 50만원-현재잔액으로해서 충전가능하다해놓고...
# 2789    개쓰레기같은 앱 사용하려고 해도 부산 동백전 로딩화면만 쳐깜빡이는 개쓰레기같은 앱입...
# 2790    캐시백 한도가 30만원 이면 충전한도도 30만원, 보유한도도 30만원으로 결정하면되...
# 2791                             불편하네요.게시밳ᆢ용하기도~ 엄데이트도안도고
# 2792    잔액확인 카드잔액확인 어플 처음 켰을때 화면에서 할수있게 개선바랍니다 매번너부 불편...
# 2793                 아이폰 알림 카드 결제하고 난 뒤 알림 좀 오게 업데이트 해주세요
# 2794    총받은혜택 이달에만 받은 혜택으로 바꾸거나 아예 없애는것도 좋을것같아요 총 받은혜택...
# 2795    하라는 대로 해도 업데이트가 안됩니다 지우고 다시 설치해도 역시 안되네요 부산시는 ...
# 2796    내가 캐쉬백받은 금액이 얼마인지 확인이 안되요. 그거때문에 동백전 쓰는 건데요. 이...
# 2797                   한도가 바뀌고하면 공지를 좀 해주세요 너희끼리만 알면 뭐합니까
# 2798                     쿠폰주고 cu 매장가면 전카드 버린카드가져오라고함 어이없음
# 2799    잔액 표시를 캐쉬백잔액 사용 할때 안할때 변경을 하면 남아있는 잔액이 바뀌어야 구분...
# 2800                                               잘 씁니다.
# 2801    대중교통 이용도 않되게 해놓고 무슨 부산동백전 이라고...한심하네요 어떻게 선정되었...
# 2802    계좌등록 여러건 등록 안되나요? 입금 출금 전부다 계좌 인증하면서 수시로 바꿔야하네...
# 2803                                                   그냥
# 2804                                                  좋와요
# 2805                                                  좋아요
# 2806    진짜 ui부터 편의기능 싹다 최악이네ㅡㅡ 삼성페이등록도 안돼 바코드결제도 안돼 qr...
# 2807    주유소에서 사용이 안됩니다. 카드를 긁어서 결재하는 방식은 하지못합니다 . 긁을수 ...
# 2808                                        난좋은데 정신병자들 많네
# 2809                             항상 감사한 마음으로 사용 잘 하고 있습니다
# 2810                      너무 불편 그자체 누가 만드는지 모르겠지만 안써보는것같음
# 2811                                               편리해요!!
# 2812                                카드.결제는.되는데.내용확인이.안돼네요
# 2813                              진짜 성의없네 답글은 전부 복사 붙혀넣기내
# 2814                                한동상향했는데 50만원이상충전 안되네요
# 2815                                                  불편함
# 2816                                        그전에 비해 너무불편해요
# 2817                                        잔돈없이 사는세상 ㅡ감사
# 2818                                      현금인출기능이 없어가 불편함
# 2819                                           잘 사용하고 있어요
# 2820                              업데이트 안됨 이전보다 아주 불편 짜증폭발
# 2821    서비스 뭐 같이하네 업데이트 하니까 소득공제 신청 동의 자동으로 뜨던데 미리한 사람...
# 2822    포인트 사용 표시가 헷갈리게 되어 있고 총받은 포인트 표시가 불필요하게 표시되어 있...
# 2823                                 이전 동백전보다 사용하기가 너무 불편
# 2824         잘 쓰고 있습니다. 삼성페이가 안 되어서 별1개 감점. 삼성페이 되게 해주세요.
# 2825                                                  좋아요
# 2826                                                좋아요^^
# 2827                                     앱 바뀌고나서 너무불편사항만음
# 2828                                           예전보다많이불편해요
# 2829                                   사용이 편리하고 충전도 쉬워요..
# 2830                                                  우꾸끠
# 2831                                            ,7,aW ,,5
# 2832    업뎃 이후에 개인정보 동의 안하면 화면이 안넘어가네요 이건 먼짓거리인지..쓸수록 짜...
# 2833           한도 늘리면 뭐하노 어플 업데이트도 안되 다시 설치도 안되... 아 짜증나네
# 2834                                                    👍
# 2835                                                  좋아요
# 2836    아니 왜 자꾸 댓글로 1대1 문의를 달라고하는건가요? 리뷰평을 보고 편의성을 보는건...
# 2837                        너무 불편하게 바뀌고 기존카드 사용도 못하게 해놨네요
# 2838                                                  좋아요
# 2839                  실력이 없는지 개선이 안되는 업데이트는 왜 하는지 알 수가 없다
# 2840                                      ㅣㅣㅣㄴ 도영 ㅣㅣㅣㅏㅡㅡㄷ
# 2841    업데이트도 안되고 삭제하니 앱이 다운로드도 안되고 어쩌라는건지 바뀌고 나서 사용엄청...
# 2842    업데이트도 안되고 삭제하고 다시깔려고 하니 대기중만 나오고 사용 엄청불편하네요 빠른...
# 2843                 앱이갑자기업데이트하라고뜨면서 업데이트 도 안돼고 앱자체가아예안돼요
# 2844    우씨 업뎃이 안되잖아요..설명한것처럼 들어가서 삭제하고 했는데도 안되요..개짜증남....
# 2845                                 업데이트를 너무 자주해서 불편합니다!
# 2846    다들 부산시에 동백전 민원 넣어주세요 이렇게 불편하게 만들어놓고 담당자는 뭐 하나 ...
# 2847                                                    굿
# 2848    업데이트가 왜이리 안되나요? 카드를 쓰고싶은데 업데이트가 안되고 앱이 안열려서 못쓰...
# 2849                            진짜 최악! 어쩔 수 없어서 사용.. 아...
# 2850                                            조아요 저도 요ㄸ
# 2851    잔액이 업데이트가 안되요 5만원 충전하고 계속 오프라인 카드로 쓰는 중입니다\n결제...
# 2852                                           예전보다 ㄷ~~불편
# 2853                                    기냥 광고쓰레기 어쩔수없이쓰는듯
# 2854    동백전 사업자 가맹점.. 개인 사업자로 개인용 카드 사용하면서\n사업장에 동백전 큐...
# 2855    문제가 너무 많네요 몇개월이 지났는데 사용내역 알림이 왜 아직까지 안오는지 그게 뭐...
# 2856    1. 우선 실물카드를 가지고 다녀야 하는 불편함 2. 초반 자동차 지급하는 이벤트로...
# 2857                                          별 반 개는 없는지?
# 2858                                예전 이관되기전에 카드 사용되나요 ??
# 2859    케이뱅크도 지원 좀 해주세요. 카카오뱅크도 있는데 1금융권인 케이뱅크가 없는건 이해...
# 2860    ㅠ 어플이진짜 직관적이지가 않음 지역카드인만큼 나이드신분들이 많이 사용할텐데 헷갈리...
# 2861    21/07/18 설문조사하라해서 설문조사중 맨밑에 건의사항 적고 있는데 갑자기 휴대...
# 2862    연결계좌 여러개 할수 있도록 조치 부탁 드립니다 충전시 연결계좌가 하나라 사용이 너...
# 2863    ㅋㅋㅋ불편사항 백날 말하면 머하누 매크로가 답변하는데 ㅋㅋㅋ +네 매크로저격하는 리...
# 2864                                           가맹점찾비불편합니다
# 2865    제발 안드로이드에서 국가사용제한 좀 풀어주세오 메일도 보냈습니다 ㅠ 제발 풀어주세오 ㅠㅠ
# 2866                       업데이트가안되요ㅜㅜ 설정에서 데이터 삭제했는데두요 ㅜㅜ
# 2867                         다 좋긴한데 빠른시일내에 삼성페이 연동되길 바랍니다
# 2868    로코 정책지원금 사용할수있게 해주세여 정책지원금이라고 이벤트성으로 들어온 적립금이 ...
# 2869    로코 이벤트라고 3천원 주더니 사용조건이 충전금 전액사용 이후에 카드캐시네? 자동충...
# 2870                                    부산에서 사용해서는 정말 좋아요
# Name: REVIEW, dtype: object

# %% [markdown]
# #### tf-idf 활용한 빈도분석

# %%
total_tokens = [token for mag in corpus for token in str(mag).split()]

print('띄어쓰기 기준으로 나누어봤을 때의 단어(토큰)의 개수:', len(total_tokens), '개')
# Out:
# 띄어쓰기 기준으로 나누어봤을 때의 단어(토큰)의 개수: 33050 개

# %%
total_tokens[:10]
# Out:
# ['부산에도', '기다리던', '지역화폐가', '나왔네요', '앱도', '깔끔하고', '카드도', '바로', '신청하고', '잘']

# %%
tfidf = TfidfVectorizer(max_features=1000)
tdm = tfidf.fit_transform(corpus)
word_count = pd.DataFrame({'단어': tfidf.get_feature_names(), 
                           '빈도': tdm.sum(axis=0).flat})
word_count.sort_values('빈도', ascending=False).head(20)
# Out:
#        단어          빈도
# 806   좋아요  224.191436
# 158    너무   63.117580
# 200   동백전   62.978886
# 869    카드   46.494622
# 829    진짜   37.231087
# 86     계속   35.787430
# 804  좋습니다   33.267327
# 884   캐시백   31.875934
# 585    앱이   31.704516
# 178    다시   28.102289
# 527   안되고   27.959463
# 592   어떻게   25.062833
# 784    정말   25.006864
# 33    가맹점   24.156462
# 518    아주   23.864718
# 530  안되네요   23.677442
# 601    어플   23.336554
# 812    좋음   23.263746
# 544  안됩니다   23.097242
# 396    사용   22.700495

# %% [markdown]
# #### 텍스트 전처리
# - 자음모음만으로 구성된 것 제거
# - 특수문자 제거
# - 숫자 제거

# %%
def message_cleaning(docs):

  
   
    # Series의 object를 str로 변경.
    docs = [str(doc) for doc in docs]
    
    
    # 1. 자음 모음 제거하기
    pattern1 = re.compile("[ㄱ-ㅎ]*[ㅏ-ㅢ]*")
    docs = [pattern1.sub("", doc) for doc in docs]
    # 2. 특수문자 제거
    pattern2 = re.compile("[\{\}\[\]\/?.,;:'|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]")
    docs = [pattern2.sub("", doc) for doc in docs]
    # 3. 숫자 제거
    pattern3 = re.compile('\d+')
    docs = [pattern3.sub("", doc) for doc in docs]
    
    return docs
# Out:
# <>:13: DeprecationWarning: invalid escape sequence \{
# <>:16: DeprecationWarning: invalid escape sequence \d
# <>:13: DeprecationWarning: invalid escape sequence \{
# <>:16: DeprecationWarning: invalid escape sequence \d
# <>:13: DeprecationWarning: invalid escape sequence \{
# <>:16: DeprecationWarning: invalid escape sequence \d
# <ipython-input-69-5090dc8cd3d9>:13: DeprecationWarning: invalid escape sequence \{
#   pattern2 = re.compile("[\{\}\[\]\/?.,;:'|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]")
# <ipython-input-69-5090dc8cd3d9>:16: DeprecationWarning: invalid escape sequence \d
#   pattern3 = re.compile('\d+')

# %% [markdown]
# #### 명사추출

# %%
import re
import MeCab # 형태소 분석기
mecab = MeCab.Tagger()
import requests
import pickle
import ast
## mecab형태소 분석기로 명사 추출하는 함수
def mecab_nouns(text): 
    nouns = []
    
    # 우리가 원하는 TOKEN\tPOS의 형태를 추출하는 정규표현식.
    pattern = re.compile(".*\t[A-Z]+")
    
    # 패턴에 맞는 문자열을 추출하여 konlpy의 mecab 결과와 같아지도록 수정.
    temp = [tuple(pattern.match(token).group(0).split("\t")) for token in mecab.parse(text).splitlines()[:-1]] 
    
    # 추출한 token중에 POS가 명사 분류에 속하는 토큰만 선택.
    for token in temp:
        if token[1] == "NNG" or token[1] == "NNP" or token[1] == "NNB" or token[1] == "NNBC" or token[1] == "NP" or token[1] == "NR"or token[1] == "NNS"  :
            nouns.append(token[0])
    return nouns

# %%
## 텍스트 정제
cleaned_corpus = message_cleaning(corpus)
cleaned_corpus
# Out:
# ['부산에도 기다리던 지역화폐가 나왔네요 앱도 깔끔하고 카드도 바로 신청하고 잘 사용하겠습니다',
#  '화이팅',
#  '기다렸었는데 앞으로 잘 쓸게요',
#  '동백전으로 여기저기 많이 사용해 볼게요 부산 경제에도 많은 도움이 되면 좋겠습니다',
#  '부산 동백전 쓰기 편하게 잘 만들어졌네요 부산에서 혜택이 많았겠네요',
#  '잘 사용해 볼게요 동백전으로 혜택 많이 받으면 좋겠습니다',
#  '가자 글로벌 테스트베드 부산',
#  '오 부산도 드디어 모바일 지역화폐가 나왔네요 앱설치하고 카드신청도 해봤는데요 복잡하지 않고 간편하게 구성되어 있는거 같아 좋네요 저는 수도권에 올라와 있어서 명절에 내려가면 쓰려고 하는데 카드만 긁으면 된다고 하니 엄청 편할거 같네요  내려가면 부모님도 쓰실 수 있게 알려드릴까 해요 지역페이는 수당도 주고 하는거 같던데 나중에 복지비용도 이걸로 쓸 수 있게 나오면 부모님도 어렵지 않게 쓰실 수 있을거 같아 기대됩니다',
#  '드디어 기다리던 동백전앱이 출시됐네요 앞으로 이용 많이 하겠습니다',
#  '군더더기 없는 ui가 마음에 드는군요 많은 사업장에서 사용가능하면 더 좋겠습니다',
#  '좋아요',
#  '선택약정선택하면 네트워크장애라고 뜨면서 진행되지 않음부산시에서 개인정보를 팔아 장사하는지',
#  '많은 이용 바랍니다 부산시민과 함께 성장해 갑시다',
#  '부산을 대표하는 꽃 이름으로 지은 동백전 이름이 멋지네요 부산에서 이용하는 혜택도 많아 기대가 됩니다 앱도 복잡하지 않고 사용하기 편리해 보여 한번 써 봐야겠네요',
#  '편의점에서도 사용되나요',
#  '설치가 아주 간단하고 쉽네요',
#  '군더더기 없이 사용하기 편하고 좋습니다 ',
#  '어플이 깔끔하니 사용하기 좋아요 자주 사용하게 될듯 하네요',
#  '아니 QR코드 결제가 안되냐 기본인데 하 카드 신청도 잘 안되고 미치겄네',
#  '회원가입이 안 돼요 다음주에 만 세 되는 사람인데요 계속 만 세 이상만 가입이 된다고 떠요 어떡해요',
#  '적립한도 볼 수 있게 잘 쓰고 있는데 충전한도 말고 적립한도도 볼 수 있게 하면 훨씬 좋을 것 같네요',
#  '지웠다 깔아도 들어갈 수가 없음  마트에서는 결제가 안됐다고 하고 돈이 빠졌는지 확인을 해야 하는데 이 무슨 xx같은 상황인지 쓸때마다 왜 이런일이 일어나는지 충전하고나서 어플에 안들어가짐 네트워크 상태 확인하라면서 별하나도 아깝',
#  '앱 오류 안고쳐주실건가요 충전하려고 앱들어가면 데이터 상태로는 들어가지지도 않고 와이파이로 들어가면 사용자 정보를 가져올수없다고하고 쓰지말라는건가요 아예 좀 고쳐주세요 오류가 너무 심하네요 진짜 ',
#  '오류 좀 개선해주새오 너무 오류가 심해요 캐시백이 안되어서 문의했더니 다시 가게에 가서 취소하고 재결제 방법밖에 없다고 하고 오류일 경우 해결방안이 너무 불편해요',
#  '앱실행이 안됩니다 사용자 정보 취득에 실패하였다면서 앱이 꺼져버립니다…',
#  '안들어가져요 먹통입니다다시 설치해도 그래요',
#  '정말 오류가 많이 뜨네요 오류가 계속 떠서 사용하기 너무 힘들어요',
#  '발급받은 지 한참 지났는데 앱 오류 때문에 충전을 못합니다 빨리 개선 부탁드립니다… 하루에도 몇번을 시도하는데 매번 충전 금액 입력하고 나면 앱이 자동으로 꺼집니다',
#  '안켜져요  계속 오류나서 새로 설치했는데 자꾸 네트워크 오류라고 하네요',
#  '욕나올정도로 후짐 며칠전부터 가맹점조회 아예 안됨',
#  '동백전 카드 결제지연 오류 아니 무슨 카드가 사용자가 많다고 오류가 되서 계산이 안되나요  사람들이 갑자기 카드 많이 쓰는건 감안하고 처음부터 오류같은건 안나가게해야되는거아닌가요 이카드 하나만 가지고 밖에 나왔다가 분동안 안들어가져서 집갔다가 다른카드 가져왔네요 빨리 보안해주세요 ',
#  '가맹점 찾기 일까지는 문제 없었는데 일 서버 폭주로 접속 제한된 다음부터는 가맹점이 개입니다 가맹점은 앱 내에서만 검색이 되는데 언제쯤 다시 가맹점을 확인 할 수 있을까요… 안드로이드 애플 둘 다 안 됩니다',
#  '갑자기 가맹점 찾기가 안되요 갑자기 가맹점 찾기가 안되요 삭제후 재설치 했는데도 안되고 위치도 허용했는데 안되요',
#  '가맹점찾기 가맹점찾기 아무것도 안뜨고 도대체 어딜 봐야하나요 오류가 너무 잦아요',
#  '가맹점 찾기가 안 되어 문의드립니다 동백전 정말 잘 사용하고 있어요 캐시백  되는 것도 너무 만족스럽습니다 그런데 얼마 전부터 가맹점 찾기가 안 돼요 가맹점을 찾으려고 들어가면 전체 개의 가맹점이 뜬다고 되어 있고 분명히 동백전 사용이 가능하던 가게를 검색해도 관련된 가게가 아무것도 없다고 뜹니다 평소에 자주 이용하던 가게는 찾지 않아도 되기 때문에 사용에 불편이 없지만 동네에서 조금 벗어나서 다른 곳으로 갔을때 사용 가능 유무를 모르기 때문에 불편합니다 혹시 제가 어떤 설정을 잘못했기 때문에 뜨지 않는 것이라면 설정에서 어떤 것을 활성화하면 되는 것인지 알려주셨으면 좋겠어요 또 만약 앱의 문제라면 업데이트 해주셨으면 좋겠습니다 감사합니다',
#  '가맹점 가맹점 찾기 아예안되요 쓰지말라는건가요',
#  '어플이 진짜 구려요 오류나서 접속이 안되고 로그인도 안되고써야할 때 못쓰면 무슨 소용이죠 시스템안정화 신경써주세요',
#  '가맹점 찾기 가맹점검색하려면 만뜨고 전에는 검색이 됐는데 아무것도 안나오는데  왜이런거죠',
#  '오류가 장난 아니네요 좋아요 포인트도 많이 쌓이고 돈쓸맛 나는데 오류가 심해서 금하게 충전하려할때 앱이 안열려서 쓰지도 못하고 하네요 개선 좀 해주세요',
#  '갑자기 왜 안들어가지죠 낮에 분명 사용하고 방금 가맹점 카페와서 사용하려고 하는데 잔액이 있음에도 불구하고 계속 오류나서 어플누르니까 계속 튕기고 지웠다가 다시 깔아도 안되는데요',
#  '못쓰겠네요 버그빨리 수정요 뭔 자꾸 튕기니  쓰지말라는 뜻인가요 빨리 버그 수정해주세요',
#  '가맹점찾기 다 좋은데 얼마전부터 가맹점찾기가 안되네요 계속 건만 뜹니다 빨리 해결해주세요',
#  '네트워크 네트워크로 인해 실행이 안된다고 뜨네욤 아까 까지 되었는데 수정해주세욤',
#  '기간별 검색기능 강화 요청 예를들어 월일부터 오늘까지 사용실적 또는 적립실적 검색하면 그 기간동안 사용 총 금액 또는 적립 총 금액이 같이 떴으면 좋겠습니다',
#  '문자인증이 안와요 어플이 안켜져서 삭제했다가 다시 깔았는데 문자인증메세지가 안와요',
#  '교통카드 이용내역 다 좋은데 카드 이용 내역에 후불교통카드로 쓰인 금액도 적혀있으면 좋을 것 같아요',
#  '한달동안 결제한 내역 총 합계를 볼 수 있었으면 한달동안 결제한 내역 총 합계를 볼 수 있으면 좋겠어요 하나하나는 결제 내역 확인이 되는데 합계한달에 얼마 썼는지를 볼 수 있는 시스템이 없어서 지출 관리가 불편해요',
#  '문제가 많네요 만원 충전했다가 충전취소하고 다시 충전하려고 했더니 충전이 안되는데 이게 충전 한도만큼 충전을 했기때문인가요 충전 취소하면 다시 충전한도가 초기화되야하는 것 아닌가요',
#  '앱 쓰레기 동백전 신청하려고 앱 깔았는데 에러만 벌써 번째… KT에서 개발한거라고 SKT전화에서는 에러나게 만든거예요 진짜 그런거면 실력 인정… 제발 에러나는거 좀 고쳐봐요',
#  '최악 어플이되야쓰죠',
#  '금액 충전이 안 되고 자꾸 꺼져요 금액 충전해서 쓰고 싶은데 앱이 자꾸 다운되고 꺼져서 충전 자체를 못 해서 카드 발급만 받고 아예 못 쓰고 있네요 고객센터에 전화해도 전화 안 받고  문의 올려놔도 답변도 빨리 안 주시는 것 같고 실망이 크네요',
#  '사용내역 보려고 하면 어플이 꺼져요 충전만 되고 뭐 하려고 하면 꺼져서 쓸수가없어요',
#  '안켜져요 업데이트하고나서 동백전 어플이 안들어가집니다 오류 보완 부탁드려요',
#  '어플을 운영을 하실거면 불편함은 제때 개선좀 하세요 국민들 불편함 의견제기  점심시간 퇴근시간 카드승인 불가  점심시간 퇴근시간 어플 내 돈충전 불가  업데이트후 어플켜지지 않는 문제 등등 불편함이 정말 많은데 좋은점캐쉬백만 광고하고 실적 쌓으시는건가요 퇴근 후에 장보러 마트가서 결국 동백전 카드 쓰지도 못하고 기존에 쓰던 카드 씁니다 괜히 헛걸음 하게 만드시네요 좋은만큼 불편함도 큽니다 이렇게 운영하실바엔 어플 안만드는 게 좋을듯요',
#  '열면 안들어지네요 안들어가쟈여 고쳐주세요',
#  '잘 쓰고 있어요 렉이나 오류도 없고 캐시백도 많이 받아서 쓰는 재미가 쏠쏠하고 좋아요 하나 건의하자면 기간 내 한달 단위 등 이용자가 받은 캐시백 혜택 전체 총합을 한눈에 볼 수 있으면 좋겠어요 그러면 얼마나 돈을 돌려받았는지 직관적으로 알 수 있으니까 만족도도 더 높아질 것 같습니다',
#  '오류 어플 오류가 너무 많아요 쓰고싶을때 한번도 제대로 써본적이 없어요',
#  '이번달만 오류가 몇번인지 하 이렇게 오류가 많이 나는데 어찌 쓰란말인가요 여분으로 다른카드 더 들고다녀요 개선한다면서 전혀안되고있네요 어플개발 실력자좀',
#  '확실히 진짜 좋은데… 카카오 뱅크 계좌는 왜 등록이 안되는건가요 정말 불편해요…',
#  '고객센터 고객센터 답변 얼마나 기다렸는데 일 쥰나 안 해요',
#  '결제안된다해서 다른카드로 결제했는데 동백전에선 또 돈이 나가네요 일반 슈퍼인데도 동백전카드가 잘 결제가안되고 실패한다고해서 다른 카드로 결제했는데 어플 알림보니 또 동백전 카드에선 돈이 나갔고 캐시백도 들어왔네요 그래서 확인하려고 어플키니까 갑자기 사용자정보 어쩌고 오류뜨면서 다시 어플키라고 계속 뜨길래 어플삭제하고 다시 깔았더니 바로  service unavailable 뜨네요 중결제됐는지 확인도못하고 이게뭡니까 당연히 슈퍼쪽에선 결제안됐다하고 내일 오전에 카드사 전화해야겠네요 좀 제대로 안정화해주세요',
#  '가맹점 찾기 기능 개선 해주세요 가맹점 찾기 기능에서 현재 위치에서 지도를 보면 사용 가능한 가맹점이 다 보일 수 있게 해주시면 안될까요 하나씩 검색하기 불편해서…',
#  '좋긴한데요… 결제 어플인데 이거 업뎃때문에 못쓴다고 안 막았으면 합니다 결제해야해서 잔액 보려고 들어가니 업데이트 하라고 어플이 안 켜지다니요  업데이트 공지 올려주시고 일단 주요 기능은 쓸 수 있게 해주세요',
#  '백원 단위도 충전되게 해주세요 제발요 다좋은데',
#  '택시는 안되나요 몇번 결제할려는데 다 안되네요 ',
#  '가맹점 표시 지도상에 한꺼번에 표시될 수 있게 해 주시고 띄어쓰기 잘못하면 검색이 안되던데 검색조건을 좀 느슨하게 해서 오탈자가 있더라도 검색될 수 있게 해주세요',
#  '사용자정보취득에 실패하였습니다 사용자정보취득에 실패하였습니다 앱을 다시 실행해주세요 라는 문구가 계속 떠서 삭제 후 다시 깔았는데도 여전히 안되네요… 오늘 카드 받아서 충전해서 내일부터 쓸려고 했는데 사용할 수가 없네요… 빠른 해결 부탁드립니다',
#  '앱더럽게안됨 안들어가지고 삭제했다가 다시 들어가니 로그인 화면도 없고 회원가입하라고 뜸 인증도 안되고 먹통이고 뭐 어쩌란말임',
#  '갑자기 안되니까 어이없네… 아니 왜 갑자기 네트워크 불안정 하다고 뜨고 안 들어가지는 겁니까 얼마 남았는지도 봐야하고 포인트도 써야되는데 이것 참 미춰버리겠네…',
#  '어플실행오류 어플이 갑자기 실행이 안됩니다 와이파이도하고 데이터로도 해봤지만 두개다 오류뜨네여 고쳐주세여',
#  '갑자기 서비스가 안돼요 개인정보 확인이 안된다고 오류메시지가뜨고 튕겨서 삭제했다 다시깔아보니  Service unavailable 이라고 오류메시지가 떠요',
#  '어플 설치가안되어요 잘쓰고있었는데 금일 저녁 씨유에서 카드 주니 포스기에서 결제가 안된다고 했는데 동백전 어플로는 결제가 되어서 확인위해 어플 들어가니 튕기고 어플 삭제하고 다시까지 에러 서버  뜨면서 아예 사용할수없게되엇어요 어떻게 해야하나요',
#  '본인인증단계에서 인증문자가 안와요 개선해주세요 본인인증단계에서 인증문자가 안와요 개선해주세요',
#  '이 앱 덕분에 동백전 씁니다 오랜만에 앱 제대로 만들었다 싶네요 놀라울 정도로 간결하고 간편한 앱이에요 카드 발급받고 잘 쓰고 있습니다 ',
#  '빠르고 좋은 앱이네요 메인화면 하단 카드바가 메인 화면 진입시 움직이는 모션은 예쁘고 좋은데 급하게 카드에 돈없어서 충전 할려 할때마다 움직이니까 계속 캐시백 사용설정 메뉴로 들어가서 다소 불편하네요 그외에는 빠르고 만족합니다',
#  '내가 보유한동백전 칸에 불필요한건 삭제 너무 잘쓰고있습니다  근데 충전할라고 켜면 맨날 내가보유한 부산 동백전 칸에 포인트 내역과 부산시민이라면 지금은동백전 쓸 무렵이라는 아무기능없는 광고만 뜨고 좀 있어야 충전 칸으로 옮겨져 맨날 잘못클릭하게되네요  동백전 현황에는 딱 충전금액과 포인트만 표시하고 안움직이게 해두면 시안성과 활용성에도 더 좋을거같습니다  앱화면은 동백전할라고 앱설치한 사람한테만 보이느거니 광고내용은 불필요할거같네요  아니면 아래쪽으로 내렸을때 나오게 하든가',
#  '좋아요 좋습니당',
#  '앱 사용 내역 볼려고하면 계에에에에속 나가지네요 빨리 고쳐 주세요 ',
#  '큐알 코드 결제 부탁… 실물 카드로만 되는 보네여… 아이폰은 웁니다',
#  '클릭 안됨 가입 다 하고 맨 마지막에 비밀번호 설정하는 거 클릭이 안되네요',
#  '쓰라는거야 카드 신청도 안되고 계좌 등록도 안되고',
#  '너무좋아요 얼마 쓰지도 않았는데 캐시백 쏠쏠해요 원 단위 충전도 가능해서 현명한 소비가 가능해요',
#  '정말 잘쓰고 있습니다 굿굿',
#  '금액을 직접 설정해서 충전하면 좋겠어요 정해진 금액만 말고 사용자가 충전하고 싶은 금액을 입력해서 충전할 수 있었으면 좋겠어요',
#  '가맹점 찾기라뇨 생각보다 안되는곳도 많고 충전금액 환불은 왜 안되는거죠 계속 실패했다고 뜨는데',
#  '가맹점 찾기 왜있나요 되는곳도있고 아닌곳이있고 그게 헷갈려서 찾기 서비스가 있는거 아닌가요 왜이렇게 안되는곳이 많죠 심지어 충전식이라서 다른통장에서 돈을 뺐는데 안된다니 지도상 틀린곳도 많습니다',
#  '가맹점이 두개씩 중복되서 나와요 가맹점 검색하면 중복해서 나와서 보기 힘들어요',
#  '인증안됩니다 전화번호 누르고 인증하기 버튼이 먹통이네요 혜택도 좋은데 이러다 잊혀져 갈까 걱정입니다',
#  'QR코드 간편결제도 되었으면 좋겠어요 카카오페이처럼 QR코드로 간편결제도 되었으면 좋겠어요 안드로이드는 삼성페이도 되는데 아이폰은 안되니까 좀 아쉽네요  QR코드 간편결제만 되면 점만점에 점',
#  '동백전 최고 동백전 충전하면 캐쉬백도 나 해주고 가정생활에 많은 도움이 되네요 지하철도 되고 또 계좌연결하면 카드처럼 사용할 수도 있고 너무 좋아요',
#  '할인 많이 되네요 할인 생각보다 많이 되네요 더 가맹점 늘려주시길',
#  '안증안되요 쓰고싶어도 인증이안되니 쓸수가없네요',
#  '출시기념 월 한달간 이벤트를 하는데 월 지났는데도 아직 다운로드를 받지 못하는 어플이 있다 두둥 탁 마 이것이 붓싼의 정책이다 캬 이집 지역화폐 잘하네',
#  '기다렸는데 드디어 빨리 가입 흥해라 동백전',
#  '뭐 이런 개쓰레기 같은 앱이 다 있어 죽도록 카드신청해도 안됨 안써',
#  '앱에서 결제되게 해주세요 동백전 좋다 좋다 말 많이 듣고 드디어 실물카드 받았습니다 근데 충전 상황 캐시백 상황 다 앱에서 확인하는데 이왕이면 앱으로 결제도 할 수 있게 해주세요 불편해요… 아이폰도 편하게 쓰게 해 줘요',
#  '실행이 안됩니다 어플을 실행시키면 알림설정 창과 필수동의 까지는 되는데 그 다음 화면에  Service Unavailable 이라는 오류가 뜨고 아무것도 안되요',
#  '쓸만하네요 캐시백 비율이 높아서 쓰는데 좋네요',
#  '국굿 아이폰 바코드나 큐알코드 결제만 앱에서 가능 하면 최고일것 같아요',
#  '어플 오류 아예 접속 불가',
#  '너무 좋은데 앱실행이 안되요 저만 안되나요',
#  '앱 오류 빨리좀 해결해주세요 잘사용하다가 앱켜면 사용자정보를 읽을수없다고 다시시도해라고 하길래 지웠다가 다시 설치했는데 이젠 아예 다운되서 깔아서 넘어가지도 않네요 빨리 해결 좀 해주세요 잘쓰고있었는데',
#  '잘사용하고있었는데 잘 사용하고있던 중이었는데 갑자기 앱 오류로 안들어가져서 앱삭제하고 새로 깔았는데 계속 오류나네요 어떻게 해결할수 있을까요',
#  '아예오류나고안들어가져요 오류나고 아예안들어가지는데 어떻게요 서버없다고만 뜨고요',
#  '사용자찾을 수 없다고 오류가 계속 뜨고 넘어가질 않는데 왜그럴까요 어플 삭제 후에 다시 켜도  service unavailable 오류만 뜨는데 어떻게 해결하나요… 카드까지 발급받았습니다',
#  '어제까지 앱실행 잘 됐는데 No server is available to handle this request 오늘은 서버가 없다고 하네요',
#  '오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하면 점검들어간다하고 동백전에 돈 충전해서 체크카드에서 출금이 됬는데 동백전에는 충전금액 뜨지도 않네요 내 돈은 어디로 간거임  별개도 아까움',
#  '오류 뜨면서 실행안되네요 우째해야되나요',
#  '돈 넣었는데 어플 실행이 안돼요  잘 쓰다가 돈 남아있는데 어플 실행이 안돼요 뭔데요',
#  '오류 갑자기 오늘 접속오류 계속 뜨길래 삭제 후 다시 깔았더니 아예 안되네요 빠른시일내에 업데이트 부탁드립니다 아예 접속을 못하니 이용불가입니다',
#  '아이폰 X 충전안됨 충전하러 가면 튕겨요',
#  '내역만 들어가면 팅김 내역에 들어가면 팅겨요 아이폰 xs입니다 다른 내역 확인 가능한 싸이트가 있으면 좀 알려주세요 아 답답해 미쳐버리겠네요',
#  '카드신청안됨 다 하고 마지막에 계속 오류가 나요 청구서 수령관련 등록을 해야된다는데 중간에 그런거 입력하는 부분도 없고 어쩌라는건지',
#  '왜때문에 인증이안되나효 내이름에 내 탄생일에 내 명의의 핸드폰번혼데 자꾸 확인하래 내가 난데 왜 나라는걸 인증을 못해',
#  '고객 서비스가 최악이네요 어플 오류로 인하여 충전 하려고 하니 바탕화면으로 팅기는데  문의를 넣어도 일동안 응답 안하고 전화는 하루에 번씩 해도 하루종일 바빠서 못받는다고 하네요',
#  '안들어가져요 업데이트 했는데 안들어가져요 해결 좀 해주세여',
#  '앱 꺼짐 문제 앱 들어가서 캐쉬백을 누르면 앱이 꺼져버리는데 어떻게 해야되나요 다시깔아도 마찬가지 입니다',
#  '불안정한 앱 이용내역 확인 시 강제종료 앱 메뉴도 간단하고 동백전 서비스도 훌륭한데 ',
#  ' 주민등록증 찍는데 청소년들은 청소년증으로 하라해서 청소년증 찍고 발급날짜 했는데 면허번호 그거 오류라고 뜨면서 청소년한테 면허번호가 어딨어요 ',
#  '개선사항 요청하고 싶습니다 본인 인증 수단을 공인인증서도 추가 하였으면 좋겠습니다 어머니도 발급해드리려는데 어머니가 핸드폰을 제 명의로 사용하고 있습니다 어머니도 발급해드리려고 하는데 앱을 깔아 드릴수가 없네요  다른건 너무 좋습니다',
#  '동백전 어플설치 저는 아이폰이라 설치를 했지만 아버지도 동백전 어플 설치해드리려고 하니 갤럭시노트는 오래된 폰이라고 안된다고 하네요 부산지역화폐인데 모두 설치하여 사용할 수 있게 낮은버전의 폰에도 동백전 어플 설치가 가능하도록 해주시면 더 좋을 것 같아요',
#  '어플 팅김현상 월달부터 잘 사용하다가 오늘 업데이트를 했는데 어플 접속이 안됩니다 어플 누르면 동백전 화면 뜨고 초뒤 바탕화면으로 팅겨버려요',
#  '동백점 미가맹점 결제 가능 요청 잘 사용중입니다 감사합니다 다만 동백점 미가맹점에도 일반 체크카드처럼 캐쉬백은 안되어도 결제는 가능했으면 좋겠습니다 처음 방문하는 사업장에 카드를 주면 결제 실패로 안된다고 돌려받고 다른 카드로 결제를 해야하는 경우가 발생하니 불편한 감이 있네요 캐쉬백사용 onoff처럼 미가맹점결제여부도 onoff 기능을 추가해주시면 시간도 절약되고 편리할거 같습니다',
#  '아이폰에서도 쓸 수 있어 좋아요 동백전 아이폰에서도 쓸 수 있어서 좋아요 자주 사용해야지',
#  '동백전 아이폰 앱 드디어 출시됐네요… 잘 쓸게요…',
#  '노트에서는 버전이 낮아서 검색이 안되는데 어느버전 까지 가능 한가요 앱 다운 없이 카드만 사용가능한가요',
#  '부산경제를 위한 동백전이네요  혜택을 주니 잘 사용하겠습니다 앱 사용이 편리하네요',
#  '아이폰은 안되나요',
#  '이름도 이쁘고 앱도 깔금하게 잘되어 있네요',
#  '정말 편리하네요',
#  '부산시에도 지역화폐가 생겼네요 동백전 이름 좋고 화면도 깔끔하네요',
#  '심플하고 사용하기 편하네요 잡다한 기능보다 기본에 충실한게 좋죠',
#  '부산에서도 이제 사용이 가능하군요많니 기대가 됩니다',
#  '아니 QR기반 회사 KT가 왜 카드를 발행해요 카드는 또 하나카드네 하도인가 대기업들 대단하네요 신청하는데 뭔 개인정보를 이렇게나 많이 요구하는거임 개인정보 간소화 시대에',
#  '부산은행은 결제계좌로등록이안됨',
#  '카드도 발급받고 가입도 다 했는데 새로 앱 실행할때마다 인증된 폰번호와 현재 폰번호가 다릅니다 재인증하셔서 사용해주세요 이렇게 뜨는데 어떻게 해야하나요',
#  '가입하고 카드 신청해놓고 아직 사용은 안해 봤지만 어플은 정말 잘 만들었네요 박수 짝짝짝 이름도 정말 잘지었고  여러 기능 빼버리고 자주 이용하는 기능만 넣어서 깔끔하고 심플해서 좋네요 정말 앱은 대만족입니다 부산시민으로서 동백전 잘되길 바랍니다 그런데 앱 내 충전에서 계좌연결 은행이랑 카드신청 시 계좌연결 은행이랑 차이가 뭔가요',
#  '부산이 살아야 대한민국이 산다 부산지역경제를 위하여 똑똑한 소비',
#  '신청',
#  '개인 정보 입력만 회 했습니다 이 어이없는 오류 뭡니까',
#  '동백전 앱 들어갈려면 꼭세네번만에들어감프로그램 개발을 어떻게 한것인지짜증나네S 사용하고 있음 그리고 충전 금액을 만원도 넣어 놓아야지만원 입금할려면만원세번을 해야됨',
#  '아직 사용 경험이 없어 잘 모르겠습니다',
#  '시안성과 디자인도 뛰어나 사용이 간편하며 다양한 혜택이 있어 무조건 강추 합니다 동백전의 매력에 푹 빠져 살고 있읍니다',
#  '이벤트기간에 사용하면  캐시백 즉시 지급되구요 평상시엔 적립이 되어서 사용합니다',
#  '사용시 가입자에게 혜택이 매우 큰것 같습니다 적극 사용할께요',
#  '너무 조아요',
#  '사용편리해서 좋아요',
#  '캐시백 개꿀',
#  '네트워크오류로 계속안들어가 지는데 원래이런건가요 답답하네요',
#  '너무 편하고 좋아요',
#  '오늘 카드발급 후 앱을 깔아 하나은행 계좌를 등록했는데 결제상황 등 보유내역 등 전혀나오지않습니다알려주세요',
#  '응원할께요',
#  '동백전 설치후 사용해보니 새로운 세상이 열리네요',
#  '앱도 편리해서 사용도 좋고 캐시백도 좋네요굿',
#  '사용이 편리하고 앱 디자인도 멋집니다',
#  '혜택이 혜자스럽네요',
#  '바로바로 캐시백이 들어오니까 혜택이 더욱 크게 느껴지네요 굿입니다 bb',
#  '앱설치 후 사용해보니 App 디자인도 세련되었고 심플한것이 너무너무 마음에 들어요 많이들 사용 강추드립니다',
#  '동백전을 설치 후 사용해보니 새로운 세상이 열리네요 앞으로 카드사용은 자제하고 무조건 동백전을 이용할 예정입니다 앱 디자인도 깔끔하고 사용하기에 정말 편리합니다 저의 별점은 백점 만점에 백점',
#  '캐쉬백 좋아요',
#  '사용하기에 매우 편리 함',
#  '체크카드라서 좋아요 퍼센트 페이백 좋네요 프로모션기간이 길었으면 좋겠어요',
#  '좋아요 qr코드결제도 어서 됐으면 좋겠네요',
#  'Good',
#  '좋은것 같아요ᆢ',
#  '새마을금고 없어 카드발급 안돼요 괜히 충전하여 환불 해주세요 사용도 못 하는데',
#  '괜찮아요',
#  '캐시백도 바로 사용가능하고 매우만족',
#  '신나네요',
#  '카드만들다 사용 포기합니다',
#  '할인폭이 너무 크고 넘 편리해요 우리 부산시 상공인에게 도움된다니 더욱 좋네요',
#  '동백전으로 이용할 생각 입니다 사용하기 편리 합니다',
#  '만족',
#  '충전하려니깐 카카오뱅크가 없네요',
#  '본인명의폰 아닌사람은 가입을 못하네요 공인인증같은거나 다른 인증할수있는방법 더 생기게 해주세요',
#  '아주 유용한 앱 서비스네요 충전하구 카드 받아서 쓰는 게 좋구 쓰고나니 캐쉬백이 들어오구 디자인도 깔끔하구 기능도 심플하구 직관적입니다 만드시느라 고생하셨어요',
#  '안들어가지네요',
#  '어플에서 바로 결제가 됐으면 좋겠어요 카드 발급 받는 게 시간도 오래 걸리고 은행도 지정돼 있어서 불편하네요',
#  '매우 유용합니다 전 가족이 쓰고 있어요',
#  '너무 좋습니다😊',
#  '동백전을 사용해 보니 사용하면 할수록 차곡 차곡 적립되는 캐시백',
#  '동백전 휴대폰 단말기 살때도 캐시백 되나요',
#  '너무 어려워요 충전방식이라 많이 번거롭네요 폰결제 되는 쉬은 방법으로 업그레이드 부탁드립니다',
#  '문의 답변확인이 안되네요 호완성문제인지 다른어플은 정상적으로 작동하는데 이것만 먹통이에요',
#  '정말 사용하기 편하고 좋습니다',
#  '계좌등록이 계속 실패로 떠서 사용이 불가능함',
#  '깔끔하고 혜택 좋고',
#  '회원가입 할때 동의사항들전부선택햇는데도 다음으로 안넘어가지는데 혹시 오류인가요',
#  '치명적인 단점 지적합니다 환불정책 정말 불편하네요 전체 적립금에 이상 써야 나머지 금액 환불이 가능하게 해놓는 것은 너무 불편합니다 또 부분환불도 안되고 전체 환불만 된다니요 미리 현금을 충전을 했다가 현금이 필요해 일부 환불 받으려하면 환불이 안됩니다 환불제도 다시 검토하셔야 할 것 같아요 만원 넣고 만원 이상 쓸 때까지 환불이 안된다면 급 현금 필요한 사람들 어쩌란말인가요 이거 쓰시는 분들은 미리 돈 충전하면 환불받기 어려우니 쓸만큼만 조금씩 충전하셔야 할 것 같네요',
#  '회원가입할때 직장주소 검색하고 다시들어오니까 어플 끄지도 않았는데 처음부터 다시 입력해야 되네요 개선바랍니다',
#  '아니 계좌등록하려니 계속 계좌번호 오류라고하는데 왜그런거예요 숫자 잘못친줄알고 번은 더 넣어좟어여 심지어 개 계좌 다 안되는데 하 화가나네요',
#  '좋아요',
#  '교통카드버스나 지하철만 써도 캐시백 되나요',
#  '앱이 다운로드가 안되고 계속 로딩 중이네요 서버좀 늘려요',
#  '본인명의 핸펀만가능한거가요 아이핀이나 본인인증다른방법도 하게 해주세요 배우자나 부모명의인사람은 쓸수가없네요',
#  '들어가지지도 않구만 전화도 안받고 장난합니까',
#  '가맹점찾기가 너무 불편하네요 지도에서 찾기 기능이 있으면 훨씬 찾기 편할것 같아요',
#  '앱 접속시 계속 팅김 카드신청과정에서도 불안정함 주민번호 입력하면 자꾸 다른숫자로 인식함 카드신청부터 이래서 쓰다가 어떻게 관리하나라는 생각에 동백전 못쓰겟다싶네요',
#  '카드도 너무 예쁘고 앱도 깔끔해서 좋아요 편하게 잘 사용할 것 같네요 ',
#  '기능도 만족스럽고 검색해서 가맹점 찾을 수 있는거 너무 좋은거 같아요 그런데 카드발급신청했을때 진행도를 알 수가 없어서 불편하네요 동백전 어플에서 확인 할 수 있으면 좋겠어요 그리고 디이터로 접속하면 접속이 안되던데 왜그런가요',
#  '살인데 카드 발급받을때 주민등록증 번호를 작성하라는데 주민등록증이나 운전면허가 없는학생은 어떻하나요',
#  '최악임 깔고나서 본인인증문자아안옴',
#  '앱 실행이 안됩니다 네트워크 상태를 확인하라는 매세지만 뜨네요',
#  '가맹점 찾기 카테고리를 구별로 나누어 주셨으면 좋겠습니다 부터 시작하니까 해운대구 찾을려면 한참을 내려가야해서 불편한 부분이 있네요',
#  '정말 유용한 앱이네요',
#  '동백전가입시 LGU알뜰폰은 인증이 안돼 가입이 안됩니다 조정바랍니다',
#  '동백전 정말 좋아요 어디다가 리뷰를 써야될지 몰라서 여기 씁니다 우선 적립이 바로 이루어지는점이 좋고 원하는만큼 충전할 수 있어서 좋아요 가맹점 찾기 기능도 매우 유용합니다 또한 적립금을 사용하는거도 모드 on 만 해놓으면 되어서 너무 간단해요  포인트로 사용할때 조금 미안하거나 민망할때 있는데 동백전은 그럴일 전혀 없음  이거 사용 후에 동백전 사용 가능한 곳에 많이 방문하게 되는거같아요 지역화폐 취지에 딱 맞게 잘 사용하고 있습니다  앞으로도 적극 사용하고 주변에도 추천할게요 감사합니다 ',
#  '아직 써보지도 못했을 뿐더러 예기치못한 오류라며 앱 접속조차 안되네요 부산지역화폐가 나와서 기대했는데 실망스럽습니다',
#  '동백전 앱을 다운받아 회원가입 단계까진 잘되나 다음단계에서 처음단계로 되돌아가버려 회원가입이 되질 않아요 은행에 가봐도 별다른 방법이 없고 답답한 마음에 문의드립니다 동백전꼭 사용하고 싶어요 휴대폰은 lg v 안드로이드버전  커널버전 ',
#  '어제부터 통신중예기치않은 오류라고 앱사용이 불가합니다 무슨문제인거고 언제 정상화되나요',
#  '본인인증 방법이 폰인증 밖에 없나요 본인명의의 폰이 아닌 사람은 발급이 불가하나요',
#  '추천인은 뭘 써야하나요 한글은 안써지고 숫자는 써지는데 휴대폰번호를 쓰는것도 아닌것같고',
#  '좋아요',
#  '카드신청에 들어가서 카드선택후 신청하기누르면 일정기간 미사용으로 작업이중단됩니다요래떠요 삭제하고 다시 깔아도 그렇고뭘 신청할수가 없는데 우찌해야될까요',
#  '다운받았는데 카드신청이 안되네요 계좌등록하고 충전 후에 카드신청 가능한건가요 사용설명서가 있으면 더 좋을것 같아요',
#  '회원가입시 인증번호가 안옵니다 이틀째 가입중인데 인증번호가 계속 수신이 안되는데 뭐가 문제일까요',
#  '지금 카드사용 불가네요 통신오류 뜹니다 ',
#  '가맹점 검색에서 지역을 지정 후 검색 가능하도록 기능 추가 부탁 드립니다',
#  '네트워크 상태 원할하지 않습니다 계속 뜨네요 해결 하셔야 할듯합니다 속도 제한 데이터 Mbps  G 일떄는 실행도 안되네요 빨리 개선해야 하실듯요 데이터 속도가 느린 폰들은 아예 이용도 못하겠네요',
#  '좋아요',
#  '껐다가 켜면 다시 처음부터 인증해야 하는 치명적인 버그가 존재합니다 충전 하자마자 껐다가 다시 켰더니 또 문자인증 다시 하고 비밀번호 새로 설정해야 합니다 벌써 번째입니다 들어갈때마다 인증된 폰번호와 현재 폰번호가 일치하지 않습니다 번호 변경시 초기화하기 메뉴 선택후 재인증하셔서 사용해주세요 종료 초기화하기라는 창이 뜨면서 다시 처음부터 인증해야 들어가지고 다시 인증받고 계좌 연결해서 돈 충전후 껐다가 다시 켜면 또 저 창이 뜨면서 또 처음부터 인증을 해야 합니다 아니면 차라리 하나은행 체크카드를 주세요 왜 하나은행 계좌 만들었는데 하나은행 체크카드를 안주고 동백전 체크카드만 주나요 이래서야 돈을 쓸 수가 없잖아요 충전을 해야 돈을 쓸 수 있는데 충전하러 들어갈 때마다 처음부터 인증을 해야 하면 누가 씁니까 사용중인 스마트폰은 KT 화웨이 비와이입니다 국민은행은 유심 인식 안되도 공인인증서로 로그인이 되는데 동백전은 그런것도 없나요',
#  '친구가 캐시 바로 들어오더라고 추천해줌',
#  '지역경제에 기여하면서 캐쉬백도 가능한 동백전이 있으니 더이상의 카드는 필요없네요',
#  '좋아여',
#  '최고',
#  '굿',
#  '좋아요',
#  '세금공제 프로',
#  '최고',
#  '부산의 주유소에서 사용이 안된다하여 난감한 경험있습니다 사용가능하도록 지원 배려 바랍니다 감사합니다',
#  '쓰자마자 깨시가 로 바로 들어오니깐 완전짱입니다',
#  '슈퍼에서 우유를  번 샀읍니다 씩 적립 되여 기분 좋았읍니다 택시는 개인 도 일반 택시도 안되더라고요 언제쯤 택시 될가요',
#  '동백전 편하고 좋아요',
#  '실물카드받았는데 어플엔 등록안되어있어요',
#  '지역 자영업에 도움이 됩니다',
#  '소상공인과 시민들에게 좋은 제도네요',
#  '걸제불가능한 곳에 대한 정보 제공이 필요함',
#  '너무 좋아요',
#  '케시포인트 너무 좋습니다',
#  '절약에 도움이됨',
#  '적립 대박',
#  '넘좋아요',
#  '멋져요',
#  '업데이트 실행 안되네요 삭제 후 재설치도 안됨',
#  '캐시백 개꿀',
#  '최고입니다',
#  '굿굿',
#  '깔고 위치확인동의 같은 것들 모두 동의 누른다음에 계속 흰화면이 뜨고 한 분 기다리면 네트워크 상태 확인하라고 하네요 실행이안되서 가입도 못했어요',
#  '동백전 어플들어가니깐 악성코드를탐지햇다고뜨는데 왜그런거에요',
#  '편해요',
#  '완전 좋아요',
#  '카드 수령지가 자택 외에 설정이 안되네요 리뷰 보니 형식적인 답변 뿐이고 활성화 되려면 업체부터 다시 바꿔야겟네요 시에 연락 할 예정입니다',
#  '신통방통합니다',
#  '정말 좋습니다 굿',
#  '구웃',
#  '사용이 편하네요동백전 지점 정보가 좀더 명확했음 하네요',
#  '가맹점이 어디더라 생각 안하고 일단 들어가서 결재하면 어지간하면 가맹점이네요  프로 캐시백 이벤트 오래오래 했음 좋겠어요 월까지',
#  '동백전 밴드앱 악성코드로 인식합니다 확인바랍니다',
#  '무리 없음',
#  '네이버 밴드 어플을 악성코드로 인식하네요 밴드어플을 삭제하고 어플설치후 밴드를 다시 설치하니 다시 악성코드로 인식 밴드를 사용해야하는데 어찌해야할지',
#  '아',
#  '앱 시작하면 악성코드가 발견되었다면서 창이 뜨는데 이거 해킹당한거 아닌가요 불안해서 앱을 못열겠고 이미 내 폰에 악성코드가 심어진거 아닌지 불안합니다',
#  '굿',
#  '카드는 언제받을 수 있나요',
#  '사용처 제한으로 불편함이 많음 특히 재래시장에는 카드계산기 없는 상점이 많아 더 불편함 그리고 업데이트 하라면서 며칠째 업데이트 했는데도 아직도 설치 중와 이런다요 아예 업데이트가 안되네요',
#  '앱 업로드이후 자꾸 재시작해야 하는 버그가 계속발생 합니다 업로드전에는 전혀 문제 없었으나 업로드이후 한번에 연결이 되지 않고 여러번 해야 겨우 연결됩니다 앱 실행하면 첫번째 화면나오다 꺼지는 현상이며 네트웍 연결이 안되었다고 하기도 하고 여러번 실행해야 겨우 겨우 됩니다 와이파이나 네트웍장비 바로 앞 및 LG 통신장비 바로 앞에서도 겨우 겨우 연결됩니다 다른 인터넷이나 연결속도 측정해도 전혀 문제 없습니다 핸드폰 기종은 VLG 모델입니다 리뷰에 보면 여러사람들이 문제제기를 합니다 빠른조치 부탁해요',
#  '동백전의 의도는 너무 좋으나 앱이 너무 안 좋습니다 동백전이 활성화하지 못하게 된다면 앱이 가장 큰 비율을 차지할것 같군요 계좌등록하려고 ARS전화하고오면 다시 첫화면으로 돌아갑니다 어찌저찌 통과를 해도 제계좌에 원이체 후 인증숫자를 쓰라는데 그 확인하기위한 타행어플이 같은 휴대폰에 있는데 확인하고오면 다시 첫화면 처음부터 다시 해야합니다 결국 번 시도했다고 오늘 더 못한다는군요',
#  '동백전회원가입하려는데 현재폰이 부모님명의로 되어있는데 휴대폰인증말고 다른방법으로 가입할수는 없나요',
#  '편하게 잘 사용하고 있어요',
#  '와이파이 연결시에는 어플 접속이 잘됩니다 하지만 데이터 사용시 접속이 잘 안됩니다 데이터 잔여량도 많이 있고 통신상태도 양호한 지역에서도 마찬가지입니다 기기는 skt 갤럭시s 안드로이드 파이버전입니다',
#  '음식점 가맹점되는곳에서 카드사용시 배달의 민족이나 배달대행어플을 통해서 계산해도 캐쉬백이 가능한가요',
#  '잘안됨',
#  '휴대폰 명의가 틀리는데 어떻게 가입안 안될까요',
#  '인증문자 자체가 안오는데 뭘 어떻게 카드발급 받으라는거죠 뭔가 제대로 이용할수 있도록 시스템을 만들어넣고 홍보를 해야지 시간낭비만 하고 있네요',
#  '인증번호 발송됐다는데인번이 안와서',
#  '페이코랑 하나머니가 추가되어 피킹률 퍼센트를 넘길수있는 갓혜자카드',
#  '굿',
#  '가맹점 찾기를 통해 나오는 가맹점이 년전쯤에 그 자리에 있던걸로 현재는 없어졌는데도 나오네요',
#  '캐쉬백 이벤트기간 퍼 장난 아니네요 좀 있음 퍼겠지만 대만족중 입니다',
#  '동백전어플을깔고난후에 회원가입 약관선택 후 다음 화면으로 넘어가지지않고 네트워크가원활하지않다고만 표기됩니다 재설치 후도 동일하며 네트워크 다른 앱들은 다잘되는데 동백전만이렇습니다',
#  '페이백 굿',
#  '아직 사용하기전이나 왜 항상 국가사업이 들어간 금융앱이나 국가지자체에서 실시하는 사업들은 돈은돈대로 쓰고 서비스는 형편없는지 모르겠습니다 부산시에서 광고 많이하고 혜택많다기에 받았는데 댓글들보니 혹시나했는데 역시나네요',
#  '아쉽지만 쓰는데 불편함은 없다',
#  '인증번호가 안오네요 앱에 문제가 있나요',
#  '계속 통신 오류가 뜨네요 이러면 동백전 사용하기 불편해서 사용이 안될 것 같은데요',
#  '앱이문제네요 성질돋구네요',
#  '가입은 수월히 카드신청시 은행계좌 연결하여 다시 키려면 다시 처음부터 충전계좌 연결해보려 입금명을 보려 모바일뱅킹 열어보고 다시 넘어오면 또 꺼집니다 어떻해야하죠 결론  가입 카드신청까지는 했으나 충전계좌연결은 못하여 포기한 상태 계좌앱을 열고 다시 넘어오면 다시 동백전 처음 상태로 돌아옴 해결방법을 알려주세요',
#  '다운로드가안되여',
#  '어플실행시 정상적인OS가 아니라서 이용할수가 없다고 메세지가 나옵니다 엘지V이며 안드로이드버전입니다 확인좀 부탁드립니다',
#  '어제부터 와이파이해도 안해도 서버통신문제로 연결안된다고 뜨네요',
#  '본인인증이 휴대폰말고 아이핀이나 공인인증도 추가되었음 합니다',
#  '다운이안받아지네요',
#  '이벤기간이라 캐시백 비율이 높아 내가 내는 돈은 줄었음 그러나 이 카드를 아예 안받는 유명한 직영가맹점들 대형마트 등이 많음 부산카드라 시외에서는 못씀 근데 캐시백 되는 비용은 누가 부담하는 것인가 부산시 세금',
#  '내게 만족을 주는 그런 카드면서 행복감을 주는 동백전',
#  '어플이 실행안되요 통신중 오류가 발생했다고 어플 삭제후 다시 하여도 그대로 입니다 충전을 할수가 없네요',
#  '업데이트 이후에 뭘사러 갔더니 분명 해당점포가 캐쉬백대상점포인걸로 아는데 캐쉬백이 바로 안들어와서 다른카드로 결제했습니다 그런데 바로 취소내역도 안뜨고 이거 어플 뭐하는 겁니까 돈과 연관된 어플이면 좀 제대로 돌아가야하는거 아닙니까 정말 업데이트 이후로 실망입니다',
#  '카드신청오류 계속뜨네요',
#  '하이마트에서 사용가능한다고 나오나 사용이되지 않습니다 확인부탁드릴게요',
#  '네트워크 연결이 원활하지 않습니다 접속오류 다른 어플과 인터넷은 잘 사용되는 중인데 동백전 어플만 사용하면 이 문구가 나오네요 접속이 되어도 예기치 못한 경우문구가 나오며 무한 로딩만 반복되고 동백전 충전을 하려고 몇번이나 어플을 접속해야하는지 모르겠네요 고객센터로 전화를 걸어도 모든 상담원이 통화중입니다 무한 반복 cs부서가 있는건 맞죠 좋은 취지에서 만든 지역화페인데 사용도 제대로 못하고 참 좋네요 별점 점이 있다면 점 주고싶습니다',
#  '계속 렉걸리고 네트워크접속이 안된다고하고 예기치못한오류가 생겼다며 너무 잘 안됩니다',
#  '켤때마다 통신이어쩌고하면서 종료되고 다시들어가야 됩니다 이번에는 번이나 튕기고 들어가지네요',
#  '동백전 앱 사용시 카드충전금액이 모자라거나 안되어 있으면 연결계좌에서 빠져나가잖아요 근데 연결계좌에서 나가니 캐시백이 안되는데 이런 시스템이 맞나요 어떻게 되는건지 정보가 없어서요',
#  '카드신청이 안됩니다 눌러도 반응이없어요',
#  '카드신청시 주민번호 입력후 다음화면으로 넘어가지않습니다 업데이트해주세요',
#  '정말 좋은 카드라서 잘 사용하고 있는데 앱에 문제가 있는지 실행하려고 앱을 누르면 자꾸 튕깁니다 여러번 실행해야 앱에 들어가집니다 확인 하시고 고쳐주시기 바랍니다',
#  '인증된 번홓하 현재 번호가 달라서 계속 초기화 하라고 뜨는데 어떻게 해결해야 되나요',
#  '너무좋은 카드인데 앱 오류가 너무 심해서 잔액 확인이 안되는점 빨리 개선 되었음 좋겠습니다 그리고 와이파이 꺼지면 네트워크 오류가 나서 충전 해야 할때 상당히 곤란합니다',
#  '휴대폰 본인인증 문자가 분뒤에 전송되어서 가입이 불가능합니다 인증시스템에 문제가 있는 거 같습니다',
#  '아빠 폰에도 동백전 깔아드려서 쓰는데 이상하게 동백전만 켯다 끄면 문자에 들어갈 수가 없네요 다른 어플들 다 테스트 해봤는데 동백전 어플이 문제예요 해결방법 없나요',
#  '실행도 안되는구만 별 하나도 아까워',
#  '정상적인 os가 아니면 서비스 이용이 안된다면서 앱실행이 안됩니다 고객센터 전화연결도 안되구요 오류인가요',
#  '연일째 계속 앱도운로드중 아직도 다운중이네요',
#  '회원가입 과정중 인증번호 전송 버튼을 아무리 눌러도 전송이 되지 않음',
#  '왜 두번 터치해야 정상적으로 어플이 실행되는지 모르겠네요 한번 실행하면 보안프로그램 실행되명서 종료되고 두번 실행해야 정상적으로 화면이 뜨네요 이거 해결해 주세요',
#  '캐시백 현재 프로 대박 ',
#  '너무좋네요 근데홍보가 이제되기시작했는지 지금만든사람이 많아요 프로캐시백 월까지 연장하면안되사요',
#  '탭으론 접속조차 안되네요 저 처럼 폰은 g폰이고 탭으로 인터넷하는 사람은 어떻게 충전하죠 발급 후 사용 못하고 잇습니다 빠른 개선 부탁드립니다',
#  '잘사용하고 있습니다 근데 어플을 실행시키면 왜 첫번째는 실행되다가 닫기고 두번째 실행시키면 되는걸까요 그거 말고는 간단해게 사용할수 있어서 좋아요',
#  '동백전앱이 안됨',
#  '일정 시간 미사용으로 작업이 중단 되었습니다 라고 계속 떠는데 어떻게 하면 되나요 삭제하고 다시 설치해도 마찬가지 입니다',
#  '혹시 카드 수령지를 자택에서 직장으로 변경되지 않나요 이것땜에 가입 못하고 있읍니다',
#  '굿 좋아용',
#  '어플 다운 불가',
#  '다 좋은데 연결계좌 은행에 카카오뱅크가 없어서 불편합니다 연결계좌은행은 좀 다양해져도 좋을것 같아서 별하나 뺐습니다',
#  '월별 사용합계를 자동으로 볼수 있으면 더 좋을듯해요',
#  '좋아요',
#  '체크카드도 캐시백주시지',
#  '겁나 좋음 짱',
#  '좋아요',
#  '캐쉬백 짱 지역 발전 짱',
#  '잘 이용됩니다 굿',
#  '개편함',
#  '감사합니다',
#  '굿',
#  '매우 좋음',
#  '최곱니다',
#  '부산 동백전이 엄청 편리하고 캐시백이  되니 얼마나 좋습니까 월이후에도 년말까지 쭈욱 했으면 좋겠습니다',
#  '프로 꿀',
#  '추천합니다',
#  '좋아요',
#  '굿',
#  '폰결제 쫌 되겠죠',
#  '어느카드보다 혜택 최고입니다',
#  '사용한금액에 포이트도 받고 너무 좋아요굿',
#  '좋아요',
#  '동백전 사용가능 업체라고 검색하고 갔는데 사용되지 않았습니다 완전 비추',
#  '굿',
#  '좋아요',
#  '좋아요',
#  '좋아요',
#  '공인인증서로도 로그인가능하게해주세요 휴대폰명의가 다른게 너무불편 제발요 아님 폰번호라도 수정가능하게해줘요',
#  '미적용 매장에서도 체크 카드 겸용이용 할수 있으면 더욱 좋겠군요',
#  '감사합니다',
#  '사업자용카드로 등록 가능한가요',
#  '최고 입니다',
#  '좋아요',
#  '따봉',
#  '캐시적립이 정말대박이네요',
#  '최고의지역화폐',
#  '로그인후 사용하게 해주세요',
#  '좋아요',
#  '사용 편하고 좋아요',
#  '좋아요',
#  '아주만족합니다',
#  '이렇게 좋을 수 가 없습니다 할인 너무 좋습니다',
#  '너무좋아요 하지만 택시에서 카드결제시 번중 번만 승인되서 다른카드로해요',
#  '충전금액 입력가능하게 합시다',
#  '편리하고 좋아요 다만 잔액부족시 바로 카드결제 되는점은 개선 바랍니다',
#  '전월사용실적이 연간으로 있으면 더편할것같아요 동백전 너무 좋습니다',
#  '좋아요 계속  해주셍ᆢ',
#  '편리합니다 그러나 Pay 앱이나 잔액을 표시하면 좋을듯합니다',
#  '넘 좋아요',
#  '캐시백 모으는 재미가 쏠쏠하네요♡♡',
#  '좋아요🤗 동백전 짱',
#  '개꿀입니다 대신 여기가 사용가능한곳결제는 웬만한곳에서 가능하나 캐쉬백이 되는곳 인지 아닌지 아는게 약간불편한점이지만 쓰시기전에 사용법은 읽어보고 쓰시면 크게 불편하지않아요 퍼 할인 기간이 끝나는게 슬퍼요',
#  '사용하기 아주 편리하게 잘만들었음',
#  '좋은데 에러가 너무 많이 뜹니다',
#  '좋아요',
#  '도대체 고객센터는 왜있는겁니까 에 문의 했는데 일이 지났는데도 보지도않을꺼면 아예 없애세요전화연결도 안되고 도대체 일은 하는거임',
#  '너무 좋아요그리고월달까지 이벤 연장도 해주셔서 감사합니다',
#  '캐쉬백 이만큼 되는 카드는 동백전 뿐',
#  '바로 캐쉬백되니 좋아요',
#  '충전금액 환불이 자유로울거라 생각하고 카드발급 어플설치를 하고 충전을 했었는데 급히 보낼 곳이 있어서 환불을 했어야 됬기에 환불 버튼을 눌렀는데 아무것도 못하더라구요 그래서 밑에 쓰인 글을 읽어보니까 전액 환불은 충전후 일 이내로 문의하여야 되고 조금이라도 사용한 경우에는 충전금액의 퍼센트를 사용하여야 남은 금액을 수수료 없이 환불이 가능하다고 쓰여있더라구요그래서 급한 마음에 고객센터에 분을 붙잡고 전화를 한 끝에 겨우 통화가 연결되서 환불을 받았습니다 환불은 당일이 아닌 다음날 오전에 환불이 된다고 하셨구 오전에 바로 들어와서 받았습니다 캐시백 받으려다 보내야될 돈을 못보낼 뻔 했어요 환불정책이 어렵고 복잡한데다가 고객센터 문의가 많은지 연결도 잘 안되서 충전하고 급히 보낼 곳이 있을때 유의해야 겠더라구요 잘 사용하시는분은 계속 사용하시겠지만 저는 이렇게 사용할거면 못쓰겠어서 부산 지역 화폐가 생겨서 좋았지만',
#  '굿요',
#  '좋아요',
#  '부산에선 동백전 좋아요',
#  '온라인은 사용이 안되서 아쉬워요',
#  ' 캐시백이 월까지라서 약간 아쉬웠는데 월까지 연장이라 좋아용 꿀이 떨어지는 동백전 너무 좋앙',
#  '동백전 사용시 와이파이가터지는 곳에서도 모바일 데이터를 켜지 않으면 사용이 안되는데 와이파이만으로도 사용할수 있게는 안되나요',
#  '캐쉬백넘좋아요',
#  'Good',
#  '사용하기 쉬움',
#  '덕분에 잘 사용하고 있습니다 업데이트 되면서 충전하기가 더 어렵게 되었네요 이전처럼 큰 네모 안의 금액이면 좋을텐데 작은 네모안의 숫자가 잘 보이질 않아 불편합니다 그리고 기간별 총합 사용 금액이 나왔으면 정말 좋을것같습니다 수정 좀 부탁드립니다',
#  '좋아요♡',
#  '편하게 잘쓰고있는데 월도  캐시백해준다니 넘 좋아요 년 가즈아',
#  '굳',
#  '맘에들어요',
#  '좋음',
#  '좋아요',
#  '충전금액이 얼마나 남았는지 알려주면 좋겠어요',
#  '진짜진짜진짜루 좋아영',
#  '없음',
#  '앱너무좋아요',
#  '완전좋음',
#  '너무좋아요 보너스 받는 느낌입니다',
#  '정말좋네요',
#  '잘 사용하고 있어요 프로 적립 오 유익해요',
#  '완전굿입니다',
#  '대박좋아야',
#  '굿',
#  '너무 잘쓰고 있어요  사용방법이 간단해서 좋네요',
#  '편리함',
#  '굿',
#  '아주 유용합니다 포인트가 금방 쌓여요',
#  '잘사용하고있습니다',
#  '좋아요',
#  '어플도 보기 편하고 실시간 캐쉬백 확인되니 너무 잘 쓰고있어요 가맹점 찾기 힘들다는 분들 그냥 가셔서 동백전 내세요 그럼 되는가능한 곳은 해주시고 안되는곳은 안된다 하십니다 그런데 충전금액보다 더 큰 금액을 결제하면 차액만 통장에서 출금되는게 아니라 온전히 통장에서만 출금이 되던데 이부분은 개선이 안되나요 두달째 잔액이 조금씩 남게되니 싫어요',
#  '카드신청 일주일이 지나도 오지않음 배송업체는 전화도 받지않음 언제 오려나 차라리 하나은행가서 신청하는게 정신적으로 훨씬 나아요 정말 언제오나요 일 일 일 걸리나',
#  '최고입니다 학령기 자녀를 둔 주부에게는 선물같은 카드이네요',
#  '혜택업소가 좀더 많았으면 해요 프로혜택 너무좋아요 다같이 윈윈',
#  '굿',
#  '코로나 여파로 사용실적이 적은데 월까지  혜택을 연장 해주면 좋겠습니다',
#  '쓸만합니ㅣ다',
#  'Good',
#  '사용하기 편리해요',
#  '동백전 너무 좋아요',
#  '아주좋아요',
#  '좋아요 부산 화이팅',
#  '갠차늠',
#  '지역경제도 살리고 우리집에도 도움되는 최고 앱',
#  '좋아요',
#  '너무 편하고 좋습니다 혜택도 많고',
#  '업데이트가 안되요',
#  '프로충전너무좋아요',
#  '오거돈 시장님 감사합니다 ',
#  '감사합니다',
#  '좋고 편해요',
#  '좋음',
#  '택시가 연동이안되 아쉽네요',
#  '굳굳',
#  '아직은 완벽한 어플아닌듯',
#  '감사',
#  '너무좋아요',
#  '좋네요',
#  '긋입니다',
#  '쏙쏙 되돌아 오는 재미',
#  '좋아요',
#  '아니 충전하려 들어가면 계속 튕기고 지우고 깔아도 튕기는데 이러면 그냥 쓰지말라는 소리 아닌가요',
#  '무조건 조아여',
#  '좋아요',
#  '너무좋습니다',
#  '개꿀',
#  '굿',
#  '아직 동백전을 모르는사람이많은듯 더욱더 홍보가 필요합니다',
#  '잘쓰고있습니다 한가지 요청드리고 싶은건 월별 또는 일정기간별 사용금액을 조회했을때 총 사용금액이 뜨면 좋겠네요 각 건수별 금액은 뜨는데 총 사용금액을 알고자할땐 일일이 더해야하는 불편함이 잇다보니 그것만 개선요청드려요',
#  '개꿀',
#  '포인트적립 정말 최곱니다',
#  '알림이 빨라요',
#  '계속 통신중 오류 뜨는건 뭐여',
#  '업데이트안됨',
#  '회원가입조차 되질않아요 문자인증전까지 입력은 되는데 인증문자가 전혀 오질않네요 SKT는 사용이 안되나요 부산은행에서도 정확히 모르더군요',
#  '프로 할인이 연장되어 기분이 좋아서 리뷰씀',
#  '아주 유용하게 쓸것 같네요',
#  '업데이트가 너무 안되네요',
#  '말이 필요없음 최고',
#  '충전 환불 제도도 불편하고 상담원 연결 너무 안됩니다 그리고 쓸 금액만 충전해서 그거 전부 사용했는데 캐시백이 안됬더라구요 보니까 금액이 모자라서 연결된 카드로 빠져나갔다던데 왜 그렇게 되는건가요 쓸 금액만 충전해서 충전한 그대로 다 썼는데 왜 카드 전환이 된거죠 제대로된 설명도 없고 하나부터 열까지 마음에 안듭니다',
#  '가맹점도 많고 좋아요',
#  '좋아요',
#  '조금번잡스러움',
#  '좋아요',
#  '다들 좋은거 인정',
#  '대형마트 사용만 가능하면 우리나라 최고의 카드혜택이라 믿어 의심치 않습니다',
#  '어떤 vvip 신용카드가  할인을 해주겠나요 이보다 좋을 순 없어요',
#  '충전 할려니까 옳바르지 않는 계좌라고 하면서 안되네요',
#  '왜 자꾸 다운로드대기중인가요',
#  '계속 오류가 떠요',
#  '앱에 접속안되는 날이 왜이리많아요 접속할때마다 는 접속불가',
#  '업데이트 왜이리 안돼요',
#  '동백전 사용하기 좋아요 그렇지만 안드로이드 버전이 낮아 동백전 어플 자체가 아예 설치 안되는 경우가 있어요 부산지역화폐이고 어플을 통해서만 가입이 가능한 부분을 감안한다면 버전이 낮은 폰의 경우에도 동백전 어플을 설치할 수 있게 조정해주시면 더 좋을 것 같아요',
#  '너무 조아요',
#  '포인트많이 쌓여서 좋아요',
#  '본인인증 단계에서 휴대폰 인증번호 발송이 안되고 카드번호로 인증하려고 해도 번호오류라고 계속뜨네요 카드신청을 할 수가 없네요',
#  '기간 설정해서 사용내역을 볼 때 합계도 나왔으면 좋겠어요',
#  '업데이트일동안 안되고 앱실행이안되여',
#  '하루종일 앱이 실행이 안되요',
#  '가입하려고 폰인증번호 전송누르면 예기치못한문제발생 했다고 진행이 안됩니다 수십번을 해봐도 똑같네요 머가 문제인가요',
#  '팝업창 아랫부분 닫기인지 다시보지않기 인지 선택하는 창이 화면에 잘려서 누를수가 없어요 제발 팝업창 크기 좀 조절해주세요',
#  '간단 명료하게 잘 꾸며져 있슴다 적절히 사용하여 부산 경제에 도움이 되도록 주위 분들께 홍보 많이 많이 하세요',
#  '가맹점 확인할때 카테고리가 나눠져있긴 하지만 그 속에서 가게 이름을 일일이 다 보면서 즐겨찾기 하니까 많이 불편해요 가게이름을 봐도 어딘지 모르겠어서 지도 클릭해야되고 번거롭네요 구글맵처럼 사용하기 편한 지도로 가맹점 표시를 해주세요 부산 어디를 초행길로 가더라도 지도에 가맹점이 바로 떠서 확인할 수 있으면 훨씬 편리할 것 같아요',
#  '지금 설치가 안되요 ',
#  '잘쓰고 있습니다 충전을 해야하는데 업데이트를 요구하는데 설치는 계속 대기중이네요 이제 잔액이 없어요 얼른쓰고싶어요',
#  '동백전 잔액이랑 캐시백 바로 업데이트되니 좋아요',
#  '카드가 도착했다해서 우편함에 놔둬달라했는데 집에 갔는데 없더라구요 그래서 재발급을 받고싶은데 찾아봐도 재발급 받는데가 없더라구요 어떻게 재발급을 받죠',
#  '안열리네요',
#  '어플이 와이파이 연결될때만 실행 됩니다 데이터를 켜면  네트워크 상태가 원활하지 않습니다 연결상태를 확인후 다시 시도해주세요라고 뜨는데 고객센터는 연결이 잘 안되서요 어플설정을 들여다봐도 안될 이유를 못찾겠어요 그것빼고는 다른 건 정말 좋아요 캐시백도 바로바로 되고 캐시백 도 크고 대만족입니다',
#  '동백전카드 가입에서 비밀번호 실패하고 나서는 접속하기가 힘들어요 충전시킬려고 하는데 본인인증이 안 됩니다',
#  '가입이 안됩니다인증이 안되요발급 받아보려고 어플깔고 휴대폰 인증하는거 아무리 눌러도 안되니 신경질나서 쓰겠나싶어요나만 안되는거야짜증나요',
#  '이음카드에 비하면 너무 기능도 없고 카드 개 밖에 신청도 안되고 부족한점이 너무 많아요',
#  'g폰 사용하고 있는데 동백전 발급받을 수 있는 방법은 없나요 예를들면 아이패드나 갤럭시탭 또는 공폰 이용하여 앱 다운받은 다음 사용할 수도 있나요',
#  '동백전은 좋은데 어플이 왜이래요 결제가 두번 된거 같아 확인하려고 하니 네트워크 불량이라고 연결이 안되요 또해도 안되요 계속해도 안되요 나중에 집에가서 결제 두번된거 확인하고 다시 돌아가서 결제 취소하고 돌아왔어요 제발 쫌 어플 관리 좀 잘해주세요',
#  '계좌도 다 안맞다그러고 신분증 발급일자도 틀리다고그러고 그냥 발급이 이제 안되는건가 몇번을 확인해도 틀린게읍는디',
#  '잘 사용하고 있습니다 아쉬운건 잔액정보인데 사용 전 금액 상품권 원 캐시뱁 원 합계  원 사용 금액 상품권 원 캐시백 원 합계 원 잔액 상품권  원 캐시백 원 합계  원 이런식으로 사용 전 후 정보를 제공해주셨으면 합니다',
#  '동백전은 너무좋은데 간혹오류로 결제가안될때가있고 어플들어가는거도 팅길때가있어요 유용하게잘쓰고있어요',
#  '폰마다 차이가있는지 제폰에서는 와이파이 아니면 앱에 접속이 거의 안됩니다A 길거리에서 갑자기 충전해야할때 또는 가맹점확인해야할때 LTE면 네트워크 상태가 원활하지 않다며 바로 꺼집니다 확인이 불가능해요 길 한복판에서 와이파이 잡는게 쉬운것도 아닌데 너무너무너무 불편하고 급할때는 정말 욕나와요 어제도 앱 번 출구컷 당하고 물건 못사고 나왔습니다 개선 안됩니까',
#  '전산오류로 결제가 두번 됐는데 충전한 돈으로 결제한 첫번째 결제를 취소시키고 두번째 결제는 잔액이 없다고 통장에서 돈빼감 캐시백 포인트도 회수 거기다 어플에다 문의했는데 시간동안 답변없음',
#  '아직 모름',
#  '인증번호가 안오는데 어떻게 해야될까요',
#  '데이터 인식을 못하나봐요 깔아도 쓸수가없네요',
#  '좋아요',
#  '열때마다 다시 종료해야되네요 어플 제대로 좀 만드세요',
#  '카드발급해서 사용중인데 계속 카드등록발급하라고 어플에 뜨네요카드등록 할수있게 해주세요',
#  '앱이 자주 버벅 거립니다 터치도 안되고 먹통이 되요',
#  '최고에요 계속되는  적립혜택도 좋고 UI도 신경써서 만든 것 같아요 편리합니다',
#  '좋아요',
#  '돈만빠져나가고 충전이안됨 아직은 많이 부족한듯',
#  '열리지가않아요',
#  '네트워크가 원활하지 않아 안된다고 뜨네요 그런데 옆에 남편은 확인이 잘되는데 뭐가 문제인가요 통신세기의 문제도 아닌거 같은데핸드폰 버전에 따라 차이가 나는건가요 확인이 안되니 답답하네요',
#  '결제도 안되고 잔액확인도안됩니다 계속 오류뜨는데 왜이런건가요',
#  '급하게 충전 해야 할 때 안 됩니다 어플도 통신사도 케이티라 뭐가 쓰레긴지는 알 수 없는 노릇',
#  '네트워크 오류라면서 어플 접속이 안될뿐더러 오늘 실 결제한 금액 캐시백도 안됐네요뭐지요',
#  '인터넷 접속이 안될때가 더 많습니다',
#  '뭐가자꾸 접속이안된대 짜증나게',
#  '어플에 접속이 안되는데 어떻게 쓰라는거에요 아이폰에서 안드로이드로 넘어왓는데 아이폰에선 문제없이 잘썼는데 안드로이드로 넘어오니 왜이래요 와이파이읾대도 네트워크접속 안된다그러고 데이터일때도 안된다 그러고 가맹점찾기나 확인하려고 하는데 안들어가지면 어떻게쓰라는거에요 아 진짜 욕나와요 개선좀 해주세요 네트워크 문제 얘기하는 사람이 한둘도 아니구만 도대체 괘 안고쳐지는거에요',
#  '명불허전 공무원 작품 접속장애 엄청 심합니다',
#  '혜택은 좋은데 어플 동작이 너무 느림 이 가게가 해당되는지 확인하려고 어플켜다가 포기하는 경우가 많을정도로 구동속도가 너무 느림',
#  '신청을해서 등록하려는데 자꾸 통신상연결이안된다하고 네트워크문제라고뜨네요 다른인터넷어플들은다잘되는데 왜그런지모르겠네요',
#  '제 폰이 이상한건 가요 데이터로는 동백전이 안들어가지고 돈 충전도 안됩니다 길에서 충전해서 급히 쓸려고할때 사용도 못하고 계속 튕겨져 나오는데 확인해봐주세요',
#  '오늘 결제도 안되고 어플실행도 안되요',
#  '어휴 어플관리 진짜 최악이다',
#  '진짜 넘하시네요 아니 뭐 접속도 안되고 맨날천날 통신이 불안하다고 하면 시에서 일하시는 분들이 국민이 내는 세금 쳐받아먹고 이런거 하나 제대로 못하시면 안되죠',
#  '어플이 연결이되야지 충전을할껀데 어제도오후내내 안되서 결국딴카드사용햇네요 네트워크오류로인하여 실행안된다고떠서 내폰이이상한가하고 다른폰으로연결해도 똑같던데 어플연결좀 잘되게해주세요 가게에서 동백전카드만결재안될때도잇던데요 네트워크오류나서  기능은좋은데 사용이잘안되면 무용지물아입니까 부탁드립니다',
#  '연결이잘안되요네트워크 상태라면서뜨지를않아요',
#  '가맹점 검색할때 현재 위치가 아닌 처음 접속했던 위치로 계속 검색되는듯요',
#  '잘 사용하고 있습니다 월별 이용금액합계 좀 보이게 개선해주세요 사용금액 합계 내려면 계산기 뚜드려야되고 불편하네요',
#  '설치하고 카드 신청하는데 폰으로 인증번호 확인차 문자앱 실행해서 보고 다시 동백전앱에 인증번호 넣을려고 클릭하면 재시작 되어서 다시 휴대폰 번호 넣어라함 몇번째 다시하다가 성질나서 카드신청 안함 먼 앱을 이따위로 만들었는지',
#  '접속이 잘되다가 갑자기 안되네여 다른분들말처럼 데이터 와이파이 구분없이 네트워크 장애 오류 하면서 안되네셔 이거 사용하는 사람이 무지하게 많은데 빠른 개선 요해요 빠른 개선 감사드립니다 답변까지 수고많으십니다',
#  '좋아요',
#  '마이너스 없어서 별 개만 줌 카드신청하고 일주일 만에 받았는데 어플에서 충전이 안된다 올바르지 않은 계좌라네  하아 오프라인 충전은 또 부산은행이나 하나은행가서 하라네 허 이걸 쓰라고 만든건지 플라스틱 쓰레기를 받은건지 가입만 시켜놓고 대책이 없니  모두 내 명의 맞고요 신한 국민 계좌로 등록 시도 했었지만 올바르지 않은 계좌라고 해서 앱평가에 글 적은거임 이런거면 어플 문제 아님',
#  '어플 접속이 자꾸 튕겨요 캐쉬백도 제대로 들어오지않고 부족하게 들어오고 고객센터 전화연결도 몇번이나 안돼서 아직 문제점을 물어보지도 못했습니다',
#  '다른어플은 실행이되는데 이어플은 lte인데도 왜 실행이 안되고 와이파이껴야 그나마 접속이 되는건가요 똑같은답변만 달지말고 업데이트를 해서 고쳐주세요 저는 갤럭시s엣지입니다',
#  '문의글남겨도답변도안하고점심이라고일안하고가맹점이라고버젓이되잇는데사장은동백전가입안되잇다고사기치질않나충전도천이상만되고에라이때려쳐라뚜레쥬르는동백전사용방법도모르고그럼서홍보만함다냐별반개도아깝다',
#  '넘좋아요♡',
#  '앱을 실행할 때마다 아래와 같이 계속 에러가 뜨면서 초기화 되요   인증된 폰번호와 현재 폰번호가 일치하지 않습니다 번호 변경시 초기화 하기 메뉴 선택 후 재인증하셔서 사용해 주세요 종료 초기화 하기  참고로 제가 쓰는 핸드폰은 샤오미 홍미노트프로 이구요 통신사는 KT알뜰폰 입니다',
#  '카드신청시 일정시간미사용으로 거래불가가 계속 뜨는데 제거후 다시 설치해도 그렇네요 어떻게 해결해야 할까요',
#  '잘 사용 하고 있습니다 근데 가맹점에 포함 돼 있는 곳인데 앱에는 검색이 안되네요 가게에 물어보니까 된다고 하는데 앱에는 없어요',
#  '제안을 하고자 합니다 어린이들도 동백전 사용자로 참여하도록 하면 어떨까요 인천의 인천e음카드처럼 세 부산 어린이를 위한 어린이용 동백전이 발급되면 좋겠어요 체크카드 기능을 빼고 선불 충전방식에 부산을 상징하는 캐릭터가 들어간 디자인의 동백전으로 부산의 세 어린이들을 공략해 용돈카드로 활용토록 하면서 경제 개념도 가르치고 우리동네만의 특별한 카드를 갖는다는 든든함도 함께 하면서 우리 부산에 소속된 어린이라는 자부심을 안겨주면서 부산 지역경제를 어린이들도 활성화에 동참하도록 하면 좋을거같아요',
#  '와이파이에서만 접속이 됩니다 거의 일주일 이런 상탠데 오류 언제 잡아주실지 이런 증상이 다른 분들도 있는거 같은데 그 댓글들 답변달으신 것처럼 통신불량 이런거 절대 아님다 오류가 났으면 조치를 해줘야죠',
#  '서버 좀',
#  '동백전 어플이 와이파이 일 때는 잘 되지만 와이파이가 아닌 상태에서는 오류가 떠서 충전도 잔액 확인도 할 수 없어 결국은 다른 카드를 쓰게 되네요',
#  '진짜 다 좋은데 카카오뱅크 계좌등록되게해주세요',
#  '앱 실행하니 통신 중 예기치않는 오류가 발생했다면서 실행이 안 됩니다 왜 이런거죠',
#  '괞찬아서 주변에 강추합니다',
#  '자기명의휴대폰아니면 가입이 안되는거 같은데 아이핀으로 가입할수있게 해주세요',
#  '어플에서 바로 qr코드같은걸로 결제기능이 있으면 좋겠네요',
#  '그냥 무조건 사용해야합니다',
#  '원래 와이파이있어야만 접속가능한건가요 데이터로는 접속이안되고 꼭 와이파이가있어야만 쓸수있어서 불편해요',
#  '뭐 켜져야 잔액을 확인하고 사용하는 곳 확인해서 쓰지 와이파이연결하니까 데이터만 된데서 데이터 연결했더니 네크워크상태가 안좋다뜨고 껐다켜도 지금 번째 네트워크 상태가 안좋다뜨고 물론 캐시백이다뭐다 평소에 잘 이용하는데 오늘 왜이러죠 내 데이터는 변하지 않았는데 데체 뭐가 문제라서 네트워크 상태가 안좋다하는지 내 네트워크 상태가 안좋다하는건 동백전 밖에 없네영 어떻게 해야하는지 알려주세요 고객센터 연락해보라는 말 하면 진짜 찐으로 빡칠 듯',
#  '데이터확인하라고 연결이안되요 다른 앱은 실행되는데 시간째 안되니 화나요',
#  '아니 충전할려고 앱켰더니 실행이 안되면 어쩌라고요 짜증나네',
#  '어플이 왜이러죠 데이터상태에서 사용이 안되면 밖에선 사용하지말란건가요',
#  '일단 어플이 너무 느려요 또 실행할때 네트워크가 불안정하다고 안열리네요 가맹점이라고 표시되어있어서 갔는데 결제가 안된다고해서 다른 카드로 계산했네요 자잘한 오류가 너무 많은거같아요',
#  '캐시백이 많아 너무 좋네요',
#  '제발 서버 확장 좀 하세요 앱에 한번 들어가려면 하루종일 걸림',
#  '앱 접속이 안되요 확인해주세요 계속 오류나요',
#  '어플이 실행이 잘안됨',
#  '앱이 잘 열리지도 닫히지도 않아요 일단 카드신청만 겨우하고 강제 종료했네요 ',
#  'Ios 안드로이드 버전 낮으니까 아예 플레이스토어에 없네요 다른 카드나 은행앱은 다 깔리는데 이게 뭡니까 버전 범위좀 수정해주세요 ',
#  '동백전 가맹점 위치 알수 있는 어플 있으면 더 좋겠네요',
#  '일정시간 미사용으로 작업이 중단되었습니다 카드 신청을 할려니 위처럼 나오며 안되네요 앱을 지웠다 다시 깔아도 똑같이 메세지 나옵니다 어떻게 해야 하나요',
#  '갤s 브라우저 크롬으로 설정해야된다고 진작좀 알려주지 어제 전화문의는 그런거 안알려주더니 오늘은 알려주네 하 ',
#  '아니 앱 설치해서 들어가니깐 이앱을 삭제하시겠습니까 뜨고 예하면 진짜 삭제되고 아니오하면 그냥 흰화면이고 용량 문제인가 싶어서 이것저것 다 지우고했더만 안되네 어쩔거에요',
#  '네트워크도 잘안되는걸 어떻게 써라고 써다가 열불나서 카드부쉈음 일부러 이렇게 만든거 아니요',
#  '이용내역 조회시 이용기간에 따른 합계액이 표기되면 좋겠습니다 일치 결제내역조회시 현재는 리스트만 보여주니 합계액을 따로 계산해야 함',
#  '본인확인 방법을 추가해 주세요 법인사용자의 경우 본인명의의 폰이 아니라며 어플 사용이 불가합니다 카드를 발급받을 때에는 카드와 인증서 등으로 온라인 발급을 받았는데 어플사용이 안되니 불편합니다 심을 바꿔서 개인폰번호으로 인증을 받고서 법인심으로 구동하면 역시나 에러가 발생하며 사용이 불가합니다 듀얼심 휴대폰에서도 그런 현상때문에 사용상 어려움이 있습니다',
#  '설치 후 켤때마다 초기화재인증하라고 하죠 등록된 정보와 핸드폰 번호가 다르다는 안내가 나오네요 동일한 번호로 인증받고 설치했습니다 재설치해도 동일한 현상이 반복됩니다 어떻게 하면 되나요',
#  '저한테는 너무 좋습니다',
#  '별 개도 아깝습니다 결제가 제대로안돼서 어플실행시키는데 들어가져야지 확인을하지 분간 시간버리고 한번더결제하고나왔습니다 카드관리랑 어플관리가안되면 애초에 시행을하지마세요 이딴식으로 운영해서 불편하게만들지말고',
#  '어플이 실행되야 쓰던가 하죠',
#  '동백전 가입할라는데 인증번호가 안와요 번 시간초과됫는데도 안와요 왜안오는거죠',
#  '아 진짜 불편하네요 ',
#  '가입은 하고 되는가 볼려고  원 충전 했는데요 카드를 만들수가 없네요 뭐이 요렇게 복잡하나요',
#  '카드뱌아서 충전하고 사용하는대 어플에는 사용됬다고 금액뜨는대 가게에서는 사용중지되있다고 결제안된다는대 뭔가요 확인해보니 카드 사용등록 다되있는대 왜안되는겁니까 어플은 들어가지다가 첫 로딩화면에서 넘어가지도않내 다시받아도 똑같고',
#  '어플화면에서는 결제완료창이랑 캐쉬백 내역이 뜨는데 가맹점에서 실결제가 되지는 않는 상황이 발생해 카드를 세 번이나 긁었으나 실패했어요 간헐적으로 이러면 어떤 사람들이 쓰겠습니까 고객센터에서도 같은답변이고 해결되는건 없고 정말 불편해서 못쓰겠네요',
#  '접속이 안됨',
#  '앱 실행이 안됩니다',
#  '앱연결하기 하늘의별따기임얼마썼는지 확인을할수가없음앱이 실행이돼야 뭘하지  LTE상태에서는 앱 안열림 그리고 결제시 계속 오류떠서 결제할수가 없음 가게점원분이 동백전은 늘 오류뜬다고 함',
#  '오류 투성이 접속 됐다 안됐다 네트워크도 불안정함',
#  '급하게 만든거 엄청티나네 안정성 엉망임',
#  '카드가 오류가 떠서 결제가 취소됐는데 캐쉬백은 들어왔고 어플은 켜지지도 않고 어플을 지웠다 깔았다 수차례 폰을 켰다 껐다 수차례 아직도 안켜지고 답답하네요 아 속터져',
#  '이거 확인안되는데 왜이렇죠 결제안된다고하는데 어플에는 결제한거처럼 나오고 진짜 왜그럽니까 방금 쓴글은 지우고',
#  '안들어가지는게 너무심하네요 이래서 사용가능하겠어요 데이터 와이파이 다 안들어가져요',
#  '다운로드만 되고 아이콘누르면 동백전로고만 내내떠있고 아무것도 안되는데요 와이파이 데이터 둘다해봤는데',
#  '동백전은 좋은데 앱이 말썽이네요 충전할때마다 짜증이 나요 앱이 쓰레기',
#  '굿',
#  '오늘 하루종일 먹통에 중 결재 됐습니다 확인해주세요',
#  '카뱅이 없어서 아쉽긴 하지만 좋아요♡',
#  '어플이 켜져야 잔액 확인을 할텐데 어플이 켜질 생각을 안하네요 리뷰 보니까 다른분들도 그런거 같은데 언제 오류 수정 되나요 이런 현상 계속 되면 캐시백이고 머고 더이상 동백전 쓸 이유가 없지 않을까요',
#  '잘사용하고있습니다 월 일 오후 부터 앱 자체가 켜지지 않습니다이유가 뭔가요',
#  '부산사람이라면 강추 이벤트프로 평소프로',
#  '카드를 받고 앱을 실행할려니 안되네요 이렇게 허접하다니',
#  '켜져야 뭘하지 공공기관에서 만드는 어플 답다',
#  '결제 알림문자를 받음과 동시 입금 알림문자가 울립니다코로나 같은 지금 시기에 경제도 많이 힘든터인데 경제적으로 정신적으로도 위로가 됩니다 부산 동백전 감사합니다',
#  '출시 되자마자 사용해서 몇달짼데 처음보다는 세분화된 충전 단위도 편리하구요 너무 잘쓰고 있습니다 좋아요',
#  '와 앱 실행 너무 안되요 너무너무너무 너어어어무 LTE로 해도 안되고 와이파이는 된다고 해서 와이파이로 했더니 여전히 안되고 이건 뭐 앱을 사용 하라는 건지 말라는 건지 모르겠네요 부산사람들이 쓰는 앱일텐데 사용자가 많다고 하면 대체 전국민이 쓰는 앱들은 어떻게 켜지는 건가요 다른 분들도 계속 안 켜진다고 건의 하시는 거 같은데 이 부분은 빠른시일내에 조치를 취해주셨으면 합니다',
#  '머 접속이되야하지우짜라는건지 안되요 아예 로딩도안되고 따운됨 하',
#  '왜 제일은행계좌연결이없나요 그리고 카드는왔는데 잔액충전을못하고있어요 어플이 오류라고 켜지지가않아요 다시깔아도 똑같네요',
#  '잘 쓰다가 월 일 갑자기 카드가 잘 안되더니 어플도 안되네요  혜택이 마음에 들어서 잘 쓰고 있었는데 왜 안되는 건지 알 수 있을까요 어플이 안되서 결제 확인도 안되네요 ',
#  '앱이 화면이 멈춰있어요 접속이 안되는거같아요',
#  '돈 충전하고 카페에서 사용했는데 직원분이 은행에 문제가 있는거같다고 안된다해서 디른카드 썻는데 폰 앱 알림에는 또 캐시백 들아왔더라구요그래서 확인해볼라니까 앱이 그냥 메인화면에서 그 카드 충전 화면으로 계속 안넘어가요  돈쓴건지 안써진건지 모르겟네요 지웠다 다시 깔앗다 두번하는데 처음 화면에서 안넘어가요 ',
#  '지금 앱이 첫화면에서 넘어가지를 않네요 폰을 다시 켜보아도 마찬가지고 앱제거하고 다시 설치를 여러번 반복해도 안되네요',
#  '서버터져서 안써지는게 태반입니다 심지어 결제처리도 안되었는데 앱 들어오니 결제된것처럼 차감되어있네요 이 시간에 고객센터는 전화도 안받고 명불허전 KT에 지자체 콜라보네요 훌륭합니다 훌륭해',
#  '정보 수집 동의후 동백전카드 이미지모양에서 어플실행이 멈추는데 이건 모에요',
#  '안들어가짐',
#  '동백전이 어플없이 사용가능하다면 모르겠지만 필수적으로 어플이 필요한 서비스인데 이 정도로 불안정하면 이건 매우 큰 문제인것 같습니다 안정화좀 해주세요 와이파이 LTE G 어디서도 안정적으로 작동하지 않습니다 정상작동 하는 경우보다 어플실행시 메인화면만 나온 상태로 멈추는 경우가 더 많습니다',
#  '앱이 안열림 뭐하자는거임 사용자 증가로 오류 골때리네',
#  '앱 알림은 결제가 되었다고 뜨는데 업체에서는 결제가 안되었다고 해서 다른 카드로 결제 했네요 확인 부탁 드립니다',
#  '오늘 결제가 된걸로 처리되는디 편의점은 안됐다고하고 충전금액만 차금되네요  kt서비스센터 번호도없고 어디서 처리하나요',
#  '실행이안됩니다 개선해주세요',
#  '짜증나요 매장에서는 결제안됐다 그러고 저는 결제됐다고 알람 떴는데 결제하려고 어플드갔더니 안드가져서 삭제 후 다시 다운받았더니 여전히 안됩니다 어쩌라는건지',
#  '오류가 잘나는데 조금전 결재하는데 동백전카드는 금액지불되는데 결재안뜬다고현금내었는데 지금은 먹통으로 열리지도 않는데 앱삭제하고 다시 깔아도 되나요 금액은 다시 자동적립되나요',
#  '너무 어이 없네요 사용할수 없어요 카드로 결재도 안되고 앱도 다운되어 먹통이 됐어요',
#  '아니 결제를 했는데 제 핸드폰에서는 결제가 됐다고 알림이 왔는데 정작 결제한곳에서는 결제가 안됐다고 하는데 고객센터로 물어보려고 해도 전화도 잘안받는데다가 저녁엔 운영도 안하면 그럼 고객들은 어디에 문제 해결을 요구하나요 정말 짜증나네요 평소에도 접속이 어려웠는데 이렇게 문제가 생겼을때마저도 접속이 안돼면 어디로 확인하라고요',
#  '또 앱 실행이 안 돼요 몇번짼지 모르겠네요 언제 개선되나요 오늘 동백전앱 오류때문인지 평소에 동백전 결제되던 프랜차이즈 빵집에서 결제가 안 되더군요',
#  '어플개떡같이 만들어서 켜지지도않고 계속 로딩이고 가끔씩만켜짐',
#  '주유하다가 결제 오류로 다시 결제 했는데 중복으로 결제 되서 취소 했는데도 돈이 안들어와서 전화 할랬더니 접속도 안되고 와이프폰으로 해도 접속이 안되네요 고객센터도 상담시간이 아니라고 하고 답답하네요',
#  '카드를 만드려다가 민증 발급일자 오류를 번 초과해서 만들 수가 없습니다 운전면허증도 없어요 이럴 경우 어떻게 해야합니까',
#  '제발 본인확인 추가좀요',
#  '써야돠는데 왜안되냐고요자주이라네요정말 오늘쓸려고있었는데 안되면혜택도안되고뭐죠',
#  '교통카드 없는 카드 개설했다가 있는걸로 바꿀려고 하나카드 통해서 카드해지를 했습니다 근데 어플상에 정보가 그대로 있어서 재발급을 하지못하고 있습니다 고객센터 또한 하루 통 이상씩하는데도 연결불가 영상통화비용으로 원이 부과되었네요 상담조차 못했는데 말이죠 아주 답답한 경우라 별 개도 아깝네요 대 문의도 답이없고 여기에 달릴 답변은 고객센터에 전화해봐라 이 얘기겠죠',
#  '인증번호가 안와서 신청못하고 있어요 어케하나요',
#  '결제가 먹통입니다 어플 접속도 안 되구요 다름 카드를 들고있었기에 망정이지 동백전만 가지고 있었으면 문제가 생길 뻔 했습니다 알아보니 결제 장애가 생긴게 이번이 처음이 아니더군요',
#  '네트워크장애로 안되는경우가 잦네요 다른뱅킹은 아무런 문제가 없는데',
#  '동백전이라는 카드혜택은 좋지만 어플만 보면 너무 불편하네요 데이터로 접속하려면 네트워크 오류로 접속불가합니다',
#  '굿',
#  '집에서 와이파이 연결된경우에만 충전이나 어플확인이 가능합니다 어플연결이 안되다보니 불편하네요저만 그러는줄 알았는데 생각보다 많은 분들이 이러한 불편을 겪는거 같네요얼른 이런 불편사항이 개선되면 좋겠습니다네트워크 이야기하기엔 저희신랑은 너무나 잘 열리네요같은 상황에서 그리고 충전금액보다 더 많은 금액결제시 바로 체크카드로 결제가 되는데 알림으로 체크카드로할건지 물어보면 좋겠습니다',
#  '느린속도데이터쓰는사람은 와이파이안잡으면아예안됨 밖에서 사용할수가없어요',
#  '회원할려는대 인증번호가 안오네요',
#  '아인증번호 입력하려 나갔다오면 자꾸 앱강종돼서 처음으로돌아가요 인증을 할수가없잖아요 별도아깝다',
#  '좋습니다 포인트도 바로사용가능해서 유용해요',
#  '어플 실행도 오래걸리고 가맹점 검색이 불편합니다 지도 외에 지역별로 볼수 있는 방식이 있었으면합니다',
#  '왜 댓글에 답장안해주냐 무시하냐',
#  '동백전 사용중에 알뜰폰통신사 이동했더니 켤때마다 계속 초기화 불러오는 오류가 있네요',
#  '결제 실패는 곧 시스템 실패 kt 하나은행 똑바하세요',
#  '좋아요',
#  '앱 실행 진짜 안됨 뭐 이런게 다있나 싶다 캐시백 주니마니 생색이나 내지 말고 실행이나 제대로 시켜주세요',
#  '너무 자주 에러나요 미리 공지라도 하고 안돼야 당황을 덜하죠 오늘도 일부러 동백전으로 결제하러 갔다가 허탕쳤습니다 너무한거 아닙니까 진짜 최악입니다 주동안 대체 몇번이나 안되는건가요',
#  '가맹점 왜 안뜨나요 가맹점을 봐야 쓰든가하지 빨리좀 고쳐주세요',
#  '아니 어플에서는 사용가능하다해서 갔는데 사장님은 사용못한다면서 자기는 들은거 없다고 하고 헛걸음질만 했네요 사용가능한 곳을 좀 똑바로 표시해줬으면 합니다',
#  '잘쓰고있었는데 어플실행이 안되네요 다시 설치해도 마찬가지이고 쓰지말라고 만든건 아닐텐데 고쳐주세요 언능',
#  '접속이 안되네요',
#  '지금 가맹점찾기 저만 안되는 건가요 앱에 오류가 너무 많아요',
#  '중소기업 수준도 안되는 어플',
#  '사용처도 확인안되는데 무슨 불편하네요',
#  '가맹점찾기에 가맹점 자체가 아예 안나옵니다 처음부터 안된게 아니고 어제부터 안나오네요 어떻게 된 건지 해결 부탁드립니다',
#  '아니 무슨 카드 발급 안해도 쓸수있나 싶어서 결제했는데 안돼는거 확인하고 환불하려 했는데 문의를 개를 눟어도 환불이 안돼는데 뭐 상술입니까 환불 해준다고 안했으면 결제도 안했을텐데 환불해준다면서 일째 확인 안하고 뭐하는 짓거립니까',
#  '가맹점찾기에서 가맹점이 하나도 안보여요',
#  '갑자기 가맹점 검색이 안되네요 어떤날은 갑자기 결제 오류나고 이렇게 불안정해서 어디 쓰겠습니까',
#  '동백전 앱에 들어가면 가맹점 찾기가 원래는 나오는데 어제 부터 위치를 잡아도 안나오는 이유가 뭔가요',
#  '어제 결제가 안되서 곤란한 경험을 했습니다 결국 다른 카드로 했죠',
#  '아니 부산에서 쓰라고 만든 카드 맞습니까 안되는곳이 왜 이렇게나 많은지 참',
#  '다른건 다 괜찮은데 가맹점 찾기에 가게가 하나도 안나와요 몇번이나 재설치했는데도 가맹점이 하나도 안뜨네요 따로 웹페이지에 가맹점 목록을 업로드하던지 다른 방법으로 개선해야 할 것 같아요',
#  '잘안될때가 많고 환불도 제약있고 그냥 안쓸랍니다 카뱅만세',
#  '앱 개발자 바꿔라 제발 부탁합니다',
#  '나머지는 다되는데 왜 가맹점 조회가 안되는지요 가맹점 이게 찾아보고 가야되는데 하나도 안떠있고 다시 깔아봐도 안되있는데 쓸수가 없네요 어떻게 해야되나요',
#  '부산사람 만큼은 최고♡',
#  '결제내역을 문자로도 보내주면 좋겠네요',
#  '어플켤때마다 초기화가 뜹니다새로 휴대폰인증완료 후 재시작하면 또 뜨고 어플 한번쓸때마다 계속 초기화해야하네요 왜이러는건지',
#  '매우 훌륭한 시스템을 갖추었다고 생각합니다',
#  '너무 좋아요',
#  '가압이 완료 된것 같은데 가드신청 을 햇는데 언제 돼나요  충전도 좀금 해놧습니다 월 일 동백전 어플 깔고 카드 오기만 기다립니다 ',
#  '고객센터는 일하는사람있나요 전화도안받고 문의글 읽지도 않음',
#  '예금이자 생각해보면 현명한 소비가 돈을 버는거임',
#  '잘 쓰고 있습니다 부산시청 열일해주셔서 감사합니다 퍼센트 캐시백 넘 좋아요 월뿐 아니라 월 월 쭉쭉 캐시백 해준다면 동네 소상공인들도 주민들도 윈윈할 수 있을 거 같아요',
#  '로그인이 안 될 때가 너무 많습니다',
#  '혜택은 좋으나 사용하기 불편한 부분이 있습니다 이용내역에 월간 결제 또는 적립내용이 합산돼서 보여지는 부분이 있었으면 합니다 한건 한건 더해야 하니 조금 불편하네요 혹시 제가 합산출력 방법을 모르는 것이라면 댓글 달아주시면 별점 수정하겠습니다',
#  '꼭 몇번 클릭해야 연결됨',
#  '빠르고 실용적인 면이 너무 좋습니다',
#  '로그인 잘 안되고 가맹점 찾기도 힘들고 별 하나 주기도 아깝네요 그리고 충전식 카드라고 말했으면 발급을 고민하고 냈을텐데 안내장에도 그런말이 없었네요 사용해보고 가족들에게 추천해주려고 했는데 추천 안하고 싶네요',
#  '오좋네요 근데갑자기 만원에서 만원으로아쉬워라',
#  'kt앱이었네요 kt폰이 아니면 사용불가인 모양이네요 계좌등록 진행중에 인증완료를 누르기전까진 네트워크 어쩌구 저쩌구 안뜨다가 꼭 인증완료를 누르기만하면 네트워크 접속불량이라고 뜨는거였네요',
#  '필요할때 앱이 작동을 안하네요',
#  '자꾸안괴요 충전해서 결제 해야 하는데 카드 달랑 한개 들고 나왓는데',
#  '머고 네트워크이상하다고 안열린다 젠장 불편해죽겠네',
#  '앱 접속이 왜 안되는거예요 아 놔 진짜',
#  '아니 왜 접속이 이렇게 안됩니까 사용을 할 수가 없네요',
#  '주말만 되면 접속이 안됨',
#  '아니 동백전 앱도 안열리고 왜이럼이거',
#  '앱이 안열립니다 왜이럽니까 진짜 확인 할게 있는데 시골이라 와이파이로 접속 할수도 없고 데이터로는 접속이 불가 하네요 지금 ',
#  '아니 데이터 무제한인데 네트워크 연결하라하고만 하고 왜 계속 접속이안되나요 돈얼마남은지 확인도안되고 어플왜 있는건지 빨리해결해주세요 제발',
#  '웹에 접속이 안되네요',
#  '앱에 접속이 너무 안됩니다',
#  '데이터 연결이 불안정하다더니 다른 어플들 접속은 잘만 됩니다 어플 재설치도 하고 와이파이도 꺼보고 데이터도 껏다 켜고 분 정도 씨름하다가 포기했습니다',
#  '머고 앱실행도안되고 장난하냐',
#  '접속이 잘안되네요 업데이트좀 부탁드립니다',
#  '접속불가 충전불가',
#  '왜 로그인이 안되나요',
#  '쓰레기입니다 이딴게 세금으로 만들어지네요',
#  '걍 먹통임 앱실행이 안됨 돈좀들여서 실력있는 개발자좀 씁시다',
#  '접속이 안되네요 빨리 계산해야되는데 앱이 접속이 안되서 주위사람들 눈치밥 먹으면서 다른 카드로 계산 했습니다',
#  ' 데이터 켜도 로그인 안되는 희대의 쓰레기 앱',
#  '충전금액 확인하고 쓰려고 했더니 어플은 켜지지도 않고 장난치는 것도 아니고 계좌결제로 생돈만 나갔잖아요 캐쉬백도 못받을 거면 그냥 신용카드 쓰고말지 뭔',
#  '앱이 와이파이든 데이터든 아무것도 연결이 안되네요 안정성 좀 신경써주세요',
#  '네트워크 오류라고 실행자체가 잘 안되네요 왜 점인지 알겠네요',
#  '아니 왜 잘 되던게 갑자기 네트워크 뭐라하면사 안들어가지냐 ',
#  '이거 왜 안들어가지나요 계속튕기기만하네요이러다 무용지물이 되는건아닌지',
#  '머하는거야 일부러 안되겠했냐 왜이래 자꾸',
#  '로그인 안되네요 사용하기 짜증나네',
#  '개느리고 접속 안됩니다',
#  '월에 발급 받아 쭉 사용 중이에요 프로 캐시백이 어마어마 하네요 동백전 덕분에 신용카드 소비도 줄이고 현금 충전해 쓰다보니 과소비도 안하게 만들어요 앞으로도 쭉 이용하겠습니다',
#  '왜 갑자기 접속이 안되나요 충전을 못해서 캐쉬백 못받았어요',
#  '접속이안돼요 충전은어찌해야하나',
#  '아니 와이파이 네 칸 풀로뜨고 유튜브 등등 빠르게 잘되는데 왜 이 앱만들어거면 네트워크 연결이 안된다고 뜰까요가입한 이후로 한번도 켜지지않아 카드 신청도 못하고 있습니다 연결문제 좀 해결해주세요',
#  '네트워크 개선좀 빨리해주세요 일주일째 데이터로도 접속이안되고 와이파이 연결된상태에서도 접속이안되고 어플 들어가는게 하늘의 별 따기수준입니다 불필요한것을 개선할게아니라 접속부터 원활하게되는게 최우선인것같습니다',
#  '엉망진창입니다 사용하려고 만든어플이 어떻게 결제하려할때마다 앱이 오류가 빈번하게 나네요 번거로워서라도 이용이 꺼려집니다 오류가 한두번도아니고 앱실행자체가 안되네오  거르세요',
#  '잘쓰고 있는데 오늘 앱이 안열리네요 네트워크 상태가 원활하지 않습니다 로 계속 뜹니다 친구꺼도 그렇게 뜨네요 앱이 이모양이면 부산 이미지가 어떻게 되겠습니까 빨리 고쳐주세요',
#  '접속도안됨',
#  '안정성이 최악이네요',
#  '한 번씩 앱이 먹통입니다 쓰고 싶어도 못쓰게 하는 앱이네요 충전금액 확인하고 쓰려는데 앱은 아무리 기다려도 안되네요 서버가 너무 불안정한거아닌가요 한 두번도 아니고해결이 안되나보네요 네 알겠습니다',
#  '취지도좋고 캐시백도 큰점 좋습니다 아쉬운점이 있네요  충전된 금액이 아닌 계좌연동으로 결제가되면 캐시백이 안되는 내용을 사전에 고지하지않은점  앱접속이 원활하지 않아 충전 잔액조회 등의 문제가 생기는점 안되는건 어쩔수없지만 안내는 똑바로 해주면 좋겠습니다 앱구동이나 시스템에 있어서도 여러 사정이 있겠지만 제일 중요한 결제 및 캐시백과 직결되는 부분들인데 이런 부분들이 원활하게 될 수 있도록 빠르게 신경써주시면 좋겠습니다 문제발생시 알림메세지나 공지등을 보내주면 조금 더 낫지않을까 하는 아쉬움이 있네요',
#  '접속에러 언제 고치나요',
#  '접속 겁나 안됨 뭐하는건지 ',
#  '좀 어플좀 들어가봅시다 뭐좀 할라하믄 네트워크 상태가 안좋다하고 충전도 못하고 사용도 못하고 콜센터도 연결안되고 캐시백 주기 싫어서 어플 안열립니까 이따구로 관리할거면 애시당초 만들지를 만들가 한시간째 안들어가지는데 도대체 관리자는 불금이라 놀러갔습니까',
#  '요즘세상에 들어가지지도 않네',
#  '와파든 데이터든 안들어가져요',
#  '앱관리 안하냐  네트워크 접속불량 머냐',
#  '리뷰는 스마트폰 쓰면서 처음 남겨봅니다 만원 충전해 놓고 사용하려고 보니 네트워크 연결이 안됩니다 이따구로 뜨면서 꺼지고리뷰 확인해보니 와이파이에서는 된다고 해서 와이파이 접속후 해도 똑같은 증상 이네요 장난하는것도 아니고 빠른시일내에 환불해 주세요 못씁니다 내 돈쓰면서 스트레스 받는경우는 뭔 경우인가 모르겠네요',
#  '아니 츙전한 뒤로 안켜져요 ',
#  '지금 사용이 안되네요',
#  '동백전 카드는 잘사용하고 있는데요 앱은 왜 이따위로 만들었나요 와이파이에서만 접속되고 그마저도 안될때도 있고 개선이 시급합니다',
#  '하 식당에서 밥 먹고 나가기전에 돈 충전해서 결제하려고 어플을 켰는데 접속이 계속 안되서 환급도 못받고 다른 카드로 결제했습니다  이거 진짜 뭔가요 열받습니다  천원 돈  손해봣네요',
#  '발급 한 달도 지나지 않았는데  시스템 장애로 결제 불가에  앱 오류로 충전 불가에  불편하기 짝이 없군요 이래서 부산 경제 어떻게 살리죠 동백전 분발해야겠어요',
#  '아니 접속이 자꾸 안되는데 어째된거죠 짜증나네요 이젠',
#  '평점이 왜 점대일까 했는데 오류 진짜 많이나고 쓰레기 같아요 충전 해야되는데 어차피 오늘 안에 안고쳐질거고 하루 기다려야겠죠 진짜 별로',
#  '왜 또 안되냐 에휴',
#  '앱이 열리지가 않는데 어떻게 충전합니까',
#  '통신오류가 너무 잦아요',
#  '로그인이 왜안되나요 이리 안들어가지는 어플도 첨봅니다빠른 수정 부탁드립니다',
#  '동일한 후기가 많습니다만 왜 자꾸 네트워크 연결안된다고 하나요 불편해서 못 쓰겠네요 고작 확인 하나 하는데 이렇게 시간이 많이 걸리다니',
#  '앱 접속 좀 하자 지금 몇일째 접속이 안되는건지 관리할 마음은 있는건지',
#  '어플이 계속안열리네요 정말 노답이네요',
#  '앱자체가 안켜지네요 부모님꺼 계좌연결도 분째 인증도못하고있어요 인터넷폰뱅킹안하시는분이라 은행까지갔다왔는데요',
#  '캐시백되는건 좋은데 앱이 몇번째 안들어가지는건지 돈이 얼마있는지 확인할수가 없네요',
#  '안 열러요 ',
#  '쓴지 얼마안됐어도 캐쉬백들어오는것도 좋고 맘에 들었는데 짜증나서 못써먹겠네요 무슨앱이 자꾸 네트워크 연결이 안된데요',
#  '앱에 잘안들어가져요 벌써 시간째 들어가지지않고 튕기는데 이게뭔가요 할인해주셔서 좋긴하지만 이렇게 접속이 어려워서야',
#  '앱 실행이 안됨 와이파이 빵빵한데도 안되고 데이터로도 안됨요 불편',
#  '잔액 확인하려고 어플 들어가는데 접속 조차 안되면카드를 어떻게 사용하라는건가요 대체',
#  '현재 시각 시간째 먹통이네요 식구들이랑 외식하고 동백전으로 계산할려니 앱도 안열리고 도무지 카드를 쓰라는건지 말라는건지충전을 할수잇게 해줘야지 될거 아닙니까 ',
#  '똥입니다 잘쓰다 안되서 몇번을 다시해도 예기치 못한 오류라고 나오네요 짜증',
#  '맨날 접속이 안됨  관리도 안할거 왜 만들었는지',
#  '앱이 먹통입니다 네트워크 연결이 안된다고 뜹니다 빨리 고쳐주세요 온 가족 폰의 앱이 다 먹통입니다',
#  '이게 뭔가요 계속 열리지도 않고 짜증 너무 나네요',
#  '어플실행시 오류 오늘카드받아쓸려했더니 바로어플접속 먹통 이래가 뭐하겠나요',
#  '어플 진짜 못 만들었네요 툭하면 접속도 안 되고',
#  '왜 연결이안돼요 위치켜도 가맹점나오지도않고아니 도대체 점거안하고 뭐하시는건지동백전괜히만드러서짱증나게',
#  '접속도안되고 깔고지웠는데도 접속안되요 개선해주세요',
#  '이게머요',
#  '네트워크 관리 좀 해주세요 뭔 맨날 연결 안 돼서 충전도 못하고 오늘도 캐시백 혜택 원은 봤을건데 네트워크 문제로 활용 못했네요 ',
#  '잘 쓰고있는데 네트워크 오류가 너무 자주 발생해서 잔액을 제대로 확인할 수 없을때가 많습니다 ',
#  '이거 인증번호가 밀려서 날라오죠 분안에 오지도 않아서 가입조차 진행할 수 없습니다',
#  '서버연결 진짜 쓰레기같네요 부산시청 실망입니다',
#  '금액확인 후 사용할려고하니 오류뜨네요자주 에러가 나니 사용하기 불편해요',
#  '심심하면 안열리네요 쓰라는건지 쓰지말라는건지 뭐 열려야 확인도하고 충전도하죠',
#  '캐시백은좋은데 앱사용오류가너무심해요 ',
#  '이전엔 접속 되었는덕 오늘새벽에 뭐 서버넓힌다고 충전안되더니 지금은 어플이 켜지지않아요',
#  '몇번을시도해도잘되지가않네요 언제쯤 제대로 될까요',
#  '와충전할려고 하는데 들어가지지가 않네요 앱이 왜 이때위인가요',
#  '이거 진짜 뭔 앱이 연결도 안되고 오류나고 레기인지',
#  '앱이 열려야 충전해서 사용을 하죠 안열리는 경우가 너무 많아요 네트워크가 원활하지않다고 자주떠요',
#  '앱 실행 단계에서부터 막힙니다 만들기만 하지 말고 관리도 좀 잘해주길 바랍니다',
#  '앱이 열리지가 않아요 잔액이 얼마남았는지 확인할수가 없네여',
#  'G Lte Wifi 전부 데이터 연결 상태가 안좋다고 실행이 안됩니다 실행이 안되면 충전을 어떻게 해야하나요',
#  '접속이 되야 충전을 하든 뭘하지 제발 접속 좀 하게 해주세요 LTE wifi 둘다 안되요',
#  '이런 결제서비스가 접속이 안된다니어처구니 없는 부산시와KT구나',
#  '어플 잘 되다가 접속이 안되네요',
#  '오류가 왤케 자주 난대요',
#  '굿',
#  '계속어플접속이안돼요왜그런거죠',
#  '다른앱은 잘되는데 동백전은 도대체 와이파이로도 데이터네트워크로도 네트워크 상태가 고르지 않다며 연결이 안되는데 어떻게 된 건지요',
#  '어제부터 네트워크연결이 안된다고 접속이 안돼요 어떻게 해결함요',
#  '잘쓰고 있었는데 최근에 번호이동을 한 뒤로알뜰폰알뜰폰 계속 초기화하라고 하고 초기화메뉴 눌러도 안넘어가고 인증을 여러번해도 들어갈때 그뿐 다시 앱을 껏다켜면 문제가 반복되네요해결해주세요',
#  '오늘 하루종일 로그인이 안되네요 오류도 자주나고 등록된 가맹점에서도 사용 안되는곳이 많이 있습니다 좀 개선해주세요 지금 일째 네트워크가 원활하지 않다는 메세지가 뜹니다 와이파이 LTE 다안되고 너무 불편하네요',
#  '앱 실행이  안되요 첫결제하고 포인트확인하려는데 종일 안됩니다 머 이런 어플이 있나 부산사람들 성격 급한거 모르나 ',
#  '왜 계속 네트워크가 연결이 안된다고 하는지ᆢ와이파이도 무선도 다 해봤어요 고객센터는 통화하기도 힘든데',
#  '갑자기 네트워크 오류라고 실행이 안됩니다 앱을 재설치해도 똑 같이 안됩니다',
#  '요 며칠동안 네트워크 상태가 원활하지 않다면서 접속이 안되는 이유를 모르겠네요 충전을 해야하는데 말이지요 와이파이 lte 접속에 아무런 문제가 없는데 왜 이런건지 조치 바랍니다',
#  '오류가 너무 잘떠요',
#  '가맹점도 많고 적립이 바로바로참 좋죵',
#  '노트 에서도 되나요 부산은행서 호환이 안된다는데 이해가 안되서요',
#  '굿 좋아요',
#  '좋아요',
#  '좋아요',
#  '앱이종종다운이되어서열리지 않을때가 있어요 벌써 번 삭제후 다시 깔았어요',
#  '좋아요',
#  '오굳',
#  '할인 좋아',
#  '간편하게 유용하게 잘 활용할 수 있어요',
#  '편리함',
#  '너무너무좋아요',
#  '조아요',
#  '좋아 요',
#  '고객센터 문의는 아예 관리를 안하는것 같아요 읽지도않고 처리도 않해주시네요',
#  '많이 쓰세요',
#  '굿',
#  '아주 좋네요',
#  '대형마트는 사용이 안돼는게 불편함',
#  '웬만한 식당 가게 다 되어서 좋아요 유용합니다 월별 한도액이 늘어나면 좋겠어요',
#  '소상공인 찾아서 사용하게되고 적립도 팍팍되고 최고입니다 부산경제 화이팅 상품권보다 편리해서 사용 빈도가 훨씬 놉네요 주유 편의점 된다는게 정말 좋아요',
#  '아주 좋아요',
#  '아주 좋아요',
#  '넘좋아요',
#  '죽이네요 엄청 적립받고있어요',
#  '페이백 프로 최고 전 만족하며 잘 쓰고 있어요 넘 좋음',
#  '정말 좋아요 부산 시민이면 동백전카드는 무조건 있어줘야 플랙스죠 ',
#  '조아조아',
#  '인증번호가안오네요 아니무슨 내폰skt고 다맞게했는데 인증번호 전송햇다카믄서 안오는건 뭐지',
#  '잘 사용하고 있어요 감사',
#  '포인트를 바로바로 받을수 있어 넘좋아요',
#  '앱을 열때 마다 폰번호와 맞지않다고 나오고 초기화하라고 해서 몇번을 다시 했는지 모릅니다 돈 입금시켜 놓고 사용할려고 하는데 이따위로 앱을 만들어 나서 너무 불편합니다',
#  '좋아요',
#  '전산 다운이라고 사용안될때 똑땅해 ',
#  '잘 사용중입니다',
#  '아주 좋아요',
#  '쓰는 본인에게 이득이 되니 매우 만족합니다',
#  '좋아요',
#  'TV선전과같이 쓰고나면 웃음이나네요 쭉 프로로가면 더 조을듯',
#  '좋아요',
#  '최고최고\U0001f929\U0001f929\U0001f929\U0001f929\U0001f929',
#  '뭔가 좀 다른 느낌 나는 했갈여요',
#  '죠아부러요',
#  '어플만으로는 별개도 아깝지만  캐시백때문에 만점 드립니다 캐시백 기간연장을 염원합니다',
#  '굿',
#  '좋아요',
#  '부산시내에서 사용하고 포인트적립하는 재미가 있습니다 포인트 금액이 쌓이는 것을 보면서 부산시민이라는 자부심이 마구마구 생깁니다 단점 처음 사용 할때는 동백전 사용가능한 곳이 많았는데 차츰 지정업소가 사라지고 있습니다 사용가능한곳을 찾아다녀야 하고 현금이나 타 카드를 가지고 다녀야하는 불편함이 생기네요',
#  '에러가많이나요',
#  '좋아요',
#  '좋아요',
#  '좋아요',
#  '어플보다동백전프로적립이너무좋네요',
#  '좋습니다',
#  '아주좋아요',
#  '아주좋아요',
#  '아주좋아요',
#  '좋습니다 지역화폐 중 젤 좋은데 근데 부산지역 가맹점의 물품을 온라인으로 결제되게 해주세요',
#  '가끔씩 접속불가됩니다',
#  '월에 얼마썻는지 안떠서 별로네요 진짜 돈많이쓰게 노린듯',
#  '좋아요',
#  '가끔 앱연결 안될때 빼고는 잘 사용하고있어요',
#  '굿 굿',
#  '혜택이 많고 좋아요',
#  '굳',
#  '좋긴한데 접속이 원활하지 않아요',
#  '굿',
#  '굿',
#  '조아요',
#  '혜택이 넘 좋음',
#  '조아용',
#  '충분히 너무 만족 합니다',
#  '좋아요',
#  '에러가 머 하루건너 한번 나는 니낌입니다',
#  '업데이트 하지 마세요 좀 짜증나게 하네',
#  '한번씩 접속이 안된다고 하네요 주기적인 업데이트 요망됩니다',
#  '좋아요',
#  '굿',
#  '잦은 오류',
#  '굿',
#  '로그인이 안되네요',
#  '최고',
#  'Goooood',
#  '아주 좋아요 부산 화이팅',
#  '흐음',
#  '굿',
#  '잘 사용하고 있어요',
#  '너무너무 편리하고 좋아요',
#  '글쎄요',
#  '좋아요',
#  '굿',
#  'Good',
#  '정말좋아요 캐시백이바로입금이되어서 요즘은장볼때 동백전카드를잘이용하고있어요부산♡굿',
#  '너무 좋아요요런거 계속 만들어주세요지역배달앱도 생기면 정말 좋겠어요',
#  '부산동백전 카드 용이 하고 잘쓰고 있어요 쓸때 마다 캐시백 팍팍너무 좋아요',
#  '좋아요',
#  '좋은 제도를 만들어주신 관계자분들께 감사드립니다',
#  '앱 오류가 너무 잦습니다 충전식인데 충전도 불가능하고 카드 이용도 불가하고 다른 지역 페이에 비해 오류가 너무 많습니다 대한민국 제 의 도시라는 부산에 어울리지 않는 수준입니다',
#  '잘 쓰고 있습니다',
#  '대형마트와백화점등대형업체만빼면 대부분사용되네요 가맹점찾기어렵다는분이해가안되는데 동네병원도되고 약국도되고 슈퍼빵집음식점주유소안되는곳찾기가더힘듦 도대체어디사시는분인지궁금하네요 캐시백도결재와동시에딱들어오고 첨엔되나안되나가맹점찾기도해봤는데 이젠필요없어요 신용카드쓸데가없어지고있어서그게문제 쓰는재미가쏠쏠합니다',
#  '사용하기좋아여',
#  '지난 토요일부터 네트워크오류라고 로그인자체가 안됨 충전잔액확인안되고혹시 이런상황일때 은행에서 충전업무가능한지 물어보니 어플에서만 가능하다고함고객센터는 통화연결이 안됨 이정도면 쓰라고만들어놓은건지 의심스러움',
#  '좋아요',
#  '앱이 안열려 충전을 못해서 필요할 때 할인을 못받았어요',
#  '아주 칭찬합니다',
#  '캐시백 넘좋아요',
#  '아무 에러없이 잘 사용중인데 뭐가 안된다는 것인지 즉시 할인되고너무 좋아요',
#  '좋아요',
#  '업데이트가 안됩니다',
#  '프로적립 바로사용 가능인데 접속이 늦음 어떠하리 인내심을 가지고 접근하세요',
#  '잘쓰고있어요♡',
#  '실용적이예요',
#  '다 평이 안좋네  난 편하기만 하던데',
#  '잘쓰고있어요',
#  '좋습니다 너무너무 좋아용',
#  '좋아요',
#  '택시는 사용 안되나요',
#  '포인트가 엄청나게쌓여요 최고b',
#  '경제절약으로 좋아요',
#  '감사합니다 혜택이 너무 좋아요 ',
#  '아직 사용 않는곳 많아요',
#  '굿굿',
#  '좋아요 캐쉬백 바로바로 되고',
#  '겁나 잘사용하고 있습니다',
#  '캐시백을 보니 또 결제하고 싶어지네요 ',
#  '좋아요',
#  '오류',
#  '정말 좋아요',
#  '좋네요',
#  '서버 불인정함',
#  '아주 좋아요',
#  '동백전 넘 좋아요 가맹점이 갑자기 안되는곳도 있던데 왜그런가요',
#  '쵝오',
#  '좋앙ᆢ',
#  '그저그럼',
#  '잘 사용하고 있음',
#  '아주많이 좋아요',
#  '좋음',
#  '초기화면에서 계속 멈춰있다가 네트워크 오류로 꺼집니다',
#  '바로 캐쉬백 되고 그걸 또 사용가능해서 참 좋습니다',
#  '긴급 점검이 왜이리 많습니까 결제할라다가 못한게 몇 번인지',
#  '잘 구성됨',
#  '좋아요',
#  '달 사용했습니다 사용하면서 저는 연결 두어번 버벅댄거말고는 지금까지 별문제없이 잘쓰고있어요',
#  '저는 되는데 어머니가 갤s 안드  cj헬로모바일 kt망 환경에서 원래 되다가 며칠전부터 네트워크 환경이 안정적이지 않습니다 라는 오류 문구와 함께 앱 실행이 안되네요 데이터를 쓰든 와이파이를 쓰든 다 안됩니다 어떻게 해야 해결할 수 있나요',
#  '할인 많이돼서 좋아요 가끔 오류로 결제가 안되지만  차츰 개선되겠죠',
#  '월부터 사용중인데 나는 한번도 오류난적 없고 잘 사용하고있음 계속 프로 캐쉬백해줬으면 좋겠어요',
#  '에러잦음',
#  '어느카드보다 좋습니다',
#  '죠앙',
#  '가맹점이 다 되는건 아니지만 소소하게 활용하고 쓰기엔 제법 괜찬습니다',
#  '잘사용하고있습니다',
#  '좋아요',
#  '좋음',
#  '동백이 최고입니다',
#  '굿',
#  '완전 좋아요 이런카드는 처음이에요',
#  '좋음 추천',
#  '캐시백 좋아요',
#  '굿',
#  '좋아요',
#  '좋아요ᆢ부산동백전 짱',
#  '최악 별하나도 아까움오류가 잦아 결제승인 안되었는데 돈이 빠져 등 가게 사장님과 불필요하게 얼굴 붉히는 일 경험 고객센터 공지사항도 없이 전화 통화중이라 전화받을수없다고만 대응 자체가 안됨',
#  '우차피쓸돈 꽁돈개꿀임',
#  '프로 잘쓰고있습니다감사합니다 충전계좌가 좀더 다양해지면 좋겠습니다',
#  '동백전 넘조아용 지금까지 내가 얼마모았는지도 볼수있나욤',
#  '접속을 하게 해달라고',
#  '최고임다',
#  '\U0001f970',
#  '굿',
#  '쓸수록 돈이되는 동백전 이왕이면 동백이가 조아요',
#  '갑자기 월 일금 점심시간때부터 네트워크상태가 원활하지 않습니다 연결상태를 확인 후 다시 시도해주세요라고 뜹니다 이 문제로 고객센터측에 문의하니 월 일부터 안드로이드 버전이 안되고 있다는 보고가 들어와서 해결중이다 라고 하던데요 도대체 언제 해결되는건가요 빨리 서버 오류 고쳐서 앱 사용할 수 있도록 해주세요',
#  '사용자가 많아 그러는지 느리고 에러 자주됌',
#  '경제 살림에 정말 굿 행복한 날을 위해ᆢ 감사합니다 ',
#  '프로 캐시백 너무좋아요 간혹 오류때문에 결제 안되서 난감할때도 있었지만 지금은 오류거의 없는것같아요 결제금액 합계 만들어주세요 불편해요',
#  '최고입니다',
#  '소상공인도 돕고 사용자도 포인트 받고 아주 좋습니다 연장해주시길',
#  '바로 적립된 금액을 사용할수 있어 너무 좋습니다',
#  '좋아요',
#  '괜찮게 잘 쓰고 있어요 그런데 앱이 자주 다운 되고 안 열릴때가 종종 발생해요 당장 필요할때 앱이 안열리니 살짝 멘붕이',
#  '좋아요',
#  '매우좋다',
#  '결제오류가 타카드에 비해 너무 자주나요',
#  '잘되네요',
#  '심플한UI로 딱 필요한것만 눈에띄게돼있어서 좋네요',
#  '굿',
#  '쓰면 쌓이는기분 요런기분이군요',
#  '좋긴좋아요 포인트 는 서버가자꾸 다운되요',
#  '그냥좋음',
#  '죤 어플인듯 짱 ',
#  '매우만족합니나',
#  '좋습니다굿',
#  '어플내에서 문의 답변은 언제 해주시나요 며칠이 지났는데도 답변대기 상태네요',
#  '적립 좋아요',
#  '넘 좋습니다',
#  '결제됐다 취소되고 지맘대로 카드긁은데서 재결제하러 오라해서 다시 갔다왔음',
#  '부산거주자 강추',
#  '계좌등록만하면 간편하게 충전 확인가능해요 다 좋은데 카카오뱅크도 추가해주세요',
#  '시ㅣ',
#  'good',
#  '전 잘 쓰고있어요 조금씩 보완만 잘 해주신다면 더 멋진 앱이될거 같네요',
#  '사용하기 편하고 적립도 많고 지역 상인도 도움되고좋아요',
#  '안되는 곳이 몇군데 있어서 불편하지만  돌려주니까 도움이 많이되네요',
#  '좋아요',
#  '완전좋아요 부신시민부심 철절',
#  '사용해보면 압니다',
#  '하나 같이 에러에 로딩에 ',
#  '충전을 충분히 해뒀는데은행에서 그냥 출금 처리됨 처음에 충전된 잔액에서 결재되었다가 잠시후 잔액부족이라고 뜨면서 취소 시키고 다시 연결된 은행에서 돈빼가고 이게 무슨 충전식 카드인지 고객사 통화하니 사용자 많을경우 그럴수도 있다고 결재한곳 다시 방문해서 취소하고 재결재하라고함 다시 차타고 가서 취소하고 재결재하라고 시간이 남아도나 ',
#  '프로 계속 진행 해주세요',
#  '좋아',
#  '안드로이드  사용자 입니다 얼마전까지 앱으로 충전 사용등모든 기능이 이루어졌었는데 갑자기 주말에 앱사용이 불가능해졌네요 안드로이드 이상버전만 사용가능한건가요 하위버전 구형단말기에는 사용이 불가능한가요 하위버전에서는 전혀 사용할수없는건가요',
#  '좋음',
#  '좋아요',
#  '넘 좋아요',
#  ...]

# %%
from tqdm import tqdm_notebook # 시간 바
def define_stopwords(path):
    
    SW = set()
    # 불용어를 추가하는 방법 1.
    # 특수 문자를 추가해보자.
#     for i in string.punctuation:
#         SW.add(i)
    
    # 불용어를 추가하는 방법 2.
    # stopwords-ko.txt에 직접 추가
    
    with open(path) as f:
        for word in f:
            SW.add(word[:-1])

    return SW


def text_tokenizing(corpus, tokenizer):
    # 명사 추출 / 형태소 분석 두 가지를 선택할 수 있게 만들어주는 함수를 만들어보자.
    mecab = MeCab.Tagger()
    token_corpus = []
    # tqdm을 사용하여 진행 과정을 볼 수 있게 만들어보자.
    if tokenizer == "noun":
        for n in tqdm_notebook(range(len(corpus))):
            token_text = mecab_nouns(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) >1]
            token_corpus.append(token_text)
            
    elif tokenizer == "morph":
        for n in tqdm_notebook(range(len(corpus))):
            token_text = mecab.nouns(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) >1]
            token_corpus.append(token_text)
    
    elif tokenizer == "word":
        for n in tqdm_notebook(range(len(corpus))):
            token_text = corpus[n].split()
            token_text = [word for word in token_text if word not in SW and len(word) >1]
            token_corpus.append(token_text)
            
    return token_corpus

# %%
SW = define_stopwords("D:/연구알바/stopwords-ko.txt")
tokenized_text = text_tokenizing(cleaned_corpus, tokenizer="word")
tokenized_text
# Out:
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\ipykernel_launcher.py:38: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/2871 [00:00<?, ?it/s]
# [['부산에도', '기다리던', '지역화폐가', '나왔네요', '앱도', '깔끔하고', '카드도', '신청하고', '사용하겠습니다'],
#  ['화이팅'],
#  ['기다렸었는데', '앞으로', '쓸게요'],
#  ['동백전으로', '여기저기', '많이', '사용해', '볼게요', '경제에도', '많은', '도움이', '되면', '좋겠습니다'],
#  ['쓰기', '편하게', '만들어졌네요', '부산에서', '혜택이', '많았겠네요'],
#  ['사용해', '볼게요', '동백전으로', '혜택', '많이', '받으면', '좋겠습니다'],
#  ['가자', '글로벌', '테스트베드'],
#  ['부산도',
#   '드디어',
#   '모바일',
#   '지역화폐가',
#   '나왔네요',
#   '앱설치하고',
#   '카드신청도',
#   '해봤는데요',
#   '복잡하지',
#   '않고',
#   '간편하게',
#   '구성되어',
#   '있는거',
#   '같아',
#   '좋네요',
#   '저는',
#   '수도권에',
#   '올라와',
#   '있어서',
#   '명절에',
#   '내려가면',
#   '쓰려고',
#   '하는데',
#   '카드만',
#   '긁으면',
#   '된다고',
#   '하니',
#   '엄청',
#   '편할거',
#   '같네요',
#   '내려가면',
#   '부모님도',
#   '쓰실',
#   '있게',
#   '알려드릴까',
#   '지역페이는',
#   '수당도',
#   '주고',
#   '하는거',
#   '같던데',
#   '나중에',
#   '복지비용도',
#   '이걸로',
#   '있게',
#   '나오면',
#   '부모님도',
#   '어렵지',
#   '않게',
#   '쓰실',
#   '있을거',
#   '같아',
#   '기대됩니다'],
#  ['드디어', '기다리던', '동백전앱이', '출시됐네요', '앞으로', '이용', '많이', '하겠습니다'],
#  ['군더더기', '없는', 'ui가', '마음에', '드는군요', '많은', '사업장에서', '사용가능하면', '좋겠습니다'],
#  [],
#  ['선택약정선택하면', '네트워크장애라고', '뜨면서', '진행되지', '않음부산시에서', '개인정보를', '팔아', '장사하는지'],
#  ['많은', '이용', '바랍니다', '부산시민과', '성장해', '갑시다'],
#  ['부산을',
#   '대표하는',
#   '이름으로',
#   '지은',
#   '이름이',
#   '멋지네요',
#   '부산에서',
#   '이용하는',
#   '혜택도',
#   '많아',
#   '기대가',
#   '됩니다',
#   '앱도',
#   '복잡하지',
#   '않고',
#   '사용하기',
#   '편리해',
#   '보여',
#   '한번',
#   '봐야겠네요'],
#  ['편의점에서도', '사용되나요'],
#  ['설치가', '간단하고', '쉽네요'],
#  ['군더더기', '없이', '사용하기', '편하고', '좋습니다'],
#  ['어플이', '깔끔하니', '사용하기', '자주', '사용하게', '될듯', '하네요'],
#  ['QR코드', '결제가', '안되냐', '기본인데', '카드', '신청도', '안되고', '미치겄네'],
#  ['회원가입이',
#   '돼요',
#   '다음주에',
#   '되는',
#   '사람인데요',
#   '계속',
#   '이상만',
#   '가입이',
#   '된다고',
#   '떠요',
#   '어떡해요'],
#  ['적립한도', '있게', '쓰고', '있는데', '충전한도', '말고', '적립한도도', '있게', '하면', '좋을', '같네요'],
#  ['지웠다',
#   '깔아도',
#   '들어갈',
#   '수가',
#   '없음',
#   '마트에서는',
#   '결제가',
#   '안됐다고',
#   '하고',
#   '돈이',
#   '빠졌는지',
#   '확인을',
#   '해야',
#   '하는데',
#   'xx같은',
#   '상황인지',
#   '쓸때마다',
#   '이런일이',
#   '일어나는지',
#   '충전하고나서',
#   '어플에',
#   '안들어가짐',
#   '네트워크',
#   '상태',
#   '확인하라면서',
#   '별하나도',
#   '아깝'],
#  ['오류',
#   '안고쳐주실건가요',
#   '충전하려고',
#   '앱들어가면',
#   '데이터',
#   '상태로는',
#   '들어가지지도',
#   '않고',
#   '와이파이로',
#   '들어가면',
#   '사용자',
#   '정보를',
#   '가져올수없다고하고',
#   '쓰지말라는건가요',
#   '아예',
#   '고쳐주세요',
#   '오류가',
#   '심하네요',
#   '진짜'],
#  ['오류',
#   '개선해주새오',
#   '오류가',
#   '심해요',
#   '캐시백이',
#   '안되어서',
#   '문의했더니',
#   '다시',
#   '가게에',
#   '가서',
#   '취소하고',
#   '재결제',
#   '방법밖에',
#   '없다고',
#   '하고',
#   '오류일',
#   '해결방안이',
#   '불편해요'],
#  ['앱실행이', '안됩니다', '사용자', '정보', '취득에', '실패하였다면서', '앱이', '꺼져버립니다…'],
#  ['안들어가져요', '먹통입니다다시', '설치해도', '그래요'],
#  ['정말', '오류가', '많이', '뜨네요', '오류가', '계속', '떠서', '사용하기', '힘들어요'],
#  ['발급받은',
#   '한참',
#   '지났는데',
#   '오류',
#   '충전을',
#   '못합니다',
#   '빨리',
#   '개선',
#   '부탁드립니다…',
#   '하루에도',
#   '몇번을',
#   '시도하는데',
#   '충전',
#   '금액',
#   '입력하고',
#   '나면',
#   '앱이',
#   '자동으로',
#   '꺼집니다'],
#  ['안켜져요', '계속', '오류나서', '새로', '설치했는데', '자꾸', '네트워크', '오류라고', '하네요'],
#  ['욕나올정도로', '후짐', '며칠전부터', '가맹점조회', '아예', '안됨'],
#  ['카드',
#   '결제지연',
#   '오류',
#   '카드가',
#   '사용자가',
#   '많다고',
#   '오류가',
#   '되서',
#   '계산이',
#   '안되나요',
#   '사람들이',
#   '갑자기',
#   '카드',
#   '많이',
#   '쓰는건',
#   '감안하고',
#   '처음부터',
#   '오류같은건',
#   '안나가게해야되는거아닌가요',
#   '이카드',
#   '하나만',
#   '가지고',
#   '밖에',
#   '나왔다가',
#   '분동안',
#   '안들어가져서',
#   '집갔다가',
#   '다른카드',
#   '가져왔네요',
#   '빨리',
#   '보안해주세요'],
#  ['가맹점',
#   '찾기',
#   '일까지는',
#   '문제',
#   '없었는데',
#   '서버',
#   '폭주로',
#   '접속',
#   '제한된',
#   '다음부터는',
#   '가맹점이',
#   '개입니다',
#   '가맹점은',
#   '내에서만',
#   '검색이',
#   '되는데',
#   '언제쯤',
#   '다시',
#   '가맹점을',
#   '확인',
#   '있을까요…',
#   '안드로이드',
#   '애플',
#   '됩니다'],
#  ['갑자기',
#   '가맹점',
#   '찾기가',
#   '안되요',
#   '갑자기',
#   '가맹점',
#   '찾기가',
#   '안되요',
#   '삭제후',
#   '재설치',
#   '했는데도',
#   '안되고',
#   '위치도',
#   '허용했는데',
#   '안되요'],
#  ['가맹점찾기', '가맹점찾기', '아무것도', '안뜨고', '도대체', '어딜', '봐야하나요', '오류가', '잦아요'],
#  ['가맹점',
#   '찾기가',
#   '되어',
#   '문의드립니다',
#   '정말',
#   '사용하고',
#   '있어요',
#   '캐시백',
#   '되는',
#   '것도',
#   '만족스럽습니다',
#   '전부터',
#   '가맹점',
#   '찾기가',
#   '돼요',
#   '가맹점을',
#   '찾으려고',
#   '들어가면',
#   '전체',
#   '개의',
#   '가맹점이',
#   '뜬다고',
#   '되어',
#   '있고',
#   '분명히',
#   '사용이',
#   '가능하던',
#   '가게를',
#   '검색해도',
#   '관련된',
#   '가게가',
#   '아무것도',
#   '없다고',
#   '뜹니다',
#   '평소에',
#   '자주',
#   '이용하던',
#   '가게는',
#   '찾지',
#   '않아도',
#   '되기',
#   '사용에',
#   '불편이',
#   '없지만',
#   '동네에서',
#   '벗어나서',
#   '곳으로',
#   '갔을때',
#   '사용',
#   '가능',
#   '유무를',
#   '모르기',
#   '불편합니다',
#   '제가',
#   '설정을',
#   '잘못했기',
#   '뜨지',
#   '않는',
#   '것이라면',
#   '설정에서',
#   '것을',
#   '활성화하면',
#   '되는',
#   '것인지',
#   '알려주셨으면',
#   '좋겠어요',
#   '앱의',
#   '문제라면',
#   '업데이트',
#   '해주셨으면',
#   '좋겠습니다',
#   '감사합니다'],
#  ['가맹점', '가맹점', '찾기', '아예안되요', '쓰지말라는건가요'],
#  ['어플이',
#   '진짜',
#   '구려요',
#   '오류나서',
#   '접속이',
#   '안되고',
#   '로그인도',
#   '안되고써야할',
#   '못쓰면',
#   '소용이죠',
#   '시스템안정화',
#   '신경써주세요'],
#  ['가맹점',
#   '찾기',
#   '가맹점검색하려면',
#   '만뜨고',
#   '전에는',
#   '검색이',
#   '됐는데',
#   '아무것도',
#   '안나오는데',
#   '왜이런거죠'],
#  ['오류가',
#   '장난',
#   '아니네요',
#   '포인트도',
#   '많이',
#   '쌓이고',
#   '돈쓸맛',
#   '나는데',
#   '오류가',
#   '심해서',
#   '금하게',
#   '충전하려할때',
#   '앱이',
#   '안열려서',
#   '쓰지도',
#   '못하고',
#   '하네요',
#   '개선',
#   '해주세요'],
#  ['갑자기',
#   '안들어가지죠',
#   '낮에',
#   '분명',
#   '사용하고',
#   '방금',
#   '가맹점',
#   '카페와서',
#   '사용하려고',
#   '하는데',
#   '잔액이',
#   '있음에도',
#   '계속',
#   '오류나서',
#   '어플누르니까',
#   '계속',
#   '튕기고',
#   '지웠다가',
#   '다시',
#   '깔아도',
#   '안되는데요'],
#  ['못쓰겠네요', '버그빨리', '수정요', '자꾸', '튕기니', '쓰지말라는', '뜻인가요', '빨리', '버그', '수정해주세요'],
#  ['가맹점찾기',
#   '좋은데',
#   '얼마전부터',
#   '가맹점찾기가',
#   '안되네요',
#   '계속',
#   '건만',
#   '뜹니다',
#   '빨리',
#   '해결해주세요'],
#  ['네트워크', '네트워크로', '인해', '실행이', '안된다고', '뜨네욤', '아까', '되었는데', '수정해주세욤'],
#  ['기간별',
#   '검색기능',
#   '강화',
#   '요청',
#   '예를들어',
#   '월일부터',
#   '오늘까지',
#   '사용실적',
#   '또는',
#   '적립실적',
#   '검색하면',
#   '기간동안',
#   '사용',
#   '금액',
#   '또는',
#   '적립',
#   '금액이',
#   '떴으면',
#   '좋겠습니다'],
#  ['문자인증이', '안와요', '어플이', '안켜져서', '삭제했다가', '다시', '깔았는데', '문자인증메세지가', '안와요'],
#  ['교통카드',
#   '이용내역',
#   '좋은데',
#   '카드',
#   '이용',
#   '내역에',
#   '후불교통카드로',
#   '쓰인',
#   '금액도',
#   '적혀있으면',
#   '좋을',
#   '같아요'],
#  ['한달동안',
#   '결제한',
#   '내역',
#   '합계를',
#   '있었으면',
#   '한달동안',
#   '결제한',
#   '내역',
#   '합계를',
#   '있으면',
#   '좋겠어요',
#   '하나하나는',
#   '결제',
#   '내역',
#   '확인이',
#   '되는데',
#   '합계한달에',
#   '썼는지를',
#   '있는',
#   '시스템이',
#   '없어서',
#   '지출',
#   '관리가',
#   '불편해요'],
#  ['문제가',
#   '많네요',
#   '만원',
#   '충전했다가',
#   '충전취소하고',
#   '다시',
#   '충전하려고',
#   '했더니',
#   '충전이',
#   '안되는데',
#   '충전',
#   '한도만큼',
#   '충전을',
#   '했기때문인가요',
#   '충전',
#   '취소하면',
#   '다시',
#   '충전한도가',
#   '초기화되야하는',
#   '아닌가요'],
#  ['쓰레기',
#   '신청하려고',
#   '깔았는데',
#   '에러만',
#   '벌써',
#   '번째…',
#   'KT에서',
#   '개발한거라고',
#   'SKT전화에서는',
#   '에러나게',
#   '만든거예요',
#   '진짜',
#   '그런거면',
#   '실력',
#   '인정…',
#   '제발',
#   '에러나는거',
#   '고쳐봐요'],
#  ['최악', '어플이되야쓰죠'],
#  ['금액',
#   '충전이',
#   '되고',
#   '자꾸',
#   '꺼져요',
#   '금액',
#   '충전해서',
#   '쓰고',
#   '싶은데',
#   '앱이',
#   '자꾸',
#   '다운되고',
#   '꺼져서',
#   '충전',
#   '자체를',
#   '해서',
#   '카드',
#   '발급만',
#   '받고',
#   '아예',
#   '쓰고',
#   '있네요',
#   '고객센터에',
#   '전화해도',
#   '전화',
#   '받고',
#   '문의',
#   '올려놔도',
#   '답변도',
#   '빨리',
#   '주시는',
#   '같고',
#   '실망이',
#   '크네요'],
#  ['사용내역',
#   '보려고',
#   '하면',
#   '어플이',
#   '꺼져요',
#   '충전만',
#   '되고',
#   '하려고',
#   '하면',
#   '꺼져서',
#   '쓸수가없어요'],
#  ['안켜져요', '업데이트하고나서', '어플이', '안들어가집니다', '오류', '보완', '부탁드려요'],
#  ['어플을',
#   '운영을',
#   '하실거면',
#   '불편함은',
#   '제때',
#   '개선좀',
#   '하세요',
#   '국민들',
#   '불편함',
#   '의견제기',
#   '점심시간',
#   '퇴근시간',
#   '카드승인',
#   '불가',
#   '점심시간',
#   '퇴근시간',
#   '어플',
#   '돈충전',
#   '불가',
#   '업데이트후',
#   '어플켜지지',
#   '않는',
#   '문제',
#   '불편함이',
#   '정말',
#   '많은데',
#   '좋은점캐쉬백만',
#   '광고하고',
#   '실적',
#   '쌓으시는건가요',
#   '퇴근',
#   '후에',
#   '장보러',
#   '마트가서',
#   '카드',
#   '쓰지도',
#   '못하고',
#   '기존에',
#   '쓰던',
#   '카드',
#   '씁니다',
#   '괜히',
#   '헛걸음',
#   '하게',
#   '만드시네요',
#   '좋은만큼',
#   '불편함도',
#   '큽니다',
#   '이렇게',
#   '운영하실바엔',
#   '어플',
#   '안만드는',
#   '좋을듯요'],
#  ['열면', '안들어지네요', '안들어가쟈여', '고쳐주세요'],
#  ['쓰고',
#   '있어요',
#   '렉이나',
#   '오류도',
#   '없고',
#   '캐시백도',
#   '많이',
#   '받아서',
#   '쓰는',
#   '재미가',
#   '쏠쏠하고',
#   '건의하자면',
#   '기간',
#   '한달',
#   '단위',
#   '이용자가',
#   '받은',
#   '캐시백',
#   '혜택',
#   '전체',
#   '총합을',
#   '한눈에',
#   '있으면',
#   '좋겠어요',
#   '돈을',
#   '돌려받았는지',
#   '직관적으로',
#   '있으니까',
#   '만족도도',
#   '높아질',
#   '같습니다'],
#  ['오류', '어플', '오류가', '많아요', '쓰고싶을때', '한번도', '제대로', '써본적이', '없어요'],
#  ['이번달만',
#   '오류가',
#   '몇번인지',
#   '이렇게',
#   '오류가',
#   '많이',
#   '나는데',
#   '쓰란말인가요',
#   '여분으로',
#   '다른카드',
#   '들고다녀요',
#   '개선한다면서',
#   '전혀안되고있네요',
#   '어플개발',
#   '실력자좀'],
#  ['확실히', '진짜', '좋은데…', '카카오', '뱅크', '계좌는', '등록이', '안되는건가요', '정말', '불편해요…'],
#  ['고객센터', '고객센터', '답변', '기다렸는데', '쥰나'],
#  ['결제안된다해서',
#   '다른카드로',
#   '결제했는데',
#   '동백전에선',
#   '돈이',
#   '나가네요',
#   '일반',
#   '슈퍼인데도',
#   '동백전카드가',
#   '결제가안되고',
#   '실패한다고해서',
#   '카드로',
#   '결제했는데',
#   '어플',
#   '알림보니',
#   '카드에선',
#   '돈이',
#   '나갔고',
#   '캐시백도',
#   '들어왔네요',
#   '확인하려고',
#   '어플키니까',
#   '갑자기',
#   '사용자정보',
#   '어쩌고',
#   '오류뜨면서',
#   '다시',
#   '어플키라고',
#   '계속',
#   '뜨길래',
#   '어플삭제하고',
#   '다시',
#   '깔았더니',
#   'service',
#   'unavailable',
#   '뜨네요',
#   '중결제됐는지',
#   '확인도못하고',
#   '이게뭡니까',
#   '당연히',
#   '슈퍼쪽에선',
#   '결제안됐다하고',
#   '내일',
#   '오전에',
#   '카드사',
#   '전화해야겠네요',
#   '제대로',
#   '안정화해주세요'],
#  ['가맹점',
#   '찾기',
#   '기능',
#   '개선',
#   '해주세요',
#   '가맹점',
#   '찾기',
#   '기능에서',
#   '현재',
#   '위치에서',
#   '지도를',
#   '보면',
#   '사용',
#   '가능한',
#   '가맹점이',
#   '보일',
#   '있게',
#   '해주시면',
#   '안될까요',
#   '하나씩',
#   '검색하기',
#   '불편해서…'],
#  ['좋긴한데요…',
#   '결제',
#   '어플인데',
#   '업뎃때문에',
#   '못쓴다고',
#   '막았으면',
#   '합니다',
#   '결제해야해서',
#   '잔액',
#   '보려고',
#   '들어가니',
#   '업데이트',
#   '하라고',
#   '어플이',
#   '켜지다니요',
#   '업데이트',
#   '공지',
#   '올려주시고',
#   '주요',
#   '기능은',
#   '있게',
#   '해주세요'],
#  ['백원', '단위도', '충전되게', '해주세요', '제발요', '다좋은데'],
#  ['택시는', '안되나요', '몇번', '결제할려는데', '안되네요'],
#  ['가맹점',
#   '표시',
#   '지도상에',
#   '한꺼번에',
#   '표시될',
#   '있게',
#   '주시고',
#   '띄어쓰기',
#   '잘못하면',
#   '검색이',
#   '안되던데',
#   '검색조건을',
#   '느슨하게',
#   '해서',
#   '오탈자가',
#   '있더라도',
#   '검색될',
#   '있게',
#   '해주세요'],
#  ['사용자정보취득에',
#   '실패하였습니다',
#   '사용자정보취득에',
#   '실패하였습니다',
#   '앱을',
#   '다시',
#   '실행해주세요',
#   '라는',
#   '문구가',
#   '계속',
#   '떠서',
#   '삭제',
#   '다시',
#   '깔았는데도',
#   '안되네요…',
#   '오늘',
#   '카드',
#   '받아서',
#   '충전해서',
#   '내일부터',
#   '쓸려고',
#   '했는데',
#   '사용할',
#   '수가',
#   '없네요…',
#   '빠른',
#   '해결',
#   '부탁드립니다'],
#  ['앱더럽게안됨',
#   '안들어가지고',
#   '삭제했다가',
#   '다시',
#   '들어가니',
#   '로그인',
#   '화면도',
#   '없고',
#   '회원가입하라고',
#   '인증도',
#   '안되고',
#   '먹통이고',
#   '어쩌란말임'],
#  ['갑자기',
#   '안되니까',
#   '어이없네…',
#   '갑자기',
#   '네트워크',
#   '불안정',
#   '하다고',
#   '뜨고',
#   '들어가지는',
#   '겁니까',
#   '남았는지도',
#   '봐야하고',
#   '포인트도',
#   '써야되는데',
#   '미춰버리겠네…'],
#  ['어플실행오류',
#   '어플이',
#   '갑자기',
#   '실행이',
#   '안됩니다',
#   '와이파이도하고',
#   '데이터로도',
#   '해봤지만',
#   '두개다',
#   '오류뜨네여',
#   '고쳐주세여'],
#  ['갑자기',
#   '서비스가',
#   '안돼요',
#   '개인정보',
#   '확인이',
#   '안된다고',
#   '오류메시지가뜨고',
#   '튕겨서',
#   '삭제했다',
#   '다시깔아보니',
#   'Service',
#   'unavailable',
#   '이라고',
#   '오류메시지가',
#   '떠요'],
#  ['어플',
#   '설치가안되어요',
#   '잘쓰고있었는데',
#   '금일',
#   '저녁',
#   '씨유에서',
#   '카드',
#   '주니',
#   '포스기에서',
#   '결제가',
#   '안된다고',
#   '했는데',
#   '어플로는',
#   '결제가',
#   '되어서',
#   '확인위해',
#   '어플',
#   '들어가니',
#   '튕기고',
#   '어플',
#   '삭제하고',
#   '다시까지',
#   '에러',
#   '서버',
#   '뜨면서',
#   '아예',
#   '사용할수없게되엇어요',
#   '해야하나요'],
#  ['본인인증단계에서', '인증문자가', '안와요', '개선해주세요', '본인인증단계에서', '인증문자가', '안와요', '개선해주세요'],
#  ['덕분에',
#   '씁니다',
#   '오랜만에',
#   '제대로',
#   '만들었다',
#   '싶네요',
#   '놀라울',
#   '정도로',
#   '간결하고',
#   '간편한',
#   '앱이에요',
#   '카드',
#   '발급받고',
#   '쓰고',
#   '있습니다'],
#  ['빠르고',
#   '좋은',
#   '앱이네요',
#   '메인화면',
#   '하단',
#   '카드바가',
#   '메인',
#   '화면',
#   '진입시',
#   '움직이는',
#   '모션은',
#   '예쁘고',
#   '좋은데',
#   '급하게',
#   '카드에',
#   '돈없어서',
#   '충전',
#   '할려',
#   '할때마다',
#   '움직이니까',
#   '계속',
#   '캐시백',
#   '사용설정',
#   '메뉴로',
#   '들어가서',
#   '불편하네요',
#   '그외에는',
#   '빠르고',
#   '만족합니다'],
#  ['내가',
#   '보유한동백전',
#   '칸에',
#   '불필요한건',
#   '삭제',
#   '잘쓰고있습니다',
#   '근데',
#   '충전할라고',
#   '켜면',
#   '맨날',
#   '내가보유한',
#   '칸에',
#   '포인트',
#   '내역과',
#   '부산시민이라면',
#   '지금은동백전',
#   '무렵이라는',
#   '아무기능없는',
#   '광고만',
#   '뜨고',
#   '있어야',
#   '충전',
#   '칸으로',
#   '옮겨져',
#   '맨날',
#   '잘못클릭하게되네요',
#   '현황에는',
#   '충전금액과',
#   '포인트만',
#   '표시하고',
#   '안움직이게',
#   '해두면',
#   '시안성과',
#   '활용성에도',
#   '좋을거같습니다',
#   '앱화면은',
#   '동백전할라고',
#   '앱설치한',
#   '사람한테만',
#   '보이느거니',
#   '광고내용은',
#   '불필요할거같네요',
#   '아래쪽으로',
#   '내렸을때',
#   '나오게',
#   '하든가'],
#  ['좋습니당'],
#  ['사용', '내역', '볼려고하면', '계에에에에속', '나가지네요', '빨리', '고쳐', '주세요'],
#  ['큐알', '코드', '결제', '부탁…', '실물', '카드로만', '되는', '보네여…', '아이폰은', '웁니다'],
#  ['클릭', '안됨', '가입', '하고', '마지막에', '비밀번호', '설정하는', '클릭이', '안되네요'],
#  ['쓰라는거야', '카드', '신청도', '안되고', '계좌', '등록도', '안되고'],
#  ['너무좋아요',
#   '쓰지도',
#   '않았는데',
#   '캐시백',
#   '쏠쏠해요',
#   '단위',
#   '충전도',
#   '가능해서',
#   '현명한',
#   '소비가',
#   '가능해요'],
#  ['정말', '잘쓰고', '있습니다', '굿굿'],
#  ['금액을',
#   '직접',
#   '설정해서',
#   '충전하면',
#   '좋겠어요',
#   '정해진',
#   '금액만',
#   '말고',
#   '사용자가',
#   '충전하고',
#   '싶은',
#   '금액을',
#   '입력해서',
#   '충전할',
#   '있었으면',
#   '좋겠어요'],
#  ['가맹점',
#   '찾기라뇨',
#   '생각보다',
#   '안되는곳도',
#   '많고',
#   '충전금액',
#   '환불은',
#   '안되는거죠',
#   '계속',
#   '실패했다고',
#   '뜨는데'],
#  ['가맹점',
#   '찾기',
#   '왜있나요',
#   '되는곳도있고',
#   '아닌곳이있고',
#   '그게',
#   '헷갈려서',
#   '찾기',
#   '서비스가',
#   '있는거',
#   '아닌가요',
#   '왜이렇게',
#   '안되는곳이',
#   '많죠',
#   '충전식이라서',
#   '다른통장에서',
#   '돈을',
#   '뺐는데',
#   '안된다니',
#   '지도상',
#   '틀린곳도',
#   '많습니다'],
#  ['가맹점이', '두개씩', '중복되서', '나와요', '가맹점', '검색하면', '중복해서', '나와서', '보기', '힘들어요'],
#  ['인증안됩니다',
#   '전화번호',
#   '누르고',
#   '인증하기',
#   '버튼이',
#   '먹통이네요',
#   '혜택도',
#   '좋은데',
#   '이러다',
#   '잊혀져',
#   '갈까',
#   '걱정입니다'],
#  ['QR코드',
#   '간편결제도',
#   '되었으면',
#   '좋겠어요',
#   '카카오페이처럼',
#   'QR코드로',
#   '간편결제도',
#   '되었으면',
#   '좋겠어요',
#   '안드로이드는',
#   '삼성페이도',
#   '되는데',
#   '아이폰은',
#   '안되니까',
#   '아쉽네요',
#   'QR코드',
#   '간편결제만',
#   '되면',
#   '점만점에'],
#  ['최고',
#   '충전하면',
#   '캐쉬백도',
#   '해주고',
#   '가정생활에',
#   '많은',
#   '도움이',
#   '되네요',
#   '지하철도',
#   '되고',
#   '계좌연결하면',
#   '카드처럼',
#   '사용할',
#   '수도',
#   '있고'],
#  ['할인', '많이', '되네요', '할인', '생각보다', '많이', '되네요', '가맹점', '늘려주시길'],
#  ['안증안되요', '쓰고싶어도', '인증이안되니', '쓸수가없네요'],
#  ['출시기념',
#   '한달간',
#   '이벤트를',
#   '하는데',
#   '지났는데도',
#   '아직',
#   '다운로드를',
#   '받지',
#   '못하는',
#   '어플이',
#   '두둥',
#   '이것이',
#   '붓싼의',
#   '정책이다',
#   '이집',
#   '지역화폐',
#   '잘하네'],
#  ['기다렸는데', '드디어', '빨리', '가입', '흥해라'],
#  ['개쓰레기', '같은', '앱이', '있어', '죽도록', '카드신청해도', '안됨', '안써'],
#  ['앱에서',
#   '결제되게',
#   '해주세요',
#   '좋다',
#   '좋다',
#   '많이',
#   '듣고',
#   '드디어',
#   '실물카드',
#   '받았습니다',
#   '근데',
#   '충전',
#   '상황',
#   '캐시백',
#   '상황',
#   '앱에서',
#   '확인하는데',
#   '이왕이면',
#   '앱으로',
#   '결제도',
#   '있게',
#   '해주세요',
#   '불편해요…',
#   '아이폰도',
#   '편하게',
#   '쓰게',
#   '줘요'],
#  ['실행이',
#   '안됩니다',
#   '어플을',
#   '실행시키면',
#   '알림설정',
#   '창과',
#   '필수동의',
#   '까지는',
#   '되는데',
#   '화면에',
#   'Service',
#   'Unavailable',
#   '이라는',
#   '오류가',
#   '뜨고',
#   '아무것도',
#   '안되요'],
#  ['쓸만하네요', '캐시백', '비율이', '높아서', '쓰는데', '좋네요'],
#  ['국굿', '아이폰', '바코드나', '큐알코드', '결제만', '앱에서', '가능', '하면', '최고일것', '같아요'],
#  ['어플', '오류', '아예', '접속', '불가'],
#  ['좋은데', '앱실행이', '안되요', '저만', '안되나요'],
#  ['오류',
#   '빨리좀',
#   '해결해주세요',
#   '잘사용하다가',
#   '앱켜면',
#   '사용자정보를',
#   '읽을수없다고',
#   '다시시도해라고',
#   '하길래',
#   '지웠다가',
#   '다시',
#   '설치했는데',
#   '아예',
#   '다운되서',
#   '깔아서',
#   '넘어가지도',
#   '않네요',
#   '빨리',
#   '해결',
#   '해주세요',
#   '잘쓰고있었는데'],
#  ['잘사용하고있었는데',
#   '사용하고있던',
#   '중이었는데',
#   '갑자기',
#   '오류로',
#   '안들어가져서',
#   '앱삭제하고',
#   '새로',
#   '깔았는데',
#   '계속',
#   '오류나네요',
#   '해결할수',
#   '있을까요'],
#  ['아예오류나고안들어가져요', '오류나고', '아예안들어가지는데', '어떻게요', '서버없다고만', '뜨고요'],
#  ['사용자찾을',
#   '없다고',
#   '오류가',
#   '계속',
#   '뜨고',
#   '넘어가질',
#   '않는데',
#   '왜그럴까요',
#   '어플',
#   '삭제',
#   '후에',
#   '다시',
#   '켜도',
#   'service',
#   'unavailable',
#   '오류만',
#   '뜨는데',
#   '해결하나요…',
#   '카드까지',
#   '발급받았습니다'],
#  ['어제까지',
#   '앱실행',
#   '됐는데',
#   'No',
#   'server',
#   'is',
#   'available',
#   'to',
#   'handle',
#   'this',
#   'request',
#   '오늘은',
#   '서버가',
#   '없다고',
#   '하네요'],
#  ['오류거지같음',
#   '쓸때마다',
#   '앱자체',
#   '오류도',
#   '많이',
#   '나고',
#   '이용자수',
#   '많다면서',
#   '결제도',
#   '안되고',
#   '툭하면',
#   '점검들어간다하고',
#   '동백전에',
#   '충전해서',
#   '체크카드에서',
#   '출금이',
#   '됬는데',
#   '동백전에는',
#   '충전금액',
#   '뜨지도',
#   '않네요',
#   '돈은',
#   '어디로',
#   '간거임',
#   '별개도',
#   '아까움'],
#  ['오류', '뜨면서', '실행안되네요', '우째해야되나요'],
#  ['넣었는데', '어플', '실행이', '안돼요', '쓰다가', '남아있는데', '어플', '실행이', '안돼요', '뭔데요'],
#  ['오류',
#   '갑자기',
#   '오늘',
#   '접속오류',
#   '계속',
#   '뜨길래',
#   '삭제',
#   '다시',
#   '깔았더니',
#   '아예',
#   '안되네요',
#   '빠른시일내에',
#   '업데이트',
#   '부탁드립니다',
#   '아예',
#   '접속을',
#   '못하니',
#   '이용불가입니다'],
#  ['아이폰', '충전안됨', '충전하러', '가면', '튕겨요'],
#  ['내역만',
#   '들어가면',
#   '팅김',
#   '내역에',
#   '들어가면',
#   '팅겨요',
#   '아이폰',
#   'xs입니다',
#   '내역',
#   '확인',
#   '가능한',
#   '싸이트가',
#   '있으면',
#   '알려주세요',
#   '답답해',
#   '미쳐버리겠네요'],
#  ['카드신청안됨',
#   '하고',
#   '마지막에',
#   '계속',
#   '오류가',
#   '나요',
#   '청구서',
#   '수령관련',
#   '등록을',
#   '해야된다는데',
#   '중간에',
#   '그런거',
#   '입력하는',
#   '부분도',
#   '없고',
#   '어쩌라는건지'],
#  ['왜때문에',
#   '인증이안되나효',
#   '내이름에',
#   '탄생일에',
#   '명의의',
#   '핸드폰번혼데',
#   '자꾸',
#   '확인하래',
#   '내가',
#   '난데',
#   '나라는걸',
#   '인증을',
#   '못해'],
#  ['고객',
#   '서비스가',
#   '최악이네요',
#   '어플',
#   '오류로',
#   '인하여',
#   '충전',
#   '하려고',
#   '하니',
#   '바탕화면으로',
#   '팅기는데',
#   '문의를',
#   '넣어도',
#   '일동안',
#   '응답',
#   '안하고',
#   '전화는',
#   '하루에',
#   '번씩',
#   '해도',
#   '하루종일',
#   '바빠서',
#   '못받는다고',
#   '하네요'],
#  ['안들어가져요', '업데이트', '했는데', '안들어가져요', '해결', '해주세여'],
#  ['꺼짐',
#   '문제',
#   '들어가서',
#   '캐쉬백을',
#   '누르면',
#   '앱이',
#   '꺼져버리는데',
#   '해야되나요',
#   '다시깔아도',
#   '마찬가지',
#   '입니다'],
#  ['불안정한', '이용내역', '확인', '강제종료', '메뉴도', '간단하고', '서비스도', '훌륭한데'],
#  ['주민등록증',
#   '찍는데',
#   '청소년들은',
#   '청소년증으로',
#   '하라해서',
#   '청소년증',
#   '찍고',
#   '발급날짜',
#   '했는데',
#   '면허번호',
#   '그거',
#   '오류라고',
#   '뜨면서',
#   '청소년한테',
#   '면허번호가',
#   '어딨어요'],
#  ['개선사항',
#   '요청하고',
#   '싶습니다',
#   '본인',
#   '인증',
#   '수단을',
#   '공인인증서도',
#   '추가',
#   '하였으면',
#   '좋겠습니다',
#   '어머니도',
#   '발급해드리려는데',
#   '어머니가',
#   '핸드폰을',
#   '명의로',
#   '사용하고',
#   '있습니다',
#   '어머니도',
#   '발급해드리려고',
#   '하는데',
#   '앱을',
#   '깔아',
#   '드릴수가',
#   '없네요',
#   '다른건',
#   '좋습니다'],
#  ['어플설치',
#   '저는',
#   '아이폰이라',
#   '설치를',
#   '했지만',
#   '아버지도',
#   '어플',
#   '설치해드리려고',
#   '하니',
#   '갤럭시노트는',
#   '오래된',
#   '폰이라고',
#   '안된다고',
#   '하네요',
#   '부산지역화폐인데',
#   '설치하여',
#   '사용할',
#   '있게',
#   '낮은버전의',
#   '폰에도',
#   '어플',
#   '설치가',
#   '가능하도록',
#   '해주시면',
#   '좋을',
#   '같아요'],
#  ['어플',
#   '팅김현상',
#   '월달부터',
#   '사용하다가',
#   '오늘',
#   '업데이트를',
#   '했는데',
#   '어플',
#   '접속이',
#   '안됩니다',
#   '어플',
#   '누르면',
#   '화면',
#   '뜨고',
#   '초뒤',
#   '바탕화면으로',
#   '팅겨버려요'],
#  ['동백점',
#   '미가맹점',
#   '결제',
#   '가능',
#   '요청',
#   '사용중입니다',
#   '감사합니다',
#   '동백점',
#   '미가맹점에도',
#   '일반',
#   '체크카드처럼',
#   '캐쉬백은',
#   '안되어도',
#   '결제는',
#   '가능했으면',
#   '좋겠습니다',
#   '처음',
#   '방문하는',
#   '사업장에',
#   '카드를',
#   '주면',
#   '결제',
#   '실패로',
#   '안된다고',
#   '돌려받고',
#   '카드로',
#   '결제를',
#   '해야하는',
#   '경우가',
#   '발생하니',
#   '불편한',
#   '감이',
#   '있네요',
#   '캐쉬백사용',
#   'onoff처럼',
#   '미가맹점결제여부도',
#   'onoff',
#   '기능을',
#   '추가해주시면',
#   '시간도',
#   '절약되고',
#   '편리할거',
#   '같습니다'],
#  ['아이폰에서도', '있어', '아이폰에서도', '있어서', '자주', '사용해야지'],
#  ['아이폰', '드디어', '출시됐네요…', '쓸게요…'],
#  ['노트에서는',
#   '버전이',
#   '낮아서',
#   '검색이',
#   '안되는데',
#   '어느버전',
#   '가능',
#   '한가요',
#   '다운',
#   '없이',
#   '카드만',
#   '사용가능한가요'],
#  ['부산경제를', '위한', '동백전이네요', '혜택을', '주니', '사용하겠습니다', '사용이', '편리하네요'],
#  ['아이폰은', '안되나요'],
#  ['이름도', '이쁘고', '앱도', '깔금하게', '잘되어', '있네요'],
#  ['정말', '편리하네요'],
#  ['부산시에도', '지역화폐가', '생겼네요', '이름', '좋고', '화면도', '깔끔하네요'],
#  ['심플하고', '사용하기', '편하네요', '잡다한', '기능보다', '기본에', '충실한게', '좋죠'],
#  ['부산에서도', '이제', '사용이', '가능하군요많니', '기대가', '됩니다'],
#  ['QR기반',
#   '회사',
#   'KT가',
#   '카드를',
#   '발행해요',
#   '카드는',
#   '하나카드네',
#   '하도인가',
#   '대기업들',
#   '대단하네요',
#   '신청하는데',
#   '개인정보를',
#   '이렇게나',
#   '많이',
#   '요구하는거임',
#   '개인정보',
#   '간소화',
#   '시대에'],
#  ['부산은행은', '결제계좌로등록이안됨'],
#  ['카드도',
#   '발급받고',
#   '가입도',
#   '했는데',
#   '새로',
#   '실행할때마다',
#   '인증된',
#   '폰번호와',
#   '현재',
#   '폰번호가',
#   '다릅니다',
#   '재인증하셔서',
#   '사용해주세요',
#   '이렇게',
#   '뜨는데',
#   '해야하나요'],
#  ['가입하고',
#   '카드',
#   '신청해놓고',
#   '아직',
#   '사용은',
#   '안해',
#   '봤지만',
#   '어플은',
#   '정말',
#   '만들었네요',
#   '박수',
#   '짝짝짝',
#   '이름도',
#   '정말',
#   '잘지었고',
#   '여러',
#   '기능',
#   '빼버리고',
#   '자주',
#   '이용하는',
#   '기능만',
#   '넣어서',
#   '깔끔하고',
#   '심플해서',
#   '좋네요',
#   '정말',
#   '앱은',
#   '대만족입니다',
#   '부산시민으로서',
#   '잘되길',
#   '바랍니다',
#   '충전에서',
#   '계좌연결',
#   '은행이랑',
#   '카드신청',
#   '계좌연결',
#   '은행이랑',
#   '차이가',
#   '뭔가요'],
#  ['부산이', '살아야', '대한민국이', '산다', '부산지역경제를', '똑똑한', '소비'],
#  ['신청'],
#  ['개인', '정보', '입력만', '했습니다', '어이없는', '오류', '뭡니까'],
#  ['들어갈려면',
#   '꼭세네번만에들어감프로그램',
#   '개발을',
#   '한것인지짜증나네S',
#   '사용하고',
#   '있음',
#   '충전',
#   '금액을',
#   '만원도',
#   '넣어',
#   '놓아야지만원',
#   '입금할려면만원세번을',
#   '해야됨'],
#  ['아직', '사용', '경험이', '없어', '모르겠습니다'],
#  ['시안성과',
#   '디자인도',
#   '뛰어나',
#   '사용이',
#   '간편하며',
#   '다양한',
#   '혜택이',
#   '있어',
#   '무조건',
#   '강추',
#   '합니다',
#   '동백전의',
#   '매력에',
#   '빠져',
#   '살고',
#   '있읍니다'],
#  ['이벤트기간에', '사용하면', '캐시백', '지급되구요', '평상시엔', '적립이', '되어서', '사용합니다'],
#  ['사용시', '가입자에게', '혜택이', '매우', '큰것', '같습니다', '적극', '사용할께요'],
#  ['조아요'],
#  ['사용편리해서'],
#  ['캐시백', '개꿀'],
#  ['네트워크오류로', '계속안들어가', '지는데', '원래이런건가요', '답답하네요'],
#  ['편하고'],
#  ['오늘',
#   '카드발급',
#   '앱을',
#   '깔아',
#   '하나은행',
#   '계좌를',
#   '등록했는데',
#   '결제상황',
#   '보유내역',
#   '전혀나오지않습니다알려주세요'],
#  ['응원할께요'],
#  ['설치후', '사용해보니', '새로운', '세상이', '열리네요'],
#  ['앱도', '편리해서', '사용도', '좋고', '캐시백도', '좋네요굿'],
#  ['사용이', '편리하고', '디자인도', '멋집니다'],
#  ['혜택이', '혜자스럽네요'],
#  ['바로바로', '캐시백이', '들어오니까', '혜택이', '더욱', '크게', '느껴지네요', '굿입니다', 'bb'],
#  ['앱설치',
#   '사용해보니',
#   'App',
#   '디자인도',
#   '세련되었고',
#   '심플한것이',
#   '너무너무',
#   '마음에',
#   '들어요',
#   '많이들',
#   '사용',
#   '강추드립니다'],
#  ['동백전을',
#   '설치',
#   '사용해보니',
#   '새로운',
#   '세상이',
#   '열리네요',
#   '앞으로',
#   '카드사용은',
#   '자제하고',
#   '무조건',
#   '동백전을',
#   '이용할',
#   '예정입니다',
#   '디자인도',
#   '깔끔하고',
#   '사용하기에',
#   '정말',
#   '편리합니다',
#   '저의',
#   '별점은',
#   '백점',
#   '만점에',
#   '백점'],
#  ['캐쉬백'],
#  ['사용하기에', '매우', '편리'],
#  ['체크카드라서', '퍼센트', '페이백', '좋네요', '프로모션기간이', '길었으면', '좋겠어요'],
#  ['qr코드결제도', '어서', '됐으면', '좋겠네요'],
#  ['Good'],
#  ['좋은것', '같아요ᆢ'],
#  ['새마을금고', '없어', '카드발급', '안돼요', '괜히', '충전하여', '환불', '해주세요', '사용도', '하는데'],
#  ['괜찮아요'],
#  ['캐시백도', '사용가능하고', '매우만족'],
#  ['신나네요'],
#  ['카드만들다', '사용', '포기합니다'],
#  ['할인폭이', '크고', '편리해요', '상공인에게', '도움된다니', '더욱', '좋네요'],
#  ['동백전으로', '이용할', '생각', '입니다', '사용하기', '편리', '합니다'],
#  ['만족'],
#  ['충전하려니깐', '카카오뱅크가', '없네요'],
#  ['본인명의폰', '아닌사람은', '가입을', '못하네요', '공인인증같은거나', '인증할수있는방법', '생기게', '해주세요'],
#  ['유용한',
#   '서비스네요',
#   '충전하구',
#   '카드',
#   '받아서',
#   '쓰는',
#   '좋구',
#   '쓰고나니',
#   '캐쉬백이',
#   '들어오구',
#   '디자인도',
#   '깔끔하구',
#   '기능도',
#   '심플하구',
#   '직관적입니다',
#   '만드시느라',
#   '고생하셨어요'],
#  ['안들어가지네요'],
#  ['어플에서',
#   '결제가',
#   '됐으면',
#   '좋겠어요',
#   '카드',
#   '발급',
#   '받는',
#   '시간도',
#   '오래',
#   '걸리고',
#   '은행도',
#   '지정돼',
#   '있어서',
#   '불편하네요'],
#  ['매우', '유용합니다', '가족이', '쓰고', '있어요'],
#  ['좋습니다😊'],
#  ['동백전을', '사용해', '보니', '사용하면', '할수록', '차곡', '차곡', '적립되는', '캐시백'],
#  ['휴대폰', '단말기', '살때도', '캐시백', '되나요'],
#  ['어려워요',
#   '충전방식이라',
#   '많이',
#   '번거롭네요',
#   '폰결제',
#   '되는',
#   '쉬은',
#   '방법으로',
#   '업그레이드',
#   '부탁드립니다'],
#  ['문의', '답변확인이', '안되네요', '호완성문제인지', '다른어플은', '정상적으로', '작동하는데', '이것만', '먹통이에요'],
#  ['정말', '사용하기', '편하고', '좋습니다'],
#  ['계좌등록이', '계속', '실패로', '떠서', '사용이', '불가능함'],
#  ['깔끔하고', '혜택', '좋고'],
#  ['회원가입', '동의사항들전부선택햇는데도', '안넘어가지는데', '오류인가요'],
#  ['치명적인',
#   '단점',
#   '지적합니다',
#   '환불정책',
#   '정말',
#   '불편하네요',
#   '전체',
#   '적립금에',
#   '써야',
#   '나머지',
#   '금액',
#   '환불이',
#   '가능하게',
#   '해놓는',
#   '것은',
#   '불편합니다',
#   '부분환불도',
#   '안되고',
#   '전체',
#   '환불만',
#   '된다니요',
#   '미리',
#   '현금을',
#   '충전을',
#   '했다가',
#   '현금이',
#   '필요해',
#   '일부',
#   '환불',
#   '받으려하면',
#   '환불이',
#   '안됩니다',
#   '환불제도',
#   '다시',
#   '검토하셔야',
#   '같아요',
#   '만원',
#   '넣고',
#   '만원',
#   '때까지',
#   '환불이',
#   '안된다면',
#   '현금',
#   '필요한',
#   '사람들',
#   '어쩌란말인가요',
#   '쓰시는',
#   '분들은',
#   '미리',
#   '충전하면',
#   '환불받기',
#   '어려우니',
#   '쓸만큼만',
#   '조금씩',
#   '충전하셔야',
#   '같네요'],
#  ['회원가입할때',
#   '직장주소',
#   '검색하고',
#   '다시들어오니까',
#   '어플',
#   '끄지도',
#   '않았는데',
#   '처음부터',
#   '다시',
#   '입력해야',
#   '되네요',
#   '개선바랍니다'],
#  ['계좌등록하려니',
#   '계속',
#   '계좌번호',
#   '오류라고하는데',
#   '왜그런거예요',
#   '숫자',
#   '잘못친줄알고',
#   '번은',
#   '넣어좟어여',
#   '계좌',
#   '안되는데',
#   '화가나네요'],
#  [],
#  ['교통카드버스나', '지하철만', '써도', '캐시백', '되나요'],
#  ['앱이', '다운로드가', '안되고', '계속', '로딩', '중이네요', '서버좀', '늘려요'],
#  ['본인명의',
#   '핸펀만가능한거가요',
#   '아이핀이나',
#   '본인인증다른방법도',
#   '하게',
#   '해주세요',
#   '배우자나',
#   '부모명의인사람은',
#   '쓸수가없네요'],
#  ['들어가지지도', '않구만', '전화도', '안받고', '장난합니까'],
#  ['가맹점찾기가', '불편하네요', '지도에서', '찾기', '기능이', '있으면', '찾기', '편할것', '같아요'],
#  ['접속시',
#   '계속',
#   '팅김',
#   '카드신청과정에서도',
#   '불안정함',
#   '주민번호',
#   '입력하면',
#   '자꾸',
#   '다른숫자로',
#   '인식함',
#   '카드신청부터',
#   '이래서',
#   '쓰다가',
#   '관리하나라는',
#   '생각에',
#   '못쓰겟다싶네요'],
#  ['카드도', '예쁘고', '앱도', '깔끔해서', '편하게', '사용할', '같네요'],
#  ['기능도',
#   '만족스럽고',
#   '검색해서',
#   '가맹점',
#   '찾을',
#   '있는거',
#   '좋은거',
#   '같아요',
#   '카드발급신청했을때',
#   '진행도를',
#   '수가',
#   '없어서',
#   '불편하네요',
#   '어플에서',
#   '확인',
#   '있으면',
#   '좋겠어요',
#   '디이터로',
#   '접속하면',
#   '접속이',
#   '안되던데',
#   '왜그런가요'],
#  ['살인데',
#   '카드',
#   '발급받을때',
#   '주민등록증',
#   '번호를',
#   '작성하라는데',
#   '주민등록증이나',
#   '운전면허가',
#   '없는학생은',
#   '어떻하나요'],
#  ['최악임', '깔고나서', '본인인증문자아안옴'],
#  ['실행이', '안됩니다', '네트워크', '상태를', '확인하라는', '매세지만', '뜨네요'],
#  ['가맹점',
#   '찾기',
#   '카테고리를',
#   '구별로',
#   '나누어',
#   '주셨으면',
#   '좋겠습니다',
#   '시작하니까',
#   '해운대구',
#   '찾을려면',
#   '한참을',
#   '내려가야해서',
#   '불편한',
#   '부분이',
#   '있네요'],
#  ['정말', '유용한', '앱이네요'],
#  ['동백전가입시', 'LGU알뜰폰은', '인증이', '안돼', '가입이', '안됩니다', '조정바랍니다'],
#  ['정말',
#   '어디다가',
#   '리뷰를',
#   '써야될지',
#   '몰라서',
#   '씁니다',
#   '적립이',
#   '이루어지는점이',
#   '좋고',
#   '원하는만큼',
#   '충전할',
#   '있어서',
#   '가맹점',
#   '찾기',
#   '기능도',
#   '매우',
#   '유용합니다',
#   '적립금을',
#   '사용하는거도',
#   '모드',
#   'on',
#   '해놓으면',
#   '되어서',
#   '간단해요',
#   '포인트로',
#   '사용할때',
#   '미안하거나',
#   '민망할때',
#   '있는데',
#   '동백전은',
#   '그럴일',
#   '전혀',
#   '없음',
#   '사용',
#   '후에',
#   '사용',
#   '가능한',
#   '곳에',
#   '많이',
#   '방문하게',
#   '되는거같아요',
#   '지역화폐',
#   '취지에',
#   '맞게',
#   '사용하고',
#   '있습니다',
#   '앞으로도',
#   '적극',
#   '사용하고',
#   '주변에도',
#   '추천할게요',
#   '감사합니다'],
#  ['아직',
#   '써보지도',
#   '못했을',
#   '뿐더러',
#   '예기치못한',
#   '오류라며',
#   '접속조차',
#   '안되네요',
#   '부산지역화폐가',
#   '나와서',
#   '기대했는데',
#   '실망스럽습니다'],
#  ['앱을',
#   '다운받아',
#   '회원가입',
#   '단계까진',
#   '잘되나',
#   '다음단계에서',
#   '처음단계로',
#   '되돌아가버려',
#   '회원가입이',
#   '되질',
#   '않아요',
#   '은행에',
#   '가봐도',
#   '별다른',
#   '방법이',
#   '없고',
#   '답답한',
#   '마음에',
#   '문의드립니다',
#   '동백전꼭',
#   '사용하고',
#   '싶어요',
#   '휴대폰은',
#   'lg',
#   '안드로이드버전',
#   '커널버전'],
#  ['어제부터', '통신중예기치않은', '오류라고', '앱사용이', '불가합니다', '무슨문제인거고', '정상화되나요'],
#  ['본인인증',
#   '방법이',
#   '폰인증',
#   '밖에',
#   '없나요',
#   '본인명의의',
#   '폰이',
#   '아닌',
#   '사람은',
#   '발급이',
#   '불가하나요'],
#  ['추천인은', '써야하나요', '한글은', '안써지고', '숫자는', '써지는데', '휴대폰번호를', '쓰는것도', '아닌것같고'],
#  [],
#  ['카드신청에',
#   '들어가서',
#   '카드선택후',
#   '신청하기누르면',
#   '일정기간',
#   '미사용으로',
#   '작업이중단됩니다요래떠요',
#   '삭제하고',
#   '다시',
#   '깔아도',
#   '그렇고뭘',
#   '신청할수가',
#   '없는데',
#   '우찌해야될까요'],
#  ['다운받았는데',
#   '카드신청이',
#   '안되네요',
#   '계좌등록하고',
#   '충전',
#   '후에',
#   '카드신청',
#   '가능한건가요',
#   '사용설명서가',
#   '있으면',
#   '좋을것',
#   '같아요'],
#  ['회원가입시',
#   '인증번호가',
#   '안옵니다',
#   '이틀째',
#   '가입중인데',
#   '인증번호가',
#   '계속',
#   '수신이',
#   '안되는데',
#   '뭐가',
#   '문제일까요'],
#  ['지금', '카드사용', '불가네요', '통신오류', '뜹니다'],
#  ['가맹점', '검색에서', '지역을', '지정', '검색', '가능하도록', '기능', '추가', '부탁', '드립니다'],
#  ['네트워크',
#   '상태',
#   '원할하지',
#   '않습니다',
#   '계속',
#   '뜨네요',
#   '해결',
#   '하셔야',
#   '할듯합니다',
#   '속도',
#   '제한',
#   '데이터',
#   'Mbps',
#   '일떄는',
#   '실행도',
#   '안되네요',
#   '빨리',
#   '개선해야',
#   '하실듯요',
#   '데이터',
#   '속도가',
#   '느린',
#   '폰들은',
#   '아예',
#   '이용도',
#   '못하겠네요'],
#  [],
#  ['껐다가',
#   '켜면',
#   '다시',
#   '처음부터',
#   '인증해야',
#   '하는',
#   '치명적인',
#   '버그가',
#   '존재합니다',
#   '충전',
#   '껐다가',
#   '다시',
#   '켰더니',
#   '문자인증',
#   '다시',
#   '하고',
#   '비밀번호',
#   '새로',
#   '설정해야',
#   '합니다',
#   '벌써',
#   '번째입니다',
#   '들어갈때마다',
#   '인증된',
#   '폰번호와',
#   '현재',
#   '폰번호가',
#   '일치하지',
#   '않습니다',
#   '번호',
#   '변경시',
#   '초기화하기',
#   '메뉴',
#   '선택후',
#   '재인증하셔서',
#   '사용해주세요',
#   '종료',
#   '초기화하기라는',
#   '창이',
#   '뜨면서',
#   '다시',
#   '처음부터',
#   '인증해야',
#   '들어가지고',
#   '다시',
#   '인증받고',
#   '계좌',
#   '연결해서',
#   '충전후',
#   '껐다가',
#   '다시',
#   '켜면',
#   '창이',
#   '뜨면서',
#   '처음부터',
#   '인증을',
#   '해야',
#   '합니다',
#   '하나은행',
#   '체크카드를',
#   '주세요',
#   '하나은행',
#   '계좌',
#   '만들었는데',
#   '하나은행',
#   '체크카드를',
#   '안주고',
#   '체크카드만',
#   '주나요',
#   '이래서야',
#   '돈을',
#   '수가',
#   '없잖아요',
#   '충전을',
#   '해야',
#   '돈을',
#   '있는데',
#   '충전하러',
#   '들어갈',
#   '때마다',
#   '처음부터',
#   '인증을',
#   '해야',
#   '하면',
#   '누가',
#   '씁니까',
#   '사용중인',
#   '스마트폰은',
#   'KT',
#   '화웨이',
#   '비와이입니다',
#   '국민은행은',
#   '유심',
#   '인식',
#   '안되도',
#   '공인인증서로',
#   '로그인이',
#   '되는데',
#   '동백전은',
#   '그런것도',
#   '없나요'],
#  ['친구가', '캐시', '들어오더라고', '추천해줌'],
#  ['지역경제에', '기여하면서', '캐쉬백도', '가능한', '동백전이', '있으니', '더이상의', '카드는', '필요없네요'],
#  ['좋아여'],
#  ['최고'],
#  [],
#  [],
#  ['세금공제', '프로'],
#  ['최고'],
#  ['부산의',
#   '주유소에서',
#   '사용이',
#   '안된다하여',
#   '난감한',
#   '경험있습니다',
#   '사용가능하도록',
#   '지원',
#   '배려',
#   '바랍니다',
#   '감사합니다'],
#  ['쓰자마자', '깨시가', '들어오니깐', '완전짱입니다'],
#  ['슈퍼에서',
#   '우유를',
#   '샀읍니다',
#   '적립',
#   '되여',
#   '기분',
#   '좋았읍니다',
#   '택시는',
#   '개인',
#   '일반',
#   '택시도',
#   '안되더라고요',
#   '언제쯤',
#   '택시',
#   '될가요'],
#  ['편하고'],
#  ['실물카드받았는데', '어플엔', '등록안되어있어요'],
#  ['지역', '자영업에', '도움이', '됩니다'],
#  ['소상공인과', '시민들에게', '좋은', '제도네요'],
#  ['걸제불가능한', '곳에', '대한', '정보', '제공이', '필요함'],
#  [],
#  ['케시포인트', '좋습니다'],
#  ['절약에', '도움이됨'],
#  ['적립', '대박'],
#  ['넘좋아요'],
#  ['멋져요'],
#  ['업데이트', '실행', '안되네요', '삭제', '재설치도', '안됨'],
#  ['캐시백', '개꿀'],
#  ['최고입니다'],
#  ['굿굿'],
#  ['깔고',
#   '위치확인동의',
#   '같은',
#   '동의',
#   '누른다음에',
#   '계속',
#   '흰화면이',
#   '뜨고',
#   '기다리면',
#   '네트워크',
#   '상태',
#   '확인하라고',
#   '하네요',
#   '실행이안되서',
#   '가입도',
#   '못했어요'],
#  ['어플들어가니깐', '악성코드를탐지햇다고뜨는데', '왜그런거에요'],
#  ['편해요'],
#  ['완전'],
#  ['카드',
#   '수령지가',
#   '자택',
#   '외에',
#   '설정이',
#   '안되네요',
#   '리뷰',
#   '보니',
#   '형식적인',
#   '답변',
#   '뿐이고',
#   '활성화',
#   '되려면',
#   '업체부터',
#   '다시',
#   '바꿔야겟네요',
#   '시에',
#   '연락',
#   '예정입니다'],
#  ['신통방통합니다'],
#  ['정말', '좋습니다'],
#  ['구웃'],
#  ['사용이', '편하네요동백전', '지점', '정보가', '좀더', '명확했음', '하네요'],
#  ['가맹점이',
#   '어디더라',
#   '생각',
#   '안하고',
#   '들어가서',
#   '결재하면',
#   '어지간하면',
#   '가맹점이네요',
#   '프로',
#   '캐시백',
#   '이벤트',
#   '오래오래',
#   '했음',
#   '좋겠어요',
#   '월까지'],
#  ['밴드앱', '악성코드로', '인식합니다', '확인바랍니다'],
#  ['무리', '없음'],
#  ['네이버',
#   '밴드',
#   '어플을',
#   '악성코드로',
#   '인식하네요',
#   '밴드어플을',
#   '삭제하고',
#   '어플설치후',
#   '밴드를',
#   '다시',
#   '설치하니',
#   '다시',
#   '악성코드로',
#   '인식',
#   '밴드를',
#   '사용해야하는데',
#   '어찌해야할지'],
#  [],
#  ['시작하면',
#   '악성코드가',
#   '발견되었다면서',
#   '창이',
#   '뜨는데',
#   '해킹당한거',
#   '아닌가요',
#   '불안해서',
#   '앱을',
#   '못열겠고',
#   '이미',
#   '폰에',
#   '악성코드가',
#   '심어진거',
#   '아닌지',
#   '불안합니다'],
#  [],
#  ['카드는', '언제받을', '있나요'],
#  ['사용처',
#   '제한으로',
#   '불편함이',
#   '많음',
#   '특히',
#   '재래시장에는',
#   '카드계산기',
#   '없는',
#   '상점이',
#   '많아',
#   '불편함',
#   '업데이트',
#   '하라면서',
#   '며칠째',
#   '업데이트',
#   '했는데도',
#   '아직도',
#   '설치',
#   '중와',
#   '이런다요',
#   '아예',
#   '업데이트가',
#   '안되네요'],
#  ['업로드이후',
#   '자꾸',
#   '재시작해야',
#   '하는',
#   '버그가',
#   '계속발생',
#   '합니다',
#   '업로드전에는',
#   '전혀',
#   '문제',
#   '없었으나',
#   '업로드이후',
#   '한번에',
#   '연결이',
#   '되지',
#   '않고',
#   '여러번',
#   '해야',
#   '연결됩니다',
#   '실행하면',
#   '첫번째',
#   '화면나오다',
#   '꺼지는',
#   '현상이며',
#   '네트웍',
#   '연결이',
#   '안되었다고',
#   '하기도',
#   '하고',
#   '여러번',
#   '실행해야',
#   '됩니다',
#   '와이파이나',
#   '네트웍장비',
#   'LG',
#   '통신장비',
#   '앞에서도',
#   '연결됩니다',
#   '인터넷이나',
#   '연결속도',
#   '측정해도',
#   '전혀',
#   '문제',
#   '없습니다',
#   '핸드폰',
#   '기종은',
#   'VLG',
#   '모델입니다',
#   '리뷰에',
#   '보면',
#   '여러사람들이',
#   '문제제기를',
#   '합니다',
#   '빠른조치',
#   '부탁해요'],
#  ['동백전의',
#   '의도는',
#   '좋으나',
#   '앱이',
#   '좋습니다',
#   '동백전이',
#   '활성화하지',
#   '못하게',
#   '된다면',
#   '앱이',
#   '가장',
#   '비율을',
#   '차지할것',
#   '같군요',
#   '계좌등록하려고',
#   'ARS전화하고오면',
#   '다시',
#   '첫화면으로',
#   '돌아갑니다',
#   '어찌저찌',
#   '통과를',
#   '해도',
#   '제계좌에',
#   '원이체',
#   '인증숫자를',
#   '쓰라는데',
#   '확인하기위한',
#   '타행어플이',
#   '같은',
#   '휴대폰에',
#   '있는데',
#   '확인하고오면',
#   '다시',
#   '첫화면',
#   '처음부터',
#   '다시',
#   '해야합니다',
#   '시도했다고',
#   '오늘',
#   '못한다는군요'],
#  ['동백전회원가입하려는데',
#   '현재폰이',
#   '부모님명의로',
#   '되어있는데',
#   '휴대폰인증말고',
#   '다른방법으로',
#   '가입할수는',
#   '없나요'],
#  ['편하게', '사용하고', '있어요'],
#  ['와이파이',
#   '연결시에는',
#   '어플',
#   '접속이',
#   '잘됩니다',
#   '데이터',
#   '사용시',
#   '접속이',
#   '안됩니다',
#   '데이터',
#   '잔여량도',
#   '많이',
#   '있고',
#   '통신상태도',
#   '양호한',
#   '지역에서도',
#   '마찬가지입니다',
#   '기기는',
#   'skt',
#   '갤럭시s',
#   '안드로이드',
#   '파이버전입니다'],
#  ['음식점',
#   '가맹점되는곳에서',
#   '카드사용시',
#   '배달의',
#   '민족이나',
#   '배달대행어플을',
#   '통해서',
#   '계산해도',
#   '캐쉬백이',
#   '가능한가요'],
#  ['잘안됨'],
#  ['휴대폰', '명의가', '틀리는데', '가입안', '안될까요'],
#  ['인증문자',
#   '자체가',
#   '안오는데',
#   '카드발급',
#   '받으라는거죠',
#   '뭔가',
#   '제대로',
#   '이용할수',
#   '있도록',
#   '시스템을',
#   '만들어넣고',
#   '홍보를',
#   '해야지',
#   '시간낭비만',
#   '하고',
#   '있네요'],
#  ['인증번호', '발송됐다는데인번이', '안와서'],
#  ['페이코랑', '하나머니가', '추가되어', '피킹률', '퍼센트를', '넘길수있는', '갓혜자카드'],
#  [],
#  ['가맹점',
#   '찾기를',
#   '통해',
#   '나오는',
#   '가맹점이',
#   '년전쯤에',
#   '자리에',
#   '있던걸로',
#   '현재는',
#   '없어졌는데도',
#   '나오네요'],
#  ['캐쉬백', '이벤트기간', '장난', '아니네요', '있음', '퍼겠지만', '대만족중', '입니다'],
#  ['동백전어플을깔고난후에',
#   '회원가입',
#   '약관선택',
#   '화면으로',
#   '넘어가지지않고',
#   '네트워크가원활하지않다고만',
#   '표기됩니다',
#   '재설치',
#   '후도',
#   '동일하며',
#   '네트워크',
#   '앱들은',
#   '다잘되는데',
#   '동백전만이렇습니다'],
#  ['페이백'],
#  ['아직',
#   '사용하기전이나',
#   '항상',
#   '국가사업이',
#   '들어간',
#   '금융앱이나',
#   '국가지자체에서',
#   '실시하는',
#   '사업들은',
#   '돈은돈대로',
#   '쓰고',
#   '서비스는',
#   '형편없는지',
#   '모르겠습니다',
#   '부산시에서',
#   '광고',
#   '많이하고',
#   '혜택많다기에',
#   '받았는데',
#   '댓글들보니',
#   '혹시나했는데',
#   '역시나네요'],
#  ['아쉽지만', '쓰는데', '불편함은', '없다'],
#  ['인증번호가', '안오네요', '앱에', '문제가', '있나요'],
#  ['계속', '통신', '오류가', '뜨네요', '이러면', '사용하기', '불편해서', '사용이', '안될', '같은데요'],
#  ['앱이문제네요', '성질돋구네요'],
#  ['가입은',
#   '수월히',
#   '카드신청시',
#   '은행계좌',
#   '연결하여',
#   '다시',
#   '키려면',
#   '다시',
#   '처음부터',
#   '충전계좌',
#   '연결해보려',
#   '입금명을',
#   '보려',
#   '모바일뱅킹',
#   '열어보고',
#   '다시',
#   '넘어오면',
#   '꺼집니다',
#   '어떻해야하죠',
#   '결론',
#   '가입',
#   '카드신청까지는',
#   '했으나',
#   '충전계좌연결은',
#   '못하여',
#   '포기한',
#   '상태',
#   '계좌앱을',
#   '열고',
#   '다시',
#   '넘어오면',
#   '다시',
#   '처음',
#   '상태로',
#   '돌아옴',
#   '해결방법을',
#   '알려주세요'],
#  ['다운로드가안되여'],
#  ['어플실행시',
#   '정상적인OS가',
#   '아니라서',
#   '이용할수가',
#   '없다고',
#   '메세지가',
#   '나옵니다',
#   '엘지V이며',
#   '안드로이드버전입니다',
#   '확인좀',
#   '부탁드립니다'],
#  ['어제부터', '와이파이해도', '안해도', '서버통신문제로', '연결안된다고', '뜨네요'],
#  ['본인인증이', '휴대폰말고', '아이핀이나', '공인인증도', '추가되었음', '합니다'],
#  ['다운이안받아지네요'],
#  ['이벤기간이라',
#   '캐시백',
#   '비율이',
#   '높아',
#   '내가',
#   '내는',
#   '돈은',
#   '줄었음',
#   '카드를',
#   '아예',
#   '안받는',
#   '유명한',
#   '직영가맹점들',
#   '대형마트',
#   '등이',
#   '많음',
#   '부산카드라',
#   '시외에서는',
#   '못씀',
#   '근데',
#   '캐시백',
#   '되는',
#   '비용은',
#   '누가',
#   '부담하는',
#   '것인가',
#   '세금'],
#  ['내게', '만족을', '주는', '그런', '카드면서', '행복감을', '주는'],
#  ['어플이',
#   '실행안되요',
#   '통신중',
#   '오류가',
#   '발생했다고',
#   '어플',
#   '삭제후',
#   '다시',
#   '하여도',
#   '그대로',
#   '입니다',
#   '충전을',
#   '할수가',
#   '없네요'],
#  ['업데이트',
#   '이후에',
#   '뭘사러',
#   '갔더니',
#   '분명',
#   '해당점포가',
#   '캐쉬백대상점포인걸로',
#   '아는데',
#   '캐쉬백이',
#   '안들어와서',
#   '다른카드로',
#   '결제했습니다',
#   '취소내역도',
#   '안뜨고',
#   '어플',
#   '뭐하는',
#   '겁니까',
#   '돈과',
#   '연관된',
#   '어플이면',
#   '제대로',
#   '돌아가야하는거',
#   '아닙니까',
#   '정말',
#   '업데이트',
#   '이후로',
#   '실망입니다'],
#  ['카드신청오류', '계속뜨네요'],
#  ['하이마트에서', '사용가능한다고', '나오나', '사용이되지', '않습니다', '확인부탁드릴게요'],
#  ['네트워크',
#   '연결이',
#   '원활하지',
#   '않습니다',
#   '접속오류',
#   '어플과',
#   '인터넷은',
#   '사용되는',
#   '중인데',
#   '어플만',
#   '사용하면',
#   '문구가',
#   '나오네요',
#   '접속이',
#   '되어도',
#   '예기치',
#   '못한',
#   '경우문구가',
#   '나오며',
#   '무한',
#   '로딩만',
#   '반복되고',
#   '충전을',
#   '하려고',
#   '몇번이나',
#   '어플을',
#   '접속해야하는지',
#   '모르겠네요',
#   '고객센터로',
#   '전화를',
#   '걸어도',
#   '모든',
#   '상담원이',
#   '통화중입니다',
#   '무한',
#   '반복',
#   'cs부서가',
#   '있는건',
#   '맞죠',
#   '좋은',
#   '취지에서',
#   '만든',
#   '지역화페인데',
#   '사용도',
#   '제대로',
#   '못하고',
#   '좋네요',
#   '별점',
#   '점이',
#   '있다면',
#   '주고싶습니다'],
#  ['계속', '렉걸리고', '네트워크접속이', '안된다고하고', '예기치못한오류가', '생겼다며', '안됩니다'],
#  ['켤때마다',
#   '통신이어쩌고하면서',
#   '종료되고',
#   '다시들어가야',
#   '됩니다',
#   '이번에는',
#   '번이나',
#   '튕기고',
#   '들어가지네요'],
#  ['사용시',
#   '카드충전금액이',
#   '모자라거나',
#   '안되어',
#   '있으면',
#   '연결계좌에서',
#   '빠져나가잖아요',
#   '근데',
#   '연결계좌에서',
#   '나가니',
#   '캐시백이',
#   '안되는데',
#   '시스템이',
#   '맞나요',
#   '되는건지',
#   '정보가',
#   '없어서요'],
#  ['카드신청이', '안됩니다', '눌러도', '반응이없어요'],
#  ['카드신청시', '주민번호', '입력후', '다음화면으로', '넘어가지않습니다', '업데이트해주세요'],
#  ['정말',
#   '좋은',
#   '카드라서',
#   '사용하고',
#   '있는데',
#   '앱에',
#   '문제가',
#   '있는지',
#   '실행하려고',
#   '앱을',
#   '누르면',
#   '자꾸',
#   '튕깁니다',
#   '여러번',
#   '실행해야',
#   '앱에',
#   '들어가집니다',
#   '확인',
#   '하시고',
#   '고쳐주시기',
#   '바랍니다'],
#  ['인증된', '번홓하', '현재', '번호가', '달라서', '계속', '초기화', '하라고', '뜨는데', '해결해야', '되나요'],
#  ['너무좋은',
#   '카드인데',
#   '오류가',
#   '심해서',
#   '잔액',
#   '확인이',
#   '안되는점',
#   '빨리',
#   '개선',
#   '되었음',
#   '좋겠습니다',
#   '와이파이',
#   '꺼지면',
#   '네트워크',
#   '오류가',
#   '나서',
#   '충전',
#   '해야',
#   '상당히',
#   '곤란합니다'],
#  ['휴대폰',
#   '본인인증',
#   '문자가',
#   '분뒤에',
#   '전송되어서',
#   '가입이',
#   '불가능합니다',
#   '인증시스템에',
#   '문제가',
#   '있는',
#   '같습니다'],
#  ['아빠',
#   '폰에도',
#   '깔아드려서',
#   '쓰는데',
#   '이상하게',
#   '동백전만',
#   '켯다',
#   '끄면',
#   '문자에',
#   '들어갈',
#   '수가',
#   '없네요',
#   '어플들',
#   '테스트',
#   '해봤는데',
#   '어플이',
#   '문제예요',
#   '해결방법',
#   '없나요'],
#  ['실행도', '안되는구만', '하나도', '아까워'],
#  ['정상적인',
#   'os가',
#   '서비스',
#   '이용이',
#   '안된다면서',
#   '앱실행이',
#   '안됩니다',
#   '고객센터',
#   '전화연결도',
#   '안되구요',
#   '오류인가요'],
#  ['연일째', '계속', '앱도운로드중', '아직도', '다운중이네요'],
#  ['회원가입', '과정중', '인증번호', '전송', '버튼을', '아무리', '눌러도', '전송이', '되지', '않음'],
#  ['두번',
#   '터치해야',
#   '정상적으로',
#   '어플이',
#   '실행되는지',
#   '모르겠네요',
#   '한번',
#   '실행하면',
#   '보안프로그램',
#   '실행되명서',
#   '종료되고',
#   '두번',
#   '실행해야',
#   '정상적으로',
#   '화면이',
#   '뜨네요',
#   '해결해',
#   '주세요'],
#  ['캐시백', '현재', '프로', '대박'],
#  ['너무좋네요', '근데홍보가', '이제되기시작했는지', '지금만든사람이', '많아요', '프로캐시백', '월까지', '연장하면안되사요'],
#  ['탭으론',
#   '접속조차',
#   '안되네요',
#   '처럼',
#   '폰은',
#   'g폰이고',
#   '탭으로',
#   '인터넷하는',
#   '사람은',
#   '충전하죠',
#   '발급',
#   '사용',
#   '못하고',
#   '잇습니다',
#   '빠른',
#   '개선',
#   '부탁드립니다'],
#  ['잘사용하고',
#   '있습니다',
#   '근데',
#   '어플을',
#   '실행시키면',
#   '첫번째는',
#   '실행되다가',
#   '닫기고',
#   '두번째',
#   '실행시키면',
#   '되는걸까요',
#   '그거',
#   '말고는',
#   '간단해게',
#   '사용할수',
#   '있어서'],
#  ['동백전앱이', '안됨'],
#  ['일정',
#   '미사용으로',
#   '작업이',
#   '중단',
#   '되었습니다',
#   '라고',
#   '계속',
#   '떠는데',
#   '하면',
#   '되나요',
#   '삭제하고',
#   '다시',
#   '설치해도',
#   '마찬가지',
#   '입니다'],
#  ['카드', '수령지를', '자택에서', '직장으로', '변경되지', '않나요', '이것땜에', '가입', '못하고', '있읍니다'],
#  ['좋아용'],
#  ['어플', '다운', '불가'],
#  ['좋은데',
#   '연결계좌',
#   '은행에',
#   '카카오뱅크가',
#   '없어서',
#   '불편합니다',
#   '연결계좌은행은',
#   '다양해져도',
#   '좋을것',
#   '같아서',
#   '별하나',
#   '뺐습니다'],
#  ['월별', '사용합계를', '자동으로', '볼수', '있으면', '좋을듯해요'],
#  [],
#  ['체크카드도', '캐시백주시지'],
#  ['겁나', '좋음'],
#  [],
#  ['캐쉬백', '지역', '발전'],
#  ['이용됩니다'],
#  ['개편함'],
#  ['감사합니다'],
#  [],
#  ['매우', '좋음'],
#  ['최곱니다'],
#  ['동백전이',
#   '엄청',
#   '편리하고',
#   '캐시백이',
#   '되니',
#   '좋습니까',
#   '월이후에도',
#   '년말까지',
#   '쭈욱',
#   '했으면',
#   '좋겠습니다'],
#  ['프로'],
#  ['추천합니다'],
#  [],
#  [],
#  ['폰결제', '되겠죠'],
#  ['어느카드보다', '혜택', '최고입니다'],
#  ['사용한금액에', '포이트도', '받고', '좋아요굿'],
#  [],
#  ['사용가능', '업체라고', '검색하고', '갔는데', '사용되지', '않았습니다', '완전', '비추'],
#  [],
#  [],
#  [],
#  [],
#  ['공인인증서로도',
#   '로그인가능하게해주세요',
#   '휴대폰명의가',
#   '다른게',
#   '너무불편',
#   '제발요',
#   '아님',
#   '폰번호라도',
#   '수정가능하게해줘요'],
#  ['미적용', '매장에서도', '체크', '카드', '겸용이용', '할수', '있으면', '더욱', '좋겠군요'],
#  ['감사합니다'],
#  ['사업자용카드로', '등록', '가능한가요'],
#  ['최고', '입니다'],
#  [],
#  ['따봉'],
#  ['캐시적립이', '정말대박이네요'],
#  ['최고의지역화폐'],
#  ['로그인후', '사용하게', '해주세요'],
#  [],
#  ['사용', '편하고'],
#  [],
#  ['아주만족합니다'],
#  ['이렇게', '좋을', '없습니다', '할인', '좋습니다'],
#  ['너무좋아요', '택시에서', '카드결제시', '번중', '번만', '승인되서', '다른카드로해요'],
#  ['충전금액', '입력가능하게', '합시다'],
#  ['편리하고', '잔액부족시', '카드결제', '되는점은', '개선', '바랍니다'],
#  ['전월사용실적이', '연간으로', '있으면', '더편할것같아요', '좋습니다'],
#  ['계속', '해주셍ᆢ'],
#  ['편리합니다', 'Pay', '앱이나', '잔액을', '표시하면', '좋을듯합니다'],
#  [],
#  ['캐시백', '모으는', '재미가', '쏠쏠하네요♡♡'],
#  ['좋아요🤗'],
#  ['개꿀입니다',
#   '대신',
#   '여기가',
#   '사용가능한곳결제는',
#   '웬만한곳에서',
#   '가능하나',
#   '캐쉬백이',
#   '되는곳',
#   '인지',
#   '아닌지',
#   '아는게',
#   '약간불편한점이지만',
#   '쓰시기전에',
#   '사용법은',
#   '읽어보고',
#   '쓰시면',
#   '크게',
#   '불편하지않아요',
#   '할인',
#   '기간이',
#   '끝나는게',
#   '슬퍼요'],
#  ['사용하기', '편리하게', '잘만들었음'],
#  ['좋은데', '에러가', '많이', '뜹니다'],
#  [],
#  ['도대체',
#   '고객센터는',
#   '왜있는겁니까',
#   '문의',
#   '했는데',
#   '일이',
#   '지났는데도',
#   '보지도않을꺼면',
#   '아예',
#   '없애세요전화연결도',
#   '안되고',
#   '도대체',
#   '일은',
#   '하는거임'],
#  ['좋아요그리고월달까지', '이벤', '연장도', '해주셔서', '감사합니다'],
#  ['캐쉬백', '되는', '카드는'],
#  ['캐쉬백되니'],
#  ['충전금액',
#   '환불이',
#   '자유로울거라',
#   '생각하고',
#   '카드발급',
#   '어플설치를',
#   '하고',
#   '충전을',
#   '했었는데',
#   '급히',
#   '보낼',
#   '곳이',
#   '있어서',
#   '환불을',
#   '했어야',
#   '됬기에',
#   '환불',
#   '버튼을',
#   '눌렀는데',
#   '아무것도',
#   '못하더라구요',
#   '밑에',
#   '쓰인',
#   '글을',
#   '읽어보니까',
#   '전액',
#   '환불은',
#   '충전후',
#   '이내로',
#   '문의하여야',
#   '되고',
#   '조금이라도',
#   '사용한',
#   '경우에는',
#   '충전금액의',
#   '퍼센트를',
#   '사용하여야',
#   '남은',
#   '금액을',
#   '수수료',
#   '없이',
#   '환불이',
#   '가능하다고',
#   '쓰여있더라구요그래서',
#   '급한',
#   '마음에',
#   '고객센터에',
#   '분을',
#   '붙잡고',
#   '전화를',
#   '끝에',
#   '통화가',
#   '연결되서',
#   '환불을',
#   '받았습니다',
#   '환불은',
#   '당일이',
#   '아닌',
#   '다음날',
#   '오전에',
#   '환불이',
#   '된다고',
#   '하셨구',
#   '오전에',
#   '들어와서',
#   '받았습니다',
#   '캐시백',
#   '받으려다',
#   '보내야될',
#   '돈을',
#   '못보낼',
#   '환불정책이',
#   '어렵고',
#   '복잡한데다가',
#   '고객센터',
#   '문의가',
#   '많은지',
#   '연결도',
#   '안되서',
#   '충전하고',
#   '급히',
#   '보낼',
#   '곳이',
#   '있을때',
#   '유의해야',
#   '겠더라구요',
#   '사용하시는분은',
#   '계속',
#   '사용하시겠지만',
#   '저는',
#   '이렇게',
#   '사용할거면',
#   '못쓰겠어서',
#   '지역',
#   '화폐가',
#   '생겨서',
#   '좋았지만'],
#  ['굿요'],
#  [],
#  ['부산에선'],
#  ['온라인은', '사용이', '안되서', '아쉬워요'],
#  ['캐시백이', '월까지라서', '아쉬웠는데', '월까지', '연장이라', '좋아용', '꿀이', '떨어지는', '좋앙'],
#  ['사용시',
#   '와이파이가터지는',
#   '곳에서도',
#   '모바일',
#   '데이터를',
#   '켜지',
#   '않으면',
#   '사용이',
#   '안되는데',
#   '와이파이만으로도',
#   '사용할수',
#   '있게는',
#   '안되나요'],
#  ['캐쉬백넘좋아요'],
#  ['Good'],
#  ['사용하기', '쉬움'],
#  ['덕분에',
#   '사용하고',
#   '있습니다',
#   '업데이트',
#   '되면서',
#   '충전하기가',
#   '어렵게',
#   '되었네요',
#   '이전처럼',
#   '네모',
#   '안의',
#   '금액이면',
#   '좋을텐데',
#   '작은',
#   '네모안의',
#   '숫자가',
#   '보이질',
#   '않아',
#   '불편합니다',
#   '기간별',
#   '총합',
#   '사용',
#   '금액이',
#   '나왔으면',
#   '정말',
#   '좋을것같습니다',
#   '수정',
#   '부탁드립니다'],
#  ['좋아요♡'],
#  ['편하게', '잘쓰고있는데', '월도', '캐시백해준다니', '가즈아'],
#  [],
#  ['맘에들어요'],
#  ['좋음'],
#  [],
#  ['충전금액이', '남았는지', '알려주면', '좋겠어요'],
#  ['진짜진짜진짜루', '좋아영'],
#  ['없음'],
#  ['앱너무좋아요'],
#  ['완전좋음'],
#  ['너무좋아요', '보너스', '받는', '느낌입니다'],
#  ['정말좋네요'],
#  ['사용하고', '있어요', '프로', '적립', '유익해요'],
#  ['완전굿입니다'],
#  ['대박좋아야'],
#  [],
#  ['잘쓰고', '있어요', '사용방법이', '간단해서', '좋네요'],
#  ['편리함'],
#  [],
#  ['유용합니다', '포인트가', '금방', '쌓여요'],
#  ['잘사용하고있습니다'],
#  [],
#  ['어플도',
#   '보기',
#   '편하고',
#   '실시간',
#   '캐쉬백',
#   '확인되니',
#   '쓰고있어요',
#   '가맹점',
#   '찾기',
#   '힘들다는',
#   '분들',
#   '그냥',
#   '가셔서',
#   '내세요',
#   '되는가능한',
#   '곳은',
#   '해주시고',
#   '안되는곳은',
#   '안된다',
#   '하십니다',
#   '충전금액보다',
#   '금액을',
#   '결제하면',
#   '차액만',
#   '통장에서',
#   '출금되는게',
#   '아니라',
#   '온전히',
#   '통장에서만',
#   '출금이',
#   '되던데',
#   '이부분은',
#   '개선이',
#   '안되나요',
#   '두달째',
#   '잔액이',
#   '조금씩',
#   '남게되니',
#   '싫어요'],
#  ['카드신청',
#   '일주일이',
#   '지나도',
#   '오지않음',
#   '배송업체는',
#   '전화도',
#   '받지않음',
#   '오려나',
#   '하나은행가서',
#   '신청하는게',
#   '정신적으로',
#   '나아요',
#   '정말',
#   '언제오나요',
#   '걸리나'],
#  ['최고입니다', '학령기', '자녀를', '주부에게는', '선물같은', '카드이네요'],
#  ['혜택업소가', '좀더', '많았으면', '프로혜택', '너무좋아요', '다같이', '윈윈'],
#  [],
#  ['코로나', '여파로', '사용실적이', '적은데', '월까지', '혜택을', '연장', '해주면', '좋겠습니다'],
#  ['쓸만합니ㅣ다'],
#  ['Good'],
#  ['사용하기', '편리해요'],
#  [],
#  ['아주좋아요'],
#  ['화이팅'],
#  ['갠차늠'],
#  ['지역경제도', '살리고', '우리집에도', '도움되는', '최고'],
#  [],
#  ['편하고', '좋습니다', '혜택도', '많고'],
#  ['업데이트가', '안되요'],
#  ['프로충전너무좋아요'],
#  ['오거돈', '시장님', '감사합니다'],
#  ['감사합니다'],
#  ['좋고', '편해요'],
#  ['좋음'],
#  ['택시가', '연동이안되', '아쉽네요'],
#  ['굳굳'],
#  ['아직은', '완벽한', '어플아닌듯'],
#  ['감사'],
#  ['너무좋아요'],
#  ['좋네요'],
#  ['긋입니다'],
#  ['쏙쏙', '되돌아', '오는', '재미'],
#  [],
#  ['충전하려',
#   '들어가면',
#   '계속',
#   '튕기고',
#   '지우고',
#   '깔아도',
#   '튕기는데',
#   '이러면',
#   '그냥',
#   '쓰지말라는',
#   '소리',
#   '아닌가요'],
#  ['무조건', '조아여'],
#  [],
#  ['너무좋습니다'],
#  ['개꿀'],
#  [],
#  ['아직', '동백전을', '모르는사람이많은듯', '홍보가', '필요합니다'],
#  ['잘쓰고있습니다',
#   '한가지',
#   '요청드리고',
#   '싶은건',
#   '월별',
#   '또는',
#   '일정기간별',
#   '사용금액을',
#   '조회했을때',
#   '사용금액이',
#   '뜨면',
#   '좋겠네요',
#   '건수별',
#   '금액은',
#   '뜨는데',
#   '사용금액을',
#   '알고자할땐',
#   '일일이',
#   '더해야하는',
#   '불편함이',
#   '잇다보니',
#   '그것만',
#   '개선요청드려요'],
#  ['개꿀'],
#  ['포인트적립', '정말', '최곱니다'],
#  ['알림이', '빨라요'],
#  ['계속', '통신중', '오류', '뜨는건', '뭐여'],
#  ['업데이트안됨'],
#  ['회원가입조차',
#   '되질않아요',
#   '문자인증전까지',
#   '입력은',
#   '되는데',
#   '인증문자가',
#   '전혀',
#   '오질않네요',
#   'SKT는',
#   '사용이',
#   '안되나요',
#   '부산은행에서도',
#   '정확히',
#   '모르더군요'],
#  ['프로', '할인이', '연장되어', '기분이', '좋아서', '리뷰씀'],
#  ['유용하게', '쓸것', '같네요'],
#  ['업데이트가', '안되네요'],
#  ['말이', '필요없음', '최고'],
#  ['충전',
#   '환불',
#   '제도도',
#   '불편하고',
#   '상담원',
#   '연결',
#   '안됩니다',
#   '금액만',
#   '충전해서',
#   '그거',
#   '사용했는데',
#   '캐시백이',
#   '안됬더라구요',
#   '보니까',
#   '금액이',
#   '모자라서',
#   '연결된',
#   '카드로',
#   '빠져나갔다던데',
#   '그렇게',
#   '되는건가요',
#   '금액만',
#   '충전해서',
#   '충전한',
#   '그대로',
#   '썼는데',
#   '카드',
#   '전환이',
#   '된거죠',
#   '제대로된',
#   '설명도',
#   '없고',
#   '하나부터',
#   '열까지',
#   '마음에',
#   '안듭니다'],
#  ['가맹점도', '많고'],
#  [],
#  ['조금번잡스러움'],
#  [],
#  ['다들', '좋은거', '인정'],
#  ['대형마트', '사용만', '가능하면', '우리나라', '최고의', '카드혜택이라', '믿어', '의심치', '않습니다'],
#  ['vvip', '신용카드가', '할인을', '해주겠나요', '이보다', '좋을', '없어요'],
#  ['충전', '할려니까', '옳바르지', '않는', '계좌라고', '안되네요'],
#  ['자꾸', '다운로드대기중인가요'],
#  ['계속', '오류가', '떠요'],
#  ['앱에', '접속안되는', '날이', '왜이리많아요', '접속할때마다', '접속불가'],
#  ['업데이트', '왜이리', '안돼요'],
#  ['사용하기',
#   '안드로이드',
#   '버전이',
#   '낮아',
#   '어플',
#   '자체가',
#   '아예',
#   '설치',
#   '안되는',
#   '경우가',
#   '있어요',
#   '부산지역화폐이고',
#   '어플을',
#   '통해서만',
#   '가입이',
#   '가능한',
#   '부분을',
#   '감안한다면',
#   '버전이',
#   '낮은',
#   '폰의',
#   '경우에도',
#   '어플을',
#   '설치할',
#   '있게',
#   '조정해주시면',
#   '좋을',
#   '같아요'],
#  ['조아요'],
#  ['포인트많이', '쌓여서'],
#  ['본인인증',
#   '단계에서',
#   '휴대폰',
#   '인증번호',
#   '발송이',
#   '안되고',
#   '카드번호로',
#   '인증하려고',
#   '해도',
#   '번호오류라고',
#   '계속뜨네요',
#   '카드신청을',
#   '수가',
#   '없네요'],
#  ['기간', '설정해서', '사용내역을', '합계도', '나왔으면', '좋겠어요'],
#  ['업데이트일동안', '안되고', '앱실행이안되여'],
#  ['하루종일', '앱이', '실행이', '안되요'],
#  ['가입하려고',
#   '폰인증번호',
#   '전송누르면',
#   '예기치못한문제발생',
#   '했다고',
#   '진행이',
#   '안됩니다',
#   '수십번을',
#   '해봐도',
#   '똑같네요',
#   '머가',
#   '문제인가요'],
#  ['팝업창',
#   '아랫부분',
#   '닫기인지',
#   '다시보지않기',
#   '인지',
#   '선택하는',
#   '창이',
#   '화면에',
#   '잘려서',
#   '누를수가',
#   '없어요',
#   '제발',
#   '팝업창',
#   '크기',
#   '조절해주세요'],
#  ['간단',
#   '명료하게',
#   '꾸며져',
#   '있슴다',
#   '적절히',
#   '사용하여',
#   '경제에',
#   '도움이',
#   '되도록',
#   '주위',
#   '분들께',
#   '홍보',
#   '많이',
#   '많이',
#   '하세요'],
#  ['가맹점',
#   '확인할때',
#   '카테고리가',
#   '나눠져있긴',
#   '속에서',
#   '가게',
#   '이름을',
#   '일일이',
#   '보면서',
#   '즐겨찾기',
#   '하니까',
#   '많이',
#   '불편해요',
#   '가게이름을',
#   '봐도',
#   '어딘지',
#   '모르겠어서',
#   '지도',
#   '클릭해야되고',
#   '번거롭네요',
#   '구글맵처럼',
#   '사용하기',
#   '편한',
#   '지도로',
#   '가맹점',
#   '표시를',
#   '해주세요',
#   '어디를',
#   '초행길로',
#   '가더라도',
#   '지도에',
#   '가맹점이',
#   '떠서',
#   '확인할',
#   '있으면',
#   '편리할',
#   '같아요'],
#  ['지금', '설치가', '안되요'],
#  ['잘쓰고',
#   '있습니다',
#   '충전을',
#   '해야하는데',
#   '업데이트를',
#   '요구하는데',
#   '설치는',
#   '계속',
#   '대기중이네요',
#   '이제',
#   '잔액이',
#   '없어요',
#   '얼른쓰고싶어요'],
#  ['잔액이랑', '캐시백', '업데이트되니'],
#  ['카드가',
#   '도착했다해서',
#   '우편함에',
#   '놔둬달라했는데',
#   '집에',
#   '갔는데',
#   '없더라구요',
#   '재발급을',
#   '받고싶은데',
#   '찾아봐도',
#   '재발급',
#   '받는데가',
#   '없더라구요',
#   '재발급을',
#   '받죠'],
#  ['안열리네요'],
#  ['어플이',
#   '와이파이',
#   '연결될때만',
#   '실행',
#   '됩니다',
#   '데이터를',
#   '켜면',
#   '네트워크',
#   '상태가',
#   '원활하지',
#   '않습니다',
#   '연결상태를',
#   '확인후',
#   '다시',
#   '시도해주세요라고',
#   '뜨는데',
#   '고객센터는',
#   '연결이',
#   '안되서요',
#   '어플설정을',
#   '들여다봐도',
#   '안될',
#   '이유를',
#   '못찾겠어요',
#   '그것빼고는',
#   '정말',
#   '캐시백도',
#   '바로바로',
#   '되고',
#   '캐시백',
#   '크고',
#   '대만족입니다'],
#  ['동백전카드',
#   '가입에서',
#   '비밀번호',
#   '실패하고',
#   '나서는',
#   '접속하기가',
#   '힘들어요',
#   '충전시킬려고',
#   '하는데',
#   '본인인증이',
#   '됩니다'],
#  ['가입이',
#   '안됩니다인증이',
#   '안되요발급',
#   '받아보려고',
#   '어플깔고',
#   '휴대폰',
#   '인증하는거',
#   '아무리',
#   '눌러도',
#   '안되니',
#   '신경질나서',
#   '쓰겠나싶어요나만',
#   '안되는거야짜증나요'],
#  ['이음카드에', '기능도', '없고', '카드', '밖에', '신청도', '안되고', '부족한점이', '많아요'],
#  ['g폰',
#   '사용하고',
#   '있는데',
#   '발급받을',
#   '있는',
#   '방법은',
#   '없나요',
#   '예를들면',
#   '아이패드나',
#   '갤럭시탭',
#   '또는',
#   '공폰',
#   '다운받은',
#   '사용할',
#   '수도',
#   '있나요'],
#  ['동백전은',
#   '좋은데',
#   '어플이',
#   '왜이래요',
#   '결제가',
#   '두번',
#   '된거',
#   '같아',
#   '확인하려고',
#   '하니',
#   '네트워크',
#   '불량이라고',
#   '연결이',
#   '안되요',
#   '또해도',
#   '안되요',
#   '계속해도',
#   '안되요',
#   '나중에',
#   '집에가서',
#   '결제',
#   '두번된거',
#   '확인하고',
#   '다시',
#   '돌아가서',
#   '결제',
#   '취소하고',
#   '돌아왔어요',
#   '제발',
#   '어플',
#   '관리',
#   '잘해주세요'],
#  ['계좌도',
#   '안맞다그러고',
#   '신분증',
#   '발급일자도',
#   '틀리다고그러고',
#   '그냥',
#   '발급이',
#   '이제',
#   '안되는건가',
#   '몇번을',
#   '확인해도',
#   '틀린게읍는디'],
#  ['사용하고',
#   '있습니다',
#   '아쉬운건',
#   '잔액정보인데',
#   '사용',
#   '금액',
#   '상품권',
#   '캐시뱁',
#   '합계',
#   '사용',
#   '금액',
#   '상품권',
#   '캐시백',
#   '합계',
#   '잔액',
#   '상품권',
#   '캐시백',
#   '합계',
#   '이런식으로',
#   '사용',
#   '정보를',
#   '제공해주셨으면',
#   '합니다'],
#  ['동백전은', '너무좋은데', '간혹오류로', '결제가안될때가있고', '어플들어가는거도', '팅길때가있어요', '유용하게잘쓰고있어요'],
#  ['폰마다',
#   '차이가있는지',
#   '제폰에서는',
#   '와이파이',
#   '앱에',
#   '접속이',
#   '안됩니다A',
#   '길거리에서',
#   '갑자기',
#   '충전해야할때',
#   '또는',
#   '가맹점확인해야할때',
#   'LTE면',
#   '네트워크',
#   '상태가',
#   '원활하지',
#   '않다며',
#   '꺼집니다',
#   '확인이',
#   '불가능해요',
#   '한복판에서',
#   '와이파이',
#   '잡는게',
#   '쉬운것도',
#   '아닌데',
#   '너무너무너무',
#   '불편하고',
#   '급할때는',
#   '정말',
#   '욕나와요',
#   '어제도',
#   '출구컷',
#   '당하고',
#   '물건',
#   '못사고',
#   '나왔습니다',
#   '개선',
#   '안됩니까'],
#  ['전산오류로',
#   '결제가',
#   '두번',
#   '됐는데',
#   '충전한',
#   '돈으로',
#   '결제한',
#   '첫번째',
#   '결제를',
#   '취소시키고',
#   '두번째',
#   '결제는',
#   '잔액이',
#   '없다고',
#   '통장에서',
#   '돈빼감',
#   '캐시백',
#   '포인트도',
#   '회수',
#   '거기다',
#   '어플에다',
#   '문의했는데',
#   '시간동안',
#   '답변없음'],
#  ['아직', '모름'],
#  ['인증번호가', '안오는데', '해야될까요'],
#  ['데이터', '인식을', '못하나봐요', '깔아도', '쓸수가없네요'],
#  [],
#  ['열때마다', '다시', '종료해야되네요', '어플', '제대로', '만드세요'],
#  ['카드발급해서', '사용중인데', '계속', '카드등록발급하라고', '어플에', '뜨네요카드등록', '할수있게', '해주세요'],
#  ['앱이', '자주', '버벅', '거립니다', '터치도', '안되고', '먹통이', '되요'],
#  ['최고에요', '계속되는', '적립혜택도', '좋고', 'UI도', '신경써서', '만든', '같아요', '편리합니다'],
#  [],
#  ['돈만빠져나가고', '충전이안됨', '아직은', '많이', '부족한듯'],
#  ['열리지가않아요'],
#  ['네트워크가',
#   '원활하지',
#   '않아',
#   '안된다고',
#   '뜨네요',
#   '옆에',
#   '남편은',
#   '확인이',
#   '잘되는데',
#   '뭐가',
#   '문제인가요',
#   '통신세기의',
#   '문제도',
#   '아닌거',
#   '같은데핸드폰',
#   '버전에',
#   '차이가',
#   '나는건가요',
#   '확인이',
#   '안되니',
#   '답답하네요'],
#  ['결제도', '안되고', '잔액확인도안됩니다', '계속', '오류뜨는데', '왜이런건가요'],
#  ['급하게', '충전', '해야', '됩니다', '어플도', '통신사도', '케이티라', '뭐가', '쓰레긴지는', '없는', '노릇'],
#  ['네트워크', '오류라면서', '어플', '접속이', '안될뿐더러', '오늘', '결제한', '금액', '캐시백도', '안됐네요뭐지요'],
#  ['인터넷', '접속이', '안될때가', '많습니다'],
#  ['뭐가자꾸', '접속이안된대', '짜증나게'],
#  ['어플에',
#   '접속이',
#   '안되는데',
#   '쓰라는거에요',
#   '아이폰에서',
#   '안드로이드로',
#   '넘어왓는데',
#   '아이폰에선',
#   '문제없이',
#   '잘썼는데',
#   '안드로이드로',
#   '넘어오니',
#   '왜이래요',
#   '와이파이읾대도',
#   '네트워크접속',
#   '안된다그러고',
#   '데이터일때도',
#   '안된다',
#   '그러고',
#   '가맹점찾기나',
#   '확인하려고',
#   '하는데',
#   '안들어가지면',
#   '어떻게쓰라는거에요',
#   '진짜',
#   '욕나와요',
#   '개선좀',
#   '해주세요',
#   '네트워크',
#   '문제',
#   '얘기하는',
#   '사람이',
#   '한둘도',
#   '아니구만',
#   '도대체',
#   '안고쳐지는거에요'],
#  ['명불허전', '작품', '접속장애', '엄청', '심합니다'],
#  ['혜택은',
#   '좋은데',
#   '어플',
#   '동작이',
#   '느림',
#   '가게가',
#   '해당되는지',
#   '확인하려고',
#   '어플켜다가',
#   '포기하는',
#   '경우가',
#   '많을정도로',
#   '구동속도가',
#   '느림'],
#  ['신청을해서',
#   '등록하려는데',
#   '자꾸',
#   '통신상연결이안된다하고',
#   '네트워크문제라고뜨네요',
#   '다른인터넷어플들은다잘되는데',
#   '왜그런지모르겠네요'],
#  ['폰이',
#   '이상한건',
#   '가요',
#   '데이터로는',
#   '동백전이',
#   '안들어가지고',
#   '충전도',
#   '안됩니다',
#   '길에서',
#   '충전해서',
#   '급히',
#   '쓸려고할때',
#   '사용도',
#   '못하고',
#   '계속',
#   '튕겨져',
#   '나오는데',
#   '확인해봐주세요'],
#  ['오늘', '결제도', '안되고', '어플실행도', '안되요'],
#  ['어휴', '어플관리', '진짜', '최악이다'],
#  ['진짜',
#   '넘하시네요',
#   '접속도',
#   '안되고',
#   '맨날천날',
#   '통신이',
#   '불안하다고',
#   '하면',
#   '시에서',
#   '일하시는',
#   '분들이',
#   '국민이',
#   '내는',
#   '세금',
#   '쳐받아먹고',
#   '이런거',
#   '제대로',
#   '못하시면',
#   '안되죠'],
#  ['어플이',
#   '연결이되야지',
#   '충전을할껀데',
#   '어제도오후내내',
#   '안되서',
#   '결국딴카드사용햇네요',
#   '네트워크오류로인하여',
#   '실행안된다고떠서',
#   '내폰이이상한가하고',
#   '다른폰으로연결해도',
#   '똑같던데',
#   '어플연결좀',
#   '잘되게해주세요',
#   '가게에서',
#   '동백전카드만결재안될때도잇던데요',
#   '네트워크오류나서',
#   '기능은좋은데',
#   '사용이잘안되면',
#   '무용지물아입니까',
#   '부탁드립니다'],
#  ['연결이잘안되요네트워크', '상태라면서뜨지를않아요'],
#  ['가맹점', '검색할때', '현재', '위치가', '아닌', '처음', '접속했던', '위치로', '계속', '검색되는듯요'],
#  ['사용하고',
#   '있습니다',
#   '월별',
#   '이용금액합계',
#   '보이게',
#   '개선해주세요',
#   '사용금액',
#   '합계',
#   '내려면',
#   '계산기',
#   '뚜드려야되고',
#   '불편하네요'],
#  ['설치하고',
#   '카드',
#   '신청하는데',
#   '폰으로',
#   '인증번호',
#   '확인차',
#   '문자앱',
#   '실행해서',
#   '보고',
#   '다시',
#   '동백전앱에',
#   '인증번호',
#   '넣을려고',
#   '클릭하면',
#   '재시작',
#   '되어서',
#   '다시',
#   '휴대폰',
#   '번호',
#   '넣어라함',
#   '몇번째',
#   '다시하다가',
#   '성질나서',
#   '카드신청',
#   '안함',
#   '앱을',
#   '이따위로',
#   '만들었는지'],
#  ['접속이',
#   '잘되다가',
#   '갑자기',
#   '안되네여',
#   '다른분들말처럼',
#   '데이터',
#   '와이파이',
#   '구분없이',
#   '네트워크',
#   '장애',
#   '오류',
#   '안되네셔',
#   '사용하는',
#   '사람이',
#   '무지하게',
#   '많은데',
#   '빠른',
#   '개선',
#   '요해요',
#   '빠른',
#   '개선',
#   '감사드립니다',
#   '답변까지',
#   '수고많으십니다'],
#  [],
#  ['마이너스',
#   '없어서',
#   '개만',
#   '카드신청하고',
#   '일주일',
#   '만에',
#   '받았는데',
#   '어플에서',
#   '충전이',
#   '안된다',
#   '올바르지',
#   '않은',
#   '계좌라네',
#   '하아',
#   '오프라인',
#   '충전은',
#   '부산은행이나',
#   '하나은행가서',
#   '하라네',
#   '이걸',
#   '쓰라고',
#   '만든건지',
#   '플라스틱',
#   '쓰레기를',
#   '받은건지',
#   '가입만',
#   '시켜놓고',
#   '대책이',
#   '없니',
#   '명의',
#   '맞고요',
#   '신한',
#   '국민',
#   '계좌로',
#   '등록',
#   '시도',
#   '했었지만',
#   '올바르지',
#   '않은',
#   '계좌라고',
#   '해서',
#   '앱평가에',
#   '적은거임',
#   '이런거면',
#   '어플',
#   '문제',
#   '아님'],
#  ['어플',
#   '접속이',
#   '자꾸',
#   '튕겨요',
#   '캐쉬백도',
#   '제대로',
#   '들어오지않고',
#   '부족하게',
#   '들어오고',
#   '고객센터',
#   '전화연결도',
#   '몇번이나',
#   '안돼서',
#   '아직',
#   '문제점을',
#   '물어보지도',
#   '못했습니다'],
#  ['다른어플은',
#   '실행이되는데',
#   '이어플은',
#   'lte인데도',
#   '실행이',
#   '안되고',
#   '와이파이껴야',
#   '그나마',
#   '접속이',
#   '되는건가요',
#   '똑같은답변만',
#   '달지말고',
#   '업데이트를',
#   '해서',
#   '고쳐주세요',
#   '저는',
#   '갤럭시s엣지입니다'],
# ...
#   '포기했습니다'],
#  ['머고', '앱실행도안되고', '장난하냐'],
#  ['접속이', '잘안되네요', '업데이트좀', '부탁드립니다'],
#  ['접속불가', '충전불가'],
#  ['로그인이', '안되나요'],
#  ['쓰레기입니다', '이딴게', '세금으로', '만들어지네요'],
#  ['먹통임', '앱실행이', '안됨', '돈좀들여서', '실력있는', '개발자좀', '씁시다'],
#  ['접속이',
#   '안되네요',
#   '빨리',
#   '계산해야되는데',
#   '앱이',
#   '접속이',
#   '안되서',
#   '주위사람들',
#   '눈치밥',
#   '먹으면서',
#   '카드로',
#   '계산',
#   '했습니다'],
#  ['데이터', '켜도', '로그인', '안되는', '희대의', '쓰레기'],
#  ['충전금액',
#   '확인하고',
#   '쓰려고',
#   '했더니',
#   '어플은',
#   '켜지지도',
#   '않고',
#   '장난치는',
#   '것도',
#   '아니고',
#   '계좌결제로',
#   '생돈만',
#   '나갔잖아요',
#   '캐쉬백도',
#   '못받을',
#   '거면',
#   '그냥',
#   '신용카드',
#   '쓰고말지'],
#  ['앱이', '와이파이든', '데이터든', '아무것도', '연결이', '안되네요', '안정성', '신경써주세요'],
#  ['네트워크', '오류라고', '실행자체가', '안되네요', '점인지', '알겠네요'],
#  ['되던게', '갑자기', '네트워크', '뭐라하면사', '안들어가지냐'],
#  ['안들어가지나요', '계속튕기기만하네요이러다', '무용지물이', '되는건아닌지'],
#  ['머하는거야', '일부러', '안되겠했냐', '왜이래', '자꾸'],
#  ['로그인', '안되네요', '사용하기', '짜증나네'],
#  ['개느리고', '접속', '안됩니다'],
#  ['월에',
#   '발급',
#   '받아',
#   '사용',
#   '중이에요',
#   '프로',
#   '캐시백이',
#   '어마어마',
#   '하네요',
#   '덕분에',
#   '신용카드',
#   '소비도',
#   '줄이고',
#   '현금',
#   '충전해',
#   '쓰다보니',
#   '과소비도',
#   '안하게',
#   '만들어요',
#   '앞으로도',
#   '이용하겠습니다'],
#  ['갑자기', '접속이', '안되나요', '충전을', '못해서', '캐쉬백', '못받았어요'],
#  ['접속이안돼요', '충전은어찌해야하나'],
#  ['와이파이',
#   '풀로뜨고',
#   '유튜브',
#   '빠르게',
#   '잘되는데',
#   '앱만들어거면',
#   '네트워크',
#   '연결이',
#   '안된다고',
#   '뜰까요가입한',
#   '이후로',
#   '한번도',
#   '켜지지않아',
#   '카드',
#   '신청도',
#   '못하고',
#   '있습니다',
#   '연결문제',
#   '해결해주세요'],
#  ['네트워크',
#   '개선좀',
#   '빨리해주세요',
#   '일주일째',
#   '데이터로도',
#   '접속이안되고',
#   '와이파이',
#   '연결된상태에서도',
#   '접속이안되고',
#   '어플',
#   '들어가는게',
#   '하늘의',
#   '따기수준입니다',
#   '불필요한것을',
#   '개선할게아니라',
#   '접속부터',
#   '원활하게되는게',
#   '최우선인것같습니다'],
#  ['엉망진창입니다',
#   '사용하려고',
#   '만든어플이',
#   '결제하려할때마다',
#   '앱이',
#   '오류가',
#   '빈번하게',
#   '나네요',
#   '번거로워서라도',
#   '이용이',
#   '꺼려집니다',
#   '오류가',
#   '한두번도아니고',
#   '앱실행자체가',
#   '안되네오',
#   '거르세요'],
#  ['잘쓰고',
#   '있는데',
#   '오늘',
#   '앱이',
#   '안열리네요',
#   '네트워크',
#   '상태가',
#   '원활하지',
#   '않습니다',
#   '계속',
#   '뜹니다',
#   '친구꺼도',
#   '그렇게',
#   '뜨네요',
#   '앱이',
#   '이모양이면',
#   '이미지가',
#   '되겠습니까',
#   '빨리',
#   '고쳐주세요'],
#  ['접속도안됨'],
#  ['안정성이', '최악이네요'],
#  ['번씩',
#   '앱이',
#   '먹통입니다',
#   '쓰고',
#   '싶어도',
#   '못쓰게',
#   '하는',
#   '앱이네요',
#   '충전금액',
#   '확인하고',
#   '쓰려는데',
#   '앱은',
#   '아무리',
#   '기다려도',
#   '안되네요',
#   '서버가',
#   '불안정한거아닌가요',
#   '두번도',
#   '아니고해결이',
#   '안되나보네요',
#   '알겠습니다'],
#  ['취지도좋고',
#   '캐시백도',
#   '큰점',
#   '좋습니다',
#   '아쉬운점이',
#   '있네요',
#   '충전된',
#   '금액이',
#   '아닌',
#   '계좌연동으로',
#   '결제가되면',
#   '캐시백이',
#   '안되는',
#   '내용을',
#   '사전에',
#   '고지하지않은점',
#   '앱접속이',
#   '원활하지',
#   '않아',
#   '충전',
#   '잔액조회',
#   '등의',
#   '문제가',
#   '생기는점',
#   '안되는건',
#   '어쩔수없지만',
#   '안내는',
#   '똑바로',
#   '해주면',
#   '좋겠습니다',
#   '앱구동이나',
#   '시스템에',
#   '있어서도',
#   '여러',
#   '사정이',
#   '있겠지만',
#   '제일',
#   '중요한',
#   '결제',
#   '캐시백과',
#   '직결되는',
#   '부분들인데',
#   '부분들이',
#   '원활하게',
#   '있도록',
#   '빠르게',
#   '신경써주시면',
#   '좋겠습니다',
#   '문제발생시',
#   '알림메세지나',
#   '공지등을',
#   '보내주면',
#   '낫지않을까',
#   '하는',
#   '아쉬움이',
#   '있네요'],
#  ['접속에러', '고치나요'],
#  ['접속', '겁나', '안됨', '뭐하는건지'],
#  ['어플좀',
#   '들어가봅시다',
#   '뭐좀',
#   '할라하믄',
#   '네트워크',
#   '상태가',
#   '안좋다하고',
#   '충전도',
#   '못하고',
#   '사용도',
#   '못하고',
#   '콜센터도',
#   '연결안되고',
#   '캐시백',
#   '주기',
#   '싫어서',
#   '어플',
#   '안열립니까',
#   '이따구로',
#   '관리할거면',
#   '애시당초',
#   '만들지를',
#   '만들가',
#   '한시간째',
#   '안들어가지는데',
#   '도대체',
#   '관리자는',
#   '불금이라',
#   '놀러갔습니까'],
#  ['요즘세상에', '들어가지지도', '않네'],
#  ['와파든', '데이터든', '안들어가져요'],
#  ['앱관리', '안하냐', '네트워크', '접속불량', '머냐'],
#  ['리뷰는',
#   '스마트폰',
#   '쓰면서',
#   '처음',
#   '남겨봅니다',
#   '만원',
#   '충전해',
#   '놓고',
#   '사용하려고',
#   '보니',
#   '네트워크',
#   '연결이',
#   '안됩니다',
#   '이따구로',
#   '뜨면서',
#   '꺼지고리뷰',
#   '확인해보니',
#   '와이파이에서는',
#   '된다고',
#   '해서',
#   '와이파이',
#   '접속후',
#   '해도',
#   '똑같은',
#   '증상',
#   '이네요',
#   '장난하는것도',
#   '아니고',
#   '빠른시일내에',
#   '환불해',
#   '주세요',
#   '못씁니다',
#   '돈쓰면서',
#   '스트레스',
#   '받는경우는',
#   '경우인가',
#   '모르겠네요'],
#  ['츙전한', '뒤로', '안켜져요'],
#  ['지금', '사용이', '안되네요'],
#  ['카드는',
#   '잘사용하고',
#   '있는데요',
#   '앱은',
#   '이따위로',
#   '만들었나요',
#   '와이파이에서만',
#   '접속되고',
#   '그마저도',
#   '안될때도',
#   '있고',
#   '개선이',
#   '시급합니다'],
#  ['식당에서',
#   '먹고',
#   '나가기전에',
#   '충전해서',
#   '결제하려고',
#   '어플을',
#   '켰는데',
#   '접속이',
#   '계속',
#   '안되서',
#   '환급도',
#   '못받고',
#   '카드로',
#   '결제했습니다',
#   '진짜',
#   '뭔가요',
#   '열받습니다',
#   '천원',
#   '손해봣네요'],
#  ['발급',
#   '달도',
#   '지나지',
#   '않았는데',
#   '시스템',
#   '장애로',
#   '결제',
#   '불가에',
#   '오류로',
#   '충전',
#   '불가에',
#   '불편하기',
#   '짝이',
#   '없군요',
#   '이래서',
#   '경제',
#   '살리죠',
#   '분발해야겠어요'],
#  ['접속이', '자꾸', '안되는데', '어째된거죠', '짜증나네요'],
#  ['평점이',
#   '점대일까',
#   '했는데',
#   '오류',
#   '진짜',
#   '많이나고',
#   '쓰레기',
#   '같아요',
#   '충전',
#   '해야되는데',
#   '어차피',
#   '오늘',
#   '안에',
#   '안고쳐질거고',
#   '하루',
#   '기다려야겠죠',
#   '진짜',
#   '별로'],
#  ['안되냐', '에휴'],
#  ['앱이', '열리지가', '않는데', '충전합니까'],
#  ['통신오류가', '잦아요'],
#  ['로그인이', '왜안되나요', '이리', '안들어가지는', '어플도', '첨봅니다빠른', '수정', '부탁드립니다'],
#  ['동일한',
#   '후기가',
#   '많습니다만',
#   '자꾸',
#   '네트워크',
#   '연결안된다고',
#   '하나요',
#   '불편해서',
#   '쓰겠네요',
#   '고작',
#   '확인',
#   '하는데',
#   '이렇게',
#   '시간이',
#   '많이',
#   '걸리다니'],
#  ['접속', '하자', '지금', '몇일째', '접속이', '안되는건지', '관리할', '마음은', '있는건지'],
#  ['어플이', '계속안열리네요', '정말', '노답이네요'],
#  ['앱자체가',
#   '안켜지네요',
#   '부모님꺼',
#   '계좌연결도',
#   '분째',
#   '인증도못하고있어요',
#   '인터넷폰뱅킹안하시는분이라',
#   '은행까지갔다왔는데요'],
#  ['캐시백되는건', '좋은데', '앱이', '몇번째', '안들어가지는건지', '돈이', '얼마있는지', '확인할수가', '없네요'],
#  ['열러요'],
#  ['쓴지',
#   '얼마안됐어도',
#   '캐쉬백들어오는것도',
#   '좋고',
#   '맘에',
#   '들었는데',
#   '짜증나서',
#   '못써먹겠네요',
#   '무슨앱이',
#   '자꾸',
#   '네트워크',
#   '연결이',
#   '안된데요'],
#  ['앱에',
#   '잘안들어가져요',
#   '벌써',
#   '시간째',
#   '들어가지지않고',
#   '튕기는데',
#   '이게뭔가요',
#   '할인해주셔서',
#   '좋긴하지만',
#   '이렇게',
#   '접속이',
#   '어려워서야'],
#  ['실행이', '안됨', '와이파이', '빵빵한데도', '안되고', '데이터로도', '안됨요', '불편'],
#  ['잔액', '확인하려고', '어플', '들어가는데', '접속', '안되면카드를', '사용하라는건가요', '대체'],
#  ['현재',
#   '시간째',
#   '먹통이네요',
#   '식구들이랑',
#   '외식하고',
#   '동백전으로',
#   '계산할려니',
#   '앱도',
#   '안열리고',
#   '도무지',
#   '카드를',
#   '쓰라는건지',
#   '말라는건지충전을',
#   '할수잇게',
#   '해줘야지',
#   '될거',
#   '아닙니까'],
#  ['똥입니다', '잘쓰다', '안되서', '몇번을', '다시해도', '예기치', '못한', '오류라고', '나오네요', '짜증'],
#  ['맨날', '접속이', '안됨', '관리도', '안할거', '만들었는지'],
#  ['앱이',
#   '먹통입니다',
#   '네트워크',
#   '연결이',
#   '안된다고',
#   '뜹니다',
#   '빨리',
#   '고쳐주세요',
#   '가족',
#   '폰의',
#   '앱이',
#   '먹통입니다'],
#  ['뭔가요', '계속', '열리지도', '않고', '짜증', '나네요'],
#  ['어플실행시', '오류', '오늘카드받아쓸려했더니', '바로어플접속', '먹통', '이래가', '뭐하겠나요'],
#  ['어플', '진짜', '만들었네요', '툭하면', '접속도', '되고'],
#  ['연결이안돼요', '위치켜도', '가맹점나오지도않고아니', '도대체', '점거안하고', '뭐하시는건지동백전괜히만드러서짱증나게'],
#  ['접속도안되고', '깔고지웠는데도', '접속안되요', '개선해주세요'],
#  ['이게머요'],
#  ['네트워크',
#   '관리',
#   '해주세요',
#   '맨날',
#   '연결',
#   '돼서',
#   '충전도',
#   '못하고',
#   '오늘도',
#   '캐시백',
#   '혜택',
#   '원은',
#   '봤을건데',
#   '네트워크',
#   '문제로',
#   '활용',
#   '못했네요'],
#  ['쓰고있는데', '네트워크', '오류가', '자주', '발생해서', '잔액을', '제대로', '확인할', '없을때가', '많습니다'],
#  ['인증번호가', '밀려서', '날라오죠', '분안에', '오지도', '않아서', '가입조차', '진행할', '없습니다'],
#  ['서버연결', '진짜', '쓰레기같네요', '부산시청', '실망입니다'],
#  ['금액확인', '사용할려고하니', '오류뜨네요자주', '에러가', '나니', '사용하기', '불편해요'],
#  ['심심하면', '안열리네요', '쓰라는건지', '쓰지말라는건지', '열려야', '확인도하고', '충전도하죠'],
#  ['캐시백은좋은데', '앱사용오류가너무심해요'],
#  ['이전엔', '접속', '되었는덕', '오늘새벽에', '서버넓힌다고', '충전안되더니', '지금은', '어플이', '켜지지않아요'],
#  ['몇번을시도해도잘되지가않네요', '언제쯤', '제대로', '될까요'],
#  ['와충전할려고', '하는데', '들어가지지가', '않네요', '앱이', '이때위인가요'],
#  ['진짜', '앱이', '연결도', '안되고', '오류나고', '레기인지'],
#  ['앱이',
#   '열려야',
#   '충전해서',
#   '사용을',
#   '하죠',
#   '안열리는',
#   '경우가',
#   '많아요',
#   '네트워크가',
#   '원활하지않다고',
#   '자주떠요'],
#  ['실행', '단계에서부터', '막힙니다', '만들기만', '하지', '말고', '관리도', '잘해주길', '바랍니다'],
#  ['앱이', '열리지가', '않아요', '잔액이', '얼마남았는지', '확인할수가', '없네여'],
#  ['Lte',
#   'Wifi',
#   '데이터',
#   '연결',
#   '상태가',
#   '안좋다고',
#   '실행이',
#   '안됩니다',
#   '실행이',
#   '안되면',
#   '충전을',
#   '해야하나요'],
#  ['접속이',
#   '되야',
#   '충전을',
#   '하든',
#   '뭘하지',
#   '제발',
#   '접속',
#   '하게',
#   '해주세요',
#   'LTE',
#   'wifi',
#   '둘다',
#   '안되요'],
#  ['결제서비스가', '접속이', '안된다니어처구니', '없는', '부산시와KT구나'],
#  ['어플', '되다가', '접속이', '안되네요'],
#  ['오류가', '왤케', '자주', '난대요'],
#  [],
#  ['계속어플접속이안돼요왜그런거죠'],
#  ['다른앱은',
#   '잘되는데',
#   '동백전은',
#   '도대체',
#   '와이파이로도',
#   '데이터네트워크로도',
#   '네트워크',
#   '상태가',
#   '고르지',
#   '않다며',
#   '연결이',
#   '안되는데',
#   '건지요'],
#  ['어제부터', '네트워크연결이', '안된다고', '접속이', '안돼요', '해결함요'],
#  ['잘쓰고',
#   '있었는데',
#   '최근에',
#   '번호이동을',
#   '뒤로알뜰폰알뜰폰',
#   '계속',
#   '초기화하라고',
#   '하고',
#   '초기화메뉴',
#   '눌러도',
#   '안넘어가고',
#   '인증을',
#   '여러번해도',
#   '들어갈때',
#   '그뿐',
#   '다시',
#   '앱을',
#   '껏다켜면',
#   '문제가',
#   '반복되네요해결해주세요'],
#  ['오늘',
#   '하루종일',
#   '로그인이',
#   '안되네요',
#   '오류도',
#   '자주나고',
#   '등록된',
#   '가맹점에서도',
#   '사용',
#   '안되는곳이',
#   '많이',
#   '있습니다',
#   '개선해주세요',
#   '지금',
#   '일째',
#   '네트워크가',
#   '원활하지',
#   '않다는',
#   '메세지가',
#   '뜹니다',
#   '와이파이',
#   'LTE',
#   '다안되고',
#   '불편하네요'],
#  ['실행이',
#   '안되요',
#   '첫결제하고',
#   '포인트확인하려는데',
#   '종일',
#   '안됩니다',
#   '어플이',
#   '있나',
#   '부산사람들',
#   '성격',
#   '급한거',
#   '모르나'],
#  ['계속',
#   '네트워크가',
#   '연결이',
#   '안된다고',
#   '하는지ᆢ와이파이도',
#   '무선도',
#   '해봤어요',
#   '고객센터는',
#   '통화하기도',
#   '힘든데'],
#  ['갑자기', '네트워크', '오류라고', '실행이', '안됩니다', '앱을', '재설치해도', '안됩니다'],
#  ['며칠동안',
#   '네트워크',
#   '상태가',
#   '원활하지',
#   '않다면서',
#   '접속이',
#   '안되는',
#   '이유를',
#   '모르겠네요',
#   '충전을',
#   '해야하는데',
#   '말이지요',
#   '와이파이',
#   'lte',
#   '접속에',
#   '아무런',
#   '문제가',
#   '없는데',
#   '이런건지',
#   '조치',
#   '바랍니다'],
#  ['오류가', '잘떠요'],
#  ['가맹점도', '많고', '적립이', '바로바로참', '좋죵'],
#  ['노트', '에서도', '되나요', '부산은행서', '호환이', '안된다는데', '이해가', '안되서요'],
#  [],
#  [],
#  [],
#  ['앱이종종다운이되어서열리지', '않을때가', '있어요', '벌써', '삭제후', '다시', '깔았어요'],
#  [],
#  ['오굳'],
#  ['할인'],
#  ['간편하게', '유용하게', '활용할', '있어요'],
#  ['편리함'],
#  ['너무너무좋아요'],
#  ['조아요'],
#  [],
#  ['고객센터', '문의는', '아예', '관리를', '안하는것', '같아요', '읽지도않고', '처리도', '않해주시네요'],
#  ['많이', '쓰세요'],
#  [],
#  ['좋네요'],
#  ['대형마트는', '사용이', '안돼는게', '불편함'],
#  ['웬만한', '식당', '가게', '되어서', '유용합니다', '월별', '한도액이', '늘어나면', '좋겠어요'],
#  ['소상공인',
#   '찾아서',
#   '사용하게되고',
#   '적립도',
#   '팍팍되고',
#   '최고입니다',
#   '부산경제',
#   '화이팅',
#   '상품권보다',
#   '편리해서',
#   '사용',
#   '빈도가',
#   '놉네요',
#   '주유',
#   '편의점',
#   '된다는게',
#   '정말'],
#  [],
#  [],
#  ['넘좋아요'],
#  ['죽이네요', '엄청', '적립받고있어요'],
#  ['페이백', '프로', '최고', '만족하며', '쓰고', '있어요', '좋음'],
#  ['정말', '시민이면', '동백전카드는', '무조건', '있어줘야', '플랙스죠'],
#  ['조아조아'],
#  ['인증번호가안오네요', '아니무슨', '내폰skt고', '다맞게했는데', '인증번호', '전송햇다카믄서', '안오는건', '뭐지'],
#  ['사용하고', '있어요', '감사'],
#  ['포인트를', '바로바로', '받을수', '있어', '넘좋아요'],
#  ['앱을',
#   '열때',
#   '마다',
#   '폰번호와',
#   '맞지않다고',
#   '나오고',
#   '초기화하라고',
#   '해서',
#   '몇번을',
#   '다시',
#   '했는지',
#   '모릅니다',
#   '입금시켜',
#   '놓고',
#   '사용할려고',
#   '하는데',
#   '이따위로',
#   '앱을',
#   '만들어',
#   '나서',
#   '불편합니다'],
#  [],
#  ['전산', '다운이라고', '사용안될때', '똑땅해'],
#  ['사용중입니다'],
#  [],
#  ['쓰는', '본인에게', '이득이', '되니', '매우', '만족합니다'],
#  [],
#  ['TV선전과같이', '쓰고나면', '웃음이나네요', '프로로가면', '조을듯'],
#  [],
#  ['최고최고\U0001f929\U0001f929\U0001f929\U0001f929\U0001f929'],
#  ['뭔가', '느낌', '나는', '했갈여요'],
#  ['죠아부러요'],
#  ['어플만으로는', '별개도', '아깝지만', '캐시백때문에', '만점', '드립니다', '캐시백', '기간연장을', '염원합니다'],
#  [],
#  [],
#  ['부산시내에서',
#   '사용하고',
#   '포인트적립하는',
#   '재미가',
#   '있습니다',
#   '포인트',
#   '금액이',
#   '쌓이는',
#   '것을',
#   '보면서',
#   '부산시민이라는',
#   '자부심이',
#   '마구마구',
#   '생깁니다',
#   '단점',
#   '처음',
#   '사용',
#   '할때는',
#   '사용가능한',
#   '곳이',
#   '많았는데',
#   '차츰',
#   '지정업소가',
#   '사라지고',
#   '있습니다',
#   '사용가능한곳을',
#   '찾아다녀야',
#   '하고',
#   '현금이나',
#   '카드를',
#   '가지고',
#   '다녀야하는',
#   '불편함이',
#   '생기네요'],
#  ['에러가많이나요'],
#  [],
#  [],
#  [],
#  ['어플보다동백전프로적립이너무좋네요'],
#  ['좋습니다'],
#  ['아주좋아요'],
#  ['아주좋아요'],
#  ['아주좋아요'],
#  ['좋습니다', '지역화폐', '좋은데', '근데', '부산지역', '가맹점의', '물품을', '온라인으로', '결제되게', '해주세요'],
#  ['가끔씩', '접속불가됩니다'],
#  ['월에', '얼마썻는지', '안떠서', '별로네요', '진짜', '돈많이쓰게', '노린듯'],
#  [],
#  ['가끔', '앱연결', '안될때', '빼고는', '사용하고있어요'],
#  [],
#  ['혜택이', '많고'],
#  [],
#  ['좋긴한데', '접속이', '원활하지', '않아요'],
#  [],
#  [],
#  ['조아요'],
#  ['혜택이', '좋음'],
#  ['조아용'],
#  ['충분히', '만족', '합니다'],
#  [],
#  ['에러가', '하루건너', '한번', '나는', '니낌입니다'],
#  ['업데이트', '하지', '마세요', '짜증나게', '하네'],
#  ['한번씩', '접속이', '안된다고', '하네요', '주기적인', '업데이트', '요망됩니다'],
#  [],
#  [],
#  ['잦은', '오류'],
#  [],
#  ['로그인이', '안되네요'],
#  ['최고'],
#  ['Goooood'],
#  ['화이팅'],
#  ['흐음'],
#  [],
#  ['사용하고', '있어요'],
#  ['너무너무', '편리하고'],
#  ['글쎄요'],
#  [],
#  [],
#  ['Good'],
#  ['정말좋아요', '캐시백이바로입금이되어서', '요즘은장볼때', '동백전카드를잘이용하고있어요부산♡굿'],
#  ['좋아요요런거', '계속', '만들어주세요지역배달앱도', '생기면', '정말', '좋겠어요'],
#  ['부산동백전', '카드', '용이', '하고', '잘쓰고', '있어요', '쓸때', '마다', '캐시백', '팍팍너무'],
#  [],
#  ['좋은', '제도를', '만들어주신', '관계자분들께', '감사드립니다'],
#  ['오류가',
#   '잦습니다',
#   '충전식인데',
#   '충전도',
#   '불가능하고',
#   '카드',
#   '이용도',
#   '불가하고',
#   '지역',
#   '페이에',
#   '비해',
#   '오류가',
#   '많습니다',
#   '대한민국',
#   '도시라는',
#   '부산에',
#   '어울리지',
#   '않는',
#   '수준입니다'],
#  ['쓰고', '있습니다'],
#  ['대형마트와백화점등대형업체만빼면',
#   '대부분사용되네요',
#   '가맹점찾기어렵다는분이해가안되는데',
#   '동네병원도되고',
#   '약국도되고',
#   '슈퍼빵집음식점주유소안되는곳찾기가더힘듦',
#   '도대체어디사시는분인지궁금하네요',
#   '캐시백도결재와동시에딱들어오고',
#   '첨엔되나안되나가맹점찾기도해봤는데',
#   '이젠필요없어요',
#   '신용카드쓸데가없어지고있어서그게문제',
#   '쓰는재미가쏠쏠합니다'],
#  ['사용하기좋아여'],
#  ['지난',
#   '토요일부터',
#   '네트워크오류라고',
#   '로그인자체가',
#   '안됨',
#   '충전잔액확인안되고혹시',
#   '이런상황일때',
#   '은행에서',
#   '충전업무가능한지',
#   '물어보니',
#   '어플에서만',
#   '가능하다고함고객센터는',
#   '통화연결이',
#   '안됨',
#   '이정도면',
#   '쓰라고만들어놓은건지',
#   '의심스러움'],
#  [],
#  ['앱이', '안열려', '충전을', '못해서', '필요할', '할인을', '못받았어요'],
#  ['칭찬합니다'],
#  ['캐시백', '넘좋아요'],
#  ['아무', '에러없이', '사용중인데', '뭐가', '안된다는', '것인지', '할인되고너무'],
#  [],
#  ['업데이트가', '안됩니다'],
#  ['프로적립', '바로사용', '가능인데', '접속이', '늦음', '어떠하리', '인내심을', '가지고', '접근하세요'],
#  ['잘쓰고있어요♡'],
#  ['실용적이예요'],
#  ['평이', '안좋네', '편하기만', '하던데'],
#  ['잘쓰고있어요'],
#  ['좋습니다', '너무너무', '좋아용'],
#  [],
#  ['택시는', '사용', '안되나요'],
#  ['포인트가', '엄청나게쌓여요', '최고b'],
#  ['경제절약으로'],
#  ['감사합니다', '혜택이'],
#  ['아직', '사용', '않는곳', '많아요'],
#  ['굿굿'],
#  ['캐쉬백', '바로바로', '되고'],
#  ['겁나', '잘사용하고', '있습니다'],
#  ['캐시백을', '보니', '결제하고', '싶어지네요'],
#  [],
#  ['오류'],
#  ['정말'],
#  ['좋네요'],
#  ['서버', '불인정함'],
#  [],
#  ['가맹점이', '갑자기', '안되는곳도', '있던데', '왜그런가요'],
#  ['쵝오'],
#  ['좋앙ᆢ'],
#  ['그저그럼'],
#  ['사용하고', '있음'],
#  ['아주많이'],
#  ['좋음'],
#  ['초기화면에서', '계속', '멈춰있다가', '네트워크', '오류로', '꺼집니다'],
#  ['캐쉬백', '되고', '그걸', '사용가능해서', '좋습니다'],
#  ['긴급', '점검이', '왜이리', '많습니까', '결제할라다가', '못한게', '번인지'],
#  ['구성됨'],
#  [],
#  ['사용했습니다', '사용하면서', '저는', '연결', '두어번', '버벅댄거말고는', '지금까지', '별문제없이', '잘쓰고있어요'],
#  ['저는',
#   '되는데',
#   '어머니가',
#   '갤s',
#   '안드',
#   'cj헬로모바일',
#   'kt망',
#   '환경에서',
#   '원래',
#   '되다가',
#   '며칠전부터',
#   '네트워크',
#   '환경이',
#   '안정적이지',
#   '않습니다',
#   '라는',
#   '오류',
#   '문구와',
#   '실행이',
#   '안되네요',
#   '데이터를',
#   '쓰든',
#   '와이파이를',
#   '쓰든',
#   '안됩니다',
#   '해야',
#   '해결할',
#   '있나요'],
#  ['할인', '많이돼서', '가끔', '오류로', '결제가', '안되지만', '차츰', '개선되겠죠'],
#  ['월부터',
#   '사용중인데',
#   '나는',
#   '한번도',
#   '오류난적',
#   '없고',
#   '사용하고있음',
#   '계속',
#   '프로',
#   '캐쉬백해줬으면',
#   '좋겠어요'],
#  ['에러잦음'],
#  ['어느카드보다', '좋습니다'],
#  ['죠앙'],
#  ['가맹점이', '되는건', '아니지만', '소소하게', '활용하고', '쓰기엔', '제법', '괜찬습니다'],
#  ['잘사용하고있습니다'],
#  [],
#  ['좋음'],
#  ['동백이', '최고입니다'],
#  [],
#  ['완전', '이런카드는', '처음이에요'],
#  ['좋음', '추천'],
#  ['캐시백'],
#  [],
#  [],
#  ['좋아요ᆢ부산동백전'],
#  ['최악',
#   '별하나도',
#   '아까움오류가',
#   '잦아',
#   '결제승인',
#   '안되었는데',
#   '돈이',
#   '빠져',
#   '가게',
#   '사장님과',
#   '불필요하게',
#   '얼굴',
#   '붉히는',
#   '경험',
#   '고객센터',
#   '공지사항도',
#   '없이',
#   '전화',
#   '통화중이라',
#   '전화받을수없다고만',
#   '대응',
#   '자체가',
#   '안됨'],
#  ['우차피쓸돈', '꽁돈개꿀임'],
#  ['프로', '잘쓰고있습니다감사합니다', '충전계좌가', '좀더', '다양해지면', '좋겠습니다'],
#  ['넘조아용', '지금까지', '내가', '얼마모았는지도', '볼수있나욤'],
#  ['접속을', '하게', '해달라고'],
#  ['최고임다'],
#  [],
#  [],
#  ['쓸수록', '돈이되는', '이왕이면', '동백이가', '조아요'],
#  ['갑자기',
#   '일금',
#   '점심시간때부터',
#   '네트워크상태가',
#   '원활하지',
#   '않습니다',
#   '연결상태를',
#   '확인',
#   '다시',
#   '시도해주세요라고',
#   '뜹니다',
#   '문제로',
#   '고객센터측에',
#   '문의하니',
#   '일부터',
#   '안드로이드',
#   '버전이',
#   '안되고',
#   '있다는',
#   '보고가',
#   '들어와서',
#   '해결중이다',
#   '라고',
#   '하던데요',
#   '도대체',
#   '해결되는건가요',
#   '빨리',
#   '서버',
#   '오류',
#   '고쳐서',
#   '사용할',
#   '있도록',
#   '해주세요'],
#  ['사용자가', '많아', '그러는지', '느리고', '에러', '자주됌'],
#  ['경제', '살림에', '정말', '행복한', '날을', '위해ᆢ', '감사합니다'],
#  ['프로',
#   '캐시백',
#   '너무좋아요',
#   '간혹',
#   '오류때문에',
#   '결제',
#   '안되서',
#   '난감할때도',
#   '있었지만',
#   '지금은',
#   '오류거의',
#   '없는것같아요',
#   '결제금액',
#   '합계',
#   '만들어주세요',
#   '불편해요'],
#  ['최고입니다'],
#  ['소상공인도', '돕고', '사용자도', '포인트', '받고', '좋습니다', '연장해주시길'],
#  ['적립된', '금액을', '사용할수', '있어', '좋습니다'],
#  [],
#  ['괜찮게',
#   '쓰고',
#   '있어요',
#   '앱이',
#   '자주',
#   '다운',
#   '되고',
#   '열릴때가',
#   '종종',
#   '발생해요',
#   '필요할때',
#   '앱이',
#   '안열리니',
#   '살짝',
#   '멘붕이'],
#  [],
#  ['매우좋다'],
#  ['결제오류가', '타카드에', '비해', '자주나요'],
#  ['잘되네요'],
#  ['심플한UI로', '필요한것만', '눈에띄게돼있어서', '좋네요'],
#  [],
#  ['쓰면', '쌓이는기분', '요런기분이군요'],
#  ['좋긴좋아요', '포인트', '서버가자꾸', '다운되요'],
#  ['그냥좋음'],
#  ['어플인듯'],
#  ['매우만족합니나'],
#  ['좋습니다굿'],
#  ['어플내에서', '문의', '답변은', '해주시나요', '며칠이', '지났는데도', '답변대기', '상태네요'],
#  ['적립'],
#  ['좋습니다'],
#  ['결제됐다', '취소되고', '지맘대로', '카드긁은데서', '재결제하러', '오라해서', '다시', '갔다왔음'],
#  ['부산거주자', '강추'],
#  ['계좌등록만하면', '간편하게', '충전', '확인가능해요', '좋은데', '카카오뱅크도', '추가해주세요'],
#  ['시ㅣ'],
#  ['good'],
#  ['쓰고있어요', '조금씩', '보완만', '해주신다면', '멋진', '앱이될거', '같네요'],
#  ['사용하기', '편하고', '적립도', '많고', '지역', '상인도', '도움되고좋아요'],
#  ['안되는', '곳이', '몇군데', '있어서', '불편하지만', '돌려주니까', '도움이', '많이되네요'],
#  [],
#  ['완전좋아요', '부신시민부심', '철절'],
#  ['사용해보면', '압니다'],
#  ['에러에', '로딩에'],
#  ['충전을',
#   '충분히',
#   '해뒀는데은행에서',
#   '그냥',
#   '출금',
#   '처리됨',
#   '처음에',
#   '충전된',
#   '잔액에서',
#   '결재되었다가',
#   '잠시후',
#   '잔액부족이라고',
#   '뜨면서',
#   '취소',
#   '시키고',
#   '다시',
#   '연결된',
#   '은행에서',
#   '돈빼가고',
#   '충전식',
#   '카드인지',
#   '고객사',
#   '통화하니',
#   '사용자',
#   '많을경우',
#   '그럴수도',
#   '있다고',
#   '결재한곳',
#   '다시',
#   '방문해서',
#   '취소하고',
#   '재결재하라고함',
#   '다시',
#   '차타고',
#   '가서',
#   '취소하고',
#   '재결재하라고',
#   '시간이',
#   '남아도나'],
#  ['프로', '계속', '진행', '해주세요'],
#  [],
#  ['안드로이드',
#   '사용자',
#   '입니다',
#   '얼마전까지',
#   '앱으로',
#   '충전',
#   '사용등모든',
#   '기능이',
#   '이루어졌었는데',
#   '갑자기',
#   '주말에',
#   '앱사용이',
#   '불가능해졌네요',
#   '안드로이드',
#   '이상버전만',
#   '사용가능한건가요',
#   '하위버전',
#   '구형단말기에는',
#   '사용이',
#   '불가능한가요',
#   '하위버전에서는',
#   '전혀',
#   '사용할수없는건가요'],
#  ['좋음'],
#  [],
#  [],
#  ...]

# %%
corpus

# %%
def dic_and_bow(clean_text):
    
    # 데이터를 dictionary 형태로 명사 list 만들기 
    dictionary = corpora.Dictionary(clean_text) 
    
    # 출현빈도가 너무 적은 단어는 제거 
    dictionary.filter_extremes(no_below=5) 
    
    # 명사 형태로 말뭉치 만들기 
    corpus = [dictionary.doc2bow(text) for text in clean_text]
    
    # TF-IDF으로 변환 
    tfidf = models.TfidfModel(corpus)
    corpus_tfidf = tfidf[corpus]
    corpus = corpus_tfidf 
    
    return corpus ,dictionary

corpus ,dictionary = dic_and_bow(tokenized_text)

# %%
corpus[0]
# Out:
# [(0, 0.6240326432838262), (1, 0.5431530731254981), (2, 0.5617543940820829)]

# %%
# 토픽 개수, 키워드 개수를 정해주는 변수를 추가.
NUM_TOPICS = 13

NUM_TOPIC_WORDS = 10

def print_topic_words(model):

    # 토픽 모델링 결과를 출력해 주는 함수.
    print("\nPrinting topic words.\n")
    
    for topic_id in range(model.num_topics):
        topic_word_probs = model.show_topic(topic_id, NUM_TOPIC_WORDS)
        print("Topic ID: {}".format(topic_id))
        
        for topic_word, prob in topic_word_probs:
            print("\t{}\t{}".format(topic_word, prob))
            
        print("\n")

# LDA를 실행.
model = models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary, alpha="auto", eta="auto")

word_dict = {};

for i in range(NUM_TOPICS):

    words = model.show_topic(i)

    word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words]

pd.DataFrame(word_dict)
# Out:
#   Topic # 01 Topic # 02 Topic # 03 Topic # 04 Topic # 05 Topic # 06  \
# 0        불편함         프로       삼성페이         캐시       해주세요         이전
# 1        하나도         최악       이전보다       부산시가      불편합니다      업데이트가
# 2      불편하네요         리뷰        새카드        캐시백        가맹점       안되네요
# 3         예전         다시      삼성페이도        일부러         알림       복잡하게
# 4       코나아이         같은       편리하고         카드     만들어주세요       안됩니다
# 5        이해가         비해         카드        안되요         이전      안되는데요
# 6         요즘      인터페이스         예전        알림이       불편하고       캐시백이
# 7       사용하기         하고         받은         안돼        쓰레기        해놓고
# 8        가맹점         제일        앱에서         없는         기존         좋음
# 9       불편해요         따로        짜증남        등록이         검색        한번에
#
#   Topic # 07 Topic # 08 Topic # 09 Topic # 10 Topic # 11 Topic # 12 Topic # 13
# 0         사용         진짜         카드         앱이        포인트       좋습니다         불편
# 1        있는데         보기       선불카드       불편해요         기존         이전        도대체
# 2        충전도         금액         쉽게        새로운         그냥        어디서        좋네요
# 3      최악입니다         만원        이벤트        업체가         누가        안되고         내가
# 4        서비스         전에        환불도         신규       신규카드        앱보다         KT
# 5        잔액을       안되나요         뭐죠       사용하기         카드      모르겠네요        않네요
# 6         아님       안됩니다       아닌가요        하는지        설치가        있는지         만든
# 7        보이게        화면이         그냥         엄청         계속        알림이       사용내역
# 8         뭐가       사용가능        아깝다        수수료       불편하게         해도      가맹점찾기
# 9         최고         나음         별로         기존        기존에       직관성이         바뀐

# %%
# Out:
# 0           부산에도 기다리던 지역화폐가 나왔네요 앱도 깔끔하고 카드도 신청하고 사용하겠습니다
# 1                                                     화이팅
# 2                                          기다렸었는데 앞으로 쓸게요
# 3              동백전으로 여기저기 많이 사용해 볼게요 경제에도 많은 도움이 되면 좋겠습니다
# 4                            쓰기 편하게 만들어졌네요 부산에서 혜택이 많았겠네요
# 5                           사용해 볼게요 동백전으로 혜택 많이 받으면 좋겠습니다
# 6                                            가자 글로벌 테스트베드
# 7       부산도 드디어 모바일 지역화폐가 나왔네요 앱설치하고 카드신청도 해봤는데요 복잡하지 ...
# 8                    드디어 기다리던 동백전앱이 출시됐네요 앞으로 이용 많이 하겠습니다
# 9              군더더기 없는 ui가 마음에 드는군요 많은 사업장에서 사용가능하면 좋겠습니다
# 10
# 11      선택약정선택하면 네트워크장애라고 뜨면서 진행되지 않음부산시에서 개인정보를 팔아 장사하는지
# 12                               많은 이용 바랍니다 부산시민과 성장해 갑시다
# 13      부산을 대표하는 이름으로 지은 이름이 멋지네요 부산에서 이용하는 혜택도 많아 기대가...
# 14                                           편의점에서도 사용되나요
# 15                                           설치가 간단하고 쉽네요
# 16                                  군더더기 없이 사용하기 편하고 좋습니다
# 17                           어플이 깔끔하니 사용하기 자주 사용하게 될듯 하네요
# 18                      QR코드 결제가 안되냐 기본인데 카드 신청도 안되고 미치겄네
# 19          회원가입이 돼요 다음주에 되는 사람인데요 계속 이상만 가입이 된다고 떠요 어떡해요
# 20              적립한도 있게 쓰고 있는데 충전한도 말고 적립한도도 있게 하면 좋을 같네요
# 21      지웠다 깔아도 들어갈 수가 없음 마트에서는 결제가 안됐다고 하고 돈이 빠졌는지 확인...
# 22      오류 안고쳐주실건가요 충전하려고 앱들어가면 데이터 상태로는 들어가지지도 않고 와이파...
# 23      오류 개선해주새오 오류가 심해요 캐시백이 안되어서 문의했더니 다시 가게에 가서 취소...
# 24                앱실행이 안됩니다 사용자 정보 취득에 실패하였다면서 앱이 꺼져버립니다…
# 25                                안들어가져요 먹통입니다다시 설치해도 그래요
# 26                      정말 오류가 많이 뜨네요 오류가 계속 떠서 사용하기 힘들어요
# 27      발급받은 한참 지났는데 오류 충전을 못합니다 빨리 개선 부탁드립니다… 하루에도 몇번...
# 28                 안켜져요 계속 오류나서 새로 설치했는데 자꾸 네트워크 오류라고 하네요
# 29                            욕나올정도로 후짐 며칠전부터 가맹점조회 아예 안됨
# 30      카드 결제지연 오류 카드가 사용자가 많다고 오류가 되서 계산이 안되나요 사람들이 갑...
# 31      가맹점 찾기 일까지는 문제 없었는데 서버 폭주로 접속 제한된 다음부터는 가맹점이 개...
# 32      갑자기 가맹점 찾기가 안되요 갑자기 가맹점 찾기가 안되요 삭제후 재설치 했는데도 안...
# 33              가맹점찾기 가맹점찾기 아무것도 안뜨고 도대체 어딜 봐야하나요 오류가 잦아요
# 34      가맹점 찾기가 되어 문의드립니다 정말 사용하고 있어요 캐시백 되는 것도 만족스럽습니...
# 35                              가맹점 가맹점 찾기 아예안되요 쓰지말라는건가요
# 36      어플이 진짜 구려요 오류나서 접속이 안되고 로그인도 안되고써야할 못쓰면 소용이죠 시...
# 37       가맹점 찾기 가맹점검색하려면 만뜨고 전에는 검색이 됐는데 아무것도 안나오는데 왜이런거죠
# 38      오류가 장난 아니네요 포인트도 많이 쌓이고 돈쓸맛 나는데 오류가 심해서 금하게 충전...
# 39      갑자기 안들어가지죠 낮에 분명 사용하고 방금 가맹점 카페와서 사용하려고 하는데 잔액...
# 40          못쓰겠네요 버그빨리 수정요 자꾸 튕기니 쓰지말라는 뜻인가요 빨리 버그 수정해주세요
# 41        가맹점찾기 좋은데 얼마전부터 가맹점찾기가 안되네요 계속 건만 뜹니다 빨리 해결해주세요
# 42              네트워크 네트워크로 인해 실행이 안된다고 뜨네욤 아까 되었는데 수정해주세욤
# 43      기간별 검색기능 강화 요청 예를들어 월일부터 오늘까지 사용실적 또는 적립실적 검색하...
# 44          문자인증이 안와요 어플이 안켜져서 삭제했다가 다시 깔았는데 문자인증메세지가 안와요
# 45      교통카드 이용내역 좋은데 카드 이용 내역에 후불교통카드로 쓰인 금액도 적혀있으면 좋...
# 46      한달동안 결제한 내역 합계를 있었으면 한달동안 결제한 내역 합계를 있으면 좋겠어요 ...
# 47      문제가 많네요 만원 충전했다가 충전취소하고 다시 충전하려고 했더니 충전이 안되는데 ...
# 48      쓰레기 신청하려고 깔았는데 에러만 벌써 번째… KT에서 개발한거라고 SKT전화에서는...
# 49                                             최악 어플이되야쓰죠
# 50      금액 충전이 되고 자꾸 꺼져요 금액 충전해서 쓰고 싶은데 앱이 자꾸 다운되고 꺼져서...
# 51           사용내역 보려고 하면 어플이 꺼져요 충전만 되고 하려고 하면 꺼져서 쓸수가없어요
# 52                  안켜져요 업데이트하고나서 어플이 안들어가집니다 오류 보완 부탁드려요
# 53      어플을 운영을 하실거면 불편함은 제때 개선좀 하세요 국민들 불편함 의견제기 점심시간...
# 54                                 열면 안들어지네요 안들어가쟈여 고쳐주세요
# 55      쓰고 있어요 렉이나 오류도 없고 캐시백도 많이 받아서 쓰는 재미가 쏠쏠하고 건의하자...
# 56                   오류 어플 오류가 많아요 쓰고싶을때 한번도 제대로 써본적이 없어요
# 57      이번달만 오류가 몇번인지 이렇게 오류가 많이 나는데 쓰란말인가요 여분으로 다른카드 ...
# 58             확실히 진짜 좋은데… 카카오 뱅크 계좌는 등록이 안되는건가요 정말 불편해요…
# 59                                  고객센터 고객센터 답변 기다렸는데 쥰나
# 60      결제안된다해서 다른카드로 결제했는데 동백전에선 돈이 나가네요 일반 슈퍼인데도 동백전...
# 61      가맹점 찾기 기능 개선 해주세요 가맹점 찾기 기능에서 현재 위치에서 지도를 보면 사...
# 62      좋긴한데요… 결제 어플인데 업뎃때문에 못쓴다고 막았으면 합니다 결제해야해서 잔액 보...
# 63                              백원 단위도 충전되게 해주세요 제발요 다좋은데
# 64                                택시는 안되나요 몇번 결제할려는데 안되네요
# 65      가맹점 표시 지도상에 한꺼번에 표시될 있게 주시고 띄어쓰기 잘못하면 검색이 안되던데...
# 66      사용자정보취득에 실패하였습니다 사용자정보취득에 실패하였습니다 앱을 다시 실행해주세요...
# 67      앱더럽게안됨 안들어가지고 삭제했다가 다시 들어가니 로그인 화면도 없고 회원가입하라고...
# 68      갑자기 안되니까 어이없네… 갑자기 네트워크 불안정 하다고 뜨고 들어가지는 겁니까 남...
# 69      어플실행오류 어플이 갑자기 실행이 안됩니다 와이파이도하고 데이터로도 해봤지만 두개다...
# 70      갑자기 서비스가 안돼요 개인정보 확인이 안된다고 오류메시지가뜨고 튕겨서 삭제했다 다...
# 71      어플 설치가안되어요 잘쓰고있었는데 금일 저녁 씨유에서 카드 주니 포스기에서 결제가 ...
# 72      본인인증단계에서 인증문자가 안와요 개선해주세요 본인인증단계에서 인증문자가 안와요 개...
# 73      덕분에 씁니다 오랜만에 제대로 만들었다 싶네요 놀라울 정도로 간결하고 간편한 앱이에...
# 74      빠르고 좋은 앱이네요 메인화면 하단 카드바가 메인 화면 진입시 움직이는 모션은 예쁘...
# 75      내가 보유한동백전 칸에 불필요한건 삭제 잘쓰고있습니다 근데 충전할라고 켜면 맨날 내...
# 76                                                   좋습니당
# 77                     사용 내역 볼려고하면 계에에에에속 나가지네요 빨리 고쳐 주세요
# 78                  큐알 코드 결제 부탁… 실물 카드로만 되는 보네여… 아이폰은 웁니다
# 79                    클릭 안됨 가입 하고 마지막에 비밀번호 설정하는 클릭이 안되네요
# 80                            쓰라는거야 카드 신청도 안되고 계좌 등록도 안되고
# 81       너무좋아요 쓰지도 않았는데 캐시백 쏠쏠해요 단위 충전도 가능해서 현명한 소비가 가능해요
# 82                                         정말 잘쓰고 있습니다 굿굿
# 83      금액을 직접 설정해서 충전하면 좋겠어요 정해진 금액만 말고 사용자가 충전하고 싶은 ...
# 84      가맹점 찾기라뇨 생각보다 안되는곳도 많고 충전금액 환불은 안되는거죠 계속 실패했다고...
# 85      가맹점 찾기 왜있나요 되는곳도있고 아닌곳이있고 그게 헷갈려서 찾기 서비스가 있는거 ...
# 86            가맹점이 두개씩 중복되서 나와요 가맹점 검색하면 중복해서 나와서 보기 힘들어요
# 87      인증안됩니다 전화번호 누르고 인증하기 버튼이 먹통이네요 혜택도 좋은데 이러다 잊혀져...
# 88      QR코드 간편결제도 되었으면 좋겠어요 카카오페이처럼 QR코드로 간편결제도 되었으면 ...
# 89      최고 충전하면 캐쉬백도 해주고 가정생활에 많은 도움이 되네요 지하철도 되고 계좌연결...
# 90                     할인 많이 되네요 할인 생각보다 많이 되네요 가맹점 늘려주시길
# 91                              안증안되요 쓰고싶어도 인증이안되니 쓸수가없네요
# 92      출시기념 한달간 이벤트를 하는데 지났는데도 아직 다운로드를 받지 못하는 어플이 두둥...
# 93                                    기다렸는데 드디어 빨리 가입 흥해라
# 94                         개쓰레기 같은 앱이 있어 죽도록 카드신청해도 안됨 안써
# 95      앱에서 결제되게 해주세요 좋다 좋다 많이 듣고 드디어 실물카드 받았습니다 근데 충전...
# 96      실행이 안됩니다 어플을 실행시키면 알림설정 창과 필수동의 까지는 되는데 화면에 Se...
# 97                              쓸만하네요 캐시백 비율이 높아서 쓰는데 좋네요
# 98                국굿 아이폰 바코드나 큐알코드 결제만 앱에서 가능 하면 최고일것 같아요
# 99                                         어플 오류 아예 접속 불가
# 100                                  좋은데 앱실행이 안되요 저만 안되나요
# 101     오류 빨리좀 해결해주세요 잘사용하다가 앱켜면 사용자정보를 읽을수없다고 다시시도해라고...
# 102     잘사용하고있었는데 사용하고있던 중이었는데 갑자기 오류로 안들어가져서 앱삭제하고 새로...
# 103           아예오류나고안들어가져요 오류나고 아예안들어가지는데 어떻게요 서버없다고만 뜨고요
# 104     사용자찾을 없다고 오류가 계속 뜨고 넘어가질 않는데 왜그럴까요 어플 삭제 후에 다시...
# 105     어제까지 앱실행 됐는데 No server is available to handle ...
# 106     오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하...
# 107                                 오류 뜨면서 실행안되네요 우째해야되나요
# 108              넣었는데 어플 실행이 안돼요 쓰다가 남아있는데 어플 실행이 안돼요 뭔데요
# 109     오류 갑자기 오늘 접속오류 계속 뜨길래 삭제 다시 깔았더니 아예 안되네요 빠른시일내...
# 110                                  아이폰 충전안됨 충전하러 가면 튕겨요
# 111     내역만 들어가면 팅김 내역에 들어가면 팅겨요 아이폰 xs입니다 내역 확인 가능한 싸...
# 112     카드신청안됨 하고 마지막에 계속 오류가 나요 청구서 수령관련 등록을 해야된다는데 중...
# 113     왜때문에 인증이안되나효 내이름에 탄생일에 명의의 핸드폰번혼데 자꾸 확인하래 내가 난...
# 114     고객 서비스가 최악이네요 어플 오류로 인하여 충전 하려고 하니 바탕화면으로 팅기는데...
# 115                        안들어가져요 업데이트 했는데 안들어가져요 해결 해주세여
# 116     꺼짐 문제 들어가서 캐쉬백을 누르면 앱이 꺼져버리는데 해야되나요 다시깔아도 마찬가지...
# 117                  불안정한 이용내역 확인 강제종료 메뉴도 간단하고 서비스도 훌륭한데
# 118     주민등록증 찍는데 청소년들은 청소년증으로 하라해서 청소년증 찍고 발급날짜 했는데 면...
# 119     개선사항 요청하고 싶습니다 본인 인증 수단을 공인인증서도 추가 하였으면 좋겠습니다 ...
# 120     어플설치 저는 아이폰이라 설치를 했지만 아버지도 어플 설치해드리려고 하니 갤럭시노트...
# 121     어플 팅김현상 월달부터 사용하다가 오늘 업데이트를 했는데 어플 접속이 안됩니다 어플...
# 122     동백점 미가맹점 결제 가능 요청 사용중입니다 감사합니다 동백점 미가맹점에도 일반 체...
# 123                         아이폰에서도 있어 아이폰에서도 있어서 자주 사용해야지
# 124                                   아이폰 드디어 출시됐네요… 쓸게요…
# 125     노트에서는 버전이 낮아서 검색이 안되는데 어느버전 가능 한가요 다운 없이 카드만 사...
# 126              부산경제를 위한 동백전이네요 혜택을 주니 사용하겠습니다 사용이 편리하네요
# 127                                             아이폰은 안되나요
# 128                               이름도 이쁘고 앱도 깔금하게 잘되어 있네요
# 129                                              정말 편리하네요
# 130                      부산시에도 지역화폐가 생겼네요 이름 좋고 화면도 깔끔하네요
# 131                   심플하고 사용하기 편하네요 잡다한 기능보다 기본에 충실한게 좋죠
# 132                          부산에서도 이제 사용이 가능하군요많니 기대가 됩니다
# 133     QR기반 회사 KT가 카드를 발행해요 카드는 하나카드네 하도인가 대기업들 대단하네요...
# 134                                      부산은행은 결제계좌로등록이안됨
# 135     카드도 발급받고 가입도 했는데 새로 실행할때마다 인증된 폰번호와 현재 폰번호가 다릅...
# 136     가입하고 카드 신청해놓고 아직 사용은 안해 봤지만 어플은 정말 만들었네요 박수 짝짝...
# 137                       부산이 살아야 대한민국이 산다 부산지역경제를 똑똑한 소비
# 138                                                    신청
# 139                            개인 정보 입력만 했습니다 어이없는 오류 뭡니까
# 140     들어갈려면 꼭세네번만에들어감프로그램 개발을 한것인지짜증나네S 사용하고 있음 충전 금...
# 141                                   아직 사용 경험이 없어 모르겠습니다
# 142     시안성과 디자인도 뛰어나 사용이 간편하며 다양한 혜택이 있어 무조건 강추 합니다 동...
# 143              이벤트기간에 사용하면 캐시백 지급되구요 평상시엔 적립이 되어서 사용합니다
# 144                     사용시 가입자에게 혜택이 매우 큰것 같습니다 적극 사용할께요
# 145                                                   조아요
# 146                                                사용편리해서
# 147                                                캐시백 개꿀
# 148                      네트워크오류로 계속안들어가 지는데 원래이런건가요 답답하네요
# 149                                                   편하고
# 150     오늘 카드발급 앱을 깔아 하나은행 계좌를 등록했는데 결제상황 보유내역 전혀나오지않습...
# 151                                                 응원할께요
# 152                                설치후 사용해보니 새로운 세상이 열리네요
# 153                              앱도 편리해서 사용도 좋고 캐시백도 좋네요굿
# 154                                    사용이 편리하고 디자인도 멋집니다
# 155                                            혜택이 혜자스럽네요
# 156               바로바로 캐시백이 들어오니까 혜택이 더욱 크게 느껴지네요 굿입니다 bb
# 157     앱설치 사용해보니 App 디자인도 세련되었고 심플한것이 너무너무 마음에 들어요 많이...
# 158     동백전을 설치 사용해보니 새로운 세상이 열리네요 앞으로 카드사용은 자제하고 무조건 ...
# 159                                                   캐쉬백
# 160                                           사용하기에 매우 편리
# 161                  체크카드라서 퍼센트 페이백 좋네요 프로모션기간이 길었으면 좋겠어요
# 162                                   qr코드결제도 어서 됐으면 좋겠네요
# 163                                                  Good
# 164                                              좋은것 같아요ᆢ
# 165             새마을금고 없어 카드발급 안돼요 괜히 충전하여 환불 해주세요 사용도 하는데
# 166                                                  괜찮아요
# 167                                      캐시백도 사용가능하고 매우만족
# 168                                                  신나네요
# 169                                        카드만들다 사용 포기합니다
# 170                       할인폭이 크고 편리해요 상공인에게 도움된다니 더욱 좋네요
# 171                          동백전으로 이용할 생각 입니다 사용하기 편리 합니다
# 172                                                    만족
# 173                                     충전하려니깐 카카오뱅크가 없네요
# 174       본인명의폰 아닌사람은 가입을 못하네요 공인인증같은거나 인증할수있는방법 생기게 해주세요
# 175     유용한 서비스네요 충전하구 카드 받아서 쓰는 좋구 쓰고나니 캐쉬백이 들어오구 디자인...
# 176                                               안들어가지네요
# 177     어플에서 결제가 됐으면 좋겠어요 카드 발급 받는 시간도 오래 걸리고 은행도 지정돼 ...
# 178                                   매우 유용합니다 가족이 쓰고 있어요
# 179                                                 좋습니다😊
# 180                   동백전을 사용해 보니 사용하면 할수록 차곡 차곡 적립되는 캐시백
# 181                                   휴대폰 단말기 살때도 캐시백 되나요
# 182      어려워요 충전방식이라 많이 번거롭네요 폰결제 되는 쉬은 방법으로 업그레이드 부탁드립니다
# 183     문의 답변확인이 안되네요 호완성문제인지 다른어플은 정상적으로 작동하는데 이것만 먹통이에요
# 184                                      정말 사용하기 편하고 좋습니다
# 185                              계좌등록이 계속 실패로 떠서 사용이 불가능함
# 186                                            깔끔하고 혜택 좋고
# 187                      회원가입 동의사항들전부선택햇는데도 안넘어가지는데 오류인가요
# 188     치명적인 단점 지적합니다 환불정책 정말 불편하네요 전체 적립금에 써야 나머지 금액 ...
# 189     회원가입할때 직장주소 검색하고 다시들어오니까 어플 끄지도 않았는데 처음부터 다시 입...
# 190     계좌등록하려니 계속 계좌번호 오류라고하는데 왜그런거예요 숫자 잘못친줄알고 번은 넣어...
# 191
# 192                               교통카드버스나 지하철만 써도 캐시백 되나요
# 193                       앱이 다운로드가 안되고 계속 로딩 중이네요 서버좀 늘려요
# 194     본인명의 핸펀만가능한거가요 아이핀이나 본인인증다른방법도 하게 해주세요 배우자나 부모...
# 195                              들어가지지도 않구만 전화도 안받고 장난합니까
# 196               가맹점찾기가 불편하네요 지도에서 찾기 기능이 있으면 찾기 편할것 같아요
# 197     접속시 계속 팅김 카드신청과정에서도 불안정함 주민번호 입력하면 자꾸 다른숫자로 인식...
# 198                           카드도 예쁘고 앱도 깔끔해서 편하게 사용할 같네요
# 199     기능도 만족스럽고 검색해서 가맹점 찾을 있는거 좋은거 같아요 카드발급신청했을때 진행...
# 200     살인데 카드 발급받을때 주민등록증 번호를 작성하라는데 주민등록증이나 운전면허가 없는...
# 201                                    최악임 깔고나서 본인인증문자아안옴
# 202                      실행이 안됩니다 네트워크 상태를 확인하라는 매세지만 뜨네요
# 203     가맹점 찾기 카테고리를 구별로 나누어 주셨으면 좋겠습니다 시작하니까 해운대구 찾을려...
# 204                                           정말 유용한 앱이네요
# 205                 동백전가입시 LGU알뜰폰은 인증이 안돼 가입이 안됩니다 조정바랍니다
# 206     정말 어디다가 리뷰를 써야될지 몰라서 씁니다 적립이 이루어지는점이 좋고 원하는만큼 ...
# 207     아직 써보지도 못했을 뿐더러 예기치못한 오류라며 접속조차 안되네요 부산지역화폐가 나...
# 208     앱을 다운받아 회원가입 단계까진 잘되나 다음단계에서 처음단계로 되돌아가버려 회원가입...
# 209          어제부터 통신중예기치않은 오류라고 앱사용이 불가합니다 무슨문제인거고 정상화되나요
# 210         본인인증 방법이 폰인증 밖에 없나요 본인명의의 폰이 아닌 사람은 발급이 불가하나요
# 211        추천인은 써야하나요 한글은 안써지고 숫자는 써지는데 휴대폰번호를 쓰는것도 아닌것같고
# 212
# 213     카드신청에 들어가서 카드선택후 신청하기누르면 일정기간 미사용으로 작업이중단됩니다요래...
# 214     다운받았는데 카드신청이 안되네요 계좌등록하고 충전 후에 카드신청 가능한건가요 사용설...
# 215     회원가입시 인증번호가 안옵니다 이틀째 가입중인데 인증번호가 계속 수신이 안되는데 뭐...
# 216                                 지금 카드사용 불가네요 통신오류 뜹니다
# 217                가맹점 검색에서 지역을 지정 검색 가능하도록 기능 추가 부탁 드립니다
# 218     네트워크 상태 원할하지 않습니다 계속 뜨네요 해결 하셔야 할듯합니다 속도 제한 데이...
# 219
# 220     껐다가 켜면 다시 처음부터 인증해야 하는 치명적인 버그가 존재합니다 충전 껐다가 다...
# 221                                    친구가 캐시 들어오더라고 추천해줌
# 222          지역경제에 기여하면서 캐쉬백도 가능한 동백전이 있으니 더이상의 카드는 필요없네요
# 223                                                   좋아여
# 224                                                    최고
# 225
# 226
# 227                                               세금공제 프로
# 228                                                    최고
# 229     부산의 주유소에서 사용이 안된다하여 난감한 경험있습니다 사용가능하도록 지원 배려 바...
# 230                                 쓰자마자 깨시가 들어오니깐 완전짱입니다
# 231     슈퍼에서 우유를 샀읍니다 적립 되여 기분 좋았읍니다 택시는 개인 일반 택시도 안되더...
# 232                                                   편하고
# 233                                 실물카드받았는데 어플엔 등록안되어있어요
# 234                                       지역 자영업에 도움이 됩니다
# 235                                   소상공인과 시민들에게 좋은 제도네요
# 236                               걸제불가능한 곳에 대한 정보 제공이 필요함
# 237
# 238                                            케시포인트 좋습니다
# 239                                              절약에 도움이됨
# 240                                                 적립 대박
# 241                                                  넘좋아요
# 242                                                   멋져요
# 243                               업데이트 실행 안되네요 삭제 재설치도 안됨
# 244                                                캐시백 개꿀
# 245                                                 최고입니다
# 246                                                    굿굿
# 247     깔고 위치확인동의 같은 동의 누른다음에 계속 흰화면이 뜨고 기다리면 네트워크 상태 ...
# 248                          어플들어가니깐 악성코드를탐지햇다고뜨는데 왜그런거에요
# 249                                                   편해요
# 250                                                    완전
# 251     카드 수령지가 자택 외에 설정이 안되네요 리뷰 보니 형식적인 답변 뿐이고 활성화 되...
# 252                                               신통방통합니다
# 253                                               정말 좋습니다
# 254                                                    구웃
# 255                        사용이 편하네요동백전 지점 정보가 좀더 명확했음 하네요
# 256     가맹점이 어디더라 생각 안하고 들어가서 결재하면 어지간하면 가맹점이네요 프로 캐시백...
# 257                                밴드앱 악성코드로 인식합니다 확인바랍니다
# 258                                                 무리 없음
# 259     네이버 밴드 어플을 악성코드로 인식하네요 밴드어플을 삭제하고 어플설치후 밴드를 다시...
# 260
# 261     시작하면 악성코드가 발견되었다면서 창이 뜨는데 해킹당한거 아닌가요 불안해서 앱을 못...
# 262
# 263                                          카드는 언제받을 있나요
# 264     사용처 제한으로 불편함이 많음 특히 재래시장에는 카드계산기 없는 상점이 많아 불편함...
# 265     업로드이후 자꾸 재시작해야 하는 버그가 계속발생 합니다 업로드전에는 전혀 문제 없었...
# 266     동백전의 의도는 좋으나 앱이 좋습니다 동백전이 활성화하지 못하게 된다면 앱이 가장 ...
# 267     동백전회원가입하려는데 현재폰이 부모님명의로 되어있는데 휴대폰인증말고 다른방법으로 가...
# 268                                          편하게 사용하고 있어요
# 269     와이파이 연결시에는 어플 접속이 잘됩니다 데이터 사용시 접속이 안됩니다 데이터 잔여...
# 270     음식점 가맹점되는곳에서 카드사용시 배달의 민족이나 배달대행어플을 통해서 계산해도 캐...
# 271                                                   잘안됨
# 272                                 휴대폰 명의가 틀리는데 가입안 안될까요
# 273     인증문자 자체가 안오는데 카드발급 받으라는거죠 뭔가 제대로 이용할수 있도록 시스템을...
# 274                                    인증번호 발송됐다는데인번이 안와서
# 275                  페이코랑 하나머니가 추가되어 피킹률 퍼센트를 넘길수있는 갓혜자카드
# 276
# 277     가맹점 찾기를 통해 나오는 가맹점이 년전쯤에 자리에 있던걸로 현재는 없어졌는데도 나오네요
# 278                    캐쉬백 이벤트기간 장난 아니네요 있음 퍼겠지만 대만족중 입니다
# 279     동백전어플을깔고난후에 회원가입 약관선택 화면으로 넘어가지지않고 네트워크가원활하지않다...
# 280                                                   페이백
# 281     아직 사용하기전이나 항상 국가사업이 들어간 금융앱이나 국가지자체에서 실시하는 사업들...
# 282                                      아쉽지만 쓰는데 불편함은 없다
# 283                                 인증번호가 안오네요 앱에 문제가 있나요
# 284               계속 통신 오류가 뜨네요 이러면 사용하기 불편해서 사용이 안될 같은데요
# 285                                         앱이문제네요 성질돋구네요
# 286     가입은 수월히 카드신청시 은행계좌 연결하여 다시 키려면 다시 처음부터 충전계좌 연결...
# 287                                              다운로드가안되여
# 288     어플실행시 정상적인OS가 아니라서 이용할수가 없다고 메세지가 나옵니다 엘지V이며 안...
# 289                    어제부터 와이파이해도 안해도 서버통신문제로 연결안된다고 뜨네요
# 290                     본인인증이 휴대폰말고 아이핀이나 공인인증도 추가되었음 합니다
# 291                                             다운이안받아지네요
# 292     이벤기간이라 캐시백 비율이 높아 내가 내는 돈은 줄었음 카드를 아예 안받는 유명한 ...
# 293                             내게 만족을 주는 그런 카드면서 행복감을 주는
# 294     어플이 실행안되요 통신중 오류가 발생했다고 어플 삭제후 다시 하여도 그대로 입니다 ...
# 295     업데이트 이후에 뭘사러 갔더니 분명 해당점포가 캐쉬백대상점포인걸로 아는데 캐쉬백이 ...
# 296                                          카드신청오류 계속뜨네요
# 297                하이마트에서 사용가능한다고 나오나 사용이되지 않습니다 확인부탁드릴게요
# 298     네트워크 연결이 원활하지 않습니다 접속오류 어플과 인터넷은 사용되는 중인데 어플만 ...
# 299             계속 렉걸리고 네트워크접속이 안된다고하고 예기치못한오류가 생겼다며 안됩니다
# 300     켤때마다 통신이어쩌고하면서 종료되고 다시들어가야 됩니다 이번에는 번이나 튕기고 들어...
# 301     사용시 카드충전금액이 모자라거나 안되어 있으면 연결계좌에서 빠져나가잖아요 근데 연결...
# 302                                 카드신청이 안됩니다 눌러도 반응이없어요
# 303               카드신청시 주민번호 입력후 다음화면으로 넘어가지않습니다 업데이트해주세요
# 304     정말 좋은 카드라서 사용하고 있는데 앱에 문제가 있는지 실행하려고 앱을 누르면 자꾸...
# 305            인증된 번홓하 현재 번호가 달라서 계속 초기화 하라고 뜨는데 해결해야 되나요
# 306     너무좋은 카드인데 오류가 심해서 잔액 확인이 안되는점 빨리 개선 되었음 좋겠습니다 ...
# 307     휴대폰 본인인증 문자가 분뒤에 전송되어서 가입이 불가능합니다 인증시스템에 문제가 있...
# 308     아빠 폰에도 깔아드려서 쓰는데 이상하게 동백전만 켯다 끄면 문자에 들어갈 수가 없네...
# 309                                     실행도 안되는구만 하나도 아까워
# 310     정상적인 os가 서비스 이용이 안된다면서 앱실행이 안됩니다 고객센터 전화연결도 안되...
# 311                              연일째 계속 앱도운로드중 아직도 다운중이네요
# 312                회원가입 과정중 인증번호 전송 버튼을 아무리 눌러도 전송이 되지 않음
# 313     두번 터치해야 정상적으로 어플이 실행되는지 모르겠네요 한번 실행하면 보안프로그램 실...
# 314                                          캐시백 현재 프로 대박
# 315     너무좋네요 근데홍보가 이제되기시작했는지 지금만든사람이 많아요 프로캐시백 월까지 연장...
# 316     탭으론 접속조차 안되네요 처럼 폰은 g폰이고 탭으로 인터넷하는 사람은 충전하죠 발급...
# 317     잘사용하고 있습니다 근데 어플을 실행시키면 첫번째는 실행되다가 닫기고 두번째 실행시...
# 318                                              동백전앱이 안됨
# 319     일정 미사용으로 작업이 중단 되었습니다 라고 계속 떠는데 하면 되나요 삭제하고 다시...
# 320           카드 수령지를 자택에서 직장으로 변경되지 않나요 이것땜에 가입 못하고 있읍니다
# 321                                                   좋아용
# 322                                              어플 다운 불가
# 323     좋은데 연결계좌 은행에 카카오뱅크가 없어서 불편합니다 연결계좌은행은 다양해져도 좋을...
# 324                            월별 사용합계를 자동으로 볼수 있으면 좋을듯해요
# 325
# 326                                          체크카드도 캐시백주시지
# 327                                                 겁나 좋음
# 328
# 329                                             캐쉬백 지역 발전
# 330                                                 이용됩니다
# 331                                                   개편함
# 332                                                 감사합니다
# 333
# 334                                                 매우 좋음
# 335                                                  최곱니다
# 336     동백전이 엄청 편리하고 캐시백이 되니 좋습니까 월이후에도 년말까지 쭈욱 했으면 좋겠습니다
# 337                                                    프로
# 338                                                 추천합니다
# 339
# 340
# 341                                               폰결제 되겠죠
# 342                                       어느카드보다 혜택 최고입니다
# 343                                   사용한금액에 포이트도 받고 좋아요굿
# 344
# 345                   사용가능 업체라고 검색하고 갔는데 사용되지 않았습니다 완전 비추
# 346
# 347
# 348
# 349
# 350     공인인증서로도 로그인가능하게해주세요 휴대폰명의가 다른게 너무불편 제발요 아님 폰번호...
# 351                   미적용 매장에서도 체크 카드 겸용이용 할수 있으면 더욱 좋겠군요
# 352                                                 감사합니다
# 353                                      사업자용카드로 등록 가능한가요
# 354                                                최고 입니다
# 355
# 356                                                    따봉
# 357                                         캐시적립이 정말대박이네요
# 358                                               최고의지역화폐
# 359                                        로그인후 사용하게 해주세요
# 360
# 361                                                사용 편하고
# 362
# 363                                               아주만족합니다
# 364                                   이렇게 좋을 없습니다 할인 좋습니다
# 365                   너무좋아요 택시에서 카드결제시 번중 번만 승인되서 다른카드로해요
# 366                                       충전금액 입력가능하게 합시다
# 367                          편리하고 잔액부족시 카드결제 되는점은 개선 바랍니다
# 368                         전월사용실적이 연간으로 있으면 더편할것같아요 좋습니다
# 369                                               계속 해주셍ᆢ
# 370                         편리합니다 Pay 앱이나 잔액을 표시하면 좋을듯합니다
# 371
# 372                                   캐시백 모으는 재미가 쏠쏠하네요♡♡
# 373                                                  좋아요🤗
# 374     개꿀입니다 대신 여기가 사용가능한곳결제는 웬만한곳에서 가능하나 캐쉬백이 되는곳 인지...
# 375                                       사용하기 편리하게 잘만들었음
# 376                                        좋은데 에러가 많이 뜹니다
# 377
# 378     도대체 고객센터는 왜있는겁니까 문의 했는데 일이 지났는데도 보지도않을꺼면 아예 없애...
# 379                          좋아요그리고월달까지 이벤 연장도 해주셔서 감사합니다
# 380                                            캐쉬백 되는 카드는
# 381                                                 캐쉬백되니
# 382     충전금액 환불이 자유로울거라 생각하고 카드발급 어플설치를 하고 충전을 했었는데 급히...
# 383                                                    굿요
# 384
# 385                                                  부산에선
# 386                                     온라인은 사용이 안되서 아쉬워요
# 387              캐시백이 월까지라서 아쉬웠는데 월까지 연장이라 좋아용 꿀이 떨어지는 좋앙
# 388     사용시 와이파이가터지는 곳에서도 모바일 데이터를 켜지 않으면 사용이 안되는데 와이파...
# 389                                               캐쉬백넘좋아요
# 390                                                  Good
# 391                                               사용하기 쉬움
# 392     덕분에 사용하고 있습니다 업데이트 되면서 충전하기가 어렵게 되었네요 이전처럼 네모 ...
# 393                                                  좋아요♡
# 394                             편하게 잘쓰고있는데 월도 캐시백해준다니 가즈아
# 395
# 396                                                 맘에들어요
# 397                                                    좋음
# 398
# 399                                  충전금액이 남았는지 알려주면 좋겠어요
# 400                                           진짜진짜진짜루 좋아영
# 401                                                    없음
# 402                                                앱너무좋아요
# 403                                                  완전좋음
# 404                                    너무좋아요 보너스 받는 느낌입니다
# 405                                                 정말좋네요
# 406                                   사용하고 있어요 프로 적립 유익해요
# 407                                                완전굿입니다
# 408                                                 대박좋아야
# 409
# 410                                잘쓰고 있어요 사용방법이 간단해서 좋네요
# 411                                                   편리함
# 412
# 413                                     유용합니다 포인트가 금방 쌓여요
# 414                                             잘사용하고있습니다
# 415
# 416     어플도 보기 편하고 실시간 캐쉬백 확인되니 쓰고있어요 가맹점 찾기 힘들다는 분들 그...
# 417     카드신청 일주일이 지나도 오지않음 배송업체는 전화도 받지않음 오려나 하나은행가서 신...
# 418                        최고입니다 학령기 자녀를 주부에게는 선물같은 카드이네요
# 419                       혜택업소가 좀더 많았으면 프로혜택 너무좋아요 다같이 윈윈
# 420
# 421                코로나 여파로 사용실적이 적은데 월까지 혜택을 연장 해주면 좋겠습니다
# 422                                                쓸만합니ㅣ다
# 423                                                  Good
# 424                                             사용하기 편리해요
# 425
# 426                                                 아주좋아요
# 427                                                   화이팅
# 428                                                   갠차늠
# 429                               지역경제도 살리고 우리집에도 도움되는 최고
# 430
# 431                                       편하고 좋습니다 혜택도 많고
# 432                                             업데이트가 안되요
# 433                                             프로충전너무좋아요
# 434                                         오거돈 시장님 감사합니다
# 435                                                 감사합니다
# 436                                                좋고 편해요
# 437                                                    좋음
# 438                                        택시가 연동이안되 아쉽네요
# 439                                                    굳굳
# 440                                         아직은 완벽한 어플아닌듯
# 441                                                    감사
# 442                                                 너무좋아요
# 443                                                   좋네요
# 444                                                  긋입니다
# 445                                          쏙쏙 되돌아 오는 재미
# 446
# 447     충전하려 들어가면 계속 튕기고 지우고 깔아도 튕기는데 이러면 그냥 쓰지말라는 소리 ...
# 448                                               무조건 조아여
# 449
# 450                                                너무좋습니다
# 451                                                    개꿀
# 452
# 453                           아직 동백전을 모르는사람이많은듯 홍보가 필요합니다
# 454     잘쓰고있습니다 한가지 요청드리고 싶은건 월별 또는 일정기간별 사용금액을 조회했을때 ...
# 455                                                    개꿀
# 456                                         포인트적립 정말 최곱니다
# 457                                               알림이 빨라요
# 458                                      계속 통신중 오류 뜨는건 뭐여
# 459                                                업데이트안됨
# 460     회원가입조차 되질않아요 문자인증전까지 입력은 되는데 인증문자가 전혀 오질않네요 SK...
# 461                               프로 할인이 연장되어 기분이 좋아서 리뷰씀
# 462                                           유용하게 쓸것 같네요
# 463                                            업데이트가 안되네요
# 464                                            말이 필요없음 최고
# 465     충전 환불 제도도 불편하고 상담원 연결 안됩니다 금액만 충전해서 그거 사용했는데 캐...
# 466                                               가맹점도 많고
# 467
# 468                                               조금번잡스러움
# 469
# 470                                             다들 좋은거 인정
# 471             대형마트 사용만 가능하면 우리나라 최고의 카드혜택이라 믿어 의심치 않습니다
# 472                       vvip 신용카드가 할인을 해주겠나요 이보다 좋을 없어요
# 473                             충전 할려니까 옳바르지 않는 계좌라고 안되네요
# 474                                         자꾸 다운로드대기중인가요
# 475                                             계속 오류가 떠요
# 476                        앱에 접속안되는 날이 왜이리많아요 접속할때마다 접속불가
# 477                                          업데이트 왜이리 안돼요
# 478     사용하기 안드로이드 버전이 낮아 어플 자체가 아예 설치 안되는 경우가 있어요 부산지...
# 479                                                   조아요
# 480                                             포인트많이 쌓여서
# 481     본인인증 단계에서 휴대폰 인증번호 발송이 안되고 카드번호로 인증하려고 해도 번호오류...
# 482                           기간 설정해서 사용내역을 합계도 나왔으면 좋겠어요
# 483                                   업데이트일동안 안되고 앱실행이안되여
# 484                                       하루종일 앱이 실행이 안되요
# 485     가입하려고 폰인증번호 전송누르면 예기치못한문제발생 했다고 진행이 안됩니다 수십번을 ...
# 486     팝업창 아랫부분 닫기인지 다시보지않기 인지 선택하는 창이 화면에 잘려서 누를수가 없...
# 487     간단 명료하게 꾸며져 있슴다 적절히 사용하여 경제에 도움이 되도록 주위 분들께 홍보...
# 488     가맹점 확인할때 카테고리가 나눠져있긴 속에서 가게 이름을 일일이 보면서 즐겨찾기 하...
# 489                                            지금 설치가 안되요
# 490     잘쓰고 있습니다 충전을 해야하는데 업데이트를 요구하는데 설치는 계속 대기중이네요 이...
# 491                                       잔액이랑 캐시백 업데이트되니
# 492     카드가 도착했다해서 우편함에 놔둬달라했는데 집에 갔는데 없더라구요 재발급을 받고싶은...
# 493                                                 안열리네요
# 494     어플이 와이파이 연결될때만 실행 됩니다 데이터를 켜면 네트워크 상태가 원활하지 않습...
# 495     동백전카드 가입에서 비밀번호 실패하고 나서는 접속하기가 힘들어요 충전시킬려고 하는데...
# 496     가입이 안됩니다인증이 안되요발급 받아보려고 어플깔고 휴대폰 인증하는거 아무리 눌러도...
# 497                  이음카드에 기능도 없고 카드 밖에 신청도 안되고 부족한점이 많아요
# 498     g폰 사용하고 있는데 발급받을 있는 방법은 없나요 예를들면 아이패드나 갤럭시탭 또는...
# 499     동백전은 좋은데 어플이 왜이래요 결제가 두번 된거 같아 확인하려고 하니 네트워크 불...
# 500     계좌도 안맞다그러고 신분증 발급일자도 틀리다고그러고 그냥 발급이 이제 안되는건가 몇...
# 501     사용하고 있습니다 아쉬운건 잔액정보인데 사용 금액 상품권 캐시뱁 합계 사용 금액 상...
# 502     동백전은 너무좋은데 간혹오류로 결제가안될때가있고 어플들어가는거도 팅길때가있어요 유용...
# 503     폰마다 차이가있는지 제폰에서는 와이파이 앱에 접속이 안됩니다A 길거리에서 갑자기 충...
# 504     전산오류로 결제가 두번 됐는데 충전한 돈으로 결제한 첫번째 결제를 취소시키고 두번째...
# 505                                                 아직 모름
# 506                                      인증번호가 안오는데 해야될까요
# 507                              데이터 인식을 못하나봐요 깔아도 쓸수가없네요
# 508
# 509                           열때마다 다시 종료해야되네요 어플 제대로 만드세요
# 510       카드발급해서 사용중인데 계속 카드등록발급하라고 어플에 뜨네요카드등록 할수있게 해주세요
# 511                          앱이 자주 버벅 거립니다 터치도 안되고 먹통이 되요
# 512              최고에요 계속되는 적립혜택도 좋고 UI도 신경써서 만든 같아요 편리합니다
# 513
# 514                             돈만빠져나가고 충전이안됨 아직은 많이 부족한듯
# 515                                               열리지가않아요
# 516     네트워크가 원활하지 않아 안된다고 뜨네요 옆에 남편은 확인이 잘되는데 뭐가 문제인가...
# 517                     결제도 안되고 잔액확인도안됩니다 계속 오류뜨는데 왜이런건가요
# 518            급하게 충전 해야 됩니다 어플도 통신사도 케이티라 뭐가 쓰레긴지는 없는 노릇
# 519        네트워크 오류라면서 어플 접속이 안될뿐더러 오늘 결제한 금액 캐시백도 안됐네요뭐지요
# 520                                     인터넷 접속이 안될때가 많습니다
# 521                                      뭐가자꾸 접속이안된대 짜증나게
# 522     어플에 접속이 안되는데 쓰라는거에요 아이폰에서 안드로이드로 넘어왓는데 아이폰에선 문...
# 523                                  명불허전 작품 접속장애 엄청 심합니다
# 524     혜택은 좋은데 어플 동작이 느림 가게가 해당되는지 확인하려고 어플켜다가 포기하는 경...
# 525     신청을해서 등록하려는데 자꾸 통신상연결이안된다하고 네트워크문제라고뜨네요 다른인터넷어...
# 526     폰이 이상한건 가요 데이터로는 동백전이 안들어가지고 충전도 안됩니다 길에서 충전해서...
# 527                                  오늘 결제도 안되고 어플실행도 안되요
# 528                                       어휴 어플관리 진짜 최악이다
# 529     진짜 넘하시네요 접속도 안되고 맨날천날 통신이 불안하다고 하면 시에서 일하시는 분들...
# 530     어플이 연결이되야지 충전을할껀데 어제도오후내내 안되서 결국딴카드사용햇네요 네트워크오...
# 531                               연결이잘안되요네트워크 상태라면서뜨지를않아요
# 532              가맹점 검색할때 현재 위치가 아닌 처음 접속했던 위치로 계속 검색되는듯요
# 533     사용하고 있습니다 월별 이용금액합계 보이게 개선해주세요 사용금액 합계 내려면 계산기...
# 534     설치하고 카드 신청하는데 폰으로 인증번호 확인차 문자앱 실행해서 보고 다시 동백전앱...
# 535     접속이 잘되다가 갑자기 안되네여 다른분들말처럼 데이터 와이파이 구분없이 네트워크 장...
# 536
# 537     마이너스 없어서 개만 카드신청하고 일주일 만에 받았는데 어플에서 충전이 안된다 올바...
# 538     어플 접속이 자꾸 튕겨요 캐쉬백도 제대로 들어오지않고 부족하게 들어오고 고객센터 전...
# 539     다른어플은 실행이되는데 이어플은 lte인데도 실행이 안되고 와이파이껴야 그나마 접속...
# 540     문의글남겨도답변도안하고점심이라고일안하고가맹점이라고버젓이되잇는데사장은동백전가입안되잇다...
# 541                                                 넘좋아요♡
# 542     앱을 실행할 때마다 아래와 계속 에러가 뜨면서 초기화 되요 인증된 폰번호와 현재 폰...
# 543     카드신청시 일정시간미사용으로 거래불가가 계속 뜨는데 제거후 다시 설치해도 그렇네요 ...
# 544     사용 하고 있습니다 근데 가맹점에 포함 있는 곳인데 앱에는 검색이 안되네요 가게에 ...
# 545     제안을 하고자 합니다 어린이들도 사용자로 참여하도록 하면 어떨까요 인천의 인천e음카...
# 546     와이파이에서만 접속이 됩니다 일주일 상탠데 오류 잡아주실지 증상이 분들도 있는거 같...
# 547                                                    서버
# 548     어플이 와이파이 때는 되지만 와이파이가 아닌 상태에서는 오류가 떠서 충전도 잔액 확...
# 549                               진짜 좋은데 카카오뱅크 계좌등록되게해주세요
# 550                 실행하니 통신 예기치않는 오류가 발생했다면서 실행이 됩니다 이런거죠
# 551                                        괞찬아서 주변에 강추합니다
# 552             자기명의휴대폰아니면 가입이 안되는거 같은데 아이핀으로 가입할수있게 해주세요
# 553                          어플에서 qr코드같은걸로 결제기능이 있으면 좋겠네요
# 554                                        그냥 무조건 사용해야합니다
# 555     원래 와이파이있어야만 접속가능한건가요 데이터로는 접속이안되고 와이파이가있어야만 쓸수...
# 556     켜져야 잔액을 확인하고 사용하는 확인해서 쓰지 와이파이연결하니까 데이터만 된데서 데...
# 557                  데이터확인하라고 연결이안되요 앱은 실행되는데 시간째 안되니 화나요
# 558                         충전할려고 앱켰더니 실행이 안되면 어쩌라고요 짜증나네
# 559                어플이 왜이러죠 데이터상태에서 사용이 안되면 밖에선 사용하지말란건가요
# 560     어플이 느려요 실행할때 네트워크가 불안정하다고 안열리네요 가맹점이라고 표시되어있어서...
# 561                                           캐시백이 많아 좋네요
# 562                      제발 서버 확장 하세요 앱에 한번 들어가려면 하루종일 걸림
# 563                                접속이 안되요 확인해주세요 계속 오류나요
# 564                                           어플이 실행이 잘안됨
# 565                  앱이 열리지도 닫히지도 않아요 카드신청만 겨우하고 강제 종료했네요
# 566     Ios 안드로이드 버전 낮으니까 아예 플레이스토어에 없네요 카드나 은행앱은 깔리는데...
# 567                              가맹점 위치 알수 있는 어플 있으면 좋겠네요
# 568     일정시간 미사용으로 작업이 중단되었습니다 카드 신청을 할려니 위처럼 나오며 안되네요...
# 569     갤s 브라우저 크롬으로 설정해야된다고 진작좀 알려주지 어제 전화문의는 그런거 안알려...
# 570     설치해서 들어가니깐 이앱을 삭제하시겠습니까 뜨고 진짜 삭제되고 아니오하면 그냥 흰화...
# 571        네트워크도 잘안되는걸 써라고 써다가 열불나서 카드부쉈음 일부러 이렇게 만든거 아니요
# 572     이용내역 조회시 이용기간에 따른 합계액이 표기되면 좋겠습니다 일치 결제내역조회시 현...
# 573     본인확인 방법을 추가해 주세요 법인사용자의 본인명의의 폰이 아니라며 어플 사용이 불...
# 574     설치 켤때마다 초기화재인증하라고 하죠 등록된 정보와 핸드폰 번호가 다르다는 안내가 ...
# 575                                             저한테는 좋습니다
# 576     개도 아깝습니다 결제가 제대로안돼서 어플실행시키는데 들어가져야지 확인을하지 분간 시...
# 577                                       어플이 실행되야 쓰던가 하죠
# 578                  가입할라는데 인증번호가 안와요 시간초과됫는데도 안와요 왜안오는거죠
# 579                                              진짜 불편하네요
# 580      가입은 하고 되는가 볼려고 충전 했는데요 카드를 만들수가 없네요 뭐이 요렇게 복잡하나요
# 581     카드뱌아서 충전하고 사용하는대 어플에는 사용됬다고 금액뜨는대 가게에서는 사용중지되있...
# 582     어플화면에서는 결제완료창이랑 캐쉬백 내역이 뜨는데 가맹점에서 실결제가 되지는 않는 ...
# 583                                                접속이 안됨
# 584                                              실행이 안됩니다
# 585     앱연결하기 하늘의별따기임얼마썼는지 확인을할수가없음앱이 실행이돼야 뭘하지 LTE상태에...
# 586                           오류 투성이 접속 됐다 안됐다 네트워크도 불안정함
# 587                                 급하게 만든거 엄청티나네 안정성 엉망임
# 588     카드가 오류가 떠서 결제가 취소됐는데 캐쉬백은 들어왔고 어플은 켜지지도 않고 어플을...
# 589     확인안되는데 왜이렇죠 결제안된다고하는데 어플에는 결제한거처럼 나오고 진짜 왜그럽니까...
# 590           안들어가지는게 너무심하네요 이래서 사용가능하겠어요 데이터 와이파이 안들어가져요
# 591     다운로드만 되고 아이콘누르면 동백전로고만 내내떠있고 아무것도 안되는데요 와이파이 데...
# 592                동백전은 좋은데 앱이 말썽이네요 충전할때마다 짜증이 나요 앱이 쓰레기
# 593
# 594                            오늘 하루종일 먹통에 결재 됐습니다 확인해주세요
# 595                                      카뱅이 없어서 아쉽긴 좋아요♡
# 596     어플이 켜져야 잔액 확인을 할텐데 어플이 켜질 생각을 안하네요 리뷰 보니까 다른분들...
# 597                      잘사용하고있습니다 오후 자체가 켜지지 않습니다이유가 뭔가요
# 598                                 부산사람이라면 강추 이벤트프로 평소프로
# 599                        카드를 받고 앱을 실행할려니 안되네요 이렇게 허접하다니
# 600                                 켜져야 뭘하지 공공기관에서 만드는 어플
# 601     결제 알림문자를 받음과 동시 입금 알림문자가 울립니다코로나 같은 지금 시기에 경제도...
# 602     출시 되자마자 사용해서 몇달짼데 처음보다는 세분화된 충전 단위도 편리하구요 잘쓰고 ...
# 603     실행 안되요 너무너무너무 너어어어무 LTE로 해도 안되고 와이파이는 된다고 해서 와...
# 604                       접속이되야하지우짜라는건지 안되요 아예 로딩도안되고 따운됨
# 605     제일은행계좌연결이없나요 카드는왔는데 잔액충전을못하고있어요 어플이 오류라고 켜지지가않...
# 606     쓰다가 갑자기 카드가 안되더니 어플도 안되네요 혜택이 마음에 들어서 쓰고 있었는데 ...
# 607                              앱이 화면이 멈춰있어요 접속이 안되는거같아요
# 608     충전하고 카페에서 사용했는데 직원분이 은행에 문제가 있는거같다고 안된다해서 디른카드...
# 609     지금 앱이 첫화면에서 넘어가지를 않네요 폰을 다시 켜보아도 마찬가지고 앱제거하고 다...
# 610     서버터져서 안써지는게 태반입니다 결제처리도 안되었는데 들어오니 결제된것처럼 차감되어...
# 611                정보 수집 동의후 동백전카드 이미지모양에서 어플실행이 멈추는데 모에요
# 612                                                 안들어가짐
# 613     동백전이 어플없이 사용가능하다면 모르겠지만 필수적으로 어플이 필요한 서비스인데 정도...
# 614                         앱이 안열림 뭐하자는거임 사용자 증가로 오류 골때리네
# 615     알림은 결제가 되었다고 뜨는데 업체에서는 결제가 안되었다고 해서 카드로 결제 했네요...
# 616     오늘 결제가 된걸로 처리되는디 편의점은 안됐다고하고 충전금액만 차금되네요 kt서비스...
# 617                                        실행이안됩니다 개선해주세요
# 618     짜증나요 매장에서는 결제안됐다 그러고 저는 결제됐다고 알람 떴는데 결제하려고 어플드...
# 619     오류가 잘나는데 조금전 결재하는데 동백전카드는 금액지불되는데 결재안뜬다고현금내었는데...
# 620              없네요 사용할수 없어요 카드로 결재도 안되고 앱도 다운되어 먹통이 됐어요
# 621     결제를 했는데 핸드폰에서는 결제가 됐다고 알림이 왔는데 정작 결제한곳에서는 결제가 ...
# 622     실행이 돼요 몇번짼지 모르겠네요 개선되나요 오늘 동백전앱 오류때문인지 평소에 결제되...
# 623                     어플개떡같이 만들어서 켜지지도않고 계속 로딩이고 가끔씩만켜짐
# 624     주유하다가 결제 오류로 다시 결제 했는데 중복으로 결제 되서 취소 했는데도 돈이 안...
# 625     카드를 만드려다가 민증 발급일자 오류를 초과해서 만들 수가 없습니다 운전면허증도 없...
# 626                                          제발 본인확인 추가좀요
# 627            써야돠는데 왜안되냐고요자주이라네요정말 오늘쓸려고있었는데 안되면혜택도안되고뭐죠
# 628     교통카드 없는 카드 개설했다가 있는걸로 바꿀려고 하나카드 통해서 카드해지를 했습니다...
# 629                             인증번호가 안와서 신청못하고 있어요 어케하나요
# 630     결제가 먹통입니다 어플 접속도 되구요 다름 카드를 들고있었기에 망정이지 동백전만 가...
# 631                  네트워크장애로 안되는경우가 잦네요 다른뱅킹은 아무런 문제가 없는데
# 632     동백전이라는 카드혜택은 좋지만 어플만 보면 불편하네요 데이터로 접속하려면 네트워크 ...
# 633
# 634     집에서 와이파이 연결된경우에만 충전이나 어플확인이 가능합니다 어플연결이 안되다보니 ...
# 635                느린속도데이터쓰는사람은 와이파이안잡으면아예안됨 밖에서 사용할수가없어요
# 636                                     회원할려는대 인증번호가 안오네요
# 637     아인증번호 입력하려 나갔다오면 자꾸 앱강종돼서 처음으로돌아가요 인증을 할수가없잖아요...
# 638                               좋습니다 포인트도 바로사용가능해서 유용해요
# 639     어플 실행도 오래걸리고 가맹점 검색이 불편합니다 지도 외에 지역별로 볼수 있는 방식...
# 640                                       댓글에 답장안해주냐 무시하냐
# 641            사용중에 알뜰폰통신사 이동했더니 켤때마다 계속 초기화 불러오는 오류가 있네요
# 642                           결제 실패는 시스템 실패 kt 하나은행 똑바하세요
# 643
# 644     실행 진짜 안됨 이런게 다있나 싶다 캐시백 주니마니 생색이나 내지 말고 실행이나 제...
# 645     자주 에러나요 미리 공지라도 하고 안돼야 당황을 덜하죠 오늘도 일부러 동백전으로 결...
# 646                      가맹점 안뜨나요 가맹점을 봐야 쓰든가하지 빨리좀 고쳐주세요
# 647     어플에서는 사용가능하다해서 갔는데 사장님은 사용못한다면서 자기는 들은거 없다고 하고...
# 648     잘쓰고있었는데 어플실행이 안되네요 다시 설치해도 마찬가지이고 쓰지말라고 만든건 아닐...
# 649                                              접속이 안되네요
# 650                            지금 가맹점찾기 저만 안되는 앱에 오류가 많아요
# 651                                       중소기업 수준도 안되는 어플
# 652                                     사용처도 확인안되는데 불편하네요
# 653     가맹점찾기에 가맹점 자체가 아예 안나옵니다 처음부터 안된게 아니고 어제부터 안나오네...
# 654     카드 발급 안해도 쓸수있나 싶어서 결제했는데 안돼는거 확인하고 환불하려 했는데 문의...
# 655                                 가맹점찾기에서 가맹점이 하나도 안보여요
# 656     갑자기 가맹점 검색이 안되네요 어떤날은 갑자기 결제 오류나고 이렇게 불안정해서 쓰겠습니까
# 657      앱에 들어가면 가맹점 찾기가 원래는 나오는데 어제 위치를 잡아도 안나오는 이유가 뭔가요
# 658                        어제 결제가 안되서 곤란한 경험을 했습니다 카드로 했죠
# 659                    부산에서 쓰라고 만든 카드 맞습니까 안되는곳이 이렇게나 많은지
# 660     다른건 괜찮은데 가맹점 찾기에 가게가 하나도 안나와요 몇번이나 재설치했는데도 가맹점...
# 661                       잘안될때가 많고 환불도 제약있고 그냥 안쓸랍니다 카뱅만세
# 662                                      개발자 바꿔라 제발 부탁합니다
# 663     다되는데 가맹점 조회가 안되는지요 가맹점 찾아보고 가야되는데 하나도 안떠있고 다시 ...
# 664                                          부산사람 만큼은 최고♡
# 665                                  결제내역을 문자로도 보내주면 좋겠네요
# 666     어플켤때마다 초기화가 뜹니다새로 휴대폰인증완료 재시작하면 뜨고 어플 한번쓸때마다 계...
# 667                               매우 훌륭한 시스템을 갖추었다고 생각합니다
# 668
# 669     가압이 완료 된것 같은데 가드신청 햇는데 돼나요 충전도 좀금 해놧습니다 어플 깔고 ...
# 670                      고객센터는 일하는사람있나요 전화도안받고 문의글 읽지도 않음
# 671                            예금이자 생각해보면 현명한 소비가 돈을 버는거임
# 672     쓰고 있습니다 부산시청 열일해주셔서 감사합니다 퍼센트 캐시백 월뿐 아니라 쭉쭉 캐시...
# 673                                          로그인이 때가 많습니다
# 674     혜택은 좋으나 사용하기 불편한 부분이 있습니다 이용내역에 월간 결제 또는 적립내용이...
# 675                                           몇번 클릭해야 연결됨
# 676                                      빠르고 실용적인 면이 좋습니다
# 677     로그인 안되고 가맹점 찾기도 힘들고 주기도 아깝네요 충전식 카드라고 말했으면 발급을...
# 678                              오좋네요 근데갑자기 만원에서 만원으로아쉬워라
# 679     kt앱이었네요 kt폰이 사용불가인 모양이네요 계좌등록 진행중에 인증완료를 누르기전까...
# 680                                      필요할때 앱이 작동을 안하네요
# 681                 자꾸안괴요 충전해서 결제 해야 하는데 카드 달랑 한개 들고 나왓는데
# 682                           머고 네트워크이상하다고 안열린다 젠장 불편해죽겠네
# 683                                         접속이 안되는거예요 진짜
# 684                               접속이 이렇게 안됩니까 사용을 수가 없네요
# 685                                         주말만 되면 접속이 안됨
# 686                                         앱도 안열리고 왜이럼이거
# 687     앱이 안열립니다 왜이럽니까 진짜 확인 할게 있는데 시골이라 와이파이로 접속 할수도 ...
# 688     데이터 무제한인데 네트워크 연결하라하고만 하고 계속 접속이안되나요 돈얼마남은지 확인...
# 689                                           웹에 접속이 안되네요
# 690                                           앱에 접속이 안됩니다
# 691     데이터 연결이 불안정하다더니 어플들 접속은 잘만 됩니다 어플 재설치도 하고 와이파이...
# 692                                       머고 앱실행도안되고 장난하냐
# 693                                접속이 잘안되네요 업데이트좀 부탁드립니다
# 694                                             접속불가 충전불가
# 695                                             로그인이 안되나요
# 696                                쓰레기입니다 이딴게 세금으로 만들어지네요
# 697                       먹통임 앱실행이 안됨 돈좀들여서 실력있는 개발자좀 씁시다
# 698     접속이 안되네요 빨리 계산해야되는데 앱이 접속이 안되서 주위사람들 눈치밥 먹으면서 ...
# 699                                데이터 켜도 로그인 안되는 희대의 쓰레기
# 700     충전금액 확인하고 쓰려고 했더니 어플은 켜지지도 않고 장난치는 것도 아니고 계좌결제...
# 701                앱이 와이파이든 데이터든 아무것도 연결이 안되네요 안정성 신경써주세요
# 702                         네트워크 오류라고 실행자체가 안되네요 점인지 알겠네요
# 703                             되던게 갑자기 네트워크 뭐라하면사 안들어가지냐
# 704                     안들어가지나요 계속튕기기만하네요이러다 무용지물이 되는건아닌지
# 705                                머하는거야 일부러 안되겠했냐 왜이래 자꾸
# 706                                    로그인 안되네요 사용하기 짜증나네
# 707                                          개느리고 접속 안됩니다
# 708     월에 발급 받아 사용 중이에요 프로 캐시백이 어마어마 하네요 덕분에 신용카드 소비도...
# 709                        갑자기 접속이 안되나요 충전을 못해서 캐쉬백 못받았어요
# 710                                      접속이안돼요 충전은어찌해야하나
# 711     와이파이 풀로뜨고 유튜브 빠르게 잘되는데 앱만들어거면 네트워크 연결이 안된다고 뜰까...
# 712     네트워크 개선좀 빨리해주세요 일주일째 데이터로도 접속이안되고 와이파이 연결된상태에서...
# 713     엉망진창입니다 사용하려고 만든어플이 결제하려할때마다 앱이 오류가 빈번하게 나네요 번...
# 714     잘쓰고 있는데 오늘 앱이 안열리네요 네트워크 상태가 원활하지 않습니다 계속 뜹니다 ...
# 715                                                 접속도안됨
# 716                                            안정성이 최악이네요
# 717     번씩 앱이 먹통입니다 쓰고 싶어도 못쓰게 하는 앱이네요 충전금액 확인하고 쓰려는데 ...
# 718     취지도좋고 캐시백도 큰점 좋습니다 아쉬운점이 있네요 충전된 금액이 아닌 계좌연동으로...
# 719                                             접속에러 고치나요
# 720                                        접속 겁나 안됨 뭐하는건지
# 721     어플좀 들어가봅시다 뭐좀 할라하믄 네트워크 상태가 안좋다하고 충전도 못하고 사용도 ...
# 722                                       요즘세상에 들어가지지도 않네
# 723                                       와파든 데이터든 안들어가져요
# 724                                  앱관리 안하냐 네트워크 접속불량 머냐
# 725     리뷰는 스마트폰 쓰면서 처음 남겨봅니다 만원 충전해 놓고 사용하려고 보니 네트워크 ...
# 726                                           츙전한 뒤로 안켜져요
# 727                                           지금 사용이 안되네요
# 728     카드는 잘사용하고 있는데요 앱은 이따위로 만들었나요 와이파이에서만 접속되고 그마저도...
# 729     식당에서 먹고 나가기전에 충전해서 결제하려고 어플을 켰는데 접속이 계속 안되서 환급...
# 730     발급 달도 지나지 않았는데 시스템 장애로 결제 불가에 오류로 충전 불가에 불편하기 ...
# 731                               접속이 자꾸 안되는데 어째된거죠 짜증나네요
# 732     평점이 점대일까 했는데 오류 진짜 많이나고 쓰레기 같아요 충전 해야되는데 어차피 오...
# 733                                                안되냐 에휴
# 734                                     앱이 열리지가 않는데 충전합니까
# 735                                             통신오류가 잦아요
# 736             로그인이 왜안되나요 이리 안들어가지는 어플도 첨봅니다빠른 수정 부탁드립니다
# 737     동일한 후기가 많습니다만 자꾸 네트워크 연결안된다고 하나요 불편해서 쓰겠네요 고작 ...
# 738                   접속 하자 지금 몇일째 접속이 안되는건지 관리할 마음은 있는건지
# 739                                  어플이 계속안열리네요 정말 노답이네요
# 740     앱자체가 안켜지네요 부모님꺼 계좌연결도 분째 인증도못하고있어요 인터넷폰뱅킹안하시는분...
# 741         캐시백되는건 좋은데 앱이 몇번째 안들어가지는건지 돈이 얼마있는지 확인할수가 없네요
# 742                                                   열러요
# 743     쓴지 얼마안됐어도 캐쉬백들어오는것도 좋고 맘에 들었는데 짜증나서 못써먹겠네요 무슨앱...
# 744     앱에 잘안들어가져요 벌써 시간째 들어가지지않고 튕기는데 이게뭔가요 할인해주셔서 좋긴...
# 745                    실행이 안됨 와이파이 빵빵한데도 안되고 데이터로도 안됨요 불편
# 746               잔액 확인하려고 어플 들어가는데 접속 안되면카드를 사용하라는건가요 대체
# 747     현재 시간째 먹통이네요 식구들이랑 외식하고 동백전으로 계산할려니 앱도 안열리고 도무...
# 748             똥입니다 잘쓰다 안되서 몇번을 다시해도 예기치 못한 오류라고 나오네요 짜증
# 749                               맨날 접속이 안됨 관리도 안할거 만들었는지
# 750     앱이 먹통입니다 네트워크 연결이 안된다고 뜹니다 빨리 고쳐주세요 가족 폰의 앱이 먹...
# 751                                 뭔가요 계속 열리지도 않고 짜증 나네요
# 752              어플실행시 오류 오늘카드받아쓸려했더니 바로어플접속 먹통 이래가 뭐하겠나요
# 753                                어플 진짜 만들었네요 툭하면 접속도 되고
# 754     연결이안돼요 위치켜도 가맹점나오지도않고아니 도대체 점거안하고 뭐하시는건지동백전괜히만...
# 755                           접속도안되고 깔고지웠는데도 접속안되요 개선해주세요
# 756                                                  이게머요
# 757     네트워크 관리 해주세요 맨날 연결 돼서 충전도 못하고 오늘도 캐시백 혜택 원은 봤을...
# 758          쓰고있는데 네트워크 오류가 자주 발생해서 잔액을 제대로 확인할 없을때가 많습니다
# 759              인증번호가 밀려서 날라오죠 분안에 오지도 않아서 가입조차 진행할 없습니다
# 760                             서버연결 진짜 쓰레기같네요 부산시청 실망입니다
# 761                 금액확인 사용할려고하니 오류뜨네요자주 에러가 나니 사용하기 불편해요
# 762              심심하면 안열리네요 쓰라는건지 쓰지말라는건지 열려야 확인도하고 충전도하죠
# 763                                   캐시백은좋은데 앱사용오류가너무심해요
# 764        이전엔 접속 되었는덕 오늘새벽에 서버넓힌다고 충전안되더니 지금은 어플이 켜지지않아요
# 765                            몇번을시도해도잘되지가않네요 언제쯤 제대로 될까요
# 766                       와충전할려고 하는데 들어가지지가 않네요 앱이 이때위인가요
# 767                               진짜 앱이 연결도 안되고 오류나고 레기인지
# 768     앱이 열려야 충전해서 사용을 하죠 안열리는 경우가 많아요 네트워크가 원활하지않다고 ...
# 769               실행 단계에서부터 막힙니다 만들기만 하지 말고 관리도 잘해주길 바랍니다
# 770                      앱이 열리지가 않아요 잔액이 얼마남았는지 확인할수가 없네여
# 771     Lte Wifi 데이터 연결 상태가 안좋다고 실행이 안됩니다 실행이 안되면 충전을 ...
# 772       접속이 되야 충전을 하든 뭘하지 제발 접속 하게 해주세요 LTE wifi 둘다 안되요
# 773                       결제서비스가 접속이 안된다니어처구니 없는 부산시와KT구나
# 774                                       어플 되다가 접속이 안되네요
# 775                                         오류가 왤케 자주 난대요
# 776
# 777                                       계속어플접속이안돼요왜그런거죠
# 778     다른앱은 잘되는데 동백전은 도대체 와이파이로도 데이터네트워크로도 네트워크 상태가 고...
# 779                        어제부터 네트워크연결이 안된다고 접속이 안돼요 해결함요
# 780     잘쓰고 있었는데 최근에 번호이동을 뒤로알뜰폰알뜰폰 계속 초기화하라고 하고 초기화메뉴...
# 781     오늘 하루종일 로그인이 안되네요 오류도 자주나고 등록된 가맹점에서도 사용 안되는곳이...
# 782     실행이 안되요 첫결제하고 포인트확인하려는데 종일 안됩니다 어플이 있나 부산사람들 성...
# 783     계속 네트워크가 연결이 안된다고 하는지ᆢ와이파이도 무선도 해봤어요 고객센터는 통화하...
# 784                  갑자기 네트워크 오류라고 실행이 안됩니다 앱을 재설치해도 안됩니다
# 785     며칠동안 네트워크 상태가 원활하지 않다면서 접속이 안되는 이유를 모르겠네요 충전을 ...
# 786                                               오류가 잘떠요
# 787                                  가맹점도 많고 적립이 바로바로참 좋죵
# 788                   노트 에서도 되나요 부산은행서 호환이 안된다는데 이해가 안되서요
# 789
# 790
# 791
# 792                 앱이종종다운이되어서열리지 않을때가 있어요 벌써 삭제후 다시 깔았어요
# 793
# 794                                                    오굳
# 795                                                    할인
# 796                                     간편하게 유용하게 활용할 있어요
# 797                                                   편리함
# 798                                               너무너무좋아요
# 799                                                   조아요
# 800
# 801             고객센터 문의는 아예 관리를 안하는것 같아요 읽지도않고 처리도 않해주시네요
# 802                                                많이 쓰세요
# 803
# 804                                                   좋네요
# 805                                    대형마트는 사용이 안돼는게 불편함
# 806                 웬만한 식당 가게 되어서 유용합니다 월별 한도액이 늘어나면 좋겠어요
# 807     소상공인 찾아서 사용하게되고 적립도 팍팍되고 최고입니다 부산경제 화이팅 상품권보다 ...
# 808
# 809
# 810                                                  넘좋아요
# 811                                       죽이네요 엄청 적립받고있어요
# 812                              페이백 프로 최고 만족하며 쓰고 있어요 좋음
# 813                          정말 시민이면 동백전카드는 무조건 있어줘야 플랙스죠
# 814                                                  조아조아
# 815     인증번호가안오네요 아니무슨 내폰skt고 다맞게했는데 인증번호 전송햇다카믄서 안오는건 뭐지
# 816                                           사용하고 있어요 감사
# 817                                 포인트를 바로바로 받을수 있어 넘좋아요
# 818     앱을 열때 마다 폰번호와 맞지않다고 나오고 초기화하라고 해서 몇번을 다시 했는지 모...
# 819
# 820                                    전산 다운이라고 사용안될때 똑땅해
# 821                                                사용중입니다
# 822
# 823                               쓰는 본인에게 이득이 되니 매우 만족합니다
# 824
# 825                         TV선전과같이 쓰고나면 웃음이나네요 프로로가면 조을듯
# 826
# ...
# 2596                         진짜 못만들었다 캐시 못쓰게 하려고 잔머리만 굴린듯
# 2597                                         가맹점찾기 만들어주세요
# 2598                                 지갑 어디갓어 있던게 없어짐 어이없네
# 2599    예전어플이 쓰기편해서 지금어플이랑 너무비교됨 쓸데없는 메뉴랑 소개글만 많고 사용가능...
# 2600    적립금이랑 현금이랑 분리해서 보여주세요 현금하고 적립금이랑 구분이 안되서 잔고에 현...
# 2601    불편하네요 기존 앱보다 불편하네요 금액충전은 메인창에 한눈에 확인하고 충전이 되었는...
# 2602    가맹점 안내 예전어플에 되는 가맹점 검색할수 있어서 편했는데 없어져서 불편해요 넣어...
# 2603    회사 바뀌고 나서 문제가 많네요 카드결제도 안되고 제한도 많고 고객센터 연락해도 해...
# 2604                                           앱사용이 불편합니다
# 2605    최소한 기존의 편리한 기능은 따라가야 할거 아니냐 대학생들 시켜서 개발시키냐 편리하...
# 2606    나는 이전 하나카드를 삼성페이에 등록해서 사용하니 불편함을 못느겼는데 신규 사용자는...
# 2607    공지를 제대로못읽었는지 기존꺼못쓰고새로만들어쓰란소린줄알고 멀쩡한기존동백카드 삼성페이...
# 2608    전에 동백전보다 사용하기 불편합니다 그냥 전과 똑같이 하면 안되나요 이벤트도 소리소...
# 2609             이전 어플방식이 편한데 캐시 이용법이 불편한 곳으로 굳이 업체를 바꾸셨네
# 2610    기존것보다 쓰기도 불편해 유저들이 불편하다고 해도 수정보완할 생각은 없고 업체가 선...
# 2611                          진짜 불편하게 바꼈다 불편한게 한두가지가 아니에요
# 2612    왤케 불편하게 바꼈는지 그전 동백전도 불편했지만 이건뭐 새건데도 복잡하게 바껴서 찾...
# 2613    불편해요 기존 앱에서는 한도가 남았고 충전할수 잇는지 명확하게 나와서 제가 계산할 ...
# 2614    도대체 누가 앱을 이렇게 기획했나요… 처음에 알아보기 힘들면 그냥 알아보기 힘든건데...
# 2615    토스 앱이 정신없고 편의성도 줄은거 같지만 이것들은 적응이 되지만 토스등록은 안되는...
# 2616                                                  별루다
# 2617    사용하기 힘듦 사용가능 가맹점 리스트를 보고싶은데 아무리 찾아도 안보여요 구석에 쳐...
# 2618    푸시알림 사용내역 알림받으려규 푸시알림 켰더니 마케팅 알람이랑 오네요… 알림껐더니 ...
# 2619    불편해요 알림 설정 아무리 해도 절대 안와요 자체도 보기 불편하고 뱅크샐러드 연결도...
# 2620    나만 불만 있는게 아니었구나어디서 할인받고 있는지 진짜 궁금한데 애먼 광고들만 많아...
# 2621    결제 푸시 알림이 안와요 이전 앱에서는 결제 푸시 알림이 왔는데 코나카드로 바뀌고 ...
# 2622    혜택 좋아서 잘쓰고있습니다 카드 이용시 앱에서 결제 금액이랑 잔액 사용처가 뜨는 P...
# 2623    하나도 아까워요 예전 어플이 사용하기 편하고 보기도 편해요 쓸데없는 팝업이나 엄청띄...
# 2624    사용내역 푸시알림 왠만하면 리뷰 안남기는데 진짜 일대일 문의해도 된다고 하는데 푸시...
# 2625    직관성 최악 환불하기도 한참 찾아야하고 돈옮기기를 계좌이체마냥 혼동하게 만들어둬서 ...
# 2626                                           앱이 먹통이네요에휴
# 2627    어플개발자 짤라야겠는데요 그사람월급도 시에서 지원받을텐데 세금아깝습니다 이상황 지속...
# 2628    가맹점확인 가맹점 찾기 메뉴가 없어진거같은데 가맹점 확인할수있는거좀 만들어주세요 결...
# 2629                          잘사용할께요 타시도처럼 기부서비스도 있었으면합니다
# 2630    공지사항 그만 띄우세요 어플들어가면 공지사항 팝업을 개를 띄웁니까 빨리 금액확인하고...
# 2631    가맹점이 있는지 찾을수 없으면 동백전의 유용한 기능을 쓰는데 하라는건지 전에는 가맹...
# 2632    하나도 아까움 삼성페이 등록 가능했던 이전 앱과 카드로 돌려주세요 너무너무 불편해서...
# 2633    하나도 아까워요 캐시랑 충전한 금액 구분도 어렵고 진짜 지난앱보다 겉만 번드르한 최...
# 2634    오랜만에 쓰려고 다시 깔았는데 카드도 다시 발급받아야되고 그건 그렇다 치고 새로운 ...
# 2635                                        금액이 적어서 불편합니다
# 2636    진짜 너무하네 예전보다 사용하기는 겁나어렵고 내돈넣고 사용하는데 광고도봐야되고 사용...
# 2637    전에 kt보다 편하구만 별점테러는 초기 정착시 설명 부족 때문일 자꾸 선불카드 등록...
# 2638                                                 거지같은
# 2639                                    참으로 불편하다 일부러 그러는가
# 2640                   이전 동백전카드에 잔액이 없어졌네요 케시백된 금액은 사라졌나요
# 2641
# 2642    지역사업하나 말아먹는 어플이네 사업 땄는지 모르겠네요 볼수록 짜증나고 멀쩡한 사업체...
# 2643                                          전에 쓰던거 돌려줘요
# 2644    문제가 많아야죠 잔액이 카드사용 후에도 변경되지 않음 이용내역을 눌러도 사용한내역이...
# 2645    코나 이벤트 참여할려고 선불카드도 발급받고 결제를해도 코나볼을 주지않습니다 도대체 ...
# 2646    제발 받은 혜택 없에주세요 받은 혜택 하나도 안궁금해요 받은 혜택 제발 빼주세요 조...
# 2647    다좋은데 가맹점 찾기가 없어졌네요 가맹점보고 충전했는데 없으니 불편함니다 가맹점 리...
# 2648                             연결계좌에 은행은 늘려줄껍니까 돈쓰지 말까요
# 2649    진짜 코나카드 바뀌고나서 개구려짐 진심이럴꺼면 왜바꾼건지 어플에서는 가맹점 조회도 ...
# 2650    바뀌고 새로 등록한 카드는 직영점 사용가능 전에 만든건 직영점 사용안됨 추잡하고 치...
# 2651                                                불편하네요
# 2652    월별 이용금액 합계로 표시 안되나요 월별로 만원까지 적립이되서 이번달에 썼나 확인하...
# 2653    이전 동백전사업자는 캐시백을 잔고처럼 쓸수있어서 자유로웠는데 코나로 바뀌고 나서는 ...
# 2654    방금까지 사용했는데 갑자기 결제시 오류가 발생한다며 실행이 전혀 안되네요 캐시백 사...
# 2655    깔끔하고 쓰기 편하네요 괜찮은데 캐시백 적립 내역과 캐시백 사용내역만 따로 없다는게...
# 2656    UI쫌 개선 합시다 캐시백 쓰는 사람이 대부분일텐데 캐시백이 얼만지 사용하는지 숨겨...
# 2657                                          회사를 왜선정 햏는지
# 2658    불편합니다 캐시백 금액보유금액 한번에 조회하게 해주세요 이전 어플은 가능했어요 기간...
# 2659                                             생각보다 편하더
# 2660    알림 돈썻으면 알림좀 울리게해주세요 토스랑도 연동이 됬으면 좋겠어요 옛날 하나키드는...
# 2661                               충전도 안되면서 쓰라는거야 충전오류 미친
# 2662    좋은데… 깔끔하고 좋은데… 사용하면 알림이 울렸으면…하는 작은 아쉬움이 있네요 잔액...
# 2663             쓰레기어플임 하나도 제대로되는게없음 문제해결안되상담사 연결안되 쓰라는거냐
# 2664                          운영할거면 제대로 하길 이도저도 아닌꼴 만들지말고
# 2665    쓰고있는데 하나만 말씀드리자면 결제 부족한 금액 자동충전 기능에서 금액이 만원으로 ...
# 2666                            사용 가능 금액과 캐쉬 금액 합산을 표시 달라
# 2667    어플에 댓글 남겨보는게 얼마만인지도 모르겠네요 개발자님은 어플이 직관적이라고 생각하...
# 2668    캐시백 세부사용내역 보여주세요 기본에 기본도 안되어 있는듯요 누가 도대체 개발하셨죠...
# 2669    If you live in BusanKorea republic of This app...
# 2670
# 2671                                           구동백전을 돌려달라
# 2672    어플 옛날처럼 하면 안되나요 내지갑 이런거 왜하죠 불편 그냥 메인에서 모든 금액 있...
# 2673    업데이트 이후 사용불가 화면으로 가기까지도 오래 걸리고 좋게 충전버튼까지 누르면 그...
# 2674    저번꺼는 포인트를 onoff로 간단하게 됬는데 그것도 안되고 삼성페이랑 연동도 안되...
# 2675    진짜 거지같음 기존 동백전은 충전 금액이 자공으로 차감됐는데 할때마다 사용을 눌러서...
# 2676    전반적으로 업체에 비해 불편함 특히 캐시백 사용하기가 제일 불편함 어플 사용이유가 ...
# 2677    지난 잔액과 잔액 비교가 되었으면 좋겠습니다 최소한 어린애 가계부도 입출내역과 잔액...
# 2678                                         옛날 카드보다 복잡해요
# 2679                                               잘쓰고있어요
# 2680                            앞전 동백전카드보다 별루 페이결제도 안되고등등
# 2681                                      불편한듯 쓸데없는 창도 많고
# 2682                 그전 앱이 펹리하고 보기도 좋습니다지금앱은 불편해요다시 돌려주세요
# 2683
# 2684    나까지 안보태고싶은데 불편불편 앱을 개발한사람이 누군지가 궁금 사용을 해봤는지 무엇...
# 2685                                                   불편
# 2686                                                 좋았어요
# 2687
# 2688                                              도움되는 시책
# 2689    업데이타 하라는데 도무지 되질안네여 종전처럼 편리하게하면 동백전쓰는분들이 편할같네여...
# 2690                           포인트와 충전금액을 이전처럼 따로 금액분리 요함
# 2691
# 2692
# 2693                                                 편리함이
# 2694                                수도권꺼보다 불편함 부산이라서 그런가요
# 2695
# 2696         영수증에보니 국민은행 체크카드라고 써있던데거기에 관해 고지받은바는 없었던것같은데
# 2697                                           저번보다 완전 불편
# 2698     업데이트 하라고 해놓고 업데이트 되도 안하고 짜증만 나네 쿠키 데이터 삭제해도 안되구만
# 2699                             삼성페이도 안되고 따위로 만들거면 했냐 진짜
# 2700    불편해졌어요 많은 분들의 의견과 동일한 내용들이지만 달이 지났는데도 개선 사항이 보...
# 2701                                        계속사용가능토록 해주세요
# 2702    사람들 생각 같구나 전체적으로 복잡한거 같아요 캐쉬백도 바로바로 확인이 안되고 불편...
# 2703              업데이트도 잘안돼는 쓰레기같은앱 국민청원하던가 해야지 이건비리있다 진짜
# 2704    이전 어플이 사용하기 용이하고 한눈에 정보 파악하기 좋았음 업체 바뀌면서 개선이 아...
# 2705                그냥 간단히 만들면 되는것을 짜증 납니다 맨날 광고을 띄워야 합니까
# 2706                                       짜증나요 수시로 접속안되요
# 2707    가맹점 배너 만들어주세요 예전에 문제 관련해서 일에 가맹점배너 만든다고 하셨는데 아...
# 2708    어플 거지같아요 이용내역에 따른 캐시백이 얼아되었다는 금액을 넣어주세요 작년 어플과...
# 2709    이전보다 불편해짐ui 누가 만든건지 참글고 충전은 한도가 왤케높게함 어짜피 씩만 쓸...
# 2710    아진짜 이따위로 만들었나요 업데으트도 안되고왜 업체가 있게 거죠 짜증이 나네요 관리...
# 2711                                        이전에 사용하던게 좋네요
# 2712          쓰기불편해요 개선의 의지가 없든지 능력부족 아래 점짜리 리뷰 내용들 공감됩니다
# 2713                                    업데이트 하루종일 안되고 뭐에요
# 2714                     오늘 업데이트했더니 적립내역이 이제 보이네요 제일 기다렸음
# 2715
# 2716    앱을 굳이 바꿔야 했는지 예전 버전의 앱이 직관적이고 사용하기에 용이했습니다 지금 ...
# 2717                                          갑자기 앱먹통은 뭐죠
# 2718    오늘은 앱이 전혀 열리지 않네요 일인지 몇번을 시도해도 열리지 않아요 답답하네요 짜...
# 2719     이전 동백전은 오류 번도 없었는데 잔액환불도 느립니다 일자 결제오류건 환불은 언제되나요
# 2720                                         업데이트도안되고 왕짜증
# 2721                                    안됨 카드 등록안됨 만원 돌리도
# 2722    등록하고 한참 사용중인데도 실물카드를 등록하라는 말이 계속 나오는데 무슨뜻인지 모르...
# 2723                                           왜안되는거에요불편해
# 2724    아이폰 사용내역 알림 아이폰 사용내역 알림 언제쯤이면 사용 가능한가요 결제 내역이 ...
# 2725    앱이 계속 실행이 안되면 사용하란 얘긴가요당장 써야하는데사용이 안되는거 대한 공지사...
# 2726                        먼저번거랑 비교가되네요 광고도많고 앱들어갈때 불편해요
# 2727                             사용가능금액중 내잔고 확인이 쉬웠으면 하네요
# 2728                                         간편하게사용할수있어좋음
# 2729       업데이트하고 나서 안들어가지고 환불도 시간엄청걸리는 바꾸고나서 좋아진게하나도 없네요
# 2730                                               구우응ㆍ우웃
# 2731                                                   완조
# 2732                                             앱실행이안되네요
# 2733    어플을 열려고 하면 열리지 않는 경우가 자주 발생합니다 캐시백 사용도 이전보다 불편...
# 2734                          UI가 과거보다 어려워졌음 UI차원에서 개선 요망
# 2735                                  앱이 이유도없이 자꾸 꺼져서 빡쳐염
# 2736                                    혜택은 계속 되었으면 좋겠습니다
# 2737                                   중단됫다고안되고업데이트하라고안되고
# 2738                                                 적립적립
# 2739    동백전은 삼성페이에서 사용이 되었는데 아건 카드를 들고 당겨야 되는건가요 아님 방법...
# 2740                                                  좋아용
# 2741                                                 좋습니다
# 2742    쓰기 싫음 자동으로 캐쉬도 안돼 사용 잔액확인도 없고 승인 내역만 있어 바뀌고 하나...
# 2743                                  프로 적립된 포인트 현금처럼 씁니다
# 2744    정말로 교통카드 기능이 없어졌나요 삼성페이 등록도 안돼던데 되게 만들 예정인가요 새...
# 2745    결제시 푸쉬알람이 안떠요 문의를 남겨서 재설정 하라는대로 했는데도 결제알람이 안뜨네...
# 2746    사용가능금액이 캐시백포함인지아닌지 알수가있어야죠 사용자가 항상 그거 합계를 하던지 ...
# 2747    아이폰 결제내역 알림은 되나요 문의를 해서 시킨대로 했는데도 안되네요 결제내역 알림...
# 2748                            사용장애로 결제잘못됐음 빨리환불해라 벌써주째다
# 2749    카드 대행사와 비교돼서 한개도 아까워요 카드 포인트 쓸때마다 어플 켜야하고 불편하네...
# 2750                                                 충전하지
# 2751    멀쩡한 이전 동백전kt을 이딴 데랑 바꿔서 시민들에게 불편을 주는 가맹점 보기 기능...
# 2752                                                  좋아용
# 2753                                                 구제불능
# 2754                                       예전 보다 사용하기 불편함
# 2755    업데이트가 안되서 데이터 캐시 삭제했는데도 안됩니다 삭제하고 다시 깔아볼려고 해도 ...
# 2756    사람들 불편사항 비슷한데 몇달이 지나도 개선의 의지가 보이네요 잔액 나오게 하는게 ...
# 2757          분명히 지난 앱이 구동되는지 봤을텐데 기본적인걸 애초에 안넣고 업데이트로 하니
# 2758    진짜 별한개도 아까움 캐시백 받은 내역 보여주는거 투명성이 없음 업체 바꼈는지 모르...
# 2759    리뷰들처럼 캐시백이나 전반적인 부분에서 이전것보다 불편함 개선의지도 없어보이고 이럴...
# 2760    사용내역 보이게 하세요 댓글은 리뷰 복붙같은거 달거면 달지말고요 댓글이 똑같아요 성...
# 2761                                 사용자에게 만은 해택이있어 추천합니다
# 2762                                         포인트 사용하기 불편함
# 2763                                              이전앱이 나음
# 2764    진짜 전에쓰던어플이훨씬좋음 뭐하나편한것도없고 잔액환불도 전에쓰던건 빠릿빠릿바로돈이들...
# 2765    불편하네요 이전에 앱은 사용가능 금액 캐시백 금액 간단하게 확인이됐는데 이번앱은 고...
# 2766            아이폰 알람 배너부터 알림설정 되어 있는데 어플에서 푸쉬알림이 안오는걸까요
# 2767                                        최곱니다 현금도 돌려받고
# 2768                              전에사용한앱에비해너무불편해요캐시쓰기도힘들고
# 2769                                  바꿨는지 전보다 사용하기 불편하네요
# 2770                                           동백전앱이 편합니다
# 2771                                                  불편함
# 2772    최악의 사용하기 완전 불편하고 연결된 카드가 있다는데 카드번호를 보니 내가 보유하고...
# 2773    와진짜 앱에 평가남겨보긴또 내가 부산시예산가지고 대행하는 업체이고 그거로 돈벌고있으...
# 2774                                                최고입니다
# 2775                       경기화폐는 삼성페이된다던데 동백전은 아직 계획이 없나요
# 2776    캐시백 받을랫다가 쓰러지겠네요 묶여있는거 어케 뺍니까 군데 돌아다녔는데 한군데도 사...
# 2777    개선요구사항 캐시백 내역 이번달 캐시백 금액 이번달 사용한 카드내역 총액 보이게 해...
# 2778                        도대체 어디에 뭐가있는지 알수도없이 별한개도 아깝네요
# 2779                                                   개똥
# 2780                            쓰레기보다 최악이라는 말보다 말이있다면 정도급
# 2781                             사용하기도전에 댓글보고안씀 부산시가노리는건가
# 2782                           계속해서 기기에서 충돌앱이라 나오는데어찌 해결좀
# 2783                                      불편합니다 저번앱이 훨나앗음
# 2784    사용금액이랑 캐시백 금액 합쳐서 나와야지 따로따로 나오면 어쩌자는 건데 어이가 없네...
# 2785    케이뱅크밖에 쓰는데 은행이 없어서 사용 못하는 모든 은행 들어오나요 적어도 이전에 ...
# 2786                                   충전은행 어케바꿔요 드럽게불편하네
# 2787                                                 충전하기
# 2788    충전 얼마했는진 알려줘야지 충전가능금액을 만원현재잔액으로해서 충전가능하다해놓고 한도...
# 2789    개쓰레기같은 사용하려고 해도 로딩화면만 쳐깜빡이는 개쓰레기같은 앱입니다 로딩할게 뭐...
# 2790    캐시백 한도가 만원 이면 충전한도도 만원 보유한도도 만원으로 결정하면되지 처음부터 ...
# 2791                               불편하네요게시밳ᆢ용하기도 엄데이트도안도고
# 2792     잔액확인 카드잔액확인 어플 처음 켰을때 화면에서 할수있게 개선바랍니다 매번너부 불편해요
# 2793                       아이폰 알림 카드 결제하고 알림 오게 업데이트 해주세요
# 2794    총받은혜택 이달에만 받은 혜택으로 바꾸거나 아예 없애는것도 좋을것같아요 받은혜택은 ...
# 2795    하라는 대로 해도 업데이트가 안됩니다 지우고 다시 설치해도 역시 안되네요 부산시는 ...
# 2796    내가 캐쉬백받은 금액이 얼마인지 확인이 안되요 그거때문에 쓰는 건데요 이전 앱에 비...
# 2797                     한도가 바뀌고하면 공지를 해주세요 너희끼리만 알면 뭐합니까
# 2798                     쿠폰주고 cu 매장가면 전카드 버린카드가져오라고함 어이없음
# 2799    잔액 표시를 캐쉬백잔액 사용 안할때 변경을 하면 남아있는 잔액이 바뀌어야 구분이 갈...
# 2800                                                  씁니다
# 2801       대중교통 이용도 않되게 해놓고 부산동백전 이라고한심하네요 선정되었는지 감사해야겠네요
# 2802    계좌등록 여러건 등록 안되나요 입금 출금 전부다 계좌 인증하면서 수시로 바꿔야하네요...
# 2803                                                   그냥
# 2804                                                  좋와요
# 2805
# 2806    진짜 ui부터 편의기능 싹다 최악이네 삼성페이등록도 안돼 바코드결제도 안돼 qr결제...
# 2807    주유소에서 사용이 안됩니다 카드를 긁어서 결재하는 방식은 하지못합니다 긁을수 있도록...
# 2808                                        난좋은데 정신병자들 많네
# 2809                               항상 감사한 마음으로 사용 하고 있습니다
# 2810                         불편 그자체 누가 만드는지 모르겠지만 안써보는것같음
# 2811                                                 편리해요
# 2812                                    카드결제는되는데내용확인이안돼네요
# 2813                                 진짜 성의없네 답글은 복사 붙혀넣기내
# 2814                                  한동상향했는데 만원이상충전 안되네요
# 2815                                                  불편함
# 2816                                        그전에 비해 너무불편해요
# 2817                                         잔돈없이 사는세상 감사
# 2818                                      현금인출기능이 없어가 불편함
# 2819                                             사용하고 있어요
# 2820                                 업데이트 안됨 이전보다 불편 짜증폭발
# 2821    서비스 같이하네 업데이트 하니까 소득공제 신청 동의 자동으로 뜨던데 미리한 사람은 ...
# 2822    포인트 사용 표시가 헷갈리게 되어 있고 총받은 포인트 표시가 불필요하게 표시되어 있...
# 2823                                    이전 동백전보다 사용하기가 불편
# 2824                 쓰고 있습니다 삼성페이가 되어서 별개 감점 삼성페이 되게 해주세요
# 2825
# 2826
# 2827                                       바뀌고나서 너무불편사항만음
# 2828                                           예전보다많이불편해요
# 2829                                     사용이 편리하고 충전도 쉬워요
# 2830                                                  우꾸끠
# 2831                                                   aW
# 2832    업뎃 이후에 개인정보 동의 안하면 화면이 안넘어가네요 먼짓거리인지쓸수록 짜증만나네리...
# 2833                한도 늘리면 뭐하노 어플 업데이트도 안되 다시 설치도 안되 짜증나네
# 2834
# 2835
# 2836    자꾸 댓글로 문의를 달라고하는건가요 리뷰평을 보고 편의성을 보는건데 여기다 답글 달...
# 2837                           불편하게 바뀌고 기존카드 사용도 못하게 해놨네요
# 2838
# 2839                      실력이 없는지 개선이 안되는 업데이트는 하는지 수가 없다
# 2840                                           ㅣㅣㅣ 도영 ㅣㅣㅣ
# 2841    업데이트도 안되고 삭제하니 앱이 다운로드도 안되고 어쩌라는건지 바뀌고 나서 사용엄청...
# 2842    업데이트도 안되고 삭제하고 다시깔려고 하니 대기중만 나오고 사용 엄청불편하네요 빠른...
# 2843                   앱이갑자기업데이트하라고뜨면서 업데이트 안돼고 앱자체가아예안돼요
# 2844    우씨 업뎃이 안되잖아요설명한것처럼 들어가서 삭제하고 했는데도 안되요개짜증남 마넌 뭐...
# 2845                                     업데이트를 자주해서 불편합니다
# 2846    다들 부산시에 민원 넣어주세요 이렇게 불편하게 만들어놓고 담당자는 하는게 없나봐요 ...
# 2847
# 2848    업데이트가 왜이리 안되나요 카드를 쓰고싶은데 업데이트가 안되고 앱이 안열려서 못쓰고...
# 2849                                      진짜 최악 어쩔 없어서 사용
# 2850                                               조아요 저도
# 2851    잔액이 업데이트가 안되요 만원 충전하고 계속 오프라인 카드로 쓰는 중입니다 결제 승...
# 2852                                              예전보다 불편
# 2853                                    기냥 광고쓰레기 어쩔수없이쓰는듯
# 2854    사업자 가맹점 개인 사업자로 개인용 카드 사용하면서 사업장에 큐알결제도 가능하게 사...
# 2855    문제가 많네요 몇개월이 지났는데 사용내역 알림이 아직까지 안오는지 그게 뭐라고 아직...
# 2856    실물카드를 가지고 다녀야 하는 불편함 초반 자동차 지급하는 이벤트로 기존카드가 있음...
# 2857                                               개는 없는지
# 2858                                   예전 이관되기전에 카드 사용되나요
# 2859     케이뱅크도 지원 해주세요 카카오뱅크도 있는데 금융권인 케이뱅크가 없는건 이해가 안되네요
# 2860    어플이진짜 직관적이지가 않음 지역카드인만큼 나이드신분들이 많이 사용할텐데 헷갈리게 ...
# 2861    설문조사하라해서 설문조사중 맨밑에 건의사항 적고 있는데 갑자기 휴대폰 문제인지 입력...
# 2862    연결계좌 여러개 할수 있도록 조치 부탁 드립니다 충전시 연결계좌가 하나라 사용이 불...
# 2863    불편사항 백날 말하면 머하누 매크로가 답변하는데 매크로저격하는 리뷰에도 매크로 답변...
# 2864                                           가맹점찾비불편합니다
# 2865           제발 안드로이드에서 국가사용제한 풀어주세오 메일도 보냈습니다 제발 풀어주세오
# 2866                            업데이트가안되요 설정에서 데이터 삭제했는데두요
# 2867                           좋긴한데 빠른시일내에 삼성페이 연동되길 바랍니다
# 2868    로코 정책지원금 사용할수있게 해주세여 정책지원금이라고 이벤트성으로 들어온 적립금이 ...
# 2869    로코 이벤트라고 천원 주더니 사용조건이 충전금 전액사용 이후에 카드캐시네 자동충전 ...
# 2870                                        부산에서 사용해서는 정말
# Name: REVIEW, dtype: object

# %% [markdown]
# #### 불용어 처리 및 한글자 제거

# %%
def define_stopwords(path):
    
    SW = set()
    #불용어를 추가하는 방법 1.
    #SW.add("동백전")
    
    # 불용어를 추가하는 방법 2.
    # stopwords-ko.txt에 직접 추가
    
    with open(path) as f:
        for word in f:
            SW.add(word[:-1])
            
    return SW

from tqdm import tqdm_notebook # 시간 바

# 명사 추출한 것 중 SW에 포함되지 않으면서 한글자 제거
def text_tokenizing(corpus):   
    token_corpus = []
    # tqdm을 사용하여 진행 과정을 보기
    for n in tqdm_notebook(range(len(corpus))):
        token_text = mecab_nouns(corpus[n]) # 위에서 정의한 명사추출 함수 실행
        token_text = [word for word in token_text if word not in SW and len(word) >1]
        token_corpus.append(token_text)
    return token_corpus

SW = define_stopwords("D:/연구알바/stopwords-ko.txt")

# %% [markdown]
# #### 사용자사전(분리되면 안되는 단어들을 따로 사전에 정의)
# > 동백전
# 하나은행
# 부산은행
# 캐쉬백
# 캐시백
# 지역화폐
# 해결방안
# 고객센터
# 교통카드
# 체크카드
# 불편함
# 본인인증
# 본인 인증
# 인증번호
# 코나아이
# 삼성페이
# 오프라인
# 온라인
# 비번
# 비밀번호
# 아이디
# 전화번호
# 폰 번호
# 생년월일
# 홈페이지
# 소상공인
# 지원금
# 로코
# 큐알코드 등등

# %%
tokenized_text = text_tokenizing(cleaned_corpus)
print(tokenized_text)
# Out:
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\ipykernel_launcher.py:22: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/2871 [00:00<?, ?it/s]
# [['지역화폐', '카드', '신청', '사용'], ['화이팅'], [], ['여기저기', '사용', '경제', '도움'], ['혜택'], ['사용', '혜택'], ['글로벌', '테스트', '베드'], ['모바일', '지역화폐', '설치', '카드', '신청', '구성', '수도', '명절', '카드', '부모', '지역', '페이', '수당', '나중', '복지', '비용', '이걸로', '부모', '기대'], ['출시', '이용'], ['군더더기', '마음', '사업장', '사용', '가능'], [], ['선택', '약정', '선택', '네트워크', '장애', '진행', '개인', '정보', '장사'], ['이용', '시민', '성장'], ['대표', '이름', '이름', '이용', '혜택', '기대', '사용', '편리'], ['편의점', '사용'], ['설치'], ['군더더기', '사용'], ['사용', '사용'], ['코드', '결제', '기본', '카드', '신청'], ['회원가입', '사람', '가입'], ['적립', '한도', '충전', '적립', '한도'], ['마트', '결제', '확인', '상황', '충전', '네트워크', '상태', '확인'], ['오류', '충전', '데이터', '상태', '와이파이', '사용', '정보', '오류'], ['오류', '개선', '오류', '캐시백', '문의', '가게', '취소', '재결', '방법', '오류', '해결방안', '불편'], ['실행', '사용', '정보', '취득', '실패'], ['먹통', '설치'], ['오류', '오류', '사용'], ['발급', '한참', '오류', '충전', '개선', '부탁', '하루', '시도', '충전', '금액', '입력', '자동'], ['오류', '설치', '네트워크', '오류'], ['며칠', '가맹점', '조회'], ['카드', '결제', '지연', '오류', '카드', '사용', '오류', '계산', '사람', '카드', '감안', '처음', '오류', '카드', '카드', '보안'], ['가맹점', '문제', '서버', '접속', '제한', '가맹점', '가맹점', '검색', '가맹점', '확인', '안드로이드', '애플'], ['가맹점', '가맹점', '삭제', '재설', '위치', '허용'], ['가맹점', '가맹점', '아무것', '어딜', '오류'], ['가맹점', '사용', '캐시백', '만족', '가맹점', '가맹점', '전체', '가맹점', '사용', '가능', '가게', '검색', '관련', '가게', '아무것', '평소', '이용', '가게', '사용', '불편', '동네', '사용', '가능', '유무', '불편', '설정', '설정', '활성', '문제', '업데이트', '감사'], ['가맹점', '가맹점'], ['오류', '접속', '로그인', '소용', '시스템', '안정', '신경'], ['가맹점', '가맹점', '검색', '검색', '아무것'], ['오류', '장난', '포인트', '오류', '충전', '개선'], ['사용', '가맹점', '카페', '사용', '잔액', '오류'], ['버그', '수정', '버그', '수정'], ['가맹점', '가맹점', '해결'], ['네트워크', '네트워크', '실행', '수정'], ['기간', '검색', '기능', '강화', '요청', '월일', '오늘', '사용', '실적', '적립', '실적', '검색', '기간', '사용', '금액', '적립', '금액'], ['문자', '인증', '삭제', '문자', '인증', '메세지'], ['교통카드', '이용', '내역', '카드', '이용', '내역', '교통카드', '금액'], ['결제', '내역', '합계', '결제', '내역', '합계', '결제', '내역', '확인', '합계', '시스템', '지출', '관리', '불편'], ['문제', '충전', '충전', '취소', '충전', '충전', '충전', '한도', '충전', '충전', '취소', '충전', '한도', '초기'], ['쓰레기', '신청', '에러', '개발', '전화', '에러', '실력', '인정', '에러'], ['최악'], ['금액', '충전', '금액', '충전', '다운', '충전', '자체', '카드', '발급', '고객센터', '전화', '전화', '답변', '실망'], ['사용', '내역', '충전'], ['업데이트', '오류', '보완', '부탁'], ['운영', '불편함', '제때', '개선', '국민', '불편함', '의견', '제기', '점심', '퇴근', '카드', '승인', '불가', '점심', '퇴근', '충전', '불가', '업데이트', '문제', '불편함', '캐쉬백', '광고', '실적', '퇴근', '마트', '카드', '기존', '카드', '걸음', '불편함', '운영'], [], ['오류', '캐시백', '재미', '기간', '단위', '이용자', '캐시백', '혜택', '전체', '총합', '한눈', '직관', '만족도'], ['오류', '오류'], ['오류', '오류', '여분', '카드', '개선', '개발', '실력자'], ['카카오', '뱅크', '계좌', '등록', '불편'], ['고객센터', '고객센터', '답변'], ['결제', '카드', '결제', '일반', '슈퍼', '카드', '결제', '실패', '카드', '결제', '카드', '캐시백', '확인', '사용', '정보', '오류', '삭제', '결제', '확인', '뭡니까', '슈퍼', '결제', '오전', '카드', '전화', '안정'], ['가맹점', '기능', '개선', '가맹점', '기능', '위치', '지도', '사용', '가능', '가맹점', '검색', '불편'], ['결제', '결제', '잔액', '업데이트', '업데이트', '공지', '주요', '기능'], ['단위', '충전'], ['택시', '결제'], ['가맹점', '표시', '지도', '표시', '띄어쓰기', '검색', '검색', '조건', '오탈', '검색'], ['사용', '정보', '취득', '실패', '사용', '정보', '취득', '실패', '실행', '문구', '삭제', '오늘', '카드', '충전', '내일', '사용', '해결', '부탁'], ['삭제', '로그인', '화면', '회원가입', '인증', '먹통'], ['네트워크', '안정', '겁니까', '포인트'], ['실행', '오류', '실행', '와이파이', '데이터', '오류'], ['서비스', '개인', '정보', '확인', '오류', '메시지', '삭제', '오류', '메시지'], ['설치', '금일', '저녁', '카드', '주니', '포스', '결제', '플로', '결제', '확인', '삭제', '에러', '서버', '사용'], ['본인인증', '단계', '인증', '문자', '개선', '본인인증', '단계', '인증', '문자', '개선'], ['덕분', '오랜만', '카드', '발급'], ['화면', '하단', '카드', '화면', '진입', '모션', '카드', '충전', '캐시백', '사용', '설정', '메뉴', '불편', '만족'], ['보유', '필요', '삭제', '충전', '보유', '포인트', '내역', '시민', '기능', '광고', '충전', '클릭', '현황', '충전', '금액', '포인트', '표시', '시안', '활용', '화면', '설치', '사람', '보이', '광고', '내용', '필요', '아래쪽'], [], ['사용', '내역'], ['코드', '결제', '부탁', '실물', '카드', '아이폰'], ['클릭', '가입', '마지막', '비밀번호', '설정', '클릭'], ['카드', '신청', '계좌', '등록'], ['캐시백', '단위', '충전', '가능', '현명', '소비', '가능'], [], ['금액', '설정', '충전', '금액', '사용', '충전', '금액', '입력', '충전'], ['가맹점', '생각', '충전', '금액', '환불', '실패'], ['가맹점', '그게', '서비스', '충전', '식이', '통장 ...

# %% [markdown]
# #### 문서 단어 행렬

# %%
def dic_and_bow(clean_text):
    
    # 데이터를 dictionary 형태로 명사 list 만들기 
    dictionary = corpora.Dictionary(clean_text) 
    
    # 출현빈도가 너무 적은 단어는 제거 
    dictionary.filter_extremes(no_below=5) 
    
    # 명사 형태로 말뭉치 만들기 
    corpus = [dictionary.doc2bow(text) for text in clean_text]
    
    # TF-IDF으로 변환 
    tfidf = models.TfidfModel(corpus)
    corpus_tfidf = tfidf[corpus]
    corpus = corpus_tfidf 
    
    return corpus ,dictionary

corpus ,dictionary = dic_and_bow(tokenized_text)

# %% [markdown]
# - TF-IDF는 모든 문서에서 자주 등장하는 단어는 중요도가 낮다고 판단하며, 특정 문서에서만 자주 등장하는 단어는 중요도가 높다고 판단합니다.
# - TF-IDF 값이 낮으면 중요도가 낮은 것이며, TF-IDF 값이 크면 중요도가 큰 것입니다.
# - 즉, the나 a와 같이 불용어의 경우에는 모든 문서에 자주 등장하기 마련이기 때문에 자연스럽게 불용어의 TF-IDF의 값은 다른 단어의 TF-IDF에 비해서 낮아지게 됩니다.
# > 모든 문서에서 자주 등장하는 단어의 중요도를 낮게 평가 (?!)

# %% [markdown]
# #### 최적 Topic 개수 산출
#
# <span style="color:red">coherence 보단 perplexity를 우선적으로 보는 게 좋음</span>
#
#
# __(1) Coherence Model__
#
# Topic이 얼마나 의미론적으로 일관성 있는지 판단.
# 수치가 높을수록 일관성 높음. 0.55 정도면 우수하다고 함.
# Coherence가 너무 높아지면 정보의 양이 줄어들게 되고, coherence가 너무 낮아 정보들이 인관성이 없다면 분석의 의미가 낮아지게 됨.
#
# .3 is bad
#
# .4 is low
#
# .55 is okay
#
# .65 might be as good as it is going to get
#
# .7 is nice
#
# .8 is unlikely and
#
# .9 is probably wrong

# %% [markdown]
# ### 매번 모델을 돌릴때마다 토픽이 달라지기에 random_state가 필요할 것 같다

# %%
# Coherence Model

coherence_values = []

for i in range(2,51) : 
    ldamodel = models.ldamodel.LdaModel(corpus, num_topics=i, id2word=dictionary, alpha="auto", eta="auto"  ) # 파라미터는 기본으로 설정 
    coherence_model_lda = CoherenceModel(model=ldamodel, texts=tokenized_text, dictionary=dictionary, topn=10)
    coherence_lda = coherence_model_lda.get_coherence()
    coherence_values.append(coherence_lda)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-9e61f1a36f7b> in <module>
#       6     ldamodel = models.ldamodel.LdaModel(corpus, num_topics=i, id2word=dictionary, alpha="auto", eta="auto"  ) # 파라미터는 기본으로 설정
#       7     coherence_model_lda = CoherenceModel(model=ldamodel, texts=tokenized_text, dictionary=dictionary, topn=10)
# ----> 8     coherence_lda = coherence_model_lda.get_coherence()
#       9     coherence_values.append(coherence_lda)
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\gensim\models\coherencemodel.py in get_coherence(self)
#     610
#     611         """
# --> 612         confirmed_measures = self.get_coherence_per_topic()
#     613         return self.aggregate_measures(confirmed_measures)
#     614
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\gensim\models\coherencemodel.py in get_coherence_per_topic(self, segmented_topics, with_std, with_support)
#     570             segmented_topics = measure.seg(self.topics)
#     571         if self._accumulator is None:
# --> 572             self.estimate_probabilities(segmented_topics)
#     573
#     574         kwargs = dict(with_std=with_std, with_support=with_support)
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\gensim\models\coherencemodel.py in estimate_probabilities(self, segmented_topics)
#     542                 kwargs['model'] = self.keyed_vectors
#     543
# --> 544             self._accumulator = self.measure.prob(**kwargs)
#     545
#     546         return self._accumulator
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\gensim\topic_coherence\probability_estimation.py in p_boolean_sliding_window(texts, segmented_topics, dictionary, window_size, processes)
#     154         accumulator = ParallelWordOccurrenceAccumulator(processes, top_ids, dictionary)
#     155     logger.info("using %s to estimate probabilities from sliding windows", accumulator)
# --> 156     return accumulator.accumulate(texts, window_size)
#     157
#     158
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\gensim\topic_coherence\text_analysis.py in accumulate(self, texts, window_size)
#     441
#     442     def accumulate(self, texts, window_size):
# --> 443         workers, input_q, output_q = self.start_workers(window_size)
#     444         try:
#     445             self.queue_all_texts(input_q, texts, window_size)
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\gensim\topic_coherence\text_analysis.py in start_workers(self, window_size)
#     475             accumulator = PatchedWordOccurrenceAccumulator(self.relevant_ids, self.dictionary)
#     476             worker = AccumulatingWorker(input_q, output_q, accumulator, window_size)
# --> 477             worker.start()
#     478             workers.append(worker)
#     479
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\multiprocessing\process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\multiprocessing\context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\multiprocessing\context.py in _Popen(process_obj)
#     320         def _Popen(process_obj):
#     321             from .popen_spawn_win32 import Popen
# --> 322             return Popen(process_obj)
#     323
#     324     class SpawnContext(BaseContext):
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      63             try:
#      64                 reduction.dump(prep_data, to_child)
# ---> 65                 reduction.dump(process_obj, to_child)
#      66             finally:
#      67                 set_spawning_popen(None)
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# KeyboardInterrupt:

# %%
x = range(2,51)
plt.plot(x, coherence_values)
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score")
plt.show()

# %% [markdown]
# __(2) 언어 모델 평가방법 (PPL: Perplexity)__
#
# 확률 모델이 결과를 얼마나 정확하게 예측하는지 나타내는 값.
# 동일 모델 내 파라미터에 따른 성능 평가할 때 사용.
# 선정된 토픽 개수마다 학습시켜 가장 낮은 값을 보이는 구간을 찾아 최적화된 토픽의 개수 선정.
# 수치가 낮을수록 높은 정확도.
# Coherence Score와 함께 고려해야함.

# %% [markdown]
# <span style="color:red">train, test set 나누기</span>
#
# - 8:2로 나누는 게 좋다고 함.
# - 80%로 학습한 lda model을 20%의 테스트셋에 적용시켜 수치를 보고, 가장 좋은 토픽의 개수를 찾아 전체 데이터셋에 토픽모델링 적용

# %%
len(corpus)
# Out:
# 2871

# %%
corpus_train = corpus[:1080]
corpus_test = corpus[1080:]

# %%
perplexity_values=[]

for i in range(2,100) : 
    ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=i, id2word=dictionary)
    perplexity_values.append(ldamodel.log_perplexity(corpus))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-481cd2c1c531> in <module>
#       3 for i in range(2,100) :
#       4     ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=i, id2word=dictionary)
# ----> 5     perplexity_values.append(ldamodel.log_perplexity(corpus))
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\gensim\models\ldamodel.py in log_perplexity(self, chunk, total_docs)
#     833         corpus_words = sum(cnt for document in chunk for _, cnt in document)
#     834         subsample_ratio = 1.0 * total_docs / len(chunk)
# --> 835         perwordbound = self.bound(chunk, subsample_ratio=subsample_ratio) / (subsample_ratio * corpus_words)
#     836         logger.info(
#     837             "%.3f per-word bound, %.1f perplexity estimate based on a held-out corpus of %i documents with %i words",
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\gensim\models\ldamodel.py in bound(self, corpus, gamma, subsample_ratio)
#    1099                 logger.debug("bound: at document #%i", d)
#    1100             if gamma is None:
# -> 1101                 gammad, _ = self.inference([doc])
#    1102             else:
#    1103                 gammad = gamma[d]
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\gensim\models\ldamodel.py in inference(self, chunk, collect_sstats)
#     663
#     664         # Initialize the variational distribution q(theta|gamma) for the chunk
# --> 665         gamma = self.random_state.gamma(100., 1. / 100., (len(chunk), self.num_topics)).astype(self.dtype, copy=False)
#     666         Elogtheta = dirichlet_expectation(gamma)
#     667         expElogtheta = np.exp(Elogtheta)
#
# KeyboardInterrupt:

# %%
x = range(2,100)
plt.plot(x, perplexity_values)
plt.xlabel("Number of Topics")
plt.ylabel("Perplexity Score")
plt.show()

# %%
# 토픽 개수, 키워드 개수를 정해주는 변수를 추가.
NUM_TOPICS = 13

NUM_TOPIC_WORDS = 10

def print_topic_words(model):

    # 토픽 모델링 결과를 출력해 주는 함수.
    print("\nPrinting topic words.\n")
    
    for topic_id in range(model.num_topics):
        topic_word_probs = model.show_topic(topic_id, NUM_TOPIC_WORDS)
        print("Topic ID: {}".format(topic_id))
        
        for topic_word, prob in topic_word_probs:
            print("\t{}\t{}".format(topic_word, prob))
            
        print("\n")

# LDA를 실행.
model = models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary, alpha="auto", eta="auto")

word_dict = {};

for i in range(NUM_TOPICS):

    words = model.show_topic(i)

    word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words]

pd.DataFrame(word_dict)

# %%
# pyLDAvis 불러오기
import pyLDAvis
import pyLDAvis.gensim

# pyLDAvis를 jupyter notebook에서 실행할 수 있게 활성화.
pyLDAvis.enable_notebook()

# pyLDAvis 실행.
data = pyLDAvis.gensim.prepare(model, corpus, dictionary)
data
