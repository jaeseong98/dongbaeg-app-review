# %% [markdown]
# 한국어 형태소 분석기 간 차이
# - https://mr-doosun.tistory.com/22
# - https://soohee410.github.io/compare_tagger
# - https://konlpy-ko.readthedocs.io/ko/v0.4.3/api/konlpy.tag/
#
# 특징적인 차이:
# - mecab 속도가 빠름
# - kkma 속도가 가장 느림
# - okt는 어근 추출에 뛰어남 (ex. 가는, 가던, 가고 == 가다 로 추출)

# %% [markdown]
# konlpy 이외의 한국어 전처리 패키지
# https://mangastorytelling.tistory.com/entry/%EB%94%A5%EB%9F%AC%EB%8B%9D%EC%9D%84%EC%9D%B4%EC%9A%A9%ED%95%9C-%EC%9E%90%EC%97%B0%EC%96%B4-%EC%B2%98%EB%A6%AC-%EC%9E%85%EB%AC%B8-0210-%ED%95%9C%EA%B5%AD%EC%96%B4-%EC%A0%84%EC%B2%98%EB%A6%AC-%ED%8C%A8%ED%82%A4%EC%A7%80-Text-Preprocessing-Tools-for-Korean-Text

# %% [raw]
# pip install konlpy
# pip install nltk
# pip install gensim
# pip install pyLDAvis
# pip install customized_konlpy

# %%
import pandas as pd
pd.options.display.max_rows = 3000
pd.options.display.max_columns = 100
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# 텍스트 전처리
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from konlpy.tag import Okt 
from ckonlpy.tag import Twitter
import re 
from string import punctuation
import requests
import pickle
import ast

# 토픽모델링
import gensim
from gensim import corpora, models
from gensim.models import CoherenceModel
import pyLDAvis 
import pyLDAvis.gensim
# Out:
# /home/a201843240/.local/lib/python3.6/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# #### 미리 만들어둔 리뷰데이터 불러오기

# %%
df = pd.read_csv('review_df')

df.head(3)
# Out:
#    Unnamed: 0        DATE  STAR  \
# 0           0  2020-01-07     1
# 1           1  2020-01-07     5
# 2           2  2020-01-07     3
#
#                                               REVIEW  LIKE
# 0  오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하...     0
# 1            국굿 아이폰 바코드나 큐알코드 결제만 앱에서 가능 하면 최고일것 같아요     0
# 2  어플 팅김현상 2월달부터 잘 사용하다가 오늘 업데이트를 했는데 어플 접속이 안됩니다...     0

# %%
del df['Unnamed: 0'] 

df.head(3)
# Out:
#          DATE  STAR                                             REVIEW  LIKE
# 0  2020-01-07     1  오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하...     0
# 1  2020-01-07     5            국굿 아이폰 바코드나 큐알코드 결제만 앱에서 가능 하면 최고일것 같아요     0
# 2  2020-01-07     3  어플 팅김현상 2월달부터 잘 사용하다가 오늘 업데이트를 했는데 어플 접속이 안됩니다...     0

# %%
df.shape # 총 2871개 리뷰
# Out:
# (2871, 4)

# %% [markdown]
# #### 부정적인 리뷰만 떼어서 새로운 df 만들기

# %%
df_negative = df[df['STAR'] < 3]

df_negative.shape
# Out:
# (1349, 4)

# %%
df_negative.head(8)
# Out:
#           DATE  STAR                                             REVIEW  LIKE
# 0   2020-01-07     1  오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하...     0
# 3   2020-01-07     2  동백전 어플설치 저는 아이폰이라 설치를 했지만, 아버지도 동백전 어플 설치해드리려고...     0
# 5   2020-01-07     1  ㅠ 주민등록증 찍는데 청소년들은 청소년증으로 하라해서 청소년증 찍고 발급날짜 했는데...     0
# 6   2020-01-07     1    불안정한 앱 이용내역 확인 시 강제종료 앱 메뉴도 간단하고 동백전 서비스도 훌륭한데      0
# 7   2020-01-07     1  앱 꺼짐 문제 앱 들어가서 캐쉬백을 누르면 앱이 꺼져버리는데 어떻게 해야되나요? 다...     0
# 8   2020-01-07     1                 안들어가져요 업데이트 했는데 안들어가져요.. 해결 좀 해주세여     0
# 9   2020-01-07     1  고객 서비스가 최악이네요 어플 오류로 인하여 충전 하려고 하니 바탕화면으로 팅기는데...     0
# 10  2020-01-07     1  왜때문에 인증이안되나효 내이름에 내 탄생일에 내 명의의 핸드폰번혼데 자꾸 확인하래 ...     0

# %%
# 토픽모델링에서의 train set, test set 분리를 위해 미리 데이터 셔플링

df_negative = df_negative.sample(frac=1).reset_index(drop=True)

df_negative.head(8)
# Out:
#          DATE  STAR                                             REVIEW  LIKE
# 0  2020-02-05     1  앱 시작하면 악성코드가 발견되었다면서 창이 뜨는데 이거 해킹당한거 아닌가요? 불안해...     0
# 1  2020-04-10     1  아니 와이파이 네 칸 풀로뜨고 유튜브 등등 빠르게 잘되는데 왜 이 앱만들어거면 네트...     0
# 2  2021-07-13     1  문제가 너무 많네요 몇개월이 지났는데 사용내역 알림이 왜 아직까지 안오는지 그게 뭐...     0
# 3  2020-09-08     1            업데이트를 해야 사용 가능하다는데 업데이트가 안됩니다 무슨 문제일까요?     0
# 4  2020-02-19     1                          연3일째 계속 앱도운로드중 아직도 다운중이네요     0
# 5  2020-12-18     1                              이렇게 대책없이 할바에 하지 말았어야지     0
# 6  2020-04-10     1                    이거 진짜 뭔 앱이 연결도 안되고 오류나고 *레기인지..     0
# 7  2021-04-30     1  쓰기 불편해졌어요.. 개선해주세요 1. 어플 키면 바로 잔액이랑 포인트, 합계 금액...     0

# %% [raw]
# df_negative.to_csv('df_negative')

# %% [markdown]
# #### corpus (말뭉치) 생성

# %%
# 각 행들을 corpus에 저장 

corpus = df_negative['REVIEW']

corpus
# Out:
# 0       앱 시작하면 악성코드가 발견되었다면서 창이 뜨는데 이거 해킹당한거 아닌가요? 불안해...
# 1       아니 와이파이 네 칸 풀로뜨고 유튜브 등등 빠르게 잘되는데 왜 이 앱만들어거면 네트...
# 2       문제가 너무 많네요 몇개월이 지났는데 사용내역 알림이 왜 아직까지 안오는지 그게 뭐...
# 3                 업데이트를 해야 사용 가능하다는데 업데이트가 안됩니다 무슨 문제일까요?
# 4                               연3일째 계속 앱도운로드중 아직도 다운중이네요
# 5                                   이렇게 대책없이 할바에 하지 말았어야지
# 6                         이거 진짜 뭔 앱이 연결도 안되고 오류나고 *레기인지..
# 7       쓰기 불편해졌어요.. 개선해주세요 1. 어플 키면 바로 잔액이랑 포인트, 합계 금액...
# 8       사용내역에 현금잔액이랑 남은포인트도 같이 정산되어 보이게 해주십쇼 뭐가 이렇게 보기...
# 9       앱실행 마다 전화번호가 맞질 않다고 뜨며 실행이 안되서, 가입을 계속 다시 하면서 ...
# 10                         휴대폰이 노트10 인대요 업데이트가안되요 이거외이러치요
# 11              앱에 접속안되는 날이 왜이리많아요? 접속할때마다 30~40%는 접속불가;;
# 12      카드 이관 신청을 하는 데 카드 재발급이 '필수'네요. 새로운 부산 동백전 선불카드...
# 13      잔액 부족하면 연결 계좌에서 바로 빼가지 말고 알람 줬으면 좋겠어요. 충전해서 쓰면...
# 14      카드 재발급 강제사항은 둘째치고, 앱 자체 가독성이 넘 떨어집니다. 적립금과 충전금...
# 15      오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하...
# 16                                       기존카드등록안되요 어떻거하나요
# 17                     아니 잔액이관도 안되고 상담사 연결도 안되고 어쩌라는 겁니까?
# 18      ? 잘 있던 동백전 놔두고 kt껄로 옮겨서 원래는 없던 수수료를 받는다? 그냥 돈 ...
# 19      주유소에서 사용이 안됩니다. 카드를 긁어서 결재하는 방식은 하지못합니다 . 긁을수 ...
# 20      계좌등록이 하나 밖에 안되네요.ㅠ 계좌변경할 때마다 인증 받아야 되고, 기존처럼 한...
# 21                                          업데이트가 안됩니다...
# 22      도대체 위치정보가 필수동의인 이유가 뭔가요? 약관내용보니까 굳이 필요없는정보나 마케...
# 23                          들어가지지도 않구만ㅡㅡ 전화도 안받고... 장난합니까
# 24      그 전 어플보다 너무 불편하고 못 만들었어요 정작 사용자가 제일 많이 쓰는 버튼과 ...
# 25      동백전 앱 개선 요청 적립금액이랑 현재금액 보기 너무 어려워요 헷갈리기도 하고 앞에...
# 26              업데이트도 잘 안되고.. 잔액 확인하려면 어플 접속해야 되고 너무 불편해요
# 27      전에 어플이 더 사용하기 쉽고 편한거같아요. 지금 어플은 뭐가 뭔지도모르겠고 사용 ...
# 28               결제됐다 취소되고 지맘대로 카드긁은데서 재결제하러 오라해서 다시 갔다왔음
# 29      어플실행시 정상적인OS가 아니라서 이용할수가 없다고 메세지가 나옵니다. 엘지V40이...
# 30      본인확인 방법을 추가해 주세요!! 법인사용자의 경우 본인명의의 폰이 아니라며 어플 ...
# 31                                          업데이트가 너무 안되네요
# 32                      대체 업데이트하라면서 하루종일 돌기만 하고 사용 안 되네요.
# 33      가입은 하고 되는가 볼려고 100.000 원 충전 했는데요 카드를 만들수가 없네요~...
# 34                   고객센터는 일하는사람있나요? 전화도안받고 1:1문의글 읽지도 않음
# 35       이거 인증번호가 밀려서 날라오죠? 3분안에 오지도 않아서 가입조차 진행할 수 없습니다.
# 36      현재잔액 왜안보여요? 이전 앱에서는 잔액이 바로보여서 바로 쓰고했는데 지금은 잔액이...
# 37                 장난치나?앱을 이따구로 만들고 고객센터 아무리 전화해도 안받네? 하아
# 38      코나 이벤트 참여할려고 선불카드도 발급받고 결제를해도 코나볼을 주지않습니다. 도대체...
# 39                                            어플 다운 불가...
# 40      완전 최악임 .요새 누가 카드실물들고 다니면서 결제합니까. 체크카드 당장 만들어서 ...
# 41                 환불 규정 바뀌고 실시간 환불도 없어지고 진짜 전에있던앱이 훨씬 나음
# 42      로그인 잘 안되고 가맹점 찾기도 힘들고 별 하나 주기도 아깝네요. 그리고 충전식 카...
# 43      앱이 오류로 열리지도 않아요 ㅡㅡ 머하자는 건지 충전을 못하고 있어요 화가 나요 ㅡ...
# 44      후발주자면 훨씬더 앱사용이 편해져야하는데 쓸데없는 설명만 많고 복잡합니다 제일 궁금...
# 45                                                   충전하기
# 46                          너무 불편하게 바뀌고 기존카드 사용도 못하게 해놨네요
# 47                                    최악의 어플. 예전 동백전이 훨나음
# 48      삼페도 안되는 무쓸모 실물카드 강제 발급은 누구 머리에서 나온 거람? 앱도 너저분한...
# 49      왜 리뷰가 지워진줄 모르겠는데 이관 할려면 왜 카드를 강제로 발급해야하는지 설명 부...
# 50      전반적으로 저번 업체에 비해 불편함. 특히 캐시백 사용하기가 제일 불편함. 이 어플...
# 51      지금 해외에 있는데 앱설치하면 계속해서 연결오류가 뜹니다. 해외에 있어서 고객센터 ...
# 52                     한번씩 접속이 안된다고 하네요. 주기적인 업데이트 요망됩니다.
# 53      초기 동백전 앱 보기 참 편리했는데, 코나로 바뀐 후 너무 보기 불편함. 일부러 그...
# 54      이전엔 접속 되었는덕 오늘새벽에 뭐 서버넓힌다고 충전안되더니 지금은 어플이 켜지지않...
# 55      평점이 왜 2점대일까 했는데 오류 진짜 많이나고 쓰레기 같아요 충전 해야되는데 어차...
# 56                         아이폰 배지 표시 아이폰 배지 표시 가능하게 해주세요.
# 57                                           삼성페이는 언제 되나요
# 58                                               정책이 거지같냐
# 59      결제가 먹통입니다 어플 접속도 안 되구요 다름 카드를 들고있었기에 망정이지 동백전만...
# 60                                        앱이 엉망진창 매우불편합니다
# 61      사용자 편의성 면에서 직관성이 이전 앱보다 떨어지네요 실행 후 메인화면이 너무 산만...
# 62        삼성페이 등록 안됨 캐시 사용 시간제한 있음 캐시 다 쓰고 사용의사 없음 완전 불편함
# 63      기존 어플보다 10배는 쓰레기. 1. 터치해도 바코드나 qr코드가 나오는게 아님. ...
# 64      나만 불만 있는게 아니었구나~어디서 얼마나 할인받고 있는지 진짜 궁금한데 애먼 광고...
# 65      계좌도 다 안맞다그러고 신분증 발급일자도 틀리다고그러고... 그냥 발급이 이제 안되...
# 66                                  멍청한어플이 계속 네트워크접속안댄다하노
# 67         업데이트가 안되어 삭제후 다시 설치하려는데 계속 대기중입니다. 조치방법 부탁드립니다
# 68      선불카드도 차이코퍼레이션처럼 기명으로해서 삼성페이 등 간편결제 가능하도록 해주세요....
# 69      흠.. 글쎄요.. \n저는 이전 앱과 비교해서 불편한 점이 몇가지 보입니다. 우선 ...
# 70      이미 동백전카드를 등록해 사용하고 있는데 이관을 하니 다시 카드를 신청해야 함. 그...
# 71      ㅠ 어플이진짜 직관적이지가 않음 지역카드인만큼 나이드신분들이 많이 사용할텐데 헷갈리...
# 72      이관하니 무조건 새 선불카드 발급해야하네...기존체크카드 사용된다면서 쓸데없이 선불...
# 73      UI쫌 개선 합시다. 캐시백 때문에 쓰는 사람이 대부분일텐데.. 캐시백이 얼만지 어...
# 74      뭔가 많아졌는데 죄다 불필요한 정보들이에요. 한달에 내가 현금으로 얼마나 썼는지 이...
# 75                        앱이 다운로드가 안되고 계속 로딩 중이네요 서버좀 늘려요
# 76                         앱이 오류가 자주 뜨고 메뉴얼이 불편하게 되어 있어요.
# 77      무조건 카드 재발급 해야하고 포인트도 쓰는방법도 이전 어플이 훨씬 편합니다 리뷰 5...
# 78                                             이전앱이 훨씬 나음
# 79                                                     최악
# 80      어플 거지같아요 이용내역에 따른 캐시백이 얼아되었다는 금액을 같이 넣어주세요 작년 ...
# 81      아니 왜 자꾸 댓글로 1대1 문의를 달라고하는건가요? 리뷰평을 보고 편의성을 보는건...
# 82      '신규 동백전카드 신청 취소시 기존카드 연동이 불가함으로 카드사용이 불가합니다' 라...
# 83      이벤트 참여에 마케팅 수신동의가 선행되야 한다는 사실을 최상단에 두셔야죠. 아무것도...
# 84                      무슨 소리인지 모르겠네요 내캐쉬 밑에 세부내용 자체가 없는데
# 85                        카드 새로 오면 기존 카드 새카드 모두 사용 가능한가요?
# 86      앱들어가서 계좌연결하려는데 전화연결조차안되는? 은행직원도황당해합니다 콜센터서는 해줄...
# 87      방금까지 사용했는데 갑자기 결제시 오류가 발생한다며 앱 실행이 전혀 안되네요 동백전...
# 88      그지같이 만들었네 바로 잔액확인안되고 \n내지갑 열어야되고 비밀번호 입력해야하고\n...
# 89                                           옛날 카드보다 복잡해요
# 90      카드 강제발급 장난하나? 쓰레기 줄이자고 하는 판에 나서서 쓰레기 만들고 잘하는 짓...
# 91      대중교통 이용도 않되게 해놓고 무슨 부산동백전 이라고...한심하네요 어떻게 선정되었...
# 92                    카드 이관 신청을 안하면 충전을 못하잖아요. 빨리 해결해주세요.
# 93                               앱이 화면이 멈춰있어요 접속이 안되는거같아요
# 94      너무 어려워요. 충전방식이라 많이 번거롭네요. 폰결제 되는 쉬은 방법으로 업그레이드...
# 95                                   아니 동백전 앱도 안열리고 왜이럼이거
# 96                                        카드는 언제받을 수 있나요?
# 97      참 쓰기짱나 아니회원가입하는디 스마트폰인증으로만해놈 폰이자기명의아닌사람 짱나제 은행...
# 98                                           앱 자체가 열리지 않음
# 99      업데이트 이후 사용불가 첫 화면으로 가기까지도 너무 오래 걸리고 운 좋게 충전버튼까...
# 100                         초기화면에서 계속 멈춰있다가 네트워크 오류로 꺼집니다
# 101     너무 불편 카드 쓰던게 멀쩡히 있는데 새 카드 발급을 왜 받아야하며ㅡ\n신청하고 이...
# 102     변경되고나서 완전 별로입니다 새로선불카드를만들으라하질않나 만들어사용했더니 그동안 아...
# 103            며칠째 업데이트가 되지 않아 사용에 너무 불편합니다. 하루 이틀도 아니고..
# 104     기존 동백전체크카드 보유고객입니다 필요없는 동백전 선불카드 의무발급하게하는것은 무슨...
# 105     최악. 별하나도 아까움.오류가 잦아 결제승인 안되었는데 돈이 빠져 등 가게 사장님과...
# 106     가맹점찾기에 가맹점 자체가 아예 안나옵니다. 처음부터 안된게 아니고 어제부터 안나오...
# 107                  예전 어플로 다시 돌려주세요..뭐가 더 햇갈리고 보기도 불편하고ㅠ
# 108              앱오류가 너무 잦네요...이런데 케이티는 무지막지한 돈을 받아가는지...
# 109                           ㄹㅇ 데이터 켜도 로그인 안되는 희대의 쓰레기 앱
# 110                                          다운이 진행이 안됨..
# 111     예전 동백전으로 결재 되던곳이 이제는 안되는곳도 많아지고 가맹점이 어디인지 알수도 ...
# 112            도대체 왜 바꾼거지? 이유가 뭐래요? 앞전 동백전 아무볼편없이 아주 잘썼는데
# 113     네트워크 오류라면서 어플 접속이 안될뿐더러 오늘 실 결제한 금액 캐시백도 안됐네요....
# 114                                  삼성페이 왜 안되나요? 엄청 불편해요
# 115                                  업데이트3일동안 안되고 앱실행이안되여
# 116     접속이 안되네요 빨리 계산해야되는데 앱이 접속이 안되서 주위사람들 눈치밥 먹으면서 ...
# 117     와..리뉴얼되면서 더 불편해진건 뭐지!? 1.일단 사용 알림이 안뜨네요!\n2.전엔...
# 118                                                     굿
# 119                                  왜 재발급 해야하나요 카드 끼워팔기?
# 120             국민을 개돼지로아는 인간들 동백전 난안쓴다 10프로 길들여노코 쓰레기짓하네
# 121                                      카드재발급해야하나요? 왜죠??
# 122                                     이전앱보다 불편해서 쓰기싫을정도
# 123     정말 기존 앱이 훨씬 간단하고 사용하기 편햇는데 오ㅑㄹ케 불편하게 해놧는지모르겟네 ...
# 124                       잘안될때가 많고 환불도 제약있고 그냥 안쓸랍니다 카뱅만세
# 125       불안정한 앱 이용내역 확인 시 강제종료 앱 메뉴도 간단하고 동백전 서비스도 훌륭한데
# 126                                     전 동백전앱이 훨~~씬 편합니다
# 127                                                사기수준임.
# 128             자꾸안괴요 충전해서 결제 해야 하는데 카드 달랑 한개 들고 나왓는데ㅠㅠㅠㅠ
# 129     이번앱은 "사용가능가맹점" 검색이 안됩니다. 가맹점 검색후에 사용가능한지 미리 알았...
# 130                         사용 가능 금액과 캐쉬 금액 합산을 표시 해 달라!!
# 131     계좌등록 여러건 등록 안되나요? 입금 출금 전부다 계좌 인증하면서 수시로 바꿔야하네...
# 132                       업데이트도안되고 새로 지우고 설치하는데 설치가 안됩니다.
# 133     카드를 만드려다가 민증 발급일자 오류를 5번 초과해서 만들 수가 없습니다. 운전면허...
# 134     캐시백 이용한도 이전 서비스에는 캐시백 가능한 30만원 중 얼마 썼고 얼마 충전할 ...
# 135                       가독성 최악 인터페이스 최악 직관성 최악 그랜드슬램이네요
# 136                                   참으로 불편하다. 일부러 그러는가?
# 137                                       진짜 드럽게 불편하게만들엇네
# 138     짜증나요 매장에서는 결제안됐다 그러고 저는 결제됐다고 알람 떴는데 결제하려고 어플드...
# 139     캐시백 세부사용내역 보여주세요. 기본에 기본도 안되어 있는듯요. 누가 도대체 개발하...
# 140     충전금액 환불이 자유로울거라 생각하고 카드발급, 어플설치를 하고 충전을 했었는데 급...
# 141     이전보다 더 불편해진 느낌ㅠ 첫 메인 화면에 잔액이 나왔으면 좋겠어요\n그래야 얼마...
# 142            동백전 사용처 검색 기능이 없네요. 이전에 사용하던 앱보다 많이 불편합니다.
# 143     앱 관리 안하나요??? 업뎃 문제 계속 발생하다가 이제는 네트워크 4G,Wifi 둘...
# 144     빨리 새로 선불카드 안 만들고 기존 카드 사용할 수 있게 해주세요. 기술적인 이유라...
# 145     네트워크 연결이 원활하지 않습니다. 접속오류 다른 어플과 인터넷은 잘 사용되는 중인...
# 146     아니 충전하려 들어가면 계속 튕기고 지우고 깔아도 튕기는데 이러면 그냥 쓰지말라는 ...
# 147                             삼성페이 안됨, 10프로 안받고 일반카드 사용
# 148     별 하나도 아깝다. 부산시와 코나아이측의 사전 설명이 모두 구라이고 무조건 신규로 ...
# 149     불편하네요 기존 앱보다 너무 불편하네요\n금액충전은 메인창에  한눈에 확인하고 충전...
# 150                   ㅋㅋ고객센터 고객센터 답변 얼마나 기다렸는데 일 쥰나 안 해요~
# 151     동백전 충전하니 충전수수료 무료 이벤트중이라고 뜨는데 이벤트??에요?? 원래 무료가...
# 152                                            아이폰은 안되나요?
# 153                                       중소기업 수준도 안되는 어플
# 154                            앱설치후 가입하려고하면 인증문자가 날라오지않아요
# 155     코나아인가 뭔가 찢이랑 연관됐다더니 정말 쓰레기 인증이네요 금액 남아서 쓰긴 해야하...
# 156     문의글남겨도답변도안하고점심이라고일안하고가맹점이라고버젓이되잇는데사장은동백전가입안되잇다...
# 157     1-강제로 필요없는 선불카드를 발급해야함. 2-선불카드는 페이등록이 안되고 교통카드...
# 158                       장난해요 왜 신규카드 발급받아야 되죠 기존 카드로 해야죠
# 159                              불편하네요.게시밳ᆢ용하기도~ 엄데이트도안도고
# 160     데이터 연결이 불안정하다더니 다른 어플들 접속은 잘만 됩니다. 어플 재설치도 하고 ...
# 161     아이폰 사용내역 알림 아이폰 사용내역 알림 언제쯤이면 사용 가능한가요?\n결제 내역...
# 162                                선불카드 강제 발급은 뭐죠? 황당합니다.
# 163     기존은행앱에서 느끼는 단점을 다 가지고 오셨네요. 광고, 마케팅권한요구, 번잡한 U...
# 164     인증번호가안오네요;; 아니무슨 내폰skt고 다맞게했는데 인증번호 전송햇다카믄서 안오...
# 165                하이마트에서 사용가능한다고 나오나 사용이되지 않습니다 확인부탁드릴게요
# 166                                                    벼로
# 167                                                    ㅇ아
# 168     전에 보다 못하다.판단되고 캐시백 금액 확인도 힘들고 머좀 찾아볼려면 여러번 눌러야...
# 169     완전별로 기존카드 사용할건데 새카드는 왜 무조건 신청해야하죠? 코로나 시국에 플라스...
# 170            장난 똥때리는 이벤트...앱 깔때는 or ☞ 깐 후엔 and 기가차네 기가차
# 171     카드이관 등록하려는데 카드정보를 찾을수없다는데요 바코드 인식도 안되면서 왜 만든것이...
# 172                                    최악임 깔고나서 본인인증문자아안옴
# 173     핸드폰변경하면서 통신사를 옮겼는데 새로 번호등록하라고 초기화 버튼이 떠도 눌려지지가...
# 174     사상최악의 앱인거같아요 기존앱에 비해서 인터페이스가 최악입니다 사용자의 불편을 위해...
# 175         캐시백 따로 볼수 있게 해주세요 너무 불편해요 기존앱에서 나아진점이 하나도 없는듯
# 176     지난 잔액과 이번 잔액 비교가 되었으면 좋겠습니다. 최소한 어린애 가계부도 입출내역...
# 177     업데이트가 하루종일 안되네요 혹시나해서 폰을 껐다 다시 켜고 안되고 덕분에 동백전 ...
# 178     교통카드 없는 카드 개설했다가 있는걸로 바꿀려고 하나카드 통해서 카드해지를 했습니다...
# 179     앱 접속시 계속 팅김 카드신청과정에서도 불안정함 주민번호 입력하면 자꾸 다른숫자로 ...
# 180                신규카드 삼성페이연동안되네요 그리고 기존카드도 동백전 등록안되는데요?
# 181     쓰레기앱 대체 일처리를 어떻게 하는지 궁금할 지경임 어르신들은 어찌 쓰라는 건지 전...
# 182     너무 불편하고 복잡해요 동백전 이전 앱이 더 좋아요 캐시백 사용내역이나 적립내역도 ...
# 183     아인증번호 입력하려 나갔다오면 자꾸 앱강종돼서 처음으로돌아가요; 인증을 할수가없잖아...
# 184                                                 잦은 오류
# 185     왜 기존가입자들이 새로운 카드를 받아야되는지 이해가 안되며 기존카드를 써도 되는건지...
# 186     본인인증에 재발송 안하고 다음을 클릭했는데.. 왜 계속 인증번호가 날아오고...본인...
# 187                            포인트와 충전금액을 이전처럼 따로 금액분리 요함
# 188                  0점은 못주나 2021년에 삼페가 안되는 선불카드? 선불카드으으?
# 189                                     카드발급 또하는거 실환가????
# 190                   왜 갑자기 접속이 안되나요??? 충전을 못해서 캐쉬백 못받았어요
# 191     휴대폰 인증이 안돼요 농협 카드로 발급하려하고요 계좌있어서 본인인증만 하면되는데 휴...
# 192                         동백전 가맹점 조회 가능하게 해서 쓸수 있게 해주세요
# 193                동백전은 좋은데 앱이 말썽이네요 충전할때마다 짜증이 나요 앱이 쓰레기
# 194                동백전가입시 LGU+알뜰폰은 인증이 안돼 가입이 안됩니다 조정바랍니다
# 195           기존에 사용하던게 더 좋음...잘사용하고 있는대 고객들 불편하게 만드네요...
# 196                     걍 먹통임 앱실행이 안됨 돈좀들여서 실력있는 개발자좀 씁시다
# 197     아니 저번꺼는 동백전 포인트를 on/off로 간단하게 됬는데 이건 그것도 안되고 심...
# 198     삼성페이안됨 카드재발급 사실인감? 뭔 충전 취소도 3일 걸린다고하고 초기라 이해할려...
# 199     인증된 폰번호와 현재폰번호가 일치하지않습니다 이렇게 뜨네요 밑에 다른글 보니 나밍작...
# 200     사용내역 푸시알림 왠만하면 리뷰 안남기는데 진짜 일대일 문의해도 된다고 하는데 푸시...
# 201                                        아 진짜 불편하네요.. .
# 202                           몇번을시도해도잘되지가않네요 언제쯤 제대로 될까요?
# 203     사용처 제한으로 불편함이 많음. 특히 재래시장에는 카드계산기 없는 상점이 많아 더 ...
# 204     앱 설치했는데 바탕화면에 나타나지 않네요 다시 진행하려니까 '설치됨'이라고 되어 있...
# 205         코나아이 카드팔이 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 꺼지세요 코나아이 너네 카드는 안써 ^^
# 206     엉망 UI 도  불편하고\n\n일반 사람들이 사용하기 어렵게 시스템 구조에다가\n\...
# 207     어플에서 바코드가 뜰 방법은 없나요? 요즘 카드를 누가 들고 다닌다고....... ...
# 208     일주일 사용 후 불편한 점 1. 가맹점 찾기 기능 넣어주세요.\n2. 푸시알람켜놨는...
# 209     충전오류 무슨 충전할때 원인불명의 오류로 계속 정상적으로 처리되지 않았다고 하고 문...
# 210     왜 신규카드발급을 받지 않으면 기존 카드사용이 안되는지..이런 얄팍한 상술 정말 짜...
# 211     이용액과 관련하여 기간별 사용금액 합계가 조회되지 않고 가시성 및 가독성이 아주 현...
# 212     가입 하려고 하면 인증 문자가 안와서 가입을 못하네요? 관리를 안하시는 건지? 리뷰...
# 213                        연결계좌에 은행은 언제 늘려줄껍니까 돈쓰지 말까요???
# 214     안드로이드 5 에서 10일부터 갑자기 실행이 안됨. 언제 수정될지 계획이 없다는 답...
# 215                                              너무 불편합니다
# 216     가입하려는데 개인정보 입력에서 폰번호 넣고 휴대폰인증번호 받으려고 전송버튼 누르면,...
# 217     결재, 환급 속도가 너무 느려서.. 주유소에서 기름 가득 넣고 재결재 될때 취소된 ...
# 218     하... 식당에서 밥 먹고 나가기전에 돈 충전해서 결제하려고 어플을 켰는데 접속이 ...
# 219                        앱 업데이트를 해야 이용가능하다는데 업데이트가 안되네요
# 220     새카드 발급안하면 기존카드도 사용못하고 이게 무슨 세금낭비입니까? 안내도 제대로 안...
# 221                          앱이 자주 버벅 거립니다 터치도 안되고 먹통이 되요
# 222                               업데이트 안됨 이전보다 아주 불편 짜증폭발
# 223     동백전 바뀌고 새로 등록한 카드는 직영점 사용가능. 그 전에 만든건 직영점 사용안됨...
# 224     지난주부터 네트워크 연결 확인하라고 앱 연결이 안되서 미쳐버리것네요... 딴 사람들...
# 225     직관적이었던 과거 앱에 비해서 번잡하고 구려졌어요....글씨크기부터 인터페이스까지 ...
# 226                     카드팔이 중소기업 직관성은 개줘버렸냐? 조잡하기 그지없는 앱
# 227                              계좌등록이 계속 실패로 떠서 사용이 불가능함
# 228                           사용자 편의를 고려하지 않고 불친절하고 불편한어플
# 229                                          왜안되는거에요..불편해
# 230           동백전 가입할라는데 인증번호가 안와요 3번 시간초과됫는데도 안와요 왜안오는거죠
# 231     업데이트 해야 한다고 해서 업데이트 눌렀는데 계속 업뎃 안되네요. 결국 제때 충전 ...
# 232                                       어휴 어플관리 진짜 최악이다
# 233     동백전앱이 삭제되어 제부팅 했는데 인증번호 보냈다는 글은 올라오는데 아무데도 찾을수...
# 234     회원가입시 인증번호가 안옵니다. 이틀째 가입중인데 인증번호가 계속 수신이 안되는데 ...
# 235                            새로 깔았는데 기존카드가 입력이 안되는데요...
# 236                                                아주 좋아요
# 237     중요한 기능 중 하나인 가맹점 조회는 왜 없나요? 동백전 사용가능한지 일일이 물어볼...
# 238          진심 거지같다. 화면 전부 다 바뀌고..뭐가 뭔지. 숨바꼭질하나...개짜증일세.
# 239     새 카드를 무조건 발급 받아야 어플에 들어가진다는게...무슨 카드가 무료발급이라지만...
# 240     정 선불카드 필요하면 모바일카드 발급할것이지 우편 종이두툼에다 플라스틱ㅡㅡ 환경1도...
# 241                                기간별 얼마썼는지 합계 업데이트좀 하세요
# 242             자기명의휴대폰아니면 가입이 안되는거 같은데 아이핀으로 가입할수있게 해주세요
# 243     새로운 카드를 발급받지 않아도 되도록 앱 수정바랍니다 왜 무조건 카드를 또 발급받게...
# 244             내금고 돈 넣었더니 빼는 기능이 없네 고객센터는 당연히 잠수고 뭐 이따구냐
# 245     케이뱅크밖에 안 쓰는데 은행이 없어서 사용 못하는 중ㅋㅋㅋ... 모든 은행 언제 들...
# 246     사람들이 왜 계속 글을 쓰는지 이해를 못하는 것 같네요. 동백전 다시 앱깔고 들어갔...
# 247     아니 데이터 무제한인데 네트워크 연결하라하고만 하고 왜 계속 접속이안되나요? 돈얼마...
# 248                        앱 진짜 못만들었다 캐시 못쓰게 하려고 잔머리만 굴린듯
# 249     접속도안되고 접속할라하니 업데이트하라하고 업데에트할라하니 업데이트도안되고 어이가없네...
# 250     본인인증 단계에서 휴대폰 인증번호 발송이 안되고, 카드번호로 인증하려고 해도 번호오...
# 251          좀 속이면서 운영하지마세요 신규카드 발급유도하는게 처음부터 오만정 다 떨어지네요
# 252     카드신청에 들어가서 카드선택후 신청하기누르면 '일정기간 미사용으로 작업이중단됩니다'...
# 253     1. 기존카드 소지자도 무조건 선불카드 강제발급하게 함... 2. 선불카드는 삼성페...
# 254     돈이 남아도나요? 카드 재발급으로 인한 환경문제부터 비용 자체가 아깝네요. 수수료때...
# 255                                       요즘세상에 들어가지지도 않네
# 256                                        카드만들다 사용 포기합니다
# 257     다른 리뷰들처럼 캐시백이나 전반적인 부분에서 이전것보다 불편함. 개선의지도 없어보이...
# 258     문의도 제대로 안올라가고 기존가맹점 멀쩡하게 쓰고 있는데 새로 가입하라하고 전화도 ...
# 259                                                 입기 ㅋㄱ
# 260     알림은 왜안오는가요? 결제승인 및 캐시백 알림이 안옵니다! 일일이 앱에 접속해서 확...
# 261                           접속도안되고 깔고지웠는데도 접속안되요 개선해주세요
# 262                                                설치가안되요
# 263                                            업뎃 좀 그만...
# 264                                아이폰 X 충전안됨 충전하러 가면 튕겨요
# 265     내역만 들어가면 팅김 내역에 들어가면 팅겨요. 아이폰 xs입니다. 다른 내역 확인 ...
# 266                         안증안되요.. 쓰고싶어도 인증이안되니 쓸수가없네요..
# 267     결제취소건에 대한 환급진행도 안되고 고객센터와 전화통화는 하늘의 별따기 3월31일 ...
# 268     어휴 충전 열번도 오류나길래 딴카드 긁고 나니 되네 기존업체가 훨씬 나은데 머하러 ...
# 269                                        적립내역 왜안보여주시나요?
# 270                                            왜 설치가 안되나요
# 271                                                 장난하나?
# 272                                            별 하나도 아깝다.
# 273          앱이 잘 열리지도 닫히지도 않아요 일단 카드신청만 겨우하고 강제 종료했네요 ㅡㅡ
# 274                      업데이트좀 .. 급하게 사용해야하는데 업데이트하게 만드네요
# 275     동백전이라는 카드혜택은 좋지만 어플만 보면 너무 불편하네요 데이터로 접속하려면 네트...
# 276     왜 이렇게 불편하게 되었을까요 선불카드 재발급 요구 직관적이지 못한 메뉴 터치 3번...
# 277     4/9이후로 결제된 부분은 적립이 안돼요 10만원 이상 결제한건 바로 캐쉬백되는데 ...
# 278                                                 안들어가짐
# 279     와 피드백 ㅋㅋ진짜안받네; 의견 취합해서 업뎃해야하는거 아닌가요? 이용자들 불편하다...
# 280     0점!! 앱 열자마자 카드신청 단계이고, (구 동백전카드 사용 여부와 관계없이,무조...
# 281                                     기냥 광고쓰레기 어쩔수없이쓰는듯
# 282     네트워크 다잘되는데 계속 네트워크연결이 불안정하다고 안들어가지네여;; 종종이러던데 ...
# 283                                            업데이트가 안되네요
# 284                                                   못하다
# 285     오류 기존 하나은행 동백전 유저인데 잔액 연동이 안되니까 다음으로 넘어가지가 않습니...
# 286     ㅠ 주민등록증 찍는데 청소년들은 청소년증으로 하라해서 청소년증 찍고 발급날짜 했는데...
# 287     도대체 왜 바꾼거죠? 진짜 진심 예전이 훨씬 좋아요ㅡㅡ 가맹점 찾기도없고, 결제금액...
# 288        업데이트하고 나서 안들어가지고 환불도 시간엄청걸리는 바꾸고나서 좋아진게하나도 없네요
# 289     캐시백 함 받을랫다가 쓰러지겠네요 돈 묶여있는거 어케 뺍니까 ;;\n다섯 군데 돌아...
# 290     계속 번호가 바뀌었다며 재인증하라고 뜹니다. 매번 재가입을 해야만 사용이 가능하며 ...
# 291         앱 실행 단계에서부터 막힙니다. 만들기만 하지 말고 관리도 좀 잘해주길 바랍니다.
# 292                                                 넘 좋아요
# 293             네트워크 연결이 아안된다고 접속이안되는데 어쩌라고 ㅡㅡ 개같은앱 만들어놨네
# 294     사용불가 라는데 기존 동백전 앱은 돈 다 빼고 탈퇴했어요. 새 앱 깔고 카드 신청해...
# 295      계속 렉걸리고 네트워크접속이 안된다고하고 예기치못한오류가 생겼다며 너무 잘 안됩니다ㅠㅠ
# 296                           운영할거면 제대로 하길 이도저도 아닌꼴 만들지말고
# 297                                 한동상향했는데 50만원이상충전 안되네요
# 298     앱이 열려야 충전해서 사용을 하죠 안열리는 경우가 너무 많아요 네트워크가 원활하지않...
# 299                                앱관리 안하냐 ? 네트워크 접속불량 머냐
# 300                 기존카드등록하려니 계속 찾을수없는카드라고하는데요? 어떻게해야되나요?
# 301     정말 부산시는 미리 사전에 공고를 하셨어야지요!기존카드 그대로 쓸 수 있다고 해놓고...
# 302     고객 서비스가 최악이네요 어플 오류로 인하여 충전 하려고 하니 바탕화면으로 팅기는데...
# 303     모든 답글 꼬라지가 그냥 복사&붙이기네\n사용해도 알림도 안오고 예전보다 무조건 카...
# 304                                                    불편
# 305     기존 동백전을 사용하나 쩔수없이 여기로 이관중인데 진짜 지리멸렬 그자체이고 굳이 필...
# 306                                                    개똥
# 307     충전을 충분히 해뒀는데...은행에서 그냥 출금 처리됨..ㅡㅡ 처음에 충전된 잔액에서...
# 308                                       포인트 사용하기 너무 불편함
# 309     정말 최악입니다 가입하라고 해놓고 인증문자 발송도 안됩니다 스팸차단같은거 확인하라는...
# 310     아직 써보지도 못했을 뿐더러 예기치못한 오류라며 앱 접속조차 안되네요... 부산지역...
# 311     업데이트 이후에 뭘사러 갔더니 분명 해당점포가 캐쉬백대상점포인걸로 아는데 캐쉬백이 ...
# 312                       앱 사용 불편. 내역 확인 안됨. 사용자 편의성 전혀없음
# 313     캐시도 안들어오고, 원래되던 삼성페이도 안되도 ui도 직관적이지 않아 불편함 한개도...
# 314                  새로 카드 발급받았는데 삼성페이 안되요 대책없나요? 계획없으세요?
# 315               더도 덜도 말고 옛날 어플이랑 똑같이만 만들어주세요ㅜㅜ 넘나 불편...
# 316                                 결제오류가 타카드에 비해 너무 자주나요
# 317     카드가 오류가 떠서 결제가 취소됐는데 캐쉬백은 들어왔고 어플은 켜지지도 않고. 어플...
# 318                                              업뎃이 안됩니다
# 319     구림구림 개구림 뭣이 설치도 번잡하고 필요없는 요즘 쓰지도 않는 충전카드라니;;;;...
# 320                                  인증번호가 안오는데 어떻게 해야될까요
# 321     이전 동백전은 오류 한 번도 없었는데, 잔액환불도 너무 느립니다. 6월 1일자 결제...
# 322     결제 시 푸시 알림이 안와요 이전 앱에서는 결제 시 푸시 알림이 왔는데, 코나카드로...
# 323              어플이 왜이러죠? 데이터상태에서 사용이 안되면 밖에선 사용하지말란건가요?
# 324              앱 실행이 안됨;; 와이파이 빵빵한데도 안되고 데이터로도 안됨요.. 불편
# 325               화면이 안넘어가요 첫 화면만 뜨고 더 이상 안 넘어가는데, 왜 이렇죠?
# 326     카드 신규발급 안해도 기존카드사용해도 되는데 왜 굳이 발급의무로 해 놓은건지 마케팅...
# 327     동백전 편의성 개나 줘버리고 이전보다 못한 서비스 하면서 왜 바꾸는 거냐 어이가 사...
# 328     회원가입할때 직장주소 검색하고 다시들어오니까 어플 끄지도 않았는데 처음부터 다시 입...
# 329     별한개도 아깝다. 카드를 강제로 만들게하는 대 시민 사기를 쳐놓고 앱UI도 아주 불...
# 330     네트워크도 잘안되는걸 어떻게 써라고? 써다가 열불나서 카드부쉈음. 일부러 이렇게 만...
# 331                      앱으로 결제는 안되나요? 삼성페이 결제는 도입 예정인가요?
# 332     별 한개도 아깝다. 마이너스 별은 왜 없는지. 재무도 엉망인 회사가 신규로 선정될때...
# 333                                   아직도 콜센터도 연결 안되넹....
# 334     사용자들의 불만을 얼른 수렴해서 동백전 어플 전면 수정하세요. 플라스틱 쓰레기 만들...
# 335     네트워크가 원활치않아 접속이 안된다고 이틀째 발급신청 못하고 있음 요즘세상에 접속도...
# 336     네트워크 관리 좀 해주세요 뭔 맨날 연결 안 돼서 충전도 못하고 오늘도 캐시백 혜택...
# 337     왜 연결이안돼요-??? 위치켜도 가맹점나오지도않고-아니 도대체 점거안하고 뭐하시는건...
# 338     월별 사용내역 다 보이게 좀 기본값 설정해주시오. 매번 일별로 누가 계산합니까? 취...
# 339                          앱을 설치 했는데 어디에 깔렸는지 확인이 안되네요?
# 340                                            설치가 안됨 설치가
# 341     미리 공지해줬으면 이런 혼선도 안생겼을텐데, 그래도 부산시랑 남구-동구 업체가 같아...
# 342            카드 강제발급에 이전보다 불편한 어플, 거기에 삼성페이도 못쓰는 카드라니..
# 343                        결제 실패는 곧 시스템 실패 ,kt 하나은행 똑바하세요
# 344     사용가능 가맹점 찾기 빨리 만들어 주셔.. 필요한거는 안보이고 뭐 필요없는 것만 잔...
# 345     짜증 바빠죽겠는데 앱 다시 설치해서 회원가입까지하고\n카드도 재발급받아야 하네요^^...
# 346     동백전 어플설치 저는 아이폰이라 설치를 했지만, 아버지도 동백전 어플 설치해드리려고...
# 347     이전 동백전사업자는 캐시백을 내 잔고처럼 쓸수있어서 자유로웠는데, 코나로 바뀌고 나...
# 348     아 진짜 내가 살면서 앱 리뷰 쓰는건 처음이네. 전 앱이 훨씬 나은 이유.\n캐시백...
# 349     뭔 이유로 앱을 이렇게 복잡하게 불편하게 만들죠? 기존 동백전처럼 열자마자 충전페이...
# 350     못쓰겠네요 버그빨리 수정요 뭔 자꾸 튕기니 ㅋㅋㅋ 쓰지말라는 뜻인가요? 빨리 버그 ...
# 351     왜 평점이 4.3인가요. 별 하나도 아깝습니다. 네트워크 오류로 접속이 일주일 넘게...
# 352     업데이트 하라고 해놓고 업데이트 되도 안하고 짜증만 나네. 쿠키, 데이터 삭제해도 ...
# 353     다른어플은 실행이되는데 이어플은 lte인데도 왜 실행이 안되고 와이파이껴야 그나마 ...
# 354                    열때마다 다시 종료해야되네요.. 어플 제대로 좀 만드세요...
# 355                                                    최악
# 356     로코 정책지원금 사용할수있게 해주세여 정책지원금이라고 이벤트성으로 들어온 적립금이 ...
# 357     예전앱에 비해 너무너무 불편합니다 이전 앱은 충전하기. 사용내역보기. 계좌로 잔여금...
# 358     결제알림이 오지 않습니다. 어플이 바뀐 후 부터 결제해도 알림이 오지않습니다.\n\...
# 359     네트워크 개선좀 빨리해주세요, 일주일째 데이터로도 접속이안되고 와이파이 연결된상태에...
# 360     앱 업로드이후 자꾸 재시작해야 하는 버그가 계속발생 합니다. 업로드전에는 전혀 문제...
# 361                                인증번호가 안오네요 앱에 문제가 있나요?
# 362                                      업데이트 왜이리 안돼요????
# 363             앱이 와이파이든 데이터든 아무것도 연결이 안되네요. 안정성 좀 신경써주세요
# 364                                               1도 아깝다.
# 365     회원가입조차 되질않아요. 문자인증전까지 입력은 되는데 인증문자가 전혀 오질않네요 S...
# 366                  실행할때마다 인증된 폰번호와 일치하지 않는다고 재인증을 해야합니다
# 367     너무 자주 에러나요. 미리 공지라도 하고 안돼야 당황을 덜하죠. 오늘도 일부러 동백...
# 368     21/07/18 설문조사하라해서 설문조사중 맨밑에 건의사항 적고 있는데 갑자기 휴대...
# 369                       계속해서 기기에서 충돌앱이라 나오는데...어찌 해결좀??
# 370     ㅡㅡ 잔액 이관하면서 걍 무조건 신규카드 발급하게 돼있음 기존카드 사용 못하는 건 ...
# 371      안들어가지는게 너무심하네요. 이래서 사용가능하겠어요? 데이터 와이파이 다 안들어가져요.
# 372     사용금액이랑 캐시백 금액 합쳐서 나와야지 아니 따로따로 나오면 어쩌자는 건데?? 어...
# 373                                   선불 카드 신청 취소바람. 당일임.
# 374                          욕나올정도로 후짐 며칠전부터 가맹점조회 아예 안됨.
# 375                     진짜 불편하게 바꼈다 불편한게 한두가지가 아니에요!!!!!!
# 376     첫 화면에 뭔 이런 지저분 한 UI를 나이드신분들 사용이나 가능할련지 모르겠다 가입...
# 377        동백전 사용중에 알뜰폰통신사 이동했더니 켤때마다 계속 초기화 불러오는 오류가 있네요
# 378     이건 뭐 기존카드 정보 쳐넣어도 연동도 안되고 뭐하는 짓인지 뭐하러 어플을 새로 만...
# 379     알림 돈썻으면 알림좀 울리게해주세요\n토스랑도 연동이 됬으면 좋겠어요\n옛날 하나키...
# 380     아니 이전에 앱에서 바코드로 결제 가능했는데 이건 간단하게 충전하기까지 왜이렇게 진...
# 381                                     어플이 실행되야 쓰던가 하죠..
# 382     공지를 제대로못읽었는지 기존꺼못쓰고새로만들어쓰란소린줄알고 멀쩡한기존동백카드 삼성페이...
# 383     앱 오류 안고쳐주실건가요?? 충전하려고 앱들어가면 데이터 상태로는 들어가지지도 않고...
# 384     진짜 전에쓰던어플이훨씬좋음 뭐하나편한것도없고 \n\n잔액환불도 전에쓰던건 빠릿빠릿바...
# 385          앱실행이 안됩니다 왜? 그런걸까요? 빠른 조치바랍니다!! 죄송합니다란 말빼구요~
# 386                                애러가뜨고 기존카드로 이관이 안되는데요?
# 387     결제안된다해서 다른카드로 결제했는데 동백전에선 또 돈이 나가네요 일반 슈퍼인데도 동...
# 388     휴대폰 본인인증 문자가 10~20분뒤에 전송되어서 가입이 불가능합니다. 인증시스템에...
# 389     요즘세상에 폰으로 결제를못하게 하는게 말이되는건지요ㅡㅡ 삼성페이 안되니깐 엄청 불편...
# 390                                     삼성페이 엘지페이 지원안되나요?
# 391     일단 어플이 너무 느려요ㅠㅠ 또 실행할때 네트워크가 불안정하다고 안열리네요.. 가맹...
# 392          개인정보 왜 보험회사에 팔려서 에이스 보험 강매 전화 작작 ..그래서 탈퇴함^^
# 393                                      왜 적립이 중단하고 지ㄹ이야.
# 394        잔액과 캐시적립금과 구분되서 못보나요? 왜 합산 금액만 나옵니까? 진짜 불편하네..
# 395     어플을 열려고 하면 열리지 않는 경우가 자주 발생합니다. 캐시백 사용도 이전보다 불...
# 396     왜...? 오랜만에 동백전 쓰려고 다시 깔았는데 카드도 다시 발급받아야되고.. 그건...
# 397                                     인증번호 이틀째 접속불량 불편해
# 398     설치하고 카드 신청하는데 폰으로 인증번호 확인차 문자앱 실행해서 보고 다시 동백전앱...
# 399     세상에..업데이트하라고해서업데이트하는데계속다운로드중만뜨고짜증나서앱제거하고다시깔고있는...
# 400     다른건 다 괜찮은데 가맹점 찾기에 가게가 하나도 안나와요ㅠㅠㅠ 몇번이나 재설치했는데...
# 401             아니 부산에서 쓰라고 만든 카드 맞습니까 안되는곳이 왜 이렇게나 많은지 참
# 402     새로운 카드 받았는데 등록하면 삼성페이 사용 못하나요? 새로운카드 무조건 등록해야하...
# 403     동백전 사용하기 좋아요! 그렇지만, 안드로이드 버전이 낮아 동백전 어플 자체가 아예...
# 404      캐시백되는건 좋은데 앱이 몇번째 안들어가지는건지... 돈이 얼마있는지 확인할수가 없네요
# 405     도대체 누가 앱을 이렇게 기획했나요… 처음에 알아보기 힘들면 그냥 알아보기 힘든건데...
# 406     집에서 와이파이 연결된경우에만 충전이나 어플확인이 가능합니다.. 어플연결이 안되다보...
# 407          업데이트도 설치도 안되요 ㅡㅡ 써야하는데 업데이트안하면 실행불가 하면 어떡하나요
# 408     와이파이 연결시에는 어플 접속이 잘됩니다. 하지만 데이터 사용시 접속이 잘 안됩니다...
# 409     업데이트 후에도 선불카드 입력하라는 문제 방금 업데이트해서 기존 체크카드 입력하고 ...
# 410     업데이트가 안되서 데이터, 캐시 삭제했는데도 안됩니다. 삭제하고 다시 깔아볼려고 해...
# 411                                          업데이트도안되고 왕짜증
# 412                                      삼성페이안되는거 진짜 개같네요
# 413                                                업데이트안됨
# 414                                쓰레기입니다 이딴게 세금으로 만들어지네요
# 415     불편합니다 캐시백 금액+보유금액 한번에 조회하게 해주세요\n이전 어플은 가능했어요 ...
# 416            앱도 진짜불편, 멀쩡한카드 두고 왜 재발급받아야하죠? 자원낭비 환경오염입니다
# 417                                                  에러작렬
# 418                                       이런 회사를 왜선정 햏는지?
# 419     인터페이스 너무 정신없구요 혹시 뭔가 판매랑 연결시켜 수익창출이라도 해야하나싶은 상...
# 420     아이폰 결제내역 알림은 언제 되나요? 1:1 문의를 해서 시킨대로 다 했는데도 안되...
# 421                                        짜증나요 수시로 접속안되요
# 422                                      하나 같이 에러에 로딩에 ㅡㅡ
# 423            뭐 이런 개쓰레기 같은 앱이 다 있어. 죽도록 카드신청해도 안됨. 안써!!!
# 424                                카드는 왜 신규로 신청시키는건지 참...
# 425                          어플 진짜 못 만들었네요.. 툭하면 접속도 안 되고
# 426                                                 접속도안됨
# 427                                   뭔가 좀 다른 느낌 나는 했갈여요?
# 428                                         광고 팝업 안뜨게 하세요
# 429                         오늘 하루종일 먹통에 2중 결재 됐습니다 확인해주세요
# 430                  진짜 허접한 앱때매 사용하기 어렵네요.. 도대체 뭐하자는 겁니까?
# 431     카드 꼭 만들어야 될까요? 예전처럼 그냥 모바일로만 쓰고 싶어요. 안되면 그냥 잔액...
# 432        부산 소상공인을 위해 만든 취지는 좋았으나 너무 일찍이 예산초과로 윈윈효과가 부족함
# 433     너무 비직관적입니다. 한눈에 충전잔액, 캐시백잔액, 총 잔액을 첫화면에 볼 수 있었...
# 434                              앱 개발자 바꿔라 제발!!! 부탁합니다!!!
# 435                                        전에 비해 확실히 불편해짐
# 436     출시기념 1월 한달간 이벤트를 하는데 1월 지났는데도 아직 다운로드를 받지 못하는 ...
# 437                     업데이트도 안되고 삭제후 다시깔아보려해도 앱 다운자체가 안됨
# 438     개쓰레기같은 앱 사용하려고 해도 부산 동백전 로딩화면만 쳐깜빡이는 개쓰레기같은 앱입...
# 439                                  어플이 계속안열리네요 정말 노답이네요
# 440                                         다운로드가 며칠째 안되요
# 441     장난하나 가입시 무조건 카드발급하라는게 어딧나요?\n기존카드 쓸수있다면서 발급안하면...
# 442                                      연결이되야 쓰던가말든가하지ㅡㅡ
# 443     30살 살면서 하나은행이용해본적 단한번도 없는데 동백전 만들고 하루에 2~3번 하나...
# 444                             업데이트안되고 다시설치도안되네요 조치좀해주세요
# 445                                             업데이트가 않되요
# 446     기존 카드를 사용하고 있었는데 혜택이 사라진다고 해서 카드를 변경했더니 삼성페이 등...
# 447                                  필요할때 앱이 작동을 안하네요,,,,
# 448                               다운이 안되요 설치가 한시간째 안되요 ㅜㅜ
# 449     부산시요? 보소! 삼성페이와 연동 안되는 카드랑거? 알고있는교? 상담원은 회사카드라...
# 450                                        앱에 접속이 너무 안됩니다
# 451     신규카드 신청안하면 사용도 못하게해놓은데다 소득공제 면허증 지역 선택 잘못해서 바꿀...
# 452                                 결제내역을 문자로도 보내주면 좋겠네요.
# 453                                        왜 카드 재발급을 강요함?
# 454     도대체 고객센터는 왜있는겁니까? 2/19에 1:1문의 했는데 9일이 지났는데도 보지...
# 455       문자인증이 안와요 어플이 안켜져서 삭제했다가 다시 깔았는데 문자인증메세지가 안와요ㅠㅠ
# 456     카드를 왜또발급받아야합니까 낭비도이런낭비가있을까요 그라고 리뷰에 달린 답변보니깐 신...
# 457     최악의 앱 사용법 하나도 이해가 안감..\n이거 만든 개발자분들 반성하세요... 살...
# 458     전 동백전은 삼성페이에서 사용이 되었는데 아건 카드를 들고 당겨야 되는건가요? 아님...
# 459                                    충전은행 어케바꿔요 드럽게불편하네
# 460     시민들 우롱하는것 도대체 왜 바꿉니까? 누구를위한 정책인가요 300만 시민들 엄청스...
# 461     앱깔고 잔액이관된다하는데 기존카드로의 이관이 아닌 새로운 카드발급후 이관이네ㅠ왜이리...
# 462     세금도둑이 따로없네 ㅋㅋㅋㅋ 왜 뉴스나 곳곳에는 선불카드 재발급 안하고 기존 체크카...
# 463                                                     굿
# 464     별 1개도 아깝습니다 결제가 제대로안돼서 어플실행시키는데 들어가져야지 확인을하지ㅡㅡ...
# 465     기존 체크카드가 있음에도 추가 선불 카드 신청해야지만 동백전을 사용할 수 있다는 시...
# 466                                  부산시가 하는 일아 그렇지 뭐 ㅋㅋㅋ
# 467     UI 개쓰레기 유저 인터페이스가 개쓰레기입니다\n첫 화면에 쓰잘데기 없는 메뉴가 너...
# 468     보니까 코나 알바들 댓 달러 몰려왔네 이렇게 요상꼬름하게 선불카드 강매하면 좋습니까...
# 469     진짜 말도안되게 느려요 어떤 은행, 증권사, 카드 어플도 이렇게 느린거 본 적이 없...
# 470     동백전 결제 불가 농협 동백전카드로 최근까지 결제 되던 곳도 이제 안되네요.  점원...
# 471                        선불카드 신청하지 않고 진행할 수 있는 방법 알려주세요
# 472     도대체 어디서 신규신청을 해서 기존카드 연동하라는건지 인터페이스 진짜 엉망입니다 거...
# 473     ㅈㅂㅈㅂㅈㅂㅈㅂ개선쫌 화면이 너무 정신사납고 직관성 떨어짐 ..제발 원래 앱처럼 바...
# 474     동백전은 좋은데 어플이 왜이래요? 결제가 두번 된거 같아 확인하려고 하니 네트워크 ...
# 475            한도 늘리면 뭐하노 어플 업데이트도 안되 다시 설치도 안되... 아 짜증나네
# 476     지금 동백전앱은 캐시백 금액과 캐시백 금액과 실금액의 합금액만 나와있는데 예전 동백...
# 477                      설치가 안되고 1시간째 대기중.. 삼성페이로 사용안되나요?
# 478     아니 결제를 했는데 제 핸드폰에서는 결제가 됐다고 알림이 왔는데 정작 결제한곳에서는...
# 479     사용하기 불편하네요 전에 KT에서 할때는 편하고 직관적이고 간단해서 좋은데 지금 앱...
# 480     굳이 이전카드가 있는 사람들이 선불카드를 필수적으로 발급 받아야할 이유가 뭔가요? ...
# 481     이상한 환불정책 무슨 환불을 60%이상 결제해야 됩니까? 그럼 시스템이라도 잘 만들...
# 482      좋은말 할때 이번 달 얼마 썻는지 확인하게 해놔라 왜 이번달 얼마 썻는지도 못보게 하냐
# 483     전앱이 사용하기 편하네요 금액이 따로따로설정되어 사용가능금액도 별도 확인해야되고 환...
# 484                                         카드 재발급유도 ㅎㅎ..
# 485     16일 선불카드 강제 발급 절차를 개선해 산택발급이 가능하도록 업데이트 했다고 뉴스...
# 486     전꺼가 더 한눈에 포인트와 충전금액을 파악할수있습니다. 지금껀 포인트랑 충전금이랑 ...
# 487                 업데이트가 진행이 안 돼요 하나도 전혀 삭제도 안되고 중지도 안돼요
# 488               오류 어플 오류가 너무 많아요 쓰고싶을때 한번도 제대로 써본적이 없어요
# 489     오류 카드정보 오류라고떠요ㅡㅡ 인식도 안되고 카드번호도 입력하고 다 했는데 오류라고...
# 490     ㅠ 사용 내역과 충전 내역을 따로 볼 수 없어 불편해요 그리고 총 사용량을 일일이 ...
# 491                                                다운그레이드
# 492     재발급 강요? 재발급 하지 않으면 서비스 사용 가능으로 넘어가지 않는 형탠데 의도적...
# 493            앱 접속 좀 하자. 지금 몇일째 접속이 안되는건지. 관리할 마음은 있는건지.
# 494     너무 불편해요 예전처럼 한눈에 보이지도 않고 캐시백사용도 불편해지고\n예전 앱이 훨...
# 495     탭으론 접속조차 안되네요. 저 처럼 폰은 2g폰이고 탭으로 인터넷하는 사람은 어떻게...
# 496                                            업체 바꿔서 짜증남
# 497     엉망으로 만들어뒀네요. 누가 돈 받아먹었는지 이상한 업체로 바꼈고. 무조건 카드 새...
# 498                                            삼성페이 안되네^^
# 499                                               에러가많이나요
# 500     자주하는 질문에 기존 동백전카드 사용가능하다고 해서 앱깔고 잔액 이관신청하니 카드 ...
# 501                                        앱사용이 너무 불편합니다.
# 502                          맨날 문의하면 같은 답변만 계속하고 성의가 있는건가
# 503                                       와파든 데이터든 안들어가져요
# 504     어플이 실행안되요 통신중 오류가 발생했다고 어플 삭제후 다시 하여도 그대로 입니다 ...
# 505     앱 자체 디자인은 그럴듯 한데 중요한 정보가 없음 토탈 혜택 내역은 있는데 결제당 ...
# 506                  앱이갑자기업데이트하라고뜨면서 업데이트 도 안돼고 앱자체가아예안돼요
# 507                                                  버벅거림
# 508                   가맹점 왜 안뜨나요? 가맹점을 봐야 쓰든가하지 빨리좀 고쳐주세요
# 509     사용금액/캐쉬백 조회 화면 개선 잔액 표시, 이용금액, 캐쉬금액 등 조회되는게 너무...
# 510     기존카드 사용에 관한 안내도 없고..교통카드 기능이나 체크카드연동 기능도 없고 오로...
# 511     왤케 불편하게 바꼈는지.. 그전 동백전도 불편했지만 이건뭐 ㅠ 새건데도 복잡하게 바...
# 512     앱깔고 카드재발급까지 해논상태입니다. 그것도 낭비인데, 예전보다 화면에 뭐가 많아 ...
# 513                    업데이트가 안되어 사용에 불편합니다. 방법을 가르쳐 주셔요!!
# 514         이따위로 만들고 아직도 보수안하는거보니 알만함 그냥 애가 만들어도 이거보단 잘할듯
# 515     돈 충전하고 카페에서 사용했는데 직원분이 은행에 문제가 있는거같다고 안된다해서 디른...
# 516     왜때문에 인증이안되나효 내이름에 내 탄생일에 내 명의의 핸드폰번혼데 자꾸 확인하래 ...
# 517     인터페이스 너무 불편합니다... 혜택정보 누르면 무슨 FAQ내용스러운 것들만 뜨고....
# 518     무조건 새카드 발급되는거 너무 낭비에요.. 기존카드 등록하면된다더니 기존카드는 있든...
# 519     앱연결하기 하늘의별따기임ㅡ얼마썼는지 확인을할수가없음ㅡ앱이 실행이돼야 뭘하지 ㅡㅡㅡㅡ...
# 520                                    금액이 너무 적어서 불편합니다ㅠㅠ
# 521                                           왜 또 안되냐. 에휴
# 522                         아니 접속이 자꾸 안되는데 어째된거죠 짜증나네요 이젠
# 523                             이전 어플에 비하여 가독성 사용성 매우 떨어짐
# 524                         맨날 접속이 안됨 . 관리도 안할거 왜 만들었는지..
# 525                  이런 결제서비스가 접속이 안된다니..어처구니 없는 부산시와KT구나
# 526     치명적인 단점 지적합니다. 환불정책 정말 불편하네요. 전체 적립금에 60%이상 써야...
# 527     부산시 진짜 더럽게 운영하네요ㅋ 업체가 바뀌어도 서비스는 지속성이 있어야하는데 이건...
# 528                       앱이 안열려 충전을 못해서 필요할 때 할인을 못받았어요.
# 529      기존에 사용하던 카드에 있는 돈을 옮기려면 강제로 카드발급하게하는 말도안되는 어플이네요
# 530     사용내역 푸쉬좀 되게해주세요 사용하고나면 사용내역 캐쉬백내역이 알림이 안되고 직접앱...
# 531                  너무 속도도 느리고 업뎃도 안되고 허술 그자체 임 별하나도 아까움
# 532     젊은 우리도 사용하기 힘들 정도로 직관성 없는 앱을!! 동백전을 많이 쓰시는 어른들...
# 533                    앱이 안열림 ㅡ.ㅡ뭐하자는거임? 사용자 증가로 오류? 골때리네
# 534                                앱 접속이 왜 안되는거예요? 아 놔 진짜
# 535     지역사업하나 말아먹는 어플이네 어떻게 사업 땄는지 모르겠네요 볼수록 짜증나고 멀쩡한...
# 536     2G폰 사용중이고 공기계로 앱을 설치하여 동백전을 사용할려고 했으나 유심이 없는 상...
# 537     멀쩡한 카드 냅두고 새 카드 발급받으라구요? 몇십만장 발급되면 환경오염은 어쩔건지?...
# 538     우씨 업뎃이 안되잖아요..설명한것처럼 들어가서 삭제하고 했는데도 안되요..개짜증남....
# 539     완전 별로 새로 바뀐 어플 메뉴 너무 많고 디자인도 정신 사나움. 안그래도 멀쩡한 ...
# 540     오류 좀 개선해주새오 너무 오류가 심해요. 캐시백이 안되어서 문의했더니 다시 가게에...
# 541                                          접속에러 언제 고치나요
# 542     결제시 푸쉬알람이 안떠요 문의를 남겨서 재설정 하라는대로 다 했는데도 결제알람이 안...
# 543                                        업데이트후 들어갈수가 없음
# 544                                                접속이 안됨
# 545                                별 하나도 아까움 부산시민이 호구 인가봄
# 546                        새로(강제로) 만드는 카드 삼성페이 LG페이 안됨 ㅅㄱ
# 547     새로 카드발급이 선택이 아닌 필수라는게 진짜 어이가 없네요ㅡㅡ 부산시는 굳이 왜 업...
# 548     최악의 앱. 사용하기 완전 불편하고, 연결된 카드가 있다는데 카드번호를 보니 내가 ...
# 549                다운이 왜 안될까요? 계속 대기 상태로만 뜨고..ㅠㅠ 확인이 될까요?
# 550     카드뱌아서 충전하고 사용하는대 어플에는 사용됬다고 금액뜨는대 가게에서는 사용중지되있...
# 551     앱자체가 안켜지네요 부모님꺼 계좌연결도 20분째 인증도못하고있어요 인터넷폰뱅킹안하시...
# 552                                          앱이 먹통이네요..에휴
# 553     가장 기본적인 사용자 편의성 1도 생각안하는 업체로 변경을 왜 한건지~^^ 섬성페이...
# 554     아니 어플에서는 사용가능하다해서 갔는데 사장님은 사용못한다면서 자기는 들은거 없다고...
# 555                                  이전 동백전보다 사용하기가 너무 불편
# 556                와~~충전할려고 하는데 들어가지지가 않네요!! 앱이 왜 이때위인가요?
# 557                                            다운로드가안되여..
# 558     업뎃 이후에 개인정보 동의 안하면 화면이 안넘어가네요 이건 먼짓거리인지..쓸수록 짜...
# 559                                          카드 강제발급 최악이다
# 560     아니 왜이렇게 복잡하게 해둔거에요? 쓸대없이 카드는 왜 발급 받게 유도하고 어플 가...
# 561     어휴.. 포인트 다 쓰고나면 안쓰는게 나을듯 하네요. 요즘도 카드 들고 다니는 사람...
# 562                                더 안좋아짐 사용불편,캐시백 소멸도 됨?
# 563                                 회원할려는대 인증번호가 안오네요....
# 564     그냥 부산동구청 따라한거네요. 삼성페이 등록도 안되는 코나카드사ㅡㅡ 짱싫은데 10프...
# 565                               앱이 열리지가 않는데 어떻게 충전합니까??
# 566     가입하려고하면 이미가입된 회원이라고 하고 비번찾으려고하면 일치하는 정보가 없다고하는...
# 567     와..진짜 앱에 평가남겨보긴또 내가.. 부산시예산가지고 대행하는 업체이고 그거로 돈...
# 568                       예전껀 만족스러웠는데 코나아이 운영은 다 불만족스럽네요.
# 569     넘 불편 너무 번잡스럽고 전에 어플처럼 한눈에 보기 쉽고 찾기 쉽게 만들어주세요. ...
# 570                                             ,7,aW ,,5
# 571     Ios 안드로이드 버전 낮으니까 아예 플레이스토어에 없네요 ...다른 카드나 은행앱...
# 572                           머고 네트워크이상하다고 안열린다 젠장 불편해죽겠네
# 573                                         개느리고 접속 안됩니다.
# 574     기존 카드 사용하려면 이관해야 하며, 이관시 새 카드 발급해야지만 사용 가능 이 어...
# 575     가입을 할려고 하니, 다시 신규로 카드를 발급을 받으라고 되어 있네요... 지금 현...
# 576     기존카드 쓸 수 있다고 해놓고 왜 무조건 신규카드를 발급 받아야하나요? 플라스틱 쓰...
# 577                                       업데이트하라더니 사용이안되요
# 578                      아니 충전할려고 앱켰더니 실행이 안되면 어쩌라고요 짜증나네
# 579                                    주말만 되면 접속이 안됨...ㅠㅠ
# 580     지웠다 깔아도 들어갈 수가 없음 -_- 마트에서는 결제가 안됐다고 하고 돈이 빠졌는...
# 581     쓰지도 않을건데 새로 선불카드를 발급 받아야 한다기에 조금 더 기다려보고 이관하자 ...
# 582              아이폰 알림이 안뜨는..; 새로운 어플은 왜 사용알림이 안뜨는 겁니까??
# 583       새버전으로 바꾸고 자꾸 폰에서 소리나고 버벅되고 아니 이러면 사용을 어떻게 합니까??
# 584     어플 직관성이 떨어집니다 예전 어플은 캐시백 받은 금액 + 충전(사용가능금액)액 이...
# 585                                     어플 잘 되다가 접속이 안되네요
# 586     하라는 대로 해도 업데이트가 안됩니다 지우고 다시 설치해도 역시 안되네요 부산시는 ...
# 587     어플 보기힘들어짐 1. 최초실행시 내지갑을 눌러서 카드사용등록을 해야충전버튼이 보이...
# 588     앱 실행 진짜 안됨 뭐 이런게 다있나 싶다. 캐시백 주니마니 생색이나 내지 말고 실...
# 589                                           업데이트가 안됩니다.
# 590     회사 바뀌고 나서 문제가 많네요... 카드결제도 안되고 제한도 많고 고객센터 연락해...
# 591                  동백전 사용내역은 나오는데 캐시백된 금액은 어디서 확인할수있나요?
# 592        잘되던 얩이 얼마전부터 네트워크 상태를 확인하세요 이런 문구만뜨고 앱 실행이 안되요
# 593                    네트워크 오류라고 실행자체가 잘 안되네요 왜 2점인지 알겠네요
# 594                              데이터 인식을 못하나봐요 깔아도 쓸수가없네요
# 595                              업데이트가 안되서 못쓰겠네요 넘하는거 아네요
# 596     가맹점이 어디 있는지 찾을수 없으면 동백전의 유용한 기능을 못 쓰는데 어떻게 하라는...
# 597     업데이트 했는데 메인화면이 안열리고 업데이트해야만 사용가능하다는 안내만 자꾸 뜨네요 ㅠㅠ
# 598     가입하려고 폰인증번호 전송누르면 예기치못한문제발생 했다고 진행이 안됩니다 수십번을 ...
# 599            심심하면 안열리네요 쓰라는건지 쓰지말라는건지 뭐 열려야 확인도하고 충전도하죠
# 600                               진짜 성의없네 답글은 전부 복사 붙혀넣기내
# 601     신규카드 발급 강제.. 어이없네요 신규카드 발급 선택권 검토중이라고 하니 기다려봅니...
# 602                                         교통카드연계는 어찌합니까
# 603     사용자정보취득에 실패하였습니다 사용자정보취득에 실패하였습니다 앱을 다시 실행해주세요...
# 604     나는 이전 하나카드를 삼성페이에 등록해서 사용하니 불편함을 못느겼는데 신규 사용자는...
# 605     갤럭시s10 사용중인데 접속이안되서 재설치하면 들어가지고 익일에 또 접속안되서 재설...
# 606                                 카드.결제는.되는데.내용확인이.안돼네요
# 607                            명불허전 공무원 작품.. 접속장애 엄청 심합니다
# 608                      새 카드 이관할려고 보니 실물카드와 앱상 카드번호 다릅니다
# 609     페이백 받은 금액만 확인해 보는 게 너무 어려워요. 결제할 때 충전한 금액만 쓰고,...
# 610                          기존꺼는 삼성페이도 연결되었는데 이건 안되네요 ㅡㅡ
# 611                                             문자인증이안됩니다
# 612     동백전 바뀌고 너무 불편합니다 원래앱이랑 너무 비교되네요 이전앱참고해서 개선하는게 ...
# 613     업데이트도 안되고 삭제하니 앱이 다운로드도 안되고 어쩌라는건지 바뀌고 나서 사용엄청...
# 614     본인인증단계에서 인증문자가 안와요 개선해주세요 본인인증단계에서 인증문자가 안와요 개...
# 615              카드신청시 주민번호 입력후 다음화면으로 넘어가지않습니다. 업데이트해주세요
# 616     좀 어플좀 들어가봅시다. 뭐좀 할라하믄 네트워크 상태가 안좋다하고. 충전도 못하고 ...
# 617     예전 앱과 비교해 디자인이 복잡해서 불편해요.첫화면에 총받은 혜택 이거 없애주세요 ...
# 618     부산시에서 관리비로 100억이나 뜯어갔으면 서버관리좀 똑바로하세요 맨날 터져서 못씁니까왜
# 619     마케팅 광고는 왜 넣었으며..왜 선불카드 의무 발급하도록 하는지요?? 공지도 카드 ...
# 620      사용내역 보려고 하면 어플이 꺼져요 충전만 되고 뭐 하려고 하면 꺼져서 쓸수가없어요^^
# 621     동백전 충전오류 앱 다시 바뀐뒤에 4월 5일부터 깔아서 사용하려는데\n지금까지 충전...
# 622                                 오늘 결제도 안되고 어플실행도 안되요.
# 623     나왠만하면 평점안남기는데 마이너스 별 백만개 서비스가 개선되어야하는데 뮈야 이건 모...
# 624     아 박형준시장님 동백전 다시 돌려놔주세요 삼성페이도 안되는 쓰레기카드를 요즘 누가 ...
# 625                                           접속을 하게 해달라고
# 626     앱 쓰레기 동백전 신청하려고 앱 깔았는데 에러만 벌써 15번째… KT에서 개발한거라...
# 627                  이전 동백전카드에 잔액이 없어졌네요? 케시백된 금액은 사라졌나요?
# 628           기존 사용카드 등록하면 없는 카드라고 나오는데 어떻게 잔액 이전하라는거예요??
# 629     메뉴가 중첩되는 부분이 많아서 메뉴구성이 깔끔하지 못한 느낌입니다 메인화면에 충전,...
# 630                                      앱 바뀌고나서 너무불편사항만음
# 631     그냥 뭐 새로 만들려 하지말고 이전 동백전 앱 ui라도 그대로 해주세요 \n\n그리...
# 632     어째 더 프로그램이 다운그레이드 된거냐? 별5개 찍은리뷰 보니 대부분 4월2일~3일...
# 633                                               잘쓰다실행불가
# 634                          오류 투성이. 접속 됐다 안됐다 네트워크도 불안정함
# 635                예전꺼에 비해 불편함만 느끼고 쓰지도 않을 카드 한개 늘어나고 ...
# 636                                                  별루다.
# 637                   실력이 없는지 개선이 안되는 업데이트는 왜 하는지 알 수가 없다
# 638                어플이 한눈에 보이지않아 불편하네요 그리고 가맹점찾기는 사라진건가요?
# 639                                업데이트가 계속 언되어서 충전이 안됩니다
# 640                           솔직히 왜 바꿧는지 모를정도로 너무 형편없어졌네요
# 641     전 앱 처럼 충전금액 캐시 구분 가능하게 해주세요 간단하게 알아보게끔 처음나온 동백...
# 642                                 왜또카드를 발급 받으래 짱나게. . .
# 643     잔액확인 카드잔액확인 어플 처음 켰을때 화면에서 할수있게 개선바랍니다 매번너부 불편...
# 644     가독성이 너무 안좋아요 메인화면엔 필요한정보만 나오면 되는데 "총 받은 혜택"란에 ...
# 645     새로 발급받아야한다니...그마저도 삼성페이는 안된다구요????후...코나아이 이관후...
# 646     kt앱이었네요 kt폰이 아니면 사용불가인 모양이네요 계좌등록 진행중에 인증완료를 누...
# 647         동백전 사용좀 합시다;; 카드 오기 전까지 사용못해서 손해보는 비용만 얼마인지;;
# 648     기존카드 등록이 너무안됩니다 또한 다른사람 등록한거보니 만든꼬라지가 그냥 초등학생수...
# 649                                                 정말 싫다
# 650                                      불편합니다 저번앱이 훨나앗음ㅠ
# 651               체크 계속 사용할 수 있다는 설명도 없이 그냥 무조건 카드 발급하라니요
# 652                         노답ㅠ 기존보다 가시성 떨어지고 편리하지도 않은듯;;
# 653     기존카드사용이라고 안내하였고 추가발급해야한다는말이 없었는데카드를 발급선택도아니고 강...
# 654                                           삼페 안되기만 해봐라
# 655     잘 사용하고 있는데 괜한 업데이트를 해야만 사용할수 있게해서 지금현재 마음대로 사용...
# 656                          동백전 되나요? 전 코나로 계속 문의하라뜨네요~ ㅠ
# 657                               기존에 쓰던 카드 계속 쓸 수있게 해주세요
# 658     진짜 뭐하는겁니까 별 듣보잡회사가 운영한다고 할때부터 알아봤네요 기술이 안되면 때리...
# 659     앱 깔자마자 강제 신규발급 강요--카드발급 안하고 싶으니 환불 해주세요. 쓰고싶은 ...
# 660     진짜 너무하네 예전보다 사용하기는 겁나어렵고 난 내돈넣고 사용하는데 광고도봐야되고 ...
# 661                            앞전과 비교했을때 포인트 쓰는것도 너무불편합니다
# 662     별하나도 아깝다.앱도 구리고 운영도 구리다.신규카드 발급은 도대체 왜 하라는겨? 재...
# 663               카드재발급해야됨 기존카드 사용하려고 카드발급받아서\n쓰레기만 추가하는꼴
# 664     신청을해서 등록하려는데 자꾸 통신상연결이안된다하고 네트워크문제라고뜨네요 다른인터넷어...
# 665     기존 카드이관 요청 당연히 기존 카드 사용할수있게해야 하지않나요? \n업체가 바뀌면...
# 666                                                서버 좀ㅡㅡ
# 667     앱이 안열립니다. 왜이럽니까 진짜 확인 할게 있는데 시골이라 와이파이로. 접속 할수...
# 668                                                  번거로움
# 669                        뭐가뭔지 모르겠네요 설명을 알기쉽게 잘 설명해주던가,,
# 670                느린속도데이터쓰는사람은 와이파이안잡으면아예안됨 밖에서 사용할수가없어요
# 671     1. 앱 깔자마자 카드 강제 발급 유도에, 막상 가입하고 나니 예전에 발급받았던 체...
# 672                어제 결제가 안되서 곤란한 경험을 했습니다. 결국 다른 카드로 했죠.
# 673     어플을 쓰기위해 일부러 카드까지 신청하게만드는건 아닌거같습니다. 어플이 바뀌는거였지...
# 674                                                이전이 나음
# 675                 이전 프로그램보다 눈에도 잘안들어오고 사용하기 불편해요 개선해주세요
# 676     동백전 앱에 들어가면 가맹점 찾기가 원래는 나오는데 어제 부터 위치를 잡아도 안나오...
# 677     무슨 카드의무 발급인지;;; 진짜 환경생각 하나도 안하고 자기들만 생각하지 지들 이...
# 678                 전에 앱이 직관적이고 참 좋았는데 바뀐건 넘 복잡하고 쓰기 힘들어요
# 679                그냥 업데이트중이라고 뜨면서 작동할생각을안함 여기돈넣고쓴 내가호구인듯
# 680     별 하나도 아까운 앱이 분명합니다. 기존 사용자들의 불편은 동백전 사업자가 이관되었...
# 681     쓸데없이 있는카드 또 발급. 답글은 신규발급받아야 사용가능하다는 똑같은 대답. 필요...
# 682                                      사용가능한가맹점이부족 삽니다.
# 683                                             접속불가 충전불가
# 684                      동백전 지갑 어디갓어???? 있던게 없어짐.... 어이없네
# 685     쓰기 싫음 자동으로 캐쉬도 안돼 사용 전후 잔액확인도 없고 승인 내역만 있어 바뀌고...
# 686                                        통신오류가 너무 잦아요ㅡㅡ
# 687                                            예전보다 ㄷ~~불편
# 688                          이게 뭔가요? 계속 열리지도 않고 짜증 너무 나네요
# 689     몇일전 가입하려고 생년월일 입력하고 인증받으려면 입력한게틀리다고 5회오류나서 다음에...
# 690     정말 불편하게 바꼈어요 나이가 있다보니 앱이 너무 복잡하고 쓰기가 힘드네요 가맹점찾...
# 691     동백전 사용하기 힘듦 동백전 사용가능 가맹점 리스트를 보고싶은데 아무리 찾아도 안보...
# 692                           다운하는데 계속 몇시간동 대기중이에요. 도와주셔요
# 693                      카드를 받고 앱을 실행할려니 안되네요. 이렇게 허접하다니?
# 694     여러모로 구려요. 더 좋은 서비스 제공을 위해 시행사 바꾼 거 아닌가요? 전에는 불...
# 695          엥 곧 앱이 설치 된다고만 하고 설치도 안되고 언제까지 기다려야 설치가 되나요?
# 696     요 며칠동안 네트워크 상태가 원활하지 않다면서 접속이 안되는 이유를 모르겠네요. 충...
# 697                                             카드 취소해주세요
# 698     별한개도 아깝네!! 별한개라도 안주면 리뷰도 못남기게 해놨구만... 사용자들 말도 ...
# 699                                       앱설치가안되는데뭘써라는거요?
# 700     공무원들 하는일이 원래 그런거라하지만 그지같음 계획적소비같은 소리하네 체크카드로 누...
# 701                                  실행도 안되는구만. 별 하나도 아까워
# 702                                    혹시 부산 동백전 카드 망했나요?
# 703                 업데이트도 안되고 지웠다 깔아도 되지도 않는거 어째 사용하란말이에요
# 704                           503오류 뜨면서 실행안되네요 우째해야되나요ㅡ.ㅡ
# 705     카드가 도착했다해서 우편함에 놔둬달라했는데 집에 갔는데 없더라구요ㅠㅜ 그래서 재발급...
# 706     신규 카드 발급이 필수라서 발급하고 전에 카드는 못쓰나 싶어서 버렸더니 이제와서 뒤...
# 707     소득공제부분에 입력이 안돼요 오류가 계속나네요 실물카드 변경해야하고 새로받아야하고 ...
# 708     충전계좌등록이한계좌밖에안되네요... 앞전꺼에는2계좌도등록해서썻는데.. 최소한..이전...
# 709                                      부산은행은 결제계좌로등록이안됨
# 710                       쓰레기보다 최악이라는 말보다 더 한 말이있다면 그 정도급
# 711     갑자기 안되니까 어이없네… 아니 왜 갑자기 네트워크 불안정 하다고 뜨고 안 들어가지...
# 712         예전 동백전 앱보다 불편합니다. 적립금 확인이나 사용내역 확인이 많이 불편합니다.
# 713     불편한 UI 정신없는 인터페이스에 대한 피드백이 많네요.\n\n제일 개선했으면 하는...
# 714                           업데이트 하라고해놓고 안됨! 이건 무슨 경우인지?
# 715                                 사용처도 확인안되는데 무슨, 불편하네요
# 716                              업데이트 안되요 며칠째인데 관리도 안하나요?
# 717     어플 접속이 자꾸 튕겨요 캐쉬백도 제대로 들어오지않고 부족하게 들어오고 고객센터 전...
# 718     등록 가맹점 검색, 확인할 수 있도록 해주세요. 모든 가게가 등록한 게 아니라서 일...
# 719     왜 잘 쓰던거 바꾸는지;;;;;;; 개별로임 카드도 재발급 받아야되고... kt보다...
# 720                     어플개떡같이 만들어서 켜지지도않고 계속 로딩이고 가끔씩만켜짐
# 721                  아 새카드 발급 발급 취소도 안되네..짜증. 별 한개도 아깝다..
# 722     불편합니다 바코드로 결제하는것도없고 qr도없고... 바로 써야할일있어서 충전했는데 ...
# 723     간편결제가능하다는문자보고카드등록하려하니안되네요 저번보다 가독성도 떨어지고 어떻게 써...
# 724                  아니 왜 잘 되던게 갑자기 네트워크 뭐라하면사 안들어가지냐 ㅠㅠㅠ
# 725                               캐시백된 금액 어디서 보는지 한참찾았네ㅡㅡ
# 726             클릭 안됨 가입 다 하고 맨 마지막에 비밀번호 설정하는 거 클릭이 안되네요
# 727                                            안대는데는데무선평가
# 728     사용가능금액이 캐시백포함인지아닌지 알수가있어야죠\n사용자가 항상 그거 합계를 하던지...
# 729     직관적이지 못함 직관적이지 못함. 어르시들도 많이 사용하는데 뭐가 많이 생긴만큼 직...
# 730                                            예전보다많이불편해요
# 731             금액확인 후 사용할려고하니 오류뜨네요;;자주 에러가 나니 사용하기 불편해요
# 732     기존카드 연동후에는 신규선불카드 발급 취소도 안되네요ㅠ 당일취소 했는데도 안되네요....
# 733                  어제부터 와이파이해도, 안해도 서버통신?문제로 연결안된다고 뜨네요
# 734     갑자기 가맹점 검색이 안되네요. 어떤날은 갑자기 결제 오류나고 이렇게 불안정해서 어...
# 735                                    월 사용금액 페이백금액 집계가안됨
# 736                  가맹점찾기는 사라진건가요? 왜 안보이죠? 이전보다 더 안좋아졌어요
# 737     별 한개도 아까움 왜 이런업체로 바뀌어야 하는건지 앱도 불편하고 고객대하는 태도도 ...
# 738                                             앱실행이안되네요?
# 739     알림 왜 안오나요... 사용알림 전혀 안오네요. 기존에 쓰던 동백전 카드도 그렇고 ...
# 740                              사용가능금액중 내잔고 확인이 쉬웠으면 하네요
# 741              기존카드 불가. 상담원 연결도 불가. 오늘 결제해야되는데 왜이러세요?ㅜㅜ
# 742               기존카드 이용불가이면서 이관은 먹통임. 앱실행해도 먹통이고 되는게 없음
# 743     진짜 이렇게 불편한 앱은 처음이에요 메인 홈으로 이동하는 버튼도 안보이고 진짜 계속...
# 744                                       동백전 앱이 설치가 안돼네요
# 745     앱 알림은 결제가 되었다고 뜨는데 업체에서는 결제가 안되었다고 해서 다른 카드로 결...
# 746     별 하나도 아까워요. 캐시랑 충전한 금액 구분도 어렵고 진짜 지난앱보다 겉만 번드르...
# 747     업데이트도 안되고 삭제하고 다시깔려고 하니 대기중만 나오고 사용 엄청불편하네요 빠른...
# 748     네이버 밴드 어플을 악성코드로 인식하네요. 밴드어플을 삭제하고 어플설치후 밴드를 다...
# 749     기존 카드 등록하면 된다고 해놓고는 등록하는 난도 없고 무조건새 카드를 발급받으라고...
# 750     신규회원가입을하고 사용하려고하는데 잔액을 이동시켜야된다고해서 하라는대로 입력을했는데...
# 751                                                  별로네요
# 752     캐시백 이용시 기존 동백전 앱에는 on버튼만 키면 금액과 합산되어 사용할 수 있었는...
# 753                                                   불편함
# 754                                           어플이 실행이 잘안됨
# 755     네트워크가 원활하지 않아 안된다고 뜨네요. 그런데 옆에 남편은 확인이 잘되는데 뭐가...
# 756     소득공제 실명인증에 여권상의 영문이름은 왜 넣나요? 생전 처음듣는 회사에 운전면허번...
# 757                              앱 접속이 안되요 확인해주세요 계속 오류나요
# 758               동백전 카드에 있는 돈을 쓸수 있는건가요?? 이관 될 줄 몰랐는데요ㅠㅠ
# 759                                  10%에서보다 갈수록 쓰임이 덜해져요
# 760     쓰레기 같은 앱 알람설정도 마케팅 동의해야 가능하게 만들고, 카드도 코나카드 일부러...
# 761           그전 앱이 더 펹리하고 보기도 좋습니다.지금앱은 너무 불편해요.다시 돌려주세요
# 762     왜 기존 카드를 못쓰죠? 설명은 기존 카드를 쓸 수 있는 것 처럼 해 놓고는\n\n...
# 763     업데이트를 해야만 앱을 열수 있다는것이 아주 불편 11/10이후 업데이트를 2번이나...
# 764     제발 안드로이드에서 국가사용제한 좀 풀어주세오 메일도 보냈습니다 ㅠ 제발 풀어주세오 ㅠㅠ
# 765     어플이 켜져야 잔액 확인을 할텐데 어플이 켜질 생각을 안하네요 리뷰 보니까 다른분들...
# 766     앱 접근 오류가 너무 자주발생해서 불편하네요 잔액 캐시좀 확이하려는데 이렇게 자주 ...
# 767                                 아직 사용 경험이 없어 잘 모르겠습니다
# 768     실행이 안됩니다 어플을 실행시키면 알림설정 창과 필수동의 까지는 되는데 그 다음 화...
# 769     앱이 실행이안됨. 네트워크 잘만 연결되어있는데도 원활하지않다고 빠꾸먹임 관리좀잘해라...
# 770     충전취소 3일이나 걸린다니 너무하네요.전에꺼는 실시간취소였는데.글고 설치 후 신규발...
# 771                                            여러모로 불편합니다
# 772                                            진짜 최악으로 바뀜
# 773                                            접속이 안되네요ㅜㅜ
# 774                                      이전 앱보다 사용이 불편하네요
# 775                                         그전에 비해 너무불편해요
# 776     동백전의 의도는 너무 좋으나 앱이 너무 안 좋습니다. 동백전이 활성화하지 못하게 된...
# 777     어휴.. 별 그지같은데서 동백전 새로 이어받았네.. 이관 된다면서, 뭔 새로 입력해...
# 778     사용하기 불편해요 이전이 훨씬 사용하기 편합니다. 시인성도 떨어지고 전체적으로 별루예요.
# 779     아니 무슨 카드 발급 안해도 쓸수있나 싶어서 결제했는데 안돼는거 확인하고 환불하려 ...
# 780     1. 우선 실물카드를 가지고 다녀야 하는 불편함 2. 초반 자동차 지급하는 이벤트로...
# 781     자꾸 네트워크 이상이라면서 안 들어가집니다 급하게 써야할때마다 난감해요 폰 기종이 ...
# 782     최악!! 너무 어이 없어 생애 처음 리뷰 남깁니다. 신규카드 발급 없이 기존카드 사...
# 783                             앞전 동백전카드보다 별루 페이결제도 안되고등등
# 784     기존에 가입이 되어 있는데 이관되면서 새롭게 가입해야되고 무조건 선불카드를 신청해야...
# 785     공지사항 좀 그만 띄우세요 아니 무슨 어플들어가면 공지사항 팝업을 3개 4개를 띄웁...
# 786     뭔지 당최 알 수 없는 쓰잘데기 없는 기능을 만들었는지...이전 동백전이 훨 나았음...
# 787     동백전이 어플없이 사용가능하다면 모르겠지만, 필수적으로 어플이 필요한 서비스인데 이...
# 788     전에 올라왔던 공지글이 사라지고 1:1문의 올린 글에 내용과 다른 답을 달아줬네요....
# 789                                            주소 입력이 안돼요
# 790     기존 동백전카드만으로 신규앱에 등록되도록 빨랑 시스템 개선하세요 4일간(4.1~ 4...
# 791                                   최악 어플이되야ㅡ쓰죠!!!!!!!!
# 792     사업주바뀔때 전산시스템 확인 안해보셨나요? 기존 동백전카드앱 사용불가로 다시 동백전...
# 793                                         불편 이전보다 불편하네요
# 794             아무것도 되는게 없어요. 운영사가 바뀌고 삼성페이도 안되고 그냥 안쓸래요.
# 795          로그인이 왜안되나요? 이리 안들어가지는 어플도 첨봅니다..빠른 수정 부탁드립니다
# 796                  노트 4에서도 되나요 부산은행서 호환이 안된다는데 이해가 안되서요
# 797     양산사랑카드와 동백전 2개 다쓸려고하니 자꾸에러나네요 지우고새로깔면 이건되는데 다른...
# 798     (4) 선불카드 발급 비용은 누가 부담하나요? ▷ 카드 발급에 따른 부산시의 관련 ...
# 799     서비스 종료인데 구 어플 안내리냐?? 새 업체 어플인줄알고 또깔앗자나 이것들 정신못...
# 800     아니 QR기반 회사 KT가 왜 카드를 발행해요? 카드는 또 하나카드네? 하도인가? ...
# 801     진짜 짜증날정도로 편의성 0 충전하는것도 적립금 확인하는것도 너무 불편. 불편해서 ...
# 802     본인명의폰 아닌사람은 가입을 못하네요 공인인증같은거나 다른 인증할수있는방법 더 생기...
# 803     어플개발자 짤라야겠는데요? 그사람월급도 시에서 지원받을텐데 세금아깝습니다 이상황 지...
# 804     삼성페이가 안됩니다 기존카드도 사용가능하다면서 등록하려니 없는 정보라고 등록이안됨 ...
# 805     와 앱 실행 너무 안되요 너무너무너무 너어어어무!!!!!! LTE로 해도 안되고 와...
# 806                                                의무발급..
# 807                   동백전앱이 곧 기기에 설치된다고하고 설치가 안되는데요? 무한반복
# 808                              업데트가안데네요몃시간이지났는데도상용불가합니다
# 809                                                불편하네요.
# 810     전산오류로 결제가 두번 됐는데 충전한 돈으로 결제한 첫번째 결제를 취소시키고 두번째...
# 811                                캐시백은좋은데 앱사용오류가너무심해요 ㅜㅜ
# 812     내가 캐쉬백받은 금액이 얼마인지 확인이 안되요. 그거때문에 동백전 쓰는 건데요. 이...
# 813     새카드 발급안받고 기존카드만 사용하고 싶은데 그냥 발급 안받고 넘어가는 메뉴를 빨리...
# 814                                           가맹점찾기 기능은요?
# 815     앱도 안깔리고 진짜 이거땜시 몇시간 헛수고 하는듯 진짜열받네요..이전앱은 삭제 했고...
# 816                             안쓸렵니다 바꾼 이유나 합리적으로 설명해주세요
# 817     전 카드 대행사와 너무 비교돼서 별 한개도 아까워요... 카드 포인트 쓸때마다 어플...
# 818                         먼저번거랑 비교가되네요 광고도많고 앱들어갈때 불편해요
# 819     본인들 수익을 위해서 카드 발급 선택사항 조건이라면 이해가 가능하지만 필수사항으로 ...
# 820     캐시백 적립현황은 기본아닌가요? 볼수가 없네요. 들어왔는지 일일이 캡쳐해서 비교해봐...
# 821                                          제발 본인확인 추가좀요
# 822     별 하나도 아깝다. 기존 동백카든 쓸려면 이름도 거창한 웰컴카드 만들어야하네! 부산...
# 823     선불카드 오늘 받아서 이관된 금액으로 결제했는데 캐시백이 안됩니다. 왜 그렇죠? 바...
# 824     왜 이렇게 귀찮게 설정해놨냐 무슨 캐쉬쓸려해도 얼마 작성해서 캐쉬쓰게 만들어놓고 작...
# 825                어제부터 네트워크연결이 안된다고 접속이 안돼요.ㅡㅡ 어떻게 해결함요?
# 826     진짜 앱 거지같음. 기존 동백전은 충전 금액이 자공으로 차감됐는데 이건 뭐 할때마다...
# ...
# 1074    무슨 앱이 이렇나요? 그냥 전에 업체 앱이랑 인터페이스를 똑같이 하세요. 이거 뭐 ...
# 1075    복붙노력은 왜하는거지? 더나은서비스는ㅋㅋㅋㅋ 쓰레기게임출시하고 최고의게임으로 거듭나...
# 1076        충전만 하려고하면 어플안켜집니다 충전만 하려고하면 어플안켜집니다 한두번이 아니에요
# 1077    포인트 사용 표시가 헷갈리게 되어 있고 총받은 포인트 표시가 불필요하게 표시되어 있...
# 1078    앱 꺼짐 문제 앱 들어가서 캐쉬백을 누르면 앱이 꺼져버리는데 어떻게 해야되나요? 다...
# 1079    오늘 계속 오류라고 안열리네요.. 카드 발급하게 만들어서 선불카드 발급받았는데.. ...
# 1080                                예전 이관되기전에 카드 사용되나요 ??
# 1081    직관성이 상당히 떨어졌네요 전에는 버튼 클릭 한두번으로 원하는 설정이\n가능했다면 ...
# 1082    ㅠ가맹점 찾기라뇨ㅠ 생각보다 안되는곳도 많고 충전금액 환불은 왜 안되는거죠? 계속 ...
# 1083    설명 좀 쉽게 하지? 잔액 이관 하는데 뭔 신규발급에 신규등록에... 장난치나. 앱...
# 1084                                         업데이트가 안되네요ㅠㅠ
# 1085    새로 가입해서 새로 쓸모없는 카드 발급해서 거기다 연동하라는 짓까지함 앱 기능부터 ...
# 1086                                    에러가 잘남, 못난 케이티 통신
# 1087    동백전을 사용하는 모든 사용자가 이미 카드가 있는데 왜 새로 발급 받지 않으면 사용...
# 1088    오늘 하루종일 로그인이 안되네요 오류도 자주나고 등록된 가맹점에서도 사용 안되는곳이...
# 1089                                           사용하기가 쉽지않음
# 1090    푸시알림 사용내역 알림받으려규 푸시알림 켰더니 마케팅 알람이랑 같이 오네요… 알림껐...
# 1091    앱 사용이 직관적이지 못하고 대표적으로 월별 사용금액(기간지정)이 누적확인이 안되서...
# 1092    1. 동백전 가맹점 배너 만들어주세요 -예전에 이 문제 관련해서 4/29일에 가맹점...
# 1093    기존 회원의 보유금액과 카드정보를 새로운 동백전 시스템에서 연동하기 위한 기술적 필...
# 1094    왜 적립이안되나요? 동백전앱 새로설치하고 카드도 신청했어요 그러고 이전 동백전 카드...
# 1095                  당월결제 금액이 얼마인지 한눈에 쉽게 볼수 있게 업데이트해주세요
# 1096    기존카드 사용되지 않는다면 굳이 새로 만들 필요 없는데, 번거롭기만 하니 환불 조치...
# 1097    알뜰폰 유심으로 변경후 인증된 폰번호와 일치하지 않다는 메세지나옴ㅡ초기화해주세오ㅡ ...
# 1098    엉망진창입니다. 사용하려고 만든어플이 어떻게 결제하려할때마다 앱이 오류가 빈번하게 ...
# 1099               카드 재발급 필수인거 진짜 짜증남 며칠간 사용 못한것도 진짜 화나는데
# 1100    지난 토요일부터 네트워크오류라고 로그인자체가 안됨. 충전.잔액확인안되고,혹시 이런상...
# 1101                                             서버 맨날 터짐
# 1102    어플화면에서는 결제완료창이랑 캐쉬백 내역이 뜨는데 가맹점에서 실결제가 되지는 않는 ...
# 1103    다른건 둘째치고 캐시백 사용이 너무 번거로움. 이전 동백전 앱이 사용자 입장에서 더...
# 1104    동일한 후기가 많습니다만 왜 자꾸 네트워크 연결안된다고 하나요?? 불편해서 못 쓰겠...
# 1105                                  왜 댓글에 답장안해주냐? 무시하냐?
# 1106                       아니 왜 접속이 이렇게 안됩니까 사용을 할 수가 없네요
# 1107                 해외에서는 어플리케이션 접속이 제한되나요? 접속 자체가 안되네요.
# 1108                                  교통카드도 안되고 다안되고 개불편함
# 1109            기존카드에 바코드는없고 입력하니 등록할수없는카드라는데 어떻게쓰라는말인가요?
# 1110    기존 사용하던 카드로 결제했는데 캐시백 안됨 고객센터에 20번 넘게 전화해서 겨우 ...
# 1111       기존 어플보다 못할 정도면 회사도 신뢰가안감 개발자는 만들고 직접 사용안 해보나요?
# 1112                                           저번보다 완전 불편
# 1113                               가맹점찾기에서 가맹점이 하나도 안보여요.
# 1114    1. 기존 어플에서 가능했던 바코드 생성 결제가 불가능해짐. 신규 카드는 삼성 페이...
# 1115                                      현금인출기능이 없어가 불편함
# 1116    아..진짜 이거 뭐 이따위로 만들었나요. 업데으트도 안되고..왜 이런 업체가 이런 ...
# 1117    네트워크연결때문에 며칠째 접속이 안되요. 쓰고 남은금액 확인할랬는데 네트워크 때문이...
# 1118           앱 사용 내역 볼려고하면 계에에에에ㅔㅔㅔㅔㅔ속 나가지네요 빨리 고쳐 주세요
# 1119    동백전 카드 결제지연 오류 아니 무슨 카드가 사용자가 많다고 오류가 되서 계산이 안...
# 1120    어플을 운영을 하실거면, 불편함은 제때 개선좀 하세요 국민들 불편함 의견제기 1. ...
# 1121    아니 어플 좀 옛날처럼 하면 안되나요? 내지갑 이런거 왜하죠? 너무 불편. 그냥 메...
# 1122                                카드신청이 안됩니다 눌러도 반응이없어요
# 1123                           기존카드사용하려는데 왜카드이관신청하라고만 뜨죠?
# 1124    업데이트 하라는 공지 이후로 업데이트도 안되고, 혜택도 못받고 있습니다.언제까지 이...
# 1125                        이전보다 너무불편함 적립내용보기도없고 개선해야할게많음
# 1126    오늘은 앱이 전혀 열리지 않네요. 무슨 일인지 몇번을 시도해도 열리지 않아요. 답답...
# 1127    금액 충전이 안 되고 자꾸 꺼져요 금액 충전해서 쓰고 싶은데 앱이 자꾸 다운되고 꺼...
# 1128    청와대게시판이나 언론에 제보할일이네요 쓰잘떼기없이 굳이 신규카드를 재발급해야될 이유...
# 1129          어플 너무 조잡하고 메뉴찾기 어려워요 어르신들 못쓰라고 일부러 이렇게 만든건지
# 1130                                        너무느리고 접속이 않된다
# 1131    1점도 아까움. 몇일째 앱이 안열려서 충전을 못하니 쓸수가 없음. 카드는 왜 만들어...
# 1132                                                  별로.
# 1133                                      설마 삼성페이 등록안되나요?
# 1134                                 예전앱이 훨씬 좋았음 똥으로 변함ㅡㅡ
# 1135                                   로그인 안되네요 사용하기 짜증나네
# 1136                         부산시가 하는게 다그렇지 돈이나 받아먹고 바꾼거지뭐
# 1137                                       와 진짜 개떡같이 만들었네
# 1138                                                안열리네요
# 1139    진짜 넘하시네요! 아니 뭐 접속도 안되고 맨날천날 통신이 불안하다고 하면 시에서 일...
# 1140                         사용장애로 결제잘못됐음 빨리환불해라. 벌써2주째다.
# 1141    세상엔 플라스틱 쓰레기 줄이라고 난린데 새 카드 발급해야 기존카드 연동할수있다는 글...
# 1142                                   중단됫다고안되고업데이트하라고안되고
# 1143     돈 넣었는데 어플 실행이 안돼요 ? 잘 쓰다가 돈 남아있는데 어플 실행이 안돼요 뭔데요
# 1144    안드로이드 링크로 들어가니 구글 비번 입력하라해서 입력했는데 오류라해서 휴대전화로 ...
# 1145    진짜 불편함 진짜 어떻게 이렇게 불편하게 만들었는지 싶을 정도로 개썩음 충전 금액 ...
# 1146    왜 제일은행계좌연결이없나요 그리고 카드는왔는데 잔액충전을못하고있어요 어플이 오류라고...
# 1147    갤s8 브라우저ㅡ 크롬으로 설정해야된다고 진작좀 알려주지 어제 전화문의는 그런거 안...
# 1148    충전하는 계좌를 2개이상으로 할수 있도록 해주세요! 사옹가능 가맹점을 검색할 수 있...
# 1149                                            삼성페이 않돼나요
# 1150                              저기 인증 문자가 안오는데 어떻게 하나요?
# 1151     기존 동백카드를 계속사용중입니다.새로운카드를 받았는데 등록이되지 않습니다.어떻게 하죠?
# 1152         고객센터 1:1문의는 아예 관리를 안하는것 같아요 읽지도않고 처리도 않해주시네요
# 1153                                   아니 카드 등록 자체가 안되잖아요
# 1154    리뷰는 스마트폰 쓰면서 처음 남겨봅니다. 10만원 충전해 놓고 사용하려고 보니 네트...
# 1155                   앱이 열리지않고 답답하네요 충전을 못하고 이용하지를 못하겠네요
# 1156    아이폰은 버리는 건가요? KT가 운영사 일때는 쓸때마다 푸쉬 알림도 즉각즉각 와서\...
# 1157    다운로드만 되고 아이콘누르면 동백전로고만 내내떠있고 아무것도 안되는데요.. 와이파이...
# 1158    왜 KT와 1년으로 계약해서 사용자들에게 이런 번거로움과 불편함을 만드는지 이해가 ...
# 1159                                                  불편함
# 1160                        신규카드발급 강제하네요. 부산시청에 항의하겠 습니다.
# 1161    다들 부산시에 동백전 민원 넣어주세요 이렇게 불편하게 만들어놓고 담당자는 뭐 하나 ...
# 1162          그냥 좀 간단히 만들면 되는것을 짜증 납니다 그리고 맨날 광고을 띄워야 합니까
# 1163                        모든답변을 븥여넣기하네 헐 참~~ 담당자 이름 머고?
# 1164    왜 선불카드 추가 발급을 하라는지 모르겠네요... 그나마 기존 카드 사용은 된다하니...
# 1165                           가맹점 가맹점 찾기 아예안되요 쓰지말라는건가요?
# 1166    혜택을 많이 준다해서 하나장만했더니 무슨 행정을 손바닥 뒤집듯바꾸나요? 재수없어서 ...
# 1167                                                 짜증나~
# 1168                                             업데이트가안되여
# 1169    댓글마다에 달리 '신규동백전카드신청>수령후등록>기존카드연동'은 어디있나요? 등록하다...
# 1170            에휴 진짜 이전 회사 기능들 좀 다 개발하고 이어 받지 뭐가 급하다고...
# 1171        지들 코나동백전선불카드 끼워팔기네 이거 금감원이나 소비자보호 이런곳에 신고해야겠다
# 1172       카드발급 선택사항으로 변경했다면서 왜 자꾸 발급하라는 메뉴만 나오나요 발급하기싫은데
# 1173    카드 재발급 왜 합니까? 캐시백 사용 설정은 타인 명의 폰 사용자는 못쓰게 하는 겁...
# 1174                    삼성페이도 안되고.. 이 따위로 만들거면 왜 했냐 진짜 ㅡㅡ
# 1175     쓰기 불편해요ㅠ 지난번 앱처럼 만들어주세요ㅠ 불필요한거 다빼고 돈쓴내역 잘보이게요 ㅠㅠ
# 1176                                       대체 앱은 언제 열리나요!
# 1177    꼼수 끝판왕이네요. 기존 카드 연동을 빌미로 자기들 카드 신규 발급 받게해서 결국 ...
# 1178    충전시 연결 계좌가 하나만 등록되는건가요?? 기존에 여러개 등록을 할수있어 편했었는...
# 1179    본인인증 방법을 추가해주세요 본인명의 핸드폰이 아님 가입자체가 안된다니? 뭐 이런 ...
# 1180            안켜져요 ㅠㅠ 계속 오류나서 새로 설치했는데 자꾸 네트워크 오류라고 하네요
# 1181         메인화면 글자크기랑 잔액표시를 kt처럼 한 눈에 알아보고 쉽게 바꾸면 안되나요?
# 1182    진짜너무대박불편합니다ㆍㆍ삼성페이도안돼ㆍㆍ기존편한걸 전부없애고 이게머하는짓인지 모르겠...
# 1183    로그인이 안돼요 로그인해서 가입한 후 카드등록하는데 바코드도 안먹히고 눈 앞에 있는...
# 1184                                                편 리하다
# 1185                                계속해서 기존카드가 없는카드라고 뜬다.
# 1186                             왜 바꿨는지. 전보다 사용하기 넘 불편하네요
# 1187        아놔 열받네 또 발급받으라고? 플라스틱 쓰레기 문제많은거 알지 니들이 일조하는거야
# 1188    폰마다 차이가있는지 제폰에서는 와이파이 아니면 앱에 접속이 거의 안됩니다(A5). ...
# 1189                                          업데이트가 계속 안됨
# 1190           앱실행이 안돼요ㅠㅠ 앱실행이 안돼요 앱을 킬수가없음.. 오류 수정좀해주세요ㅜ
# 1191                                       고객센터 전화안됨..욕나옴
# 1192    앱이 계속 실행이 안되면 어떻게 사용하란 얘긴가요?당장 써야하는데...사용이 잘 안...
# 1193               삼성페이 쓸수 있게 해주세요. 갑자기 잘되던거 왜 못 쓰게 바꿨나요?
# 1194                         보기도 불편하고 삼성페이에는 등록이 또 왜 안되나요
# 1195    갑자기 왜 안들어가지죠 낮에 분명 사용하고 방금 가맹점 카페와서 사용하려고 하는데 ...
# 1196                                    동백전 사용처 검색 빨리해주세요
# 1197    카드 써도 알림이 안옴;;; 설정도 다시 해보고 어풀 깔았다가 재설치도 해봤는데 알...
# 1198          새마을금고 없어 카드발급 안돼요 괜히 충전하여 환불 해주세요 사용도 못 하는데
# 1199    너무 불편해요 알림 설정 아무리 해도 절대 안와요\n\n앱 자체도 보기 불편하고 뱅...
# 1200                         최악이네요 세금이중낭비 답변은 메크로 돌리시나...
# 1201    별 한 개도 아깝다. 평점 조작했나. 뭔 4.5야, 캐시백만 아니면 거들떠도 안본다...
# 1202    몇일 전까지 잘 쓰다가 갑자기 네트워크 원활하지않다고 몇일째 접속안되네요!!;; 고...
# 1203        다사용 될수있도록 가능할때 만드세요 ㅡㅡ아니 접속도 안되고 똑바로좀 만드세요 제발
# 1204                     쿠폰주고 cu 매장가면 전카드 버린카드가져오라고함 어이없음
# 1205    동백전 pc페이지에서 신청하는 바람에 해당선불카드가 도착할때까지 카드 사용을 하지 ...
# 1206                                        앱이문제네요 성질돋구네요
# 1207    가맹점 찾기 버튼도 없고 인터페이스 구조가 너무 조잡합니다. 기존 카드 그대로 사용...
# 1208    전에 동백전보다 사용하기 너무 불편합니다. 그냥 전과 똑같이 하면 안되나요? 이벤트...
# 1209    장난치심? 기존카드 쓸 수 있게한다면서 먼 지롤이심? 나는 옛날카드 계속 쓸거고 삼...
# 1210    어지간하면 평 안 쓰는데 왜 이렇게 불편한 업체로 바뀌었는지 모르겠네요. 인터페이스...
# 1211                                        앱이 왜 안깔리나욧???
# 1212    충전금액,캐시백금액 왜 따로 나오는지 엄청 불편. 예전처럼 합계금액이 나오고 캐시백...
# 1213    업데이트가 왜이리 안되나요? 카드를 쓰고싶은데 업데이트가 안되고 앱이 안열려서 못쓰...
# 1214       회원가입하니 있는 이메일이라고 하고 찾을려고하니 없다고 가입해라고 하고 어쩌라는거죠
# 1215                     도대체 어디에 뭐가있는지 알수도없이 .. 별한개도 아깝네요
# 1216    마이너스 없어서 별 1개만 줌 카드신청하고 일주일 만에 받았는데 어플에서 충전이 안...
# 1217    부산 탁상공론의 대표적인 예가 동백전이 될듯 기존카드를 왜 전부다시받아야되는지 이해...
# 1218    동백전 캐시백 사용방식이 너~~~~무 불편해서 쌍욕이 나옵니다. 일단 캐시백 잔액이...
# 1219    전보다 사용이 너무 불편하고 신규 선불카드는 의무적으로 만들어야하는 불편한 진실. ...
# 1220          머 접속이되야하지ㅡ....우짜라는건지 안되요 아예 로딩도안되고 따운됨 ...하
# 1221    진짜 별 하나 주기도 아깝다. 이전카드 쓸 수 있어도 결국은 재발급 받아서 등록절차...
# 1222    개발자 보씨오. 빠른 시일 내에 가맹점 검색 기능을 추가하지 않는다면 나도 내가 어...
# 1223    리뉴얼전이 좋아요 디자인 너무산만하고  내가 얼마큼 페이백 받았는지 확인하고싶은데 ...
# 1224                    느려서 속에서 열불터짐 혜택때문에 쓰지 코나보다 마니 안조음
# 1225    어떻게 씁니까 기존카드랑 다르게 모바일카드번호가 발급되면 어떻게 같이 연동시키나요 ...
# 1226    주유하다가 결제 오류로 다시 결제 했는데 중복으로 결제 되서 취소 했는데도 돈이 안...
# 1227    시차원에서 일부러 사용하기 복잡하게 만들라고 한거아닌지 의심이 들만큼 불편함 뭣보다...
# 1228    잔액 얼마 남았는지도 표시 안 되어서 50만 넘게 사용하니 자동으로 체크카드로 넘어...
# 1229    깔고 위치확인동의 같은 것들 모두 동의 누른다음에 계속 흰화면이 뜨고 한 4~5분 ...
# 1230    충전하기 눈에띄게좀 아니, 내 지갑이라고되어있는버튼찾다가 충전도 못했네요\n차라리 ...
# 1231    삼성페이 기능되게해주세요 기존꺼보다 더 나아지는게 있어야지..실물카드 요즘 누가 들...
# 1232    이거 기존있는거는 왜 지우고, 굳이 신규 운영업자 선정했나요? 이중으로 세금드는거 ...
# 1233                                 접속안됨! 어플실행이...걍 욕나옮!
# 1234    가맹점 찾기 왜있나요? 되는곳도있고 아닌곳이있고. 그게 헷갈려서 찾기 서비스가 있는...
# 1235    이거 확인안되는데 왜이렇죠? 결제안된다고하는데 어플에는 결제한거처럼 나오고 진짜 왜...
# 1236    최소한 기존의 편리한 기능은 따라가야 할거 아니냐? 너희들 대학생들 시켜서 앱 개발...
# 1237    어플이 진짜 구려요 오류나서 접속이 안되고 로그인도 안되고..써야할 때 못쓰면 무슨...
# 1238                                               쓰레기 앱.
# 1239    이전 어플방식이 훨씬 편한데 캐시 이용법이 더 불편한 곳으로 굳이 업체를 바꾸셨네....
# 1240                                         카드신청오류 계속뜨네요
# 1241    진짜 ui부터 편의기능 싹다 최악이네ㅡㅡ 삼성페이등록도 안돼 바코드결제도 안돼 qr...
# 1242                                             설치가 안됩니다
# 1243    일정 시간 미사용으로 작업이 중단 되었습니다 라고 계속 떠는데 어떻게 하면 되나요....
# 1244    직관성 최악 환불하기도 한참 찾아야하고\n돈옮기기를 계좌이체마냥 혼동하게 만들어둬서...
# 1245                   본인인증이 휴대폰말고 아이핀이나 공인인증도 추가되었음 합니다.
# 1246                                                 쓰레기ㅡ
# 1247                     앱은 설치했으나 ᆞ 네트워크 원활하지 않다고 압접속않됩니다
# 1248                   날짜검색이라던지 총 사용금액에 대한 조회가 좀 불편합니다...
# 1249    삼성페이도 안돼, 앱카드도 안돼, 바코드 큐알 결제도 안돼, 이건뭐 무조건 실물카드...
# 1250                 앱 실행이 안됩니다. 네트워크 상태를 확인하라는 매세지만 뜨네요.
# 1251    강제 신규발급은 이상하네요. 신규발급을 하지않으면 앱자체를 쓸수 없게 만든건 누구의...
# 1252    다른건 다그렇다쳐도 삼성페이 안되게 해놓은거는 너무 불편하네요. 삼성페이로 결제많이...
# 1253    캐시백 재원부족이라더니...업데이트를 해야 충전 할 수 있는데 수일째 업데이트가 안...
# 1254    알아보기 더 힘들고 대체 이걸 디자인 이라고 한건지.이전처럼 직전 캐쉬 적립 내역....
# 1255                 긴급 점검이 왜이리 많습니까? 결제할라다가 못한게 몇 번인지...
# 1256    왜 계속 네트워크가 연결이 안된다고 하는지ᆢ와이파이도 무선도 다 해봤어요 고객센터는...
# 1257    선불카드 정리하면 삼성페이 등록이 안되고 실물카드 없거나 잔액 없으면 결제가 당연히...
# 1258    이용하기 더 불편하게 만들꺼면 전 운용사가 더 돈을 많이 받아서 바꾼건가 싶음 바코...
# 1259                                     하루종일 앱이 실행이 안되요~
# 1260    기존카드가 있어서 그대로 쓸려고하는데 카드번호 월/년 cvc 똑같이 몇번을 시도 계...
# 1261                                급하게 만든거 엄청티나네 안정성 엉망임
# 1262    동백전 앱 들어갈려면 꼭...세,네번만에...들어감....프로그램 개발을 어떻게 한...
# 1263    이번달만 오류가 몇번인지..ㅡㅡ 하 이렇게 오류가 많이 나는데 어찌 쓰란말인가요? ...
# 1264    동백전 앱 개선부탁드립니다 잔액이 초기화면에서 보이지 않는 점이 가장 불편하고 이전...
# 1265                                            거지같은 앱 ㅜㅜ
# 1266    충전했는데 오류 뜨더니 돈은 빠져나갔는데 왜 충전은 안되있죠 (다행히 문의전화 걸어...
# 1267               이런 인터페이스는 내가 그림판으로 만들어도 10배는 잘만들 자신있다.
# 1268    발급 한 달도 지나지 않았는데 1. 시스템 장애로 결제 불가에 2. 앱 오류로 충전...
# 1269    앱 설치후 화원가입시 기존 동백전 카드 이관 및 잔액이관이 가능하다 해 놓고 실제 ...
# 1270        쓰레기어플임 하나도 제대로되는게없음 문제해결안되,상담사 연결안되 어떻해 쓰라는거냐
# 1271                                                이게머요?
# 1272                                  기존 카드 사용불가, 재발급 필수.
# 1273    5G, Lte, Wifi 전부 데이터 연결 상태가 안좋다고 실행이 안됩니다. 실행이...
# 1274           어플실행시 오류. 오늘카드받아쓸려했더니 바로어플접속 먹통 이래가 뭐하겠나요?
# 1275                 지금 가맹점찾기 저만 안되는 건가요?? 앱에 오류가 너무 많아요ㅠ
# 1276    리뷰댓글에 복사붙여넣기 좀 하지마라 사람들 홧딱지나서 귀찮은거감수하고 심사숙고해서 ...
# 1277    접속이 되야 충전을 하든 뭘하지... 제발 접속 좀 하게 해주세요! LTE wifi...
# 1278    ㅜㅜ 예전 앱이 훨씬 직관적이고 편해요....이용할때마다 포인트 쌓이는거 바로바로 ...
# 1279                                          구동백전을 돌려달라!
# 1280            왜 연계 사용이 안되나요? 코나아이로 자동 연결되게 해야 되는거 아닌가요?
# 1281    왜 카드를 새로 발급 받아야 하나요? 기존 카드 그대로 사용된다고 하지 않았나요? ...
# 1282         아예오류나고안들어가져요 오류나고 아예안들어가지는데 어떻게요? 서버없다고만 뜨고요
# 1283    예전어플이 훨 쓰기편해서 지금어플이랑 너무비교됨. 별 쓸데없는 메뉴랑 소개글만 많고...
# 1284                                         왜 로그인이 안되나요?
# 1285    뭣같이 만들어 놓고선~ 지네들 직원끼리 별다섯게 주고 기대가 된다느니 오만 조작질 ...
# 1286    제발 총 받은 혜택 없에주세요. 총 받은 혜택 하나도 안궁금해요... 총 받은 혜택...
# 1287                                      동백전 어플 다운이 안됩니다
# 1288    인터페이스 접근성 최악.. 화면이 너무너무 정신없어요\n핵심기능만 있으면 됐지 왜 ...
# 1289                            이관할려면 카드신규발급을 강제하는 쓰레기 업체
# 1290                  네트워크 오류라고 하면서 접속이 안되요~ 업데이트 좀 해주세요~
# 1291    가맹점 찾기도 안되고, 기존카드 바로된다고 해서 깔고 이관하고 다했는데 카드신청을 ...
# 1292                                              앱이 안열려요
# 1293                                                 설치안됨
# 1294    이전 어플보다 훨씬 불편합니다 이용내역도 그달에 얼마 썼는지 각각내역은 나와도 전체...
# 1295                                  왜 자꾸 다운로드대기중인가요..ㅜㅜ
# 1296    현재 시각 1시간째 먹통이네요ㅡㅡ 식구들이랑 외식하고 동백전으로 계산할려니 앱도 안...
# 1297    카드취소후 동백전금액이 회복이 안되어 문의할래도 하루종일 전화연결은 안되고 지난번 ...
# 1298    지난 주 잘못눌려 틸퇴처리가 되어서 고객센터와 통화했고 7영업일 지나면 재가입된다고...
# 1299                                 접속 겁나 안됨..ㅡㅡ 뭐하는건지 ㅋ
# 1300    캐시포인트 사용을 이렇게 만들어 놓으면 불편해서 사용하겠습니까? 전에는 캐시포인트 ...
# 1301                       삼성페이가 안된다라.... 불편해서 동백전 절대 안쓸듯
# 1302                                             안 열러요 ㅜㅜ
# 1303       첫날이라 그런지 고객센타는 연결도 안되고 앱도 사용불편 예전께 쓰기 쉬웠던거 같아요
# 1304    넘 불편 ㅠㅠ ㅡ매번 비번 입력해야 들어가짐\nㅡ멀쩡한 카드 두고 새카드 발급신청유...
# 1305                              걸제불가능한 곳에 대한 정보 제공이 필요함
# 1306                             지금 카드사용 불가네요 통신오류 뜹니다 ㅜㅜ
# 1307                                     카드신청에서 자꾸 오류가뜨네요
# 1308                                            업데이트가 안되요
# 1309                                                  불편함
# 1310                                           니들 도대체 뭐하냐
# 1311             카드 등록을 하는데 자꾸 카드정보를 찾을 수 없다고 나오네요 허허....
# 1312                                                너무 불편
# 1313    팝업창 아랫부분 닫기인지 다시보지않기 인지 선택하는 창이 화면에 잘려서 누를수가 없...
# 1314    하나카드사에서 기존카드 쓸수있다고 했는데 왜 카드발급 유도 하시는 거죠?? 불편합니...
# 1315                   서버 다운인 상황에 결제가 안될때 난감한경우가 제법 있습니다.
# 1316    불편해요 기존 앱에서는 한도가 얼마 남았고 얼마 더 충전할수 잇는지 명확하게 나와서...
# 1317    이전 어플이 훨씬 사용하기 용이하고 한눈에 정보 파악하기 좋았음. 업체 바뀌면서 개...
# 1318                  사용하기도전에 댓글보고ㅠ안씀.. 이게 부산시가ㅜ노리는건가....
# 1319    접속하면 계속 네트워크상 오류가 있다며 어제부터 접속이 안돼요. 앱 삭제후 다시 깔...
# 1320                                        꼭 몇번 클릭해야 연결됨
# 1321                                    네트워크 연결이 안된다고 합니다
# 1322    기존카드를 그냥 사용할 수 있다고 해놓고 회원가입하면 바로 카드 신청하라고 뜨고 다...
# 1323                그지같에 그냥 그대로하지 설명이너무부족하고 선불카드은뭐고 서비스구려
# 1324    문제가 많네요 50만원 충전했다가 충전취소하고 다시 충전하려고 했더니 충전이 안되는...
# 1325                            안들어가져요 먹통입니다..다시 설치해도 그래요
# 1326    이전보다 훨 불편해짐..ui 누가 만든건지 참..글고 충전은 무슨 한도가 왤케높게함...
# 1327                          카드발급받기싫다고 아 부산 개색들 제대로하는게없노
# 1328                         충전도 안되면서 어떻게 쓰라는거야? 충전오류 미친ㅋ
# 1329           업데이트도 무슨 잘안돼는 쓰레기같은앱 국민청원하던가 해야지 이건비리있다 진짜
# 1330    신규 선불카드를 의무적으로 발급시켜 기존 체크카드가 사용하지 못한다는 인식을 줍니다...
# 1331                                     신규카드 발급시 삼성페이 불가
# 1332    제 폰이 이상한건 가요ㅜ 데이터로는 동백전이 안들어가지고 돈 충전도 안됩니다 길에서...
# 1333    저기.... 문제가 좀 많아야죠 1. 잔액이 카드사용 후에도 변경되지 않음 2. 이...
# 1334    쓰기 개불편함 원래 리뷰잘 안적는데.. 짜증나서 적으러옴\n디자인이랑 기획 누가햇는...
# 1335    동백전 카드는 잘사용하고 있는데요 앱은 왜 이따위로 만들었나요? 와이파이에서만 접속...
# 1336    너무 불편해졌어요. 많은 분들의 의견과 동일한 내용들이지만, 몇 달이 지났는데도 개...
# 1337    형편없네요 삼성페이는 물론 캐쉬사용도 앱에서 사용누르고 10분이내에 실물카드로 결제...
# 1338    기존카드 사용된다더니 신규발급화면으로 직행해서 무조건 발급! 왜 다른거 아무거도 안...
# 1339     써야돠는데 왜안되냐고요...자주이라네요정말... 오늘쓸려고있었는데 안되면혜택도안되고뭐죠
# 1340    다른앱은 잘되는데 동백전은 도대체 와이파이로도 데이터네트워크로도 네트워크 상태가 고...
# 1341                         업데이트가 안되네요 엡 관리가 너무 안되는거 같네요
# 1342                                                 편하네요
# 1343    갑자기 4월 10일(금) 점심시간때부터 "네트워크상태가 원활하지 않습니다. 연결상태...
# 1344                                  평가가 아깝다 내 개인정보 삭제해라
# 1345    업체 바뀌면서 불편해졌습니다 Qr코드 결제는 어디서 하고 가맹점 확인은 어디서 하는...
# 1346                                        계속 오류가 떠요..ㅜㅜ
# 1347    카드신청안됨 다 하고 마지막에 계속 오류가 나요ㅠ 청구서 수령관련 등록을 해야된다는...
# 1348    가맹점 조회 기능 만들어주세요. 가맹점 검색 후 지도를 볼 수 있게 만들어주세요. ...
# Name: REVIEW, dtype: object

# %% [markdown]
# #### tf-idf 활용한 빈도 분석

# %%
total_tokens = [token for mag in corpus for token in str(mag).split()]

print('띄어쓰기 기준으로 나누어봤을 때의 단어(토큰)의 개수:', len(total_tokens), '개')
# Out:
# 띄어쓰기 기준으로 나누어봤을 때의 단어(토큰)의 개수: 22494 개

# %%
total_tokens[:10]
# Out:
# ['앱', '시작하면', '악성코드가', '발견되었다면서', '창이', '뜨는데', '이거', '해킹당한거', '아닌가요?', '불안해서']

# %% [markdown]
# 단순 빈도분석

# %% [raw]
# text = nltk.Text(total_tokens, name='NSMC')
#
# print('단순 빈도분석 시 총 token 수:', len(set(text.tokens)), '개')

# %% [raw]
# word_count = pd.DataFrame(text.vocab().most_common(50)) # 상위 빈도 50위에 해당하는 단어들 저장
# word_count.columns = ['단어', '빈도'] # dataframe으로 정리해서 보기
#
# word_count.head(20) # 상위 빈도 20위에 해당하는 것들만 보기

# %%
tfidf = TfidfVectorizer(max_features=1000)
tdm = tfidf.fit_transform(corpus)

# %%
word_count = pd.DataFrame({'단어': tfidf.get_feature_names(), 
                           '빈도': tdm.sum(axis=0).flat})

# %%
word_count.sort_values('빈도', ascending=False).head(20)
# Out:
#         단어         빈도
# 886     카드  32.654489
# 157     너무  31.493430
# 194    동백전  29.498596
# 847     진짜  29.121921
# 544    안되고  25.016353
# 81      계속  24.625008
# 598     앱이  24.326419
# 176     다시  19.822712
# 606    어떻게  17.891761
# 809    접속이  17.279415
# 547   안되네요  17.059528
# 561   안됩니다  17.054177
# 618     어플  16.905427
# 125     기존  16.143251
# 639  업데이트가  16.131746
# 162   네트워크  15.211731
# 898    캐시백  14.803553
# 559     안됨  14.008800
# 96      그냥  13.979305
# 719     이전  13.752241

# %% [markdown]
# > TF-IDF으로 단어에 가중치 주었을 때의 결과가 달라짐을 알 수 있다.
#
# 참고: https://hanawithdata.tistory.com/entry/%ED%85%8D%EC%8A%A4%ED%8A%B8%EB%B6%84%EC%84%9D-%EB%8B%A8%EC%96%B4%EB%B9%88%EB%8F%84%EC%9D%98-%EA%B0%80%EC%A4%91%EC%B9%98-TF-IDF

# %% [markdown]
# __리뷰별로 리스트화__
#
# [리뷰1], [리뷰2],…[리뷰3] 형태의 데이터 구조
#
# 추후 topic modeling 시에 리뷰 단위로 문서를 나누고 해당 리뷰의 의미를 찾아내기 위해 리스트로 분리해서 나눠줘야 하기 때문.

# %%
corpus_list = list(corpus)
corpus_list[0:3]
# Out:
# ['앱 시작하면 악성코드가 발견되었다면서 창이 뜨는데 이거 해킹당한거 아닌가요? 불안해서 앱을 못열겠고 이미 내 폰에 악성코드가 심어진거 아닌지 불안합니다',
#  '아니 와이파이 네 칸 풀로뜨고 유튜브 등등 빠르게 잘되는데 왜 이 앱만들어거면 네트워크 연결이 안된다고 뜰까요..가입한 이후로 한번도 켜지지않아 카드 신청도 못하고 있습니다. 연결문제 좀 해결해주세요.',
#  '문제가 너무 많네요 몇개월이 지났는데 사용내역 알림이 왜 아직까지 안오는지 그게 뭐라고 아직 개선이 안되는지 이해가 안갑니다. \n게다가 이전 동백전앱은 가맹점 정보 조회가 쉽고 정확했는데 바뀐 동백전은 가맹점이 늘어난 것은 좋은데 조회하면 안나오네요?\n예를 들어 맥도날드 부산시청점은 이전 동백전으로는 결제가 안됐는데 어제 남편이 결제하는 걸 보니 올해는 동백전 결제가 가능하더라구요. 남편말로는 전에 안되던 곳들도 결제 가능하게 된 가맹점이 많다고 하길래 확인해보려고 검색하니 맥도날드 부산시청점은 결제가능함에도 불구하고 안나옵니다.\n\n또한 이전 동백전 앱은 가맹점 검색이 어플내에서 가능했는데 현 동백전앱은 인터넷창에 열리고 검색하는 것도 전에 비해 불편하네요\n\n가능하기만 이전 앱을 사용하고 싶을 정도입니다.\n\n사용내역 알림이라도 좀 빨리 고쳐주세요.\n이게 몇달째 이러는지 정말 이해안되네요']

# %% [markdown]
# #### 불용어 처리
#
# - 좋아요(어근 추출 시에는 '좋다'로 추출 가능하고 명사 추출 시에는 어차피 삭제되니까)는 뺐음
# - 동백전,어플, 진짜, 그냥, 정말, 아주, 하니, 건가, 이면.... 등등 단어 추가했음
# - korean_stopwords.csv 파일도 괜찮아보임. 지금 쓰고있는 txt 파일이 문어체스러워서? 출처는 https://blog.naver.com/yk02061/222262810714

# %%
def define_stopwords(path):
    
    # 방법 1: 직접 리스트에 단어 추가 
    #SW = set()
    #SW.add("동백전")
    #SW.add("앱")
    #SW.add("어플")
    
    # 방법 2: 미리 작성한 txt 파일 불러오기 
    SW = list(set())
    with open(path, encoding='cp949') as f:
        for word in f:
            SW.append(word.rstrip())

    return SW

# %%
SW = define_stopwords('stopwords-ko.txt')

# %%
SW
# Out:
# ['아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를 들면',
#  '예를 들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수 없다',
#  '해서는 안된다',
#  '뿐만 아니라',
#  '만이 아니다',
#  '만은 아니다',
#  '막론하고',
#  '관계없이',
#  '그치지 않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지 않다',
#  '따지지 않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만 못하다',
#  '하는 편이 낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이 외에',
#  '이 밖에',
#  '하여야',
#  '비로소',
#  '한다면 몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할 생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게 함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
#  '할수있다',
#  '할수있어',
#  '임에 틀림없다',
#  '한다면',
#  '등',
#  '등등',
#  '제',
#  '겨우',
#  '단지',
#  '다만',
#  '할뿐',
#  '딩동',
#  '댕그',
#  '대해서',
#  '대하여',
#  '대하면',
#  '훨씬',
#  '얼마나',
#  '얼마만큼',
#  '얼마큼',
#  '남짓',
#  '여',
#  '얼마간',
#  '약간',
#  '다소',
#  '좀',
#  '조금',
#  '다수',
#  '몇',
#  '얼마',
#  '지만',
#  '하물며',
#  '또한',
#  '그러나',
#  '그렇지만',
#  '하지만',
#  '이외에도',
#  '대해 말하자면',
#  '뿐이다',
#  '다음에',
#  '반대로',
#  '반대로 말하자면',
#  '이와 반대로',
#  '바꾸어서 말하면',
#  '바꾸어서 한다면',
#  '만약',
#  '그렇지않으면',
#  '까악',
#  '툭',
#  '딱',
#  '삐걱거리다',
#  '보드득',
#  '비걱거리다',
#  '꽈당',
#  '응당',
#  '해야한다',
#  '에 가서',
#  '각',
#  '각각',
#  '여러분',
#  '각종',
#  '각자',
#  '제각기',
#  '하도록하다',
#  '와',
#  '과',
#  '그러므로',
#  '그래서',
#  '고로',
#  '한 까닭에',
#  '하기 때문에',
#  '거니와',
#  '이지만',
#  '대하여',
#  '관하여',
#  '관한',
#  '과연',
#  '실로',
#  '아니나다를가',
#  '생각한대로',
#  '진짜로',
#  '한적이있다',
#  '하곤하였다',
#  '하',
#  '하하',
#  '허허',
#  '아하',
#  '거바',
#  '와',
#  '오',
#  '왜',
#  '어째서',
#  '무엇때문에',
#  '어찌',
#  '하겠는가',
#  '무슨',
#  '어디',
#  '어느곳',
#  '더군다나',
#  '하물며',
#  '더욱이는',
#  '어느때',
#  '언제',
#  '야',
#  '이봐',
#  '어이',
#  '여보시오',
#  '흐흐',
#  '흥',
#  '휴',
#  '헉헉',
#  '헐떡헐떡',
#  '영차',
#  '여차',
#  '어기여차',
#  '끙끙',
#  '아야',
#  '앗',
#  '아야',
#  '콸콸',
#  '졸졸',
#  '좍좍',
#  '뚝뚝',
#  '주룩주룩',
#  '솨',
#  '우르르',
#  '그래도',
#  '또',
#  '그리고',
#  '바꾸어말하면',
#  '바꾸어말하자면',
#  '혹은',
#  '혹시',
#  '답다',
#  '및',
#  '그에 따르는',
#  '때가 되어',
#  '즉',
#  '지든지',
#  '설령',
#  '가령',
#  '하더라도',
#  '할지라도',
#  '일지라도',
#  '지든지',
#  '몇',
#  '거의',
#  '하마터면',
#  '인젠',
#  '이젠',
#  '된바에야',
#  '된이상',
#  '만큼어찌됏든',
#  '그위에',
#  '게다가',
#  '점에서 보아',
#  '비추어 보아',
#  '고려하면',
#  '하게될것이다',
#  '일것이다',
#  '비교적',
#  '좀',
#  '보다더',
#  '비하면',
#  '시키다',
#  '하게하다',
#  '할만하다',
#  '의해서',
#  '연이서',
#  '이어서',
#  '잇따라',
#  '뒤따라',
#  '뒤이어',
#  '결국',
#  '의지하여',
#  '기대여',
#  '통하여',
#  '자마자',
#  '더욱더',
#  '불구하고',
#  '얼마든지',
#  '마음대로',
#  '주저하지 않고',
#  '곧',
#  '즉시',
#  '바로',
#  '당장',
#  '하자마자',
#  '밖에 안된다',
#  '하면된다',
#  '그래',
#  '그렇지',
#  '요컨대',
#  '다시 말하자면',
#  '바꿔 말하면',
#  '즉',
#  '구체적으로',
#  '말하자면',
#  '시작하여',
#  '시초에',
#  '이상',
#  '허',
#  '헉',
#  '허걱',
#  '바와같이',
#  '해도좋다',
#  '해도된다',
#  '게다가',
#  '더구나',
#  '하물며',
#  '와르르',
#  '팍',
#  '퍽',
#  '펄렁',
#  '동안',
#  '이래',
#  '하고있었다',
#  '이었다',
#  '에서',
#  '로부터',
#  '까지',
#  '예하면',
#  '했어요',
#  '해요',
#  '함께',
#  '같이',
#  '더불어',
#  '마저',
#  '마저도',
#  '양자',
#  '모두',
#  '습니다',
#  '가까스로',
#  '하려고하다',
#  '즈음하여',
#  '다른',
#  '다른 방면으로',
#  '해봐요',
#  '습니까',
#  '했어요',
#  '말할것도 없고',
#  '무릎쓰고',
#  '개의치않고',
#  '하는것만 못하다',
#  '하는것이 낫다',
#  '매',
#  '매번',
#  '들',
#  '모',
#  '어느것',
#  '어느',
#  '로써',
#  '갖고말하자면',
#  '어디',
#  '어느쪽',
#  '어느것',
#  '어느해',
#  '어느 년도',
#  '라 해도',
#  '언젠가',
#  '어떤것',
#  '어느것',
#  '저기',
#  '저쪽',
#  '저것',
#  '그때',
#  '그럼',
#  '그러면',
#  '요만한걸',
#  '그래',
#  '그때',
#  '저것만큼',
#  '그저',
#  '이르기까지',
#  '할 줄 안다',
#  '할 힘이 있다',
#  '너',
#  '너희',
#  '당신',
#  '어찌',
#  '설마',
#  '차라리',
#  '할지언정',
#  '할지라도',
#  '할망정',
#  '할지언정',
#  '구토하다',
#  '게우다',
#  '토하다',
#  '메쓰겁다',
#  '옆사람',
#  '퉤',
#  '쳇',
#  '의거하여',
#  '근거하여',
#  '의해',
#  '따라',
#  '힘입어',
#  '그',
#  '다음',
#  '버금',
#  '두번째로',
#  '기타',
#  '첫번째로',
#  '나머지는',
#  '그중에서',
#  '견지에서',
#  '형식으로 쓰여',
#  '입장에서',
#  '위해서',
#  '단지',
#  '의해되다',
#  '하도록시키다',
#  '뿐만아니라',
#  '반대로',
#  '전후',
#  '전자',
#  '앞의것',
#  '잠시',
#  '잠깐',
#  '하면서',
#  '그렇지만',
#  '다음에',
#  '그러한즉',
#  '그런즉',
#  '남들',
#  '아무거나',
#  '어찌하든지',
#  '같다',
#  '비슷하다',
#  '예컨대',
#  '이럴정도로',
#  '어떻게',
#  '만약',
#  '만일',
#  '위에서 서술한바와같이',
#  '인 듯하다',
#  '하지 않는다면',
#  '만약에',
#  '무엇',
#  '무슨',
#  '어느',
#  '어떤',
#  '아래윗',
#  '조차',
#  '한데',
#  '그럼에도 불구하고',
#  '여전히',
#  '심지어',
#  '까지도',
#  '조차도',
#  '하지 않도록',
#  '않기 위하여',
#  '때',
#  '시각',
#  '무렵',
#  '시간',
#  '동안',
#  '어때',
#  '어떠한',
#  '하여금',
#  '네',
#  '예',
#  '우선',
#  '누구',
#  '누가 알겠는가',
#  '아무도',
#  '줄은모른다',
#  '줄은 몰랏다',
#  '하는 김에',
#  '겸사겸사',
#  '하는바',
#  '그런 까닭에',
#  '한 이유는',
#  '그러니',
#  '그러니까',
#  '때문에',
#  '그',
#  '너희',
#  '그들',
#  '너희들',
#  '타인',
#  '것',
#  '것들',
#  '너',
#  '위하여',
#  '공동으로',
#  '동시에',
#  '하기 위하여',
#  '어찌하여',
#  '무엇때문에',
#  '붕붕',
#  '윙윙',
#  '나',
#  '우리',
#  '엉엉',
#  '휘익',
#  '윙윙',
#  '오호',
#  '아하',
#  '어쨋든',
#  '만 못하다하기보다는',
#  '차라리',
#  '하는 편이 낫다',
#  '흐흐',
#  '놀라다',
#  '상대적으로 말하자면',
#  '마치',
#  '아니라면',
#  '쉿',
#  '그렇지 않으면',
#  '그렇지 않다면',
#  '안 그러면',
#  '아니었다면',
#  '하든지',
#  '아니면',
#  '이라면',
#  '좋아',
#  '알았어',
#  '하는것도',
#  '그만이다',
#  '어쩔수 없다',
#  '하나',
#  '일',
#  '일반적으로',
#  '일단',
#  '한켠으로는',
#  '오자마자',
#  '이렇게되면',
#  '이와같다면',
#  '전부',
#  '한마디',
#  '한항목',
#  '근거로',
#  '하기에',
#  '아울러',
#  '하지 않도록',
#  '않기 위해서',
#  '이르기까지',
#  '이 되다',
#  '로 인하여',
#  '까닭으로',
#  '이유만으로',
#  '이로 인하여',
#  '그래서',
#  '이 때문에',
#  '그러므로',
#  '그런 까닭에',
#  '알 수 있다',
#  '결론을 낼 수 있다',
#  '으로 인하여',
#  '있다',
#  '어떤것',
#  '관계가 있다',
#  '관련이 있다',
#  '연관되다',
#  '어떤것들',
#  '에 대해',
#  '이리하여',
#  '그리하여',
#  '여부',
#  '하기보다는',
#  '하느니',
#  '하면 할수록',
#  '운운',
#  '이러이러하다',
#  '하구나',
#  '하도다',
#  '다시말하면',
#  '다음으로',
#  '에 있다',
#  '에 달려 있다',
#  '우리',
#  '우리들',
#  '오히려',
#  '하기는한데',
#  '어떻게',
#  '어떻해',
#  '어찌됏어',
#  '어때',
#  '어째서',
#  '본대로',
#  '자',
#  '이',
#  '이쪽',
#  '여기',
#  '이것',
#  '이번',
#  '이렇게말하자면',
#  '이런',
#  '이러한',
#  '이와 같은',
#  '요만큼',
#  '요만한 것',
#  '얼마 안 되는 것',
#  '이만큼',
#  '이 정도의',
#  '이렇게 많은 것',
#  '이와 같다',
#  '이때',
#  '이렇구나',
#  '것과 같이',
#  '끼익',
#  '삐걱',
#  '따위',
#  '와 같은 사람들',
#  '부류의 사람들',
#  '왜냐하면',
#  '중의하나',
#  '오직',
#  '오로지',
#  '에 한하다',
#  '하기만 하면',
#  '도착하다',
#  '까지 미치다',
#  '도달하다',
#  '정도에 이르다',
#  '할 지경이다',
#  '결과에 이르다',
#  '관해서는',
#  '여러분',
#  '하고 있다',
#  '한 후',
#  '혼자',
#  '자기',
#  '자기집',
#  '자신',
#  '우에 종합한것과같이',
#  '총적으로 보면',
#  '총적으로 말하면',
#  '총적으로',
#  '대로 하다',
#  '으로서',
#  '참',
#  '그만이다',
#  '할 따름이다',
#  '쿵',
#  '탕탕',
#  '쾅쾅',
#  '둥둥',
#  '봐',
#  '봐라',
#  '아이야',
#  '아니',
#  '와아',
#  '응',
#  '아이',
#  '참나',
#  '년',
#  '월',
#  '일',
#  '령',
#  '영',
#  '일',
#  '이',
#  '삼',
#  '사',
#  '오',
#  '육',
#  '륙',
#  '칠',
#  '팔',
#  '구',
#  '이천육',
#  '이천칠',
#  '이천팔',
#  '이천구',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '다섯',
#  '여섯',
#  '일곱',
#  '여덟',
#  '아홉',
#  '령',
#  '영',
#  '굿',
#  '잘',
#  '수',
#  '동백전',
#  '앱',
#  '어플',
#  '어플리케이션',
#  '애플리케이션',
#  '하니',
#  '건가',
#  '건가요',
#  '이면',
#  '가요',
#  '곳도',
#  '해도',
#  '어찌',
#  '다해',
#  '처럼',
#  '하니',
#  '된거',
#  '이내',
#  '대한',
#  '가장',
#  '하라',
#  '하라고',
#  '하라니',
#  '되다',
#  '라면',
#  '야하다',
#  '대하',
#  '산사',
#  '일조',
#  '안보',
#  '이고',
#  '때문',
#  '인하다',
#  '려고',
#  '에야',
#  '오류로',
#  '슈레기',
#  '피하',
#  '인데',
#  '인가요',
#  '하고',
#  '이라고',
#  '껀데',
#  '그건',
#  '백전',
#  '이다',
#  '아안',
#  '돼다',
#  '라는',
#  '하다',
#  '동백',
#  '에서는',
#  '개구리',
#  '이세',
#  '수가',
#  '구로',
#  '한수',
#  '년뒤',
#  '오라',
#  '멸렬',
#  '와이프',
#  '할랬더',
#  '글쎄요',
#  '하든',
#  '여요',
#  '였슴',
#  '빵점앱',
#  '로만',
#  '하나요',
#  '뭔가',
#  '두둥',
#  '별루',
#  '이건',
#  '빠꾸먹임',
#  '어딧는',
#  '분뒤',
#  '손바닥',
#  '카드뱌아',
#  '환경부',
#  '돈빼감',
#  '분안',
#  '쉬좀',
#  '이권',
#  '면서',
#  '성도',
#  '업뎃하',
#  '누가',
#  '이집',
#  '해지',
#  '로라',
#  '화가',
#  '성도',
#  '앞전',
#  '전보',
#  '보고',
#  '리도',
#  '유해',
#  '번혼데',
#  '안감',
#  '통해',
#  '나가야',
#  '해기',
#  '성은',
#  '뭐좀',
#  '주기',
#  '애시',
#  '당초',
#  '불금',
#  '뿌던',
#  '기네',
#  '도해',
#  '해놈',
#  '위해',
#  '복진',
#  '쓰기',
#  '띵작',
#  '바꿧는',
#  '미치것',
#  '려면',
#  '인대',
#  '거외',
#  '가지',
#  '생기',
#  '안듭니',
#  '라이',
#  '개쉑이들',
#  '이나',
#  '도안',
#  '은동',
#  '고사기',
#  '치질',
#  '천이',
#  '라이',
#  '반개',
#  '어쩌구',
#  '저쩌구',
#  '거도',
#  '대의',
#  '이드',
#  '대해',
#  '개탄',
#  '기전',
#  '처사',
#  '왜또',
#  '마다',
#  '달이',
#  '위해',
#  '그것',
#  '개도',
#  '리다',
#  '어쩌자',
#  '이얼',
#  '야합',
#  '가입',
#  '나니',
#  '갈랬더',
#  '이군',
#  '햏는',
#  '드릅',
#  '케시백된',
#  '주기도',
#  '귀사',
#  '전도',
#  '거나',
#  '전보',
#  '어디가',
#  '도해',
#  '잘되지',
#  '하노',
#  '엄청스트례스',
#  '이해도',
#  '옥나옮',
#  '점거',
#  '지동',
#  '짱증',
#  '돌기',
#  '이안',
#  '부분환',
#  '불도',
#  '어쩌란말',
#  '리지',
#  '거나',
#  '지아',
#  '고지우',
#  '할랫',
#  '더니',
#  '할랫더',
#  '하래',
#  '환가',
#  '어딧나',
#  '사보',
#  '억이',
#  '이게뭡',
#  '점도',
#  '안나',
#  '누굴위',
#  '이안',
#  '안해',
#  '형탠데',
#  '야합',
#  '바꿧는',
#  '전과',
#  '다카',
#  '조사해',
#  '군데',
#  '네네',
#  '도나',
#  '남아',
#  '법도',
#  '부적',
#  '대로',
#  '가호',
#  '전이',
#  '훨나음',
#  '야기',
#  '정도',
#  '기종은',
#  '실바',
#  '다년',
#  '시대',
#  '안대',
#  '을해',
#  '젠장',
#  '죽겠네',
#  '빵빵',
#  '활활',
#  '바꿈',
#  '더욱이',
#  '주지',
#  '나볼',
#  '자꾸안괴',
#  '나왓는데',
#  '난걸',
#  '리좀',
#  '산가지',
#  '그거',
#  '앱좀',
#  '만듭시',
#  '천은',
#  '그레이드',
#  '구나',
#  '어쩌란말임',
#  '안주',
#  '일이',
#  '는걸',
#  '학벌',
#  '이해도',
#  '전교',
#  '일등',
#  '초딩',
#  '성적',
#  '도하',
#  '왤케높게함',
#  '쓸껀데',
#  '돌리시',
#  '별롭니',
#  '편햇',
#  '라서',
#  '바하',
#  '해놧',
#  '나밍작업',
#  '애러가뜨',
#  '런가',
#  '개색',
#  '모로',
#  '고서',
#  '가짐',
#  '크로마뇽인',
#  '보이',
#  '어쩌',
#  '매우',
#  '거람',
#  '항만',
#  '달도',
#  '인지',
#  '인제',
#  '도록',
#  '이따',
#  '청해',
#  '어도',
#  '오니',
#  '추어',
#  '여서',
#  '안드네',
#  '라서',
#  '어서',
#  '난하',
#  '어도',
#  '매하',
#  '간정',
#  '한시',
#  '만하',
#  '무하',
#  '어가',
#  '지고',
#  '입하',
#  '어가',
#  '해주시',
#  '긴지',
#  '해주',
#  '쓰레',
#  '더라면',
#  '고지',
#  '웠는데',
#  '매우',
#  '가안',
#  '어가',
#  '은어',
#  '중이',
#  '기계로',
#  '치하',
#  '도록',
#  '이지',
#  '라오',
#  '오지',
#  '서도',
#  '무비',
#  '어요',
#  '가안',
#  '어가',
#  '지우',
#  '오하',
#  ...]

# %% [raw]
# # 방법 3: stopword로 지정하고 싶은 단어들을 공백으로 바꿔주기 -- 안 쓰기로 했으나 참고적으로 남겨둠
#
# corpus_sw = []
#
# for i in range(len(corpus_list)) :
#     corpus_sw.append(re.sub('동백전|앱|어플|진짜|그냥|정말|아주|가장|백퍼|그런|무슨|어찌|하고|엇|쯧쯧쯧| \
#                              아니|그러면|아니면|그래서|근데',
#                             ' ', corpus_list[i]))

# %% [markdown]
# #### 사전에 특정 단어 추가
#
# - 하나은행, 안드로이드, 캐쉬백과 같은 단어들이 쪼개지는 걸 방지하기 위함.
# - 방법 1: 직접 사용자 사전 구축
# - 방법 2: customized konlpy의 add_dictionary 기능 사용 (더욱 간편, 패키지의 다른 기능들도 활용 가능)
# - 참고 https://blog.naver.com/yk02061/222262810714 https://inspiringpeople.github.io/data%20analysis/ckonlpy/

# %%
twitter = Twitter()

twitter.add_dictionary('동백전', 'Noun')
twitter.add_dictionary('하나은행', 'Noun')
twitter.add_dictionary('부산은행', 'Noun')
twitter.add_dictionary('안드로이드', 'Noun')
twitter.add_dictionary('아이폰', 'Noun')
twitter.add_dictionary('갤럭시', 'Noun')
twitter.add_dictionary('삼성페이', 'Noun')
twitter.add_dictionary('카카오뱅크', 'Noun')
twitter.add_dictionary('뱅크샐러드', 'Noun')
twitter.add_dictionary('뱅크 샐러드', 'Noun')
twitter.add_dictionary('업데이트', 'Noun')
twitter.add_dictionary('업뎃', 'Noun')
twitter.add_dictionary('업그레이드', 'Noun')
twitter.add_dictionary('캐시백', 'Noun')
twitter.add_dictionary('캐쉬백', 'Noun')
twitter.add_dictionary('페이백', 'Noun')
twitter.add_dictionary('케이티', 'Noun')
twitter.add_dictionary('교통카드', 'Noun')
twitter.add_dictionary('지역화페', 'Noun')
twitter.add_dictionary('지역 화폐', 'Noun')
twitter.add_dictionary('10프로', 'Noun')
twitter.add_dictionary('10 프로', 'Noun')
twitter.add_dictionary('6프로', 'Noun')
twitter.add_dictionary('6 프로', 'Noun')
twitter.add_dictionary('재발급', 'Noun')
twitter.add_dictionary('고객센터', 'Noun')
twitter.add_dictionary('고객 센터', 'Noun')
twitter.add_dictionary('코나아이', 'Noun')
twitter.add_dictionary('본인인증', 'Noun')
twitter.add_dictionary('본인 인증', 'Noun')
twitter.add_dictionary('부산시', 'Noun')
twitter.add_dictionary('부산광역시', 'Noun')
twitter.add_dictionary('인터페이스', 'Noun')
twitter.add_dictionary('오프라인', 'Noun')
twitter.add_dictionary('온라인', 'Noun')
twitter.add_dictionary('회원가입', 'Noun')
twitter.add_dictionary('비번', 'Noun')
twitter.add_dictionary('비밀번호', 'Noun')
twitter.add_dictionary('아이디', 'Noun')
twitter.add_dictionary('전화번호', 'Noun')
twitter.add_dictionary('폰번호', 'Noun')
twitter.add_dictionary('생년월일', 'Noun')
twitter.add_dictionary('폰 번호', 'Noun')
twitter.add_dictionary('홈페이지', 'Noun')
twitter.add_dictionary('가맹점', 'Noun')
twitter.add_dictionary('운영사', 'Noun')
twitter.add_dictionary('소상공인', 'Noun')
twitter.add_dictionary('지원금', 'Noun')
twitter.add_dictionary('로코', 'Noun')
twitter.add_dictionary('이벤트', 'Noun')
twitter.add_dictionary('큐알', 'Noun')
twitter.add_dictionary('큐알코드', 'Noun')
twitter.add_dictionary('큐알 코드', 'Noun')
twitter.add_dictionary('큐알 코드', 'Noun')
twitter.add_dictionary('공지사항', 'Noun')
twitter.add_dictionary('공지 사항', 'Noun')
twitter.add_dictionary('불안정', 'Noun')
twitter.add_dictionary('어수선', 'Noun')
twitter.add_dictionary('번거로움', 'Noun')
twitter.add_dictionary('직관성', 'Noun')
# Out:
# /home/a201843240/.local/lib/python3.6/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
twitter.morphs('부산광역시 지역화폐는 동백전입니다. 운영사는 코나아이입니다')
# Out:
# ['부산광역시', '지역화폐', '는', '동백전', '입니다', '.', '운영사', '는', '코나아이', '입니다']

# %% [markdown]
# __특수문자, 오타, 불필요한 자음, 숫자 등 제거__
#
# - ㅋㅋㅋ와 같은 불필요한 자음
# - '좋아ㅏ요'와 같은 오타 처리
# - 숫자는 제거하지 않음 (10프로, 6프로 등을 남기기 위해)
# - 영어는 남김 (ex: UI, KT와 같은 단어를 지울 수 없어서..)

# %%
def message_cleaning(clean):
    
    # Series의 object를 str로 변경
    clean = [str(corpus_list) for corpus_list in clean]
    
    # 자음 모음만 있는 단어들 제거
    delete1 = re.compile("[ㄱ-ㅎ]*[ㅏ-ㅢ]*")
    clean = [delete1.sub("", corpus_list) for corpus_list in clean]
    
    # 특수문자 제거
    delete2 = re.compile("[\{\}\[\]\/?.,;:'|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]") 
    clean = [delete2.sub("", corpus_list) for corpus_list in clean]
    
    # 숫자 제거
    #delete3 = re.compile('\d+')
    #clean = [delete3.sub("", corpus_list) for corpus_list in clean]
    
    return clean
# Out:
# <>:11: DeprecationWarning: invalid escape sequence \{
# <>:11: DeprecationWarning: invalid escape sequence \{
# <>:11: DeprecationWarning: invalid escape sequence \{
# <ipython-input-20-e6d91e38eff2>:11: DeprecationWarning: invalid escape sequence \{
#   delete2 = re.compile("[\{\}\[\]\/?.,;:'|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]")

# %%
clean_list = message_cleaning(corpus)

clean_list[:3]
# Out:
# ['앱 시작하면 악성코드가 발견되었다면서 창이 뜨는데 이거 해킹당한거 아닌가요 불안해서 앱을 못열겠고 이미 내 폰에 악성코드가 심어진거 아닌지 불안합니다',
#  '아니 와이파이 네 칸 풀로뜨고 유튜브 등등 빠르게 잘되는데 왜 이 앱만들어거면 네트워크 연결이 안된다고 뜰까요가입한 이후로 한번도 켜지지않아 카드 신청도 못하고 있습니다 연결문제 좀 해결해주세요',
#  '문제가 너무 많네요 몇개월이 지났는데 사용내역 알림이 왜 아직까지 안오는지 그게 뭐라고 아직 개선이 안되는지 이해가 안갑니다 \n게다가 이전 동백전앱은 가맹점 정보 조회가 쉽고 정확했는데 바뀐 동백전은 가맹점이 늘어난 것은 좋은데 조회하면 안나오네요\n예를 들어 맥도날드 부산시청점은 이전 동백전으로는 결제가 안됐는데 어제 남편이 결제하는 걸 보니 올해는 동백전 결제가 가능하더라구요 남편말로는 전에 안되던 곳들도 결제 가능하게 된 가맹점이 많다고 하길래 확인해보려고 검색하니 맥도날드 부산시청점은 결제가능함에도 불구하고 안나옵니다\n\n또한 이전 동백전 앱은 가맹점 검색이 어플내에서 가능했는데 현 동백전앱은 인터넷창에 열리고 검색하는 것도 전에 비해 불편하네요\n\n가능하기만 이전 앱을 사용하고 싶을 정도입니다\n\n사용내역 알림이라도 좀 빨리 고쳐주세요\n이게 몇달째 이러는지 정말 이해안되네요']

# %% [markdown]
# #### 필요한 품사만 추출 - 명사
# (okt 트위터 형태소분석기 사용)
#
# okt 설명 https://soyoung-new-challenge.tistory.com/31
#
# 토큰화 관련 https://wikidocs.net/21698

# %% [raw]
# # 어근 추출
#
# def morphs_tokenizer(c):
#
#     okt = Okt() # 따로 다른 변수에 선언해야 함
#
#     morphs = []
#
#     for i in range(len(c)):
#         try:
#             morphs.append(okt.morphs(c[i],
#             stem=True, # 어근 추출 ex. 가던 가도 가지 --> 가다
#             norm=True)) # 정규화 ex. 안냥하세욬ㅋㅋㅋ --> 안녕하세요
#         except Exception as e:
#             continue
#
#     return morphs

# %% [raw]
# morphs = morphs_tokenizer(clean_list)
#
# morphs[:3]

# %%
# 명사만 추출 

def noun_tokenizer(c):
    
    #okt = Okt() # 따로 다른 변수에 선언해야 함

    noun = []

    for i in range(len(c)):
        try:
            noun.append(twitter.nouns(c[i]))
        except Exception as e:
            continue
    
    return noun

# %%
# 명사만 추출 

def noun_tokenizer(c):
    
    okt = Okt() # 따로 다른 변수에 선언해야 함

    noun = []

    for i in range(len(c)):
        try:
            noun.append(okt.nouns(c[i]))
        except Exception as e:
            continue
    
    return noun

# %%
nouns = noun_tokenizer(clean_list)

nouns[:3]
# Out:
# [['앱',
#   '시작',
#   '악성코드',
#   '발견',
#   '면서',
#   '창',
#   '거',
#   '해킹',
#   '당한',
#   '거',
#   '가요',
#   '불안',
#   '앱',
#   '내',
#   '폰',
#   '악성코드',
#   '심',
#   '어진',
#   '거',
#   '닌지',
#   '불안'],
#  ['와이파이',
#   '네',
#   '칸',
#   '풀',
#   '유튜브',
#   '등등',
#   '왜',
#   '이',
#   '앱',
#   '네트워크',
#   '연결',
#   '요',
#   '가입',
#   '이후',
#   '한번',
#   '켜',
#   '지지',
#   '카드',
#   '신청',
#   '못',
#   '연결',
#   '문제',
#   '좀',
#   '해결',
#   '해주'],
#  ['문제',
#   '몇개',
#   '월',
#   '사용',
#   '역',
#   '알림',
#   '왜',
#   '아직까지',
#   '그게',
#   '뭐',
#   '아직',
#   '개선',
#   '이해',
#   '게다가',
#   '이전',
#   '동백전',
#   '앱',
#   '가맹점',
#   '정보',
#   '조회',
#   '정확',
#   '동백전',
#   '가맹점',
#   '것',
#   '조',
#   '회하',
#   '안나',
#   '예',
#   '맥도날드',
#   '부산시',
#   '청점',
#   '이전',
#   '동백전',
#   '결제',
#   '어제',
#   '남편',
#   '결',
#   '제하',
#   '걸',
#   '올해',
#   '동백전',
#   '결제',
#   '가능',
#   '남편',
#   '말로',
#   '전',
#   '곳',
#   '결제',
#   '가능',
#   '가맹점',
#   '확인',
#   '보',
#   '려고',
#   '검색',
#   '하니',
#   '맥도날드',
#   '부산시',
#   '청점',
#   '결제',
#   '가능',
#   '함',
#   '불구',
#   '안나',
#   '또한',
#   '이전',
#   '동백전',
#   '앱',
#   '가맹점',
#   '검색',
#   '어플',
#   '내',
#   '가능',
#   '현',
#   '동백전',
#   '앱',
#   '인터넷',
#   '창',
#   '검색',
#   '것',
#   '전',
#   '불편',
#   '가능',
#   '기만',
#   '이전',
#   '앱',
#   '사용',
#   '정',
#   '도입',
#   '사용',
#   '역',
#   '알림',
#   '좀',
#   '이',
#   '달',
#   '정말',
#   '이해']]

# %% [markdown]
# #### 불용어 및 한 글자 단어 삭제
#
# - 한 글자 단어들 삭제
# - 불용어에 속하는 단어 삭제

# %%
def delete_stopwords(text):
    morphs_sw = []

    for i in range(len(text)):
        t = []
        for j in range(len(text[i])):
            if len(text[i][j]) > 1 and text[i][j] not in SW: 
                t.append(text[i][j])
        morphs_sw.append(t)
       
    return morphs_sw

# %%
nouns = delete_stopwords(nouns)

nouns[:3]
# Out:
# [['시작', '악성코드', '발견', '해킹', '당한', '불안', '악성코드', '불안'],
#  ['와이파이', '유튜브', '네트워크', '연결', '이후', '한번', '카드', '신청', '연결', '문제', '해결'],
#  ['문제',
#   '몇개',
#   '사용',
#   '알림',
#   '아직까지',
#   '아직',
#   '개선',
#   '이해',
#   '이전',
#   '가맹점',
#   '정보',
#   '조회',
#   '정확',
#   '가맹점',
#   '맥도날드',
#   '부산시',
#   '청점',
#   '이전',
#   '결제',
#   '어제',
#   '남편',
#   '올해',
#   '결제',
#   '가능',
#   '남편',
#   '말로',
#   '결제',
#   '가능',
#   '가맹점',
#   '확인',
#   '검색',
#   '맥도날드',
#   '부산시',
#   '청점',
#   '결제',
#   '가능',
#   '불구',
#   '이전',
#   '가맹점',
#   '검색',
#   '가능',
#   '인터넷',
#   '검색',
#   '불편',
#   '가능',
#   '기만',
#   '이전',
#   '사용',
#   '도입',
#   '사용',
#   '알림',
#   '이해']]

# %% [markdown]
# #### 문서-단어 행렬

# %%
def dic_and_bow(clean_text):
    
    # 데이터를 dictionary 형태로 명사 list 만들기 
    dictionary = corpora.Dictionary(clean_text) 
    
    # 출현빈도가 너무 적은 단어는 제거 
    dictionary.filter_extremes(no_below=5) 
    
    # 명사 형태로 말뭉치 만들기 
    corpus = [dictionary.doc2bow(text) for text in clean_text]
    
    # TF-IDF으로 변환 
    tfidf = models.TfidfModel(corpus)
    corpus_tfidf = tfidf[corpus]
    corpus = corpus_tfidf 
    
    return corpus

# %% [markdown]
# 참고 https://conanmoon.medium.com/%EB%8D%B0%EC%9D%B4%ED%84%B0%EA%B3%BC%ED%95%99-%EC%9C%A0%EB%A7%9D%EC%A3%BC%EC%9D%98-%EB%A7%A4%EC%9D%BC-%EA%B8%80%EC%93%B0%EA%B8%B0-58-8f05f611d783

# %%
corpus = dic_and_bow(nouns)

corpus[0][:3]
# Out:
# [(0, 1.0)]

# %% [markdown]
# #### 최적 Topic 개수 산출
#
# <span style="color:red">coherence 보단 perplexity를 우선적으로 보는 게 좋음</span>
#
#
# __(1) Coherence Model__
#
# Topic이 얼마나 의미론적으로 일관성 있는지 판단.
# 수치가 높을수록 일관성 높음. 0.55 정도면 우수하다고 함.
# Coherence가 너무 높아지면 정보의 양이 줄어들게 되고, coherence가 너무 낮아 정보들이 인관성이 없다면 분석의 의미가 낮아지게 됨.
#
# .3 is bad
#
# .4 is low
#
# .55 is okay
#
# .65 might be as good as it is going to get
#
# .7 is nice
#
# .8 is unlikely and
#
# .9 is probably wrong

# %% [raw]
# # Coherence Model
#
# dictionary = corpora.Dictionary(nouns)
# dictionary.filter_extremes(no_below=5)
#
# coherence_values = []
#
# for i in range(2,51) :
#     ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=i, id2word = dictionary) # 파라미터는 기본으로 설정
#     coherence_model_lda = CoherenceModel(model=ldamodel, texts=nouns, dictionary=dictionary, topn=10)
#     coherence_lda = coherence_model_lda.get_coherence()
#     coherence_values.append(coherence_lda)

# %% [raw]
# x = range(2,51)
# plt.plot(x, coherence_values)
# plt.xlabel("Number of Topics")
# plt.ylabel("Coherence Score")
# plt.show()

# %% [raw]
# max_y = max(coherence_values)
# max_x = x[coherence_values.index(max_y)]
# print('최대 coherence 값: Topic이', max_x, '개일 때', max_y)

# %% [raw]
# __(2) 언어 모델 평가방법 (PPL: Perplexity)__
#
# 확률 모델이 결과를 얼마나 정확하게 예측하는지 나타내는 값.
# 동일 모델 내 파라미터에 따른 성능 평가할 때 사용.
# 선정된 토픽 개수마다 학습시켜 가장 낮은 값을 보이는 구간을 찾아 최적화된 토픽의 개수 선정.
# 수치가 낮을수록 높은 정확도.
# Coherence Score와 함께 고려해야함.

# %% [raw]
# <span style="color:red">train, test set 나누기</span>
#
# - 8:2로 나누는 게 좋다고 함.
# - 80%로 학습한 lda model을 20%의 테스트셋에 적용시켜 수치를 보고, 가장 좋은 토픽의 개수를 찾아 전체 데이터셋에 토픽모델링 적용

# %% [raw]
# len(corpus)

# %% [raw]
# corpus_train = corpus[:1080]
# corpus_test = corpus[1080:]

# %% [raw]
# dictionary = corpora.Dictionary(nouns)
# dictionary.filter_extremes(no_below=5)
#
# perplexity_values=[]
#
# for i in range(2,100) :
#     ldamodel = gensim.models.ldamodel.LdaModel(corpus_train,
#                                                num_topics=i,
#                                                id2word=dictionary,
#                                                alpha="auto", eta="auto")
#
#     perplexity_values.append(ldamodel.log_perplexity(corpus_test))

# %% [raw]
# x = range(2,100)
# plt.plot(x, perplexity_values)
# plt.xlabel("Number of Topics")
# plt.ylabel("Perplexity Score")
# plt.show()

# %% [markdown]
# __LDA 시각화__
#
# adjust your parameters alpha = .1, beta = .01 or .001, random_state = 123

# %%
topics = 8

# %%
dictionary = corpora.Dictionary(nouns)   
dictionary.filter_extremes(no_below=5)

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, 
                                           num_topics=topics, 
                                           alpha="auto", 
                                           eta="auto",
                                           #gamma_threshold=0.9,
                                           id2word=dictionary,
                                           #chunksize=100,
                                           passes=10,
                                           iterations=1000,
                                           random_state=100)

# %% [markdown]
# http://bigdata.emforce.co.kr/index.php/2020072401/ 파라미터 설명
#
# 파이썬에서 alpha 값은 1/k(토픽개수)
#
# beta(β)는 0.01로 지정한다(Lin and He, 2009)
#
# λ = 1 일수록 토픽 별로 가장 자주 등장하는 단어들을 우선적으로 키워드로 선택한다는 의미,
#
# λ = 0 일수록 토픽 간에 차이가 많이 나는 단어를 선택한다는 의미(해당 토픽에서 많이 등장한 단어)

# %%
ldamodel.print_topics(num_words=10)
# Out:
# [(0,
#   '0.037*"설치" + 0.030*"카드" + 0.021*"등록" + 0.018*"입력" + 0.018*"기존" + 0.017*"확인" + 0.017*"다시" + 0.016*"인증" + 0.014*"몇번" + 0.014*"잔액"'),
#  (1,
#   '0.067*"삼성페이" + 0.032*"오류" + 0.029*"연결" + 0.028*"결제" + 0.025*"계좌" + 0.021*"등록" + 0.021*"포인트" + 0.021*"네트워크" + 0.020*"캐시" + 0.020*"불편"'),
#  (2,
#   '0.074*"업데이트" + 0.062*"접속" + 0.041*"실행" + 0.040*"사용" + 0.023*"불편" + 0.021*"데이터" + 0.020*"이전" + 0.019*"알림" + 0.018*"최악" + 0.017*"확인"'),
#  (3,
#   '0.051*"가맹점" + 0.035*"찾기" + 0.031*"캐시백" + 0.027*"불편" + 0.024*"사용" + 0.020*"금액" + 0.019*"이전" + 0.019*"기능" + 0.016*"사용자" + 0.015*"편의"'),
#  (4,
#   '0.051*"번호" + 0.045*"인증" + 0.042*"계속" + 0.039*"짜증" + 0.033*"업뎃" + 0.028*"네트워크" + 0.025*"자꾸" + 0.025*"오류" + 0.018*"자체" + 0.016*"버전"'),
#  (5,
#   '0.050*"충전" + 0.040*"금액" + 0.034*"환불" + 0.025*"적립" + 0.025*"결제" + 0.023*"에러" + 0.022*"사용" + 0.022*"캐시백" + 0.020*"만원" + 0.017*"불가"'),
#  (6,
#   '0.075*"카드" + 0.060*"발급" + 0.033*"기존" + 0.026*"신규" + 0.024*"부산시" + 0.023*"재발급" + 0.022*"신청" + 0.021*"사용" + 0.020*"선불카드" + 0.019*"강제"'),
#  (7,
#   '0.087*"불편" + 0.039*"다운" + 0.026*"하루" + 0.022*"종일" + 0.022*"대기" + 0.018*"인터페이스" + 0.016*"사용" + 0.016*"엉망" + 0.015*"카드" + 0.015*"먹통"')]

# %%
pyLDAvis.enable_notebook()

vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.073839  0.003852       1        1  18.340428
# 2      0.064148 -0.132367       2        1  17.454920
# 6     -0.058070  0.167915       3        1  16.192017
# 3      0.101603  0.041098       4        1  11.560248
# 5      0.150155  0.024396       5        1  11.376726
# 1      0.028165 -0.026141       6        1   9.740654
# 7     -0.088390  0.047378       7        1   8.127557
# 4     -0.123771 -0.126131       8        1   7.207450, topic_info=      Term       Freq      Total Category  logprob  loglift
# 28    업데이트  46.000000  46.000000  Default  30.0000  30.0000
# 162   삼성페이  24.000000  24.000000  Default  29.0000  29.0000
# 16      불편  60.000000  60.000000  Default  28.0000  28.0000
# 47      접속  41.000000  41.000000  Default  27.0000  27.0000
# 122     번호  15.000000  15.000000  Default  26.0000  26.0000
# 81      인증  21.000000  21.000000  Default  25.0000  25.0000
# 11     가맹점  23.000000  23.000000  Default  24.0000  24.0000
# 50      발급  39.000000  39.000000  Default  23.0000  23.0000
# 42      실행  26.000000  26.000000  Default  22.0000  22.0000
# 148     짜증  22.000000  22.000000  Default  21.0000  21.0000
# 128     다운  10.000000  10.000000  Default  20.0000  20.0000
# 134     찾기  13.000000  13.000000  Default  19.0000  19.0000
# 188     설치  25.000000  25.000000  Default  18.0000  18.0000
# 43      충전  38.000000  38.000000  Default  17.0000  17.0000
# 132     환불  13.000000  13.000000  Default  16.0000  16.0000
# 1     네트워크  21.000000  21.000000  Default  15.0000  15.0000
# 32      금액  28.000000  28.000000  Default  14.0000  14.0000
# 29      계속  27.000000  27.000000  Default  13.0000  13.0000
# 263     업뎃   8.000000   8.000000  Default  12.0000  12.0000
# 57     캐시백  24.000000  24.000000  Default  11.0000  11.0000
# 7       카드  73.000000  73.000000  Default  10.0000  10.0000
# 59      계좌  13.000000  13.000000  Default   9.0000   9.0000
# 62      적립   9.000000   9.000000  Default   8.0000   8.0000
# 30      오류  33.000000  33.000000  Default   7.0000   7.0000
# 207     자꾸  12.000000  12.000000  Default   6.0000   6.0000
# 14      결제  32.000000  32.000000  Default   5.0000   5.0000
# 117     하루   7.000000   7.000000  Default   4.0000   4.0000
# 112     에러   8.000000   8.000000  Default   3.0000   3.0000
# 55     재발급  13.000000  13.000000  Default   2.0000   2.0000
# 167    데이터  11.000000  11.000000  Default   1.0000   1.0000
# 224   회원가입   4.596736   5.451363   Topic1  -4.7282   1.5255
# 153    일부러   4.902154   6.210469   Topic1  -4.6639   1.4595
# 280     인식   2.902582   3.681736   Topic1  -5.1880   1.4583
# 220     입력   9.611637  12.322548   Topic1  -3.9906   1.4476
# 188     설치  19.142524  25.030432   Topic1  -3.3017   1.4279
# 138     몇번   7.264437   9.560268   Topic1  -4.2706   1.4214
# 344     평가   3.506749   4.636622   Topic1  -4.9989   1.4168
# 330     완료   2.458559   3.281979   Topic1  -5.3540   1.4072
# 355     이름   2.327776   3.118726   Topic1  -5.4087   1.4036
# 155     편리   2.233662   3.016514   Topic1  -5.4499   1.3956
# 209     문자   6.312696   8.559082   Topic1  -4.4110   1.3916
# 341    운영사   1.976829   2.759285   Topic1  -5.5721   1.3626
# 281     직접   1.944651   2.722360   Topic1  -5.5885   1.3596
# 151     조치   3.714065   5.263741   Topic1  -4.9414   1.3473
# 265     모든   2.124254   3.119254   Topic1  -5.5002   1.3119
# 33      비번   1.635880   2.416159   Topic1  -5.7614   1.3061
# 285    핸드폰   2.391384   3.561373   Topic1  -5.3817   1.2978
# 242    모바일   2.388879   3.619272   Topic1  -5.3827   1.2806
# 35      지갑   2.887563   4.498746   Topic1  -5.1932   1.2527
# 226     단계   1.926031   3.003478   Topic1  -5.5981   1.2518
# 80      변경   3.408816   5.663025   Topic1  -5.0272   1.1885
# 82      처음   5.031808   8.414594   Topic1  -4.6378   1.1819
# 296     실력   1.862251   3.160002   Topic1  -5.6318   1.1673
# 24      정보   6.591579  11.498258   Topic1  -4.3678   1.1397
# 172     연동   4.998274   8.733085   Topic1  -4.6445   1.1380
# 2       문제   7.163983  12.737151   Topic1  -4.2845   1.1206
# 258     여전   1.692713   3.055466   Topic1  -5.7272   1.1055
# 328     교체   1.167418   2.231743   Topic1  -6.0988   1.0481
# 84     도대체   5.371718  10.495690   Topic1  -4.5724   1.0262
# 288     과정   1.249874   2.482874   Topic1  -6.0305   1.0097
# 252     여러   2.576279   5.135542   Topic1  -5.3072   1.0062
# 187     삭제   5.953781  11.986797   Topic1  -4.4695   0.9963
# 140    캐쉬백   4.787954   9.750341   Topic1  -4.6875   0.9849
# 72      등록  10.984679  24.380576   Topic1  -3.8571   0.8988
# 41      다시   8.877784  21.727036   Topic1  -4.0700   0.8011
# 81      인증   8.396634  21.206620   Topic1  -4.1257   0.7696
# 175     화면   6.482370  15.635779   Topic1  -4.3845   0.8156
# 27      확인   9.086488  29.023535   Topic1  -4.0468   0.5347
# 7       카드  15.792148  73.815736   Topic1  -3.4941   0.1540
# 34      잔액   7.251377  22.576595   Topic1  -4.2724   0.5603
# 71      기존   9.404954  34.624559   Topic1  -4.0123   0.3927
# 157     오늘   3.985093   9.291083   Topic1  -4.8710   0.8496
# 59      계좌   4.693041  13.151727   Topic1  -4.7075   0.6656
# 12      개선   5.163132  16.514916   Topic1  -4.6120   0.5333
# 14      결제   6.536076  32.874767   Topic1  -4.3762   0.0807
# 3       신청   5.275816  22.491150   Topic1  -4.5904   0.2461
# 17      사용   7.037013  61.256445   Topic1  -4.3024  -0.4678
# 4       연결   4.460092  23.888357   Topic1  -4.7584   0.0178
# 73      그냥   3.999729  14.641441   Topic1  -4.8673   0.3984
# 42      실행   4.074921  26.917384   Topic1  -4.8487  -0.1919
# 28    업데이트   4.178698  46.543296   Topic1  -4.8236  -0.7143
# 50      발급   4.134098  39.313387   Topic1  -4.8343  -0.5562
# 167    데이터  10.204188  11.671256   Topic2  -3.8813   1.6112
# 156     서버   6.777438   8.072104   Topic2  -4.2905   1.5707
# 202   다운로드   4.606515   5.499536   Topic2  -4.6766   1.5684
# 203     로딩   3.697215   4.674019   Topic2  -4.8965   1.5111
# 19      알림   9.174257  11.665563   Topic2  -3.9877   1.5053
# 28    업데이트  36.366223  46.543296   Topic2  -2.6104   1.4988
# 338    페이백   2.706861   3.499120   Topic2  -5.2083   1.4888
# 233     며칠   4.899522   6.390558   Topic2  -4.6149   1.4799
# 184     할인   2.676171   3.514477   Topic2  -5.2197   1.4730
# 42      실행  20.231320  26.917384   Topic2  -3.1969   1.4600
# 47      접속  30.731355  41.127308   Topic2  -2.7788   1.4542
# 5     와이파이   7.935519  10.654578   Topic2  -4.1327   1.4509
# 298     푸시   2.167131   2.966105   Topic2  -5.4307   1.4317
# 262     관리   7.762365  10.734617   Topic2  -4.1548   1.4214
# 147     저번   3.371620   5.005040   Topic2  -4.9887   1.3505
# 270     상황   3.192796   4.844293   Topic2  -5.0432   1.3286
# 283     상태   5.648364   8.791843   Topic2  -4.4727   1.3031
# 133    로그인   4.873654   7.611179   Topic2  -4.6202   1.2998
# 237   공지사항   1.737021   2.744378   Topic2  -5.6519   1.2882
# 240     아예   4.721926   8.159641   Topic2  -4.6519   1.1986
# 106  안드로이드   2.472838   4.328670   Topic2  -5.2987   1.1857
# 79      방식   2.103089   3.826264   Topic2  -5.4607   1.1471
# 347     예산   1.519934   2.829494   Topic2  -5.7854   1.1241
# 185     이제   2.054615   3.853163   Topic2  -5.4840   1.1167
# 63     적립금   2.536104   4.895225   Topic2  -5.2735   1.0879
# 343     통신   3.238735   6.266766   Topic2  -5.0289   1.0855
# 238     승인   1.584575   3.076982   Topic2  -5.7438   1.0819
# 302    일주일   1.216509   2.410587   Topic2  -6.0081   1.0617
# 9       해결   4.418743   8.841103   Topic2  -4.7182   1.0520
# 126    똑바로   1.830406   3.670428   Topic2  -5.5995   1.0498
# 130     최악   9.080897  18.380876   Topic2  -3.9979   1.0404
# 124     제발   4.340772   8.860229   Topic2  -4.7360   1.0320
# 142     예전   7.260656  15.381361   Topic2  -4.2216   0.9949
# 105     부탁   4.747137  10.174520   Topic2  -4.6465   0.9832
# 17      사용  19.607967  61.256445   Topic2  -3.2282   0.6064
# 158    쓰레기   7.063559  17.874022   Topic2  -4.2491   0.8171
# 21      이전   9.922380  27.767444   Topic2  -3.9093   0.7165
# 148     짜증   7.370677  22.121337   Topic2  -4.2066   0.6465
# 27      확인   8.316026  29.023535   Topic2  -4.0859   0.4956
# 16      불편  11.248030  60.584017   Topic2  -3.7839   0.0617
# 30      오류   7.874277  33.909665   Topic2  -4.1405   0.2854
# 14      결제   7.223357  32.874767   Topic2  -4.2268   0.2302
# 43      충전   7.736826  38.832999   Topic2  -4.1581   0.1323
# 29      계속   6.705055  27.838496   Topic2  -4.3012   0.3220
# 1     네트워크   5.388719  21.350809   Topic2  -4.5198   0.3688
# 10      가능   4.875238  21.701379   Topic2  -4.6199   0.2523
# 7       카드   5.438436  73.815736   Topic2  -4.5106  -0.8625
# 65      강제   8.537735   9.918602   Topic3  -3.9845   1.6707
# 276     낭비   5.186875   6.101473   Topic3  -4.4829   1.6583
# 48     무조건   8.018179   9.621355   Topic3  -4.0473   1.6384
# 279   플라스틱   5.223872   6.277546   Topic3  -4.4757   1.6369
# 55     재발급  10.711595  13.235947   Topic3  -3.7577   1.6090
# 54      유도   3.194063   4.043899   Topic3  -4.9677   1.5847
# 277     세금   4.209472   5.445255   Topic3  -4.6916   1.5632
# 87      비용   2.735942   3.558718   Topic3  -5.1225   1.5577
# 350     강요   2.301742   3.078226   Topic3  -5.2953   1.5300
# 83      내용   4.030471   5.392925   Topic3  -4.7351   1.5294
# 0       시작   1.981111   2.765079   Topic3  -5.4453   1.4872
# 50      발급  27.686651  39.313387   Topic3  -2.8080   1.4700
# 139     설명   6.625805   9.551007   Topic3  -4.2380   1.4550
# 66      사항   4.377287   6.448336   Topic3  -4.6526   1.4333
# 353     절차   1.651424   2.443152   Topic3  -5.6273   1.4290
# 200     신규  11.917284  17.755121   Topic3  -3.6510   1.4220
# 346     자원   1.755541   2.617213   Topic3  -5.5662   1.4213
# 305     관련   1.919942   2.894440   Topic3  -5.4767   1.4102
# 15     부산시  11.020904  16.680870   Topic3  -3.7292   1.4062
# 88      시청   1.465583   2.269141   Topic3  -5.7467   1.3835
# 306     기간   2.096706   3.257665   Topic3  -5.3886   1.3800
# 206     댓글   3.875896   6.058319   Topic3  -4.7742   1.3740
# 198   교통카드   3.269842   5.125246   Topic3  -4.9442   1.3712
# 145     리뷰   6.370416  10.376279   Topic3  -4.2773   1.3328
# 53    선불카드   9.181020  15.159825   Topic3  -3.9118   1.3191
# 215     캐쉬   2.763041   4.572253   Topic3  -5.1127   1.3170
# 64     가독성   2.658542   4.414148   Topic3  -5.1512   1.3136
# 304    공무원   2.708461   4.502526   Topic3  -5.1326   1.3124
# 58      필수   3.227749   5.398017   Topic3  -4.9572   1.3064
# 318    담당자   1.839896   3.110449   Topic3  -5.5193   1.2956
# 7       카드  34.349031  73.815736   Topic3  -2.5924   1.0557
# 71      기존  15.271490  34.624559   Topic3  -3.4030   1.0021
# 3       신청  10.003210  22.491150   Topic3  -3.8261   1.0104
# 22      이해   4.672528   8.807417   Topic3  -4.5873   1.1868
# 158    쓰레기   6.993172  17.874022   Topic3  -4.1840   0.8822
# 269    제대로   4.313103   9.130079   Topic3  -4.6673   1.0707
# 77      혜택   4.513708  10.891128   Topic3  -4.6219   0.9398
# 52      생각   3.835519   9.310999   Topic3  -4.7847   0.9338
# 17      사용   9.610389  61.256445   Topic3  -3.8661  -0.0316
# 146     업체   4.739788  15.044297   Topic3  -4.5730   0.6656
# 130     최악   4.943563  18.380876   Topic3  -4.5309   0.5074
# 251     답변   4.213878  12.589019   Topic3  -4.6906   0.7262
# 72      등록   5.053796  24.380576   Topic3  -4.5088   0.2470
# 16      불편   4.617024  60.584017   Topic3  -4.5992  -0.7536
# 29      계속   3.936570  27.838496   Topic3  -4.7587  -0.1355
# 134     찾기  11.449382  13.200673   Topic4  -3.3541   2.0153
# 174     편의   5.062370   6.075956   Topic4  -4.1702   1.9751
# 273   번거로움   2.751512   3.574965   Topic4  -4.7799   1.8958
# 315     중요   2.157605   2.964778   Topic4  -5.0230   1.8398
# 149     홍보   2.088455   2.890641   Topic4  -5.0556   1.8325
# 26      조회   4.261968   6.019797   Topic4  -4.3423   1.8123
# 11     가맹점  16.605814  23.937578   Topic4  -2.9823   1.7919
# 235     고객   3.711571   6.162988   Topic4  -4.4806   1.6505
# 98      제일   1.955336   3.488867   Topic4  -5.1215   1.5786
# 8       한번   3.729056   6.745753   Topic4  -4.4759   1.5648
# 308     계획   1.476662   2.674754   Topic4  -5.4023   1.5635
# 287   하나카드   1.437151   2.686820   Topic4  -5.4294   1.5319
# 181     광고   3.087814   5.816593   Topic4  -4.6646   1.5243
# 86     마케팅   1.810185   3.419656   Topic4  -5.1986   1.5215
# 311     구려   1.355345   2.701128   Topic4  -5.4880   1.4680
# 178    바코드   3.256579   6.522300   Topic4  -4.6114   1.4630
# 97     사용자   5.213851  10.479854   Topic4  -4.1407   1.4595
# 107     이용   5.002727  10.626955   Topic4  -4.1821   1.4042
# 208     먼저   1.112687   2.412834   Topic4  -5.6853   1.3836
# 100     한눈   2.671539   5.826197   Topic4  -4.8094   1.3779
# 31      굳이   2.818227   6.285801   Topic4  -4.7559   1.3554
# 321     대행   1.089566   2.444535   Topic4  -5.7063   1.3495
# 336    용해도   1.015370   2.291709   Topic4  -5.7768   1.3436
# 232     회사   2.968411   6.806673   Topic4  -4.7040   1.3277
# 316     진심   1.220826   2.800642   Topic4  -5.5925   1.3273
# 309     물어   1.521569   3.493048   Topic4  -5.3723   1.3266
# 348     본적   1.187932   2.745230   Topic4  -5.6198   1.3199
# 57     캐시백  10.263898  24.268548   Topic4  -3.4634   1.2970
# 274     번잡   1.345411   3.209502   Topic4  -5.4953   1.2882
# 94      기능   6.233335  14.981156   Topic4  -3.9621   1.2807
# 229    그대로   2.733245   6.670484   Topic4  -4.7865   1.2654
# 244     간단   2.090592   5.075005   Topic4  -5.0546   1.2707
# 120     문의   4.172749  10.896319   Topic4  -4.3635   1.1977
# 103     지금   3.997783  11.400380   Topic4  -4.4063   1.1097
# 102     방법   3.037086   8.338648   Topic4  -4.6811   1.1476
# 104     취소   3.619565  11.637501   Topic4  -4.5057   0.9897
# 32      금액   6.643880  28.270673   Topic4  -3.8983   0.7095
# 21      이전   6.373155  27.767444   Topic4  -3.9399   0.6858
# 16      불편   8.959802  60.584017   Topic4  -3.5993   0.2463
# 17      사용   8.020542  61.256445   Topic4  -3.7100   0.1245
# 119   고객센터   3.278176  12.279196   Topic4  -4.6047   0.8370
# 34      잔액   3.842060  22.576595   Topic4  -4.4460   0.3867
# 43      충전   4.627005  38.832999   Topic4  -4.2601   0.0302
# 4       연결   3.829509  23.888357   Topic4  -4.4493   0.3269
# 10      가능   3.615383  21.701379   Topic4  -4.5068   0.3654
# 7       카드   4.403785  73.815736   Topic4  -4.3096  -0.6615
# 93      전화   2.862826  12.965450   Topic4  -4.7402   0.6471
# 112     에러   7.284133   8.303478   Topic5  -3.7903   2.0426
# 160    아이폰   4.999557   5.811307   Topic5  -4.1667   2.0231
# 62      적립   8.152192   9.579252   Topic5  -3.6777   2.0123
# 132     환불  10.867602  13.363904   Topic5  -3.3902   1.9668
# 137     만원   6.606143   8.273948   Topic5  -3.8880   1.9485
# 310     통장   2.447713   3.246001   Topic5  -4.8809   1.8913
# 253     입금   2.369690   3.186439   Topic5  -4.9133   1.8775
# 241     계산   3.670555   5.266986   Topic5  -4.4757   1.8125
# 60      알람   3.387567   4.861372   Topic5  -4.5559   1.8124
# 136     기본   3.508426   5.345808   Topic5  -4.5209   1.7525
# 214     소리   2.738206   4.201803   Topic5  -4.7687   1.7454
# 323     나은   2.031132   3.312490   Topic5  -5.0674   1.6845
# 247     종료   2.092624   3.524200   Topic5  -5.0376   1.6524
# 201     한참   1.759024   2.996925   Topic5  -5.2113   1.6408
# 40      현금   1.968116   3.377384   Topic5  -5.0990   1.6336
# 161     표시   3.465015   6.080836   Topic5  -4.5333   1.6112
# 18      아직   5.258438   9.240644   Topic5  -4.1162   1.6098
# 115     대체   3.350067   5.916976   Topic5  -4.5671   1.6048
# 32      금액  12.922768  28.270673   Topic5  -3.2170   1.3908
# 255     한도   2.555927   5.600546   Topic5  -4.8376   1.3892
# 46      불가   5.574131  12.416678   Topic5  -4.0579   1.3727
# 119   고객센터   5.296202  12.279196   Topic5  -4.1090   1.3327
# 103     지금   4.823822  11.400380   Topic5  -4.2025   1.3135
# 93      전화   5.469369  12.965450   Topic5  -4.0769   1.3105
# 43      충전  16.078378  38.832999   Topic5  -2.9986   1.2918
# 120     문의   4.413877  10.896319   Topic5  -4.2913   1.2699
# 297     일부   0.885498   2.230708   Topic5  -5.8976   1.2497
# 290     처리   1.435741   3.845432   Topic5  -5.4144   1.1884
# 99      개발   1.683072   4.767918   Topic5  -5.2554   1.1323
# 337   지역화폐   1.017976   3.069524   Topic5  -5.7582   1.0699
# 246    서비스   2.492674   7.731929   Topic5  -4.8627   1.0416
# 73      그냥   4.569642  14.641441   Topic5  -4.2566   1.0092
# 57     캐시백   7.068196  24.268548   Topic5  -3.8204   0.9400
# 14      결제   8.009878  32.874767   Topic5  -3.6954   0.7616
# 146     업체   4.107456  15.044297   Topic5  -4.3632   0.8754
# 27      확인   5.306558  29.023535   Topic5  -4.1071   0.4744
# 17      사용   7.234476  61.256445   Topic5  -3.7972   0.0374
# 36     포인트   3.454392  12.102953   Topic5  -4.5364   0.9198
# 34      잔액   3.662633  22.576595   Topic5  -4.4779   0.3549
# 16      불편   4.918908  60.584017   Topic5  -4.1829  -0.3373
# 10      가능   3.267652  21.701379   Topic5  -4.5920   0.2803
# 30      오류   3.310308  33.909665   Topic5  -4.5790  -0.1531
# 7       카드   3.210912  73.815736   Topic5  -4.6095  -0.9614
# 162   삼성페이  18.574351  24.677781   Topic6  -2.6990   2.0447
# 131     페이   3.287440   4.902014   Topic6  -4.4307   1.9293
# 313     크기   1.621705   2.568179   Topic6  -5.1373   1.8691
# 204     자주   4.398782   6.981934   Topic6  -4.1394   1.8669
# 301     요즘   3.530524   5.663342   Topic6  -4.3593   1.8563
# 217    갑자기   5.116829   8.636627   Topic6  -3.9882   1.8054
# 300    사업자   2.106567   3.589471   Topic6  -4.8757   1.7959
# 176     캐시   5.623991   9.733348   Topic6  -3.8937   1.7803
# 213     잘못   2.153025   3.881020   Topic6  -4.8539   1.7396
# 59      계좌   6.998230  13.151727   Topic6  -3.6751   1.6980
# 23     인터넷   2.275184   4.309711   Topic6  -4.7987   1.6901
# 248     수준   2.503026   4.811222   Topic6  -4.7033   1.6754
# 38      보기   4.702437   9.062245   Topic6  -4.0727   1.6728
# 96      별로   3.736311   7.305785   Topic6  -4.3027   1.6583
# 319     세상   1.659055   3.276940   Topic6  -5.1145   1.6482
# 239     통화   1.797551   3.712455   Topic6  -5.0343   1.6036
# 197     직관   3.281316   6.857965   Topic6  -4.4325   1.5917
# 218     방금   1.304625   2.753126   Topic6  -5.3549   1.5820
# 36     포인트   5.723441  12.102953   Topic6  -3.8762   1.5800
# 243     국민   1.657830   3.574848   Topic6  -5.1153   1.5604
# 359     의심   1.197309   2.630175   Topic6  -5.4407   1.5419
# 289    어르신   1.526245   3.439026   Topic6  -5.1980   1.5165
# 245    불안정   2.150745   4.920378   Topic6  -4.8550   1.5013
# 216     은행   3.174719   7.708914   Topic6  -4.4656   1.4417
# 39     부모님   1.185355   2.973219   Topic6  -5.4507   1.4093
# 143     머리   1.286603   3.252695   Topic6  -5.3688   1.4014
# 345     구분   1.390252   3.610584   Topic6  -5.2913   1.3745
# 271   코나아이   2.835479   7.383851   Topic6  -4.5786   1.3718
# 196     지역   1.494856   4.029855   Topic6  -5.2187   1.3372
# 303   부산은행   1.109292   3.135008   Topic6  -5.5171   1.2900
# 4       연결   8.052866  23.888357   Topic6  -3.5347   1.2415
# 30      오류   8.911403  33.909665   Topic6  -3.4334   0.9925
# 1     네트워크   5.690853  21.350809   Topic6  -3.8819   1.0066
# 14      결제   7.736258  32.874767   Topic6  -3.5749   0.8821
# 72      등록   5.906370  24.380576   Topic6  -3.8447   0.9111
# 41      다시   4.871494  21.727036   Topic6  -4.0374   0.8337
# 16      불편   5.524894  60.584017   Topic6  -3.9115  -0.0659
# 17      사용   4.845155  61.256445   Topic6  -4.0428  -0.2082
# 7       카드   5.044453  73.815736   Topic6  -4.0025  -0.3544
# 43      충전   3.232269  38.832999   Topic6  -4.4476  -0.1572
# 47      접속   3.099181  41.127308   Topic6  -4.4896  -0.2567
# 158    쓰레기   1.867322  17.874022   Topic6  -4.9963   0.0700
# 21      이전   1.876260  27.767444   Topic6  -4.9915  -0.3657
# 186     대기   5.062166   6.009519   Topic7  -3.8179   2.3384
# 128     다운   9.070371  10.844794   Topic7  -3.2347   2.3312
# 116     종일   5.181713   6.489477   Topic7  -3.7946   2.2849
# 221     옛날   3.294390   4.138418   Topic7  -4.2475   2.2818
# 163     엉망   3.649928   4.798207   Topic7  -4.1450   2.2364
# 117     하루   5.962095   7.952040   Topic7  -3.6543   2.2219
# 111     본인   2.283094   3.106057   Topic7  -4.6142   2.2021
# 317     노답   2.866234   3.966627   Topic7  -4.3867   2.1850
# 333   하나은행   1.933568   2.731837   Topic7  -4.7804   2.1643
# 234     이틀   1.989329   2.944679   Topic7  -4.7519   2.1177
# 118     복잡   2.931944   4.798852   Topic7  -4.3641   2.0172
# 257     매장   1.848879   3.188735   Topic7  -4.8251   1.9649
# 282   본인인증   2.588500   4.532848   Topic7  -4.4886   1.9496
# 260     확실   1.387426   2.555279   Topic7  -5.1123   1.8992
# 295     먹통   3.383274   6.279331   Topic7  -4.2209   1.8915
# 45     휴대폰   2.812261   5.429816   Topic7  -4.4057   1.8520
# 256  인터페이스   4.115680   7.998619   Topic7  -4.0249   1.8454
# 193    불가능   2.504915   4.939807   Topic7  -4.5215   1.8308
# 109     명의   1.994085   3.945295   Topic7  -4.7495   1.8276
# 294    알뜰폰   1.506290   3.000160   Topic7  -5.0301   1.8209
# 180     터치   1.323546   2.803106   Topic7  -5.1594   1.7595
# 339     주소   1.667083   3.585014   Topic7  -4.9286   1.7442
# 89      의무   1.585646   3.554253   Topic7  -4.9787   1.7028
# 101     현재   1.985523   4.508610   Topic7  -4.7538   1.6898
# 25      정확   1.046895   2.426319   Topic7  -5.3939   1.6694
# 303   부산은행   1.351857   3.135008   Topic7  -5.1382   1.6688
# 91      추가   3.150230   7.754719   Topic7  -4.2922   1.6091
# 312     실패   1.886732   4.655643   Topic7  -4.8049   1.6067
# 223     선정   1.299424   3.233914   Topic7  -5.1778   1.5981
# 44      노트   1.291763   3.245263   Topic7  -5.1837   1.5887
# 16      불편  19.977385  60.584017   Topic7  -2.4451   1.4005
# 22      이해   2.831108   8.807417   Topic7  -4.3991   1.3750
# 172     연동   2.220375   8.733085   Topic7  -4.6420   1.1405
# 76      필요   2.344335  11.549615   Topic7  -4.5877   0.9153
# 81      인증   2.820257  21.206620   Topic7  -4.4029   0.4924
# 43      충전   3.274017  38.832999   Topic7  -4.2537   0.0367
# 17      사용   3.719088  61.256445   Topic7  -4.1262  -0.2917
# 28    업데이트   3.164693  46.543296   Topic7  -4.2877  -0.1784
# 7       카드   3.427771  73.815736   Topic7  -4.2078  -0.5598
# 71      기존   2.720523  34.624559   Topic7  -4.4389  -0.0338
# 41      다시   2.428042  21.727036   Topic7  -4.5526   0.3184
# 21      이전   2.467706  27.767444   Topic7  -4.5364   0.0893
# 263     업뎃   6.837538   8.536355   Topic8  -3.3972   2.4081
# 225     기기   2.634992   3.764945   Topic8  -4.3507   2.2732
# 190     선불   1.787943   2.592906   Topic8  -4.7385   2.2583
# 122     번호  10.403501  15.121638   Topic8  -2.9774   2.2561
# 254     초과   2.428966   3.574481   Topic8  -4.4321   2.2437
# 342     버전   3.171378   4.767454   Topic8  -4.1654   2.2224
# 154     초기   2.535709   4.097412   Topic8  -4.3891   2.1502
# 199     당일   1.556462   2.740686   Topic8  -4.8772   2.0643
# 357     검토   1.150839   2.057340   Topic8  -5.1791   2.0491
# 362     동일   1.387632   2.549309   Topic8  -4.9920   2.0218
# 75      원래   2.755946   5.483955   Topic8  -4.3058   1.9420
# 340     바람   1.356911   2.770328   Topic8  -5.0144   1.9163
# 266     문구   1.454907   3.038887   Topic8  -4.9446   1.8935
# 272     기대   1.242907   2.708961   Topic8  -5.1021   1.8509
# 81      인증   9.157157  21.206620   Topic8  -3.1050   1.7903
# 255     한도   2.362940   5.600546   Topic8  -4.4597   1.7671
# 173    직관성   2.115175   5.017523   Topic8  -4.5704   1.7663
# 194     비교   1.741263   4.335488   Topic8  -4.7650   1.7178
# 207     자꾸   5.133351  12.796486   Topic8  -3.6838   1.7166
# 314    일일이   1.317423   3.348137   Topic8  -5.0439   1.6973
# 44      노트   1.271631   3.245263   Topic8  -5.0793   1.6932
# 141     클릭   1.539109   3.929745   Topic8  -4.8884   1.6927
# 267     반복   1.155796   3.010670   Topic8  -5.1748   1.6727
# 70      출금   1.028575   2.690729   Topic8  -5.2914   1.6684
# 148     짜증   7.997715  22.121337   Topic8  -3.2404   1.6127
# 284    통신사   1.093285   3.044589   Topic8  -5.2304   1.6059
# 210    별하나   1.462230   4.148257   Topic8  -4.9396   1.5873
# 275     전송   1.089266   3.374020   Topic8  -5.2341   1.4995
# 332     회원   1.207063   3.741508   Topic8  -5.1314   1.4988
# 67      자체   3.650334  11.373036   Topic8  -4.0248   1.4936
# 29      계속   8.641434  27.838496   Topic8  -3.1630   1.4602
# 1     네트워크   5.755063  21.350809   Topic8  -3.5695   1.3190
# 69    체크카드   2.250428   9.136112   Topic8  -4.5085   1.2289
# 30      오류   5.131249  33.909665   Topic8  -3.6842   0.7417
# 166     느낌   1.429972   4.870855   Topic8  -4.9619   1.4044
# 104     취소   2.030387  11.637501   Topic8  -4.6114   0.8840
# 283     상태   1.787275   8.791843   Topic8  -4.7389   1.0369
# 3       신청   2.280796  22.491150   Topic8  -4.4951   0.3415
# 47      접속   2.577434  41.127308   Topic8  -4.3728  -0.1398
# 188     설치   2.176984  25.030432   Topic8  -4.5416   0.1879
# 16      불편   2.141514  60.584017   Topic8  -4.5581  -0.7125
# 7       카드   2.149200  73.815736   Topic8  -4.5545  -0.9064
# 2       문제   1.511407  12.737151   Topic8  -4.9065   0.4986, token_table=      Topic      Freq   Term
# term
# 10        1  0.184320     가능
# 10        2  0.230400     가능
# 10        3  0.138240     가능
# 10        4  0.184320     가능
# 10        5  0.138240     가능
# 10        6  0.092160     가능
# 10        8  0.046080     가능
# 64        3  0.679633    가독성
# 64        6  0.226544    가독성
# 11        1  0.083551    가맹점
# 11        2  0.125326    가맹점
# 11        4  0.710180    가맹점
# 11        5  0.041775    가맹점
# 11        6  0.041775    가맹점
# 244       4  0.394088     간단
# 244       5  0.197044     간단
# 244       6  0.197044     간단
# 217       2  0.231572    갑자기
# 217       6  0.578930    갑자기
# 350       3  0.649725     강요
# 65        3  0.907386     강제
# 99        1  0.419470     개발
# 99        4  0.209735     개발
# 99        5  0.419470     개발
# 12        1  0.302757     개선
# 12        2  0.242205     개선
# 12        3  0.181654     개선
# 12        4  0.121103     개선
# 12        6  0.060551     개선
# 12        7  0.060551     개선
# 357       8  0.486065     검토
# 14        1  0.212929     결제
# 14        2  0.212929     결제
# 14        3  0.030418     결제
# 14        4  0.030418     결제
# 14        5  0.243348     결제
# 14        6  0.243348     결제
# 241       5  0.759448     계산
# 241       7  0.189862     계산
# 29        1  0.107764     계속
# 29        2  0.251450     계속
# 29        3  0.143686     계속
# 29        4  0.035921     계속
# 29        5  0.035921     계속
# 29        6  0.071843     계속
# 29        7  0.071843     계속
# 29        8  0.323293     계속
# 59        1  0.380178     계좌
# 59        6  0.532249     계좌
# 59        7  0.076036     계좌
# 308       4  0.373866     계획
# 308       5  0.373866     계획
# 235       1  0.162259     고객
# 235       4  0.649036     고객
# 119       2  0.081439   고객센터
# 119       4  0.244316   고객센터
# 119       5  0.407193   고객센터
# 119       6  0.162877   고객센터
# 304       3  0.666293    공무원
# 304       4  0.222098    공무원
# 304       5  0.222098    공무원
# 237       2  0.728762   공지사항
# 288       1  0.402759     과정
# 288       3  0.402759     과정
# 305       3  0.690980     관련
# 262       1  0.186313     관리
# 262       2  0.745253     관리
# 181       2  0.343844     광고
# 181       4  0.515766     광고
# 328       1  0.448080     교체
# 198       1  0.195113   교통카드
# 198       3  0.585338   교통카드
# 311       3  0.370216     구려
# 311       4  0.370216     구려
# 345       1  0.276964     구분
# 345       6  0.276964     구분
# 243       2  0.279732     국민
# 243       6  0.559464     국민
# 31        1  0.159089     굳이
# 31        3  0.318177     굳이
# 31        4  0.477266     굳이
# 31        6  0.159089     굳이
# 73        1  0.273197     그냥
# 73        3  0.204898     그냥
# 73        4  0.136599     그냥
# 73        5  0.341496     그냥
# 73        7  0.068299     그냥
# 229       1  0.149914    그대로
# 229       2  0.149914    그대로
# 229       3  0.149914    그대로
# 229       4  0.449742    그대로
# 229       8  0.149914    그대로
# 32        1  0.106117     금액
# 32        2  0.106117     금액
# 32        3  0.035372     금액
# 32        4  0.247606     금액
# 32        5  0.459840     금액
# 32        6  0.035372     금액
# 306       3  0.613937     기간
# 306       4  0.306968     기간
# 225       8  0.796824     기기
# 94        1  0.133501     기능
# 94        2  0.200252     기능
# 94        4  0.400503     기능
# 94        6  0.066751     기능
# 94        7  0.133501     기능
# 272       5  0.369145     기대
# 272       8  0.369145     기대
# 136       1  0.187062     기본
# 136       4  0.187062     기본
# 136       5  0.748250     기본
# 71        1  0.259931     기존
# 71        2  0.028881     기존
# 71        3  0.433219     기존
# 71        4  0.086644     기존
# 71        5  0.028881     기존
# 71        6  0.057762     기존
# 71        7  0.086644     기존
# 71        8  0.028881     기존
# 323       4  0.301888     나은
# 323       5  0.603775     나은
# 276       3  0.819474     낭비
# 83        1  0.185428     내용
# 83        3  0.741713     내용
# 1         1  0.187347   네트워크
# 1         2  0.234183   네트워크
# 1         6  0.281020   네트워크
# 1         8  0.281020   네트워크
# 317       7  0.756310     노답
# 44        7  0.308141     노트
# 44        8  0.308141     노트
# 166       3  0.205303     느낌
# 166       4  0.410606     느낌
# 166       6  0.205303     느낌
# 166       8  0.205303     느낌
# 41        1  0.414230     다시
# 41        2  0.092051     다시
# 41        3  0.046026     다시
# 41        4  0.046026     다시
# 41        5  0.046026     다시
# 41        6  0.230128     다시
# 41        7  0.092051     다시
# 128       7  0.829891     다운
# 128       8  0.092210     다운
# 202       2  0.909168   다운로드
# 226       1  0.665895     단계
# 318       1  0.321497    담당자
# 318       3  0.642994    담당자
# 251       1  0.158869     답변
# 251       2  0.158869     답변
# 251       3  0.317737     답변
# 251       4  0.158869     답변
# 251       5  0.158869     답변
# 199       8  0.729744     당일
# 186       7  0.832013     대기
# 115       3  0.169005     대체
# 115       5  0.507016     대체
# 115       7  0.169005     대체
# 321       4  0.409076     대행
# 206       3  0.660249     댓글
# 206       6  0.330125     댓글
# 167       1  0.085681    데이터
# 167       2  0.856806    데이터
# 84        1  0.476386    도대체
# 84        3  0.095277    도대체
# 84        4  0.190554    도대체
# 84        5  0.095277    도대체
# 362       8  0.392263     동일
# 72        1  0.451179     등록
# 72        3  0.205081     등록
# 72        4  0.041016     등록
# 72        5  0.041016     등록
# 72        6  0.246098     등록
# 126       2  0.544896    똑바로
# 126       3  0.272448    똑바로
# 133       2  0.656928    로그인
# 133       4  0.262771    로그인
# 203       2  0.855795     로딩
# 145       1  0.096374     리뷰
# 145       3  0.578242     리뷰
# 145       5  0.096374     리뷰
# 86        2  0.292427    마케팅
# 86        4  0.584854    마케팅
# 137       3  0.120861     만원
# 137       5  0.846029     만원
# 257       5  0.313604     매장
# 257       7  0.627208     매장
# 143       6  0.307437     머리
# 143       7  0.307437     머리
# 295       1  0.318505     먹통
# 295       7  0.477758     먹통
# 208       4  0.414450     먼저
# 233       2  0.782404     며칠
# 109       1  0.253466     명의
# 109       4  0.253466     명의
# 109       7  0.506933     명의
# 138       1  0.732197     몇번
# 138       5  0.104600     몇번
# 138       6  0.104600     몇번
# 265       1  0.641179     모든
# 242       1  0.552597    모바일
# 242       2  0.276299    모바일
# 48        1  0.103935    무조건
# 48        3  0.831484    무조건
# 266       6  0.329068     문구
# 266       8  0.329068     문구
# 120       4  0.367096     문의
# 120       5  0.367096     문의
# 120       7  0.091774     문의
# 120       8  0.091774     문의
# 209       1  0.701010     문자
# 209       7  0.116835     문자
# 2         1  0.549573     문제
# 2         2  0.157021     문제
# 2         3  0.078510     문제
# 2         7  0.078510     문제
# 2         8  0.157021     문제
# 309       4  0.572566     물어
# 309       5  0.286283     물어
# 309       8  0.286283     물어
# 340       1  0.360968     바람
# 340       8  0.360968     바람
# 178       1  0.306640    바코드
# 178       4  0.459960    바코드
# 267       6  0.332152     반복
# 267       8  0.332152     반복
# 50        1  0.101747     발급
# 50        3  0.712226     발급
# 50        4  0.076310     발급
# 50        5  0.025437     발급
# 50        6  0.025437     발급
# 50        7  0.050873     발급
# 50        8  0.025437     발급
# 218       2  0.363223     방금
# 218       6  0.363223     방금
# 102       1  0.239847     방법
# 102       2  0.119924     방법
# 102       4  0.359771     방법
# 102       7  0.119924     방법
# 79        2  0.522703     방식
# 79        4  0.261352     방식
# 342       1  0.209756     버전
# 342       8  0.629267     버전
# 273       4  0.839169   번거로움
# 274       2  0.311575     번잡
# 274       4  0.311575     번잡
# 274       6  0.311575     번잡
# 122       1  0.264522     번호
# 122       8  0.661304     번호
# 80        1  0.529752     변경
# 80        3  0.176584     변경
# 80        4  0.176584     변경
# 96        4  0.273756     별로
# 96        5  0.136878     별로
# 96        6  0.547511     별로
# 210       1  0.241065    별하나
# 210       4  0.241065    별하나
# 210       8  0.241065    별하나
# 38        3  0.110348     보기
# 38        4  0.220696     보기
# 38        5  0.110348     보기
# 38        6  0.551740     보기
# 118       1  0.208383     복잡
# 118       4  0.208383     복잡
# 118       7  0.625149     복잡
# 111       7  0.643903     본인
# 282       1  0.220612   본인인증
# 282       7  0.661836   본인인증
# 282       8  0.220612   본인인증
# 348       3  0.364268     본적
# 348       4  0.364268     본적
# 39        1  0.336336    부모님
# 39        6  0.336336    부모님
# 15        1  0.119898    부산시
# 15        2  0.059949    부산시
# 15        3  0.659438    부산시
# 15        5  0.059949    부산시
# 303       6  0.318978   부산은행
# 303       7  0.318978   부산은행
# 105       1  0.294854     부탁
# 105       2  0.491424     부탁
# 105       3  0.098285     부탁
# 105       4  0.098285     부탁
# 46        1  0.080537     불가
# 46        2  0.241611     불가
# 46        3  0.080537     불가
# 46        5  0.483221     불가
# 46        7  0.080537     불가
# 193       1  0.202437    불가능
# 193       3  0.202437    불가능
# 193       7  0.607311    불가능
# 245       1  0.203236    불안정
# 245       2  0.203236    불안정
# 245       5  0.203236    불안정
# 245       6  0.406473    불안정
# 16        1  0.049518     불편
# 16        2  0.181566     불편
# 16        3  0.082530     불편
# 16        4  0.148554     불편
# 16        5  0.082530     불편
# 16        6  0.099036     불편
# 16        7  0.330120     불편
# 16        8  0.033012     불편
# 194       4  0.461309     비교
# 194       8  0.461309     비교
# 33        1  0.827760     비번
# 87        3  0.843000     비용
# 300       6  0.557185    사업자
# 17        1  0.114274     사용
# 17        2  0.326496     사용
# 17        3  0.163248     사용
# 17        4  0.130599     사용
# 17        5  0.114274     사용
# 17        6  0.081624     사용
# 17        7  0.065299     사용
# 17        8  0.016325     사용
# 97        1  0.095421    사용자
# 97        2  0.095421    사용자
# 97        3  0.095421    사용자
# 97        4  0.477106    사용자
# 97        6  0.095421    사용자
# 66        1  0.155079     사항
# 66        3  0.620315     사항
# 187       1  0.500551     삭제
# 187       2  0.250275     삭제
# 187       3  0.083425     삭제
# 187       7  0.083425     삭제
# 162       1  0.162089   삼성페이
# 162       3  0.040522   삼성페이
# 162       6  0.769923   삼성페이
# 162       7  0.040522   삼성페이
# 283       1  0.113742     상태
# 283       2  0.682451     상태
# 283       8  0.227484     상태
# 270       2  0.619285     상황
# 270       3  0.206428     상황
# 52        1  0.214800     생각
# 52        3  0.429599     생각
# 52        4  0.214800     생각
# 52        7  0.107400     생각
# 156       2  0.867184     서버
# 156       5  0.123883     서버
# 246       1  0.129334    서비스
# 246       3  0.129334    서비스
# 246       4  0.258668    서비스
# 246       5  0.258668    서비스
# 190       8  0.771335     선불
# 53        1  0.197891   선불카드
# 53        3  0.593674   선불카드
# 53        4  0.065964   선불카드
# 53        6  0.065964   선불카드
# 223       1  0.309223     선정
# 223       7  0.309223     선정
# 139       1  0.104701     설명
# 139       3  0.732907     설명
# 139       4  0.104701     설명
# 188       1  0.759076     설치
# 188       2  0.079903     설치
# 188       5  0.039951     설치
# 188       8  0.079903     설치
# 277       3  0.734585     세금
# 319       6  0.610325     세상
# 214       1  0.237993     소리
# 214       5  0.713979     소리
# 248       1  0.207847     수준
# 248       4  0.207847     수준
# 248       6  0.623542     수준
# 238       2  0.649987     승인
# 238       3  0.324994     승인
# 0         3  0.723307     시작
# 88        3  0.440695     시청
# 200       1  0.168965     신규
# 200       3  0.675861     신규
# 200       4  0.056322     신규
# 200       6  0.056322     신규
# 200       7  0.056322     신규
# 3         1  0.222310     신청
# 3         3  0.444619     신청
# 3         4  0.044462     신청
# 3         5  0.044462     신청
# 3         6  0.044462     신청
# 3         7  0.088924     신청
# 3         8  0.088924     신청
# 296       1  0.632911     실력
# 312       1  0.214793     실패
# 312       4  0.214793     실패
# 312       7  0.429586     실패
# 42        1  0.148603     실행
# 42        2  0.743014     실행
# 42        6  0.037151     실행
# 42        8  0.037151     실행
# 158       1  0.055947    쓰레기
# 158       2  0.391630    쓰레기
# 158       3  0.391630    쓰레기
# 158       5  0.055947    쓰레기
# 158       6  0.111894    쓰레기
# 240       2  0.612772     아예
# 240       4  0.122554     아예
# 240       8  0.122554     아예
# 160       5  0.860392    아이폰
# 18        2  0.108218     아직
# 18        3  0.216435     아직
# 18        5  0.541088     아직
# 18        8  0.108218     아직
# 106       2  0.462036  안드로이드
# 106       8  0.231018  안드로이드
# 294       7  0.666631    알뜰폰
# 294       8  0.333316    알뜰폰
# 60        3  0.205703     알람
# 60        5  0.617110     알람
# 19        1  0.085722     알림
# 19        2  0.771502     알림
# 289       5  0.290780    어르신
# 289       6  0.581560    어르신
# 289       8  0.290780    어르신
# 28        1  0.085941   업데이트
# 28        2  0.773473   업데이트
# 28        3  0.042971   업데이트
# 28        7  0.064456   업데이트
# 263       4  0.117146     업뎃
# 263       8  0.820022     업뎃
# 146       1  0.066470     업체
# 146       2  0.132941     업체
# 146       3  0.332352     업체
# 146       4  0.066470     업체
# 146       5  0.265881     업체
# 146       7  0.066470     업체
# 146       8  0.066470     업체
# 163       7  0.833645     엉망
# 112       5  0.843020     에러
# 252       1  0.584164     여러
# 252       7  0.194721     여러
# 258       1  0.654565     여전
# 4         1  0.167446     연결
# 4         2  0.167446     연결
# 4         3  0.041861     연결
# 4         4  0.167446     연결
# 4         5  0.083723     연결
# 4         6  0.334891     연결
# 4         8  0.041861     연결
# 172       1  0.572535     연동
# 172       7  0.229014     연동
# 172       8  0.114507     연동
# 347       2  0.706840     예산
# 142       1  0.130028     예전
# 142       2  0.455096     예전
# 142       4  0.195041     예전
# 142       5  0.130028     예전
# 142       6  0.065014     예전
# 221       7  0.724915     옛날
# 157       1  0.430520     오늘
# 157       3  0.107630     오늘
# 157       5  0.215260     오늘
# 157       6  0.215260     오늘
# 157       7  0.107630     오늘
# 30        1  0.117960     오류
# 30        2  0.235921     오류
# 30        3  0.058980     오류
# 30        4  0.058980     오류
# 30        5  0.088470     오류
# 30        6  0.265411     오류
# 30        7  0.029490     오류
# 30        8  0.147451     오류
# 5         1  0.093856   와이파이
# 5         2  0.750851   와이파이
# 5         6  0.093856   와이파이
# 330       1  0.609388     완료
# 301       2  0.176574     요즘
# 301       6  0.706297     요즘
# 336       4  0.436356    용해도
# 341       1  0.724825    운영사
# 75        4  0.364700     원래
# 75        8  0.547050     원래
# 54        3  0.741858     유도
# 216       1  0.259440     은행
# 216       4  0.129720     은행
# 216       6  0.389160     은행
# 216       7  0.129720     은행
# 89        4  0.281353     의무
# 89        7  0.562706     의무
# 359       2  0.380203     의심
# 359       6  0.380203     의심
# 355       1  0.641288     이름
# 107       1  0.094100     이용
# 107       2  0.188201     이용
# 107       4  0.470502     이용
# 107       5  0.094100     이용
# 107       6  0.094100     이용
# 21        1  0.036013     이전
# 21        2  0.360134     이전
# 21        3  0.108040     이전
# 21        4  0.216080     이전
# 21        5  0.108040     이전
# 21        6  0.072027     이전
# 21        7  0.072027     이전
# 185       1  0.259527     이제
# 185       2  0.519054     이제
# 234       7  0.679191     이틀
# 22        3  0.567703     이해
# 22        7  0.340622     이해
# 280       1  0.814833     인식
# 81        1  0.377241     인증
# 81        7  0.141465     인증
# 81        8  0.424396     인증
# 23        1  0.232034    인터넷
# 23        6  0.464068    인터넷
# 256       3  0.250043  인터페이스
# 256       4  0.125022  인터페이스
# 256       5  0.125022  인터페이스
# 256       7  0.500086  인터페이스
# 297       5  0.448288     일부
# 297       8  0.448288     일부
# 153       1  0.805092    일부러
# 153       6  0.161018    일부러
# 314       1  0.298674    일일이
# 314       8  0.298674    일일이
# 302       2  0.414837    일주일
# 253       5  0.627660     입금
# 220       1  0.811520     입력
# 220       7  0.081152     입력
# 220       8  0.081152     입력
# 207       1  0.312586     자꾸
# 207       3  0.078146     자꾸
# 207       5  0.156293     자꾸
# 207       8  0.390732     자꾸
# 346       3  0.764172     자원
# 204       3  0.143227     자주
# 204       6  0.572907     자주
# 204       7  0.143227     자주
# 67        1  0.087927     자체
# 67        2  0.175855     자체
# 67        3  0.087927     자체
# 67        4  0.087927     자체
# 67        6  0.087927     자체
# 67        7  0.087927     자체
# 67        8  0.351709     자체
# 34        1  0.310056     잔액
# 34        2  0.044294     잔액
# 34        3  0.132881     잔액
# 34        4  0.177175     잔액
# 34        5  0.177175     잔액
# 34        6  0.088587     잔액
# 34        7  0.088587     잔액
# 213       3  0.257664     잘못
# 213       6  0.515328     잘못
# 55        1  0.075552    재발급
# 55        3  0.831070    재발급
# 55        4  0.075552    재발급
# 147       2  0.599396     저번
# 147       6  0.199799     저번
# 62        5  0.835138     적립
# 62        6  0.104392     적립
# 63        2  0.612842    적립금
# 63        3  0.204281    적립금
# 63        4  0.204281    적립금
# 63        5  0.204281    적립금
# 275       1  0.296382     전송
# 275       8  0.296382     전송
# 93        1  0.077128     전화
# 93        2  0.154256     전화
# 93        4  0.231384     전화
# 93        5  0.385640     전화
# 93        6  0.154256     전화
# 93        7  0.077128     전화
# 353       3  0.818615     절차
# 47        1  0.024315     접속
# 47        2  0.753757     접속
# 47        5  0.072944     접속
# 47        6  0.072944     접속
# 47        8  0.072944     접속
# 24        1  0.608788     정보
# 24        2  0.173939     정보
# 24        3  0.086970     정보
# 24        7  0.086970     정보
# 25        7  0.412147     정확
# 269       1  0.109528    제대로
# 269       3  0.438112    제대로
# 269       4  0.109528    제대로
# 269       5  0.109528    제대로
# 269       6  0.109528    제대로
# 124       2  0.451456     제발
# 124       3  0.112864     제발
# 124       6  0.112864     제발
# 124       7  0.112864     제발
# 124       8  0.112864     제발
# 98        4  0.573252     제일
# 98        6  0.286626     제일
# 151       1  0.759916     조치
# 151       6  0.189979     조치
# 26        2  0.166119     조회
# 26        4  0.664474     조회
# 247       5  0.567505     종료
# 247       6  0.283752     종료
# 116       2  0.154096     종일
# 116       7  0.770478     종일
# 339       1  0.278939     주소
# 339       7  0.557878     주소
# 315       4  0.674587     중요
# 35        1  0.666853     지갑
# 103       3  0.087716     지금
# 103       4  0.350865     지금
# 103       5  0.438582     지금
# 103       7  0.087716     지금
# 196       2  0.248148     지역
# 196       6  0.248148     지역
# 196       8  0.248148     지역
# 337       2  0.325783   지역화폐
# 337       5  0.325783   지역화폐
# 337       8  0.325783   지역화폐
# 197       2  0.145816     직관
# 197       3  0.145816     직관
# 197       4  0.145816     직관
# 197       6  0.437448     직관
# 197       7  0.145816     직관
# 173       1  0.199302    직관성
# 173       4  0.199302    직관성
# 173       8  0.398603    직관성
# 281       1  0.734657     직접
# 316       3  0.357061     진심
# 316       4  0.357061     진심
# 148       1  0.135616     짜증
# 148       2  0.316437     짜증
# 148       3  0.090410     짜증
# 148       5  0.045205     짜증
# 148       6  0.045205     짜증
# 148       8  0.361642     짜증
# 134       4  0.833291     찾기
# 134       5  0.075754     찾기
# 290       3  0.260049     처리
# 290       5  0.260049     처리
# 290       6  0.260049     처리
# 82        1  0.594206     처음
# 82        4  0.118841     처음
# 82        5  0.118841     처음
# 82        6  0.118841     처음
# 69        1  0.437823   체크카드
# 69        4  0.218911   체크카드
# 69        5  0.109456   체크카드
# 69        8  0.218911   체크카드
# 254       8  0.559522     초과
# 154       8  0.732169     초기
# 130       2  0.489639     최악
# 130       3  0.272022     최악
# 130       4  0.054404     최악
# 130       6  0.108809     최악
# 130       7  0.054404     최악
# 130       8  0.054404     최악
# 91        1  0.128954     추가
# 91        2  0.128954     추가
# 91        3  0.257907     추가
# 91        7  0.386861     추가
# 70        1  0.371646     출금
# 70        8  0.371646     출금
# 43        1  0.077254     충전
# 43        2  0.206010     충전
# 43        4  0.128756     충전
# 43        5  0.412021     충전
# 43        6  0.077254     충전
# 43        7  0.077254     충전
# 43        8  0.025751     충전
# 104       1  0.085929     취소
# 104       4  0.343716     취소
# 104       5  0.171858     취소
# 104       6  0.171858     취소
# 104       8  0.171858     취소
# 7         1  0.216756     카드
# 7         2  0.067736     카드
# 7         3  0.460606     카드
# 7         4  0.054189     카드
# 7         5  0.040642     카드
# 7         6  0.067736     카드
# 7         7  0.040642     카드
# 7         8  0.027094     카드
# 215       3  0.656132     캐쉬
# 215       5  0.218711     캐쉬
# 140       1  0.512803    캐쉬백
# 140       4  0.102561    캐쉬백
# 140       5  0.205121    캐쉬백
# 140       6  0.102561    캐쉬백
# 176       2  0.102740     캐시
# 176       4  0.205479     캐시
# 176       5  0.102740     캐시
# 176       6  0.616437     캐시
# 57        1  0.123617    캐시백
# 57        2  0.082411    캐시백
# 57        3  0.082411    캐시백
# 57        4  0.412056    캐시백
# 57        5  0.288439    캐시백
# 271       1  0.270861   코나아이
# 271       3  0.270861   코나아이
# 271       6  0.406292   코나아이
# 313       6  0.778762     크기
# 141       1  0.254469     클릭
# 141       8  0.508939     클릭
# 180       1  0.356747     터치
# 180       7  0.356747     터치
# 343       2  0.478716     통신
# 343       3  0.159572     통신
# 343       5  0.159572     통신
# 284       5  0.328452    통신사
# 284       8  0.328452    통신사
# 310       5  0.616143     통장
# 239       1  0.269364     통화
# 239       6  0.538727     통화
# 239       7  0.269364     통화
# 131       4  0.203998     페이
# 131       6  0.611993     페이
# 338       2  0.857359    페이백
# 155       1  0.663017     편리
# 174       4  0.822916     편의
# 344       1  0.862697     평가
# 36        1  0.082624    포인트
# 36        2  0.082624    포인트
# 36        3  0.082624    포인트
# 36        5  0.247873    포인트
# 36        6  0.495747    포인트
# 161       1  0.164451     표시
# 161       2  0.164451     표시
# 161       3  0.164451     표시
# 161       5  0.493353     표시
# 298       2  0.674285     푸시
# 279       3  0.796490   플라스틱
# 58        3  0.555760     필수
# 58        7  0.185253     필수
# 76        1  0.173166     필요
# 76        2  0.086583     필요
# 76        3  0.173166     필요
# 76        4  0.173166     필요
# 76        5  0.086583     필요
# 76        7  0.173166     필요
# 333       7  0.732108   하나은행
# 287       4  0.372187   하나카드
# 287       8  0.372187   하나카드
# 117       6  0.125754     하루
# 117       7  0.754523     하루
# 100       2  0.171639     한눈
# 100       4  0.514916     한눈
# 100       5  0.343277     한눈
# 255       5  0.535662     한도
# 255       8  0.357108     한도
# 8         1  0.296483     한번
# 8         3  0.148241     한번
# 8         4  0.592966     한번
# 201       5  0.667351     한참
# 184       2  0.853612     할인
# 9         1  0.113108     해결
# 9         2  0.452432     해결
# 9         4  0.113108     해결
# 9         7  0.113108     해결
# 9         8  0.113108     해결
# 285       1  0.561581    핸드폰
# 40        5  0.592174     현금
# 40        6  0.296087     현금
# 101       2  0.221798     현재
# 101       4  0.221798     현재
# 101       7  0.443596     현재
# 77        1  0.091818     혜택
# 77        2  0.183636     혜택
# 77        3  0.459089     혜택
# 77        4  0.091818     혜택
# 77        5  0.183636     혜택
# 149       4  0.691888     홍보
# 175       1  0.383735     화면
# 175       2  0.127912     화면
# 175       3  0.191868     화면
# 175       4  0.063956     화면
# 175       6  0.127912     화면
# 175       7  0.063956     화면
# 175       8  0.063956     화면
# 260       7  0.391347     확실
# 27        1  0.310093     확인
# 27        2  0.275638     확인
# 27        3  0.068910     확인
# 27        4  0.068910     확인
# 27        5  0.172274     확인
# 27        6  0.034455     확인
# 27        7  0.034455     확인
# 27        8  0.034455     확인
# 132       4  0.074828     환불
# 132       5  0.823113     환불
# 232       1  0.293829     회사
# 232       2  0.146915     회사
# 232       4  0.440744     회사
# 332       1  0.534544     회원
# 332       8  0.267272     회원
# 224       1  0.917202   회원가입
# 45        1  0.184168    휴대폰
# 45        7  0.552505    휴대폰
# 45        8  0.184168    휴대폰, R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 3, 7, 4, 6, 2, 8, 5])

# %% [raw]
# kk = ldamodel.show_topic(0)
# type(ldamodel.show_topic)
# kk2 = pd.DataFrame(kk)
#
# kk2.head(10)

# %%
word_dict = {};

for i in range(topics):

    words = ldamodel.show_topic(i)

    word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words]

pd.DataFrame(word_dict)
# Out:
#   Topic # 01 Topic # 02 Topic # 03 Topic # 04 Topic # 05 Topic # 06  \
# 0         설치       삼성페이       업데이트        가맹점         번호         충전
# 1         카드         오류         접속         찾기         인증         금액
# 2         등록         연결         실행        캐시백         계속         환불
# 3         입력         결제         사용         불편         짜증         적립
# 4         기존         계좌         불편         사용         업뎃         결제
# 5         확인         등록        데이터         금액       네트워크         에러
# 6         다시        포인트         이전         이전         자꾸         사용
# 7         인증       네트워크         알림         기능         오류        캐시백
# 8         몇번         캐시         최악        사용자         자체         만원
# 9         잔액         불편         확인         편의         버전         불가
#
#   Topic # 07 Topic # 08
# 0         카드         불편
# 1         발급         다운
# 2         기존         하루
# 3         신규         종일
# 4        부산시         대기
# 5        재발급      인터페이스
# 6         신청         사용
# 7         사용         엉망
# 8       선불카드         카드
# 9         강제         먹통

# %% [markdown]
# 참고: 아마존 고객리뷰 토픽모델링 https://blog.naver.com/upennsolution/221437143732

# %% [markdown]
# 토픽 네이밍 그룹화
# 1. 연결,접속,네트워크
# 2. 업데이트
# 2. 카드 발급 및 등록
# 3. 사용 불편
# 3. 충전 및 금액 내역
# 4. 기존 및 이관
# 5. 결제
# 6. 설치

# %% [markdown]
# #### 토픽별 문서

# %%
def make_topictable_per_doc(ldamodel, corpus):
    topic_table = pd.DataFrame()

    # 몇 번째 문서인지를 의미하는 문서 번호와 해당 문서의 토픽 비중을 한 줄씩 꺼내온다.
    for i, topic_list in enumerate(ldamodel[corpus]):
        doc = topic_list[0] if ldamodel.per_word_topics else topic_list            
        doc = sorted(doc, key=lambda x: (x[1]), reverse=True)
        # 각 문서에 대해서 비중이 높은 토픽순으로 토픽을 정렬한다.
        # EX) 정렬 전 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (10번 토픽, 5%), (12번 토픽, 21.5%), 
        # Ex) 정렬 후 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (12번 토픽, 21.5%), (10번 토픽, 5%)
        # 48 > 25 > 21 > 5 순으로 정렬이 된 것.

        # 모든 문서에 대해서 각각 아래를 수행
        for j, (topic_num, prop_topic) in enumerate(doc): #  몇 번 토픽인지와 비중을 나눠서 저장한다.
            if j == 0:  # 정렬을 한 상태이므로 가장 앞에 있는 것이 가장 비중이 높은 토픽
                topic_table = topic_table.append(pd.Series([int(topic_num), round(prop_topic,4), topic_list]), ignore_index=True)
                # 가장 비중이 높은 토픽과, 가장 비중이 높은 토픽의 비중과, 전체 토픽의 비중을 저장한다.
            else:
                break
    return(topic_table)

# %% [markdown]
# 참고한 코드 출처 https://wikidocs.net/30708
#
# 사용한 코드는 아니나 혹시나 싶어 https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#15visualizethetopicskeywords

# %%
topictable = make_topictable_per_doc(ldamodel, corpus)
topictable = topictable.reset_index() # 리뷰번호를 의미하는 열로 사용하기 위해서 인덱스 열을 하나 더 만들어줌
topictable.columns = ['리뷰 번호', '가장 비중이 높은 토픽', '가장 높은 토픽의 비중', '각 토픽의 비중']
topictable[:10]
# Out:
#    리뷰 번호  가장 비중이 높은 토픽  가장 높은 토픽의 비중  \
# 0      0           6.0        0.5956
# 1      1           0.0        0.8012
# 2      2           2.0        0.7492
# 3      3           2.0        0.7301
# 4      4           5.0        0.4179
# 5      5           2.0        0.1637
# 6      6           1.0        0.6610
# 7      7           0.0        0.8269
# 8      8           1.0        0.7610
# 9      9           2.0        0.7770
#
#                                             각 토픽의 비중
# 0  [(0, 0.07083974), (1, 0.052243352), (2, 0.0762...
# 1  [(0, 0.80121326), (1, 0.026245983), (2, 0.0386...
# 2  [(0, 0.028299924), (1, 0.020766228), (2, 0.749...
# 3  [(0, 0.049246177), (1, 0.03617392), (2, 0.7300...
# 4  [(0, 0.05894041), (1, 0.043436598), (2, 0.0636...
# 5  [(0, 0.1520835), (1, 0.112159565), (2, 0.16365...
# 6  [(0, 0.05807857), (1, 0.661047), (2, 0.0625837...
# 7  [(0, 0.8268528), (1, 0.022890046), (2, 0.03353...
# 8  [(0, 0.0409836), (1, 0.76095873), (2, 0.044109...
# 9  [(0, 0.04073872), (1, 0.029870195), (2, 0.7770...

# %% [markdown]
# ##### 토픽 1
#
# '0.037*"설치" + 0.030*"카드" + 0.021*"등록" + 0.018*"입력" + 0.018*"기존" + 0.017*"확인" + 0.017*"다시" + 0.016*"인증" + 0.014*"몇번" + 0.014*"잔액"

# %%
topic_1 = topictable[topictable['가장 비중이 높은 토픽'] == 0.0]

print('토픽 1에 해당하는 리뷰의 개수:', topic_1.shape[0], '개')
# Out:
# 토픽 1에 해당하는 리뷰의 개수: 213 개

# %%
# 토픽 1에 해당하는 리뷰들만 모아서 하나의 df 만들기

topic_1_list = topic_1['리뷰 번호'].unique()
df_topic_1 = df_negative.loc[topic_1_list, :]

df_topic_1.head(5)
# Out:
#           DATE  STAR                                             REVIEW  LIKE
# 1   2020-04-10     1  아니 와이파이 네 칸 풀로뜨고 유튜브 등등 빠르게 잘되는데 왜 이 앱만들어거면 네트...     0
# 7   2021-04-30     1  쓰기 불편해졌어요.. 개선해주세요 1. 어플 키면 바로 잔액이랑 포인트, 합계 금액...     0
# 20  2021-04-05     1  계좌등록이 하나 밖에 안되네요.ㅠ 계좌변경할 때마다 인증 받아야 되고, 기존처럼 한...     9
# 58  2020-05-02     1                                           정책이 거지같냐     0
# 59  2020-03-31     1  결제가 먹통입니다 어플 접속도 안 되구요 다름 카드를 들고있었기에 망정이지 동백전만...     0

# %%
# 리뷰 전부 모아보기 --> 복사해서 R로 들고가서 감성분석 진행

df_topic_1['REVIEW'].unique()
# Out:
# array(['아니 와이파이 네 칸 풀로뜨고 유튜브 등등 빠르게 잘되는데 왜 이 앱만들어거면 네트워크 연결이 안된다고 뜰까요..가입한 이후로 한번도 켜지지않아 카드 신청도 못하고 있습니다. 연결문제 좀 해결해주세요.',
#        '쓰기 불편해졌어요.. 개선해주세요 1. 어플 키면 바로 잔액이랑 포인트, 합계 금액 나왔는데, 이건 굳이 내지갑 한번 누르고 비번도 누르고 해야 잔액 확인… face id 사용하면 마스크 쓰고 있어서 더 불편..\n어플 키면 내 지갑 누르지 않아도 확인할 수 있도록 해주세요\n\n2. 동백전 가맹점 확인.. 어디서 하나요? 할 수는 있는건가요 ? 개선해주세요',
#        '계좌등록이 하나 밖에 안되네요.ㅠ 계좌변경할 때마다 인증 받아야 되고, 기존처럼 한번 등록하면 언제든지 바꿀수 있게 해 주세요. 처음 쓰기도 전에 너무 불편하네요. ㅠ',
#        '정책이 거지같냐',
#        '결제가 먹통입니다 어플 접속도 안 되구요 다름 카드를 들고있었기에 망정이지 동백전만 가지고 있었으면 문제가 생길 뻔 했습니다 알아보니 결제 장애가 생긴게 이번이 처음이 아니더군요',
#        '사용자 편의성 면에서 직관성이 이전 앱보다 떨어지네요 실행 후 메인화면이 너무 산만한 느낌이에요 좀더 간결하게 하면 좋을텐데 디자인이 매우 아쉽네요 그리고 선불카드 등록을 새로 무조건해야 기술적으로 개인정보 연동이 가능하다는 점도 정보가 디지털 데이터라는 점에서 단순이관이 분명 가능할텐데 이해하기가 어렵네요 왜 불필요한 발급을 하게 하는지 그리고 앱사용에 부정적인 반응을 만드는 시스템을 개발했는지 납득하기 어렵네요 전체적으로 사용자 편의성에서 불합격의 앱이라 생각합니다',
#        '기존 어플보다 10배는 쓰레기. 1. 터치해도 바코드나 qr코드가 나오는게 아님. 2. 결제 후 결제금액은 나오지만 캐쉬백 이력은 나오지 않음. 운영 기관이 이전된 건 어쩔 수 없지만 어플도 그냥 이관하지... 개발자가 손이 아닌 개발로 제작한 것 밖에 안되는데?',
#        '계좌도 다 안맞다그러고 신분증 발급일자도 틀리다고그러고... 그냥 발급이 이제 안되는건가? 몇번을 확인해도 틀린게읍는디;;',
#        '업데이트가 안되어 삭제후 다시 설치하려는데 계속 대기중입니다. 조치방법 부탁드립니다',
#        '그지같이 만들었네 바로 잔액확인안되고 \n내지갑 열어야되고 비밀번호 입력해야하고\n기존보다 더  불편하게 만듬 ㅡㅡ 짜증난다',
#        '참 쓰기짱나 아니회원가입하는디 스마트폰인증으로만해놈 폰이자기명의아닌사람 짱나제 은행도멀제 그냥쓰지마라는거군 공인인증서 회원가입도걸어쥬지 바보들만모였나 ... 망하게꾼',
#        '업데이트 이후 사용불가 첫 화면으로 가기까지도 너무 오래 걸리고 운 좋게 충전버튼까지 누르면 그때부터 또 다음 단계로 진행이 되지 않아서 사용할 수가 없습니다. 제 기기의 문제라고 하기에는 동백전 외에 데이터를 필요로 하는 어플들은 모두 정상적으로 사용 가능합니다.',
#        '너무 불편 카드 쓰던게 멀쩡히 있는데 새 카드 발급을 왜 받아야하며ㅡ\n신청하고 이관했는데 캐쉬백금액 확인도 안되고 온오프 설정도 안되고ㅡ\n쓸데없이 메뉴만 많네요.\n어플 안내도 전혀 없고.\n캐쉬백 어디서 확인하나요',
#        '도대체 왜 바꾼거지? 이유가 뭐래요? 앞전 동백전 아무볼편없이 아주 잘썼는데',
#        '와..리뉴얼되면서 더 불편해진건 뭐지!? 1.일단 사용 알림이 안뜨네요!\n2.전엔 카드실물이없어도 큐알코드로 모바일결제가 가능했는데 안되구요\n3.교통카드기능도 없어졌네요\n4.그리고 잔액을 굳이 내지갑까지 터치를해야 볼수있다니\n예전 어플보다 더 퇴화한건 무슨이유죠?',
#        '계좌등록 여러건 등록 안되나요? 입금 출금 전부다 계좌 인증하면서 수시로 바꿔야하네요.. 그리고 답변글 보아하니 확인없이 복붙만 하시는것 같네요',
#        '업데이트도안되고 새로 지우고 설치하는데 설치가 안됩니다.', '참으로 불편하다. 일부러 그러는가?',
#        '짜증나요 매장에서는 결제안됐다 그러고 저는 결제됐다고 알람 떴는데 결제하려고 어플드갔더니 안드가져서 삭제 후 다시 다운받았더니 여전히 안됩니다 어쩌라는건지ㅡㅡ',
#        '앱설치후 가입하려고하면 인증문자가 날라오지않아요',
#        '카드이관 등록하려는데 카드정보를 찾을수없다는데요 바코드 인식도 안되면서 왜 만든것이며 직접 입력하라고해서 입력햇더니 카드정보를 찾을수 없다는데 이걸 10번 이나 해봣는데 똑같네요 뭐하자는겁니까?',
#        '앱 접속시 계속 팅김 카드신청과정에서도 불안정함 주민번호 입력하면 자꾸 다른숫자로 인식함 카드신청부터 이래서 쓰다가 어떻게 관리하나라는 생각에 동백전 못쓰겟다싶네요',
#        '신규카드 삼성페이연동안되네요 그리고 기존카드도 동백전 등록안되는데요?',
#        '걍 먹통임 앱실행이 안됨 돈좀들여서 실력있는 개발자좀 씁시다', '몇번을시도해도잘되지가않네요 언제쯤 제대로 될까요?',
#        "앱 설치했는데 바탕화면에 나타나지 않네요 다시 진행하려니까 '설치됨'이라고 되어 있는데 그이후로는 진행이 안됩니다",
#        '가입 하려고 하면 인증 문자가 안와서 가입을 못하네요? 관리를 안하시는 건지? 리뷰가 다들 네트워크 문제니 뭐니 문제가 하나 둘이 아니네요 어플을 쓰라고 만든건지 사람들 스트레스 받게 만들려는건지 알수가없습니다 공지 같은건 확인 어디서 하나요? 친구한테 소개 받고 좋은 어플이겟구나 했더니 첫 이미지는 별점 1도 아깝습니다 앞으로 지켜볼게요',
#        '가입하려는데 개인정보 입력에서 폰번호 넣고 휴대폰인증번호 받으려고 전송버튼 누르면, 입력한 정보를 다시 확인하라고 뜨고 5번 넘으면 다음날 하라고 하면서 더이상 진행이 안되요 가입도 안되고 물어보려해도 연락처도 없고 어떻게 하면 되나요?',
#        '동백전 바뀌고 새로 등록한 카드는 직영점 사용가능. 그 전에 만든건 직영점 사용안됨 ㅋㅋ 추잡하고 치사하다 진짜 ㅋㅋㅋ',
#        '동백전앱이 삭제되어 제부팅 했는데 인증번호 보냈다는 글은 올라오는데 아무데도 찾을수가 없네요.',
#        '새로 깔았는데 기존카드가 입력이 안되는데요...',
#        '진심 거지같다. 화면 전부 다 바뀌고..뭐가 뭔지. 숨바꼭질하나...개짜증일세.',
#        '좀 속이면서 운영하지마세요 신규카드 발급유도하는게 처음부터 오만정 다 떨어지네요', '설치가안되요',
#        '왜 설치가 안되나요',
#        '4/9이후로 결제된 부분은 적립이 안돼요 10만원 이상 결제한건 바로 캐쉬백되는데 그 이하는 적립이 안되네요~ 앱 업뎃 이후로 적립이 안되는것 같아요 고객센터는 늘 통화중이고 문의사항 남겨도 답변도 없고 동백전 관리 너무 안하시는거 아닌가요!!!',
#        '오류 기존 하나은행 동백전 유저인데 잔액 연동이 안되니까 다음으로 넘어가지가 않습니다  카드 뒷면에 바코드도 없고 카드 정보 입력해도 오류만 뜨고 조치 바랍니다',
#        '앱 실행 단계에서부터 막힙니다. 만들기만 하지 말고 관리도 좀 잘해주길 바랍니다.',
#        '사용불가 라는데 기존 동백전 앱은 돈 다 빼고 탈퇴했어요. 새 앱 깔고 카드 신청해서 받아서 등록했고, 돈도 채워넣고 할 건 다 했습니다. 그런데 오늘 나가서 결제하려니 빵집에서 결제가 안된다고 뜹니다. 항상 사용했던 동네 빵집이구요. 원인이 뭔가요.',
#        '모든 답글 꼬라지가 그냥 복사&붙이기네\n사용해도 알림도 안오고 예전보다 무조건 카드 재발급에 무슨 비리가 있는건지 원..\n자 복붙답변 큐.',
#        '충전을 충분히 해뒀는데...은행에서 그냥 출금 처리됨..ㅡㅡ 처음에 충전된 잔액에서 결재되었다가 잠시후 잔액부족이라고 뜨면서 취소 시키고 다시 연결된 은행에서 돈빼가고...ㅡㅡ 이게 무슨 충전식 카드인지... 고객사 통화하니 사용자 많을경우 그럴수도 있다고.. 결재한곳 다시 방문해서 취소하고 재결재하라고함... 다시 차타고 가서 취소하고 재결재하라고? 시간이 남아도나? ㅡㅡ',
#        '정말 최악입니다 가입하라고 해놓고 인증문자 발송도 안됩니다 스팸차단같은거 확인하라는대로 다 했고 와이파이 접속으로 해라고해서 해도 전혀 안되네요 사용하지 못할 서비스는 왜 하는거죠?',
#        '업데이트 이후에 뭘사러 갔더니 분명 해당점포가 캐쉬백대상점포인걸로 아는데 캐쉬백이 바로 안들어와서 다른카드로 결제했습니다. 그런데 바로 취소내역도 안뜨고 이거 어플 뭐하는 겁니까? 돈과 연관된 어플이면 좀 제대로 돌아가야하는거 아닙니까? 정말 업데이트 이후로 실망입니다.',
#        '화면이 안넘어가요 첫 화면만 뜨고 더 이상 안 넘어가는데, 왜 이렇죠?',
#        '회원가입할때 직장주소 검색하고 다시들어오니까 어플 끄지도 않았는데 처음부터 다시 입력해야 되네요.. 개선바랍니다',
#        '네트워크도 잘안되는걸 어떻게 써라고? 써다가 열불나서 카드부쉈음. 일부러 이렇게 만든거 아니요?',
#        '네트워크 관리 좀 해주세요 뭔 맨날 연결 안 돼서 충전도 못하고 오늘도 캐시백 혜택 30000원은 봤을건데 네트워크 문제로 활용 못했네요 ㅋ',
#        '앱을 설치 했는데 어디에 깔렸는지 확인이 안되네요?', '설치가 안됨 설치가',
#        '짜증 바빠죽겠는데 앱 다시 설치해서 회원가입까지하고\n카드도 재발급받아야 하네요^^ 다시는 안씁니다',
#        '이전 동백전사업자는 캐시백을 내 잔고처럼 쓸수있어서 자유로웠는데, 코나로 바뀌고 나서는 캐시백쓰려면 꼭 얼마쓸건지 입력하고 실물카드로 결제해야된다는게 짜증나요. 기능수정 좀 해주세요.',
#        '왜 평점이 4.3인가요. 별 하나도 아깝습니다. 네트워크 오류로 접속이 일주일 넘게 안됩니다. 고객센터는 매일 통화중으로 연결도 힘들군요. 앱이 실행되야 충전을 하든지 사용내역을 확인하든지 하죠. 일주일 넘게 제 핸드폰에 문제 있어서 그런가 하고 앱 지우고 설치를 몇번이나 반복 했는지 모르겠습니다.',
#        '앱 업로드이후 자꾸 재시작해야 하는 버그가 계속발생 합니다. 업로드전에는 전혀 문제 없었으나 업로드이후 한번에 연결이 되지 않고 여러번 해야 겨우 연결됩니다. 앱 실행하면 첫번째 화면나오다 꺼지는 현상이며 네트웍 연결이 안되었다고 하기도 하고 여러번 실행해야 겨우 겨우 됩니다. 와이파이나 네트웍장비 바로 앞 및 LG 통신장비 바로 앞에서도 겨우 겨우 연결됩니다. 다른 인터넷이나 연결속도 측정해도 전혀 문제 없습니다 핸드폰 기종은 V30(LG) 모델입니다. 리뷰에 보면 여러사람들이 문제제기를 합니다. 빠른조치 부탁해요!',
#        '회원가입조차 되질않아요. 문자인증전까지 입력은 되는데 인증문자가 전혀 오질않네요 SKT는 사용이 안되나요? 부산은행에서도 정확히 모르더군요.',
#        '실행할때마다 인증된 폰번호와 일치하지 않는다고 재인증을 해야합니다',
#        '너무 자주 에러나요. 미리 공지라도 하고 안돼야 당황을 덜하죠. 오늘도 일부러 동백전으로 결제하러 갔다가 허탕쳤습니다. 너무한거 아닙니까??? 진짜 최악입니다. 1-2주동안 대체 몇번이나 안되는건가요.',
#        '21/07/18 설문조사하라해서 설문조사중 맨밑에 건의사항 적고 있는데 갑자기 휴대폰 문제인지 입력하고 있는중 저장되어 그냥 넘어가버림 내 의도치않게 자동으로 완료되고 다시 적으려하니 수정이 안됨 할말이 없음 불편한게 있다면 문자확인하는것 신용카드,체크카드 결제하면 얼마썻고 얼마남았다 바로바로 문자와서 확인이 가능한데 동백카드는 결제한것도 보안인지 동백카드 들어가서 비밀번호 누르고 내역확인하러 클릭해야되야 되는 몇단계를 거쳐야됨 다른카드들은 한번만 누르면 되는데 비번칠필요도 없이',
#        '앱실행이 안됩니다 왜? 그런걸까요? 빠른 조치바랍니다!! 죄송합니다란 말빼구요~',
#        '결제안된다해서 다른카드로 결제했는데 동백전에선 또 돈이 나가네요 일반 슈퍼인데도 동백전카드가 잘 결제가안되고 실패한다고해서 다른 카드로 결제했는데 어플 알림보니 또 동백전 카드에선 돈이 나갔고 캐시백도 들어왔네요? 그래서 확인하려고 어플키니까 갑자기 사용자정보 어쩌고 오류뜨면서 다시 어플키라고 계속 뜨길래 어플삭제하고 다시 깔았더니 바로 503 service unavailable 뜨네요;; 2중결제됐는지 확인도못하고 이게뭡니까 당연히 슈퍼쪽에선 결제안됐다하고;; 내일 오전에 카드사 전화해야겠네요 좀 제대로 안정화해주세요',
#        '설치하고 카드 신청하는데 폰으로 인증번호 확인차 문자앱 실행해서 보고 다시 동백전앱에 인증번호 넣을려고 클릭하면 재시작 되어서 다시 휴대폰 번호 넣어라함ㅡ.ㅡ 몇번째 다시하다가 성질나서 카드신청 안함ㅡ 먼 앱을 이따위로 만들었는지ㅡ.ㅡ',
#        '캐시백되는건 좋은데 앱이 몇번째 안들어가지는건지... 돈이 얼마있는지 확인할수가 없네요',
#        '집에서 와이파이 연결된경우에만 충전이나 어플확인이 가능합니다.. 어플연결이 안되다보니. 불편하네요...저만 그러는줄 알았는데 생각보다 많은 분들이 이러한 불편을 겪는거 같네요..얼른 이런 불편사항이 개선되면 좋겠습니다..네트워크 이야기하기엔 저희신랑은 너무나 잘 열리네요ㅡㅡ같은 상황에서 그리고 충전금액보다 더 많은 금액결제시 바로 체크카드로 결제가 되는데 알림으로 체크카드로할건지 물어보면 좋겠습니다....',
#        '업데이트 후에도 선불카드 입력하라는 문제 방금 업데이트해서 기존 체크카드 입력하고 동백전 사용이 가능해질 줄 알았는데, ‘새로운 부산 동백전 선불카드’를 입력하라고 나오네요?\n새로운 선불카드를 입력하라는 거랑 새로운 선불카드를 신청하라는 거랑 뭐가 다른 건지 알 수가 없군요. 결국은 코나아이에서 발급한 카드가 없으면 기존 카드로 동백전 사용은 불가능하다는 거잖아요.\n기존 체크카드 정보를 입력하고 그 카드로 동백전을 사용할 수는 없는 건가요?',
#        '진짜 허접한 앱때매 사용하기 어렵네요.. 도대체 뭐하자는 겁니까?',
#        '업데이트안되고 다시설치도안되네요 조치좀해주세요',
#        '부산시요? 보소! 삼성페이와 연동 안되는 카드랑거? 알고있는교? 상담원은 회사카드라 안된다하고 언제되는지 모른다 하던데 그럼 가족 3명이 모두 통장 카드 각각 만들어야라 말입니꺼? 애는 미성년자고 마눌은 가정주부고 이거 비효율 아닙니꺼? 와이리 복잡게 했는교?',
#        '결제내역을 문자로도 보내주면 좋겠네요.',
#        '문자인증이 안와요 어플이 안켜져서 삭제했다가 다시 깔았는데 문자인증메세지가 안와요ㅠㅠ',
#        '시민들 우롱하는것 도대체 왜 바꿉니까? 누구를위한 정책인가요 300만 시민들 엄청스트례스와 불편초래케한 동백전교체 책임자는 사과하고 물러나세요',
#        '별 1개도 아깝습니다 결제가 제대로안돼서 어플실행시키는데 들어가져야지 확인을하지ㅡㅡ 20분간 시간버리고 한번더결제하고나왔습니다. 카드관리랑 어플관리가안되면 애초에 시행을하지마세요 이딴식으로 운영해서 불편하게만들지말고',
#        '선불카드 신청하지 않고 진행할 수 있는 방법 알려주세요',
#        '아니 결제를 했는데 제 핸드폰에서는 결제가 됐다고 알림이 왔는데 정작 결제한곳에서는 결제가 안됐다고 하는데 고객센터로 물어보려고 해도 전화도 잘안받는데다가 저녁엔 운영도 안하면 그럼 고객들은 어디에 문제 해결을 요구하나요 정말 짜증나네요 평소에도 접속이 어려웠는데 이렇게 문제가 생겼을때마저도 접속이 안돼면 어디로 확인하라고요?',
#        '업데이트가 진행이 안 돼요 하나도 전혀 삭제도 안되고 중지도 안돼요',
#        '오류 카드정보 오류라고떠요ㅡㅡ 인식도 안되고 카드번호도 입력하고 다 했는데 오류라고만 하고 안됩니다 개선해주세요',
#        '기존카드 사용에 관한 안내도 없고..교통카드 기능이나 체크카드연동 기능도 없고 오로지 선불카드 기능만..너무하시네요.. 어쩔수 없이 새카드를 신청 했지만 서랍속에 넣어두고 가능하다면 기존카드를 계속 쓸겁니다..2021년에 시대를 역행하시는 군요..실망입니다',
#        '왤케 불편하게 바꼈는지.. 그전 동백전도 불편했지만 이건뭐 ㅠ 새건데도 복잡하게 바껴서 찾다짜증남 환불 규정도 뭣같고 부산시는 뭐 이런곳에 맡겼는지 노답...솔직히 캐쉬백때문에 다들쓰지 캐쉬백 다른 카드 수준으로 낮추면 아무도 안쓸듯',
#        '돈 충전하고 카페에서 사용했는데 직원분이 은행에 문제가 있는거같다고 안된다해서 디른카드 썻는데 폰 앱 알림에는 또 캐시백 들아왔더라구요...그래서 확인해볼라니까 앱이 그냥 메인화면에서 그 카드 충전 화면으로 계속 안넘어가요 ㅠㅠ 돈쓴건지 안써진건지 모르겟네요ㅠㅠ 지웠다 다시 깔앗다 두번하는데 처음 화면에서 안넘어가요 ㅠㅠ',
#        '왜때문에 인증이안되나효 내이름에 내 탄생일에 내 명의의 핸드폰번혼데 자꾸 확인하래 내가 난데 왜 나라는걸 인증을 못해',
#        '업뎃 이후에 개인정보 동의 안하면 화면이 안넘어가네요 이건 먼짓거리인지..쓸수록 짜증만나네..리뷰 답글 단것도 복사 붙이기고..여기도 붙이기겠지..답없네',
#        '가입하려고하면 이미가입된 회원이라고 하고 비번찾으려고하면 일치하는 정보가 없다고하는데 어케해야하죠....슈뢰딩거의 회원인가요 저...?',
#        '예전껀 만족스러웠는데 코나아이 운영은 다 불만족스럽네요.',
#        "쓰지도 않을건데 새로 선불카드를 발급 받아야 한다기에 조금 더 기다려보고 이관하자 싶어 어플의 업데이와 개선을 기다렸습니다 '19일 부산시에 따르면 동백전 운영대행사 코나아이는 새로운 동백전 앱을 설치하고 가입할 때 무조건 실물 선불카드를 발급해야 했던 문제를 해결한 새로운 앱을 지난 16일 업데이트했다' 기사는 이렇게 났는데 마지막 업데이트는 14일이고 여전히 이관신청 과정에는 신규카드 발급이 있네요?? 기사와는 전혀 다르네요. 언제쯤 신규 발급없이 기존 카드만 쓸수 있는 겁니까.",
#        '하라는 대로 해도 업데이트가 안됩니다 지우고 다시 설치해도 역시 안되네요 부산시는 어떤 근거로 업체선정하는지 궁금해집니다 저도 평가처음 남겨봅니다 그냥 예전버전과 유사하게 변경해주세요',
#        '데이터 인식을 못하나봐요 깔아도 쓸수가없네요',
#        '업데이트 했는데 메인화면이 안열리고 업데이트해야만 사용가능하다는 안내만 자꾸 뜨네요 ㅠㅠ',
#        '사용자정보취득에 실패하였습니다 사용자정보취득에 실패하였습니다 앱을 다시 실행해주세요 라는 문구가 계속 떠서 삭제 후 다시 깔았는데도 여전히 안되네요… 오늘 카드 받아서 충전해서 내일부터 쓸려고 했는데 사용할 수가 없네요… 빠른 해결 부탁드립니다',
#        '문자인증이안됩니다', '본인인증단계에서 인증문자가 안와요 개선해주세요 본인인증단계에서 인증문자가 안와요 개선해주세요',
#        '카드신청시 주민번호 입력후 다음화면으로 넘어가지않습니다. 업데이트해주세요',
#        '예전 앱과 비교해 디자인이 복잡해서 불편해요.첫화면에 총받은 혜택 이거 없애주세요 잔액보다 큰 폰트크기여서 잔액같고 헷갈려요 예전 앱 첫화면은 바로 충전할수는 버튼있고 포인트도 얼마있는지 확인이 쉬웠는데 어줍잖게 있어보이는척하지말고 단순하게 바꿔주세요 추가로 예전엔 여러 계좌에서 충전할수있어고 계좌 선택가능했는데, 이건 1개만 계좌등록돼서 아쉽네요',
#        '오늘 결제도 안되고 어플실행도 안되요.',
#        '나왠만하면 평점안남기는데 마이너스 별 백만개 서비스가 개선되어야하는데 뮈야 이건 모바일 결제 삼성페이도 안되고 요즘 젊은사람들 누가 실물카드 들고 다님? 개선된점1개만 답변해줘요 왜 이카드로 변경되어야하는지 반드시 부산시감사들어가야함 청와대 청원 넣고싶다',
#        '메뉴가 중첩되는 부분이 많아서 메뉴구성이 깔끔하지 못한 느낌입니다 메인화면에 충전,혜택정보,이용내역이 있는데 카드부분 누르면 똑같은 메뉴가 하단에 왜 나오는지 모르겠네요 가맹점검색메뉴는 왜 없어졌나요',
#        '실력이 없는지 개선이 안되는 업데이트는 왜 하는지 알 수가 없다',
#        '잔액확인 카드잔액확인 어플 처음 켰을때 화면에서 할수있게 개선바랍니다 매번너부 불편해요..',
#        'kt앱이었네요 kt폰이 아니면 사용불가인 모양이네요 계좌등록 진행중에 인증완료를 누르기전까진 네트워크 어쩌구 저쩌구 안뜨다가 꼭 인증완료를 누르기만하면 네트워크 접속불량이라고 뜨는거였네요',
#        '별하나도 아깝다.앱도 구리고 운영도 구리다.신규카드 발급은 도대체 왜 하라는겨? 재활용 할생각은 안하니? 부모님 때문에 대신하다 화가 치밀어 오른다.',
#        '신청을해서 등록하려는데 자꾸 통신상연결이안된다하고 네트워크문제라고뜨네요 다른인터넷어플들은다잘되는데 왜그런지모르겠네요',
#        '어플을 쓰기위해 일부러 카드까지 신청하게만드는건 아닌거같습니다. 어플이 바뀌는거였지 카드를 새로 만들게 하기위함 이였나요',
#        '동백전 지갑 어디갓어???? 있던게 없어짐.... 어이없네',
#        '엥 곧 앱이 설치 된다고만 하고 설치도 안되고 언제까지 기다려야 설치가 되나요?', '앱설치가안되는데뭘써라는거요?',
#        '소득공제부분에 입력이 안돼요 오류가 계속나네요 실물카드 변경해야하고 새로받아야하고 너무 불편하네요 기존처럼 삼성페이로 결제가능한가요?',
#        '불편한 UI 정신없는 인터페이스에 대한 피드백이 많네요.\n\n제일 개선했으면 하는 부분은,\n“앱을 들어가자마자 잔액을 볼 수 없다는 점”입니다.\n\n동백전과 같은 체크카드는 잔액이 가장 중요한 정보인데 왜 안쪽에 숨겨뒀는지 모르겠습니다. 굳이 내 지갑 버튼을 누르지 않고도 볼 수 있도록 제일 첫화면에 배치시켜 주세요.',
#        '업데이트 하라고해놓고 안됨! 이건 무슨 경우인지?',
#        '등록 가맹점 검색, 확인할 수 있도록 해주세요. 모든 가게가 등록한 게 아니라서 일일이 확인해야 하는데....지난 번 케이티는 검색배너덕에 편했거든요',
#        '안대는데는데무선평가',
#        '사용가능금액이 캐시백포함인지아닌지 알수가있어야죠\n사용자가 항상 그거 합계를 하던지 빼던지 해야하는건지 ... 캐시백빼고는 얼마가 있는건지 좀 구분해서 볼수있게 하면 안되요? \n기능성 개똥망어플',
#        '동백전 앱이 설치가 안돼네요',
#        '네이버 밴드 어플을 악성코드로 인식하네요. 밴드어플을 삭제하고 어플설치후 밴드를 다시 설치하니 다시 악성코드로 인식... 밴드를 사용해야하는데 어찌해야할지',
#        '신규회원가입을하고 사용하려고하는데 잔액을 이동시켜야된다고해서 하라는대로 입력을했는데 카드정보가없다고 이동이안됩니다.잔액 이동안해도좋으니 그냥 쓰고싶은데 잔액이동을안하면 다음화면으로도 넘어가질않습니다. 저만이러는건지 다그런건지 궁금합니다 이문제점을 피드백주셨으면합니다.감사합니다',
#        '캐시백 이용시 기존 동백전 앱에는 on버튼만 키면 금액과 합산되어 사용할 수 있었는데 일일이 사용금액을 입력해야하고 10분안에 사용해야하는 거까지 번거롭네요 카드도 재발급받아야하고 소득공제신청도 해야하고...캐시백 이용 수정 안되나요?',
#        '네트워크가 원활하지 않아 안된다고 뜨네요. 그런데 옆에 남편은 확인이 잘되는데 뭐가 문제인가요? 통신세기의 문제도 아닌거 같은데..핸드폰 버전에 따라 차이가 나는건가요ㅡㅡ 확인이 안되니 답답하네요.',
#        '소득공제 실명인증에 여권상의 영문이름은 왜 넣나요? 생전 처음듣는 회사에 운전면허번호, 주민번호 뒷자리까지 다 기입하는 신분증 사항 넣는것도 찜찜한데.. 영문이름 안넣으면 진행 자체가 안되네요~ 소득공제 신청하면서 이런경우 처음봐서요.. 사용내역이랑 캐시 적립내역 보는것도 어렵게 만들어놨고, 어플 개발 한번도 안해보신분이 만든거 같아요ㅜㅜ 젊은사람도 불편한데 어르신들은 어떻게 쓰시나요',
#        '동백전의 의도는 너무 좋으나 앱이 너무 안 좋습니다. 동백전이 활성화하지 못하게 된다면 앱이 가장 큰 비율을 차지할것 같군요... 계좌등록하려고 ARS전화하고오면 다시 첫화면으로 돌아갑니다. 어찌저찌 통과를 해도 제계좌에 1원이체 후 인증숫자를 쓰라는데 그 확인하기위한 타행어플이 같은 휴대폰에 있는데 확인하고오면 다시 첫화면... 처음부터 다시 해야합니다... 결국 5번 시도했다고 오늘 더 못한다는군요...',
#        '동백전이 어플없이 사용가능하다면 모르겠지만, 필수적으로 어플이 필요한 서비스인데 이 정도로 불안정하면.. 이건 매우 큰 문제인것 같습니다.. 안정화좀 해주세요.. 와이파이 LTE 5G 어디서도 안정적으로 작동하지 않습니다.. 정상작동 하는 경우보다 어플실행시 메인화면만 나온 상태로 멈추는 경우가 더 많습니다',
#        '기존 동백전카드만으로 신규앱에 등록되도록 빨랑 시스템 개선하세요 4일간(4.1~ 4.4)의 여유 있었는데 무작정 덮고 가시네요 선불카드 발급 강제조건이 코나아이의 "신의 한수" 이세요? 다 보입니다... 공짜라는 선불카드가 메인이 되고 기존체크카드를 연계하여 서브로 묶는 사유가 다 있으시죠.. 기존공지대로 기존체크카드 바로 등록되도록 앱 개선하세요 시민들 불편을 기회로 부산시와 협상 다시 할려고 하세요 부산시 동백전 운영도 시민들 비싼 세금으로 운영되고 있어요.. 시청 및 코나아이 모두 "부산 시민들"이 바보로 보이셔요? 코나아이 앱도 이전 KT 수준으로 향상 시켜주세요 현재 수준이 너무 낮습니다 가맹점에서 사용하면 잔액 및 캐시백에 실시간 반영이 정상입니다. 모든 시민들 바램은 요약하면 기존체크카드를 코나아이 동백전 앱에서 단독으로 등록가능토록 하시고, 앱 구성도 대폭 향상시켜 KT수준으로 해주세요. 변명성 답변은 사양합니다.',
#        '사업주바뀔때 전산시스템 확인 안해보셨나요? 기존 동백전카드앱 사용불가로 다시 동백전 앱카드 새로 설치 첫화면이 회원가입 유도로 카드 주소입력하고 새카드 발급으로 넘어갑니다.\n간결하고 보기편하게 하던지\n조잡하고 난잡해요\n그리고 기존 가맹점주로 사용했던 화면은 어떻게 전환되는거하고 가맹점 신청하는법도 자세히 안내도 없네요? 니들이 알아서 찾아보고 해봐라는건가요?\n바뀌지전에 앱 테스트 안해보고 추진한건 무슨 경우죠? 이거 고객지원센터 연락해도 해결할수 있는 부분은 없는거 아닌가요?? 내부적으로 혼란 많은거 같은데 빠르게 수습처리 바랍니다. 업체를 바꾸던지 기존꺼 사용하게 해주던지 빠르게 처리바래요\n똑같은거 글내용 복사하고 붙였다 하지마시고 글 하나하나 진전성있게 피드백해주세요',
#        '아무것도 되는게 없어요. 운영사가 바뀌고 삼성페이도 안되고 그냥 안쓸래요.',
#        '아니 QR기반 회사 KT가 왜 카드를 발행해요? 카드는 또 하나카드네? 하도인가? 대기업들 대단하네요. 신청하는데 뭔 개인정보를 이렇게나 많이 요구하는거임? 개인정보 간소화 시대에....',
#        '새카드 발급안받고 기존카드만 사용하고 싶은데 그냥 발급 안받고 넘어가는 메뉴를 빨리 만들어주세요 !! 기존카드 그대로 사용가능하다고 문자로 안내 다 해놓고 새카드 발급 받아야 동백전 잔액을 쓸수 있다니 이게 무슨 경우 인가요??? 진짜 어이가 없습니다!!',
#        '별 하나도 아깝다. 기존 동백카든 쓸려면 이름도 거창한 웰컴카드 만들어야하네! 부산시 일 이따구로 할꺼냐! 기존 카드만으로 되게 바꿔라!',
#        '선불카드 오늘 받아서 이관된 금액으로 결제했는데 캐시백이 안됩니다. 왜 그렇죠? 바뀐후로 불편한 점이 많습니다. 개선 부탁드립니다.',
#        '기존카드로 등록하려니 카드정보를 찾을 수 없다 나와요 삭제 여러번 다시 해봐두 안됩니다',
#        '쓸데없이 카드1개 왜 더 추가발급하게 만들었나요 대실망입니다',
#        '무조건 신규카드 발급은 그렇게 살계되었다고 하는데 그렇게 설계를 안하면 되지않나요. 실패한 앱이네요. 원래 앱이 직관적이고 디자인도 이쁘고 사용하기 편리했는데 왜 교체했는지 의문이 가시질 않네요. 전국 지역카드는 코나아이에게 몰아줘야하는 이유가 있나요? 어떤 이권이 개입한건지. 주소와 개인정보를 빼내기 위한 신규발급인가요. 이런거 한번 하면 미친듯이 피싱문자와 온갖 마케팅전화가 오는데 당분간 짜증나겠네요. 그리고 디자인도 인터페이스도 촌스럽고 구려요.',
#        '사용자들은 새카드를 발급받고 싶지 않단 말이다. 새카드 발급해라고 개소리 매크로 복사해 써 넣지 말고 기존 카드로만 연동해서 쓸 수 있도록 해 달란 말이야. 정맣 몰라서 이러고 있나 영자야.',
#        '장점이 정말 1도 없네요. 앱 자주하는 질문에서 복붙합니다. 참고로 삼성페이안됨^^ 기존 체크카드와 신규 후불카드의 차이점 (1) 간편결제 선불카드는 실물카드로 결제 가능 체크카드는 실물카드 미 소지시에도 결제 가능하며 삼성/LG페이 등 탑재하여 사용 가능 (2) 충전한도 소진 시 충전금액 소진 시 선불카드는 결제가 불가하여 계획적인 소비가 가능 체크카드는 계좌 내 잔액이 있을 경우 결제 가능 (3) 소득공제 선불카드는 동백전 앱에서 소득공제 신청해야함 체크카드는 별도의 소득공제 신청 없이 자동으로 연말정산 자료에 반영 (4) 교통카드 기능 선불카드는 교통 기능이 탑재된 카드 도입을 검토중 체크카드는 후불 교통카드 기능 탑재를 신청하여 발급받은 경우에 한해 가능 (5) 신규 발급 선불카드는 동백전 회원 당 1장 무상 발급 체크카드는 기존 동백전에서 이용한 회원에 한해서만 신규 동백전에 연동하여 이용 가능 ※ 할인, 캐시백 및 이벤트는 카드종류와 무관하게 이용 가능',
#        '왜 카드를 다시 하나 더 만들어야하는지 모르겠습니다 별점 하나 주기도 아깝네요',
#        '어플 메인화면에 계좌잔액, 캐시백잔액, 총 잔액이 바로 떴으면 좋겠어요. 가맹점 검색도 가능했으면 좋겠어요.',
#        '앱이 열리지가 않아요 잔액이 얼마남았는지 확인할수가 없네여',
#        '가맹점 검색하는 메뉴는 어디다가 팔아먹었나요? 부산관광 추천 뭐 이런 메뉴는 빼고 간결하게 변경하고 가맹점 검색 기능 복구하고 메인화면에서 캐시백 사용 여부를 원클릭으로 바꿀 수 있게 해주세요',
#        '직관성이 너무 떨어져요 캐시백 받은 금액이 얼마인지, 사용 가능하고 불가능하게 하는 버튼은 어떤 것인지, 사용처 등등 너무 복잡하고 정신없습니다. 저도, 부모님도 헤맬 정도로 직관성이 너무너무 떨어져요. 디자인 개선 부탁드립니다.',
#        '카드 재발급 강제하고 선불카드 소득공제 확인은 주민등록증 이나 운전면허증 정보 입력에 여권 영어이름에 주소까지. 과도한 정보요구에 편리성도 전혀 없음. 운영업체 바꾼 이유를 모르겠음.',
#        '금액중 현금이 얼마인지 포인트가 얼마인지 구분을 좀 해주세요. 살면서 앱평가 처음 남겨보네요. 그전에 사용하던 앱보다 너무 불편해졌네요.',
#        '카드이관이 안되요 카드잔액은 나오는데 아무리 카드정보를 몇번이고 입력했지만 없는카드라고 자꾸 뜨네요 언제쯤 이관이 될까요?',
#        '충전금액 확인하고 쓰려고 했더니 어플은 켜지지도 않고 장난치는 것도 아니고 계좌결제로 생돈만 나갔잖아요 캐쉬백도 못받을 거면 그냥 신용카드 쓰고말지 뭔',
#        '이거 이전 카드 등록이 안되는데... 카드에 없는 바코드입력하라고 하질안나 카드번호입력하면 등록안된 번호라고 뜨네요 잔액확인까지 다되는데 이전카드 등록이 안되다니 이거 금융사기앱처럼 여겨지네요 무능해서 인수인계가 제대로 안되서 이런건지 아니면 업무자체에 집중을 못해서 이런 사고가 나는건지 능력은 안되는데 시에서 밀어주기 해서 인수한건지 다른 앱평가사항을 봐도 형편없네요',
#        '앱더럽게안됨 안들어가지고 삭제했다가 다시 들어가니 로그인 화면도 없고 회원가입하라고 뜸 인증도 안되고 먹통이고 뭐 어쩌란말임?',
#        '앱이 어제부터 업그래이드를 하라더니 럽그레이드도 안되고 재설치도 안됩니다 충전이나 잔여금 확인 마일리지 사용을 확인 할수가 없습니다 빠른 조치 부탁드립니다',
#        "이전 동백전앱보다 직관성이나 사용의 편의성이 많이 떨어지는 것 같습니다. 첫 화면이 너무 복잡해보이고 개인적으로 중요하다고 생각되는 '사용가능 금액, 잔액 및 캐시 등의 숫자' 크기가 너무 작습니다. 이전 동백전앱은 첫 화면이 심플하고 딱 필요한 정보(숫자)들만 큼직하게 표시가 되어 보기가 참 쉽고 좋았거든요. 피드백 많이 받으시고 하루 빨리 개선되길 바랍니다.",
#        '이전 동백전이 더 간단하고 직관적이었어요 사실 이앱을 사용하는 가장 큰 용도는 \n잔액확인\n금액충전\n포인트\n이 세 개 밖에 없는데, 들어가자마자 메인에 이 세개가 없고 너무.. 정신 없어요\n심지어 첫페이지에 잔액이 안보이는게 좀..\n내 지갑이라는 걸 하단에 눌러야 위에 핵심 기능이 뜨네요 \n앱이 본래 기능에 충실하게 메인이 좀 단순화 되면 좋을 것 같습니다.',
#        '카드정보가 기입후 완료창이 안뜨네요ㅡㅡ',
#        '똥입니다 잘쓰다 안되서 몇번을 다시해도 예기치 못한 오류라고 나오네요 짜증',
#        '개인 정보 입력만 13회 했습니다. 이 어이없는 오류 뭡니까?',
#        '분명히 지난 앱이 어떻게 구동되는지 봤을텐데 기본적인걸 애초에 안넣고 업데이트로 하니 ㄷㄷㄷ',
#        '회원가입 과정중 인증번호 전송 버튼을 아무리 눌러도 전송이 되지 않음',
#        '님들 이거 새로 발급되는거 동백전 전용 선불카드 입니다. 은행카드 아닙니다.. 앱카드 등록이 안댑니다. 삼성페이x 기존카드(은행카드) 들고계신거 저처럼 필요없다고 연동되어 넘어온 앱에서 삭제하시고 신규꺼 쓰실려는분 삭제하지마세요. 기존카드는 연동만되지 신규로 새로 연동(등록)안댑니다 ㅋ 앱카드 이제 못쓰네요ㅋㅋㅋㅋ 누구 머리에서 나온거지요? 전에꺼 가져오기는 되는데 다시 등록은 안댄다??? 앱카드 왜안댐?',
#        '업데이트가잘안됩니다 계속시도해도잘안되요 확인하기가잘안되요',
#        '아니 앱 설치해서 들어가니깐 이앱을 삭제하시겠습니까 뜨고 예하면 진짜 삭제되고 아니오하면 그냥 흰화면이고 용량 문제인가 싶어서 이것저것 다 지우고했더만 안되네 어쩔거에요',
#        '인증안됩니다. 전화번호 누르고 인증하기 버튼이 먹통이네요. 혜택도 좋은데 이러다 잊혀져 갈까 걱정입니다.',
#        '연결계좌 여러개 할수 있도록 조치 부탁 드립니다 충전시 연결계좌가 하나라 사용이 너무 불편합니다',
#        '단순 합계도 안되고, 무슨 문의만 하면 답변 가능한 것도 하나도 없고, 앞으로 이렇게 개선하겠다는 것도 없고, 도대체 무슨 생각으로 이 사업을 하려고 했는지 의문임.',
#        '사용을 하라는건지 마라는건지... 계속 설치만 하라고 뜨고 설치는 됬다고 하는데 어플은 안깔리고... 똑같은 방법으로 몇번을 하고 있는지 모르겠네요;;; 무한으로 설치만 하라는데 어찌해야하나요???',
#        '잔액 표시를 캐쉬백잔액 사용 할때 안할때 변경을 하면 남아있는 잔액이 바뀌어야 구분이 갈텐데 이돈이 캐쉬백합쳐진 돈인진 아닌지 구분이 안돼요',
#        '당신들은 정확한 정보를 소비자에게 제공할 책임이 있다. 이관시 자동으로 연결되게 해 놓고 "이미 체크카드 연동시켜서 카드발급 당일 취소가 불가하다"는 말 자체가 어불성설임. 선불 줘도 안쓴다는 사람 천진데 몇 만 개의 쓰레기를 또 만들려고? 수령 후 해지/취소도 불가하다는데 쓰지도 않는 카드에 내 개인정보 엮어놓기 싫음. 당신들은 처음 앱 시작시 기존 체크 카드 계속 사용할 건지 선불 카드 새로 발급할 건지 물어봤어야 함. 취소 요구자 대다수가 마치 새카드 발급 안받으면 이용 못하는 것처럼 유도한 안내에 속은 사람임. 나는 체크카드 이용이 훨씬 편하고(잔액부족 시 연동 카드에서 결제 가능한거 진짜 편함) 체크카드는 소득공제도 자동으로 되고 지금 사용하는 교통카드로 계속 사용하고 싶으며 선불카드는 필요없음. 이에 대한 답변 및 해결 바람.',
#        '앱을 열때 마다 폰번호와 맞지않다고 나오고 초기화하라고 해서 몇번을 다시 했는지 모릅니다. 돈 입금시켜 놓고 사용할려고 하는데 이따위로 앱을 만들어 나서 너무 불편합니다.',
#        '이거 머 등록하려해도 안되고 기존카드등록하려하면 몇번이고 해도 카드가 없는 정보라고 하고..안되네요 결국. 이런걸로 무슨 서비스는 한다는건지 내 잔액만 못쓰게 만들고.',
#        '기존 실물 카드를 갖고 있어서 연동하려고 시도하다가 글씁니다. 바코드 인식이 안되서 카드정보를 직접 입력 시도를 총 4회 했고 틀린 게 적은건 없는지 일일히 확인해가며 했습니다. 근데 안됩니다. 문제 발생시 어디로 연락하라 등의 안내도 없고, 리뷰들 읽어보니 답변도 무성의하네요. 이렇게 운영할거면 나도 충분히 할 수 있을 것 같습니다.ㅋ ※앱 삭제 후 다시 시도해봤습니다. 여전히 안됩니다.',
#        '멀쩡한 카드 왜 바꿔야 하는지 모르겠다. 이게 시민을 위한 정책이냐. 체크카드는 왜 등록이 안되나? 증말 짜증난다.기존 체크카드도 사용이 안된다. 뭐냐. 별점 한개도 아깝다.',
#        '앱 실행하니 인터넷연결 안된다고하네요.연결되니 이글도쓰고있는데..재설치해야하나요? 다시 입력해야하나...ㅜ',
#        '앱이 이유도없이 자꾸 꺼져서 빡쳐염',
#        '디자인, 편리성 둘 다 전보다 구리고 쓸데없이 카드 새로 발급받게 하면서 발급 취소도 못하게 해놨네요^^',
#        '확인할수없음',
#        '또 앱 실행이 안 돼요 몇번짼지 모르겠네요 언제 개선되나요?? 오늘 동백전앱 오류때문인지 평소에 동백전 결제되던 프랜차이즈 빵집에서 결제가 안 되더군요',
#        '머하는거야 일부러 안되겠했냐 왜이래 자꾸',
#        '앱 꺼짐 문제 앱 들어가서 캐쉬백을 누르면 앱이 꺼져버리는데 어떻게 해야되나요? 다시깔아도 마찬가지 입니다',
#        '새로 가입해서 새로 쓸모없는 카드 발급해서 거기다 연동하라는 짓까지함 앱 기능부터 호환성까지 기존 잘되던 kt에서 이 회사껄로 바꿀 아무런 이유가 없는데도 왜 바뀐건지 알수가 없음. 커넥션이라도 있나?',
#        '동백전을 사용하는 모든 사용자가 이미 카드가 있는데 왜 새로 발급 받지 않으면 사용하지 못하는지 모르겠네요. 회원 가입하고 개인정보 입력하면 기존 발급카드에 대한 정보도 보이는데 새 카드 발급 없이 기존카드 사용 못하는 이유가 있나요? 제휴카드사 변경, 카드발급실적 늘리기 뭐 이런 이유인가요? 이유라도 알고 싶은데 안내도 없고, 불필요한 카드 재발급으로 자원도 낭비되고, 뭔가 사용자 편의는 생각되지 않은 정책이내요',
#        '알뜰폰 유심으로 변경후 인증된 폰번호와 일치하지 않다는 메세지나옴ㅡ초기화해주세오ㅡ 그래서 초기화하고 회원등록 다시 ㅡ 환영합니다ㅡ 앱 닫고 앱을 열면 똑 같은 메세지 뜸. 앱지우고 다시해도 똑 같은 현상.3번 했음. 폰번호는 변경안함.통신사만 변경함.',
#        '기존카드에 바코드는없고 입력하니 등록할수없는카드라는데 어떻게쓰라는말인가요?',
#        '기존 어플보다 못할 정도면 회사도 신뢰가안감 개발자는 만들고 직접 사용안 해보나요?',
#        '오늘은 앱이 전혀 열리지 않네요. 무슨 일인지 몇번을 시도해도 열리지 않아요. 답답하네요. 짜증 만 나네요. 이런경우 첨 이라 당황 스럽네요.',
#        '세상엔 플라스틱 쓰레기 줄이라고 난린데 새 카드 발급해야 기존카드 연동할수있다는 글이있던데 사실입니까? 그럼 충분히 기존카드만으로 연동할 수 있는 시스템이 되어있다는 말 아닌가요?',
#        '안드로이드 링크로 들어가니 구글 비번 입력하라해서 입력했는데 오류라해서 휴대전화로 인증하라해서 했습니다. 해외 구글에서 인증번호 전송왔어요. 그리곤 동백전 설치됨이라고 뜨는데 폰에는 새로운 동백전 아이콘이 없어요. 설정에 애플리케이션 검색해도 없어요. 이거 어떻게 된거죠? 혹시 피싱 당한건가요? 신규등록 같은 내용 없었어요. 해결방법 부탁드려요.',
#        '저기 인증 문자가 안오는데 어떻게 하나요?', '아니 카드 등록 자체가 안되잖아요',
#        '리뷰는 스마트폰 쓰면서 처음 남겨봅니다. 10만원 충전해 놓고 사용하려고 보니 네트워크 연결이 안됩니다? 이따구로 뜨면서 꺼지고....리뷰 확인해보니 와이파이에서는 된다고 해서 와이파이 접속후 해도 똑같은 증상 이네요.. 장난하는것도 아니고 빠른시일내에 환불해 주세요 못씁니다. 내 돈쓰면서 스트레스 받는경우는 뭔 경우인가 모르겠네요...',
#        '아이폰은 버리는 건가요? KT가 운영사 일때는 쓸때마다 푸쉬 알림도 즉각즉각 와서\n잔액이나 포인트 등 여러정보를 볼 수 있는데 이건 좀...\n\n고객센터와 통화도 했었고, 폰 자체에도 알림 허용도 하고, 어플상에도 알림도 켜 놨는데도\n여전히...\n빠른시일내 개선 부탁드립니다\n코로나 시국에 건강유의 하세요^^',
#        '모든답변을 븥여넣기하네 헐 참~~ 담당자 이름 머고?',
#        "댓글마다에 달리 '신규동백전카드신청>수령후등록>기존카드연동'은 어디있나요? 등록하다보면 나오겠지하다보니 그냥 신규로 다 완료 되어버렸어요. 취소도 되지 않네요.. 뭐죠 .. 이 쓰레긴",
#        '충전시 연결 계좌가 하나만 등록되는건가요?? 기존에 여러개 등록을 할수있어 편했었는데 뭔가 좀 불편하네요...',
#        '본인인증 방법을 추가해주세요 본인명의 핸드폰이 아님 가입자체가 안된다니? 뭐 이런 어플이 다있어요? 카드발급은 은행에서 되고 어플은 사용이 안되고? 신용카드사나 은행은 핸드폰말고도 여러가지가 있는데 무슨 배짱으로 인증을 하나만 하나요?',
#        '진짜너무대박불편합니다ㆍㆍ삼성페이도안돼ㆍㆍ기존편한걸 전부없애고 이게머하는짓인지 모르겠네요 기존카드등록하려해도 안된다고뜨고 새로발급받은걸삭제하려니 기존체크카드가연결되어있어서안된다하고 이게머하는겁니까 별주기도아깝네요 이게시글도 별하나는줘야 올릴수있네요 참나!',
#        '로그인이 안돼요 로그인해서 가입한 후 카드등록하는데 바코드도 안먹히고 눈 앞에 있는 카드 번호도 안적히는데;; 이거 새로 발급 받으라는 건가요? 해결 방법 좀 알려주세요.',
#        '동백전 pc페이지에서 신청하는 바람에 해당선불카드가 도착할때까지 카드 사용을 하지 못하고 이러지도 저러지도 못하고 있습니다. 이 부분에 대해 안내가 되었더라면 좋았을텐데 많이 아쉽네요.',
#        '앱이문제네요 성질돋구네요',
#        '업데이트가 왜이리 안되나요? 카드를 쓰고싶은데 업데이트가 안되고 앱이 안열려서 못쓰고있어요 앱삭제후 다시 설치도 안되고 뭐가 문제죠?ㅡㅡ',
#        '회원가입하니 있는 이메일이라고 하고 찾을려고하니 없다고 가입해라고 하고 어쩌라는거죠',
#        '도대체 어디에 뭐가있는지 알수도없이 .. 별한개도 아깝네요',
#        '개발자 보씨오. 빠른 시일 내에 가맹점 검색 기능을 추가하지 않는다면 나도 내가 어떻게 될 지 모릅니다.',
#        '어떻게 씁니까 기존카드랑 다르게 모바일카드번호가 발급되면 어떻게 같이 연동시키나요 모바일카드 사용법은 삼성페이처럼 쓰면 되나요??',
#        '시차원에서 일부러 사용하기 복잡하게 만들라고 한거아닌지 의심이 들만큼 불편함 뭣보다 어르신들은 포인트 어떻게 쓰라고 누르고 금액도 입력하고 실물카드로 10분내 결제하라는지 엄마한테 설명드리면서도 거지같아서 이걸로 동네경제활성화가 될리가 앞으로 원클릭결재가능한 쿠팡이나 이용할생각',
#        '충전하기 눈에띄게좀 아니, 내 지갑이라고되어있는버튼찾다가 충전도 못했네요\n차라리 내 지갑이 아니라 충전하기 등으로 명확하게 표기를 해놓든가 까만색이 아니라 다른 색으로 잘. 보이게  해두던가 변경이. 필요할 것같네요',
#        '이거 기존있는거는 왜 지우고, 굳이 신규 운영업자 선정했나요? 이중으로 세금드는거 아니니가요? 왜 운영사 바꿨죠? 처음에 앱개발에 돈 몇천은 줬을텐데, 이번에 운영사 선정하면서 또 앱개발비 포함되어있을테죠? 부산시 정신차리세요 여기 돈받고 선정했나요? 누가 선정했죠? 왜 다운그레이드가 되는거죠? 1년뒤 다시 만든 앱이면 더 좋아져야되는게 정상아닌가요? 이거 리뷰 좀 보세요. 이렇게 최악인 리뷰가 달린 어플은 처음 봅니다. 누가 뒷돈 쳐먹고 만들었나 진짜 개구리네',
#        '최소한 기존의 편리한 기능은 따라가야 할거 아니냐? 너희들 대학생들 시켜서 앱 개발시키냐? 편리하라고 만든 앱을 이딴식으로 만드냐? 고객들 목소리가 이렇게 많은데 장기간 반영된게 하나도 없네. 국민신문고든 부산시청이든 정말 여기 고객 평가 다 올려서 개선사항 건의를 할겁니다. 이건 시에서 돈 먹는 앱 하청업체 날강도 수준이네',
#        '진짜 ui부터 편의기능 싹다 최악이네ㅡㅡ 삼성페이등록도 안돼 바코드결제도 안돼 qr결제도 안돼 별 쓰레기같은거 다보네. 진짜 코나아이 안그래도 이미지별로인데. 부산시는 왜 이런 거지같은곳이랑 계약했는지 이해가안되네. 전 운영사보다 나아야지 정상아니냐? 1도 나은게 없다ㅡㅡ 별하나도 아깝다',
#        '설치가 안됩니다',
#        '일정 시간 미사용으로 작업이 중단 되었습니다 라고 계속 떠는데 어떻게 하면 되나요. 삭제하고 다시 설치해도 마찬가지 입니다.',
#        '선불카드 정리하면 삼성페이 등록이 안되고 실물카드 없거나 잔액 없으면 결제가 당연히 안되고, 소득공제도 따로 앱으로 신청해줘야함ㅋㅋ쓰레기 카드 맞나요? 진짜 어이가 없어서 웃음밖에 안나오네요ㅋㅋ장점이 1도 없는 카드를 붙이고 있네 클라스 오집니다.',
#        '기존카드가 있어서 그대로 쓸려고하는데 카드번호 월/년 cvc 똑같이 몇번을 시도 계속 일치하는 정보가 없다고 오류 뜨내요',
#        '이번달만 오류가 몇번인지..ㅡㅡ 하 이렇게 오류가 많이 나는데 어찌 쓰란말인가요? 여분으로 다른카드 더 들고다녀요 개선한다면서 전혀안되고있네요^^,,,, 어플개발 실력자좀^^',
#        '어플실행시 오류. 오늘카드받아쓸려했더니 바로어플접속 먹통 이래가 뭐하겠나요?',
#        '왜 카드를 새로 발급 받아야 하나요? 기존 카드 그대로 사용된다고 하지 않았나요? 카드 이관절차 진행하지 않으면 앱 사용 진행도 안되고 도대체 이게 뭐하는거임?',
#        '설치안됨', '니들 도대체 뭐하냐', '카드 등록을 하는데 자꾸 카드정보를 찾을 수 없다고 나오네요 허허....',
#        '꼭 몇번 클릭해야 연결됨',
#        '기존카드를 그냥 사용할 수 있다고 해놓고 회원가입하면 바로 카드 신청하라고 뜨고 다음 화면으로 넘어가지가 않네요. 제가 잘모르는 거라면 설명 좀 해주시고 일부러 그렇게 만든거라면 욕 좀 많이 들어야 겠네요.',
#        '안들어가져요 먹통입니다..다시 설치해도 그래요',
#        '신규 선불카드를 의무적으로 발급시켜 기존 체크카드가 사용하지 못한다는 인식을 줍니다. 그로 인해 사용하기 더 편리(삼성페이, lg페이 등록가능, 은행사 별 결제금액 할인 등) 했던 기존 체크 카드를 폐기하게끔 유도했던 점이 최악입니다. 많은 사람들이 신규 선불카드 발급 때문에 기존 체크카드를 잘라버리거나 폐기했습니다. 부산시와 운영사 측은 당연히 공지했다고 했지만 애초에 이런 혼란을 생각 못했다면 그것도 부산시와 운영사가 실력이 없었다는 거겠지요. 저는 오륙도페이도 쓰고 있지만 요즘 시대에 실제카드를 들고다니는 것도 조금 불편합니다. 동백전, 오륙도페이 등 코나아이에서 운영하는 선불카드 형식을 은행 IC카드처럼 사용할 수 있게 개선부탁드립니다.',
#        '저기.... 문제가 좀 많아야죠 1. 잔액이 카드사용 후에도 변경되지 않음 2. 이용내역을 눌러도 사용한내역이 몇일째 표시되지 않음 3. 무슨 화수분도 아니고 계속 쓸수있는건지 4. 이런내용을 일일이 1대1문의, 전화로 해결법 찾으라는 건 무슨 태도죠? 5. 어른들도 다 쓰시는 어플인데, 이런식으로 개선이 안되면, 쓰지말라는겁니까? 6. 돈몇푼 아끼자고 부모님께도 권해드린 어플인데, 골칫덩이만 되가네요 7. 굉장히 무책임합니다.',
#        '평가가 아깝다 내 개인정보 삭제해라'], dtype=object)

# %% [markdown]
# ##### 토픽 2
#
# '0.067*"삼성페이" + 0.032*"오류" + 0.029*"연결" + 0.028*"결제" + 0.025*"계좌" + 0.021*"등록" + 0.021*"포인트" + 0.021*"네트워크" + 0.020*"캐시" + 0.020*"불편

# %%
topic_2 = topictable[topictable['가장 비중이 높은 토픽'] == 1.0]

print('토픽 2에 해당하는 리뷰의 개수:', topic_2.shape[0], '개')
# Out:
# 토픽 2에 해당하는 리뷰의 개수: 123 개

# %%
# 토픽 2에 해당하는 리뷰들만 모아서 하나의 df 만들기

topic_2_list = topic_2['리뷰 번호'].unique()
df_topic_2 = df_negative.loc[topic_2_list, :]

df_topic_2.head(5)
# Out:
#           DATE  STAR                                             REVIEW  LIKE
# 6   2020-04-10     1                    이거 진짜 뭔 앱이 연결도 안되고 오류나고 *레기인지..     0
# 8   2021-04-09     1  사용내역에 현금잔액이랑 남은포인트도 같이 정산되어 보이게 해주십쇼 뭐가 이렇게 보기...     0
# 17  2021-04-05     1                 아니 잔액이관도 안되고 상담사 연결도 안되고 어쩌라는 겁니까?     2
# 28  2020-04-13     1           결제됐다 취소되고 지맘대로 카드긁은데서 재결제하러 오라해서 다시 갔다왔음     0
# 40  2021-04-22     1  완전 최악임 .요새 누가 카드실물들고 다니면서 결제합니까. 체크카드 당장 만들어서 ...     1

# %%
# 리뷰 전부 모아보기 --> 복사해서 R로 들고가서 감성분석 진행

df_topic_2['REVIEW'].unique()
# Out:
# array(['이거 진짜 뭔 앱이 연결도 안되고 오류나고 *레기인지..',
#        '사용내역에 현금잔액이랑 남은포인트도 같이 정산되어 보이게 해주십쇼 뭐가 이렇게 보기 힘들게 해놓으셨는지... 부모님도 사용이 어려워 못쓰겠답니다',
#        '아니 잔액이관도 안되고 상담사 연결도 안되고 어쩌라는 겁니까?',
#        '결제됐다 취소되고 지맘대로 카드긁은데서 재결제하러 오라해서 다시 갔다왔음',
#        '완전 최악임 .요새 누가 카드실물들고 다니면서 결제합니까. 체크카드 당장 만들어서 페이 기능 쓸수있게 해주세요',
#        '지금 해외에 있는데 앱설치하면 계속해서 연결오류가 뜹니다. 해외에 있어서 고객센터 연락하기도 어렵습니다. 연결오류 조치 바랍니다.',
#        '초기 동백전 앱 보기 참 편리했는데, 코나로 바뀐 후 너무 보기 불편함. 일부러 그런 건지 역량이 부족한 건지 별 하나도 아까움.',
#        '평점이 왜 2점대일까 했는데 오류 진짜 많이나고 쓰레기 같아요 충전 해야되는데 어차피 오늘 안에 안고쳐질거고 하루 기다려야겠죠? 진짜 별로',
#        '삼성페이는 언제 되나요', '삼성페이 등록 안됨 캐시 사용 시간제한 있음 캐시 다 쓰고 사용의사 없음 완전 불편함',
#        '선불카드도 차이코퍼레이션처럼 기명으로해서 삼성페이 등 간편결제 가능하도록 해주세요. 기존 kt의 체크카드식 동백전에서 되던 것들이 코나카드 선불 동백전에서도 가능하도록...',
#        'ㅠ 어플이진짜 직관적이지가 않음 지역카드인만큼 나이드신분들이 많이 사용할텐데 헷갈리게 만들어둠 최근사용한 어플중에  최악…',
#        '앱이 오류가 자주 뜨고 메뉴얼이 불편하게 되어 있어요.',
#        '앱들어가서 계좌연결하려는데 전화연결조차안되는? 은행직원도황당해합니다 콜센터서는 해줄수있는게없다하고 앱을몇번 깔고지우고한지아십니까? 전화가걸려와야 연결하죠 진짜 몆십번을한건지',
#        '예전 어플로 다시 돌려주세요..뭐가 더 햇갈리고 보기도 불편하고ㅠ',
#        '앱오류가 너무 잦네요...이런데 케이티는 무지막지한 돈을 받아가는지...',
#        '네트워크 오류라면서 어플 접속이 안될뿐더러 오늘 실 결제한 금액 캐시백도 안됐네요...뭐지요?',
#        '삼성페이 왜 안되나요? 엄청 불편해요',
#        '국민을 개돼지로아는 인간들 동백전 난안쓴다 10프로 길들여노코 쓰레기짓하네', '사기수준임.',
#        '네트워크 연결이 원활하지 않습니다. 접속오류 다른 어플과 인터넷은 잘 사용되는 중인데 동백전 어플만 사용하면 이 문구가 나오네요. 접속이 되어도 예기치 못한 경우......문구가 나오며 무한 로딩만 반복되고 동백전 충전을 하려고 몇번이나 어플을 접속해야하는지 모르겠네요. 고객센터로 전화를 걸어도 모든 상담원이 통화중입니다 무한 반복 cs부서가 있는건 맞죠?? 좋은 취지에서 만든 지역화페인데 사용도 제대로 못하고 참 좋네요^^ 별점 0점이 있다면 0점 주고싶습니다ㅎㅎ',
#        '삼성페이 안됨, 10프로 안받고 일반카드 사용', '중소기업 수준도 안되는 어플', '잦은 오류',
#        '왜 기존가입자들이 새로운 카드를 받아야되는지 이해가 안되며 기존카드를 써도 되는건지 첫날부터 혼란스러워 죽을뻔했습니다 일처리가 정말 별로네요 그리고 앱 구성도 예전 동백전이 더 간단하고 수월했던것같아서 실망이 큽니다',
#        '왜 갑자기 접속이 안되나요??? 충전을 못해서 캐쉬백 못받았어요',
#        '아니 저번꺼는 동백전 포인트를 on/off로 간단하게 됬는데 이건 그것도 안되고 심지어 삼성페이랑 연동도 안되네요 왜만들었나요 그냥 저번꺼 쓰지',
#        '코나아이 카드팔이 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 꺼지세요 코나아이 너네 카드는 안써 ^^',
#        '충전오류 무슨 충전할때 원인불명의 오류로 계속 정상적으로 처리되지 않았다고 하고 문의달라 그러는데 애초에 이런 오류가 자주 발생하면 faq에 그런거 답변이라도 적어놓던가 뭐하자는거임 또 주말엔 고객센터 하지도 않네 ㅋㅋㅋㅋㅋ\n+문의하니까 부산은행은 원인불명의 오류로 안된다고 딴 계좌 연결하라는데 바뀌면서 뭔 이딴 오류나 생기는지 ㅋㅋㅋ',
#        '연결계좌에 은행은 언제 늘려줄껍니까 돈쓰지 말까요???',
#        '케이뱅크밖에 안 쓰는데 은행이 없어서 사용 못하는 중ㅋㅋㅋ... 모든 은행 언제 들어오나요? 적어도 이전에 사용하던건 사용하게 해줘야 계속 쓰죠',
#        '앱 진짜 못만들었다 캐시 못쓰게 하려고 잔머리만 굴린듯', '요즘세상에 들어가지지도 않네',
#        '네트워크 다잘되는데 계속 네트워크연결이 불안정하다고 안들어가지네여;; 종종이러던데 원레열리는거도 느리고;',
#        '네트워크 연결이 아안된다고 접속이안되는데 어쩌라고 ㅡㅡ 개같은앱 만들어놨네',
#        '앱이 열려야 충전해서 사용을 하죠 안열리는 경우가 너무 많아요 네트워크가 원활하지않다고 자주떠요',
#        '포인트 사용하기 너무 불편함',
#        '캐시도 안들어오고, 원래되던 삼성페이도 안되도 ui도 직관적이지 않아 불편함 한개도 아까움...',
#        '결제오류가 타카드에 비해 너무 자주나요', '앱으로 결제는 안되나요? 삼성페이 결제는 도입 예정인가요?',
#        '네트워크가 원활치않아 접속이 안된다고 이틀째 발급신청 못하고 있음 요즘세상에 접속도 안되는 어플이 있다니...',
#        '열때마다 다시 종료해야되네요.. 어플 제대로 좀 만드세요...',
#        '예전앱에 비해 너무너무 불편합니다 이전 앱은 충전하기. 사용내역보기. 계좌로 잔여금액 보내는것 등등 편리한 기능들이 보기 쉽게 있었는데 이번 앱은 보기도 사용하기도 다 힘듭니다. 특히 내역 볼때 이전 앱은 충전금액.캐쉬백 금액. 총 사용가능 금액. 사용내역 이렇게 보기 쉽게 되어 있었는데, 이번 앱은 그렇지 않아서 상당히 불편하네요. 그리고 삼성페이에 해당카드 등록이 불가합니다....',
#        '공지를 제대로못읽었는지 기존꺼못쓰고새로만들어쓰란소린줄알고 멀쩡한기존동백카드 삼성페이도잘됐는데...짤라버리고 코나꺼썻더니 뭐 삼성페이도안되고 좋은점이 별로읍네요...페이등록하면잃어버릴일도없는데 이번에또하필분실하고 열이받아한자씁니다..',
#        '요즘세상에 폰으로 결제를못하게 하는게 말이되는건지요ㅡㅡ 삼성페이 안되니깐 엄청 불편합니다 빨리개선해주세요!!',
#        '삼성페이 엘지페이 지원안되나요?',
#        '잔액과 캐시적립금과 구분되서 못보나요? 왜 합산 금액만 나옵니까? 진짜 불편하네..',
#        '삼성페이안되는거 진짜 개같네요', '연결이되야 쓰던가말든가하지ㅡㅡ',
#        '신규카드 신청안하면 사용도 못하게해놓은데다 소득공제 면허증 지역 선택 잘못해서 바꿀라고 돌아가기해도 안되네. 누가 만들었는지 최악이네. 사업자 바꿀때 뒷돈 받았나보네.',
#        '충전은행 어케바꿔요 드럽게불편하네',
#        "보니까 코나 알바들 댓 달러 몰려왔네 이렇게 요상꼬름하게 선불카드 강매하면 좋습니까?? 전화통화도 안 되고. 남은포인트 쓰면 다신 kt가 다시운영하기전엔 안씁니다'",
#        '진짜 말도안되게 느려요 어떤 은행, 증권사, 카드 어플도 이렇게 느린거 본 적이 없네요. 앱 메인화면에서 넘어가지 않은 적도 많고, 이용 가능한 시간인데도 충전이 튕기는 현상도 자주 발생합니다. 제발 제대로 운영해주세요',
#        '삼성페이 안되네^^', '이전 어플에 비하여 가독성 사용성 매우 떨어짐',
#        '새로(강제로) 만드는 카드 삼성페이 LG페이 안됨 ㅅㄱ',
#        '앱자체가 안켜지네요 부모님꺼 계좌연결도 20분째 인증도못하고있어요 인터넷폰뱅킹안하시는분이라 은행까지갔다왔는데요',
#        '어휴.. 포인트 다 쓰고나면 안쓰는게 나을듯 하네요. 요즘도 카드 들고 다니는 사람들 있나요? ㅡㅡ',
#        '기존꺼는 삼성페이도 연결되었는데 이건 안되네요 ㅡㅡ',
#        '아 박형준시장님 동백전 다시 돌려놔주세요 삼성페이도 안되는 쓰레기카드를 요즘 누가 어떻게 쓰라는거에요 짜증나서 미쳐버릴거같아요',
#        '오류 투성이. 접속 됐다 안됐다 네트워크도 불안정함',
#        '전 앱 처럼 충전금액 캐시 구분 가능하게 해주세요 간단하게 알아보게끔 처음나온 동백전 앱 처럼 만들어주세요 보기 불편해요ㅠㅠ 단지 충전해서 쓰고 쓴 만큼 캐시만 받는건데 복잡하게 만들어놨어요ㅠ',
#        '새로 발급받아야한다니...그마저도 삼성페이는 안된다구요????후...코나아이 이관후 더 불편해진건 왜죠?',
#        '충전계좌등록이한계좌밖에안되네요... 앞전꺼에는2계좌도등록해서썻는데.. 최소한..이전에사용했던서비스같은거는비슷하게하고.더새로운기능을츠가하셔야지... 이건....앞전보다.더어렵고..보기도힘들고... 불편하네요...',
#        '부산은행은 결제계좌로등록이안됨',
#        '갑자기 안되니까 어이없네… 아니 왜 갑자기 네트워크 불안정 하다고 뜨고 안 들어가지는 겁니까? 얼마 남았는지도 봐야하고 포인트도 써야되는데 이것 참 미춰버리겠네….',
#        '간편결제가능하다는문자보고카드등록하려하니안되네요 저번보다 가독성도 떨어지고 어떻게 써야할지 어려워졌어요',
#        '아니 왜 잘 되던게 갑자기 네트워크 뭐라하면사 안들어가지냐 ㅠㅠㅠ',
#        '직관적이지 못함 직관적이지 못함. 어르시들도 많이 사용하는데 뭐가 많이 생긴만큼 직관적이지 못해서 사용함에서 불편함. 자동충전한도가 왜 오만원부터인지 이것도 불편함. 이전 동백전 앱이 보기 쳔하고 한눈에 바로바로 들어와서 훨씬 나음. 기존카드 사용안되는 줄 알고 폐기하고 새로 발급받은카 등록해서 사용하려는데 결제안됨 카드 등록도 했고 충전금액도 충분한데 결제자체가 안돼서 사용을 전혀 못하고 있음!!!!!',
#        '갑자기 가맹점 검색이 안되네요. 어떤날은 갑자기 결제 오류나고 이렇게 불안정해서 어디 쓰겠습니까',
#        '별 하나도 아까워요. 캐시랑 충전한 금액 구분도 어렵고 진짜 지난앱보다 겉만 번드르한 최악의 앱이에요.',
#        '별로네요', '그전 앱이 더 펹리하고 보기도 좋습니다.지금앱은 너무 불편해요.다시 돌려주세요',
#        '앱 접근 오류가 너무 자주발생해서 불편하네요 잔액 캐시좀 확이하려는데 이렇게 자주 접속 오류가 나면 어떻게 하죠??',
#        '앞전 동백전카드보다 별루 페이결제도 안되고등등',
#        '삼성페이가 안됩니다 기존카드도 사용가능하다면서 등록하려니 없는 정보라고 등록이안됨 삼성페이되게 해주세요',
#        '앱도 안깔리고 진짜 이거땜시 몇시간 헛수고 하는듯 진짜열받네요..이전앱은 삭제 했고 다시 다운받았는데.. 쓰레기앱임~이걸 왜 코나아이가 받아갔는지 의심스럽네요',
#        '번잡스럽게 만들어놨슴. 코나아이가 어떤 업체인지는 모르겠는데, 교묘하게 잔머리를 굴러서 앱을 만든 느낌임.',
#        '동백전 사업자 가맹점.. 개인 사업자로 개인용 카드 사용하면서\n사업장에 동백전 큐알결제도 가능하게 사용중이였는데이관하면서 동백전 큐알로 받은 결제금액이 같이 이관 안된 것 같다고 이관자료 요청해도 서로 나몰라라\n이거 관련 명확한 자료가 없어서 여기저기 자료요청으로 전화만 수십건 하고 누구는 잔액에 포함되었다 누구는 포인트로 줬다 누구는 아직 이관안된게 맞다 5월초에 이관될꺼다 말이 다 다르다가 결국은 포인트로 이관했다로 끝났지만 \n정확하게 얼마가 이관된건지 자료도 받지 못해 이 찝찝함은 지울 수 없네요',
#        '아니... 계좌등록하려니 계속 계좌번호 오류라고하는데 왜그런거예요? 숫자 잘못친줄알고 10번은 더 넣어좟어여!!!!! 심지어 2개 계좌 다 안되는데... 하... 화가나네요.',
#        '전에사용한앱에비해너무불편해요캐시쓰기도힘들고',
#        '진짜 별로 아니 너무 짜증나서 앱리뷰 처음 남겨요\nui도별로고 , 잔액 잘못 충전해서 환불하려는데 어디서 하는지도 모르겠고 내금고로 옮기면 환불되는지 알고 햇는데 그럼 또 60%넘게 써야한다네요 아 진짜 이전 동백전 화면 참고해서 첫 페이지 깔끔하게 바꿔주세요 아 진짜 이렇게 별로인 앱 첨 써보네요',
#        '앱 오류가 너무 잦습니다. 충전식인데 충전도 불가능하고, 카드 이용도 불가하고 다른 지역 페이에 비해 오류가 너무 많습니다. 대한민국 제 2의 도시라는 부산에 어울리지 않는 수준입니다.',
#        '오류가 너무 잘떠요',
#        '어머니 폰에 동백전 실행시 네트워크 오류에 관한 글이 뜨면서 앱실행이 안됩니다. 지우고 다시 깔아봐도 같은 오류가 반복됩니다. 고객센터는 전화연결도 힘들고 어찌하란말인가요?',
#        '갑자기 네트워크 오류라고 실행이 안됩니다. 앱을 재설치해도 똑 같이 안됩니다',
#        '쓰라는거야? 카드 신청도 안되고 계좌 등록도 안되고',
#        '앱 설치하고 개인정보 등록하니 새 카드 발급받으라네요 근데 방금 뉴스보니 새로 발급 안받아도 된다는데 새 사업자는 도둑놈인지 쓰레기인지~ 부산시민 우롱하는 새 사업자 ㅉㅉ',
#        '별 하나도 아까움. 삼성페이 등록 가능했던 이전 앱과 카드로 돌려주세요. 너무너무 불편해서 못쓰겠어요. 요즘 누가 실물카드 갖고 다닙니까. 다른건 모르겠고 삼성페이 되도록 못하면 사업권 반납하세요.',
#        '연계 계좌 등록 은행에 카카오뱅크 추가 요청', 'URL에 연결해서 깔아도 핸폰에서 앱이 안보이네요 왜인가요?',
#        '어플에 댓글 남겨보는게 얼마만인지도 모르겠네요. 개발자님은 이 어플이 직관적이라고 생각하십니까? 동백전 최초 어플부터 사용한 사용자로서 이건 아닙니다. 젊은 사람도 뭐가 어디에 있는지 모르겠는데 어르신들은 이걸 어찌 사용하라고 이렇게 제작했나요? 이전 사업자 KT보고 대기업 횡포라 했던게 부끄럽네요. 차라리 그 동네는 어플이라도 직관적이고 삼성페이 등 호환성 및 편의성에 관심이라도 가졌지 업체 교체 후 이건 뭐 어플제작 초급자에게 의뢰하셨나 답답하네요. 멀쩡한 기존카드를 왜 자르고 삼성페이에서 삭제했는지 제 자신이 답답하고 한심하네요,,, 지갑 없이 삼성페이 쓰는 사람들은 앞으로도 계속 이놈에 동백전 카드 챙겨서 다녀야 하나요? 그리고 동백몰인가 광고 적당히 하세요. 본 바탕이 엉망진창인데 거기 딸린 몰이 눈에 들어옵니까?',
#        '인터넷 접속이 안될때가 더 많습니다',
#        '선택약정선택하면 네트워크장애라고 뜨면서 진행되지 않음...부산시에서 개인정보를 팔아 장사하는지...',
#        '삼성페이에 카드등록이 안됨 이런 난감한 일이...',
#        '지난 토요일부터 네트워크오류라고 로그인자체가 안됨. 충전.잔액확인안되고,혹시 이런상황일때 은행에서 충전업무가능한지 물어보니 어플에서만 가능하다고함.고객센터는 통화연결이 안됨. 이정도면 쓰라고만들어놓은건지 의심스러움',
#        '동백전 카드 결제지연 오류 아니 무슨 카드가 사용자가 많다고 오류가 되서 계산이 안되나요 ? 사람들이 갑자기 카드 많이 쓰는건 감안하고 처음부터 오류같은건 안나가게해야되는거아닌가요? 이카드 하나만 가지고 밖에 나왔다가 20분동안 안들어가져서 집갔다가 다른카드 가져왔네요. 빨리 보안해주세요. ',
#        '어플 너무 조잡하고 메뉴찾기 어려워요 어르신들 못쓰라고 일부러 이렇게 만든건지', '별로.',
#        '설마 삼성페이 등록안되나요?', '사용장애로 결제잘못됐음 빨리환불해라. 벌써2주째다.',
#        '진짜 불편함 진짜 어떻게 이렇게 불편하게 만들었는지 싶을 정도로 개썩음 충전 금액 다시 계좌로 넣는거도 안되고 금고라는 개쓸데없는거 만들어서 어떻게 옮기는지 설명도 안되어있고 짜증나 죽겠음',
#        '왜 제일은행계좌연결이없나요 그리고 카드는왔는데 잔액충전을못하고있어요 어플이 오류라고 켜지지가않아요 다시깔아도 똑같네요!!!!!!',
#        '삼성페이 않돼나요', '삼성페이도 안되고.. 이 따위로 만들거면 왜 했냐 진짜 ㅡㅡ',
#        '메인화면 글자크기랑 잔액표시를 kt처럼 한 눈에 알아보고 쉽게 바꾸면 안되나요?',
#        '삼성페이 쓸수 있게 해주세요. 갑자기 잘되던거 왜 못 쓰게 바꿨나요?',
#        '보기도 불편하고 삼성페이에는 등록이 또 왜 안되나요',
#        '갑자기 왜 안들어가지죠 낮에 분명 사용하고 방금 가맹점 카페와서 사용하려고 하는데 잔액이 있음에도 불구하고 계속 오류나서 어플누르니까 계속 튕기고ㅡㅡ 지웠다가 다시 깔아도 안되는데요?',
#        '마이너스 없어서 별 1개만 줌 카드신청하고 일주일 만에 받았는데 어플에서 충전이 안된다. 올바르지 않은 계좌라네 .. 하아.... 오프라인 충전은 또 부산은행이나 하나은행가서 하라네 허!! 이걸 쓰라고 만든건지 플라스틱 쓰레기를 받은건지 가입만 시켜놓고 대책이 없니? @@@@@@@@@@@@@@@@@@@@@ 모두 내 명의 맞고요 신한/ 국민 계좌로 등록 시도 했었지만 올바르지 않은 계좌라고 해서 앱평가에 글 적은거임 이런거면 어플 문제 아님?',
#        '삼성페이 기능되게해주세요 기존꺼보다 더 나아지는게 있어야지..실물카드 요즘 누가 들고다니나요 ㅠ',
#        '이거 확인안되는데 왜이렇죠? 결제안된다고하는데 어플에는 결제한거처럼 나오고 진짜 왜그럽니까? 방금 쓴글은 지우고',
#        '다른건 다그렇다쳐도 삼성페이 안되게 해놓은거는 너무 불편하네요. 삼성페이로 결제많이하는 저는 굳이 신규동백전을 써야하나 싶어요',
#        '알아보기 더 힘들고 대체 이걸 디자인 이라고 한건지.이전처럼 직전 캐쉬 적립 내역. 즉시 결제 되었는지 직관적으로 알아 볼수있게 해주세요! 초창기 인터넷 뱅킹 페이지도 아니고 다 숨겨 놓았어요?',
#        '왜 계속 네트워크가 연결이 안된다고 하는지ᆢ와이파이도 무선도 다 해봤어요 고객센터는 통화하기도 힘든데',
#        'ㅜㅜ 예전 앱이 훨씬 직관적이고 편해요....이용할때마다 포인트 쌓이는거 바로바로 볼수있었는데 새로바뀐 앱은 포괄적으로만 보이고 각각의 포인트 내역은 안보네요',
#        '왜 연계 사용이 안되나요? 코나아이로 자동 연결되게 해야 되는거 아닌가요?',
#        '지난 주 잘못눌려 틸퇴처리가 되어서 고객센터와 통화했고 7영업일 지나면 재가입된다고 하셔서 기다렸다가 재가입 진행을 했는데요. 계속 가입 제한된다고 뜹니다 . 확인해주세요',
#        '캐시포인트 사용을 이렇게 만들어 놓으면 불편해서 사용하겠습니까? 전에는 캐시포인트 사용 ON하면 포인트 먼저 결제되고 했는데 이제는 캐시포인트 사용할때마다 설정해야 하고 넘 불편 하네요',
#        '삼성페이가 안된다라.... 불편해서 동백전 절대 안쓸듯',
#        '팝업창 아랫부분 닫기인지 다시보지않기 인지 선택하는 창이 화면에 잘려서 누를수가 없어요ㅠㅠ 제발 팝업창 크기 좀 조절해주세요',
#        '네트워크 연결이 안된다고 합니다',
#        '써야돠는데 왜안되냐고요...자주이라네요정말... 오늘쓸려고있었는데 안되면혜택도안되고뭐죠'], dtype=object)

# %% [markdown]
# ##### 토픽 3
#
# 0.074*"업데이트" + 0.062*"접속" + 0.041*"실행" + 0.040*"사용" + 0.023*"불편" + 0.021*"데이터" + 0.020*"이전" + 0.019*"알림" + 0.018*"최악" + 0.017*"확인"

# %%
topic_3 = topictable[topictable['가장 비중이 높은 토픽'] == 2.0]

print('토픽 3에 해당하는 리뷰의 개수:', topic_3.shape[0], '개')
# Out:
# 토픽 3에 해당하는 리뷰의 개수: 338 개

# %%
# 토픽 3에 해당하는 리뷰들만 모아서 하나의 df 만들기

topic_3_list = topic_3['리뷰 번호'].unique()
df_topic_3 = df_negative.loc[topic_3_list, :]

df_topic_3.head(5)
# Out:
#           DATE  STAR                                             REVIEW  LIKE
# 2   2021-07-13     1  문제가 너무 많네요 몇개월이 지났는데 사용내역 알림이 왜 아직까지 안오는지 그게 뭐...     0
# 3   2020-09-08     1            업데이트를 해야 사용 가능하다는데 업데이트가 안됩니다 무슨 문제일까요?     0
# 5   2020-12-18     1                              이렇게 대책없이 할바에 하지 말았어야지     0
# 9   2020-05-02     2  앱실행 마다 전화번호가 맞질 않다고 뜨며 실행이 안되서, 가입을 계속 다시 하면서 ...     0
# 11  2020-03-04     2          앱에 접속안되는 날이 왜이리많아요? 접속할때마다 30~40%는 접속불가;;     0

# %%
# 리뷰 전부 모아보기 --> 복사해서 R로 들고가서 감성분석 진행

df_topic_3['REVIEW'].unique()
# Out:
# array(['문제가 너무 많네요 몇개월이 지났는데 사용내역 알림이 왜 아직까지 안오는지 그게 뭐라고 아직 개선이 안되는지 이해가 안갑니다. \n게다가 이전 동백전앱은 가맹점 정보 조회가 쉽고 정확했는데 바뀐 동백전은 가맹점이 늘어난 것은 좋은데 조회하면 안나오네요?\n예를 들어 맥도날드 부산시청점은 이전 동백전으로는 결제가 안됐는데 어제 남편이 결제하는 걸 보니 올해는 동백전 결제가 가능하더라구요. 남편말로는 전에 안되던 곳들도 결제 가능하게 된 가맹점이 많다고 하길래 확인해보려고 검색하니 맥도날드 부산시청점은 결제가능함에도 불구하고 안나옵니다.\n\n또한 이전 동백전 앱은 가맹점 검색이 어플내에서 가능했는데 현 동백전앱은 인터넷창에 열리고 검색하는 것도 전에 비해 불편하네요\n\n가능하기만 이전 앱을 사용하고 싶을 정도입니다.\n\n사용내역 알림이라도 좀 빨리 고쳐주세요.\n이게 몇달째 이러는지 정말 이해안되네요',
#        '업데이트를 해야 사용 가능하다는데 업데이트가 안됩니다 무슨 문제일까요?', '이렇게 대책없이 할바에 하지 말았어야지',
#        '앱실행 마다 전화번호가 맞질 않다고 뜨며 실행이 안되서, 가입을 계속 다시 하면서 잔액확인, 충전을 하고 있어요 매번 이러니 넘 불편합니다',
#        '앱에 접속안되는 날이 왜이리많아요? 접속할때마다 30~40%는 접속불가;;',
#        '주유소에서 사용이 안됩니다. 카드를 긁어서 결재하는 방식은 하지못합니다 . 긁을수 있도록 바꿔주시요.',
#        '업데이트가 안됩니다...', '들어가지지도 않구만ㅡㅡ 전화도 안받고... 장난합니까',
#        '업데이트도 잘 안되고.. 잔액 확인하려면 어플 접속해야 되고 너무 불편해요',
#        '어플실행시 정상적인OS가 아니라서 이용할수가 없다고 메세지가 나옵니다. 엘지V40이며 안드로이드10버전입니다. 확인좀 부탁드립니다',
#        '업데이트가 너무 안되네요', '최악의 어플. 예전 동백전이 훨나음',
#        '한번씩 접속이 안된다고 하네요. 주기적인 업데이트 요망됩니다.',
#        '나만 불만 있는게 아니었구나~어디서 얼마나 할인받고 있는지 진짜 궁금한데 애먼 광고들만 많아요..어디로 전화해라 마라하는 순간에 불만 많은점부터 빨리 고치는게 낫지 않을까요?..답글은 또 전화하라하겠지..ㅎ',
#        '앱이 다운로드가 안되고 계속 로딩 중이네요 서버좀 늘려요', '이전앱이 훨씬 나음', '최악',
#        '방금까지 사용했는데 갑자기 결제시 오류가 발생한다며 앱 실행이 전혀 안되네요 동백전 캐시백 사용하려는데 실행이 안되니 불편합니다 빨리 해결해주세요',
#        '카드 이관 신청을 안하면 충전을 못하잖아요. 빨리 해결해주세요.', '앱이 화면이 멈춰있어요 접속이 안되는거같아요',
#        '너무 어려워요. 충전방식이라 많이 번거롭네요. 폰결제 되는 쉬은 방법으로 업그레이드 부탁드립니다',
#        '아니 동백전 앱도 안열리고 왜이럼이거',
#        '최악. 별하나도 아까움.오류가 잦아 결제승인 안되었는데 돈이 빠져 등 가게 사장님과 불필요하게 얼굴 붉히는 일 경험. 고객센터 공지사항도 없이 전화 통화중이라 전화받을수없다고만 대응 자체가 안됨.',
#        'ㄹㅇ 데이터 켜도 로그인 안되는 희대의 쓰레기 앱',
#        '예전 동백전으로 결재 되던곳이 이제는 안되는곳도 많아지고 가맹점이 어디인지 알수도 없네요 문의해도 해결 안되고...',
#        '업데이트3일동안 안되고 앱실행이안되여', '굿', '이전앱보다 불편해서 쓰기싫을정도',
#        '전 동백전앱이 훨~~씬 편합니다',
#        '이번앱은 "사용가능가맹점" 검색이 안됩니다. 가맹점 검색후에 사용가능한지 미리 알았으면 하는데 불편합니다.. [자주하는 질문 바로가기 에 동백전 지역화페는 어디에서 사용할 수있나요? ◎ 별도의 동백전 가맹점 표시가 없어도 부산 지역내 신용카드 가맹점에서는 어디서나 이용 가능합니다. ] 안되는 가맹점도 많아요.. 가맹점 검색할수있게 개선부탁드립니다.',
#        '앱 관리 안하나요??? 업뎃 문제 계속 발생하다가 이제는 네트워크 4G,Wifi 둘 다 문제 없는데도 앱 실행시 오류 뜨거나 네트워크 문제라고 뜨면서 자꾸 팅기네요. 조속히 문제 해결 바랍니다.',
#        '데이터 연결이 불안정하다더니 다른 어플들 접속은 잘만 됩니다. 어플 재설치도 하고 와이파이도 꺼보고 데이터도 껏다 켜고 30분 정도 씨름하다가 포기했습니다.',
#        '하이마트에서 사용가능한다고 나오나 사용이되지 않습니다 확인부탁드릴게요', '벼로', 'ㅇ아',
#        '장난 똥때리는 이벤트...앱 깔때는 or ☞ 깐 후엔 and 기가차네 기가차',
#        '사상최악의 앱인거같아요 기존앱에 비해서 인터페이스가 최악입니다 사용자의 불편을 위해 만든거같아요',
#        '동백전은 좋은데 앱이 말썽이네요 충전할때마다 짜증이 나요 앱이 쓰레기',
#        '사용내역 푸시알림 왠만하면 리뷰 안남기는데 진짜 일대일 문의해도 된다고 하는데 푸시 알림 안와여ㅋㅋㅋㅋㅋ개선쩜',
#        '사용처 제한으로 불편함이 많음. 특히 재래시장에는 카드계산기 없는 상점이 많아 더 불편함~ 그리고 업데이트 하라면서 며칠째 업데이트 했는데도 아직도 설치 중....와 이런다요? 아예 업데이트가 안되네요~',
#        '하... 식당에서 밥 먹고 나가기전에 돈 충전해서 결제하려고 어플을 켰는데 접속이 계속 안되서.. 환급도 못받고 다른 카드로 결제했습니다 .... 이거 진짜 뭔가요 열받습니다 ... 7천원 돈 ... 손해봣네요...',
#        '앱 업데이트를 해야 이용가능하다는데 업데이트가 안되네요', '업데이트 안됨 이전보다 아주 불편 짜증폭발',
#        '업데이트 해야 한다고 해서 업데이트 눌렀는데 계속 업뎃 안되네요. 결국 제때 충전 못해서 혜택 못 받고 화납니다.',
#        '어휴 어플관리 진짜 최악이다', '아주 좋아요',
#        '아니 데이터 무제한인데 네트워크 연결하라하고만 하고 왜 계속 접속이안되나요? 돈얼마남은지 확인도안되고 어플왜 있는건지;; 빨리해결해주세요 제발',
#        '접속도안되고 접속할라하니 업데이트하라하고 업데에트할라하니 업데이트도안되고 어이가없네 별 마이너스로 줄수는없나..',
#        '입기 ㅋㄱ',
#        '알림은 왜안오는가요? 결제승인 및 캐시백 알림이 안옵니다! 일일이 앱에 접속해서 확인을 해야하나요? 알림 따로 꺼놓은것도 없는데..앱 설정에는 마케팅 수신여부 알림만 나와있고!! 동백전 참 전체적으로 답답합니다',
#        '접속도안되고 깔고지웠는데도 접속안되요 개선해주세요', '장난하나?', '별 하나도 아깝다.',
#        '업데이트좀 .. 급하게 사용해야하는데 업데이트하게 만드네요',
#        '동백전이라는 카드혜택은 좋지만 어플만 보면 너무 불편하네요 데이터로 접속하려면 네트워크 오류로 접속불가합니다.',
#        '안들어가짐', '기냥 광고쓰레기 어쩔수없이쓰는듯', '업데이트가 안되네요', '못하다', '넘 좋아요',
#        '앱관리 안하냐 ? 네트워크 접속불량 머냐', '개똥',
#        '구림구림 개구림 뭣이 설치도 번잡하고 필요없는 요즘 쓰지도 않는 충전카드라니;;;; 실물경제가 어떻게 돌아가는지 좀 보고 만드세요!!!!잘쓰던 동백전 1년도 안돼서 바꾸는 이런 말ㄷᆢ안되는...쓰던금액은 돌려주든지 처음의 취지와는 다르게 페이백도 이제 얼마 되지도 않터만ㅡㅡ 부산시민을 이렇게 불편하게 만들다니요',
#        '결제 시 푸시 알림이 안와요 이전 앱에서는 결제 시 푸시 알림이 왔는데, 코나카드로 바뀌고 안오네요. 기능 넣어주세요',
#        '어플이 왜이러죠? 데이터상태에서 사용이 안되면 밖에선 사용하지말란건가요?',
#        '앱 실행이 안됨;; 와이파이 빵빵한데도 안되고 데이터로도 안됨요.. 불편',
#        '업데이트 하라고 해놓고 업데이트 되도 안하고 짜증만 나네. 쿠키, 데이터 삭제해도 안되구만!!!!',
#        '다른어플은 실행이되는데 이어플은 lte인데도 왜 실행이 안되고 와이파이껴야 그나마 접속이 되는건가요? 똑같은답변만 달지말고 업데이트를 해서 고쳐주세요 저는 갤럭시s7엣지입니다.',
#        '로코 정책지원금 사용할수있게 해주세여 정책지원금이라고 이벤트성으로 들어온 적립금이 있는데, 1.2.3가지 방법으로 설정하고 결제를 해 봐도 안됌. \n나만 안써서 날리는거면 상관없는데 나같은사람 또 없는건가? 정책지원금이라는데 카드포인트처럼 눈먼돈이 되는건가 싶어서 짜증.\n애초에 주지를 말던가 줘놓고 사용법 공지도 없어. 포인트 자동사용중인데 사용도 안돼. \n기존 동백전 앱보다 나아졌나 기대했더니\n오히려 이것저것 기능만 많아지고 더 불편.',
#        '결제알림이 오지 않습니다. 어플이 바뀐 후 부터 결제해도 알림이 오지않습니다.\n\n지웠다가 재설치하면 개선이 될까요?',
#        '네트워크 개선좀 빨리해주세요, 일주일째 데이터로도 접속이안되고 와이파이 연결된상태에서도 접속이안되고 어플 들어가는게 하늘의 별 따기수준입니다;;; 불필요한것을 개선할게아니라 접속부터 원활하게되는게 최우선인것같습니다',
#        '업데이트 왜이리 안돼요????', '앱이 와이파이든 데이터든 아무것도 연결이 안되네요. 안정성 좀 신경써주세요',
#        '1도 아깝다.', '안들어가지는게 너무심하네요. 이래서 사용가능하겠어요? 데이터 와이파이 다 안들어가져요.',
#        '욕나올정도로 후짐 며칠전부터 가맹점조회 아예 안됨.', '어플이 실행되야 쓰던가 하죠..',
#        '앱 오류 안고쳐주실건가요?? 충전하려고 앱들어가면 데이터 상태로는 들어가지지도 않고 와이파이로 들어가면 사용자 정보를 가져올수없다고하고.. 쓰지말라는건가요 아예? 좀 고쳐주세요 오류가 너무 심하네요 진짜 ㅡㅡ',
#        '세상에..업데이트하라고해서업데이트하는데계속다운로드중만뜨고짜증나서앱제거하고다시깔고있는데계속다운로드중..이와중에실물카드로결재는되지만쫌짜증.사용자가많아지는만큼서버를큰걸로하든지..',
#        '아니 부산에서 쓰라고 만든 카드 맞습니까 안되는곳이 왜 이렇게나 많은지 참',
#        '업데이트도 설치도 안되요 ㅡㅡ 써야하는데 업데이트안하면 실행불가 하면 어떡하나요',
#        '와이파이 연결시에는 어플 접속이 잘됩니다. 하지만 데이터 사용시 접속이 잘 안됩니다. (데이터 잔여량도 많이 있고, 통신상태도 양호한 지역에서도 마찬가지입니다.) 기기는 skt 갤럭시s8 ,안드로이드 파이버전입니다.',
#        '업데이트가 안되서 데이터, 캐시 삭제했는데도 안됩니다. 삭제하고 다시 깔아볼려고 해도 안되네요.',
#        '업데이트도안되고 왕짜증', '업데이트안됨', '짜증나요 수시로 접속안되요', '하나 같이 에러에 로딩에 ㅡㅡ',
#        '어플 진짜 못 만들었네요.. 툭하면 접속도 안 되고', '접속도안됨',
#        '부산 소상공인을 위해 만든 취지는 좋았으나 너무 일찍이 예산초과로 윈윈효과가 부족함',
#        '앱 개발자 바꿔라 제발!!! 부탁합니다!!!',
#        '출시기념 1월 한달간 이벤트를 하는데 1월 지났는데도 아직 다운로드를 받지 못하는 어플이 있다??! 두둥 탁! 마! 이것이 붓싼의 정책이다! 캬~ 이집 지역화폐 잘하네~~',
#        '개쓰레기같은 앱 사용하려고 해도 부산 동백전 로딩화면만 쳐깜빡이는 개쓰레기같은 앱입니다. 로딩할게 뭐가 그리도 많은지 진짜 욕도 아까운 앱 그 자체입니다.',
#        '다운로드가 며칠째 안되요', '업데이트가 않되요', '앱에 접속이 너무 안됩니다',
#        'UI 개쓰레기 유저 인터페이스가 개쓰레기입니다\n첫 화면에 쓰잘데기 없는 메뉴가 너무 많아요\n그리고 충전화면에서 금액순서가 5만/2만/10만 인것까지ㅋㅋㅋㅋㅋ 이런건 오름차순 배열입니다 기본이에요\n가맹점리스트 확인도 안되고... 1:1문의 남겼더니 성의없이 “그런 서비스 제공 안합니다”이딴 답이나 달고... 앞으로 개선방향을 제시하셔야죠; 일하기 싫나;\n푸시알람도 안옴ㅋ 재설치 재부팅 다해봐도 안옴ㅋ\nkt에서 운영할때 앱이 훨씬 나았음',
#        '동백전 결제 불가 농협 동백전카드로 최근까지 결제 되던 곳도 이제 안되네요.  점원 말로는 결제 되는 동백전 카드는 따로 있다는데 그게 코나 동백전카드 인가요? 이런 꼼수 쓸려고 결제 가능매장 검색 안되게 해놓은건가요? 황당하네요. 이전 카드 그대로  쓸 수 있다 해놓고 이런식으로 제약을 둬서 코나카드 이용하게 하려는 건가요? 부산 사람들 기만하지 마세요. 속보입니다.',
#        '동백전은 좋은데 어플이 왜이래요? 결제가 두번 된거 같아 확인하려고 하니 네트워크 불량이라고 연결이 안되요 또해도 안되요 계속해도 안되요 나중에 집에가서 결제 두번된거 확인하고 다시 돌아가서 결제 취소하고 돌아왔어요 제발 쫌 어플 관리 좀 잘해주세요',
#        '좋은말 할때 이번 달 얼마 썻는지 확인하게 해놔라 왜 이번달 얼마 썻는지도 못보게 하냐',
#        '앱 접속 좀 하자. 지금 몇일째 접속이 안되는건지. 관리할 마음은 있는건지.',
#        '탭으론 접속조차 안되네요. 저 처럼 폰은 2g폰이고 탭으로 인터넷하는 사람은 어떻게 충전하죠? 발급 후 사용 못하고 잇습니다. 빠른 개선 부탁드립니다',
#        '와파든 데이터든 안들어가져요',
#        '어플이 실행안되요 통신중 오류가 발생했다고 어플 삭제후 다시 하여도 그대로 입니다 충전을 할수가 없네요',
#        '앱 자체 디자인은 그럴듯 한데 중요한 정보가 없음 토탈 혜택 내역은 있는데 결제당 얼마 페이백 받았나 내역이 없음 심각함',
#        '앱이갑자기업데이트하라고뜨면서 업데이트 도 안돼고 앱자체가아예안돼요', '버벅거림',
#        '앱깔고 카드재발급까지 해논상태입니다. 그것도 낭비인데, 예전보다 화면에 뭐가 많아 불편해요 딱 내 쓸잔액, 쓴내역만 있던 예전이 더 좋은것같아요. 한눈에 들어오고.',
#        '업데이트가 안되어 사용에 불편합니다. 방법을 가르쳐 주셔요!!',
#        '앱연결하기 하늘의별따기임ㅡ얼마썼는지 확인을할수가없음ㅡ앱이 실행이돼야 뭘하지 ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ LTE상태에서는 앱 안열림 그리고 결제시 계속 오류떠서 결제할수가 없음 가게점원분이 동백전은 늘 오류뜬다고 함',
#        '왜 또 안되냐. 에휴', '맨날 접속이 안됨 . 관리도 안할거 왜 만들었는지..',
#        '앱이 안열려 충전을 못해서 필요할 때 할인을 못받았어요.',
#        '사용내역 푸쉬좀 되게해주세요 사용하고나면 사용내역 캐쉬백내역이 알림이 안되고 직접앱들어가서 조회를 해야 합니다. 답변에 된다고 하셨는데 안됩니다 \n\n예전 동백전은 사용하면 푸쉬로 사용금액 알려\n줬는데 코나아이앱은 사용을 한건지 안한건지 매번들어가서 확인해야함. 너무 귀찮고 불편하니 푸쉬로 알림 기능 되게 해주시기바랍니다',
#        '앱 접속이 왜 안되는거예요? 아 놔 진짜',
#        '지역사업하나 말아먹는 어플이네 어떻게 사업 땄는지 모르겠네요 볼수록 짜증나고 멀쩡한 사업체 바꾸더니 되는게 하나도 없는 것도 역겨워서 동백전도 못쓰겠다 귀사엔 프로그래머가 없나요? 있던 기능 모사조차 못하면서 결제 앱을 만든다는 것도 웃기고 기능을 바꾼게 아니라 능력부족으로 다 포기하거나 반쪽으로 낸거 티나는데 짜증나네 진짜 부산망신',
#        '2G폰 사용중이고 공기계로 앱을 설치하여 동백전을 사용할려고 했으나 유심이 없는 상태에서는 접속조차 안되도록 되어있네요.... 도대체 왜 이런 시스템을 만들어놓았는지 모르겠습니다 제발 평가좀 읽고 개선해주세요 불만이 이만저만이 아닙니다',
#        '업데이트후 들어갈수가 없음', '접속이 안됨',
#        '카드뱌아서 충전하고 사용하는대 어플에는 사용됬다고 금액뜨는대 가게에서는 사용중지되있다고 결제안된다는대 뭔가요 확인해보니 카드 사용등록 다되있는대 왜안되는겁니까 어플은 들어가지다가 첫 로딩화면에서 넘어가지도않내 다시받아도 똑같고',
#        '아니 어플에서는 사용가능하다해서 갔는데 사장님은 사용못한다면서 자기는 들은거 없다고 하고 헛걸음질만 했네요 사용가능한 곳을 좀 똑바로 표시해줬으면 합니다',
#        '이전 동백전보다 사용하기가 너무 불편', '와~~충전할려고 하는데 들어가지지가 않네요!! 앱이 왜 이때위인가요?',
#        '다운로드가안되여..', ',7,aW ,,5', '개느리고 접속 안됩니다.', '업데이트하라더니 사용이안되요',
#        '아니 충전할려고 앱켰더니 실행이 안되면 어쩌라고요 짜증나네', '주말만 되면 접속이 안됨...ㅠㅠ',
#        '지웠다 깔아도 들어갈 수가 없음 -_- 마트에서는 결제가 안됐다고 하고 돈이 빠졌는지 확인을 해야 하는데 이 무슨 xx같은 상황인지,,, 쓸때마다 왜 이런일이 일어나는지.. 충전하고나서 어플에 안들어가짐 네트워크 상태 확인하라면서 별하나도 아깝',
#        '아이폰 알림이 안뜨는..; 새로운 어플은 왜 사용알림이 안뜨는 겁니까??', '어플 잘 되다가 접속이 안되네요',
#        '앱 실행 진짜 안됨 뭐 이런게 다있나 싶다. 캐시백 주니마니 생색이나 내지 말고 실행이나 제대로 시켜주세요',
#        '업데이트가 안됩니다.',
#        '회사 바뀌고 나서 문제가 많네요... 카드결제도 안되고 제한도 많고 고객센터 연락해도 해결될기미가 안보이고 어쩌라는거... 사용하지말라는거지뭐... 회사 급하게 갈아치운것 같은데.. 능력도 안되면서 일거리 뒷돈주고 뺏은거 아닌가 의심이든다 답으로 고객센터로 전화하라고 하지마세요 전화해도 해결안해준다니깐 부산시당담에 전화해야지',
#        '업데이트가 안되서 못쓰겠네요 넘하는거 아네요',
#        '갤럭시s10 사용중인데 접속이안되서 재설치하면 들어가지고 익일에 또 접속안되서 재설치하고있어요 안드로이드os 에 대해서 유지보수부탁드려요',
#        '페이백 받은 금액만 확인해 보는 게 너무 어려워요. 결제할 때 충전한 금액만 쓰고, 페이백 받았던 금액은 안 쓰이도록 설정하고 싶은데 그것도 어딧는지 모르겠어요. 너무 불편하게 만들어진 것 같아요. 제 돈의 분류를 잘 확인할 수 있게 해주세요.',
#        '업데이트도 안되고 삭제하니 앱이 다운로드도 안되고 어쩌라는건지 바뀌고 나서 사용엄청불편하네요.',
#        '좀 어플좀 들어가봅시다. 뭐좀 할라하믄 네트워크 상태가 안좋다하고. 충전도 못하고 사용도 못하고. 콜센터도 연결안되고. 캐시백 주기 싫어서 어플 안열립니까. 이따구로 관리할거면 애시당초 만들지를 만들가. 한시간째 안들어가지는데 도대체 관리자는 불금이라 놀러갔습니까?',
#        '부산시에서 관리비로 100억이나 뜯어갔으면 서버관리좀 똑바로하세요 맨날 터져서 못씁니까왜', '접속을 하게 해달라고',
#        '잘쓰다실행불가', '예전꺼에 비해 불편함만 느끼고 쓰지도 않을 카드 한개 늘어나고 ...', '별루다.',
#        '업데이트가 계속 언되어서 충전이 안됩니다', '솔직히 왜 바꿧는지 모를정도로 너무 형편없어졌네요', '정말 싫다',
#        '불편합니다 저번앱이 훨나앗음ㅠ', '삼페 안되기만 해봐라',
#        '진짜 뭐하는겁니까 별 듣보잡회사가 운영한다고 할때부터 알아봤네요 기술이 안되면 때리치아뿌던가 ㅡㅡ 답변들 하나같이 복붙이내',
#        '진짜 너무하네 예전보다 사용하기는 겁나어렵고 난 내돈넣고 사용하는데 광고도봐야되고 사용하기도 오질라게 어렵고! 짜증밖에안난다 진짜 앱도 지금 열리지도않네',
#        '서버 좀ㅡㅡ',
#        '앱이 안열립니다. 왜이럽니까 진짜 확인 할게 있는데 시골이라 와이파이로. 접속 할수도 없고 데이터로는 접속이 불가 하네요 지금 ㅡㅡ',
#        '느린속도데이터쓰는사람은 와이파이안잡으면아예안됨 밖에서 사용할수가없어요',
#        '어제 결제가 안되서 곤란한 경험을 했습니다. 결국 다른 카드로 했죠.', '이전이 나음',
#        '이전 프로그램보다 눈에도 잘안들어오고 사용하기 불편해요 개선해주세요', '통신오류가 너무 잦아요ㅡㅡ',
#        '예전보다 ㄷ~~불편', '카드를 받고 앱을 실행할려니 안되네요. 이렇게 허접하다니?',
#        '요 며칠동안 네트워크 상태가 원활하지 않다면서 접속이 안되는 이유를 모르겠네요. 충전을 해야하는데 말이지요. 와이파이, lte 접속에 아무런 문제가 없는데 왜 이런건지 조치 바랍니다.',
#        '실행도 안되는구만. 별 하나도 아까워', '혹시 부산 동백전 카드 망했나요?',
#        '업데이트도 안되고 지웠다 깔아도 되지도 않는거 어째 사용하란말이에요',
#        '503오류 뜨면서 실행안되네요 우째해야되나요ㅡ.ㅡ', '쓰레기보다 최악이라는 말보다 더 한 말이있다면 그 정도급',
#        '예전 동백전 앱보다 불편합니다. 적립금 확인이나 사용내역 확인이 많이 불편합니다.',
#        '사용처도 확인안되는데 무슨, 불편하네요', '업데이트 안되요 며칠째인데 관리도 안하나요?',
#        '어플개떡같이 만들어서 켜지지도않고 계속 로딩이고 가끔씩만켜짐', '예전보다많이불편해요',
#        '어제부터 와이파이해도, 안해도 서버통신?문제로 연결안된다고 뜨네요', '월 사용금액 페이백금액 집계가안됨',
#        '앱실행이안되네요?',
#        '알림 왜 안오나요... 사용알림 전혀 안오네요. 기존에 쓰던 동백전 카드도 그렇고 새로받은 동백전 카드도. 둘다 알림이 전혀 안와요. 앱설정과 폰설정에서 알림 다 켜놓았는데도 안오면 어쩌라는 건지요. 너무 불편해요. \n캐시백사용하는 것도 이번달 사용금액 보는 것도 \n이전 동백전 앱이 훨씬 편합니다...',
#        '앱 알림은 결제가 되었다고 뜨는데 업체에서는 결제가 안되었다고 해서 다른 카드로 결제 했네요.... 확인 부탁 드립니다',
#        '업데이트도 안되고 삭제하고 다시깔려고 하니 대기중만 나오고 사용 엄청불편하네요 빠른복구해주세요 왕짜증나요',
#        '어플이 실행이 잘안됨', '앱 접속이 안되요 확인해주세요 계속 오류나요', '10%에서보다 갈수록 쓰임이 덜해져요',
#        '업데이트를 해야만 앱을 열수 있다는것이 아주 불편 11/10이후 업데이트를 2번이나 더하라네요 배부르겠어요😤😠😧',
#        '제발 안드로이드에서 국가사용제한 좀 풀어주세오 메일도 보냈습니다 ㅠ 제발 풀어주세오 ㅠㅠ',
#        '실행이 안됩니다 어플을 실행시키면 알림설정 창과 필수동의 까지는 되는데 그 다음 화면에 503 Service Unavailable 이라는 오류가 뜨고 아무것도 안되요',
#        '앱이 실행이안됨. 네트워크 잘만 연결되어있는데도 원활하지않다고 빠꾸먹임 관리좀잘해라 진짜ㅡㅡ 고쳐줘 빨리',
#        '진짜 최악으로 바뀜', '접속이 안되네요ㅜㅜ', '이전 앱보다 사용이 불편하네요',
#        '사용하기 불편해요 이전이 훨씬 사용하기 편합니다. 시인성도 떨어지고 전체적으로 별루예요.',
#        '공지사항 좀 그만 띄우세요 아니 무슨 어플들어가면 공지사항 팝업을 3개 4개를 띄웁니까\n빨리 금액확인하고 결제 해야하는데\n취소취소 눌리다가 정신이 나가겟네요\n공지 볼 사람들은 알아서 들어가서 봅니다\n봣던거 왜 계속 보게 합니까\n광고도 아니고 사람 겁나 피곤하게 하네요\n에휴',
#        '최악 어플이되야ㅡ쓰죠!!!!!!!!',
#        '로그인이 왜안되나요? 이리 안들어가지는 어플도 첨봅니다..빠른 수정 부탁드립니다',
#        '진짜 짜증날정도로 편의성 0 충전하는것도 적립금 확인하는것도 너무 불편. 불편해서 안쓰고 싶을 정도... 동백전 혜택아니면 절대 안쓸 어플.',
#        '와 앱 실행 너무 안되요 너무너무너무 너어어어무!!!!!! LTE로 해도 안되고 와이파이는 된다고 해서 와이파이로 했더니 여전히 안되고 이건 뭐 앱을 사용 하라는 건지 말라는 건지 모르겠네요;;;ㅜㅜㅜ 부산사람들이 쓰는 앱일텐데 사용자가 많다고 하면 대체 전국민이 쓰는 앱들은 어떻게 켜지는 건가요ㅠㅠㅠ 다른 분들도 계속 안 켜진다고 건의 하시는 거 같은데 이 부분은 빠른시일내에 조치를 취해주셨으면 합니다.',
#        '어제부터 네트워크연결이 안된다고 접속이 안돼요.ㅡㅡ 어떻게 해결함요?',
#        '이건 무슨 앞전에 사용한 앱보다 복잡하네 잔액확인도 그렇고...아휴 충전 ARS승인은 하루죙일 연결도 안되고 짜증나 죽것네..승인되야 충전을 하던가 하지.. 머 이런 앱이 다있노... 이그 쯧쯧쯧...',
#        '서버연결 진짜 쓰레기같네요 부산시청 실망입니다.', '계속 통신중 오류 뜨는건 뭐여', '안되요 정말 안되네요',
#        '1점도 아깝다 진짜 어렵게도 바꿔놨다',
#        '계속 통신 오류가 뜨네요. 이러면 동백전 사용하기 불편해서 사용이 안될 것 같은데요.',
#        '업데이트가 할때마다안되서 정말짜증납니다', '안정성이 최악이네요',
#        '어플 실행때마다, 인증된 폰번호와 현재 폰번호가 일치하지 않습니다... 글귀가 나와 재인증해 사용하는데요. 알뜬폰이라 그런건지, 이번에 업데이트해도 동일하네요. 폰번호가 맞는데 이유를 모르겠는요, 담에 수정 부탁드립니다.',
#        '앱 오류 빨리좀 해결해주세요 잘사용하다가 앱켜면 사용자정보를 읽을수없다고 다시시도해라고 하길래 지웠다가 다시 설치했는데 이젠 아예 다운되서 깔아서 넘어가지도 않네요 빨리 해결 좀 해주세요 잘쓰고있었는데..!!!',
#        '구제불능', '안하는게 답', '안들어가져요 업데이트 했는데 안들어가져요.. 해결 좀 해주세여',
#        '로그인이 안되네요',
#        '어플이 연결이되야지 충전을할껀데 어제도오후내내 안되서 결국딴카드사용햇네요 네트워크오류로인하여 실행안된다고떠서 내폰이이상한가하고 다른폰으로연결해도 똑같던데 어플연결좀 잘되게해주세요! 가게에서 동백전카드만결재안될때도잇던데요 네트워크오류나서 ! 기능은좋은데 사용이잘안되면 무용지물아입니까 부탁드립니다',
#        '카드 사용 알림 온오프 기능 좀 추가해주세요',
#        '삼성페이도 안되고 I.C카드만 결재 된다구요? 카드를 항상 들고 다녀야 한다고요? 이거 부산시청의 정책인가요? 캐시백 예산이 부족해서? 미리 공지도 안하고. 이게 무슨 처사입니까?',
#        '접속이안돼요 충전은어찌해야하나', '업데이트가 안되어 앱을 실행할수 없어요', '안들어가지네요',
#        '하나도 아까움 KT 돌아와.', '왜이러니~ 업데이트하라고 해서 며칠동안 몇번째 하는데 끝없이 안됨~',
#        '별 반 개는 없는지?', '어플내에서 1:1문의 답변은 언제 해주시나요?? 며칠이 지났는데도 답변대기 상태네요',
#        '동백전 어플들어가니깐 악성코드를탐지햇다고뜨는데 왜그런거에요?', '업데이트가 안됩니다. 수십번 접속해도 안됩니다.',
#        '2월한정때만이라도 모집끝냈으면 예산이 남아돌았을텐데 7월까지하니 이사단 인제6프로할인해봤자 사람들 신용카드쓰는게 더이득일듯',
#        '이전에 사용하던게 훨씬 좋네요', '바뀐게 이전보다 더 않좋으면...뭐하는짓인지',
#        '잘되다가 앱업뎃도 안되고 지우고 새로 깔려니 다운도 안되고 어째야될런지..와이파이 수신잘되고 데이터도 많은데ㅡㅡ',
#        'Ui 개별로네', '앱 업데이트가 안되요ㅜㅜ', '웹에 접속이 안되네요?',
#        '한 번씩 앱이 먹통입니다.. 쓰고 싶어도 못쓰게 하는 앱이네요.. 충전금액 확인하고 쓰려는데 앱은 아무리 기다려도 안되네요.. 서버가 너무 불안정한거아닌가요? 한 두번도 아니고..해결이 안되나보네요 네 알겠습니다..',
#        '계속 업데이트만 한다.짜증남', '하....',
#        '오류 갑자기 오늘 접속오류 계속 뜨길래 삭제 후 다시 깔았더니 아예 안되네요; 빠른시일내에 업데이트 부탁드립니다ㅠ 아예 접속을 못하니 이용불가입니다ㅠ',
#        '업데이트 실행 안되네요. 삭제 후 재설치도 안됨',
#        '동백전 사용가능 업체라고 검색하고 갔는데 사용되지 않았습니다. 완전 비추', '이런거는 안했으면합니다',
#        '켜져야 뭘하지 공공기관에서 만드는 어플 답다',
#        '동백전앱 검색해서 깔려고 하는데 안깔려요 ㅠㅠ 며칠째 버퍼링중.. 뭐죠?',
#        '앱에 잘안들어가져요 벌써 5시간째 들어가지지않고 튕기는데 이게뭔가요? 할인해주셔서 좋긴하지만 이렇게 접속이 어려워서야...',
#        '업그레이드가 안되고 있네요', '아니 츙전한 뒤로 안켜져요 ㅡㅡ',
#        '안켜져요 업데이트하고나서 동백전 어플이 안들어가집니다. 오류 보완 부탁드려요',
#        '업데이트해야 사용가능하다는데 업데이트가 안되네요',
#        '너무너무너무 사용하기 불편해요.. 요즘 환경문제가 심각한데.. 잘 쓰고 있던 카드를 왜 재발급해야 합니까? 그로인해 발생하는 플라스틱 쓰레기는 어떻게 책임지실 겁니까..?\n그리고 업데이트가 되었는데 이전 버젼보다 효율적이지 못한거 같습니다..',
#        '정보 수집 동의후 동백전카드 이미지모양에서 어플실행이 멈추는데 이건 모에요?', '멘 오류 업데이트 안정화좀하세요',
#        '서버 불인정함', '진짜 최악! 어쩔 수 없어서 사용.. 아...',
#        '뭔 업데이트가 되어야 사용가능하다는데 업뎃이 안되네요 안드로이드도 최신버젼인데 계속 안되네요 뭐 충전이나 남은 금액을 확인할수가 없네요 빨리좀 개선해주세요 이래서야 뭐 쓰겠어여',
#        '오늘아침 업데이트 하고나서 결제 잘되던 가맹점에서 오류난다고 결제안됨.. 업데이트를 어떻게 하신건지..',
#        '별점 1점도 아깝다 이따위로 관리할거면 하지마라 ㅡㅡ',
#        '너무 불편하네요... 1. 적립금응 보는게 너무 힘듬 다눌려봤네요 2. 전체 ui/ux가 너무 불편합니다.',
#        '앱 실행하니 통신 중 예기치않는 오류가 발생했다면서 실행이 안 됩니다. 왜 이런거죠?',
#        '머고 앱실행도안되고 장난하냐???!!!',
#        '앱 실행이 ㅡㅡ 안되요 첫결제하고 포인트확인하려는데 종일 안됩니다 머 이런 어플이 있나 부산사람들 성격 급한거 모르나 ㅡㅡ',
#        '업데이타 하라는데 도무지 되질안네여 종전처럼 편리하게하면 동백전쓰는분들이 편할같네여 쉽게쉽게 삽시다',
#        '최악 수레기어플', '택시 왜 사용안된다그러죠?',
#        '잘사용하고있었는데 잘 사용하고있던 중이었는데 갑자기 앱 오류로 안들어가져서 앱삭제하고 새로 깔았는데 계속 오류나네요ㅠㅠ 어떻게 해결할수 있을까요?',
#        '기술의 퇴보', '허구한날 업데이트', '결제도 안되고 잔액확인도안됩니다 계속 오류뜨는데 왜이런건가요??',
#        '동백전 사용시 와이파이가터지는 곳에서도 모바일 데이터를 켜지 않으면 사용이 안되는데 와이파이만으로도 사용할수 있게는 안되나요?',
#        '쓰레기입니다..어플이 안들어가집니다... 계속 새로깔아 들어가야해요... 어플도 저번 것은 직관적으로 캐시백과 충전금액이 쉽게 보였는데 이번 어플은 젊은 제가봐도 어렵고 헷갈리네요...',
#        '몇일네네 네트워크상태가 원활하지않다고 계속뜨네요 참불편하네요', '전에 쓰던거 돌려줘요 걍',
#        '왜 바꿨는지 모르겠음',
#        '로코 이벤트라고 3천원 주더니 사용조건이 충전금 전액사용 이후에 카드캐시네? 자동충전 해놨는데 그냥 쓰지 말라는거네? 개똥쓰레기같은 정책 쓸거면 이따위 이벤트 하지마라.',
#        '충전하려니깐 카카오뱅크가 없네요ㅜㅜ', '예전 이관되기전에 카드 사용되나요 ??', '업데이트가 안되네요ㅠㅠ',
#        '오늘 하루종일 로그인이 안되네요 오류도 자주나고 등록된 가맹점에서도 사용 안되는곳이 많이 있습니다 좀 개선해주세요 지금 3일째 네트워크가 원활하지 않다는 메세지가 뜹니다 와이파이 LTE 다안되고 너무 불편하네요!!!',
#        '사용하기가 쉽지않음',
#        '푸시알림 사용내역 알림받으려규 푸시알림 켰더니 마케팅 알람이랑 같이 오네요… 알림껐더니 사용해도 아예 알림이 안오구요^^ 보통 마케팅 알림이랑 사용내역 알림 설정은 분리해주지않나요 사용내역 보는 것도 불편하고 이전 앱에 비해 사용성이 한참 많이 떨어지네요',
#        '1. 동백전 가맹점 배너 만들어주세요 -예전에 이 문제 관련해서 4/29일에 가맹점배너 만든다고 하셨는데 아직도 안됐습니다.. 업데이트 하라길래 이젠 만들어졌겠지 했는데 없어요 아직도 .. 2. 다른분들이 많이 써놓으셨네요...',
#        '엉망진창입니다. 사용하려고 만든어플이 어떻게 결제하려할때마다 앱이 오류가 빈번하게 나네요. 번거로워서라도 이용이 꺼려집니다. 오류가 한두번도아니고 앱실행자체가 안되네오 ㅎㅎ 거르세요',
#        '서버 맨날 터짐',
#        '어플화면에서는 결제완료창이랑 캐쉬백 내역이 뜨는데 가맹점에서 실결제가 되지는 않는 상황이 발생해 카드를 세 번이나 긁었으나 실패했어요. 간헐적으로 이러면 어떤 사람들이 쓰겠습니까?? 고객센터에서도 같은답변이고 해결되는건 없고 정말 불편해서 못쓰겠네요.',
#        '아니 왜 접속이 이렇게 안됩니까 사용을 할 수가 없네요',
#        '해외에서는 어플리케이션 접속이 제한되나요? 접속 자체가 안되네요.', '저번보다 완전 불편',
#        '1. 기존 어플에서 가능했던 바코드 생성 결제가 불가능해짐. 신규 카드는 삼성 페이도 등록 불가능한 상황이니, 기존 카드 분실시 휴대폰으로 결제하는 건 포기해야 함... 2. 충전된 잔액이 부족할 때, 후불 결제 건 관련 정보 부족. 이에 대한 공지도/설정 방법도 찾아볼 수 없고 심지어! 결제 내역 확인도 불가능함. 애초에 동백전을 캐시백 때문에 쓰는 건데, 교통비 이외의 후불 결제를 통제하거나 관리, 조회하는 방법이 아예 없는 상황을 어떻게 받아들여야 하는 걸까요... ... .',
#        '아..진짜 이거 뭐 이따위로 만들었나요. 업데으트도 안되고..왜 이런 업체가 이런 걸 할 수 있게 된 거죠? 짜증이 나네요. 이건 관리감독 주체인 부산시가 문제인 듯..민원을 넣어야겠네요.',
#        '네트워크연결때문에 며칠째 접속이 안되요. 쓰고 남은금액 확인할랬는데 네트워크 때문이 접속이 안된다고 해서 지웠다가 다시 깔았는데 언제 정상화 되나요? 여전히 안됩니다',
#        '앱 사용 내역 볼려고하면 계에에에에ㅔㅔㅔㅔㅔ속 나가지네요 빨리 고쳐 주세요 ',
#        '어플을 운영을 하실거면, 불편함은 제때 개선좀 하세요 국민들 불편함 의견제기 1. 점심시간 퇴근시간 카드승인 불가 2. 점심시간 퇴근시간 어플 내 돈충전 불가 3. 업데이트후 어플켜지지 않는 문제 등등 불편함이 정말 많은데, 좋은점(캐쉬백)만 광고하고 실적 쌓으시는건가요? 퇴근 후에 장보러 마트가서 결국 동백전 카드 쓰지도 못하고, 기존에 쓰던 카드 씁니다. 괜히 헛걸음 하게 만드시네요. 좋은만큼 불편함도 큽니다. 이렇게 운영하실바엔 어플 안만드는 게 좋을듯요.',
#        '업데이트 하라는 공지 이후로 업데이트도 안되고, 혜택도 못받고 있습니다.언제까지 이럴껀가요?',
#        '너무느리고 접속이 않된다',
#        '1점도 아까움. 몇일째 앱이 안열려서 충전을 못하니 쓸수가 없음. 카드는 왜 만들어야 하는지 이해도 안되고. 카드는 둘째치고 앱이 열려야 쓰던말던 할텐데 이건 뭔 상황인지...',
#        '예전앱이 훨씬 좋았음 똥으로 변함ㅡㅡ', '로그인 안되네요 사용하기 짜증나네', '와 진짜 개떡같이 만들었네',
#        '안열리네요',
#        '진짜 넘하시네요! 아니 뭐 접속도 안되고 맨날천날 통신이 불안하다고 하면 시에서 일하시는 분들이 국민이 내는 세금 쳐받아먹고 이런거 하나 제대로 못하시면 안되죠!',
#        '중단됫다고안되고업데이트하라고안되고',
#        '돈 넣었는데 어플 실행이 안돼요 ? 잘 쓰다가 돈 남아있는데 어플 실행이 안돼요 뭔데요',
#        '다운로드만 되고 아이콘누르면 동백전로고만 내내떠있고 아무것도 안되는데요.. 와이파이 데이터 둘다해봤는데',
#        '업데이트가안되여', '편 리하다',
#        '폰마다 차이가있는지 제폰에서는 와이파이 아니면 앱에 접속이 거의 안됩니다(A5). 길거리에서 갑자기 충전해야할때 또는 가맹점확인해야할때 LTE면 네트워크 상태가 원활하지 않다며 바로 꺼집니다. 확인이 불가능해요. 길 한복판에서 와이파이 잡는게 쉬운것도 아닌데ㅜ 너무너무너무 불편하고 급할때는 정말 욕나와요ㅠㅠㅠ 어제도 앱 50번 출구컷 당하고 물건 못사고 나왔습니다. 개선 안됩니까',
#        '업데이트가 계속 안됨', '앱실행이 안돼요ㅠㅠ 앱실행이 안돼요 앱을 킬수가없음.. 오류 수정좀해주세요ㅜ',
#        '앱이 계속 실행이 안되면 어떻게 사용하란 얘긴가요?당장 써야하는데...사용이 잘 안되는거 대한 공지사항도 없구 넘 불편하네요.',
#        '동백전 사용처 검색 빨리해주세요',
#        '카드 써도 알림이 안옴;;; 설정도 다시 해보고 어풀 깔았다가 재설치도 해봤는데 알림이 안오네요;;;',
#        '몇일 전까지 잘 쓰다가 갑자기 네트워크 원활하지않다고 몇일째 접속안되네요!!;; 고객센터 전화했더니 답변준다고 번호남겨놔라해놓고 연락도 없고.. 옆에 다른사람은 접속되던데.. 폰 버전차이인지..? 원활하게 잘 쓸때처럼 빨리 바꿔주세요!!!',
#        '다사용 될수있도록 가능할때 만드세요 ㅡㅡ아니 접속도 안되고 똑바로좀 만드세요 제발', '앱이 왜 안깔리나욧???',
#        '머 접속이되야하지ㅡ....우짜라는건지 안되요 아예 로딩도안되고 따운됨 ...하',
#        '리뉴얼전이 좋아요 디자인 너무산만하고  내가 얼마큼 페이백 받았는지 확인하고싶은데 너무 필요없는  탭들이 많고 사용하기 너무 불편해요',
#        '접속안됨! 어플실행이...걍 욕나옮!', '앱은 설치했으나 ᆞ 네트워크 원활하지 않다고 압접속않됩니다',
#        '앱 실행이 안됩니다. 네트워크 상태를 확인하라는 매세지만 뜨네요.', '이게머요?',
#        '5G, Lte, Wifi 전부 데이터 연결 상태가 안좋다고 실행이 안됩니다. 실행이 안되면 충전을 어떻게 해야하나요?',
#        '접속이 되야 충전을 하든 뭘하지... 제발 접속 좀 하게 해주세요! LTE wifi 둘다 안되요!',
#        '아예오류나고안들어가져요 오류나고 아예안들어가지는데 어떻게요? 서버없다고만 뜨고요', '왜 로그인이 안되나요?',
#        '네트워크 오류라고 하면서 접속이 안되요~ 업데이트 좀 해주세요~', '앱이 안열려요',
#        '이전 어플보다 훨씬 불편합니다 이용내역도 그달에 얼마 썼는지 각각내역은 나와도 전체는 안나오고 결재된 금액에 포인트는 얼마나 사용되고있는지 여부도 확인도 안되고 교통카드도 안되고 그냥 이전처럼만 쓸수있게 해줬으면 좋겠는데 현재 너무 불편함',
#        '왜 자꾸 다운로드대기중인가요..ㅜㅜ', '접속 겁나 안됨..ㅡㅡ 뭐하는건지 ㅋ', '안 열러요 ㅜㅜ',
#        '업데이트가 안되요', '서버 다운인 상황에 결제가 안될때 난감한경우가 제법 있습니다.',
#        '이전 어플이 훨씬 사용하기 용이하고 한눈에 정보 파악하기 좋았음. 업체 바뀌면서 개선이 아니라 개악이 된 듯. 젊은 사람도 어플 사용에 불편함을 겪는데 나이드신 분들은 어떨런지... 업체 선정과정에 의혹이 생길 지경임. 카드는 왜 중복해서 또 만들라고 한건지도 의심스러움.',
#        '접속하면 계속 네트워크상 오류가 있다며 어제부터 접속이 안돼요. 앱 삭제후 다시 깔아도 안됨. 데이터접속해도 안되고 와이파이켠 상태서도 안됨.',
#        '업데이트도 무슨 잘안돼는 쓰레기같은앱 국민청원하던가 해야지 이건비리있다 진짜',
#        '제 폰이 이상한건 가요ㅜ 데이터로는 동백전이 안들어가지고 돈 충전도 안됩니다 길에서 충전해서 급히 쓸려고할때 사용도 못하고 계속 튕겨져 나오는데 확인해봐주세요',
#        '동백전 카드는 잘사용하고 있는데요 앱은 왜 이따위로 만들었나요? 와이파이에서만 접속되고 그마저도 안될때도 있고.. 개선이 시급합니다.!!!',
#        '너무 불편해졌어요. 많은 분들의 의견과 동일한 내용들이지만, 몇 달이 지났는데도 개선 사항이 보이지 않아 글 남깁니다. \n\n1. 사용내역의 알림이 안 옵니다. 보안 설정 때문에 안 오는 거 같기는 한데 보안 설정이라 함은 충전, 결제에 대한 보안 설정으로 한정해주시면 안 될까요? 사용 내역에 대한 알림은 따로 설정이 되면 좋겠습니다. 일일이 매번 로그인을 해서 확인하든가 아예 보안을 풀든가 그래야 하네요. 불편합니다.\n\n2. 월별로 이용 총액, 충전 총액이 나오면 좋겠습니다. 누적액은 보이지 않고 검색 기간 내 건별만 확인 가능해서 불편합니다. \n\n3. 인트로 화면에 정보나 글자가 너무 많아서 제가 원하는 정보 찾기가 아직도 어색합니다. 딱히 내 쿠폰, 총 받은 혜택, 럭키로코 같은 내역은 인트로 화면에 없어도 되지 않을까 싶네요. 좀 더 간결하고 직관적인 내용으로 누구나 사용하기 쉬운 디자인을 고려해서 수정해주셨으면 합니다.\n\n많은 분들이 비슷한 사항을 리뷰로 작성함에도 ‘불편을 드려 죄송합니다.’라는 댓글만 달리고 어떻게 사용하라든지 여전히 개선 사항이 없다는 건 개선 여지가 있는지 없는지 의문을 갖게 되네요. \n\n이왕 만드신 거 많은 사람들이 만족하며 감사히 사용하게 만들어주시면 좋겠습니다.',
#        '다른앱은 잘되는데 동백전은 도대체 와이파이로도 데이터네트워크로도 네트워크 상태가 고르지 않다며 연결이 안되는데 어떻게 된 건지요?',
#        '업데이트가 안되네요 엡 관리가 너무 안되는거 같네요', '편하네요',
#        '갑자기 4월 10일(금) 점심시간때부터 "네트워크상태가 원활하지 않습니다. 연결상태를 확인 후 다시 시도해주세요"라고 뜹니다. 이 문제로 고객센터측에 문의하니 4월 10일부터 5.0.1안드로이드 버전이 안되고 있다는 보고가 들어와서 해결중이다 라고 하던데요. 도대체 언제 해결되는건가요? 빨리 서버 오류 고쳐서 앱 사용할 수 있도록 해주세요~'],
#       dtype=object)

# %% [markdown]
# ##### 토픽 4
#
# '0.051*"가맹점" + 0.035*"찾기" + 0.031*"캐시백" + 0.027*"불편" + 0.024*"사용" + 0.020*"금액" + 0.019*"이전" + 0.019*"기능" + 0.016*"사용자" + 0.015*"편의"

# %%
topic_4 = topictable[topictable['가장 비중이 높은 토픽'] == 3.0]

print('토픽 4에 해당하는 리뷰의 개수:', topic_4.shape[0], '개')
# Out:
# 토픽 4에 해당하는 리뷰의 개수: 135 개

# %%
# 토픽 4에 해당하는 리뷰들만 모아서 하나의 df 만들기

topic_4_list = topic_4['리뷰 번호'].unique()
df_topic_4 = df_negative.loc[topic_4_list, :]

df_topic_4.head(5)
# Out:
#           DATE  STAR                                             REVIEW  LIKE
# 18  2021-04-04     1  ? 잘 있던 동백전 놔두고 kt껄로 옮겨서 원래는 없던 수수료를 받는다? 그냥 돈 ...     0
# 24  2021-04-12     1  그 전 어플보다 너무 불편하고 못 만들었어요 정작 사용자가 제일 많이 쓰는 버튼과 ...     3
# 25  2021-05-05     1  동백전 앱 개선 요청 적립금액이랑 현재금액 보기 너무 어려워요 헷갈리기도 하고 앞에...     0
# 27  2021-04-09     1  전에 어플이 더 사용하기 쉽고 편한거같아요. 지금 어플은 뭐가 뭔지도모르겠고 사용 ...     1
# 42  2020-04-08     1  로그인 잘 안되고 가맹점 찾기도 힘들고 별 하나 주기도 아깝네요. 그리고 충전식 카...    56

# %%
# 리뷰 전부 모아보기 --> 복사해서 R로 들고가서 감성분석 진행

df_topic_4['REVIEW'].unique()
# Out:
# array(['? 잘 있던 동백전 놔두고 kt껄로 옮겨서 원래는 없던 수수료를 받는다? 그냥 돈 벌겠다는 말 같은데 다른 더 큰 혜택 없으면 솔직히 이거 쓸 필요 없음. 캐시백보다 수수료가 더 많이 나갈듯',
#        '그 전 어플보다 너무 불편하고 못 만들었어요 정작 사용자가 제일 많이 쓰는 버튼과 기능들은 매우 조그마해서 너무 불편해요 누구를 위한 어플인가요?? 그 전 어플은 안 보셨어요?? 완전 별로입니다',
#        '동백전 앱 개선 요청 적립금액이랑 현재금액 보기 너무 어려워요 헷갈리기도 하고 앞에 썼던 앱처럼 캐시백 잔액 충전한 금액 캐시금핵사용하기 한눈에 보기 쉽게 개발해주세요 너무 번거로워요\n내쿠폰,총받은 혜택 이런건 세부적으로 들어갔을때 볼수있게 해주세요 별로 잘 사용하지도 않는게 앞에있으 헷갈리고 별로에요',
#        '전에 어플이 더 사용하기 쉽고 편한거같아요. 지금 어플은 뭐가 뭔지도모르겠고 사용 방법도 모르겠어요. 사용방법 쫌 알려주시면 좋을거같아요.',
#        '로그인 잘 안되고 가맹점 찾기도 힘들고 별 하나 주기도 아깝네요. 그리고 충전식 카드라고 말했으면 발급을 고민하고 냈을텐데 안내장에도 그런말이 없었네요. 사용해보고 가족들에게 추천해주려고 했는데 추천 안하고 싶네요.',
#        '전반적으로 저번 업체에 비해 불편함. 특히 캐시백 사용하기가 제일 불편함. 이 어플 사용이유가 잔액확인, 사용내역 보기위한건데 저번 어플에 비해 굉장히 불편함 그리고 대부분이 카드있을텐데도 억지로 선불카드 발급받게한것, 또 선불카드 홍보까지 하는게 너무 짜증남. 왜 이런 업체가 위탁을 받은건지 모르겠음 별점을 최하점이 1개라 1개...',
#        '흠.. 글쎄요.. \n저는 이전 앱과 비교해서 불편한 점이 몇가지 보입니다. 우선 가독성이 떨어져요. 보유잔액과 캐시가 메인 화면에서 한번에 확인이 불가능합니다. 포맷은 전에 것이 더 좋았던 것 같아요. 개선되기를 기대합니다.',
#        '어플 거지같아요 이용내역에 따른 캐시백이 얼아되었다는 금액을 같이 넣어주세요 작년 어플과 똑같이 해주세요',
#        '변경되고나서 완전 별로입니다 새로선불카드를만들으라하질않나 만들어사용했더니 그동안 아무이상없이 잘 사용되었던곳도 갑자기 지원불가라고하고 좀 이상해진듯 회사가변경되면서 남은잔액과 이용내역만 그대로 연계된거지 새로운 시스템으로 사용될꺼라는 상담사님의말씀 예전에 사용됬었던곳인데 왜이제는 안되나요?? 하고질문하니 회사가 바뀌었고 예전 회사방침은 저도 모릅니다 라고 상담하는 상담사님 하... 암튼 전 동백전 안녕',
#        '기존 동백전체크카드 보유고객입니다 필요없는 동백전 선불카드 의무발급하게하는것은 무슨 논리인가요? 고객이 선택할수있게해주세요\n삼성페이는 왜  등록이안대는건가요?\n고객센터는 10통을해도 한번도 연결이안됩니다..',
#        '가맹점찾기에 가맹점 자체가 아예 안나옵니다. 처음부터 안된게 아니고 어제부터 안나오네요. 어떻게 된 건지 해결 부탁드립니다.',
#        '이전보다 더 불편해진 느낌ㅠ 첫 메인 화면에 잔액이 나왔으면 좋겠어요\n그래야 얼마 충전해야하는지 확인이 되고\n이용내역에 이용내역 뿐만 아니라 잔액이 나왔으면 합니다. 빠른 개선 부탁드립니다',
#        '동백전 사용처 검색 기능이 없네요. 이전에 사용하던 앱보다 많이 불편합니다.',
#        '문의글남겨도답변도안하고점심이라고일안하고가맹점이라고버젓이되잇는데사장은동백전가입안되잇다고사기치질않나충전도5천이상만되고에라이때려쳐라뚜레쥬르는동백전사용방법도모르고그럼서홍보만함다냐별반개도아깝다',
#        '기존은행앱에서 느끼는 단점을 다 가지고 오셨네요. 광고, 마케팅권한요구, 번잡한 UI와 UX 최악입니다',
#        '전에 보다 못하다.판단되고 캐시백 금액 확인도 힘들고 머좀 찾아볼려면 여러번 눌러야 되고 전보다 못하고 꼭 돈쳐넣고 그냥 써라는 그리고 남은금액,캐시백 궁금하면 가끔열어보라는 느낌!이 드네요.ㅋㅋㅋ 개발자님 좀 간단하게 한 눈에 보고 확인하고 쓸데없는건 좀 묶어서 한번에 보도록 개선해 보이소.',
#        '캐시백 따로 볼수 있게 해주세요 너무 불편해요 기존앱에서 나아진점이 하나도 없는듯',
#        "지난 잔액과 이번 잔액 비교가 되었으면 좋겠습니다. 최소한 어린애 가계부도 입출내역과 잔액란이 있는데, 여긴 결제내역밖에 없어요. '지난번에 잔액이 얼마였는데 그뒤 충전해서 얼마가 되고 이번에 또 결제해서 잔액이 얼마다' 이런 계산이 서야 할텐데 이 앱을 보면 뭔가가 확 빠진것 같아요. 솔직히 뭔가 어느순간 셈 틀려서 잔액이 좀 빠지더라도 눈치 못채게 하려는 저의가 있는 것처럼 느껴지기까지 합니다.",
#        '교통카드 없는 카드 개설했다가 있는걸로 바꿀려고 하나카드 통해서 카드해지를 했습니다. 근데 어플상에 정보가 그대로 있어서 재발급을 하지못하고 있습니다. 고객센터 또한 하루 30통 이상씩하는데도 연결불가 영상통화비용으로 11000원이 부과되었네요? 상담조차 못했는데 말이죠? 아주 답답한 경우라 별 1개도 아깝네요 1대1 문의도 답이없고 여기에 달릴 답변은 고객센터에 전화해봐라 이 얘기겠죠?',
#        '동백전 가맹점 조회 가능하게 해서 쓸수 있게 해주세요',
#        '기존에 사용하던게 더 좋음...잘사용하고 있는대 고객들 불편하게 만드네요...',
#        '어플에서 바코드가 뜰 방법은 없나요? 요즘 카드를 누가 들고 다닌다고....... 그냥 핸드폰 어플에 바코드가 떠야 쓸만하겠습니다',
#        '일주일 사용 후 불편한 점 1. 가맹점 찾기 기능 넣어주세요.\n2. 푸시알람켜놨는데 카드 사용 후 알람 왜 안오나요?\n3. 현금과 캐시 사용 적립내역 같이 보게 해주세요.\n\n기존 동백전 어플에비해서 번잡하고 사용하기엔 오히려 더 불편해요. 사용자들의 불편 보시고 꼭 어플 수정해주세요.',
#        '지난주부터 네트워크 연결 확인하라고 앱 연결이 안되서 미쳐버리것네요... 딴 사람들은 잘되던데 폰이 이상한건지 앱이 이상한건지.. 1577 1432 전화연결도 안되는거 왜 만들엇는지.. 아무리검색해도안나오고 ㅎ 홈페이지를 제작하던지.. 쓰지도 못하고 4월이 지나가것네요 어디다 연락해야되나요? ㅎ',
#        '사용자 편의를 고려하지 않고 불친절하고 불편한어플',
#        '중요한 기능 중 하나인 가맹점 조회는 왜 없나요? 동백전 사용가능한지 일일이 물어볼 수도 없고.. 다른 지역 화폐처럼 가맹점이 지도로 표시되면 좋겠어요.',
#        '내금고 돈 넣었더니 빼는 기능이 없네 고객센터는 당연히 잠수고 뭐 이따구냐',
#        '문의도 제대로 안올라가고 기존가맹점 멀쩡하게 쓰고 있는데 새로 가입하라하고 전화도 안받고 문의올려도 답변시원찮게하고 지금 뭐하자는건지 모르겠네 0점은 어떻게 주는지 몰라서 별1개 준다',
#        '결제취소건에 대한 환급진행도 안되고 고객센터와 전화통화는 하늘의 별따기 3월31일 동백전 가맹점에서 결제취소를 했지만 일주일 넘게 환급이 되고 있지 않습니다. 대행사가 바껴 그 과정에서 생긴 문제라면 사전에 고객에게 설명이 필요한건데 그런 설명도 없네요.\n하나카드 고객센터에 전화했더니 취소승인 및 취소전표까지 발행됐고 이런 경우 자동으로 이틀이내에 환급이 되는 것이 정상이라고 했음\n다시 동백전에 전화했더니 알아보고 연락주겠다고 했지만 지금까지 연락도 주지 않고 있습니다. 증발해버린 제 돈은 어디서 받죠? 무엇보다 고객센터로 전화 한번 연결하는것도 대기가 너무 오래 걸려서 속이 터집니다.\n동백전을 이용하는 사람들이 얼마나 많은데 이런 부분은 개선되어야할 것이고 빨리 제 돈 돌려주세요.',
#        '도대체 왜 바꾼거죠? 진짜 진심 예전이 훨씬 좋아요ㅡㅡ 가맹점 찾기도없고, 결제금액이랑 캐시백 따로 나오는것도 불편하고, 캐시백 사용할때 캐시사용 누른후 결제하는것도 그렇고 이래저래 너무 불편해요 ㅡㅡ',
#        '캐시백 함 받을랫다가 쓰러지겠네요 돈 묶여있는거 어케 뺍니까 ;;\n다섯 군데 돌아다녔는데 단 한군데도 사용이 안되고\n못 쓰는 돈 빼지도 못하고 카드 삭제도 안돼\n해지 신청하면 그대로 돈 날리고 2천원 주고 \n재발급 받아서 다시 사용 하라니요 ;;;;;;\n이용정책에 나와있는대로 해도 충전취소인지 뭔지\n뜨지도 않고요 불편하게ㅜ만들어놨으면\n안내나 고객센터 연결이라도 돼야지 원 뭐 이건\n만들어놓고 쓰라는건지 말라는건지 ㅋㅋ',
#        '기존 동백전을 사용하나 쩔수없이 여기로 이관중인데 진짜 지리멸렬 그자체이고 굳이 필요도 없는 카드는 또 발급받아야하는 번거로움에 진짜 기존 동백전앱이 최고였슴~ 여긴 가맹점 찾기도 확인안되고 현재까지는 완전 빵점앱',
#        '앱 사용 불편. 내역 확인 안됨. 사용자 편의성 전혀없음',
#        '새로 카드 발급받았는데 삼성페이 안되요 대책없나요? 계획없으세요?',
#        '카드 신규발급 안해도 기존카드사용해도 되는데 왜 굳이 발급의무로 해 놓은건지 마케팅이 도를 넘었어 ㅉㅉ',
#        '동백전 편의성 개나 줘버리고 이전보다 못한 서비스 하면서 왜 바꾸는 거냐 어이가 사망하셨네',
#        '왜 연결이안돼요-??? 위치켜도 가맹점나오지도않고-아니 도대체 점거안하고 뭐하시는건지-동백전괜히만드러서짱증나게',
#        '사용가능 가맹점 찾기 빨리 만들어 주셔.. 필요한거는 안보이고 뭐 필요없는 것만 잔뜩만들고 한번에 했던걸 두번 세번 거쳐서 하게 만들어놨노',
#        '아니 이전에 앱에서 바코드로 결제 가능했는데 이건 간단하게 충전하기까지 왜이렇게 진입하는게 번거로운데다 바코드 기능이 없어서 카드를 무조건 들고 다녀야 하네요 이렇게 대충 앱출시할거면 왜 이어받아서 욕먹습니까?',
#        '개인정보 왜 보험회사에 팔려서 에이스 보험 강매 전화 작작 ..그래서 탈퇴함^^',
#        '어플을 열려고 하면 열리지 않는 경우가 자주 발생합니다. 캐시백 사용도 이전보다 불편하구요. 개선이 필요한거 같습니다.',
#        '왜...? 오랜만에 동백전 쓰려고 다시 깔았는데 카드도 다시 발급받아야되고.. 그건 그렇다 치고 새로운 어플인데 가맹점 찾기가 없어졌네요 .. 왜 다운그레이드 되었는지...? ㅠ 가맹점 찾으려면 온 가게 돌아다니면서 동백전 받으시나요 물어봐야 되나요.. 왜... 왜 없어져...',
#        '다른건 다 괜찮은데 가맹점 찾기에 가게가 하나도 안나와요ㅠㅠㅠ 몇번이나 재설치했는데도 가맹점이 하나도 안뜨네요 따로 웹페이지에 가맹점 목록을 업로드하던지 다른 방법으로 개선해야 할 것 같아요',
#        '불편합니다 캐시백 금액+보유금액 한번에 조회하게 해주세요\n이전 어플은 가능했어요 \n기간별로 통합 조회 원합니다',
#        '이런 회사를 왜선정 햏는지?', '광고 팝업 안뜨게 하세요',
#        '너무 비직관적입니다. 한눈에 충전잔액, 캐시백잔액, 총 잔액을 첫화면에 볼 수 있었던 3월 어플에 비해 지금 UI가 상당히 어수선하고 사용하기 불편하네요. 또한, 한 번에 결제금액과 캐시백 사용내역을 볼 수 있는 사용내역 페이지도 만들어주세요.',
#        '30살 살면서 하나은행이용해본적 단한번도 없는데 동백전 만들고 하루에 2~3번 하나카드에서 전화오지게 오네요 다음엔 다른은행이랑 합시다 부산',
#        '도대체 고객센터는 왜있는겁니까? 2/19에 1:1문의 했는데 9일이 지났는데도 보지도않을꺼면 아예 없애세요!!전화연결도 안되고 도대체 일은 하는거임?',
#        '전 동백전은 삼성페이에서 사용이 되었는데 아건 카드를 들고 당겨야 되는건가요? 아님 방법이 있는데 제가 모는건가요',
#        '사용하기 불편하네요 전에 KT에서 할때는 편하고 직관적이고 간단해서 좋은데 지금 앱은 너무많은정보가 있어서 찾기도 힘들고 등록하기도 불편하네요.',
#        '오류 어플 오류가 너무 많아요 쓰고싶을때 한번도 제대로 써본적이 없어요',
#        '너무 불편해요 예전처럼 한눈에 보이지도 않고 캐시백사용도 불편해지고\n예전 앱이 훨씬낫네요 캐시백과 충전금액이 편하게 보이게끔 바꿔주세요',
#        '맨날 문의하면 같은 답변만 계속하고 성의가 있는건가',
#        '가맹점 왜 안뜨나요? 가맹점을 봐야 쓰든가하지 빨리좀 고쳐주세요',
#        '젊은 우리도 사용하기 힘들 정도로 직관성 없는 앱을!! 동백전을 많이 쓰시는 어른들은 어떻게 쓰겠습니까!! 게다가 캐시사용도 10분 이내인데 10분 내에 앱조작도 어려운 어르신들이 이걸 잘 사용하리라 생각하십니까? 배려심 부족한 앱입니다.',
#        '앱이 안열림 ㅡ.ㅡ뭐하자는거임? 사용자 증가로 오류? 골때리네',
#        '오류 좀 개선해주새오 너무 오류가 심해요. 캐시백이 안되어서 문의했더니 다시 가게에 가서 취소하고 재결제 방법밖에 없다고 하고 오류일 경우 해결방안이 너무 불편해요',
#        '가장 기본적인 사용자 편의성 1도 생각안하는 업체로 변경을 왜 한건지~^^ 섬성페이 사용안됩니다',
#        '더 안좋아짐 사용불편,캐시백 소멸도 됨?',
#        '넘 불편 너무 번잡스럽고 전에 어플처럼 한눈에 보기 쉽고 찾기 쉽게 만들어주세요. 특히 가맹점찾는기능 빨리 만들어주세요. 그리고 충전하는거랑 캐쉬백잔액도 넘 번잡스러움 불편하네요 진심..',
#        '어플 직관성이 떨어집니다 예전 어플은 캐시백 받은 금액 + 충전(사용가능금액)액 이렇게 단순하게 나와서 이용하기 편했는데 지금은 덕지덕지 부산시 홍보 베너에 너무 보기도 불편하고 공무원이 만든것 같은 느낌 입니다.ㅔㅕㅐㅕ',
#        '가맹점이 어디 있는지 찾을수 없으면 동백전의 유용한 기능을 못 쓰는데 어떻게 하라는건지 전에는 가맹점을 확인할수 있어서 좋았는데 지금은 저희도 가맹점 어디 있는지 모르니 알아서 쓰세요 라는 느낌이 드네요',
#        '나는 이전 하나카드를 삼성페이에 등록해서 사용하니 불편함을 못느겼는데 신규 사용자는 선불카드만 사용해야 해서 삼성페이 등록이 안되면서 사용성이 떨어짐/ 캐시백 사용도 이전에는 자동으로 등록되고 사용이 되었는데 지금은 이상하게 분리되어 이써어서 직관성도 떨어지고 사용성도 헷갈림 그래도 10%가 어디냐 하면서 쓰고 있지만 왜 이전보다 못한 서비스를 제공하는지 모르겠음',
#        '이전 동백전카드에 잔액이 없어졌네요? 케시백된 금액은 사라졌나요?',
#        '그냥 뭐 새로 만들려 하지말고 이전 동백전 앱 ui라도 그대로 해주세요 \n\n그리고 사용가능 금액 새로고침도 꼭 이용내역 한번 들어가야 새로 고쳐지는것도 앱 바로 들어가면 새로고쳐지게 바꿔주세요\n\n그리고 이용내역에서도 결제하거나 충전하면 잔액도 같이 나오게 해주세요\n\n금융 어플에 이정도는 기본 아닙니까\n\n별 한개도 아까운 수준입니다',
#        '어플이 한눈에 보이지않아 불편하네요 그리고 가맹점찾기는 사라진건가요?', '번거로움',
#        '동백전 앱에 들어가면 가맹점 찾기가 원래는 나오는데 어제 부터 위치를 잡아도 안나오는 이유가 뭔가요?',
#        '사용가능한가맹점이부족 삽니다.',
#        '정말 불편하게 바꼈어요 나이가 있다보니 앱이 너무 복잡하고 쓰기가 힘드네요 가맹점찾기는 어디갔나요ㅠ 그리고 충전금액이랑 캐시백 따로 있었으면 좋겠어요 충전금액이 없었으면 동백전 사용안했을텐데 어쩔 수 없이 카드 신청했어요 편리하게 개선 좀 부탁해요',
#        '동백전 사용하기 힘듦 동백전 사용가능 가맹점 리스트를 보고싶은데 아무리 찾아도 안보여요\n어디 구석에 쳐박혀 있는건지 앱 사용하기 어려워요',
#        '카드 취소해주세요',
#        '별한개도 아깝네!! 별한개라도 안주면 리뷰도 못남기게 해놨구만... 사용자들 말도 많고 탈도 많은 동백전 소상공인들 위해서 쓸려면 쓰고 굳이 동백전 안써도 체크카드나 신용카드 토스 카드 토스도 충전해서 쓴다는걸 모르는 돌ㄷ가리들 엄청 많음ㅋㅋ 동백전 쓸일이 거의 없는 사람들은 다른 카드사용해도 사용실적이나 IC로 결재하면 캐시백 이라던더 기타등등 혜택 더 많이 받는데 뭣하러 동백전을 쓰남 개개인의 취양이나 라이프 스타일에 맞춰서 쓰면 될것을 초딩들도 아는걸 몰라서 여기서 충전해서 쓴다는건 기본 상식인데 몰랐다고 난리치는 돌ㄷ가ㄹ들 동백전이 무슨 체크카드,신용카드도 아니고 하여튼 유치원새이나 초딩들도 이해하고 아는걸 상식적인것을 이해도 못하고 따지고 쌩 난리치는 돌ㄷㄱㄹ들 보면 여하튼 이런거 보면 학벌 이나 성적순하고 전혀 상관 없는 무식한 돌ㄷㄱㄹ들 세상살다 보면 정말 많다니까 일류대 나오고 전교 일등 하는것들도 이런걸 모르는 사람들이 천지빼까리라는 초딩보다 못함',
#        '공무원들 하는일이 원래 그런거라하지만 그지같음 계획적소비같은 소리하네 체크카드로 누가 충동 소비하냐? 암튼 원래 쓰던게 더 직관적이고 간편함 뭐하러 바꿈? 세금 활활 타오른다',
#        '불편합니다 바코드로 결제하는것도없고 qr도없고... 바로 써야할일있어서 충전했는데 카드없다고 못쓰네요 전에 업체가 더 나았던거 같아요',
#        '기존카드 연동후에는 신규선불카드 발급 취소도 안되네요ㅠ 당일취소 했는데도 안되네요. 신규카드발급은 앱 대행업체의 수수료 명분으로 발급되는건가요? 두카드 중 아무거나 써도 되나요?',
#        '가맹점찾기는 사라진건가요? 왜 안보이죠? 이전보다 더 안좋아졌어요',
#        '충전취소 3일이나 걸린다니 너무하네요.전에꺼는 실시간취소였는데.글고 설치 후 신규발급 유도하지마세요 하고나니까 체크카드 보유자는 발급취소도 안 된다하고 고객센터 연결도 안되고 참~',
#        '뭔지 당최 알 수 없는 쓰잘데기 없는 기능을 만들었는지...이전 동백전이 훨 나았음을 여실히 느끼게 해주는 어플인듯^^;',
#        '캐시백은좋은데 앱사용오류가너무심해요 ㅜㅜ',
#        '내가 캐쉬백받은 금액이 얼마인지 확인이 안되요. 그거때문에 동백전 쓰는 건데요. 이전 앱에 비해 사용자편의성이 많이 떨어져요.',
#        '가맹점찾기 기능은요?',
#        '전 카드 대행사와 너무 비교돼서 별 한개도 아까워요... 카드 포인트 쓸때마다 어플 켜야하고... 너무 불편하네요 다시 대행사 바뀌었으면..',
#        '먼저번거랑 비교가되네요 광고도많고 앱들어갈때 불편해요', '찾기 너무 힘듬',
#        '인증문자 자체가 안오는데 뭘 어떻게 카드발급 받으라는거죠? 뭔가 제대로 이용할수 있도록 시스템을 만들어넣고 홍보를 해야지 시간낭비만 하고 있네요',
#        '별하나도 아깝내요 이따위로 할거면 안하는것이 나을듯 좀더 사용자의 편의를 생각해서 만들어 줄수는 없는것인답변도 하나같이 같고',
#        '카드 있는데 왜또 굳이 신청해라는건지....',
#        '충전 환불 제도도 불편하고 상담원 연결 너무 안됩니다. 그리고 쓸 금액만 충전해서 그거 전부 사용했는데 캐시백이 안됬더라구요. 보니까 금액이 모자라서 연결된 카드로 빠져나갔다던데 왜 그렇게 되는건가요? 쓸 금액만 충전해서 충전한 그대로 다 썼는데 왜 카드 전환이 된거죠.. 제대로된 설명도 없고 하나부터 열까지 마음에 안듭니다..',
#        '충전후 다시 빼는 기능도 없고 맨날 업뎃 해라고 하고 어디가 가맹점인지 안내도 없고',
#        '앱 사용 더 어려워졌음 캐시백 받은거 사용하려면 사용할때마다 앱 들어가서 설정해야하고 설정하는것도 한번에 안되고 까다롭게 해놈 부산시민을 위해서 만든 복진데 이걸 이렇게 만들어놓으면 나이 많으신 분들은 쓰기 힘드실텐데 이걸 왜 이렇게 만들었을까 예전 앱이 더 사용하기 편하고 한눈에 딱 들어왔다고 생각함',
#        '이음카드에 비하면 너무 기능도 없고 카드 1개 밖에 신청도 안되고 부족한점이 너무 많아요', '캐시백 환원요',
#        '너무 불편하고 알아보기도 힘듭니다 잔액 이관시켰는데 캐시백금액은 바로 사용할 수도 없고 ㅠ 지난 번 앱이 훨씬 쓰기 편했습니다 캐시백 사용설정만 ON으로 해놓으면 언제든 캐시백 금액부터 사용가능했는데 이 번엔 캐시백 사용설정하고 일정 시간 내에 실물카드로 결재하라고 하네요 언제든 캐시백금액부터 사용되도록 시스템 만들어 주세요 대체 왜 사업자 변경하고 앱 새로 만들었을까요? 부산 시민 의견이나 사용편의성은 전혀 안중에도 없나보네요',
#        '와 진짜 코나카드? 바뀌고나서 개구려짐 진심이럴꺼면 왜바꾼건지? 전 어플에서는 가맹점 조회도 할수있었는데 지금은 어디갔는지 없어진거도 짜증나고 ui도 완전 구리고 너무 불편함\n나아진게 하나도 없네 피드백 수용해서 제대로 좀 만드세요.. 앱 개발자가 누군진 모르겠는데 이렇게 하나도 빠짐없이 다 불편하게 만들어놓은게 참 신기하네요 ;',
#        '가맹점찾비불편합니다',
#        '가맹점 찾기 고객센터에 1:1문의도 남겼는데 답변도 없고..\n캐쉬백 받을 수 있는 가맹점 찾기는 어떻게 하나요?\n매번 결제시 물어 봐야 하는건가요?',
#        '별 하나도 아깝네요ㅜ전에 쓰던 앱이 훨씬 나은듯.. 얼마나 썼는지 적립은 된건지 알 수도 없고 가맹점 찾기도 안되고 뭐 되는게 없는ㅡㅡ 겁나 불편해요.. 그냥 이관할때 앱도 같이 사서 앱은 그대로 이용하게 해주지..이건 뭐 앱이 달라져서 적응하면 편하겠지가 아니라 앱 자체가 슈레기ㅠㅜ',
#        '사람들 불편사항 다 비슷한데 몇달이 지나도 개선의 의지가 안 보이네요. 잔액 나오게 하는게 힘든것도 아닌데 왜 안 하는지 모르겠고, 이용내역에서 충전한 돈이든 캐시백받아 적립된 돈이든 함께 볼 수 있게 해주세요. 이전에 동백전에선 아주 간단하게 통합형/충전한 캐시/적립금 사용금액 같이 또 따로 볼 수 있었는데 여긴 뭐 이렇게 복잡하게 해놓는지. 애초에 사용가능금액에 충전한 잔액만 나오는것도 말이 안 맞고. 캐시백 사용내역보려면 캐시백 금액을 클릭해야 하는것도 불편해요. 사용가능금액은 금액 누르는게 아니라 이용내역 눌러야하는데 말이죠. 이런 사소한것들이 모여서 동백전이 불편해졌다고 느끼는겁니다.',
#        '너무 불편하네요 이전에 앱은 \n사용가능 금액 캐시백 금액 \n간단하게 바로 확인이됐는데\n\n이번앱은 고객 편의가 아닌\n의뢰처 기준인지\n지원받은 혜택받은 금액 위주로 불편하게 되어 있네요\n\n아주 불편해요',
#        '레이아웃이 엉망이에요 제일 중요한게 남은잔액,캐시 등인데 쓸데없는 기능은 엄청 크게해놓고 정작 중요한 잔금 등은 글자도 작고 시인성도 안좋아서 아무리 적응하려해도 적응이 안되네요',
#        '새로운 동백전 카드 새로 발급 받아야됨 교통카드 기능 없음 체크카드 기능 없음 새로운 카드는 선불카드 기능만 있다고 하네요 예전 동백전 카드를 계속 쓸수있다니 예전 카드 계속 쓰고 새로운 카드는 쓸일이 없겠네요.',
#        '캐시 적립현황을 볼수있는화면이 왜없는거죠? 일별,월별조회되어야되는거아닌가?', '가맹점찾기 만들어주세요.',
#        '아니 멀쩡한 이전 동백전(kt)을 왜 이딴 데랑 바꿔서 시민들에게 불편을 주는 건지?? 동백전 가맹점 보기 기능도 첨부터 제공안하고 허술하기 짝이 없고 맨날 뭐만하면 업뎃하래.... 겁나 불편....1점도 아깝다....',
#        '가맹점 찾기 만들어주세요 가게마다 물어볼 수도 없고 전 앱에서는 검색 가능해서 좋았는데 너무 불편해요 지금ㅋㅋ...',
#        '앱이 너무 불편해요. 이전 앱은 충전금액, 캐시백 따로따로 한눈에 볼 수 있고 캐시백 사용도 온오프 설정으로 간편했는데...완전 개악입니다. 동백전 캐시백은 없어진건가요',
#        '가맹점 검색하는 기능 왜 없어졌나요 ㅠ 잘쓰고 있었는데;',
#        '가맹점 조회도 안되고..예전보다 훨씬 불편해졌네..누굴위한 앱인지... 너무 불편하네요 실용성이 너무 낮아요.. ㅠㅠ 쓸데 없는 부분은 좀 정리햇으면 좋겠어요..',
#        '왜 기존 사용카드는 사용하면 않되나요. 꼭 카드 새로 발급받도록 앱을 만들었을까요. 고객 편의 좀 봅시다.기존 카드 그대로 사용토록 앱 만듭시다. 0점 드릴께요',
#        'ㅠ가맹점 찾기라뇨ㅠ 생각보다 안되는곳도 많고 충전금액 환불은 왜 안되는거죠? 계속 실패했다고 뜨는데',
#        '기존카드 사용되지 않는다면 굳이 새로 만들 필요 없는데, 번거롭기만 하니 환불 조치는 가능한지요?',
#        '다른건 둘째치고 캐시백 사용이 너무 번거로움. 이전 동백전 앱이 사용자 입장에서 더 좋은 것 같음.',
#        '가맹점찾기에서 가맹점이 하나도 안보여요.',
#        '아니 어플 좀 옛날처럼 하면 안되나요? 내지갑 이런거 왜하죠? 너무 불편. 그냥 메인에서 모든 금액 다 볼 수 있게 바꿔주세요\n그리고 가맹점 찾기는 왜 이렇게 안되죠? 검색도 잘 안되고 리스트도 한눈에 볼 수도 없고\n도대체 업체를 왜 바꾼건지 모르겠네요\n옛날 어플 좀 참조하시면 안될까요?  너무 답답하네요',
#        '충전하는 계좌를 2개이상으로 할수 있도록 해주세요! 사옹가능 가맹점을 검색할 수 있게 해주세요!',
#        '앱이 열리지않고 답답하네요 충전을 못하고 이용하지를 못하겠네요',
#        '왜 KT와 1년으로 계약해서 사용자들에게 이런 번거로움과 불편함을 만드는지 이해가 안되네요. 1. 기존 체크카드 사용자는 신규 발급없이 기존 것 그대로 이관 및 사용이 가능하다더니, "반드시" 카드 만들지않으면 어플 실행도 못하게 해놓은 게 맞는건가요? 누구 좋자고 이런 비용 버리는지 모르겠네요. 2. 충전 계좌 여러개 지정할 수 있었는데 1계좌밖에 안되니 이 또한 불편합니다. 3. 삼성페이 된다고 적혀있는데 기존의 충전식 체크카드가 아니라 선불카드 개념인데 확실히 되는거 맞나요? 왜 사용자들은 안된다하는데 어플 설명에는 가능하다 하는지.. 4. 금고는 왜 만들고, 사용처 검색도 없고 UI자체가 뭔가 더 찾기 어렵고 매끄럽지 않은 느낌입니다. 5. 소득공제 신청도 필수로 해야한다하니 점입가경입니다. *여러모로 좋은 점은 1도 없고 업체가 바뀌는 통에 개인정보만 원하지도 않게 한번 더 노출된 격이네요.',
#        '그냥 좀 간단히 만들면 되는것을 짜증 납니다 그리고 맨날 광고을 띄워야 합니까',
#        '가맹점 가맹점 찾기 아예안되요 쓰지말라는건가요?',
#        '에휴 진짜 이전 회사 기능들 좀 다 개발하고 이어 받지 뭐가 급하다고...',
#        '카드 재발급 왜 합니까? 캐시백 사용 설정은 타인 명의 폰 사용자는 못쓰게 하는 겁니까? 이전 시스템과 같을 수는 없지만 비슷하게는 할 수 있지 않습니까? 이대로라면 너무 불편해서 동백전 안쓸거 같습니다 카드 신청 취소해주세요~!',
#        '너무 불편해요 알림 설정 아무리 해도 절대 안와요\n\n앱 자체도 보기 불편하고 뱅크샐러드 연결도 안돼서 정말 쓰기 싫어질 정도… \n\n가맹점 찾기 기능이 제일 중요한데 업뎃 좀 빨리 해주세요ㅠ',
#        '가맹점 찾기 왜있나요? 되는곳도있고 아닌곳이있고. 그게 헷갈려서 찾기 서비스가 있는거 아닌가요? 왜이렇게 안되는곳이 많죠? 심지어 충전식이라서 다른통장에서 돈을 뺐는데 안된다니. 지도상 틀린곳도 많습니다.',
#        '어플이 진짜 구려요 오류나서 접속이 안되고 로그인도 안되고..써야할 때 못쓰면 무슨 소용이죠 시스템안정화 신경써주세요',
#        '이전 어플방식이 훨씬 편한데 캐시 이용법이 더 불편한 곳으로 굳이 업체를 바꾸셨네.....',
#        '날짜검색이라던지 총 사용금액에 대한 조회가 좀 불편합니다...',
#        '캐시백 재원부족이라더니...업데이트를 해야 충전 할 수 있는데 수일째 업데이트가 안됨 결국 사용하지 마라는건지..',
#        '이용하기 더 불편하게 만들꺼면 전 운용사가 더 돈을 많이 받아서 바꾼건가 싶음 바코드 결제도 안돼고 캐시백 사용도 온오프로 해주시고 개선 좀 해주세요',
#        '동백전 앱 개선부탁드립니다 잔액이 초기화면에서 보이지 않는 점이 가장 불편하고 이전 어플에서 유용하게 썼던 큐알코드, 바코드 결제가 없어 불편합니다. 새로운 카드 발급이야 어쩔수 없이 했지만 이전에 되던게 안되니 너무 불편하네요',
#        '지금 가맹점찾기 저만 안되는 건가요?? 앱에 오류가 너무 많아요ㅠ',
#        '첫날이라 그런지 고객센타는 연결도 안되고 앱도 사용불편 예전께 쓰기 쉬웠던거 같아요',
#        '그지같에 그냥 그대로하지 설명이너무부족하고 선불카드은뭐고 서비스구려',
#        '가맹점 조회 기능 만들어주세요. 가맹점 검색 후 지도를 볼 수 있게 만들어주세요. \n(기존 동백전 방식 처럼) 더불어 오륙도페이도 같은기능 추가 부탁드려여'],
#       dtype=object)

# %% [markdown]
# ##### 토픽 5
#
# 0.051*"번호" + 0.045*"인증" + 0.042*"계속" + 0.039*"짜증" + 0.033*"업뎃" + 0.028*"네트워크" + 0.025*"자꾸" + 0.025*"오류" + 0.018*"자체" + 0.016*"버전"

# %%
topic_5 = topictable[topictable['가장 비중이 높은 토픽'] == 4.0]

print('토픽 5에 해당하는 리뷰의 개수:', topic_5.shape[0], '개')
# Out:
# 토픽 5에 해당하는 리뷰의 개수: 82 개

# %%
# 토픽 5에 해당하는 리뷰들만 모아서 하나의 df 만들기

topic_5_list = topic_5['리뷰 번호'].unique()
df_topic_5 = df_negative.loc[topic_5_list, :]

df_topic_5.head(5)
# Out:
#            DATE  STAR                                             REVIEW  LIKE
# 15   2020-01-07     1  오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하...     0
# 35   2020-04-10     1   이거 인증번호가 밀려서 날라오죠? 3분안에 오지도 않아서 가입조차 진행할 수 없습니다.     0
# 66   2021-01-14     2                              멍청한어플이 계속 네트워크접속안댄다하노     1
# 98   2020-04-13     1                                       앱 자체가 열리지 않음     0
# 100  2020-04-13     1                      초기화면에서 계속 멈춰있다가 네트워크 오류로 꺼집니다     0

# %%
# 리뷰 전부 모아보기 --> 복사해서 R로 들고가서 감성분석 진행

df_topic_5['REVIEW'].unique()
# Out:
# array(['오류거지같음 쓸때마다 앱자체 오류도 많이 나고 이용자수 많다면서 결제도 안되고 툭하면 점검들어간다하고 동백전에 돈 충전해서 체크카드에서 출금이 됬는데 동백전에는 충전금액 뜨지도 않네요-_- 내 돈은 어디로 간거임 ㅈㄴ 별1개도 아까움',
#        '이거 인증번호가 밀려서 날라오죠? 3분안에 오지도 않아서 가입조차 진행할 수 없습니다.',
#        '멍청한어플이 계속 네트워크접속안댄다하노', '앱 자체가 열리지 않음',
#        '초기화면에서 계속 멈춰있다가 네트워크 오류로 꺼집니다',
#        '카드를 만드려다가 민증 발급일자 오류를 5번 초과해서 만들 수가 없습니다. 운전면허증도 없어요. 이럴 경우 어떻게 해야합니까?',
#        '인증번호가안오네요;; 아니무슨 내폰skt고 다맞게했는데 인증번호 전송햇다카믄서 안오는건 뭐지',
#        '핸드폰변경하면서 통신사를 옮겼는데 새로 번호등록하라고 초기화 버튼이 떠도 눌려지지가않아요. 인증만10번째인데 아직도 계속 그상태 그대로입니다. 로그인할때마다 인증해야하면서까지 써야하나싶네요',
#        '아인증번호 입력하려 나갔다오면 자꾸 앱강종돼서 처음으로돌아가요; 인증을 할수가없잖아요 별1도아깝다',
#        '본인인증에 재발송 안하고 다음을 클릭했는데.. 왜 계속 인증번호가 날아오고...본인 인증이 안됩니까?',
#        '삼성페이안됨 카드재발급 사실인감? 뭔 충전 취소도 3일 걸린다고하고 초기라 이해할려지만 배려가 없네 없어 다운그레이드된 느낌 4월 5일부터 사용가능이라는데 카드발급이 당일날 되나? 나참',
#        '카드팔이 중소기업 직관성은 개줘버렸냐? 조잡하기 그지없는 앱',
#        '동백전 가입할라는데 인증번호가 안와요 3번 시간초과됫는데도 안와요 왜안오는거죠',
#        '회원가입시 인증번호가 안옵니다. 이틀째 가입중인데 인증번호가 계속 수신이 안되는데 뭐가 문제일까요?',
#        '본인인증 단계에서 휴대폰 인증번호 발송이 안되고, 카드번호로 인증하려고 해도 번호오류라고 계속뜨네요. 카드신청을 할 수가 없네요ㅠ',
#        '업뎃 좀 그만...', '안증안되요.. 쓰고싶어도 인증이안되니 쓸수가없네요..',
#        '와 피드백 ㅋㅋ진짜안받네; 의견 취합해서 업뎃해야하는거 아닌가요? 이용자들 불편하다는 요소 싹 무시하고 뭔 업뎃을 한지 모르겠네요.',
#        'ㅠ 주민등록증 찍는데 청소년들은 청소년증으로 하라해서 청소년증 찍고 발급날짜 했는데 면허번호 그거 오류라고 뜨면서ㅠㅠ 청소년한테 면허번호가 어딨어요 ㅋㅋ',
#        '계속 번호가 바뀌었다며 재인증하라고 뜹니다. 매번 재가입을 해야만 사용이 가능하며 심지어는 가입하자마자 앱을 종료했다가 실행시 또 휴대폰 번호가 다르다며 초기화 후 재가입하라는 안내가 뜹니다',
#        '계속 렉걸리고 네트워크접속이 안된다고하고 예기치못한오류가 생겼다며 너무 잘 안됩니다ㅠㅠ', '업뎃이 안됩니다',
#        '인증번호가 안오는데 어떻게 해야될까요',
#        '미리 공지해줬으면 이런 혼선도 안생겼을텐데, 그래도 부산시랑 남구-동구 업체가 같아졌으니 연계를 통한 지역활성화 조금은 기대해봅니다. 아직은 2점...',
#        '동백전 어플설치 저는 아이폰이라 설치를 했지만, 아버지도 동백전 어플 설치해드리려고 하니 갤럭시노트2는 오래된 폰이라고 안된다고 하네요~ 부산지역화폐인데 모두 설치하여 사용할 수 있게 낮은버전의 폰에도 동백전 어플 설치가 가능하도록 해주시면 더 좋을 것 같아요~\\',
#        '인증번호가 안오네요 앱에 문제가 있나요?', '계속해서 기기에서 충돌앱이라 나오는데...어찌 해결좀??',
#        '선불 카드 신청 취소바람. 당일임.',
#        '동백전 사용중에 알뜰폰통신사 이동했더니 켤때마다 계속 초기화 불러오는 오류가 있네요',
#        '인증번호 이틀째 접속불량 불편해',
#        '동백전 사용하기 좋아요! 그렇지만, 안드로이드 버전이 낮아 동백전 어플 자체가 아예 설치 안되는 경우가 있어요. 부산지역화폐이고 어플을 통해서만 가입이 가능한 부분을 감안한다면, 버전이 낮은 폰의 경우에도 동백전 어플을 설치할 수 있게 조정해주시면 더 좋을 것 같아요!',
#        '뭔가 좀 다른 느낌 나는 했갈여요?',
#        'ㅈㅂㅈㅂㅈㅂㅈㅂ개선쫌 화면이 너무 정신사납고 직관성 떨어짐 ..제발 원래 앱처럼 바꿔주세요 별한개도 아깝네요',
#        '한도 늘리면 뭐하노 어플 업데이트도 안되 다시 설치도 안되... 아 짜증나네', '업체 바꿔서 짜증남',
#        '아니 접속이 자꾸 안되는데 어째된거죠 짜증나네요 이젠',
#        '너무 속도도 느리고 업뎃도 안되고 허술 그자체 임 별하나도 아까움',
#        '우씨 업뎃이 안되잖아요..설명한것처럼 들어가서 삭제하고 했는데도 안되요..개짜증남. 3마넌 때문에 이게 뭐하는 짓인지..글고 질문에 대한 답변이 너무 성의없는거 아니예요?',
#        '회원할려는대 인증번호가 안오네요....',
#        'Ios 안드로이드 버전 낮으니까 아예 플레이스토어에 없네요 ...다른 카드나 은행앱은 다 깔리는데 이게 뭡니까 ...버전 범위좀 수정해주세요 ㅡㅡ',
#        '머고 네트워크이상하다고 안열린다 젠장 불편해죽겠네',
#        '새버전으로 바꾸고 자꾸 폰에서 소리나고 버벅되고 아니 이러면 사용을 어떻게 합니까??',
#        '잘되던 얩이 얼마전부터 네트워크 상태를 확인하세요 이런 문구만뜨고 앱 실행이 안되요',
#        '네트워크 오류라고 실행자체가 잘 안되네요 왜 2점인지 알겠네요',
#        '가입하려고 폰인증번호 전송누르면 예기치못한문제발생 했다고 진행이 안됩니다 수십번을 해봐도 똑같네요 머가 문제인가요',
#        '동백전 바뀌고 너무 불편합니다 원래앱이랑 너무 비교되네요 이전앱참고해서 개선하는게 좋을 듯합니다',
#        '앞전과 비교했을때 포인트 쓰는것도 너무불편합니다', '이게 뭔가요? 계속 열리지도 않고 짜증 너무 나네요',
#        '아 새카드 발급 발급 취소도 안되네..짜증. 별 한개도 아깝다..',
#        '클릭 안됨 가입 다 하고 맨 마지막에 비밀번호 설정하는 거 클릭이 안되네요',
#        '자꾸 네트워크 이상이라면서 안 들어가집니다 급하게 써야할때마다 난감해요 폰 기종이 갤럭시 노트4라서 그런건가요?',
#        '동백전앱이 곧 기기에 설치된다고하고 설치가 안되는데요? 무한반복',
#        '일일 출금 한도를 초과햇다고요? 왜 충전이 안됩니까', '인증번호가 안와서 신청못하고 있어요. 어케하나요.',
#        '노트2에서는 버전이 낮아서 검색이 안되는데.. 어느버전 까지 가능 한가요? 앱 다운 없이 카드만 사용가능한가요?',
#        '인증번호 발송됐다는데..인번이 안와서...',
#        '복붙좀 그만하세요; 1대1상담은 왜 있는겁니까? 뭐 물어봐도 동문서답하질않나. UI는 20대인 제가 사용하기도 복잡한데 나이드신분들은 오죽할까요? 그리고 원래 기존카드 사용된다고했다가 앱에서 선불체크카드등록이라는 애매한 말써서 신규카드 발급시키게 유도하는거 누가 모를줄 아십니까? 또 복붙으로 답글 달아주세요 얼른',
#        '한도가 바뀌고하면 공지를 좀 해주세요 너희끼리만 알면 뭐합니까', '몇일째 업뎃이 안되네영 ㅡ.ㅡ;;',
#        '네트워크오류로 계속안들어가 지는데 원래이런건가요? 답답하네요',
#        '별하나도 아깝네요..기존회원이라 새로운앱깔고 하라는대로 다 했는데 확인할수없는다는 문구만..전화로 문의하니 아직 백퍼이관이 안돼서그렇다는 말만 반복.. 이렇게 제대로 안될꺼면 아예 날짜를 넉넉하게 잡아서 일처리하는게 맞는게 아닌가요..',
#        '설치 후 켤때마다 초기화,재인증하라고 하죠? 등록된 정보와 핸드폰 번호가 다르다는 안내가 나오네요.. 동일한 번호로 인증받고 설치했습니다. 재설치해도 동일한 현상이 반복됩니다. 어떻게 하면 되나요?',
#        '진짜 짜증난다ㅡㅡㅡ', '자꾸 휴대폰번호가 일치하지 않다고 함..왕짜증',
#        '정말 오류가 많이 뜨네요 오류가 계속 떠서 사용하기 너무 힘들어요',
#        '이거 왜 안들어가지나요? 계속튕기기만하네요...이러다 무용지물이 되는건아닌지...', '짜증남',
#        '너무 불편 그자체 누가 만드는지 모르겠지만 안써보는것같음',
#        '가입이 안됩니다!!인증이 안되요~ㅎㅎ발급 받아보려고 어플깔고 휴대폰 인증하는거 아무리 눌러도 안되니 신경질나서 쓰겠나싶어요~나만 안되는거야!!!??짜증나요^^',
#        '쓴지 얼마안됐어도 캐쉬백들어오는것도 좋고 맘에 들었는데 짜증나서 못써먹겠네요 무슨앱이 자꾸 네트워크 연결이 안된데요?',
#        '뭐가자꾸 접속이안된대 짜증나게ㅡㅡ',
#        '동일한 후기가 많습니다만 왜 자꾸 네트워크 연결안된다고 하나요?? 불편해서 못 쓰겠네요 고작 확인 하나 하는데 이렇게 시간이 많이 걸리다니',
#        '짜증나~', '안켜져요 ㅠㅠ 계속 오류나서 새로 설치했는데 자꾸 네트워크 오류라고 하네요',
#        '별 한 개도 아깝다. 평점 조작했나. 뭔 4.5야, 캐시백만 아니면 거들떠도 안본다. 충전하려고 해도 앱이 열려야지. 네트워크 접속이 안된다고 하고 정상적 os가 아니라고 하고 지웠다깔았다. 수번에 수백번 접속 실패. 쓰기 불편해서 나이 많은 사람들은 안씀.',
#        '가맹점 찾기 버튼도 없고 인터페이스 구조가 너무 조잡합니다. 기존 카드 그대로 사용이 가능하다고 했는데 이관신청 하면 바로 배송지 받을 주소가 왜 나오죠? 계속 진행해서 신청하고 발급현황에서 바로 해지하려고 하는데 신청당일 해지 가능이라면서 되지도 않습니다.',
#        '깔고 위치확인동의 같은 것들 모두 동의 누른다음에 계속 흰화면이 뜨고 한 4~5분 기다리면 네트워크 상태 확인하라고 하네요. 실행이안되서 가입도 못했어요',
#        '카드신청오류 계속뜨네요',
#        '직관성 최악 환불하기도 한참 찾아야하고\n돈옮기기를 계좌이체마냥 혼동하게 만들어둬서 잘못 건들면 돈도 그대로 묶임 ㅋㅋㅋ\n여태까지 본 금융어플 중 최악',
#        '뭣같이 만들어 놓고선~ 지네들 직원끼리 별다섯게 주고 기대가 된다느니 오만 조작질 평점,리뷰 싸지르고 있네~ 쓰레기 같은것들~ KT가 계속하지 왜 바꿔가지구 이 사단을 만드는지 쯧쯧쯧',
#        '카드신청에서 자꾸 오류가뜨네요', '계속 오류가 떠요..ㅜㅜ'], dtype=object)

# %% [markdown]
# ##### 토픽 6
#
# '0.050*"충전" + 0.040*"금액" + 0.034*"환불" + 0.025*"적립" + 0.025*"결제" + 0.023*"에러" + 0.022*"사용" + 0.022*"캐시백" + 0.020*"만원" + 0.017*"불가"

# %%
topic_6 = topictable[topictable['가장 비중이 높은 토픽'] == 5.0]

print('토픽 6에 해당하는 리뷰의 개수:', topic_6.shape[0], '개')
# Out:
# 토픽 6에 해당하는 리뷰의 개수: 144 개

# %%
# 토픽 6에 해당하는 리뷰들만 모아서 하나의 df 만들기

topic_6_list = topic_6['리뷰 번호'].unique()
df_topic_6 = df_negative.loc[topic_6_list, :]

df_topic_6.head(5)
# Out:
#           DATE  STAR                                             REVIEW  LIKE
# 4   2020-02-19     1                          연3일째 계속 앱도운로드중 아직도 다운중이네요     0
# 13  2020-09-07     1  잔액 부족하면 연결 계좌에서 바로 빼가지 말고 알람 줬으면 좋겠어요. 충전해서 쓰면...     4
# 34  2020-04-06     1               고객센터는 일하는사람있나요? 전화도안받고 1:1문의글 읽지도 않음     0
# 37  2021-04-05     1             장난치나?앱을 이따구로 만들고 고객센터 아무리 전화해도 안받네? 하아     7
# 41  2021-04-25     1             환불 규정 바뀌고 실시간 환불도 없어지고 진짜 전에있던앱이 훨씬 나음     2

# %%
# 리뷰 전부 모아보기 --> 복사해서 R로 들고가서 감성분석 진행

df_topic_6['REVIEW'].unique()
# Out:
# array(['연3일째 계속 앱도운로드중 아직도 다운중이네요',
#        '잔액 부족하면 연결 계좌에서 바로 빼가지 말고 알람 줬으면 좋겠어요. 충전해서 쓰면 6% 적립인데 자동 결제되버리면 적립기회놓쳐요. 그리고 잔액+적립금 동시에 쓸수 있게 해주세요!',
#        '고객센터는 일하는사람있나요? 전화도안받고 1:1문의글 읽지도 않음',
#        '장난치나?앱을 이따구로 만들고 고객센터 아무리 전화해도 안받네? 하아',
#        '환불 규정 바뀌고 실시간 환불도 없어지고 진짜 전에있던앱이 훨씬 나음',
#        '앱이 오류로 열리지도 않아요 ㅡㅡ 머하자는 건지 충전을 못하고 있어요 화가 나요 ㅡㅡ 돈충전을 못해서 사용을 못하고 있습니다 갤럭시s10입니다',
#        '후발주자면 훨씬더 앱사용이 편해져야하는데 쓸데없는 설명만 많고 복잡합니다 제일 궁금한 캐쉬백 충전내역은 몇번을 클릭해야 알수있고 이번달 10% 캐쉬백 받을수 있는 잔액을 한눈에 알수있었던 기존의 앱과는 달리 기본충전 금액이 50만원이라 혜택가능금액을 알수가 없네요 어른들이 다들 전에꺼보다 힘들다고 하십니다',
#        '충전하기', '이전엔 접속 되었는덕 오늘새벽에 뭐 서버넓힌다고 충전안되더니 지금은 어플이 켜지지않아요...',
#        '아이폰 배지 표시 아이폰 배지 표시 가능하게 해주세요.',
#        'UI쫌 개선 합시다. 캐시백 때문에 쓰는 사람이 대부분일텐데.. 캐시백이 얼만지 어떻게 사용하는지 어디 숨겨놨나요? 한참 찾아도 안보여서 여기 리뷰답니다. 일부러 숨긴거 아니면 UI를 이전 어플 따라하던가, 쫌 바꿉시다!!!',
#        '뭔가 많아졌는데 죄다 불필요한 정보들이에요. 한달에 내가 현금으로 얼마나 썼는지 이전처럼 확인할 수 있게 해 주세요. 캐시백 혜택을 받을 수 있는지는 확인해야죠',
#        '접속이 안되네요 빨리 계산해야되는데 앱이 접속이 안되서 주위사람들 눈치밥 먹으면서 다른 카드로 계산 했습니다..;;',
#        '정말 기존 앱이 훨씬 간단하고 사용하기 편햇는데 오ㅑㄹ케 불편하게 해놧는지모르겟네 캐시뱍 적립된거 얼마적립됫다는거 도대체어디서 확인할수잇죠? 총 얼마 혜택금액만 나와잇지 얼마가 언제적립됫는지는 란나와요 ㅠㅠ 3만원까지라서 그런건가 아님 3만원 까지는 그래도 적립이되는건지 증말 앵간하면 리뷰안다는데 이건 너무 ㅠㅠㅠ 불편하구 억지로 새카드 발행하게하구 메뉴 필요이상으로 많고...',
#        '잘안될때가 많고 환불도 제약있고 그냥 안쓸랍니다 카뱅만세',
#        '불안정한 앱 이용내역 확인 시 강제종료 앱 메뉴도 간단하고 동백전 서비스도 훌륭한데 ',
#        '자꾸안괴요 충전해서 결제 해야 하는데 카드 달랑 한개 들고 나왓는데ㅠㅠㅠㅠ',
#        '사용 가능 금액과 캐쉬 금액 합산을 표시 해 달라!!',
#        '캐시백 이용한도 이전 서비스에는 캐시백 가능한 30만원 중 얼마 썼고 얼마 충전할 수 있는지 알 수 있었는데 \n바뀌고 나서는 사용 가능 금액 제외 충전할 수 있다고 뜨니까 \n캐시백 이용한도 안에서 얼마를 썼는지 하나하나 계산하고 이용해야해서 너무 불편해요 \n일반 사람들은 캐시백때문에 동백전을 쓰는 경우가 많으니, \n캐시백 이용한도 30만원 중 얼마 이용가능이라든지 얼마 충전가능이라든지 그런 서비스를 추가해주셨으면 좋겠습니다',
#        '캐시백 세부사용내역 보여주세요. 기본에 기본도 안되어 있는듯요. 누가 도대체 개발하셨죠? 이 카드 쓰는 이유가 10%적립 받으려고 쓰는건데, 적립내역을 세부적으로 볼수가 없어요!!! 진짜 기본에 기본을 무시한거 아닌가요? 저는 제가 적립확인 페이지를 못찾았나 했는데, 여기 리플들 보니 아예 없는게 맞았네요. 그전처럼 간단하고 확실하게 볼수 있게 다시 만드세요. 예전엔 너무 편하게 확인하고 썼었는데, 바뀐 어플은 불편하기짝이없네요!! 도대체 왜 바껴서 이렇게 불편하게 하나요!! 못만들겠으면 그냥 그전꺼랑 똑같이 만들면 됩니다!',
#        '충전금액 환불이 자유로울거라 생각하고 카드발급, 어플설치를 하고 충전을 했었는데 급히 보낼 곳이 있어서 환불을 했어야 됬기에 환불 버튼을 눌렀는데 아무것도 못하더라구요. 그래서 밑에 쓰인 글을 읽어보니까 전액 환불은 충전후 7일 이내로 문의하여야 되고 조금이라도 사용한 경우에는 충전금액의 60퍼센트를 사용하여야 남은 금액을 수수료 없이 환불이 가능하다고 쓰여있더라구요..그래서 급한 마음에 고객센터에 30분을 붙잡고 전화를 한 끝에 겨우 통화가 연결되서 환불을 받았습니다. 환불은 당일이 아닌 다음날 오전에 환불이 된다고 하셨구 오전에 바로 들어와서 받았습니다. 캐시백 받으려다 보내야될 돈을 못보낼 뻔 했어요.. 환불정책이 어렵고 복잡한데다가 고객센터 문의가 많은지 연결도 잘 안되서 충전하고 급히 보낼 곳이 있을때 유의해야 겠더라구요. 잘 사용하시는분은 계속 사용하시겠지만 저는 이렇게 사용할거면 못쓰겠어서ㅠ 부산 지역 화폐가 생겨서 좋았지만..',
#        '아니 충전하려 들어가면 계속 튕기고 지우고 깔아도 튕기는데 이러면 그냥 쓰지말라는 소리 아닌가요?',
#        '불편하네요 기존 앱보다 너무 불편하네요\n금액충전은 메인창에  한눈에 확인하고 충전이 되었는지 금방 확인할수 있어야 되는데  이건 들어가서 또보고 확인하고 캐쉬백도 사용 설정이 명확하지 않아 된건지 아닌지 ..이런 앱이 지리멸렬할 필요가 있나요',
#        'ㅋㅋ고객센터 고객센터 답변 얼마나 기다렸는데 일 쥰나 안 해요~', '아이폰은 안되나요?',
#        '아이폰 사용내역 알림 아이폰 사용내역 알림 언제쯤이면 사용 가능한가요?\n결제 내역이 안와서 항상 잘 되었는지 어플 켜서 확인해야하고 너무 번거롭네요.',
#        '쓰레기앱 대체 일처리를 어떻게 하는지 궁금할 지경임 어르신들은 어찌 쓰라는 건지 전체적으로 불편한 인터페이스에 총사용액이 안 나와있어서 쫌쫌따리로 충전해서 쓰면 나중에 얼마썼는지 계산하기 번거로움 게다가 전에는 동백전 환불하면 바로 입금됐는데 이제는 며칠씩 걸림 쓸데없이 카드를 만들라하지않나,, 동백전 이관되고 더 나아질 줄 알았는데 퇴보하기만 하네요',
#        '너무 불편하고 복잡해요 동백전 이전 앱이 더 좋아요 캐시백 사용내역이나 적립내역도 못보고,,,',
#        '포인트와 충전금액을 이전처럼 따로 금액분리 요함',
#        '안드로이드 5 에서 10일부터 갑자기 실행이 안됨. 언제 수정될지 계획이 없다는 답변에 ㅎㅎㅎ 그냥 웃지요.',
#        '결재, 환급 속도가 너무 느려서.. 주유소에서 기름 가득 넣고 재결재 될때 취소된 금액 환급이 빨리 안되니 통장에서 바로 빠지네요. 주유하실때 참고하세요. 구동백에서은 안그랬는데....',
#        '아이폰 X 충전안됨 충전하러 가면 튕겨요',
#        '내역만 들어가면 팅김 내역에 들어가면 팅겨요. 아이폰 xs입니다. 다른 내역 확인 가능한 싸이트가 있으면 좀 알려주세요 아 답답해 미쳐버리겠네요',
#        '어휴 충전 열번도 오류나길래 딴카드 긁고 나니 되네 기존업체가 훨씬 나은데 머하러 이런업체랑 하는지 참',
#        '적립내역 왜안보여주시나요?', '업데이트하고 나서 안들어가지고 환불도 시간엄청걸리는 바꾸고나서 좋아진게하나도 없네요',
#        '한동상향했는데 50만원이상충전 안되네요',
#        '아직 써보지도 못했을 뿐더러 예기치못한 오류라며 앱 접속조차 안되네요... 부산지역화폐가 나와서 기대했는데 실망스럽습니다',
#        '카드가 오류가 떠서 결제가 취소됐는데 캐쉬백은 들어왔고 어플은 켜지지도 않고. 어플을 지웠다 깔았다 수차례. 폰을 켰다 껐다 수차례. 아직도 안켜지고 답답하네요. 아 속터져',
#        '이전 동백전은 오류 한 번도 없었는데, 잔액환불도 너무 느립니다. 6월 1일자 결제오류건 환불은 언제되나요?',
#        '아직도 콜센터도 연결 안되넹....',
#        '월별 사용내역 다 보이게 좀 기본값 설정해주시오. 매번 일별로 누가 계산합니까? 취합자료 보려면 월별로 보느디',
#        '아 진짜 내가 살면서 앱 리뷰 쓰는건 처음이네. 전 앱이 훨씬 나은 이유.\n캐시백이랑 충전금액 따로 나와있었는데\n없이 불편하고 쓸데 없이 복잡함.\n그리고 이관도 어이 없는게 \n충전금액이랑 캐시백 둘 중에서 많은쪽 하나만 넘어옴',
#        '사용금액이랑 캐시백 금액 합쳐서 나와야지 아니 따로따로 나오면 어쩌자는 건데?? 어이가 없네\n\n결제할때 캐시백 금액이랑 같이 계산해서 해야하는거야???',
#        '진짜 전에쓰던어플이훨씬좋음 뭐하나편한것도없고 \n\n잔액환불도 전에쓰던건 빠릿빠릿바로돈이들어오고 그랫는데 지금쓰는건뭔\n2일지나도 환불도안되고잇고 답답합니다그냥...',
#        '일단 어플이 너무 느려요ㅠㅠ 또 실행할때 네트워크가 불안정하다고 안열리네요.. 가맹점이라고 표시되어있어서 갔는데 결제가 안된다고해서 다른 카드로 계산했네요ㅠㅠ 자잘한 오류가 너무 많은거같아요..',
#        '왜 적립이 중단하고 지ㄹ이야.',
#        '도대체 누가 앱을 이렇게 기획했나요… 처음에 알아보기 힘들면 그냥 알아보기 힘든건데….\n본인 충전금액, 받은혜택으로 인한 캐쉬백, 총 사용금액을 가시화하는게 그렇게 어렵던가요…\n\n현재 충전금액, 캐쉬백, 총 가용금액 이렇게 3가지라도 확실하게 가시화되게 좀 업데이트 해줬으면 좋겠습니다…',
#        '에러작렬',
#        '아이폰 결제내역 알림은 언제 되나요? 1:1 문의를 해서 시킨대로 다 했는데도 안되네요. 결제내역 알림은 무슨 큰 기술이라고 아직 업데이트 안되나요? 담당공무원 업체 전부다 일 좀 하세요.',
#        '카드 꼭 만들어야 될까요? 예전처럼 그냥 모바일로만 쓰고 싶어요. 안되면 그냥 잔액 환불이라도 받고 싶은데 어쩌면 되는걸까요 카드만드는게 선택이 아니라서 화면 안넘어감..',
#        '지금 동백전앱은 캐시백 금액과 캐시백 금액과 실금액의 합금액만 나와있는데 예전 동백전 앱처럼 실 금액만 볼수있게도 했으면 좋겠습니다.',
#        '이상한 환불정책 무슨 환불을 60%이상 결제해야 됩니까? 그럼 시스템이라도 잘 만들던가요. 주유소에서 가득주유해서 취소되고 다시 재결제 하는데 왜 연결된 계좌에서 빠져나가죠? 돈 충전한건 결제도 안되고..괜한 통장에 있는돈 나갔네요. 무슨 이따위로 만들어놓고 쓰라는건지...앱도 불편해서 최악이네요 진짜',
#        '전앱이 사용하기 편하네요 금액이 따로따로설정되어 사용가능금액도 별도 확인해야되고 환불도 불편합니다',
#        '전꺼가 더 한눈에 포인트와 충전금액을 파악할수있습니다. 지금껀 포인트랑 충전금이랑 따로 파악이 힘듬니다. 포인트 사용도 선택할수있는게 어디있는지;;',
#        'ㅠ 사용 내역과 충전 내역을 따로 볼 수 없어 불편해요 그리고 총 사용량을 일일이 계산해야 알 수 있다는 것이 불편해요 그리고 갑자기 생긴 비밀번호 6자리 번거로워요',
#        '에러가많이나요',
#        '사용금액/캐쉬백 조회 화면 개선 잔액 표시, 이용금액, 캐쉬금액 등 조회되는게 너무 불편합니다\n\n한번 결제 했을때\n1)결제된금액 2)캐쉬백결제액 3)캐쉬백적립액이 한 화면에 조회할 수가 없습니다\n이전 앱에서는 편리하게 사용했는데, 지금 너무 불편해요\n\n그리고 메인화면에서 ‘사용가능금액’이 현금 잔액인지 캐쉬백 포함 사용가능금액인지 헷갈립니다\n\n시각적으로도 전체적인 화면 구성이 복잡하여 눈에 잘 안들어옵니다\n심플하게 개선 부탁드립니다',
#        '이따위로 만들고 아직도 보수안하는거보니 알만함 그냥 애가 만들어도 이거보단 잘할듯',
#        '금액이 너무 적어서 불편합니다ㅠㅠ', '이런 결제서비스가 접속이 안된다니..어처구니 없는 부산시와KT구나',
#        '치명적인 단점 지적합니다. 환불정책 정말 불편하네요. 전체 적립금에 60%이상 써야 나머지 금액 환불이 가능하게 해놓는 것은 너무 불편합니다. 또 부분환불도 안되고 전체 환불만 된다니요... 미리 현금을 충전을 했다가 현금이 필요해 일부 환불 받으려하면 환불이 안됩니다. 환불제도 다시 검토하셔야 할 것 같아요. 100만원 넣고 60만원 이상 쓸 때까지 환불이 안된다면 급 현금 필요한 사람들 어쩌란말인가요? 이거 쓰시는 분들은 미리 돈 충전하면 환불받기 어려우니 쓸만큼만 조금씩 충전하셔야 할 것 같네요.',
#        '접속에러 언제 고치나요',
#        '결제시 푸쉬알람이 안떠요 문의를 남겨서 재설정 하라는대로 다 했는데도 결제알람이 안뜨네요.. 이벤트 알람은 잘만 떠요,,',
#        '그냥 부산동구청 따라한거네요. 삼성페이 등록도 안되는 코나카드사ㅡㅡ 짱싫은데 10프로 기준도 애매하게 해서 혼란야기하고 차이카드쓴다 . 여러분차이카드 쓰세요. 혜택 더좋음.',
#        '앱이 열리지가 않는데 어떻게 충전합니까??',
#        '와..진짜 앱에 평가남겨보긴또 내가.. 부산시예산가지고 대행하는 업체이고 그거로 돈벌고있으면 앱좀 잘 만듭시다. 지난번업체는 불만없고 불편함 1도없었는데 이건뭐 삑하면 오류나고 삑하면 체크카드로 결제되고..진짜 어이가 없네..한두번도 아니고 앱때문에 날아간 내 적립캐쉬 어쩔꺼냐구요!!',
#        '어플 보기힘들어짐 1. 최초실행시 내지갑을 눌러서 카드사용등록을 해야충전버튼이 보이는것이 껄끄러웠음.\n2. 집근처 가맹점 보는거 어딨는지 아직도 못찾겠음.\n어르신들은 더더욱 사용하기 힘드실듯..\n3.잔액 환불도 예전엔 바로 이체됐는데 지금은 2~3일 걸림',
#        '동백전 사용내역은 나오는데 캐시백된 금액은 어디서 확인할수있나요?',
#        '심심하면 안열리네요 쓰라는건지 쓰지말라는건지 뭐 열려야 확인도하고 충전도하죠',
#        '사용내역 보려고 하면 어플이 꺼져요 충전만 되고 뭐 하려고 하면 꺼져서 쓸수가없어요^^',
#        '동백전 충전오류 앱 다시 바뀐뒤에 4월 5일부터 깔아서 사용하려는데\n지금까지 충전오류 계속 뜨네요 전화문의하니깐 전화기는 한대인지 한시간정도기다려야 전화문의 가능하고 몇번을 재등록하고 앱지웠다 깔았다 했는데 안되서 답답해서 전화하니깐 답변이 고객님 같이 오류뜨는 사람들이 많다고 기다려야될거같다고 딸랑 그말만하네요 도대체 일 왜그렇게 하나요?? 언제까지 정확히 기다려야된다는 말도 없고 죄송하다는 말도 없고 내가 리뷰 웬만하면 안남기는데 진짜 너무하다 싶어서 리뷰남깁니다',
#        '앱 쓰레기 동백전 신청하려고 앱 깔았는데 에러만 벌써 15번째… KT에서 개발한거라고 SKT전화에서는 에러나게 만든거예요? 진짜 그런거면 실력 인정… 제발 에러나는거 좀 고쳐봐요!',
#        '동백전 되나요? 전 코나로 계속 문의하라뜨네요~ ㅠ', '접속불가 충전불가',
#        '어플 접속이 자꾸 튕겨요 캐쉬백도 제대로 들어오지않고 부족하게 들어오고 고객센터 전화연결도 몇번이나 안돼서 아직 문제점을 물어보지도 못했습니다',
#        '캐시백된 금액 어디서 보는지 한참찾았네ㅡㅡ',
#        '금액확인 후 사용할려고하니 오류뜨네요;;자주 에러가 나니 사용하기 불편해요',
#        '사용가능금액중 내잔고 확인이 쉬웠으면 하네요',
#        '기존카드 불가. 상담원 연결도 불가. 오늘 결제해야되는데 왜이러세요?ㅜㅜ',
#        '진짜 이렇게 불편한 앱은 처음이에요 메인 홈으로 이동하는 버튼도 안보이고 진짜 계속 뒤지다 겨우 알아냈어요 그냥 껐다 켜요^^ 충전하고 안쓴 현금(캐시백제외) 환불도 안되고 이전 카드어플 반만이라도 따라갔으면 좋겠네요',
#        '아직 사용 경험이 없어 잘 모르겠습니다',
#        '아니 무슨 카드 발급 안해도 쓸수있나 싶어서 결제했는데 안돼는거 확인하고 환불하려 했는데 문의를 2개를 눟어도 환불이 안돼는데 뭐 상술입니까? 환불 해준다고 안했으면 결제도 안했을텐데 환불해준다면서 3일째 확인 안하고 뭐하는 짓거립니까',
#        '양산사랑카드와 동백전 2개 다쓸려고하니 자꾸에러나네요 지우고새로깔면 이건되는데 다른게 안되고 다른걸 지우고 깔면그건되는데 이게안되고 2개가 같이 사용이 안되나요?',
#        '서비스 종료인데 구 어플 안내리냐?? 새 업체 어플인줄알고 또깔앗자나 이것들 정신못차리네 아주',
#        '업데트가안데네요몃시간이지났는데도상용불가합니다',
#        '전산오류로 결제가 두번 됐는데 충전한 돈으로 결제한 첫번째 결제를 취소시키고 두번째 결제는 잔액이 없다고 통장에서 돈빼감ㅋㅋㅋ 캐시백 포인트도 회수ㅋㅋㅋㅋ 거기다 어플에다 문의했는데 24시간동안 답변없음',
#        '캐시백 적립현황은 기본아닌가요? 볼수가 없네요. 들어왔는지 일일이 캡쳐해서 비교해봐야하네요. 글씨도 작고 앱이 쉽게 보이질 않네요! 사람들 글쓴거보면 많이 개선해야할것같습니다.',
#        '진짜 앱 거지같음. 기존 동백전은 충전 금액이 자공으로 차감됐는데 이건 뭐 할때마다 사용을 눌러서 매번 금액을 입력해야하고... 포인트 사용방법을 불편하게 만들어서 포인트 자동소멸되는걸 노리시는건지... 앱 좀 수정해주세요 자동으로 사용되도록',
#        'UI가 이전에 비해 불편함 1. 이용내역에 따른 잔액확인 불가 2. 캐시 사용 버튼을 누르고 10분 이내에 써야한다는 제한 3. 어떤 것을 터치해야 원하는 정보를 볼 수 있는지 직관적으로 이해하기 어려움 4. 혜택정보, 소득공제 신청 같은 메뉴는 처음에 한 번 읽어보고 나면 계속 보는 메뉴가 아닌데 왜 중앙에 배치했는지 이해 불가',
#        '급하게 충전 해야 할 때 안 됩니다.... 어플도 통신사도 케이티라 뭐가 쓰레긴지는 알 수 없는 노릇!',
#        '돈만빠져나가고 충전이안됨 아직은 많이 부족한듯',
#        '발급받은 지 한참 지났는데 앱 오류 때문에 충전을 못합니다 빨리 개선 부탁드립니다… 하루에도 몇번을 시도하는데 매번 충전 금액 입력하고 나면 앱이 자동으로 꺼집니다',
#        '상경해서 부산 갈일 없는데 60퍼 이상 안써서 환불이 안되는게 말인가..',
#        '대체 어 떤 정치적 목적과 꽌시로 멀쩡히 잘운영하던업체를 이관한단말입니까???',
#        '아니 QR코드 결제가 안되냐 기본인데 하. 카드 신청도 잘 안되고 미치겄네.',
#        '나까지 안보태고싶은데 불편..불편 이 앱을 개발한사람이 누군지가 궁금 사용을 해봤는지? 무엇이 불편했는지 지금은 아실랑가?',
#        '진짜 별한개도 아까움 캐시백 받은 내역 안 보여주는거 너무 투명성이 없음 업체 왜 바꼈는지 모르겠음 기본도 안된 업체임',
#        '잔액 확인하려고 어플 들어가는데 접속 조차 안되면...카드를 어떻게 사용하라는건가요 대체',
#        '0점 주고싶은데 별1개도 아깝군요 소득공제 신청을 따로 해야하는것도 짜증나고 캐시백이 제대로 적립되고 있는지 건별로 적립되는걸 보는 것도 확인이 어렵고 동백전 사용가능한 가맹점인지 확인안되서 매번 점원에게 여기 동백전되나요? 묻는것도 짜증나네요 3만원 캐시백받으려고 진짜 귀찮네요',
#        '동백전 충전후 취소시 3일 정도 소요된다고하는데 왜 3일정도 소요되는지 모르겠고, 그렇다면 입금되기전까지 이자는 주나요?',
#        '폰 교체후 폰 알람설정과 동백전 알람 설정 했지만 알람이 뜨지않아요.',
#        '평점을 바라는건 아니죠? 기존꺼 사용가능하다면서요 카드 수수료 받아서 부자 되시겠어요 안쓸테니 잔액 환불은 어떻게 받나요? 설마 앱에 가입해야 되는거 아니지요? 고객센터는 전화도 드릅게 안받던데',
#        '서버터져서 안써지는게 태반입니다. 심지어 결제처리도 안되었는데 앱 들어오니 결제된것처럼 차감되어있네요. 이 시간에 고객센터는 전화도 안받고. 명불허전 KT에 지자체 콜라보네요. 훌륭합니다. 훌륭해.',
#        '지금 설치가 안되요 ㅠㅠ', '에러잦음',
#        '별 하나도 아까워요 예전 어플이 훨씬 사용하기 편하고 보기도 편해요 쓸데없는 팝업이나 엄청띄우고 캐시백금액과 남은금액 같이 결제되도록 바꾸세요 당장 부산시청한테 뇌물주고 위탁받은겁니까???????? 뭐 이따위 어플을 개발했나요? 예전 어플로 바꿔주세요',
#        '앱 안됨.. 카드 등록안됨. 50만원 돌리도~~',
#        '캐시백 한도가 30만원 이면 충전한도도 30만원, 보유한도도 30만원으로 결정하면되지. 왜 처음부터 50만원하라고 해놓고. 아무도 모르게 충전한도를 30만원 되게 바꾸면서 아무런 설명도 없고, 공지도 없고. 전화하니까 6월14일 부터 그렇게 한다하면서. 도대체 부산시의 정책인지 위탁업체 소행인지 모르겠어요',
#        '그동안 잘 사용하던 동백전업체는 느닷없이 왜 바꾸나? 지금 설치해 봤더니 앱 인터페이스도 이전 업체것이 더 예쁘고 사용성도 좋은 것 같은데. 이유가 도대체 뭐야?',
#        '충전 얼마했는진 알려줘야지 충전가능금액을 50만원-현재잔액으로해서 충전가능하다해놓고 한도초과했다 알람띄우는 이딴앱이어디있나요 개발자가 논리가 없는건가요',
#        '진짜 너무너무너무 불편해요 그전 동백전 어플이 훨씬 나아요..\n젊은 저도 쓰기 어렵고 복잡은데\n어른들은 더 얼마나 헷갈릴까요...?\n진짜 어플 쓰기 편하게 제발 쉽게 단순화시켜주세요\n저번처럼 ????충전금액잔액 / 내캐쉬 ????카테고리만 깔끔하게 있었으면 좋겠어요....이달의 총 받은 혜택 이런거 필요 없어요.. 30만원이 최대면 3만원 캐시가 최대인거 동백전 쓰는 사람이면 다 아니깐요...\n??????그리고 예를 들어 만약 내가 30,000원 충전금액이 있었는데 어디 가맹점가서 5,500원 결제했다면 쓰고 남은 금액이 24,500원 사용내역에 떴으면 좋겠어요 은행통장처리하면 나오듯이요...지금은 그 가맹점에서 쓴액금액들만 나와서 너무 불편해요...\n제발 더 이상 복잡게 만들지 말아주세요...더 이상 추가하지말고 그냥 예전으로 돌려주세요 제발~~~~\n쓰기 너무 불편 ㅠㅠㅠㅠㅠㅠ 주위에서도 쓰기 불편하다고 난리난리 예전보다 동백전카드에 손이 안가요............................',
#        '복붙노력은 왜하는거지? 더나은서비스는ㅋㅋㅋㅋ 쓰레기게임출시하고 최고의게임으로 거듭나도록 노력하겠습니다 같은 똥싸지르노ㅋㅋ',
#        '충전만 하려고하면 어플안켜집니다 충전만 하려고하면 어플안켜집니다 한두번이 아니에요',
#        '포인트 사용 표시가 헷갈리게 되어 있고 총받은 포인트 표시가 불필요하게 표시되어 있고 바로 결제한 포인트가 안보여요',
#        '직관성이 상당히 떨어졌네요 전에는 버튼 클릭 한두번으로 원하는 설정이\n가능했다면 지금은 조금 복잡한 느낌이 있습니다.\n어르신들이 처음 등록하고 자주사용하는 카드 설정하는 것들이나 적립금 사용하는 방식등이 상당히 불편합니다.',
#        '에러가 잘남, 못난 케이티 통신',
#        '왜 적립이안되나요? 동백전앱 새로설치하고 카드도 신청했어요 그러고 이전 동백전 카드로 결제를했는데 왜 결제만되고 적립안됩니까?',
#        '당월결제 금액이 얼마인지 한눈에 쉽게 볼수 있게 업데이트해주세요',
#        '기존 사용하던 카드로 결제했는데 캐시백 안됨 고객센터에 20번 넘게 전화해서 겨우 연결함 상담사님 전산에는 정상적으로 캐시백이 된걸로 나온다는데 내 어플에는 왜 안뜨죠?ㅋㅋㅋㅋㅋ 그걸 내가 볼 수 있게 해놔야지 상담사님한테만 보이면 어쩌자는건지ㅋㅋ 결제하고 일일히 고객센터 전화해서 확인해야돼요? 지금 저말고도 어플 에러 문의로 전화 폭주한다고 하는데 제발 똑바로 만들어서 상담사님이나 사용자나 쓸데없는 고생 안하게 해주시길',
#        '금액 충전이 안 되고 자꾸 꺼져요 금액 충전해서 쓰고 싶은데 앱이 자꾸 다운되고 꺼져서 충전 자체를 못 해서 카드 발급만 받고 아예 못 쓰고 있네요;; 고객센터에 전화해도 전화 안 받고 1:1 문의 올려놔도 답변도 빨리 안 주시는 것 같고,,, 실망이 크네요',
#        '갤s8 브라우저ㅡ 크롬으로 설정해야된다고 진작좀 알려주지 어제 전화문의는 그런거 안알려주더니 오늘은 알려주네 하 .....',
#        '고객센터 1:1문의는 아예 관리를 안하는것 같아요 읽지도않고 처리도 않해주시네요', '대체 앱은 언제 열리나요!',
#        '고객센터 전화안됨..욕나옴', '새마을금고 없어 카드발급 안돼요 괜히 충전하여 환불 해주세요 사용도 못 하는데',
#        '전에 동백전보다 사용하기 너무 불편합니다. 그냥 전과 똑같이 하면 안되나요? 이벤트도 소리소문없이 그냥 당첨자다 발표하고 끝이네요, 그 전에는 유튜브에서 실시간 라이브로 발표를 하던데요, 소리 소문없이 당첨자 누구누구 이렇게 적혀있는 거 보니 신뢰성도 엄청 떨어지네요 ㅋㅋ',
#        '어지간하면 평 안 쓰는데 왜 이렇게 불편한 업체로 바뀌었는지 모르겠네요. 인터페이스도 직관적이지 못하고, 선불카드는 대체 왜 발급 받아야하는지도 모르겠네요. 카드 발급 안 받아도 된다는데 안 받으면 이관하라는 화면 계속 뜨고 이미 적립된 캐시도 못 써요. 캐시 쓰는 것도 이전엔 그냥 사용 누르고 충전금액처럼 그냥 카드 사용하면 됐는데 여기는 앱에서 금랙입력하고 10분안에 캐시쓰라고 하네요. 모은 캐시랑 충전했던 금액 다 쓰면 탈퇴하려구요. 그냥 신용카드 혜택 받는게 낫겠어요.',
#        '충전금액,캐시백금액 왜 따로 나오는지 엄청 불편. 예전처럼 합계금액이 나오고 캐시백금액확인할수있게 된게 더편한데.',
#        '동백전 캐시백 사용방식이 너~~~~무 불편해서 쌍욕이 나옵니다. 일단 캐시백 잔액이 얼마 있는지 확인이 바로 안됩니다. 충전금액+캐시백 잔액 둘다 확인할 수 있게 바꿔주세요. 그리고 캐시 사용 버튼 누르면 바로 전액 사용 들어가는 예전 방식이 훨씬 편한 것 같아요 뭐하러 얼마 쓸지 금액을 쳐 넣어야 하나요? 그리고 캐시백 사용시간 10분 제한 없애주세요. 필요한 이유를 모르겠네요 켜놓으면 돈 나가나요? 또 전체이용내역 할인내역 제발 알아볼수 있게 만들어주세요.. 그리고 충전금액 만원 없어지고 2만원이 중간에 있는 요상한 순서도 좀 어떻게 해주세요 이딴 서순은 동백전에서 처음 봅니다. 선불카드 발급도 필수라더니 바꾼거 보면 어플 개선도 가능할 거 같은데^^ 빨리 일 좀 하세요~~~~~~~~~ 별점 0이 없어서 1 드림',
#        '주유하다가 결제 오류로 다시 결제 했는데 중복으로 결제 되서 취소 했는데도 돈이 안들어와서 전화 할랬더니 접속도 안되고 와이프폰으로 해도 접속이 안되네요 고객센터도 상담시간이 아니라고 하고 답답하네요',
#        '잔액 얼마 남았는지도 표시 안 되어서 50만 넘게 사용하니 자동으로 체크카드로 넘어갑니다. . 총 누적 사용 금액이나 잔액 표시 바랍니다',
#        '긴급 점검이 왜이리 많습니까? 결제할라다가 못한게 몇 번인지...',
#        '동백전 앱 들어갈려면 꼭...세,네번만에...들어감....프로그램 개발을 어떻게 한것인지..짜증나네.....S9+ 사용하고 있음... 그리고 충전 금액을 2,3,4만원도 넣어 놓아야지....3만원 입금할려면..만원세번을 해야됨......',
#        '충전했는데 오류 뜨더니 돈은 빠져나갔는데 왜 충전은 안되있죠 (다행히 문의전화 걸어보니 좀 있다 충전 되어 있네요) 앱 바뀌고 인터페이스도 엄청 구리게 바꿨는데 이런 오류까지 뜨니깐 황당하네요',
#        '발급 한 달도 지나지 않았는데 1. 시스템 장애로 결제 불가에 2. 앱 오류로 충전 불가에 ㅠㅠ 불편하기 짝이 없군요. 이래서 부산 경제 어떻게 살리죠? 동백전 분발해야겠어요~!',
#        '예전어플이 훨 쓰기편해서 지금어플이랑 너무비교됨. 별 쓸데없는 메뉴랑 소개글만 많고 동백전 사용가능 매장찾기도없고 뭐하나 찾으려면 여기저기 몇번을 눌려봐야하고 캐시백쓰는것도 번거롭고ㅡㅡ뭔 캐시백쓰는데 제한시간을 걸어놈? 불편하기짝이없음',
#        '카드취소후 동백전금액이 회복이 안되어 문의할래도 하루종일 전화연결은 안되고 지난번 1대1문의글남긴거 1달지나도 답변대기중 답도없고 오늘 통화연결계속안되어 포기하고 문의란 다시 글남겼는데 언제답변올지 도대체 이래가 쓰겠나요?',
#        '지금 카드사용 불가네요 통신오류 뜹니다 ㅜㅜ',
#        '불편해요 기존 앱에서는 한도가 얼마 남았고 얼마 더 충전할수 잇는지 명확하게 나와서 제가 계산할 필요가 없엇는데 지금은 포인트 사용까지 티가 안나게 되잇어서 너무 헷갈려요',
#        '문제가 많네요 50만원 충전했다가 충전취소하고 다시 충전하려고 했더니 충전이 안되는데 이게 충전 한도만큼 충전을 했기때문인가요? 충전 취소하면 다시 충전한도가 초기화되야하는 것 아닌가요?',
#        '이전보다 훨 불편해짐..ui 누가 만든건지 참..글고 충전은 무슨 한도가 왤케높게함? 어짜피 30씩만 쓸껀데 답변들 다는거보면 복붙ㅋㅋ 답변하지마라',
#        '충전도 안되면서 어떻게 쓰라는거야? 충전오류 미친ㅋ',
#        '업체 바뀌면서 불편해졌습니다 Qr코드 결제는 어디서 하고 가맹점 확인은 어디서 하는지 도저히 알 수가 없네요'],
#       dtype=object)

# %% [markdown]
# ##### 토픽 7
#
# 0.075*"카드" + 0.060*"발급" + 0.033*"기존" + 0.026*"신규" + 0.024*"부산시" + 0.023*"재발급" + 0.022*"신청" + 0.021*"사용" + 0.020*"선불카드" + 0.019*"강제"

# %%
topic_7 = topictable[topictable['가장 비중이 높은 토픽'] == 6.0]

print('토픽 7에 해당하는 리뷰의 개수:', topic_7.shape[0], '개')
# Out:
# 토픽 7에 해당하는 리뷰의 개수: 207 개

# %%
# 토픽 7에 해당하는 리뷰들만 모아서 하나의 df 만들기

topic_7_list = topic_7['리뷰 번호'].unique()
df_topic_7 = df_negative.loc[topic_7_list, :]

df_topic_7.head(5)
# Out:
#           DATE  STAR                                             REVIEW  LIKE
# 0   2020-02-05     1  앱 시작하면 악성코드가 발견되었다면서 창이 뜨는데 이거 해킹당한거 아닌가요? 불안해...     0
# 12  2021-04-05     1  카드 이관 신청을 하는 데 카드 재발급이 '필수'네요. 새로운 부산 동백전 선불카드...    68
# 14  2021-04-09     1  카드 재발급 강제사항은 둘째치고, 앱 자체 가독성이 넘 떨어집니다. 적립금과 충전금...     2
# 16  2021-04-07     1                                   기존카드등록안되요 어떻거하나요     0
# 22  2021-04-05     1  도대체 위치정보가 필수동의인 이유가 뭔가요? 약관내용보니까 굳이 필요없는정보나 마케...    10

# %%
# 리뷰 전부 모아보기 --> 복사해서 R로 들고가서 감성분석 진행

df_topic_7['REVIEW'].unique()
# Out:
# array(['앱 시작하면 악성코드가 발견되었다면서 창이 뜨는데 이거 해킹당한거 아닌가요? 불안해서 앱을 못열겠고 이미 내 폰에 악성코드가 심어진거 아닌지 불안합니다',
#        "카드 이관 신청을 하는 데 카드 재발급이 '필수'네요. 새로운 부산 동백전 선불카드를 신청할 수 있습니다에서 무조건 신청해야 한다고 워딩을 바꾸셔야겠어요. Ui는 좋다고 생각했는데... 새 선불카드 발급을 유도함을 미리 고지 안한 점, 필수로 발급받아야 이전 앱의 잔액 및 캐시백 정책을 사용할 수 있는 점은 납득하기 어렵네요. 신속히 부산시와 논의하시길 바랍니다.ㅜ",
#        '카드 재발급 강제사항은 둘째치고, 앱 자체 가독성이 넘 떨어집니다. 적립금과 충전금 소진이 어떻게 되고 있는지, 보기 넘 헷갈려요....전에 사용하던 앱이 훨씬 사용하기 편하네요',
#        '기존카드등록안되요 어떻거하나요',
#        '도대체 위치정보가 필수동의인 이유가 뭔가요? 약관내용보니까 굳이 필요없는정보나 마케팅용이드만 그리고 기존에 쓰던 동백전카드를 왜 새로 발급받아야되나요? 추가-혹시 시청에 알아보니 카드발급의무라고 하는데 혹시 카드발급비용 부산시가 내는건가요?',
#        '코나 이벤트 참여할려고 선불카드도 발급받고 결제를해도 코나볼을 주지않습니다. 도대체 똑바로 관리하는게 뭡니까',
#        '너무 불편하게 바뀌고 기존카드 사용도 못하게 해놨네요',
#        '왜 리뷰가 지워진줄 모르겠는데 이관 할려면 왜 카드를 강제로 발급해야하는지 설명 부탁드립니다.',
#        '이미 동백전카드를 등록해 사용하고 있는데 이관을 하니 다시 카드를 신청해야 함. 그리고 동백전에 돈이 없으면 결제가 안 되도록 해야지 자동으로 기존 채크카드에서 돈이 나가도록 설정이 되어 있음. 최악',
#        '이관하니 무조건 새 선불카드 발급해야하네...기존체크카드 사용된다면서 쓸데없이 선불카드는 왜 신청하게 만드는건지? 신청 당일에는 발급 취소 가능하다더니 발급취소도 안되고... 지들 맘대로 강제로 발급시킨 새 선불카드 메인카드로 등록해놓고서는 기존 체크카드는 지들맘대로 선불카드에 보조카드로 연결시키고... 자기들이 올려놓은 체크카드, 선불카드 차이점 설명에도 기존에 쓰던 체크카드 비해서 아무런 장점도 없구만 왜 강제로 발급시키는건지.... 그런다고 교통카드, 삼성페이 다되는 체크카드 잘 쓰던 사람들이 번거롭게 삼성페이 안되고 교통카드도 안되는 선불카드 쓰겄냐... 신규카드 오면 버리고 원래 체크카드 쭉 써야겄다...',
#        '무조건 카드 재발급 해야하고 포인트도 쓰는방법도 이전 어플이 훨씬 편합니다 리뷰 5점 내용도 비슷하고 평점 조작해요? 왜 1점리뷰는 지우는거죠?',
#        '아니 왜 자꾸 댓글로 1대1 문의를 달라고하는건가요? 리뷰평을 보고 편의성을 보는건데 여기다 답글 달아주시면 안되나요?',
#        "'신규 동백전카드 신청 취소시 기존카드 연동이 불가함으로 카드사용이 불가합니다' 라고 하셨는데 그럼 신규카드 발급을 받아야지 기존카드도 사용이 가능하다는 말씀이신가요?",
#        '이벤트 참여에 마케팅 수신동의가 선행되야 한다는 사실을 최상단에 두셔야죠. 아무것도 모르고 실물카드 등록이랑 10만원 충전 먼저했더니 이벤트 신청도 안되있고 다시 수신동의를 해도 응모 소급적용이 안되는군요. 광고성 문자 전화오는거 싫어서 차단 제가 선택했던것 맞지만.. 이벤트 참여해보겠다고 덤볐다가 낚인 것 같은 기분이라 썩 좋진 않네요. 상단에 마케팅 수신동의해라 먼저 알려주면 안먹어도 될 욕 하나 방지할 것 같습니다. 이벤트 잘못 낚인것 별하나 감점, 그리고 여기 대다수가 말하는 불편한 점 별점 세개 감점해서 1점 드립니다.',
#        '무슨 소리인지 모르겠네요 내캐쉬 밑에 세부내용 자체가 없는데',
#        '카드 새로 오면 기존 카드 새카드 모두 사용 가능한가요?',
#        '카드 강제발급 장난하나? 쓰레기 줄이자고 하는 판에 나서서 쓰레기 만들고 잘하는 짓이다. 어플도 조잡하기 짝이 없음. 결제도 보니까 잔액 모자라면 계좌 자동출금이 아니라 걍 결제 안되는 것 같은데 가지가지로 귀찮게 만들었네 진짜;',
#        '카드는 언제받을 수 있나요?', '왜 재발급 해야하나요 카드 끼워팔기?', '카드재발급해야하나요? 왜죠??',
#        '가독성 최악 인터페이스 최악 직관성 최악 그랜드슬램이네요',
#        '빨리 새로 선불카드 안 만들고 기존 카드 사용할 수 있게 해주세요. 기술적인 이유라고 하면 시민들이 기술적인 이유라고 믿을 것 같습니까? 누가봐도 뻔한 사유인데, 빨리 협의하여 기존카드만 있어도 사용할 수 있게 부탁드립니다.',
#        '별 하나도 아깝다. 부산시와 코나아이측의 사전 설명이 모두 구라이고 무조건 신규로 카드발급 해야하는 이상황이 개탄스럽다 한세기전에나 있을법한 고객 우롱처사다',
#        '동백전 충전하니 충전수수료 무료 이벤트중이라고 뜨는데 이벤트??에요?? 원래 무료가 아니고요? 이벤트가 끝나면 충전하면 수수료가 드나요?? 뭐죠 진짜 최악이에요 잘쓰던거 굳이 바꾸게 만든 부산시도 최악. 이전 동백전 앱보다 1년이상 늦게 만들었는데 더 못하게 만든 코나아이? 업체도 참.. 이상하고 예전 리뷰 읽어봤는데 너무 티나게 5점에 기대됩니다 라는 댓글 달아놓은것도 참 웃겨요 ㅋㅋㅋㅋㅋ',
#        '코나아인가 뭔가 찢이랑 연관됐다더니 정말 쓰레기 인증이네요 금액 남아서 쓰긴 해야하는데 그러자면 카드 신규로 발급 받아야하고 카드 발급 안하면 아예 사용을 못하니 남은 돈 다 넘어가는거고..진짜 옘뵹이네요',
#        '1-강제로 필요없는 선불카드를 발급해야함. 2-선불카드는 페이등록이 안되고 교통카드기능이 없음. 3-따라서 과거와달리 실물카드를 무조건 들고다녀야하는 번거로움이 생겨 아주아주 매우 불편함. 4-앱ui 직관성이 없고 이전앱에 비하면 허접함. 5-고객센터 연락도 안되고 충전수수료 무료라는 글이 써져있는데 각종 설명도 부족하고 여러가지면으로 불안함.',
#        '장난해요 왜 신규카드 발급받아야 되죠 기존 카드로 해야죠', '선불카드 강제 발급은 뭐죠? 황당합니다.',
#        '완전별로 기존카드 사용할건데 새카드는 왜 무조건 신청해야하죠? 코로나 시국에 플라스틱 쓰레기 줄여야 할판에 쓸데없이 플라스틱 쓰레기 양산하네요.. 앱도 완전 별로고 이전 앱이 훨씬 나아요!! 애초에 동백전 만들때 계약 똑바로했으면 됐을껄 KT에 과다 수수료지불등 문제만 생기고.. 쓸데없이 시민들 불편하게하고 혈세 낭비하고... 제발 세금쓸때는 생각 좀 많이해보고 집행해주세요',
#        '0점은 못주나 2021년에 삼페가 안되는 선불카드? 선불카드으으?', '카드발급 또하는거 실환가????',
#        '왜 신규카드발급을 받지 않으면 기존 카드사용이 안되는지..이런 얄팍한 상술 정말 짜증남...추진한 공무원도 무능하고 업체는 더 나쁜놈임..',
#        '이용액과 관련하여 기간별 사용금액 합계가 조회되지 않고 가시성 및 가독성이 아주 현저하게 성능이 부족함',
#        '새카드 발급안하면 기존카드도 사용못하고 이게 무슨 세금낭비입니까? 안내도 제대로 안되어있어서 지금 다들 혼란속에 불편을 겪고 있어요 시간낭비 돈낭비 세금낭비 난리났네',
#        '직관적이었던 과거 앱에 비해서 번잡하고 구려졌어요....글씨크기부터 인터페이스까지 부모님도 그렇고 어르신들이 혼자서 못하겠다고 힘들어하시네요. 그리고 선불카드 필수 발급이 너무 충격적입니다. 연동 후에는 취소도 안된다도 하고 부산시 측에서 부산을 해양 수도로서 밀고있는만큼 환경문제에도 신경쓰는 걸로 알고있는데 부산시민이 죄다 플라스틱카드 신규발급하게하면 과연 좋을까요? 플라스틱 줄이기 실패 직관적이고 사용자 중심의 인터페이스 실패 너무너무 실망입니다.',
#        '새 카드를 무조건 발급 받아야 어플에 들어가진다는게...무슨 카드가 무료발급이라지만 내가 낸 세금으로 만드는거 아닙니까 이건 좀 심하네요',
#        '정 선불카드 필요하면 모바일카드 발급할것이지 우편 종이두툼에다 플라스틱ㅡㅡ 환경1도 생각안하지?',
#        '기간별 얼마썼는지 합계 업데이트좀 하세요',
#        '새로운 카드를 발급받지 않아도 되도록 앱 수정바랍니다 왜 무조건 카드를 또 발급받게 해놓나요?',
#        '사람들이 왜 계속 글을 쓰는지 이해를 못하는 것 같네요. 동백전 다시 앱깔고 들어갔을 때 신규등록창이 떠야 당신들이 말하는대로 할건데.. 시작이 이관신청인데..기존 카드를 사용했던 사람들이 앱을 깔았을 때 기준으로 설명을 해줘야 따라 할 것 아닌가요?',
#        "카드신청에 들어가서 카드선택후 신청하기누르면 '일정기간 미사용으로 작업이중단됩니다'..요래떠요 삭제하고 다시 깔아도 그렇고..뭘 신청할수가 없는데 우찌해야될까요?",
#        '1. 기존카드 소지자도 무조건 선불카드 강제발급하게 함... 2. 선불카드는 삼성페이 등록도 안되고 실물카드 무조건 들고다녀야돼서 불편함 3. 가맹점 검색창 없음;; 4. 계좌연결 하나밖에 안 됨... 선불카드보다 기존 체크카드가 훨씬 좋아요ㅠ',
#        '돈이 남아도나요? 카드 재발급으로 인한 환경문제부터 비용 자체가 아깝네요. 수수료때문이라고 하는데. 부산시 담당자는 이정도도 생각안하고 진행을 하는건지.. 진짜 노답이네요 백만장 플라스틱..생산.. 진짜 아주 웃기네 환경부에서는 플라스틱 쓰지말라하고 다른 경제쪽은 카드를 아주 쓸데없이 찍어내고.. 코나도 부산시도 정신차리세요',
#        '카드만들다 사용 포기합니다',
#        '다른 리뷰들처럼 캐시백이나 전반적인 부분에서 이전것보다 불편함. 개선의지도 없어보이고 이럴거면 왜 바꾼건지.. 부산시가 개선의지가 없는것 같군요',
#        '앱이 잘 열리지도 닫히지도 않아요 일단 카드신청만 겨우하고 강제 종료했네요 ㅡㅡ',
#        '0점!! 앱 열자마자 카드신청 단계이고, (구 동백전카드 사용 여부와 관계없이,무조건) 신규카드신청을 완료해야 앱의 홈화면을 볼 수 있었다. 아래와 같은 공지사항 내용을 먼저 볼 수 있었다면, 신규카드 신청을 하지 않고 시스템이 개선되기를 기다렸을 것이다!!! "신규 동백전 앱 설치 및 기존 체크카드 등록 과정에서 선불카드 발급에 동의하지 않으면 신규 앱 사용이 불가능하게 시스템이 설계되어 있습니다. 이는 기존 회원의 보유금액과 카드정보를 새로운 동백전 시스템에서 연동하기 위한 기술적 필요에 따른 것으로 기존 동백전 체크카드의 재발급, 폐기·교체가 아닙니다. 다만, 선불카드 발급여부를 시민들이 선택 가능하도록 해달라는 의견이 제기되어, 운영대행사와 협의하여 수일내에 개선할 계획입니다."',
#        '운영할거면 제대로 하길 이도저도 아닌꼴 만들지말고',
#        '기존카드등록하려니 계속 찾을수없는카드라고하는데요? 어떻게해야되나요?',
#        '정말 부산시는 미리 사전에 공고를 하셨어야지요!기존카드 그대로 쓸 수 있다고 해놓고선 새카드 발급안하면 앱 깔아도 실제 사용이 안되게 해 놓으면 어찌합니까? 실물카드 아니라면 그나마 이해하겠지만요..1년 사이에 관리사를 바꿔서 웬 낭비입니까? 타도시는 몇년째 이상없습니다!',
#        '별한개도 아깝다. 카드를 강제로 만들게하는 대 시민 사기를 쳐놓고 앱UI도 아주 불편하게 만들어서 쓰기가 짜증남. 이런 업체는 망해야함. 빨리 업체 바뀌었으면.',
#        '별 한개도 아깝다. 마이너스 별은 왜 없는지. 재무도 엉망인 회사가 신규로 선정될때부터 불안하더니. 신규가입할때 무조건 실물 플라스틱 카드를 발급 받아야만 기존 시스템을 사용하도록 만들어서 부산 시민들 어이없어 하고, 심지어 부산시 담당자도 이런 사실을 몰랐다고 하는데, 금융기관으로부터 카드 발급 수수료 챙기려고 시민들 불편과 개인정보를 노리냐? 기존 카드있는데 중복으로 발급받게 만든 환경오염 처리비용은 귀사에서 내지도 않으면서 왜 이런 짓을 하는가요? 게다가 앱 인터페이스도 기존 것보다 매우 불편함. 모르는척하지말고 기존 카드로 사용할 수 있게 빨리 업데이트해라! 당장 그정도 실력안되면 운영사 자격안되는거 아닌가? 난 신규발급 받을 생각 추호도 없으니까 이 글에 카드연동하는 복사-붙히기식 답변 달지말고. 앱 업데이트나 언제 할지 답변 달아주기 바람.',
#        '사용자들의 불만을 얼른 수렴해서 동백전 어플 전면 수정하세요. 플라스틱 쓰레기 만들지 말자고하는데 너희는 왜 거꾸로 가니?',
#        '카드 강제발급에 이전보다 불편한 어플, 거기에 삼성페이도 못쓰는 카드라니..',
#        '못쓰겠네요 버그빨리 수정요 뭔 자꾸 튕기니 ㅋㅋㅋ 쓰지말라는 뜻인가요? 빨리 버그 수정해주세요',
#        'ㅡㅡ 잔액 이관하면서 걍 무조건 신규카드 발급하게 돼있음 기존카드 사용 못하는 건 줄 알았는데 그것도 아니네 ㅋ 계좌 연결시켰더니 계좌 연결했으니 신규 카드 발급취소 안 된다고 함 왜?????? 걍 기존꺼 쓰면 되지 왜 신규카드 발급해서 쓰레기 만드는지 이해 안 됨 왜 카드가 있는데 계좌 연결하면 카드 발급 취소가 안 되나요???????',
#        '첫 화면에 뭔 이런 지저분 한 UI를 나이드신분들 사용이나 가능할련지 모르겠다 가입시 카드 무조건 다시 신청하게 할꺼면 기존 카드 사용유무에 대해 안내를 하든지 해야지 이게 뭐냐고 충전제한 금액도 50만원이네? 100만원도 아니고? 엄청지저분 하고 사용힘들다는건 알겠음 연말정산도 신청따로 해야하네? 신규카드 앱으로만 받고 연결하면되지 실물은 왜 받으라는거야 발급으로 수수료나다서 그런것인가? 충전카드라 삼성페이 등록도 안되네? 이게 kt를 이겼다고? 실화냐? 평가 하는 사람들 누구였냐?',
#        '애러가뜨고 기존카드로 이관이 안되는데요?',
#        '새로운 카드 받았는데 등록하면 삼성페이 사용 못하나요? 새로운카드 무조건 등록해야하나요? 아님 구 동백전 카드 그냥 사용하면 되나요?',
#        '쓰레기입니다 이딴게 세금으로 만들어지네요',
#        '앱도 진짜불편, 멀쩡한카드 두고 왜 재발급받아야하죠? 자원낭비 환경오염입니다',
#        '뭐 이런 개쓰레기 같은 앱이 다 있어. 죽도록 카드신청해도 안됨. 안써!!!',
#        '카드는 왜 신규로 신청시키는건지 참...',
#        '장난하나 가입시 무조건 카드발급하라는게 어딧나요?\n기존카드 쓸수있다면서 발급안하면 화면도 안넘어가는데\n기사보니 부산시도 몰랐다는데 말이되나 싶기도하고\n90만명분 카드 새로만들면 환경보호도 잘되겠습니다?',
#        '기존 카드를 사용하고 있었는데 혜택이 사라진다고 해서 카드를 변경했더니 삼성페이 등록이 안됩니다. 삼성페이를 쓰면서 동백전 고유의 혜택을 포기하거나, 불편하게 카드를 들고다니면서 새 카드를 쓰는가, 둘 중 하나 입니까?',
#        '왜 카드 재발급을 강요함?',
#        '카드를 왜또발급받아야합니까 낭비도이런낭비가있을까요 그라고 리뷰에 달린 답변보니깐 신규카드등록그게어디있어요? 못찾겠음 자주묻는질문에도 보면 기존카드보유자도 신규카드발급 받아야되나요? 거기답변에 네 라고되어있고 기존카드그대로 사용해도된다고 되어있고 앞뒤가 안맞네요 머어째란말이에요?잔액도 어플깔았지만 연동이안되있네요 아진짜 파이네',
#        '최악의 앱 사용법 하나도 이해가 안감..\n이거 만든 개발자분들 반성하세요... 살다살다 앱 리뷰 처음 쓰게 만드네요. 앱 사용 엄청 불편하네요. 이렇게 비직관적인 디자인 처음봄;;',
#        '앱깔고 잔액이관된다하는데 기존카드로의 이관이 아닌 새로운 카드발급후 이관이네ㅠ왜이리 번거롭게 또 카드를 또발급을 받게하는지ㅠ기존 카드를 사용할수 없네요ㅠ기존카드 있는데도 또 카드발급했네요',
#        '세금도둑이 따로없네 ㅋㅋㅋㅋ 왜 뉴스나 곳곳에는 선불카드 재발급 안하고 기존 체크카드 사용가능하다고 해놓고 강제로 새로 카드 발급받게 만드냐 ㅋㅋㅋ 공카드로 수수료 그렇게 먹고싶은가? 너네가 짱구 굴려서 이런 상황 만든건 알겠는데 부산시가 그렇게 홍보할때 입 다물고 있던 너네도 사기꾼이야 내가 짜증나서 안쓰고 금감원에 신고하고 만다. 너네 지금 초등학교 코딩배워서 만든 조잡한 어플가지고 마케팅 광고비 쳐받고 은행에 카드발급비 쳐받을 생각이야? 이전 동백전 사용자 90만명이었는데, 공카드 건당 천원~만원 받아먹을거고 이미 존재하는 폐기물 플라스틱 카드 90만개 재발행하는데 환경부담금은 내야지? 그리고 그 엄한 세금 뜯어가면서 댓글알바 쓰지마라.',
#        "기존 체크카드가 있음에도 추가 선불 카드 신청해야지만 동백전을 사용할 수 있다는 시스템이 이해가 안됩니다. 고객센터에 문의한 결과 새롭게 발급된 선불카드는 '보관하거나 폐기' 하라며 '보관' 을 추천드린다며 기존 체크카드 사용하다가 사용기한이 끝나거나 분실하면 새 카드를 쓰라는 말은 참 어이가 없네요. 세계적으로 플라스틱 사용 제한하자는 추세인데 불필요한 플라스틱 생산에 가담하는 부분이 마음에 들지 않습니다. 새 카드를 발급하게 해서 어떤 이익이 남는지 참 궁금합니다.",
#        '부산시가 하는 일아 그렇지 뭐 ㅋㅋㅋ',
#        '도대체 어디서 신규신청을 해서 기존카드 연동하라는건지 인터페이스 진짜 엉망입니다 거기다 설명조차 불분명하니 도저히 쓰고 싶은 생각이 들지 않습니다 이럴꺼면 왜 갑자기 바꾼건지 이해가 되지않네요',
#        '굳이 이전카드가 있는 사람들이 선불카드를 필수적으로 발급 받아야할 이유가 뭔가요? 심지어 선불카드라서 삼성페이 등록도 안되고 ㅎㅎ... 시대역행하시네요',
#        '카드 재발급유도 ㅎㅎ..',
#        '16일 선불카드 강제 발급 절차를 개선해 산택발급이 가능하도록 업데이트 했다고 뉴스며 시청 홈페이지에도 나오던데 잔액이관 신청 하려고 하면 선불카드 강제 발급하라고 나오네오. 삭제하고 재 설치해도 그렇습니다. 개선됐다고 언플만 하고 실제로는 하나도 바뀐게 없는데 이런식으로 일처리하지 마세요. 선불카드 선택발급 안됩니다. 여전히 강제발급입니다. 왜 선택발급 가능하게 개선했다고 언플하나요?실제로 개선되고 바뀐건 하나도 없는데 이런식으로 언플하고 변명만 늘어놓는게 더 짜증나요 진짜',
#        '재발급 강요? 재발급 하지 않으면 서비스 사용 가능으로 넘어가지 않는 형탠데 의도적인건가요? 재발급은 좋은데 체크 카트 형태는 지원하지도 않고요. \n\n좀더 기다려야 하나요?',
#        '엉망으로 만들어뒀네요. 누가 돈 받아먹었는지 이상한 업체로 바꼈고. 무조건 카드 새로 발급받아야하는데다 삼성페이 불가능이 뭔 말같잖은 소린지. 기존에 남은 돈때문에 하긴하는데 진짜 쓰레기다',
#        '자주하는 질문에 기존 동백전카드 사용가능하다고 해서 앱깔고 잔액 이관신청하니 카드 배송 주소 입력란이 바로 나오네요. 그냥 무조건 카드를 신규로 발급받게 끔 되어있네요. 고객센터 전화는 연결도 안되고... 카드 도착할때까지 동백전을 사용도 못하네요. 너무 불편합니다.',
#        '인터페이스 너무 불편합니다... 혜택정보 누르면 무슨 FAQ내용스러운 것들만 뜨고.. 캐시백 내역만 따로는 볼 수 없는건가요?? 어제 기존카드로 썼는데 캐시백 환급이 된건지 안된건지 알 수가 없네요;; 3월까지 쌓여있던 기존금액을 기억 못하는 제가 잘못한건지ㅋㅋㅋㅋ 쓸데없이 조잡하네요.',
#        '무조건 새카드 발급되는거 너무 낭비에요.. 기존카드 등록하면된다더니 기존카드는 있든말든 새카드는 무조건 발급되는 시스템인것같은데 대체 이게 무슨 자원낭비인지......',
#        '부산시 진짜 더럽게 운영하네요ㅋ 업체가 바뀌어도 서비스는 지속성이 있어야하는데 이건 매번 서비스 바뀔때마다 카드 재발급에 기존에 넣었던 돈 찾기도 힘들고, 카드 재발급한것도 한달이 되도록 오질않아요ㅎ 누가 돈 잃을 각오하고 여기에 돈 넣겠냐? 에휴',
#        '기존에 사용하던 카드에 있는 돈을 옮기려면 강제로 카드발급하게하는 말도안되는 어플이네요',
#        '멀쩡한 카드 냅두고 새 카드 발급받으라구요? 몇십만장 발급되면 환경오염은 어쩔건지? 인터페이스도 너무불편하고 그냥 이관안할걸그랬네요 캐시백안받고말지; 후회됨',
#        '완전 별로 새로 바뀐 어플 메뉴 너무 많고 디자인도 정신 사나움. 안그래도 멀쩡한 카드 냅두고 새 카드도 추가되서 혼란스러운데 어플 들어가면 더 복잡함. 은행원 실수로 잘못 발급되어 만들자마자 폐기되서 한번도 써본적 없는 카드는 이전 어플에는 안떴었는데 왜 여기는 연결되는 것이며, 해지된 카드가 무슨 의미가 있다고 삭제도 못하게 막아놓은것임? 내가 스스로 연결시킨것도 아닌데 왜 삭제 못하냐고요. 덕분에 나는 카드 세개나 떠서 더 복잡함. 강제 발급한 카드까지 오면 총 네장임 ㅋㅋ 이게 말이 되는건지.. 이것 좀 어떻게 처리 해보세요. 이유도 설명 안하고 그냥 자꾸 안된다고만 하는데 왜 안되는건지 도대체 이해가안가네..',
#        '별 하나도 아까움 부산시민이 호구 인가봄',
#        '새로 카드발급이 선택이 아닌 필수라는게 진짜 어이가 없네요ㅡㅡ 부산시는 굳이 왜 업체를 바꾼건지 이해할 수가 없음',
#        '최악의 앱. 사용하기 완전 불편하고, 연결된 카드가 있다는데 카드번호를 보니 내가 보유하고 있는 카드 번호가 아닌데 내가 모르는 내 카드가 있나봄. 뭐하려고 어플 바꿔서 카드 재발급 받게 하는지. 앞에 앱은 쓰기 편했는데 재발급 받고부터 뭐가 뭔지 하나도 모르겠음. 알고싶지도 않음. 그냥 동백전 안 쓰는 게 정신건강에 좋음',
#        '카드 강제발급 최악이다',
#        '아니 왜이렇게 복잡하게 해둔거에요? 쓸대없이 카드는 왜 발급 받게 유도하고 어플 가독성은 최악이고...쩝',
#        '기존 카드 사용하려면 이관해야 하며, 이관시 새 카드 발급해야지만 사용 가능 이 어이없는 상황이라니...',
#        '기존카드 쓸 수 있다고 해놓고 왜 무조건 신규카드를 발급 받아야하나요? 플라스틱 쓰레기 만들고 싶지 않아요.',
#        '신규카드 발급 강제.. 어이없네요 신규카드 발급 선택권 검토중이라고 하니 기다려봅니다 +직원들이 무슨죄가 있나요 위에놈들 기름진 배 채우려고 이사단 난걸.. 조금만 기다려봅시다',
#        '교통카드연계는 어찌합니까', '카드.결제는.되는데.내용확인이.안돼네요',
#        '명불허전 공무원 작품.. 접속장애 엄청 심합니다', '새 카드 이관할려고 보니 실물카드와 앱상 카드번호 다릅니다',
#        '마케팅 광고는 왜 넣었으며..왜 선불카드 의무 발급하도록 하는지요?? 공지도 카드 발급해야 확인 가능? 동백전을 이용해주시는 부산시민분들께 혼란을 끼쳐드린점 양해 부탁드립니다. 2021. 4. 5. 9시 재개된 동백전 신규 앱 설치 및 기존 체크카드 등록 과정에서 진행되는 ‘신규 선불카드 의무 발급’과 관련하여 문의가 많았던 부분에 대해 아래와 같이 알려드립니다. (1) 기존 체크카드 보유자가 선불카드를 무조건 발급 받아야하는 이유가 무엇인가요? ▷ 신규 동백전 앱 설치 및 기존 체크카드 등록 과정에서 선불카드 발급에 동의하지 않으면 신규 앱 사용이 불가능하게 시스템이 설계되어 있습니다. 이는 기존 회원의 보유금액과 카드정보를 새로운 동백전 시스템에서 연동하기 위한 기술적 필요에 따른 것으로 기존 동백전 체크카드의 재발급, 폐기·교체가 아닙니다. 다만, 선불카드 발급여부를 시민들이 선택 가능하도록 해달라는 의견이 제기되어, 운영대행사와 협의하여 수일내에 개선할 계획입니다.',
#        '기존 사용카드 등록하면 없는 카드라고 나오는데 어떻게 잔액 이전하라는거예요??', '앱 바뀌고나서 너무불편사항만음',
#        '왜또카드를 발급 받으래 짱나게. . .',
#        '가독성이 너무 안좋아요 메인화면엔 필요한정보만 나오면 되는데 "총 받은 혜택"란에 적힌 금액표시 때문에 자주 잔액이 헷갈립니다 제발 숨김 기능이나 다른 메뉴에서 확인하도록 수정 좀 해주세요',
#        '동백전 사용좀 합시다;; 카드 오기 전까지 사용못해서 손해보는 비용만 얼마인지;;',
#        '기존카드 등록이 너무안됩니다 또한 다른사람 등록한거보니 만든꼬라지가 그냥 초등학생수준이더군요 댓글들보이 한두사람이 이래생각하는게 아닌거같은데 3만원 더받을빠에 다른카드써서 혜택 더받을랍니다 그래도 부산산다꼬 써줄라켓드만',
#        '체크 계속 사용할 수 있다는 설명도 없이 그냥 무조건 카드 발급하라니요',
#        '기존카드사용이라고 안내하였고 추가발급해야한다는말이 없었는데카드를 발급선택도아니고 강제카드발급을 시켜 필요도없는카드를 만들게함',
#        '기존에 쓰던 카드 계속 쓸 수있게 해주세요',
#        '앱 깔자마자 강제 신규발급 강요--카드발급 안하고 싶으니 환불 해주세요. 쓰고싶은 맘 없어요. 환불 절차 알려주시고 신규 카드발급건에 대해선 4월8일 답변받은내용--> 현재 신규카드 발급여부를 시민이 선택할 수있게 해달라는 의견에 협의중이다. 수일내 개선 할 내용이다.라고 답변받았는데 아직 변경내용 없이 그대로 진행인데 어떻게 된건지 설명해주시죠..! 왜 변경사항 없이 계속 진행중인신지..한달 가까이 기다렸는데 언제까지 기다려야합니까!! 증말 거지같은앱이 따로없네.',
#        '카드재발급해야됨 기존카드 사용하려고 카드발급받아서\n쓰레기만 추가하는꼴',
#        '기존 카드이관 요청 당연히 기존 카드 사용할수있게해야 하지않나요? \n업체가 바뀌면서 자사 카드 발급을 강요한다는 느낌입니다.  기존 카드 사용토록 개선바랍니다.',
#        '뭐가뭔지 모르겠네요 설명을 알기쉽게 잘 설명해주던가,,',
#        '1. 앱 깔자마자 카드 강제 발급 유도에, 막상 가입하고 나니 예전에 발급받았던 체크카드는 연계되었다만 메시지만 뜨고 카드 관리에 보이지도 않는군요. 서비스 업체가 바뀌면서 이전 카드는 알아서 관리하라 이건가요? 2. 앱 디자인, 알림 메시지 등 전반적으로 민간기업의 홍보 분위기가 풍깁니다. 부산광역시에서 주관하는 지역화폐 앱이라면 광고스런 분위기는 좀 자재할 필요가 있을 것 같네요. 3. 홈페이지에 불만사항 접수하러 갈랬더니 홈페이지는 또 먹통이군요. 4. 댓글에 똑같은 말 붙여넣기 하실 것 같으면 그냥 답글 안하시는 편이 좋을 것 같습니다. 사용자들은 떠들어라 우리는 모르겠다 처럼 보입니다.',
#        '그냥 업데이트중이라고 뜨면서 작동할생각을안함 여기돈넣고쓴 내가호구인듯',
#        '별 하나도 아까운 앱이 분명합니다. 기존 사용자들의 불편은 동백전 사업자가 이관되었으니까 당연히 감수해야하는 부분인가요? 리뷰에 기존 사용자들의 불만과 불편 사항 호소가 넘쳐나는데도 불구하고 답변 보니까 불난집에 사우디아라비아에서 직송한 기름을 그대로 때려붓고 계시네요. 개선 좀 제발 꼭 해주십시오.',
#        '쓸데없이 있는카드 또 발급. 답글은 신규발급받아야 사용가능하다는 똑같은 대답. 필요없는카드 또 발급은 혈세로? 뭐지?',
#        '쓰기 싫음 자동으로 캐쉬도 안돼 사용 전후 잔액확인도 없고 승인 내역만 있어 바뀌고 하나부터 열까지 싫음',
#        '여러모로 구려요. 더 좋은 서비스 제공을 위해 시행사 바꾼 거 아닌가요? 전에는 불만 전혀 없이 사용했는데, 바뀌고서부터는 인터페이스 디자인이나 qr코드 사용이나 다 불편해졌어요. 부산시 결정 매우 구리다!!!!!',
#        '카드가 도착했다해서 우편함에 놔둬달라했는데 집에 갔는데 없더라구요ㅠㅜ 그래서 재발급을 받고싶은데 찾아봐도 재발급 받는데가 없더라구요 어떻게 재발급을 받죠?ㅠㅜ',
#        '신규 카드 발급이 필수라서 발급하고 전에 카드는 못쓰나 싶어서 버렸더니 이제와서 뒤늦게 공지로 기존카드 쓸 수 있다네... 장난하는것도 아니고... 그리고 새로운 앱 IU도 엄청 불편하고 내포인트 확인도 안되고 대체 왜 이쪽 회사로 이관하는지 이해가 안됨. 각종 지역화폐중 역대급 쓰레기임. 그리고 답변은 복, 붙혀넣기만 하고있는데 붙혀넣기한 답변의 문법이 맞다고 생각하고 게속 붙혀넣기 하는거임? 읽어도 이해가 안되네... 아 이제 그만 써야겠다.',
#        '왜 잘 쓰던거 바꾸는지;;;;;;; 개별로임 카드도 재발급 받아야되고... kt보다 훨씬 못하네....',
#        '별 한개도 아까움 왜 이런업체로 바뀌어야 하는건지 앱도 불편하고 고객대하는 태도도 엉망이고 신규발급 받게 시스템 만들고 시스템 탓하고 공지사항 제대로 안띄우고 신규카드 만들면 취소된다하구서 취소하려니 연동해서 안된다함 그럼 연동시 문구 띄어서 주의할수 있게 해야지 무조건 앱깔아서 신규카드 발급받게하고 공카드고 나발이고 필요없는걸 왜 만들어야 하며 이렇게 불편하고 고작 3만원 안쓰면 1년 얼마 혜택도 크지도 않는데 불편한게 한두가지가 아님 부산시랑코나아이 조사해라',
#        '기존 카드 등록하면 된다고 해놓고는 등록하는 난도 없고 무조건새 카드를 발급받으라고 하네. 결국 플라스틱 쓰레기만 늘어나고, 새 카드 오는 동안 동백전 못쓰고 기다려야 하나? 부산시는 하는 짓이 왜 이 모양인가? 시민들이 좀 편리하게 쓸 수 있도록 해주지 못하나? 새로 시장 누가 되든지 이런 거 하나라도 좀 제대로 했음 좋겠다. 에이ㅡ',
#        '동백전 카드에 있는 돈을 쓸수 있는건가요?? 이관 될 줄 몰랐는데요ㅠㅠ',
#        '쓰레기 같은 앱 알람설정도 마케팅 동의해야 가능하게 만들고, 카드도 코나카드 일부러 발급하게 만들고, 계좌도 하나만 등록할 수 있게 되어 있고... 이전 앱비해 하나도 나은 점이 없습니다. 케시백 아니면 당장 지워버리고 싶은 앱입니다. 어짜피 건의사항 얘기해줘봤자 코나카드 플랫폼 그대로 옮겨온 수준이고 고칠 생각도 없어보이네요 ㅉ',
#        '왜 기존 카드를 못쓰죠? 설명은 기존 카드를 쓸 수 있는 것 처럼 해 놓고는\n\n이관신청(발급신청)을 하지 않으면 앱 자체를\n\n못쓰게 막아놓았네요??',
#        '어플이 켜져야 잔액 확인을 할텐데 어플이 켜질 생각을 안하네요 리뷰 보니까 다른분들도 그런거 같은데 언제 오류 수정 되나요? 이런 현상 계속 되면 캐시백이고 머고 더이상 동백전 쓸 이유가 없지 않을까요?',
#        '어휴.. 별 그지같은데서 동백전 새로 이어받았네.. 이관 된다면서, 뭔 새로 입력해야 될게 이래 많냐.. 그리고 기존카드 사용가능하다면서, 앱 설치해보면 절차상으로 새카드 발급받게끔 유도해놨네.. 드럽게 번거롭게 해놨네ㅉㅉ',
#        '1. 우선 실물카드를 가지고 다녀야 하는 불편함 2. 초반 자동차 지급하는 이벤트로 기존카드가 있음에도 실물코나카드 발급받게 해놓고 추첨하고 (당연히 당첨안됨) 바로 카드발급등록만 하면 포인트지급하는 이벤트열어서 기존발급대상자는 참여조차하지못하게 함 3. 포인트사용도 예전 동백전은 그냥 사용만 누르면 자동으로 나가고 잔액확인 가능했으나 지금은 사용할금액을 미리설정해야함 만약 설정된 금액보다 사용금액이 더 클 때 나머지 잔액 포인트는 제대로 들어오고 있을지 의문임 4. 고객대응 천안 지역카드의 CS와 확연하게 차이남 (어떻게든 문제해결을 위한 마음이 담겨 있음을 앱 평가창을 보면 느낄 수 있음) 결론.. 사용하기 완전 불편함 개선이 매우 필요함',
#        '최악!! 너무 어이 없어 생애 처음 리뷰 남깁니다. 신규카드 발급 없이 기존카드 사용되게 해주세요.',
#        '기존에 가입이 되어 있는데 이관되면서 새롭게 가입해야되고 무조건 선불카드를 신청해야 기존에 잔액과 캐시백 사용이 가능하네요. 기존 실물카드가 있음에도 또 카드가 온다는게 납득이 잘 가진 않네요.',
#        '전에 올라왔던 공지글이 사라지고 1:1문의 올린 글에 내용과 다른 답을 달아줬네요. 불필요한 선불카드 발급을 피하려고 계속 알아보다가 오늘에야 업데이트 후 기존 체크카드만 설치 연동 했습니다. 사용자 편의가 전혀 고려되지 않은 접근및 사용성에 정말 불편합니다. 기존 업체가 달라 UI를 동일하게 못한건지...아무리 그래도 실 검토후 반영을 해야 하는게 아닐까요? 많은 사람들의 불만과 요구에 진심으로 대하길 바랍니다~',
#        '(4) 선불카드 발급 비용은 누가 부담하나요? ▷ 카드 발급에 따른 부산시의 관련 예산 소요는 전혀 없으며, 선불카드 발급 수수료 및 배송비는 운영대행사인 ‘코나아이(주)’가 부담합니다. 코나아이 돈은 돈이 아니냐? 이게 다 자원낭비에, 운영비용 증가, 담당자 업무량 증가, 결국에는 또 소비자에게 비용전가될거 아니냐!!! 그 돈으로 불우이웃을 돕던지, 선물 이벤트를 하던지 하지 뭐야ㅜ이게!!!',
#        '어플개발자 짤라야겠는데요? 그사람월급도 시에서 지원받을텐데 세금아깝습니다 이상황 지속되면 민원도 계속넣을생각입니다 ㅋ진짜 못만들었네요',
#        '안쓸렵니다 바꾼 이유나 합리적으로 설명해주세요',
#        '본인들 수익을 위해서 카드 발급 선택사항 조건이라면 이해가 가능하지만 필수사항으로 하다니 정말 사리사욕 끔찍하네요. 부산시 담당자는 뭘하는지 ㅋㅋ 기본적인 부분 사전 검토도 안하고',
#        '왜 이렇게 귀찮게 설정해놨냐 무슨 캐쉬쓸려해도 얼마 작성해서 캐쉬쓰게 만들어놓고 작성하고 10분 타이머 맞추고 폰잠시끄면 사라지고 \n더럽게 설정 이상하게 해놨네 \n저번처럼 그냥 캐쉬사용 버튼만 누르면 되지 뭘 얼마까지 작성하라고 하노 \n누가 이거 만들었냐 더럽게 못만들었네',
#        '새 카드 발급 안받고 싶다고요! 말귀가 어둡나!!',
#        '저 카드발급안받고싶은데요 발급받아야지만되는 프로세스라니..이해가안되는데',
#        '일단.카드신규신청해래서 주소쓰고다했는데요.아직 그신규카드는.배송준비중이라고만뜨던데, 이전 카드에 잔액있는거 ,(구.)동백전카드로 긁고 사용은가능한가요,?',
#        '카드 수령지가 자택 외에 설정이 안되네요... 리뷰 보니 형식적인 답변 뿐이고 활성화 되려면 업체부터 다시 바꿔야겟네요~ 시에 연락 할 예정입니다.',
#        '신규카드 발급사항은 선택사항으로 할 예정에 있다하여 어제 발급신청하고 30분도 안되서 발급취소 분명히 했는데 어제 발급 배송 안내 톡이 오더니 오늘 앱에서는 배송준비중이라고 되어있네요 결국 배송기사가 도착했다고연락이 오네요 앱에서 취소를 해도 배송이 오는 시스템이라 참 어이가 없습니다 고객센터는 전화를 받지도 않고 앱도 화면이 어수선하여 직관적으로 충전 금액과 캐시백 금액이 보이지 않아서 불편하고요 개선 사항이 너무 많아보이네요',
#        '카드 발급신청 안하면 앱 못쓰게 해놨네 최악이다',
#        '새카드를 무조건 발급 받아야하는 설명도 없고 부산시에서 하는 행정이 참 한심함',
#        '시키는데로 했는데 무슨 기존카드 등록 안되고 없는 카드라고 하고...나참...써라고 만들어 놓은건지 고객들 돈 못빼내게 수작부리는건지 모르겠네 빨리 고쳐주시죠 있는 돈까지만 쓰고 안써야지... 리뷰같은거 안쓰는데 진짜 최악이네요',
#        '앱이 첫화면부터 들어가지질 않네요 부산시는 이딴걸로 바꾼다고 돈쓰는거예요?',
#        '카드이관신청하는데, 왜 카드를 새로 신청해야하나요?',
#        '사람들 생각 다 같구나.. 전체적으로 더 복잡한거 같아요 캐쉬백도 바로바로 확인이 안되고 이런 불편사항 적어도 또 복붙해서 개선하겠다는 말만 하겠죠?? 이만큼 사람들이 공통적으로 말하면 좀 들었으면 좋겠습니다',
#        '기존동백전이 훨씬 간단하고 편했음. 설명도 없이 불핑요한 카드를 강제로 발급해야하는 낭비. 고객센터 연락도 안되고 마인드가 틀렸음. 부산시의 행정도 한심함.',
#        '사용내역 보이게 하세요. 댓글은 리뷰 복붙같은거 달거면 달지말고요. 어떻게 다 댓글이 똑같아요? 성의가 있으세요.',
#        '잔액환불 기존카드잔액환불 받을라고\n동백전카드새로발급받으래서\n발급하고  앱카드 등록했더니\n머시절차가   복잡네요\n얼마안되는금액이지만\n이제이카드안쓰려고 \n남은금액  받을려는데  80프로90프로먼가요\n딸랑1370원에서  몇프로띠고  준다는건가요\n내돈내가이관하겠다는데\n어이없군요\n그리고 현금영수증 혜택받는데서\n작년에 동백전카드로 결제한것들\n현금영수증 신청하나도 안되어있군여\n먼이따구의 시스템에  이득대는게  하나도없고\n대형마트는  사용도안돼.\n내돈이나  돌리주이소\n돈받고.내정보 다삭제하고\n철회할렵니다',
#        '이래저래 바뀌고나서 쓰레기처럼 되버렸네요...왜 바꾼거죠 진짜!!',
#        '새카드발급하래서 안하고있는데 계정은 어떻게 탈톼하나요',
#        '신규카드 무조건 발급 받으라고 너무 한거 아닙니까? 기존 카드랑 그냥 연동해서 쓰게 하는게 기본 아닙니까? 신규카드 신청 할 사람만 신청 받고',
#        '쓰기불편해요 개선의 의지가 없든지 능력부족 아래 1점짜리 리뷰 내용들 전부 공감됩니다.',
#        '진짜 쓰렉이같이 만들어놨네 새카드 필요 없는데 강제로 신청하게 하고 새카드 등록하는데 3번 인증에 한도증액 강요 ㅋㅋㅋㅋㅋㅋ 애라이 개쉑이들아 엿이나 처먹어라',
#        '코나아이가 부산시 고위 공무원이랑 한배타서 수수료 띵작? 하기로 한건지 이해가 안돼네',
#        '기존 동백전은 앱만 깔면 된다더니 로그인까지 해놔도 사용 안 됨 카드 등록이 안 됐나 싶어 등록하려니 유효하지 않은 카드 결국 새로 카드 신청해서 받았더니 정작 새로운 카드는 교통카드 기능이 없음. 기존거 등록을 못하니 충전도 못하고 왜 멀쩡히 잘 쓰던 업체 바꿔서 이따위 쓰레기 업체랑 계약했는지 돈 받아 쳐먹은 건 없는지 반드시 수사해봐야함.',
#        '굳이 안만들어도 되는 카드 억지로 만들게 해 놓고는 수일내 시정할거라는 답변이 오니 어이가 없네요.? 개선이 가능한 부분이면 준비 과정에서 미리 갖추어 두어야 하는 거 아닌가요?ㅎ 꼼수 쓰는 부분이 너무나도 훤히 보여서 어이가 없네요. 그리고 포인트 사용 방식이며 앱사용법도 지난 업체보다 너무 구린데 도대체 부산시는 이 업체로 갈아탄거죠?ㅎ.. 너무 마음에 안드네요.',
#        '서비스 뭐 같이하네 업데이트 하니까 소득공제 신청 동의 자동으로 뜨던데 미리한 사람은 안뜨게 해야지 지금 강제로 동의하게 창 띄우면 지금 동의후부터 소득공제 해준다는 말로 밖에 안들리네 별 한개도 아깝다',
#        'ㅋㅋㅋ불편사항 백날 말하면 머하누 매크로가 답변하는데 ㅋㅋㅋ +네 매크로저격하는 리뷰에도 매크로 답변하죠?ㅋㅋㅋ걍 배째라임',
#        '오늘 계속 오류라고 안열리네요.. 카드 발급하게 만들어서 선불카드 발급받았는데.. 안받아도되는건가요.. 바뀌니까 너무 불편하고 별롭니다',
#        '설명 좀 쉽게 하지? 잔액 이관 하는데 뭔 신규발급에 신규등록에... 장난치나. 앱을 자다가 만들었나. 오거돈이 시장질에 시청 공무원놈들까지 개판이구나. 이딴데에다 외주준 공무원 도데체 누구냐? 진짜 일못한다',
#        '앱 사용이 직관적이지 못하고 대표적으로 월별 사용금액(기간지정)이 누적확인이 안되서 확인이 불가능하다는게 불편함 개선해주세요 이전보다 발전해야지 불편해지는건 이해할수없음(무능력으로 보여짐)',
#        '기존 회원의 보유금액과 카드정보를 새로운 동백전 시스템에서 연동하기 위한 기술적 필요에 따른 것 => 왜 불필요한 카드 발급비용과 인력 낭비를 합니까?선불카드 충전을 통해 수수료 지급 절감과 고객 예탁금 이자 수익 확보 위한 회원수 늘릴려는 꼼수 아닌가요?게다가 자동충전 최소금액이 5만원 ㅋㅋㅋ 부산시에서는 확실한 해명이 필요 할것 같습니다.',
#        '카드 재발급 필수인거 진짜 짜증남 며칠간 사용 못한것도 진짜 화나는데', '왜 댓글에 답장안해주냐? 무시하냐?',
#        '교통카드도 안되고 다안되고 개불편함', '카드신청이 안됩니다 눌러도 반응이없어요',
#        '기존카드사용하려는데 왜카드이관신청하라고만 뜨죠?', '이전보다 너무불편함 적립내용보기도없고 개선해야할게많음',
#        '청와대게시판이나 언론에 제보할일이네요 쓰잘떼기없이 굳이 신규카드를 재발급해야될 이유가 전혀없는데 번거롭게 앱설치는 그렇다치더라도 기존카드사용할수있음에도 신규카드를 강제발급받게하는건 뭔가 납득이 가지않네요. 더욱이 일반사기업에서 진행하는 사업도아니고.. 복붙으로 답변하는 꼬락서니하고는..쯧 위에다 똑바로 보고하세요 어디든 제보할테니까!',
#        '부산시가 하는게 다그렇지 돈이나 받아먹고 바꾼거지뭐',
#        '기존 동백카드를 계속사용중입니다.새로운카드를 받았는데 등록이되지 않습니다.어떻게 하죠?',
#        '신규카드발급 강제하네요. 부산시청에 항의하겠 습니다.',
#        '다들 부산시에 동백전 민원 넣어주세요 이렇게 불편하게 만들어놓고 담당자는 뭐 하나 하는게 없나봐요; 민원이라도 넣으면 담당자 바껴서 사용알람 오게 해줄라나보네요; 민원 넣으러 갑니다~',
#        '왜 선불카드 추가 발급을 하라는지 모르겠네요... 그나마 기존 카드 사용은 된다하니 전 기존채크카드 사용 할 겁니다. 강제로 신청된 실물카드 보내지 말아주세요. (당일밖에 취소 안된다면서 기존 채크카드 연동되었다고 선불카드 발급 취소도 안되네요. 자동으로 연동되게끔 해놓고 어쩌라는건지 원)',
#        '혜택을 많이 준다해서 하나장만했더니 무슨 행정을 손바닥 뒤집듯바꾸나요? 재수없어서 짤라 버려야겠다',
#        '지들 코나동백전선불카드 끼워팔기네 이거 금감원이나 소비자보호 이런곳에 신고해야겠다',
#        '카드발급 선택사항으로 변경했다면서 왜 자꾸 발급하라는 메뉴만 나오나요 발급하기싫은데',
#        '꼼수 끝판왕이네요. 기존 카드 연동을 빌미로 자기들 카드 신규 발급 받게해서 결국 부산지역 소상공인 수수료 뜯어 먹겠다는 심보인데.. 재무상태도 안좋은 이런기업을 위해 부산시민의 돈이 나가야 하는지 이해기 안되네요..누구를 위한 동백전인지 코나아이 배불리기 위한 동백전인가요?? 부산시민을 위한 동백전인가요??',
#        '계속해서 기존카드가 없는카드라고 뜬다.',
#        '아놔 열받네 또 발급받으라고? 플라스틱 쓰레기 문제많은거 알지 니들이 일조하는거야',
#        '최악이네요 세금이중낭비 답변은 메크로 돌리시나...',
#        '전보다 사용이 너무 불편하고 신규 선불카드는 의무적으로 만들어야하는 불편한 진실. 자원낭비. 캐쉬백도 직접 설정해야하는 귀차니즘. 사용해보다 개선없음 사용안하겠음! 별 하나도 아깝네요!',
#        '진짜 별 하나 주기도 아깝다. 이전카드 쓸 수 있어도 결국은 재발급 받아서 등록절차 끝내야 이전카드 쓸 수 있다는 소리잖아. 다른 댓글에 답변 단거 봐도 죄다 복붙한 거 마냥 답글이 다 똑같고..진짜 욕 나오네 이게 뭐 하자는건지..',
#        '느려서 속에서 열불터짐 혜택때문에 쓰지 코나보다 마니 안조음', '쓰레기 앱.', '쓰레기ㅡ',
#        '삼성페이도 안돼, 앱카드도 안돼, 바코드 큐알 결제도 안돼, 이건뭐 무조건 실물카드 들고 다녀야겠네 ㅋㅋㅋㅋ 이거 앱 만들어놓은건 결국 카드등록/충전기능 밖에 없는거네요? 아니 진짜 더 좋아지지는 못할지언정 퇴보는 하지 말아야지 ㅋㅋㅋㅋ 10% 1달 최대 30만원 혜택 보려면 이정도 불편은 감수하라 이건가? 이래놓고 나중에 부산시민들 지역화폐 안쓴다고 징징거리지나 마라 ㅡㅡ',
#        '강제 신규발급은 이상하네요. 신규발급을 하지않으면 앱자체를 쓸수 없게 만든건 누구의 생각일까요?? 부산시??? 코나아이??? 부산시에 항의 전화하면 바뀌려나요...? 이미 기존카드쓰는 사람들은 왜 신규발급만을 받아야 하는지 카드만드는 회사에 왜 세금을 써야하는지 알 수가 없네요. 뭘하던 세금 낭비라는건 잘 알겠는데 이게 아무런 문제가 없다니 놀랍네요. 우선 카드 발급 신청으로 바로 넘어가서 신규카드발급안하려고 기다리는데 시정되면 좋겠습니다.',
#        '거지같은 앱 ㅜㅜ', '쓰레기어플임 하나도 제대로되는게없음 문제해결안되,상담사 연결안되 어떻해 쓰라는거냐',
#        '기존 카드 사용불가, 재발급 필수.',
#        '리뷰댓글에 복사붙여넣기 좀 하지마라 사람들 홧딱지나서 귀찮은거감수하고 심사숙고해서 댓글다는데 지네는 똑같은 의믜없는 답변 갓다붙이네 앱사용해보고 너무빡쳐서 사람들은 어떻게 생각하나 보러왓더만 댓글보고 폰집어던질뻔햇네 반성해라진짜',
#        '구동백전을 돌려달라!',
#        '제발 총 받은 혜택 없에주세요. 총 받은 혜택 하나도 안궁금해요... 총 받은 혜택 제발 빼주세요.. 넘 조잡해서 아직도 적응불가.. 총 받은 혜택 빼고 그냥 잔액이랑 캐시만 시작 화면에 넣어주세요.. 내 지갑은 왜 따로 있는지 모르겠네요..',
#        '이관할려면 카드신규발급을 강제하는 쓰레기 업체',
#        '가맹점 찾기도 안되고, 기존카드 바로된다고 해서 깔고 이관하고 다했는데 카드신청을 하라는 란이 바로나오네요.? 그럼 이전 실물 카드는 사용이 불가한거아닌가요.? (카드번호로 등록하려고하니 안되더군요) 그리고 앱디자인도 이전이 이쁘긴하고 깔끔합니다. 게다가 이전 앱보다 ui가독성도 현저히 많이 떨어집니다. 앱사용환경 인터페이스도 별로입니다. 직관성은 이전게 더 편합니다. 개선이 많이 필요해보입니다.',
#        '넘 불편 ㅠㅠ ㅡ매번 비번 입력해야 들어가짐\nㅡ멀쩡한 카드 두고 새카드 발급신청유도해서 플라스틱 쓰레기 생산\nㅡ정신 사나운 앱 디자인\nㅡ사용 금액에 대한 적립금 확인이 쉽지않음\n*일을 하려면 개선된 방향으로 또는 진보된 방향으로 해야지 아니면 최소한 그대로라도 두든지. 이 앱은 사람들을 괴롭히려고 만들었거나 현대인에서 크로마뇽인으로 역진화하려고 만든 듯.',
#        '하나카드사에서 기존카드 쓸수있다고 했는데 왜 카드발급 유도 하시는 거죠?? 불편합니다 기존카드 사용 가능하게 업뎃 해주세요 !!',
#        '사용하기도전에 댓글보고ㅠ안씀.. 이게 부산시가ㅜ노리는건가....',
#        '카드발급받기싫다고 아 부산 개색들 제대로하는게없노', '신규카드 발급시 삼성페이 불가',
#        '쓰기 개불편함 원래 리뷰잘 안적는데.. 짜증나서 적으러옴\n디자인이랑 기획 누가햇는지.. uiux\n아진짜 보기 불편하네요.. 좀 더 직관적으로 만들수없나요????????????????????????,??????????????아니면 개발자를 초급오브초급 개발자로 데려다 놓으신건지..\n+) 쭉 내려서 읽고왓는데 답변이 하나같이 복붙이네요 ㅋ 동문서답해서 더 짜증남 ㅋㅋ 이용자 우롱하나? 제글에도 복붙할거 생각하니 ㅋㅋㅋ그럴거면 답변을 안다는게 낫지않을까요?ㅎㅎ',
#        '형편없네요 삼성페이는 물론 캐쉬사용도 앱에서 사용누르고 10분이내에 실물카드로 결제해야한다니 뭐이런 병맛이',
#        '기존카드 사용된다더니 신규발급화면으로 직행해서 무조건 발급! 왜 다른거 아무거도 안되게 해놨냐? 시청에 전화합시다!',
#        '카드신청안됨 다 하고 마지막에 계속 오류가 나요ㅠ 청구서 수령관련 등록을 해야된다는데 중간에 그런거 입력하는 부분도 없고 어쩌라는건지;;;;'],
#       dtype=object)

# %% [markdown]
# ##### 토픽 8
#
# '0.087*"불편" + 0.039*"다운" + 0.026*"하루" + 0.022*"종일" + 0.022*"대기" + 0.018*"인터페이스" + 0.016*"사용" + 0.016*"엉망" + 0.015*"카드" + 0.015*"먹통"

# %%
topic_8 = topictable[topictable['가장 비중이 높은 토픽'] == 7.0]

print('토픽 8에 해당하는 리뷰의 개수:', topic_8.shape[0], '개')
# Out:
# 토픽 8에 해당하는 리뷰의 개수: 107 개

# %%
# 토픽 8에 해당하는 리뷰들만 모아서 하나의 df 만들기

topic_8_list = topic_8['리뷰 번호'].unique()
df_topic_8 = df_negative.loc[topic_8_list, :]

df_topic_8.head(5)
# Out:
#           DATE  STAR                                             REVIEW  LIKE
# 10  2020-04-29     1                     휴대폰이 노트10 인대요 업데이트가안되요 이거외이러치요     0
# 30  2020-03-28     2  본인확인 방법을 추가해 주세요!! 법인사용자의 경우 본인명의의 폰이 아니라며 어플 ...    10
# 32  2020-11-07     1                  대체 업데이트하라면서 하루종일 돌기만 하고 사용 안 되네요.     6
# 33  2020-03-30     2  가입은 하고 되는가 볼려고 100.000 원 충전 했는데요 카드를 만들수가 없네요~...     0
# 36  2021-04-11     1  현재잔액 왜안보여요? 이전 앱에서는 잔액이 바로보여서 바로 쓰고했는데 지금은 잔액이...     0

# %%
# 리뷰 전부 모아보기 --> 복사해서 R로 들고가서 감성분석 진행

df_topic_8['REVIEW'].unique()
# Out:
# array(['휴대폰이 노트10 인대요 업데이트가안되요 이거외이러치요',
#        '본인확인 방법을 추가해 주세요!! 법인사용자의 경우 본인명의의 폰이 아니라며 어플 사용이 불가합니다. 카드를 발급받을 때에는 카드와 인증서 등으로 온라인 발급을 받았는데 어플사용이 안되니 불편합니다. 심을 바꿔서 개인폰번호으로 인증을 받고서 법인심으로 구동하면 역시나 에러가 발생하며 사용이 불가합니다. 듀얼심 휴대폰에서도 그런 현상때문에 사용상 어려움이 있습니다.',
#        '대체 업데이트하라면서 하루종일 돌기만 하고 사용 안 되네요.',
#        '가입은 하고 되는가 볼려고 100.000 원 충전 했는데요 카드를 만들수가 없네요~?? 뭐이 요렇게 복잡하나요?',
#        '현재잔액 왜안보여요? 이전 앱에서는 잔액이 바로보여서 바로 쓰고했는데 지금은 잔액이 얼마남았는지 모르니까 들어가서 지갑인가 또들어가서 보고 써야하니까 너무너무 불편해요.... 제발 이것좀 바로보여지게 해주세요',
#        '어플 다운 불가...',
#        '삼페도 안되는 무쓸모 실물카드 강제 발급은 누구 머리에서 나온 거람? 앱도 너저분한게 정신없음 동백전 탈출각 날카롭다. 추가 ㅡ 환불도 복잡하게 해놨네 ㅋㅋㅋㅋ 미치겠다 돈 써야되는데 쓰지도 못하고 빼지도 못하고 돌겠다',
#        '앱이 엉망진창 매우불편합니다', '옛날 카드보다 복잡해요',
#        '대중교통 이용도 않되게 해놓고 무슨 부산동백전 이라고...한심하네요 어떻게 선정되었는지 꼭 감사해야겠네요',
#        '며칠째 업데이트가 되지 않아 사용에 너무 불편합니다. 하루 이틀도 아니고..', '다운이 진행이 안됨..',
#        '진짜 드럽게 불편하게만들엇네', '불편하네요.게시밳ᆢ용하기도~ 엄데이트도안도고',
#        '최악임 깔고나서 본인인증문자아안옴',
#        '업데이트가 하루종일 안되네요 혹시나해서 폰을 껐다 다시 켜고 안되고 덕분에 동백전 써야할때 충전도 못해서 못썼네요 제발 개선해주세요!',
#        '휴대폰 인증이 안돼요 농협 카드로 발급하려하고요 계좌있어서 본인인증만 하면되는데 휴대폰 인증번호 발송을 하면 문자가 안와요 앱 지웠다 다시 깔아도 마찬가지고요 통신사는 LGU+입니다 빨리 수정 부탁드려요',
#        '동백전가입시 LGU+알뜰폰은 인증이 안돼 가입이 안됩니다 조정바랍니다',
#        '인증된 폰번호와 현재폰번호가 일치하지않습니다 이렇게 뜨네요 밑에 다른글 보니 나밍작업을 해야 한다고 하던데 나밍작업을 어떻게 해야 합니까 해외직구폰 갤럭시a51입니다 kt알뜰폰 입니다',
#        '아 진짜 불편하네요.. .',
#        '엉망 UI 도  불편하고\n\n일반 사람들이 사용하기 어렵게 시스템 구조에다가\n\n이전에 사용하던 기능에서 추가로 좋은 기능을 넣어야지\n\n왜 이전에 사용하던 기능들이나 사업자 기능을 다 없애고\n\n새로운 것만 딱 있으면\n\n기존에 사용하던 체계를 완전히 바꾸고\n\n문제 말하면 차차 개선만 한다고 하고\n\n그 정도는 미리 다 생각 할 수 있는 것 아닌가요?',
#        '너무 불편합니다', '앱이 자주 버벅 거립니다 터치도 안되고 먹통이 되요',
#        '계좌등록이 계속 실패로 떠서 사용이 불가능함', '왜안되는거에요..불편해',
#        '자기명의휴대폰아니면 가입이 안되는거 같은데 아이핀으로 가입할수있게 해주세요',
#        '왜 이렇게 불편하게 되었을까요 선불카드 재발급 요구 직관적이지 못한 메뉴 터치 3번이면 끝났던 충전이 여러번 터치해야하네요. 매장찾기도 없이 앱을 출시하다니.... 빠른 시일내에 매장찾기 기능이 추가되었으면 좋겠습니다.',
#        '고객 서비스가 최악이네요 어플 오류로 인하여 충전 하려고 하니 바탕화면으로 팅기는데 1:1 문의를 넣어도 5일동안 응답 안하고 전화는 하루에 4번씩 해도 하루종일 바빠서 못받는다고 하네요.',
#        '불편', '더도 덜도 말고 옛날 어플이랑 똑같이만 만들어주세요ㅜㅜ 넘나 불편...',
#        '결제 실패는 곧 시스템 실패 ,kt 하나은행 똑바하세요',
#        '뭔 이유로 앱을 이렇게 복잡하게 불편하게 만들죠? 기존 동백전처럼 열자마자 충전페이지+ 충전잔액도 바로 볼 수 있게 해주세요 너무 불편합니다',
#        '진짜 불편하게 바꼈다 불편한게 한두가지가 아니에요!!!!!!',
#        '이건 뭐 기존카드 정보 쳐넣어도 연동도 안되고 뭐하는 짓인지 뭐하러 어플을 새로 만든건지 참 이해가 안되네요',
#        '알림 돈썻으면 알림좀 울리게해주세요\n토스랑도 연동이 됬으면 좋겠어요\n옛날 하나키드는 됐는데 안돼요',
#        '휴대폰 본인인증 문자가 10~20분뒤에 전송되어서 가입이 불가능합니다. 인증시스템에 문제가 있는 거 같습니다.',
#        '인터페이스 너무 정신없구요 혹시 뭔가 판매랑 연결시켜 수익창출이라도 해야하나싶은 상업적 인터페이스입니다. 뭣보다 멀쩡한 카드 두고 신규카드발급 필수는 어처구니 없고 행정이 뭐 이따위 낭비행정인가 싶습니다. 앱에 기능을 추가하던지 해서 기존카드 연동되게 해주세요.',
#        '오늘 하루종일 먹통에 2중 결재 됐습니다 확인해주세요', '전에 비해 확실히 불편해짐',
#        '업데이트도 안되고 삭제후 다시깔아보려해도 앱 다운자체가 안됨', '어플이 계속안열리네요 정말 노답이네요',
#        '필요할때 앱이 작동을 안하네요,,,,', '다운이 안되요 설치가 한시간째 안되요 ㅜㅜ',
#        '설치가 안되고 1시간째 대기중.. 삼성페이로 사용안되나요?', '다운그레이드', '앱사용이 너무 불편합니다.',
#        '다운이 왜 안될까요? 계속 대기 상태로만 뜨고..ㅠㅠ 확인이 될까요?', '앱이 먹통이네요..에휴',
#        '가입을 할려고 하니, 다시 신규로 카드를 발급을 받으라고 되어 있네요... 지금 현재 쓰는 카드가 이상이 없는데 왜, 다시 카드를 발급을 받지 않으면 동백전 사용을 못하게 해 놓았나요? 할수없이 발급을 신청을 해서 정상적으로 앱을 설치를 했습니다. 그런데, 화면의 인터페이스가 이전 업체보다 못한것 같습니다. 이전 업체의 인터페이스는 첫화면 에서 바로 현찰 얼마, 포인트 얼마가 눈에 확 들어 오게끔 되어 있는데 지금의 화면은 사용가능 금액이 얼마라고 표기가 되어 있어서 이 금액이 포인트 포함 금액인지 사용가능한 현찰의 금액 표기인지 했갈리게 되어 있네요... 마지막으로 현재 가지고 있는 카드는 그럼, 새 카드가 올때 까지만 사용을 할수가 있는지 그리고, 새카드를 받으면 현재 가지고 있는 카드는 사용을 할수가 없는지 궁금합니다. 마지막으로 고객센터에 통화를 할수가 업네요... 10분동안 계속 전화기를 잡고 있어도 통화를 할수가 없습니다. 인원을 충당을 하던지 무슨 방법을 강구를 좀 해주시기 바랍니다.',
#        '진짜 성의없네 답글은 전부 복사 붙혀넣기내',
#        '어째 더 프로그램이 다운그레이드 된거냐? 별5개 찍은리뷰 보니 대부분 4월2일~3일 이던데 너무 티나는거 아니냐?',
#        '노답ㅠ 기존보다 가시성 떨어지고 편리하지도 않은듯;;',
#        '잘 사용하고 있는데 괜한 업데이트를 해야만 사용할수 있게해서 지금현재 마음대로 사용할수없어서 넘 불만입니다 업데이트가 안되네요 2일이나 시도했는데 대기중만 나오고 안되서 동백전 사용도 못하고 있어요',
#        '무슨 카드의무 발급인지;;; 진짜 환경생각 하나도 안하고 자기들만 생각하지 지들 이익이 최고라 그건가',
#        '전에 앱이 직관적이고 참 좋았는데 바뀐건 넘 복잡하고 쓰기 힘들어요',
#        '몇일전 가입하려고 생년월일 입력하고 인증받으려면 입력한게틀리다고 5회오류나서 다음에다시하라해서 지금생각나서 다시하려니 똑같은증상이내요? 뭔인증받는데 내가 내생년월일 모르는것도아니고 그렇다고 몇년이상쓴번호가틀린것도아니고 내명의폰이 아닌것도아니고 뭐가 틀렷다는건지 알수가없내요? 이럴거믄 뭐하러 어플로가입먼저하고 신청하게한건지?그냥 부산은행연동해서 발급해주면될걸? 포기합니다 에혀',
#        '다운하는데 계속 몇시간동 대기중이에요. 도와주셔요',
#        '기존카드 이용불가이면서 이관은 먹통임. 앱실행해도 먹통이고 되는게 없음', '불편함', '여러모로 불편합니다',
#        '그전에 비해 너무불편해요', '주소 입력이 안돼요', '불편 이전보다 불편하네요',
#        '노트 4에서도 되나요 부산은행서 호환이 안된다는데 이해가 안되서요',
#        '본인명의폰 아닌사람은 가입을 못하네요 공인인증같은거나 다른 인증할수있는방법 더 생기게 해주세요', '의무발급..',
#        '불편하네요.', '제발 본인확인 추가좀요', '제발 서버 확장 좀 하세요 앱에 한번 들어가려면 하루종일 걸림',
#        '지금껏 잘 사용하고있었는데 오늘 업데이트 해야 사용가능이란 문구이후로 하루종일 업그레이드 안되고있네요~ 다른 충전방법이 있나요?',
#        'ㅁ뭐고 왜이래 불편노\n노답이네', '수도권꺼보다 불편함 부산이라서 그런가요?',
#        '저희어머니가 동백전잘쓰고있는데 회사바뀌면서 먹통이되서 다시 앱 깔려고하니 앱 이 깔리지도않고 하나은행찾아가서 해지하고 잔고돌려받으려힌니 자기들은권한없다네요? 장난합니까?',
#        '앱 자체도 너무느리고 업데이트 하래서 할랫더니 하루종일 대기중.. 잔액충전할랫더니 쓰지도못하겟네요',
#        '어플이 너무 난잡함 사용내역 충전내역 10프로 추가된것 다 따로 볼 수 있길 바람', '이전 앱보다 훨씬 불편함',
#        '다운이안받아지네요', '앱다운이 안됩니다',
#        '간편가입해ㅗ사용하라더만또무슨카드신청을또해야하는건지?기존카드는??설명을정확하게합시다',
#        '어플이 단순화되면 좋겠음 너무 복잡해서 보기 불편함\n별 하나도 아깝.',
#        '기존것보다 쓰기도 불편해 유저들이 불편하다고 해도 수정보완할 생각은 없고 어떻게 이런 업체가 선정되었는지 참 이해가 안되네',
#        '업데이트 하루종일 안되고 뭐에요?',
#        '와 어플도 뭐 찐따처럼 만들어놓고 카드까지 필수발급에 ㄷㄷㄷ 그냥 할말이 없다 할말이 ㄷㄷ 0점 주려고 들어갔는데 최소가 1점이네... 대체 누구 머리에서 이렇게 바꿧는지 참 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        'lg알뜰폰 본인인증실패라고 대화상자 나와서 본인인증을 시도할 수가 없네요 => 그래서 앱을 아예 못씀.. => 오늘 다시 하니까 되네요 아 근데 캐시백에 만원이 없어진거 같습니다..?',
#        '이전 앱 대비 실제 추가된 기능은 소득공제 신청 하나뿐인거 같은데 메뉴는 매우 복잡하고 사용하기 힘들게 변함.',
#        '이전게 훨신~~~~더 나음 인터페이스 불편 소득공제 따로신청 등...',
#        '업데이트 안하면 사용안된다고 해서 업데이트 눌렀더니 하루 종일 대기중이네요. 어서 좀 해결해주세요',
#        '무슨 앱이 이렇나요? 그냥 전에 업체 앱이랑 인터페이스를 똑같이 하세요. 이거 뭐 복잡해서 알아볼수가 없네요. 새로 나온 실물카드는 뭐 어떻게 쓰는지도 모르겠네요..',
#        '현금인출기능이 없어가 불편함',
#        '쓰기 불편해요ㅠ 지난번 앱처럼 만들어주세요ㅠ 불필요한거 다빼고 돈쓴내역 잘보이게요 ㅠㅠ',
#        '왜 바꿨는지. 전보다 사용하기 넘 불편하네요', '쿠폰주고 cu 매장가면 전카드 버린카드가져오라고함 어이없음',
#        '장난치심? 기존카드 쓸 수 있게한다면서 먼 지롤이심? 나는 옛날카드 계속 쓸거고 삼성페이도 써야되니깐 빨리 되게 해놓으시오!!!',
#        '부산 탁상공론의 대표적인 예가 동백전이 될듯 기존카드를 왜 전부다시받아야되는지 이해가안되며 이전 앱보다 불편함',
#        '본인인증이 휴대폰말고 아이핀이나 공인인증도 추가되었음 합니다.', '하루종일 앱이 실행이 안되요~',
#        '급하게 만든거 엄청티나네 안정성 엉망임', '이런 인터페이스는 내가 그림판으로 만들어도 10배는 잘만들 자신있다.',
#        '앱 설치후 화원가입시 기존 동백전 카드 이관 및 잔액이관이 가능하다 해 놓고 실제 앱 설치후 진행해 보니 카드이관 신청시 신규카드 발행을 하지 않으면 진행이 안되게 해두면 어쩌자는 겁니까? 상담전화는 하루종일 리다이얼 해 놓고 기다려 봤는데 통화불가능(4월5일에 업무시간중 하루종일) 하고 뭐 하자는 겁니까',
#        '동백전 어플 다운이 안됩니다',
#        '인터페이스 접근성 최악.. 화면이 너무너무 정신없어요\n핵심기능만 있으면 됐지 왜 쓸데없는 배너들을 많이 넣는지 이해가 안 가네요\n전에 쓰던 앱이 훨씬 낫습니다',
#        '현재 시각 1시간째 먹통이네요ㅡㅡ 식구들이랑 외식하고 동백전으로 계산할려니 앱도 안열리고 도무지 카드를 쓰라는건지 말라는건지..충전을 할수잇게 해줘야지 될거 아닙니까? ㅡㅡ',
#        '걸제불가능한 곳에 대한 정보 제공이 필요함', '너무 불편'], dtype=object)

# %% [markdown]
# #### 토픽별 감성분석
#
# - KnuSentiLex 감성사전 이용 https://github.com/park1200656/KnuSentiLex/blob/master/KnuSentiLex/SentiWord_Dict.txt
# - -2, -1, 0, 1, 2 감성값에 해당하는 단어들이 있는지 보고, 각 토픽별 총 감성점수를 내는 방식
# - __R에서 진행__ https://rpubs.com/shinhaenglee/767595 코드 참고

# %% [markdown]
# #### 워드 클라우드
#
# - 앞서 전처리 과정에서 형태소 분석기로 명사 추출 후 불용어 제거한 단어들로 word cloud 시각화
# - 서버에서는 한글이 보이지 않는 현상 -> 주피터 노트북에서 진행하기 위해 명사들을 df 형태로 바꾼 뒤 csv 파일로 저장해서 옮기기

# %%
nouns[:5]
# Out:
# [['시작', '악성코드', '발견', '해킹', '당한', '불안', '악성코드', '불안'],
#  ['와이파이', '유튜브', '네트워크', '연결', '이후', '한번', '카드', '신청', '연결', '문제', '해결'],
#  ['문제',
#   '몇개',
#   '사용',
#   '알림',
#   '아직까지',
#   '아직',
#   '개선',
#   '이해',
#   '이전',
#   '가맹점',
#   '정보',
#   '조회',
#   '정확',
#   '가맹점',
#   '맥도날드',
#   '부산시',
#   '청점',
#   '이전',
#   '결제',
#   '어제',
#   '남편',
#   '올해',
#   '결제',
#   '가능',
#   '남편',
#   '말로',
#   '결제',
#   '가능',
#   '가맹점',
#   '확인',
#   '검색',
#   '맥도날드',
#   '부산시',
#   '청점',
#   '결제',
#   '가능',
#   '불구',
#   '이전',
#   '가맹점',
#   '검색',
#   '가능',
#   '인터넷',
#   '검색',
#   '불편',
#   '가능',
#   '기만',
#   '이전',
#   '사용',
#   '도입',
#   '사용',
#   '알림',
#   '이해'],
#  ['업데이트', '사용', '가능', '업데이트', '문제'],
#  ['계속', '로드', '아직', '다운중']]

# %%
# 중첩리스트 제거

noun_list = []
for i in range(len(nouns)):
    for j in range(len(nouns[i])):
        noun_list.append(nouns[i][j])

# %%
x = pd.DataFrame(noun_list)

x
# Out:
#           0
# 0        시작
# 1      악성코드
# 2        발견
# 3        해킹
# 4        당한
# ...     ...
# 12564    불어
# 12565   오륙도
# 12566    은기
# 12567    추가
# 12568    부탁
#
# [12569 rows x 1 columns]

# %% [raw]
# x.to_csv('word cloud nouns_negative.csv', index=False)
