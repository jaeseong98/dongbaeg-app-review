# %%
import pickle
from pprint import pprint
import pandas as pd

# %%
with open("D:/cleaned_data.pk", "rb") as f:
    data = pickle.load(f)
    
data.reset_index(drop=True, inplace=True)
print(data.head())
print(data.info())
# Out:
#          DATE  STAR                                             REVIEW  LIKE
# 0  2019-12-27     5  부산에도 기다리던 지역화폐가 나왔네요 앱도 깔끔하고 카드도 바로 신청하고 잘 사용하...     8
# 1  2019-12-27     5                                                화이팅     4
# 2  2019-12-28     5                                   기다렸었는데 앞으로 잘 쓸게요     4
# 3  2019-12-28     5      동백전으로 여기저기 많이 사용해 볼게요 부산 경제에도 많은 도움이 되면 좋겠습니다     4
# 4  2019-12-28     5              부산 동백전 쓰기 편하게 잘 만들어졌네요 부산에서 혜택이 많았겠네요     5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    2752 non-null   object
#  1   STAR    2752 non-null   int64
#  2   REVIEW  2752 non-null   object
#  3   LIKE    2752 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 86.1+ KB
# None

# %%
##Date column을 pandas.Datetime으로 변환
data['DATE'] = pd.to_datetime(data['DATE'])
# Date column을 index로 설정
data = data.set_index("DATE")
data.()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-f2ca88afa1cc> in <module>
#       1 ##Date column을 pandas.Datetime으로 변환
# ----> 2 data['DATE'] = pd.to_datetime(data['DATE'])
#       3 # Date column을 index로 설정
#       4 data = data.set_index("DATE")
#       5 data.tail()
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\envs\textmining\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE'

# %%
data.tail()
# Out:
#             STAR                                             REVIEW  LIKE
# DATE
# 2021-07-21     3                         업데이트가안되요 설정에서 데이터 삭제했는데두요      0
# 2021-07-21     5                       다 좋긴한데 빠른시일내에 삼성페이 연동되길 바랍니다     0
# 2021-07-21     1  로코 정책지원금 사용할수있게 해주세여 정책지원금이라고 이벤트성으로 들어온 적립금이 ...     0
# 2021-07-22     1  로코 이벤트라고 3천원 주더니 사용조건이 충전금 전액사용 이후에 카드캐시네 자동충전...     1
# 2021-07-23     4                                  부산에서 사용해서는 정말 좋아요     0

# %%
## 4월을 기준으로 나누기
before_4 = data['2019-12-27' : '2021-03-31']
after_4 = data['2021-04-01': '2021-7-23']

# %%
# 확인해보기
print(before_4.info())
print(after_4.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1707 entries, 2019-12-27 to 2021-03-31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   STAR    1707 non-null   int64
#  1   REVIEW  1707 non-null   object
#  2   LIKE    1707 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 53.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1045 entries, 2021-04-01 to 2021-07-23
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   STAR    1045 non-null   int64
#  1   REVIEW  1045 non-null   object
#  2   LIKE    1045 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 32.7+ KB
# None

# %%
## 나눈 시점부터 리뷰 가져오기
slice0 = [review for review in list(before_4['REVIEW'])]
slice1 = [review for review in list(after_4['REVIEW'])]

# %%
# 확인해보기
print(slice0[:5])
print(slice1[:5])
# Out:
# ['부산에도 기다리던 지역화폐가 나왔네요 앱도 깔끔하고 카드도 바로 신청하고 잘 사용하겠습니다', '화이팅', '기다렸었는데 앞으로 잘 쓸게요', '동백전으로 여기저기 많이 사용해 볼게요 부산 경제에도 많은 도움이 되면 좋겠습니다', '부산 동백전 쓰기 편하게 잘 만들어졌네요 부산에서 혜택이 많았겠네요']
# ['도성무', '동백전 카드에 있는 돈을 쓸수 있는건가요 이관 될 줄 몰랐는데요', '좋아요', '굿', '새로운동백전 기대가 큽니다']

# %%
import nltk

total_tokens = [token for doc in slice0 for token in doc.split()]
print(len(total_tokens))
# Out:
# 12160

# %%
text = nltk.Text(total_tokens, name='NMSC')
print(len(set(text.tokens)))
pprint(text.vocab().most_common(10))
# Out:
# 6293
# [('좋아요', 260),
#  ('너무', 97),
#  ('동백전', 95),
#  ('잘', 94),
#  ('굿', 67),
#  ('앱', 65),
#  ('계속', 65),
#  ('다시', 62),
#  ('네트워크', 57),
#  ('접속이', 52)]

# %%
import matplotlib.pyplot as plt
import platform
from matplotlib import font_manager, rc
# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

plt.figure(figsize=(16, 10))
text.plot(50)

# %%
from wordcloud import WordCloud

wc = text.vocab().most_common(100)

# for win : font_path='c:/Windows/Fonts/malgun.ttf'
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      #stopwords=STOPWORDS,
                      background_color='white',
                      ).generate_from_frequencies(dict(wc))
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import nltk

total_tokens = [token for doc in slice1 for token in doc.split()]
print(len(total_tokens))
# Out:
# 18567

# %%
text = nltk.Text(total_tokens, name='NMSC')
print(len(set(text.tokens)))
pprint(text.vocab().most_common(10))
# Out:
# 8858
# [('왜', 166),
#  ('카드', 164),
#  ('동백전', 162),
#  ('너무', 128),
#  ('기존', 105),
#  ('수', 93),
#  ('앱', 88),
#  ('진짜', 75),
#  ('더', 74),
#  ('이전', 74)]

# %%
import matplotlib.pyplot as plt
import platform
from matplotlib import font_manager, rc
# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

plt.figure(figsize=(16, 10))
text.plot(50)

# %%
from wordcloud import WordCloud

wc = text.vocab().most_common(100)

# for win : font_path='c:/Windows/Fonts/malgun.ttf'
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      #stopwords=STOPWORDS,
                      background_color='white',
                      ).generate_from_frequencies(dict(wc))
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
